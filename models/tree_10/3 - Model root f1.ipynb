# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Blues':0, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Blues', 2: 'Country', 3: 'Disco', 4: 'Hip-Hop', 5: 'Jazz', 6: 'Metal', 7: 'Pop', 8: 'Reggae', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((7190, 128, 128), (7190, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((900, 128, 128), (900, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Disco

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation='softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_10/model_root_f1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_10/model_root_f1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 9
n_splits = 10

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    dict_genres_list = list(dict_genres.values())
    split = [[dict_genres_list.pop(fold_no - 1)], dict_genres_list]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Blues'], ['Country', 'Disco', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 228/228 [==============================] - 8s 23ms/step - loss: 0.3902 - accuracy: 0.8816 - val_loss: 0.3566 - val_accuracy: 0.8888
#
# Epoch 00001: val_accuracy improved from -inf to 0.88875, saving model to ./models/tree_10/model_root_f1/folder1\model.h5
# Epoch 2/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.3293 - accuracy: 0.8908 - val_loss: 0.3052 - val_accuracy: 0.8900
#
# Epoch 00002: val_accuracy improved from 0.88875 to 0.88999, saving model to ./models/tree_10/model_root_f1/folder1\model.h5
# Epoch 3/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.2817 - accuracy: 0.8926 - val_loss: 0.2938 - val_accuracy: 0.8702
#
# Epoch 00003: val_accuracy did not improve from 0.88999
# Epoch 4/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.2477 - accuracy: 0.9000 - val_loss: 0.2421 - val_accuracy: 0.9036
#
# Epoch 00004: val_accuracy improved from 0.88999 to 0.90358, saving model to ./models/tree_10/model_root_f1/folder1\model.h5
# Epoch 5/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.2079 - accuracy: 0.9161 - val_loss: 0.2250 - val_accuracy: 0.9159
#
# Epoch 00005: val_accuracy improved from 0.90358 to 0.91595, saving model to ./models/tree_10/model_root_f1/folder1\model.h5
# Epoch 6/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.1783 - accuracy: 0.9294 - val_loss: 0.1933 - val_accuracy: 0.9234
#
# Epoch 00006: val_accuracy improved from 0.91595 to 0.92336, saving model to ./models/tree_10/model_root_f1/folder1\model.h5
# Epoch 7/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.1438 - accuracy: 0.9434 - val_loss: 0.1822 - val_accuracy: 0.9308
#
# Epoch 00007: val_accuracy improved from 0.92336 to 0.93078, saving model to ./models/tree_10/model_root_f1/folder1\model.h5
# Epoch 8/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.1281 - accuracy: 0.9485 - val_loss: 0.2093 - val_accuracy: 0.9357
#
# Epoch 00008: val_accuracy improved from 0.93078 to 0.93572, saving model to ./models/tree_10/model_root_f1/folder1\model.h5
# Epoch 9/30
# 228/228 [==============================] - 4s 20ms/step - loss: 0.1047 - accuracy: 0.9600 - val_loss: 0.1821 - val_accuracy: 0.9394
#
# Epoch 00009: val_accuracy improved from 0.93572 to 0.93943, saving model to ./models/tree_10/model_root_f1/folder1\model.h5
# Epoch 10/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0775 - accuracy: 0.9717 - val_loss: 0.2485 - val_accuracy: 0.8986
#
# Epoch 00010: val_accuracy did not improve from 0.93943
# Epoch 11/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0707 - accuracy: 0.9738 - val_loss: 0.1660 - val_accuracy: 0.9370
#
# Epoch 00011: val_accuracy did not improve from 0.93943
# Epoch 12/30
# 228/228 [==============================] - 4s 20ms/step - loss: 0.0495 - accuracy: 0.9839 - val_loss: 0.2554 - val_accuracy: 0.9333
#
# Epoch 00012: val_accuracy did not improve from 0.93943
# Epoch 13/30
# 228/228 [==============================] - 4s 20ms/step - loss: 0.0352 - accuracy: 0.9878 - val_loss: 0.1842 - val_accuracy: 0.9370
#
# Epoch 00013: val_accuracy did not improve from 0.93943
# Epoch 14/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0296 - accuracy: 0.9891 - val_loss: 0.2709 - val_accuracy: 0.9394
#
# Epoch 00014: val_accuracy did not improve from 0.93943
# Epoch 15/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0202 - accuracy: 0.9931 - val_loss: 0.2633 - val_accuracy: 0.9370
#
# Epoch 00015: val_accuracy did not improve from 0.93943
# Epoch 16/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0196 - accuracy: 0.9924 - val_loss: 0.3466 - val_accuracy: 0.9357
#
# Epoch 00016: val_accuracy did not improve from 0.93943
# Epoch 17/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0496 - accuracy: 0.9809 - val_loss: 0.2139 - val_accuracy: 0.9518
#
# Epoch 00017: val_accuracy improved from 0.93943 to 0.95179, saving model to ./models/tree_10/model_root_f1/folder1\model.h5
# Epoch 18/30
# 228/228 [==============================] - 4s 20ms/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 0.3023 - val_accuracy: 0.9382
#
# Epoch 00018: val_accuracy did not improve from 0.95179
# Epoch 19/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.2897 - val_accuracy: 0.9431
#
# Epoch 00019: val_accuracy did not improve from 0.95179
# Epoch 20/30
# 228/228 [==============================] - 4s 20ms/step - loss: 7.4862e-04 - accuracy: 1.0000 - val_loss: 0.2930 - val_accuracy: 0.9444
#
# Epoch 00020: val_accuracy did not improve from 0.95179
# Epoch 21/30
# 228/228 [==============================] - 4s 20ms/step - loss: 1.9002e-04 - accuracy: 1.0000 - val_loss: 0.2943 - val_accuracy: 0.9468
#
# Epoch 00021: val_accuracy did not improve from 0.95179
# Epoch 22/30
# 228/228 [==============================] - 5s 20ms/step - loss: 1.0911e-04 - accuracy: 1.0000 - val_loss: 0.3058 - val_accuracy: 0.9493
#
# Epoch 00022: val_accuracy did not improve from 0.95179
# Epoch 23/30
# 228/228 [==============================] - 4s 20ms/step - loss: 8.3582e-05 - accuracy: 1.0000 - val_loss: 0.3125 - val_accuracy: 0.9506
#
# Epoch 00023: val_accuracy did not improve from 0.95179
# Epoch 24/30
# 228/228 [==============================] - 4s 20ms/step - loss: 6.7467e-05 - accuracy: 1.0000 - val_loss: 0.3165 - val_accuracy: 0.9493
#
# Epoch 00024: val_accuracy did not improve from 0.95179
# Epoch 25/30
# 228/228 [==============================] - 5s 20ms/step - loss: 5.6038e-05 - accuracy: 1.0000 - val_loss: 0.3198 - val_accuracy: 0.9493
#
# Epoch 00025: val_accuracy did not improve from 0.95179
# Epoch 26/30
# 228/228 [==============================] - 5s 20ms/step - loss: 4.6932e-05 - accuracy: 1.0000 - val_loss: 0.3176 - val_accuracy: 0.9506
#
# Epoch 00026: val_accuracy did not improve from 0.95179
# Epoch 27/30
# 228/228 [==============================] - 4s 20ms/step - loss: 3.9805e-05 - accuracy: 1.0000 - val_loss: 0.3260 - val_accuracy: 0.9506
#
# Epoch 00027: val_accuracy did not improve from 0.95179
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 28/30
# 228/228 [==============================] - 5s 20ms/step - loss: 3.3907e-05 - accuracy: 1.0000 - val_loss: 0.3250 - val_accuracy: 0.9506
#
# Epoch 00028: val_accuracy did not improve from 0.95179
# Epoch 29/30
# 228/228 [==============================] - 5s 20ms/step - loss: 3.1262e-05 - accuracy: 1.0000 - val_loss: 0.3282 - val_accuracy: 0.9506
#
# Epoch 00029: val_accuracy did not improve from 0.95179
# Epoch 30/30
# 228/228 [==============================] - 5s 20ms/step - loss: 2.8487e-05 - accuracy: 1.0000 - val_loss: 0.3242 - val_accuracy: 0.9506
#
# Epoch 00030: val_accuracy did not improve from 0.95179
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Country'], ['Blues', 'Disco', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.3408 - accuracy: 0.8844 - val_loss: 0.2540 - val_accuracy: 0.8999
#
# Epoch 00001: val_accuracy improved from -inf to 0.89988, saving model to ./models/tree_10/model_root_f1/folder2\model.h5
# Epoch 2/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.2572 - accuracy: 0.8936 - val_loss: 0.2550 - val_accuracy: 0.8974
#
# Epoch 00002: val_accuracy did not improve from 0.89988
# Epoch 3/30
# 228/228 [==============================] - 4s 20ms/step - loss: 0.2297 - accuracy: 0.9029 - val_loss: 0.2046 - val_accuracy: 0.9135
#
# Epoch 00003: val_accuracy improved from 0.89988 to 0.91347, saving model to ./models/tree_10/model_root_f1/folder2\model.h5
# Epoch 4/30
# 228/228 [==============================] - 4s 20ms/step - loss: 0.2109 - accuracy: 0.9137 - val_loss: 0.1842 - val_accuracy: 0.9234
#
# Epoch 00004: val_accuracy improved from 0.91347 to 0.92336, saving model to ./models/tree_10/model_root_f1/folder2\model.h5
# Epoch 5/30
# 228/228 [==============================] - 4s 20ms/step - loss: 0.1913 - accuracy: 0.9201 - val_loss: 0.2158 - val_accuracy: 0.8962
#
# Epoch 00005: val_accuracy did not improve from 0.92336
# Epoch 6/30
# 228/228 [==============================] - 4s 20ms/step - loss: 0.1706 - accuracy: 0.9304 - val_loss: 0.1584 - val_accuracy: 0.9407
#
# Epoch 00006: val_accuracy improved from 0.92336 to 0.94067, saving model to ./models/tree_10/model_root_f1/folder2\model.h5
# Epoch 7/30
# 228/228 [==============================] - 4s 20ms/step - loss: 0.1487 - accuracy: 0.9431 - val_loss: 0.1455 - val_accuracy: 0.9357
#
# Epoch 00007: val_accuracy did not improve from 0.94067
# Epoch 8/30
# 228/228 [==============================] - 4s 20ms/step - loss: 0.1258 - accuracy: 0.9501 - val_loss: 0.1557 - val_accuracy: 0.9320
#
# Epoch 00008: val_accuracy did not improve from 0.94067
# Epoch 9/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.1089 - accuracy: 0.9600 - val_loss: 0.1445 - val_accuracy: 0.9431
#
# Epoch 00009: val_accuracy improved from 0.94067 to 0.94314, saving model to ./models/tree_10/model_root_f1/folder2\model.h5
# Epoch 10/30
# 228/228 [==============================] - 4s 20ms/step - loss: 0.0915 - accuracy: 0.9654 - val_loss: 0.1526 - val_accuracy: 0.9419
#
# Epoch 00010: val_accuracy did not improve from 0.94314
# Epoch 11/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0817 - accuracy: 0.9679 - val_loss: 0.1528 - val_accuracy: 0.9456
#
# Epoch 00011: val_accuracy improved from 0.94314 to 0.94561, saving model to ./models/tree_10/model_root_f1/folder2\model.h5
# Epoch 12/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0580 - accuracy: 0.9797 - val_loss: 0.1884 - val_accuracy: 0.9345
#
# Epoch 00012: val_accuracy did not improve from 0.94561
# Epoch 13/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0491 - accuracy: 0.9809 - val_loss: 0.1486 - val_accuracy: 0.9456
#
# Epoch 00013: val_accuracy did not improve from 0.94561
# Epoch 14/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0277 - accuracy: 0.9907 - val_loss: 0.2061 - val_accuracy: 0.9431
#
# Epoch 00014: val_accuracy did not improve from 0.94561
# Epoch 15/30
# 228/228 [==============================] - 5s 23ms/step - loss: 0.0284 - accuracy: 0.9883 - val_loss: 0.2177 - val_accuracy: 0.9468
#
# Epoch 00015: val_accuracy improved from 0.94561 to 0.94685, saving model to ./models/tree_10/model_root_f1/folder2\model.h5
# Epoch 16/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0323 - accuracy: 0.9881 - val_loss: 0.2051 - val_accuracy: 0.9382
#
# Epoch 00016: val_accuracy did not improve from 0.94685
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 17/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0069 - accuracy: 0.9984 - val_loss: 0.2829 - val_accuracy: 0.9419
#
# Epoch 00017: val_accuracy did not improve from 0.94685
# Epoch 18/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2488 - val_accuracy: 0.9444
#
# Epoch 00018: val_accuracy did not improve from 0.94685
# Epoch 19/30
# 228/228 [==============================] - 5s 20ms/step - loss: 6.2444e-04 - accuracy: 1.0000 - val_loss: 0.2645 - val_accuracy: 0.9431
#
# Epoch 00019: val_accuracy did not improve from 0.94685
# Epoch 20/30
# 228/228 [==============================] - 5s 20ms/step - loss: 4.0438e-04 - accuracy: 1.0000 - val_loss: 0.2859 - val_accuracy: 0.9444
#
# Epoch 00020: val_accuracy did not improve from 0.94685
# Epoch 21/30
# 228/228 [==============================] - 5s 20ms/step - loss: 2.8914e-04 - accuracy: 1.0000 - val_loss: 0.2947 - val_accuracy: 0.9444
#
# Epoch 00021: val_accuracy did not improve from 0.94685
# Epoch 22/30
# 228/228 [==============================] - 5s 20ms/step - loss: 2.1958e-04 - accuracy: 1.0000 - val_loss: 0.3112 - val_accuracy: 0.9456
#
# Epoch 00022: val_accuracy did not improve from 0.94685
# Epoch 23/30
# 228/228 [==============================] - 5s 20ms/step - loss: 1.7604e-04 - accuracy: 1.0000 - val_loss: 0.3150 - val_accuracy: 0.9456
#
# Epoch 00023: val_accuracy did not improve from 0.94685
# Epoch 24/30
# 228/228 [==============================] - 5s 20ms/step - loss: 1.3565e-04 - accuracy: 1.0000 - val_loss: 0.3303 - val_accuracy: 0.9456
#
# Epoch 00024: val_accuracy did not improve from 0.94685
# Epoch 25/30
# 228/228 [==============================] - 5s 20ms/step - loss: 1.1498e-04 - accuracy: 1.0000 - val_loss: 0.3310 - val_accuracy: 0.9456
#
# Epoch 00025: val_accuracy did not improve from 0.94685
# Epoch 26/30
# 228/228 [==============================] - 5s 21ms/step - loss: 9.2376e-05 - accuracy: 1.0000 - val_loss: 0.3375 - val_accuracy: 0.9431
#
# Epoch 00026: val_accuracy did not improve from 0.94685
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 27/30
# 228/228 [==============================] - 5s 20ms/step - loss: 7.7157e-05 - accuracy: 1.0000 - val_loss: 0.3397 - val_accuracy: 0.9456
#
# Epoch 00027: val_accuracy did not improve from 0.94685
# Epoch 28/30
# 228/228 [==============================] - 5s 20ms/step - loss: 6.9991e-05 - accuracy: 1.0000 - val_loss: 0.3466 - val_accuracy: 0.9456
#
# Epoch 00028: val_accuracy did not improve from 0.94685
# Epoch 29/30
# 228/228 [==============================] - 5s 20ms/step - loss: 6.4371e-05 - accuracy: 1.0000 - val_loss: 0.3482 - val_accuracy: 0.9456
#
# Epoch 00029: val_accuracy did not improve from 0.94685
# Epoch 30/30
# 228/228 [==============================] - 4s 20ms/step - loss: 5.8471e-05 - accuracy: 1.0000 - val_loss: 0.3483 - val_accuracy: 0.9431
#
# Epoch 00030: val_accuracy did not improve from 0.94685
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Disco'], ['Blues', 'Country', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.3849 - accuracy: 0.8815 - val_loss: 0.3426 - val_accuracy: 0.8850
#
# Epoch 00001: val_accuracy improved from -inf to 0.88504, saving model to ./models/tree_10/model_root_f1/folder3\model.h5
# Epoch 2/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.3333 - accuracy: 0.8892 - val_loss: 0.3236 - val_accuracy: 0.8850
#
# Epoch 00002: val_accuracy did not improve from 0.88504
# Epoch 3/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.3166 - accuracy: 0.8882 - val_loss: 0.3087 - val_accuracy: 0.8850
#
# Epoch 00003: val_accuracy did not improve from 0.88504
# Epoch 4/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.2843 - accuracy: 0.8894 - val_loss: 0.2792 - val_accuracy: 0.8863
#
# Epoch 00004: val_accuracy improved from 0.88504 to 0.88628, saving model to ./models/tree_10/model_root_f1/folder3\model.h5
# Epoch 5/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.2331 - accuracy: 0.9117 - val_loss: 0.2230 - val_accuracy: 0.9184
#
# Epoch 00005: val_accuracy improved from 0.88628 to 0.91842, saving model to ./models/tree_10/model_root_f1/folder3\model.h5
# Epoch 6/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.1668 - accuracy: 0.9379 - val_loss: 0.1676 - val_accuracy: 0.9444
#
# Epoch 00006: val_accuracy improved from 0.91842 to 0.94438, saving model to ./models/tree_10/model_root_f1/folder3\model.h5
# Epoch 7/30
# 228/228 [==============================] - 4s 20ms/step - loss: 0.1307 - accuracy: 0.9528 - val_loss: 0.1629 - val_accuracy: 0.9555
#
# Epoch 00007: val_accuracy improved from 0.94438 to 0.95550, saving model to ./models/tree_10/model_root_f1/folder3\model.h5
# Epoch 8/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.1154 - accuracy: 0.9599 - val_loss: 0.1902 - val_accuracy: 0.9357
#
# Epoch 00008: val_accuracy did not improve from 0.95550
# Epoch 9/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0922 - accuracy: 0.9674 - val_loss: 0.1215 - val_accuracy: 0.9604
#
# Epoch 00009: val_accuracy improved from 0.95550 to 0.96044, saving model to ./models/tree_10/model_root_f1/folder3\model.h5
# Epoch 10/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0724 - accuracy: 0.9747 - val_loss: 0.1125 - val_accuracy: 0.9679
#
# Epoch 00010: val_accuracy improved from 0.96044 to 0.96786, saving model to ./models/tree_10/model_root_f1/folder3\model.h5
# Epoch 11/30
# 228/228 [==============================] - 4s 20ms/step - loss: 0.0595 - accuracy: 0.9795 - val_loss: 0.1628 - val_accuracy: 0.9592
#
# Epoch 00011: val_accuracy did not improve from 0.96786
# Epoch 12/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0432 - accuracy: 0.9853 - val_loss: 0.0966 - val_accuracy: 0.9679
#
# Epoch 00012: val_accuracy did not improve from 0.96786
# Epoch 13/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0380 - accuracy: 0.9874 - val_loss: 0.1354 - val_accuracy: 0.9567
#
# Epoch 00013: val_accuracy did not improve from 0.96786
# Epoch 14/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0323 - accuracy: 0.9879 - val_loss: 0.1274 - val_accuracy: 0.9642
#
# Epoch 00014: val_accuracy did not improve from 0.96786
# Epoch 15/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0209 - accuracy: 0.9924 - val_loss: 0.1240 - val_accuracy: 0.9679
#
# Epoch 00015: val_accuracy did not improve from 0.96786
# Epoch 16/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0221 - accuracy: 0.9911 - val_loss: 0.1500 - val_accuracy: 0.9654
#
# Epoch 00016: val_accuracy did not improve from 0.96786
# Epoch 17/30
# 228/228 [==============================] - 4s 20ms/step - loss: 0.0140 - accuracy: 0.9953 - val_loss: 0.1380 - val_accuracy: 0.9740
#
# Epoch 00017: val_accuracy improved from 0.96786 to 0.97404, saving model to ./models/tree_10/model_root_f1/folder3\model.h5
# Epoch 18/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0124 - accuracy: 0.9959 - val_loss: 0.1696 - val_accuracy: 0.9691
#
# Epoch 00018: val_accuracy did not improve from 0.97404
# Epoch 19/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0356 - accuracy: 0.9886 - val_loss: 0.2079 - val_accuracy: 0.9555
#
# Epoch 00019: val_accuracy did not improve from 0.97404
# Epoch 20/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0270 - accuracy: 0.9912 - val_loss: 0.1449 - val_accuracy: 0.9716
#
# Epoch 00020: val_accuracy did not improve from 0.97404
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0022 - accuracy: 0.9999 - val_loss: 0.1629 - val_accuracy: 0.9716
#
# Epoch 00021: val_accuracy did not improve from 0.97404
# Epoch 22/30
# 228/228 [==============================] - 5s 20ms/step - loss: 6.6024e-04 - accuracy: 1.0000 - val_loss: 0.1703 - val_accuracy: 0.9716
#
# Epoch 00022: val_accuracy did not improve from 0.97404
# Epoch 23/30
# 228/228 [==============================] - 4s 20ms/step - loss: 4.2598e-04 - accuracy: 1.0000 - val_loss: 0.1765 - val_accuracy: 0.9716
#
# Epoch 00023: val_accuracy did not improve from 0.97404
# Epoch 24/30
# 228/228 [==============================] - 5s 20ms/step - loss: 3.1646e-04 - accuracy: 1.0000 - val_loss: 0.1780 - val_accuracy: 0.9703
#
# Epoch 00024: val_accuracy did not improve from 0.97404
# Epoch 25/30
# 228/228 [==============================] - 5s 20ms/step - loss: 2.4410e-04 - accuracy: 1.0000 - val_loss: 0.1793 - val_accuracy: 0.9703
#
# Epoch 00025: val_accuracy did not improve from 0.97404
# Epoch 26/30
# 228/228 [==============================] - 5s 20ms/step - loss: 1.9847e-04 - accuracy: 1.0000 - val_loss: 0.1866 - val_accuracy: 0.9716
#
# Epoch 00026: val_accuracy did not improve from 0.97404
# Epoch 27/30
# 228/228 [==============================] - 4s 20ms/step - loss: 1.6106e-04 - accuracy: 1.0000 - val_loss: 0.1836 - val_accuracy: 0.9679
#
# Epoch 00027: val_accuracy did not improve from 0.97404
# Epoch 28/30
# 228/228 [==============================] - 5s 20ms/step - loss: 1.3766e-04 - accuracy: 1.0000 - val_loss: 0.1882 - val_accuracy: 0.9691
#
# Epoch 00028: val_accuracy did not improve from 0.97404
# Epoch 29/30
# 228/228 [==============================] - 5s 20ms/step - loss: 1.1308e-04 - accuracy: 1.0000 - val_loss: 0.1961 - val_accuracy: 0.9716
#
# Epoch 00029: val_accuracy did not improve from 0.97404
# Epoch 30/30
# 228/228 [==============================] - 5s 21ms/step - loss: 9.6128e-05 - accuracy: 1.0000 - val_loss: 0.2010 - val_accuracy: 0.9716
#
# Epoch 00030: val_accuracy did not improve from 0.97404
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Hip-Hop'], ['Blues', 'Country', 'Disco', 'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 228/228 [==============================] - 6s 23ms/step - loss: 0.3781 - accuracy: 0.8797 - val_loss: 0.3467 - val_accuracy: 0.8937
#
# Epoch 00001: val_accuracy improved from -inf to 0.89370, saving model to ./models/tree_10/model_root_f1/folder4\model.h5
# Epoch 2/30
# 228/228 [==============================] - 5s 22ms/step - loss: 0.2497 - accuracy: 0.8916 - val_loss: 0.1982 - val_accuracy: 0.9073
#
# Epoch 00002: val_accuracy improved from 0.89370 to 0.90729, saving model to ./models/tree_10/model_root_f1/folder4\model.h5
# Epoch 3/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.1955 - accuracy: 0.9203 - val_loss: 0.1469 - val_accuracy: 0.9481
#
# Epoch 00003: val_accuracy improved from 0.90729 to 0.94808, saving model to ./models/tree_10/model_root_f1/folder4\model.h5
# Epoch 4/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.1589 - accuracy: 0.9361 - val_loss: 0.1333 - val_accuracy: 0.9493
#
# Epoch 00004: val_accuracy improved from 0.94808 to 0.94932, saving model to ./models/tree_10/model_root_f1/folder4\model.h5
# Epoch 5/30
# 228/228 [==============================] - 5s 22ms/step - loss: 0.1244 - accuracy: 0.9489 - val_loss: 0.1029 - val_accuracy: 0.9604
#
# Epoch 00005: val_accuracy improved from 0.94932 to 0.96044, saving model to ./models/tree_10/model_root_f1/folder4\model.h5
# Epoch 6/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.1001 - accuracy: 0.9628 - val_loss: 0.1131 - val_accuracy: 0.9617
#
# Epoch 00006: val_accuracy improved from 0.96044 to 0.96168, saving model to ./models/tree_10/model_root_f1/folder4\model.h5
# Epoch 7/30
# 228/228 [==============================] - 5s 22ms/step - loss: 0.0706 - accuracy: 0.9727 - val_loss: 0.1081 - val_accuracy: 0.9666
#
# Epoch 00007: val_accuracy improved from 0.96168 to 0.96663, saving model to ./models/tree_10/model_root_f1/folder4\model.h5
# Epoch 8/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0664 - accuracy: 0.9745 - val_loss: 0.0989 - val_accuracy: 0.9703
#
# Epoch 00008: val_accuracy improved from 0.96663 to 0.97033, saving model to ./models/tree_10/model_root_f1/folder4\model.h5
# Epoch 9/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0451 - accuracy: 0.9838 - val_loss: 0.0862 - val_accuracy: 0.9716
#
# Epoch 00009: val_accuracy improved from 0.97033 to 0.97157, saving model to ./models/tree_10/model_root_f1/folder4\model.h5
# Epoch 10/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0292 - accuracy: 0.9893 - val_loss: 0.0870 - val_accuracy: 0.9740
#
# Epoch 00010: val_accuracy improved from 0.97157 to 0.97404, saving model to ./models/tree_10/model_root_f1/folder4\model.h5
# Epoch 11/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0203 - accuracy: 0.9930 - val_loss: 0.1319 - val_accuracy: 0.9691
#
# Epoch 00011: val_accuracy did not improve from 0.97404
# Epoch 12/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0342 - accuracy: 0.9882 - val_loss: 0.1057 - val_accuracy: 0.9691
#
# Epoch 00012: val_accuracy did not improve from 0.97404
# Epoch 13/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0060 - accuracy: 0.9990 - val_loss: 0.1352 - val_accuracy: 0.9703
#
# Epoch 00013: val_accuracy did not improve from 0.97404
# Epoch 14/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.1330 - val_accuracy: 0.9703
#
# Epoch 00014: val_accuracy did not improve from 0.97404
# Epoch 15/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0203 - accuracy: 0.9938 - val_loss: 0.1778 - val_accuracy: 0.9604
#
# Epoch 00015: val_accuracy did not improve from 0.97404
# Epoch 16/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0354 - accuracy: 0.9886 - val_loss: 0.2404 - val_accuracy: 0.9184
#
# Epoch 00016: val_accuracy did not improve from 0.97404
# Epoch 17/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0198 - accuracy: 0.9927 - val_loss: 0.1952 - val_accuracy: 0.9617
#
# Epoch 00017: val_accuracy did not improve from 0.97404
# Epoch 18/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0109 - accuracy: 0.9963 - val_loss: 0.1341 - val_accuracy: 0.9703
#
# Epoch 00018: val_accuracy did not improve from 0.97404
# Epoch 19/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.1140 - val_accuracy: 0.9740
#
# Epoch 00019: val_accuracy did not improve from 0.97404
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1314 - val_accuracy: 0.9691
#
# Epoch 00020: val_accuracy did not improve from 0.97404
# Epoch 21/30
# 228/228 [==============================] - 5s 20ms/step - loss: 1.4374e-04 - accuracy: 1.0000 - val_loss: 0.1558 - val_accuracy: 0.9666
#
# Epoch 00021: val_accuracy did not improve from 0.97404
# Epoch 22/30
# 228/228 [==============================] - 5s 20ms/step - loss: 9.3805e-05 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9716
#
# Epoch 00022: val_accuracy did not improve from 0.97404
# Epoch 23/30
# 228/228 [==============================] - 5s 20ms/step - loss: 5.7948e-05 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9716
#
# Epoch 00023: val_accuracy did not improve from 0.97404
# Epoch 24/30
# 228/228 [==============================] - 5s 21ms/step - loss: 4.6535e-05 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9716
#
# Epoch 00024: val_accuracy did not improve from 0.97404
# Epoch 25/30
# 228/228 [==============================] - 5s 21ms/step - loss: 3.8333e-05 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9716
#
# Epoch 00025: val_accuracy did not improve from 0.97404
# Epoch 26/30
# 228/228 [==============================] - 5s 22ms/step - loss: 3.3319e-05 - accuracy: 1.0000 - val_loss: 0.1428 - val_accuracy: 0.9716
#
# Epoch 00026: val_accuracy did not improve from 0.97404
# Epoch 27/30
# 228/228 [==============================] - 5s 20ms/step - loss: 2.8464e-05 - accuracy: 1.0000 - val_loss: 0.1440 - val_accuracy: 0.9716
#
# Epoch 00027: val_accuracy did not improve from 0.97404
# Epoch 28/30
# 228/228 [==============================] - 5s 20ms/step - loss: 2.4929e-05 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9716
#
# Epoch 00028: val_accuracy did not improve from 0.97404
# Epoch 29/30
# 228/228 [==============================] - 5s 20ms/step - loss: 2.1523e-05 - accuracy: 1.0000 - val_loss: 0.1455 - val_accuracy: 0.9716
#
# Epoch 00029: val_accuracy did not improve from 0.97404
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 30/30
# 228/228 [==============================] - 5s 20ms/step - loss: 1.9438e-05 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9716
#
# Epoch 00030: val_accuracy did not improve from 0.97404
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 5
# Genre split [['Jazz'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 228/228 [==============================] - 6s 22ms/step - loss: 0.3006 - accuracy: 0.9014 - val_loss: 0.2639 - val_accuracy: 0.8962
#
# Epoch 00001: val_accuracy improved from -inf to 0.89617, saving model to ./models/tree_10/model_root_f1/folder5\model.h5
# Epoch 2/30
# 228/228 [==============================] - 4s 20ms/step - loss: 0.1779 - accuracy: 0.9302 - val_loss: 0.1712 - val_accuracy: 0.9283
#
# Epoch 00002: val_accuracy improved from 0.89617 to 0.92831, saving model to ./models/tree_10/model_root_f1/folder5\model.h5
# Epoch 3/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.1112 - accuracy: 0.9548 - val_loss: 0.1933 - val_accuracy: 0.9419
#
# Epoch 00003: val_accuracy improved from 0.92831 to 0.94190, saving model to ./models/tree_10/model_root_f1/folder5\model.h5
# Epoch 4/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0863 - accuracy: 0.9692 - val_loss: 0.1513 - val_accuracy: 0.9407
#
# Epoch 00004: val_accuracy did not improve from 0.94190
# Epoch 5/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0641 - accuracy: 0.9760 - val_loss: 0.1265 - val_accuracy: 0.9555
#
# Epoch 00005: val_accuracy improved from 0.94190 to 0.95550, saving model to ./models/tree_10/model_root_f1/folder5\model.h5
# Epoch 6/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0453 - accuracy: 0.9827 - val_loss: 0.1820 - val_accuracy: 0.9456
#
# Epoch 00006: val_accuracy did not improve from 0.95550
# Epoch 7/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0260 - accuracy: 0.9896 - val_loss: 0.1619 - val_accuracy: 0.9617
#
# Epoch 00007: val_accuracy improved from 0.95550 to 0.96168, saving model to ./models/tree_10/model_root_f1/folder5\model.h5
# Epoch 8/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0229 - accuracy: 0.9905 - val_loss: 0.1536 - val_accuracy: 0.9679
#
# Epoch 00008: val_accuracy improved from 0.96168 to 0.96786, saving model to ./models/tree_10/model_root_f1/folder5\model.h5
# Epoch 9/30
# 228/228 [==============================] - 5s 22ms/step - loss: 0.0235 - accuracy: 0.9912 - val_loss: 0.1899 - val_accuracy: 0.9654
#
# Epoch 00009: val_accuracy did not improve from 0.96786
# Epoch 10/30
# 228/228 [==============================] - 5s 22ms/step - loss: 0.0316 - accuracy: 0.9881 - val_loss: 0.1333 - val_accuracy: 0.9691
#
# Epoch 00010: val_accuracy improved from 0.96786 to 0.96910, saving model to ./models/tree_10/model_root_f1/folder5\model.h5
# Epoch 11/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.2104 - val_accuracy: 0.9592
#
# Epoch 00011: val_accuracy did not improve from 0.96910
# Epoch 12/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0267 - accuracy: 0.9901 - val_loss: 0.2931 - val_accuracy: 0.9481
#
# Epoch 00012: val_accuracy did not improve from 0.96910
# Epoch 13/30
# 228/228 [==============================] - 5s 22ms/step - loss: 0.0165 - accuracy: 0.9945 - val_loss: 0.2162 - val_accuracy: 0.9592
#
# Epoch 00013: val_accuracy did not improve from 0.96910
# Epoch 14/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0074 - accuracy: 0.9978 - val_loss: 0.2179 - val_accuracy: 0.9592
#
# Epoch 00014: val_accuracy did not improve from 0.96910
# Epoch 15/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.1663 - val_accuracy: 0.9679
#
# Epoch 00015: val_accuracy did not improve from 0.96910
# Epoch 16/30
# 228/228 [==============================] - 5s 21ms/step - loss: 1.5145e-04 - accuracy: 1.0000 - val_loss: 0.1855 - val_accuracy: 0.9703
#
# Epoch 00016: val_accuracy improved from 0.96910 to 0.97033, saving model to ./models/tree_10/model_root_f1/folder5\model.h5
# Epoch 17/30
# 228/228 [==============================] - 5s 20ms/step - loss: 6.5736e-05 - accuracy: 1.0000 - val_loss: 0.1821 - val_accuracy: 0.9679
#
# Epoch 00017: val_accuracy did not improve from 0.97033
# Epoch 18/30
# 228/228 [==============================] - 5s 20ms/step - loss: 3.6508e-05 - accuracy: 1.0000 - val_loss: 0.1837 - val_accuracy: 0.9679
#
# Epoch 00018: val_accuracy did not improve from 0.97033
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 19/30
# 228/228 [==============================] - 5s 21ms/step - loss: 2.8556e-05 - accuracy: 1.0000 - val_loss: 0.1862 - val_accuracy: 0.9679
#
# Epoch 00019: val_accuracy did not improve from 0.97033
# Epoch 20/30
# 228/228 [==============================] - 5s 20ms/step - loss: 2.5612e-05 - accuracy: 1.0000 - val_loss: 0.1886 - val_accuracy: 0.9679
#
# Epoch 00020: val_accuracy did not improve from 0.97033
# Epoch 21/30
# 228/228 [==============================] - 5s 20ms/step - loss: 2.2936e-05 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9679
#
# Epoch 00021: val_accuracy did not improve from 0.97033
# Epoch 22/30
# 228/228 [==============================] - 5s 20ms/step - loss: 2.0410e-05 - accuracy: 1.0000 - val_loss: 0.1914 - val_accuracy: 0.9679
#
# Epoch 00022: val_accuracy did not improve from 0.97033
# Epoch 23/30
# 228/228 [==============================] - 5s 20ms/step - loss: 1.8242e-05 - accuracy: 1.0000 - val_loss: 0.1927 - val_accuracy: 0.9679
#
# Epoch 00023: val_accuracy did not improve from 0.97033
# Epoch 24/30
# 228/228 [==============================] - 5s 20ms/step - loss: 1.6310e-05 - accuracy: 1.0000 - val_loss: 0.1948 - val_accuracy: 0.9679
#
# Epoch 00024: val_accuracy did not improve from 0.97033
# Epoch 25/30
# 228/228 [==============================] - 5s 20ms/step - loss: 1.4560e-05 - accuracy: 1.0000 - val_loss: 0.1968 - val_accuracy: 0.9679
#
# Epoch 00025: val_accuracy did not improve from 0.97033
# Epoch 26/30
# 228/228 [==============================] - 5s 20ms/step - loss: 1.2978e-05 - accuracy: 1.0000 - val_loss: 0.1986 - val_accuracy: 0.9679
#
# Epoch 00026: val_accuracy did not improve from 0.97033
# Epoch 27/30
# 228/228 [==============================] - 5s 20ms/step - loss: 1.1603e-05 - accuracy: 1.0000 - val_loss: 0.1998 - val_accuracy: 0.9691
#
# Epoch 00027: val_accuracy did not improve from 0.97033
# Epoch 28/30
# 228/228 [==============================] - 5s 20ms/step - loss: 1.0378e-05 - accuracy: 1.0000 - val_loss: 0.2003 - val_accuracy: 0.9691
#
# Epoch 00028: val_accuracy did not improve from 0.97033
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 29/30
# 228/228 [==============================] - 5s 20ms/step - loss: 9.3596e-06 - accuracy: 1.0000 - val_loss: 0.2018 - val_accuracy: 0.9691
#
# Epoch 00029: val_accuracy did not improve from 0.97033
# Epoch 30/30
# 228/228 [==============================] - 5s 20ms/step - loss: 8.8105e-06 - accuracy: 1.0000 - val_loss: 0.2034 - val_accuracy: 0.9691
#
# Epoch 00030: val_accuracy did not improve from 0.97033
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 6
# Genre split [['Metal'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Jazz', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.2250 - accuracy: 0.9213 - val_loss: 0.2082 - val_accuracy: 0.9271
#
# Epoch 00001: val_accuracy improved from -inf to 0.92707, saving model to ./models/tree_10/model_root_f1/folder6\model.h5
# Epoch 2/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.1050 - accuracy: 0.9600 - val_loss: 0.1039 - val_accuracy: 0.9654
#
# Epoch 00002: val_accuracy improved from 0.92707 to 0.96539, saving model to ./models/tree_10/model_root_f1/folder6\model.h5
# Epoch 3/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0979 - accuracy: 0.9654 - val_loss: 0.1114 - val_accuracy: 0.9642
#
# Epoch 00003: val_accuracy did not improve from 0.96539
# Epoch 4/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0969 - accuracy: 0.9628 - val_loss: 0.1014 - val_accuracy: 0.9679
#
# Epoch 00004: val_accuracy improved from 0.96539 to 0.96786, saving model to ./models/tree_10/model_root_f1/folder6\model.h5
# Epoch 5/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0792 - accuracy: 0.9705 - val_loss: 0.0987 - val_accuracy: 0.9679
#
# Epoch 00005: val_accuracy did not improve from 0.96786
# Epoch 6/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0802 - accuracy: 0.9714 - val_loss: 0.0856 - val_accuracy: 0.9666
#
# Epoch 00006: val_accuracy did not improve from 0.96786
# Epoch 7/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0809 - accuracy: 0.9725 - val_loss: 0.1002 - val_accuracy: 0.9666
#
# Epoch 00007: val_accuracy did not improve from 0.96786
# Epoch 8/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0735 - accuracy: 0.9729 - val_loss: 0.0871 - val_accuracy: 0.9728
#
# Epoch 00008: val_accuracy improved from 0.96786 to 0.97281, saving model to ./models/tree_10/model_root_f1/folder6\model.h5
# Epoch 9/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0731 - accuracy: 0.9754 - val_loss: 0.1043 - val_accuracy: 0.9679
#
# Epoch 00009: val_accuracy did not improve from 0.97281
# Epoch 10/30
# ...
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 228/228 [==============================] - 5s 22ms/step - loss: 0.3905 - accuracy: 0.8812 - val_loss: 0.3315 - val_accuracy: 0.8962
#
# Epoch 00001: val_accuracy improved from -inf to 0.89617, saving model to ./models/tree_10/model_root_f1/folder8\model.h5
# Epoch 2/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.3241 - accuracy: 0.8896 - val_loss: 0.2595 - val_accuracy: 0.9197
#
# Epoch 00002: val_accuracy improved from 0.89617 to 0.91965, saving model to ./models/tree_10/model_root_f1/folder8\model.h5
# Epoch 3/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.2442 - accuracy: 0.9124 - val_loss: 0.2704 - val_accuracy: 0.9221
#
# Epoch 00003: val_accuracy improved from 0.91965 to 0.92213, saving model to ./models/tree_10/model_root_f1/folder8\model.h5
# Epoch 4/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.1875 - accuracy: 0.9324 - val_loss: 0.1666 - val_accuracy: 0.9394
#
# Epoch 00004: val_accuracy improved from 0.92213 to 0.93943, saving model to ./models/tree_10/model_root_f1/folder8\model.h5
# Epoch 5/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.1544 - accuracy: 0.9455 - val_loss: 0.1290 - val_accuracy: 0.9580
#
# Epoch 00005: val_accuracy improved from 0.93943 to 0.95797, saving model to ./models/tree_10/model_root_f1/folder8\model.h5
# Epoch 6/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.1161 - accuracy: 0.9622 - val_loss: 0.1426 - val_accuracy: 0.9567
#
# Epoch 00006: val_accuracy did not improve from 0.95797
# Epoch 7/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0976 - accuracy: 0.9672 - val_loss: 0.0955 - val_accuracy: 0.9666
#
# Epoch 00007: val_accuracy improved from 0.95797 to 0.96663, saving model to ./models/tree_10/model_root_f1/folder8\model.h5
# Epoch 8/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0629 - accuracy: 0.9773 - val_loss: 0.1506 - val_accuracy: 0.9592
#
# Epoch 00008: val_accuracy did not improve from 0.96663
# Epoch 9/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0456 - accuracy: 0.9828 - val_loss: 0.1001 - val_accuracy: 0.9642
#
# Epoch 00009: val_accuracy did not improve from 0.96663
# Epoch 10/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0304 - accuracy: 0.9886 - val_loss: 0.1114 - val_accuracy: 0.9642
#
# Epoch 00010: val_accuracy did not improve from 0.96663
# Epoch 11/30
# 228/228 [==============================] - 4s 20ms/step - loss: 0.0319 - accuracy: 0.9878 - val_loss: 0.1522 - val_accuracy: 0.9592
#
# Epoch 00011: val_accuracy did not improve from 0.96663
# Epoch 12/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0160 - accuracy: 0.9941 - val_loss: 0.1290 - val_accuracy: 0.9617
#
# Epoch 00012: val_accuracy did not improve from 0.96663
# Epoch 13/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.1268 - val_accuracy: 0.9617
#
# Epoch 00013: val_accuracy did not improve from 0.96663
# Epoch 14/30
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0338 - accuracy: 0.9887 - val_loss: 0.1502 - val_accuracy: 0.9629
#
# Epoch 00014: val_accuracy did not improve from 0.96663
# Epoch 15/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0035 - accuracy: 0.9993 - val_loss: 0.1388 - val_accuracy: 0.9666
#
# Epoch 00015: val_accuracy did not improve from 0.96663
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 16/30
# 228/228 [==============================] - 5s 20ms/step - loss: 3.7257e-04 - accuracy: 1.0000 - val_loss: 0.1271 - val_accuracy: 0.9728
#
# Epoch 00016: val_accuracy improved from 0.96663 to 0.97281, saving model to ./models/tree_10/model_root_f1/folder8\model.h5
# Epoch 17/30
# 228/228 [==============================] - 5s 20ms/step - loss: 1.8363e-04 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9728
#
# Epoch 00017: val_accuracy did not improve from 0.97281
# Epoch 18/30
# 228/228 [==============================] - 5s 20ms/step - loss: 1.3481e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9728
#
# Epoch 00018: val_accuracy did not improve from 0.97281
# Epoch 19/30
# 228/228 [==============================] - 5s 20ms/step - loss: 1.0602e-04 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 0.9728
#
# Epoch 00019: val_accuracy did not improve from 0.97281
# Epoch 20/30
# 228/228 [==============================] - 5s 20ms/step - loss: 8.6861e-05 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.9728
#
# Epoch 00020: val_accuracy did not improve from 0.97281
# Epoch 21/30
# 228/228 [==============================] - 5s 20ms/step - loss: 7.2981e-05 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9728
#
# Epoch 00021: val_accuracy did not improve from 0.97281
# Epoch 22/30
# 228/228 [==============================] - 4s 19ms/step - loss: 6.0790e-05 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9740
#
# Epoch 00022: val_accuracy improved from 0.97281 to 0.97404, saving model to ./models/tree_10/model_root_f1/folder8\model.h5
# Epoch 23/30
# 228/228 [==============================] - 4s 19ms/step - loss: 5.1264e-05 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9740
#
# Epoch 00023: val_accuracy did not improve from 0.97404
# Epoch 24/30
# 228/228 [==============================] - 4s 19ms/step - loss: 4.3467e-05 - accuracy: 1.0000 - val_loss: 0.1568 - val_accuracy: 0.9740
#
# Epoch 00024: val_accuracy did not improve from 0.97404
# Epoch 25/30
# 228/228 [==============================] - 4s 19ms/step - loss: 3.7311e-05 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 0.9740
#
# Epoch 00025: val_accuracy did not improve from 0.97404
# Epoch 26/30
# 228/228 [==============================] - 4s 19ms/step - loss: 3.1801e-05 - accuracy: 1.0000 - val_loss: 0.1635 - val_accuracy: 0.9740
#
# Epoch 00026: val_accuracy did not improve from 0.97404
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 27/30
# 228/228 [==============================] - 4s 19ms/step - loss: 2.7743e-05 - accuracy: 1.0000 - val_loss: 0.1617 - val_accuracy: 0.9740
#
# Epoch 00027: val_accuracy did not improve from 0.97404
# Epoch 28/30
# 228/228 [==============================] - 4s 19ms/step - loss: 2.5614e-05 - accuracy: 1.0000 - val_loss: 0.1615 - val_accuracy: 0.9740
#
# Epoch 00028: val_accuracy did not improve from 0.97404
# Epoch 29/30
# 228/228 [==============================] - 4s 19ms/step - loss: 2.3648e-05 - accuracy: 1.0000 - val_loss: 0.1658 - val_accuracy: 0.9740
#
# Epoch 00029: val_accuracy did not improve from 0.97404
# Epoch 30/30
# 228/228 [==============================] - 4s 19ms/step - loss: 2.1695e-05 - accuracy: 1.0000 - val_loss: 0.1649 - val_accuracy: 0.9740
#
# Epoch 00030: val_accuracy did not improve from 0.97404
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 9
# Genre split [['Rock'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Reggae']]
# Building model...
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 228/228 [==============================] - 5s 20ms/step - loss: 0.3625 - accuracy: 0.8826 - val_loss: 0.3118 - val_accuracy: 0.9048
#
# Epoch 00001: val_accuracy improved from -inf to 0.90482, saving model to ./models/tree_10/model_root_f1/folder9\model.h5
# Epoch 2/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.3296 - accuracy: 0.8870 - val_loss: 0.2683 - val_accuracy: 0.9048
#
# Epoch 00002: val_accuracy did not improve from 0.90482
# Epoch 3/30
# 228/228 [==============================] - 4s 18ms/step - loss: 0.3062 - accuracy: 0.8878 - val_loss: 0.2498 - val_accuracy: 0.9048
#
# Epoch 00003: val_accuracy did not improve from 0.90482
# Epoch 4/30
# 228/228 [==============================] - 4s 18ms/step - loss: 0.2845 - accuracy: 0.8871 - val_loss: 0.2346 - val_accuracy: 0.9036
#
# Epoch 00004: val_accuracy did not improve from 0.90482
# Epoch 5/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.2712 - accuracy: 0.8903 - val_loss: 0.2148 - val_accuracy: 0.9036
#
# Epoch 00005: val_accuracy did not improve from 0.90482
# Epoch 6/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.2697 - accuracy: 0.8918 - val_loss: 0.2188 - val_accuracy: 0.9011
#
# Epoch 00006: val_accuracy did not improve from 0.90482
# Epoch 7/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.2461 - accuracy: 0.8982 - val_loss: 0.2172 - val_accuracy: 0.9073
#
# Epoch 00007: val_accuracy improved from 0.90482 to 0.90729, saving model to ./models/tree_10/model_root_f1/folder9\model.h5
# Epoch 8/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.2239 - accuracy: 0.9066 - val_loss: 0.2244 - val_accuracy: 0.9110
#
# Epoch 00008: val_accuracy improved from 0.90729 to 0.91100, saving model to ./models/tree_10/model_root_f1/folder9\model.h5
# Epoch 9/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.2047 - accuracy: 0.9154 - val_loss: 0.1794 - val_accuracy: 0.9234
#
# Epoch 00009: val_accuracy improved from 0.91100 to 0.92336, saving model to ./models/tree_10/model_root_f1/folder9\model.h5
# Epoch 10/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.1839 - accuracy: 0.9235 - val_loss: 0.2142 - val_accuracy: 0.9147
#
# Epoch 00010: val_accuracy did not improve from 0.92336
# Epoch 11/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.1528 - accuracy: 0.9364 - val_loss: 0.1808 - val_accuracy: 0.9221
#
# Epoch 00011: val_accuracy did not improve from 0.92336
# Epoch 12/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.1173 - accuracy: 0.9522 - val_loss: 0.1617 - val_accuracy: 0.9382
#
# Epoch 00012: val_accuracy improved from 0.92336 to 0.93820, saving model to ./models/tree_10/model_root_f1/folder9\model.h5
# Epoch 13/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0826 - accuracy: 0.9698 - val_loss: 0.2204 - val_accuracy: 0.9234
#
# Epoch 00013: val_accuracy did not improve from 0.93820
# Epoch 14/30
# 228/228 [==============================] - 4s 18ms/step - loss: 0.0686 - accuracy: 0.9743 - val_loss: 0.2527 - val_accuracy: 0.9135
#
# Epoch 00014: val_accuracy did not improve from 0.93820
# Epoch 15/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0466 - accuracy: 0.9821 - val_loss: 0.2308 - val_accuracy: 0.9333
#
# Epoch 00015: val_accuracy did not improve from 0.93820
# Epoch 16/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0333 - accuracy: 0.9883 - val_loss: 0.2045 - val_accuracy: 0.9382
#
# Epoch 00016: val_accuracy did not improve from 0.93820
# Epoch 17/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0413 - accuracy: 0.9861 - val_loss: 0.2212 - val_accuracy: 0.9320
#
# Epoch 00017: val_accuracy did not improve from 0.93820
# Epoch 18/30
# 228/228 [==============================] - 4s 18ms/step - loss: 0.0241 - accuracy: 0.9922 - val_loss: 0.2403 - val_accuracy: 0.9308
#
# Epoch 00018: val_accuracy did not improve from 0.93820
# Epoch 19/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0166 - accuracy: 0.9956 - val_loss: 0.2866 - val_accuracy: 0.9382
#
# Epoch 00019: val_accuracy did not improve from 0.93820
# Epoch 20/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0211 - accuracy: 0.9940 - val_loss: 0.2258 - val_accuracy: 0.9481
#
# Epoch 00020: val_accuracy improved from 0.93820 to 0.94808, saving model to ./models/tree_10/model_root_f1/folder9\model.h5
# Epoch 21/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0223 - accuracy: 0.9929 - val_loss: 0.2615 - val_accuracy: 0.9197
#
# Epoch 00021: val_accuracy did not improve from 0.94808
# Epoch 22/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0317 - accuracy: 0.9882 - val_loss: 0.3207 - val_accuracy: 0.9271
#
# Epoch 00022: val_accuracy did not improve from 0.94808
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 23/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0128 - accuracy: 0.9964 - val_loss: 0.2613 - val_accuracy: 0.9407
#
# Epoch 00023: val_accuracy did not improve from 0.94808
# Epoch 24/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0094 - accuracy: 0.9974 - val_loss: 0.2625 - val_accuracy: 0.9407
#
# Epoch 00024: val_accuracy did not improve from 0.94808
# Epoch 25/30
# 228/228 [==============================] - 4s 18ms/step - loss: 0.0077 - accuracy: 0.9979 - val_loss: 0.2776 - val_accuracy: 0.9407
#
# Epoch 00025: val_accuracy did not improve from 0.94808
# Epoch 26/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.3039 - val_accuracy: 0.9382
#
# Epoch 00026: val_accuracy did not improve from 0.94808
# Epoch 27/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0071 - accuracy: 0.9982 - val_loss: 0.3125 - val_accuracy: 0.9370
#
# Epoch 00027: val_accuracy did not improve from 0.94808
# Epoch 28/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0077 - accuracy: 0.9978 - val_loss: 0.2733 - val_accuracy: 0.9419
#
# Epoch 00028: val_accuracy did not improve from 0.94808
# Epoch 29/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0068 - accuracy: 0.9981 - val_loss: 0.3257 - val_accuracy: 0.9407
#
# Epoch 00029: val_accuracy did not improve from 0.94808
# Epoch 30/30
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0073 - accuracy: 0.9981 - val_loss: 0.2834 - val_accuracy: 0.9345
#
# Epoch 00030: val_accuracy did not improve from 0.94808
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
