# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Country':2, 'Reggae':8, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {2: 'Country', 8: 'Reggae', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((2400, 128, 128), (2400, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((300, 128, 128), (300, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Country

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation='softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_10/model_root_f1_1_1_1_1_1_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_10/model_root_f1_1_1_1_1_1_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 3
n_splits = 10

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    dict_genres_list = list(dict_genres.values())
    split = [[dict_genres_list.pop(fold_no - 1)], dict_genres_list]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Country'], ['Reggae', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 76/76 [==============================] - 6s 35ms/step - loss: 0.7407 - accuracy: 0.6601 - val_loss: 0.5930 - val_accuracy: 0.6593
#
# Epoch 00001: val_accuracy improved from -inf to 0.65926, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 2/30
# 76/76 [==============================] - 2s 23ms/step - loss: 0.5437 - accuracy: 0.7132 - val_loss: 0.4589 - val_accuracy: 0.7556
#
# Epoch 00002: val_accuracy improved from 0.65926 to 0.75556, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 3/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.4470 - accuracy: 0.7597 - val_loss: 0.4134 - val_accuracy: 0.8111
#
# Epoch 00003: val_accuracy improved from 0.75556 to 0.81111, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 4/30
# 76/76 [==============================] - 2s 22ms/step - loss: 0.3768 - accuracy: 0.8305 - val_loss: 0.3512 - val_accuracy: 0.8519
#
# Epoch 00004: val_accuracy improved from 0.81111 to 0.85185, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 5/30
# 76/76 [==============================] - 2s 24ms/step - loss: 0.3381 - accuracy: 0.8535 - val_loss: 0.3159 - val_accuracy: 0.8741
#
# Epoch 00005: val_accuracy improved from 0.85185 to 0.87407, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 6/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.2387 - accuracy: 0.9021 - val_loss: 0.3028 - val_accuracy: 0.8815
#
# Epoch 00006: val_accuracy improved from 0.87407 to 0.88148, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 7/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.2096 - accuracy: 0.9152 - val_loss: 0.2444 - val_accuracy: 0.8963
#
# Epoch 00007: val_accuracy improved from 0.88148 to 0.89630, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 8/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.1607 - accuracy: 0.9407 - val_loss: 0.2615 - val_accuracy: 0.8852
#
# Epoch 00008: val_accuracy did not improve from 0.89630
# Epoch 9/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.1399 - accuracy: 0.9436 - val_loss: 0.2710 - val_accuracy: 0.8889
#
# Epoch 00009: val_accuracy did not improve from 0.89630
# Epoch 10/30
# 76/76 [==============================] - 2s 22ms/step - loss: 0.1291 - accuracy: 0.9486 - val_loss: 0.4667 - val_accuracy: 0.8481
#
# Epoch 00010: val_accuracy did not improve from 0.89630
# Epoch 11/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.1036 - accuracy: 0.9613 - val_loss: 0.2955 - val_accuracy: 0.9000
#
# Epoch 00011: val_accuracy improved from 0.89630 to 0.90000, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 12/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.0374 - accuracy: 0.9901 - val_loss: 0.2790 - val_accuracy: 0.9000
#
# Epoch 00012: val_accuracy did not improve from 0.90000
# Epoch 13/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.0223 - accuracy: 0.9938 - val_loss: 0.3567 - val_accuracy: 0.9037
#
# Epoch 00013: val_accuracy improved from 0.90000 to 0.90370, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 14/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.0493 - accuracy: 0.9790 - val_loss: 0.6015 - val_accuracy: 0.8593
#
# Epoch 00014: val_accuracy did not improve from 0.90370
# Epoch 15/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.0291 - accuracy: 0.9934 - val_loss: 0.4224 - val_accuracy: 0.8963
#
# Epoch 00015: val_accuracy did not improve from 0.90370
# Epoch 16/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.0295 - accuracy: 0.9897 - val_loss: 0.3457 - val_accuracy: 0.9148
#
# Epoch 00016: val_accuracy improved from 0.90370 to 0.91481, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 17/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.0238 - accuracy: 0.9909 - val_loss: 0.3438 - val_accuracy: 0.9185
#
# Epoch 00017: val_accuracy improved from 0.91481 to 0.91852, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 18/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.0054 - accuracy: 0.9992 - val_loss: 0.3604 - val_accuracy: 0.9148
#
# Epoch 00018: val_accuracy did not improve from 0.91852
# Epoch 19/30
# 76/76 [==============================] - 2s 23ms/step - loss: 0.0033 - accuracy: 0.9996 - val_loss: 0.3976 - val_accuracy: 0.9111
#
# Epoch 00019: val_accuracy did not improve from 0.91852
# Epoch 20/30
# 76/76 [==============================] - 2s 21ms/step - loss: 6.4555e-04 - accuracy: 1.0000 - val_loss: 0.3834 - val_accuracy: 0.9185
#
# Epoch 00020: val_accuracy did not improve from 0.91852
# Epoch 21/30
# 76/76 [==============================] - 2s 23ms/step - loss: 3.8441e-04 - accuracy: 1.0000 - val_loss: 0.4142 - val_accuracy: 0.9148ss: 3.4901e-0
#
# Epoch 00021: val_accuracy did not improve from 0.91852
# Epoch 22/30
# 76/76 [==============================] - 2s 21ms/step - loss: 2.9144e-04 - accuracy: 1.0000 - val_loss: 0.4129 - val_accuracy: 0.9148
#
# Epoch 00022: val_accuracy did not improve from 0.91852
# Epoch 23/30
# 76/76 [==============================] - 2s 21ms/step - loss: 2.4017e-04 - accuracy: 1.0000 - val_loss: 0.4190 - val_accuracy: 0.9185
#
# Epoch 00023: val_accuracy did not improve from 0.91852
# Epoch 24/30
# 76/76 [==============================] - 2s 21ms/step - loss: 2.0115e-04 - accuracy: 1.0000 - val_loss: 0.4424 - val_accuracy: 0.9148
#
# Epoch 00024: val_accuracy did not improve from 0.91852
# Epoch 25/30
# 76/76 [==============================] - 2s 21ms/step - loss: 1.7318e-04 - accuracy: 1.0000 - val_loss: 0.4500 - val_accuracy: 0.9148
#
# Epoch 00025: val_accuracy did not improve from 0.91852
# Epoch 26/30
# 76/76 [==============================] - 2s 21ms/step - loss: 1.5231e-04 - accuracy: 1.0000 - val_loss: 0.4467 - val_accuracy: 0.9148
#
# Epoch 00026: val_accuracy did not improve from 0.91852
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 27/30
# 76/76 [==============================] - 2s 21ms/step - loss: 1.3326e-04 - accuracy: 1.0000 - val_loss: 0.4596 - val_accuracy: 0.9148
#
# Epoch 00027: val_accuracy did not improve from 0.91852
# Epoch 28/30
# 76/76 [==============================] - 2s 22ms/step - loss: 1.2354e-04 - accuracy: 1.0000 - val_loss: 0.4612 - val_accuracy: 0.9148
#
# Epoch 00028: val_accuracy did not improve from 0.91852
# Epoch 29/30
# 76/76 [==============================] - 2s 21ms/step - loss: 1.1350e-04 - accuracy: 1.0000 - val_loss: 0.4736 - val_accuracy: 0.9148
#
# Epoch 00029: val_accuracy did not improve from 0.91852
# Epoch 30/30
# 76/76 [==============================] - 2s 21ms/step - loss: 1.0533e-04 - accuracy: 1.0000 - val_loss: 0.4863 - val_accuracy: 0.9148
#
# Epoch 00030: val_accuracy did not improve from 0.91852
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Reggae'], ['Country', 'Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 76/76 [==============================] - 2s 25ms/step - loss: 0.7942 - accuracy: 0.6486 - val_loss: 0.6518 - val_accuracy: 0.6667
#
# Epoch 00001: val_accuracy improved from -inf to 0.66667, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder2\model.h5
# Epoch 2/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.5305 - accuracy: 0.7321 - val_loss: 0.4417 - val_accuracy: 0.7593
#
# Epoch 00002: val_accuracy improved from 0.66667 to 0.75926, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder2\model.h5
# Epoch 3/30
# 76/76 [==============================] - 2s 22ms/step - loss: 0.3684 - accuracy: 0.8313 - val_loss: 0.3463 - val_accuracy: 0.8481
#
# Epoch 00003: val_accuracy improved from 0.75926 to 0.84815, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder2\model.h5
# Epoch 4/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.3056 - accuracy: 0.8704 - val_loss: 0.2598 - val_accuracy: 0.9074
#
# Epoch 00004: val_accuracy improved from 0.84815 to 0.90741, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder2\model.h5
# Epoch 5/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.2789 - accuracy: 0.8868 - val_loss: 0.2524 - val_accuracy: 0.9185
#
# Epoch 00005: val_accuracy improved from 0.90741 to 0.91852, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder2\model.h5
# Epoch 6/30
# 76/76 [==============================] - 2s 22ms/step - loss: 0.2309 - accuracy: 0.9099 - val_loss: 0.2533 - val_accuracy: 0.9185
#
# Epoch 00006: val_accuracy did not improve from 0.91852
# Epoch 7/30
# 76/76 [==============================] - 2s 22ms/step - loss: 0.2426 - accuracy: 0.8942 - val_loss: 0.2909 - val_accuracy: 0.9074
#
# Epoch 00007: val_accuracy did not improve from 0.91852
# Epoch 8/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.2168 - accuracy: 0.9107 - val_loss: 0.1927 - val_accuracy: 0.9370
#
# Epoch 00008: val_accuracy improved from 0.91852 to 0.93704, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder2\model.h5
# Epoch 9/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.1414 - accuracy: 0.9436 - val_loss: 0.1748 - val_accuracy: 0.9407
#
# Epoch 00009: val_accuracy improved from 0.93704 to 0.94074, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder2\model.h5
# Epoch 10/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.1312 - accuracy: 0.9469 - val_loss: 0.1855 - val_accuracy: 0.9407
#
# Epoch 00010: val_accuracy did not improve from 0.94074
# Epoch 11/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.0994 - accuracy: 0.9638 - val_loss: 0.1576 - val_accuracy: 0.9481
#
# Epoch 00011: val_accuracy improved from 0.94074 to 0.94815, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder2\model.h5
# Epoch 12/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.1022 - accuracy: 0.9597 - val_loss: 0.1506 - val_accuracy: 0.9444
#
# Epoch 00012: val_accuracy did not improve from 0.94815
# Epoch 13/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.0817 - accuracy: 0.9663 - val_loss: 0.1538 - val_accuracy: 0.9519
#
# Epoch 00013: val_accuracy improved from 0.94815 to 0.95185, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder2\model.h5
# Epoch 14/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.0485 - accuracy: 0.9831 - val_loss: 0.1535 - val_accuracy: 0.9444
#
# Epoch 00014: val_accuracy did not improve from 0.95185
# Epoch 15/30
# 76/76 [==============================] - 2s 25ms/step - loss: 0.0273 - accuracy: 0.9909 - val_loss: 0.1380 - val_accuracy: 0.9519
#
# Epoch 00015: val_accuracy did not improve from 0.95185
# Epoch 16/30
# 76/76 [==============================] - 2s 25ms/step - loss: 0.0108 - accuracy: 0.9979 - val_loss: 0.1353 - val_accuracy: 0.9556
#
# Epoch 00016: val_accuracy improved from 0.95185 to 0.95556, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder2\model.h5
# Epoch 17/30
# 76/76 [==============================] - 2s 23ms/step - loss: 0.0250 - accuracy: 0.9897 - val_loss: 0.1721 - val_accuracy: 0.9481
#
# Epoch 00017: val_accuracy did not improve from 0.95556
# Epoch 18/30
# 76/76 [==============================] - 2s 23ms/step - loss: 0.0456 - accuracy: 0.9835 - val_loss: 0.1742 - val_accuracy: 0.9481
#
# Epoch 00018: val_accuracy did not improve from 0.95556
# Epoch 19/30
# 76/76 [==============================] - 2s 22ms/step - loss: 0.0096 - accuracy: 0.9975 - val_loss: 0.1664 - val_accuracy: 0.9481
#
# Epoch 00019: val_accuracy did not improve from 0.95556
# Epoch 20/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9519
#
# Epoch 00020: val_accuracy did not improve from 0.95556
# Epoch 21/30
# 76/76 [==============================] - 2s 21ms/step - loss: 7.0730e-04 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9556
#
# Epoch 00021: val_accuracy did not improve from 0.95556
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 22/30
# 76/76 [==============================] - 2s 22ms/step - loss: 4.7400e-04 - accuracy: 1.0000 - val_loss: 0.1434 - val_accuracy: 0.9556
#
# Epoch 00022: val_accuracy did not improve from 0.95556
# Epoch 23/30
# 76/76 [==============================] - 2s 22ms/step - loss: 4.0964e-04 - accuracy: 1.0000 - val_loss: 0.1454 - val_accuracy: 0.9556
#
# Epoch 00023: val_accuracy did not improve from 0.95556
# Epoch 24/30
# 76/76 [==============================] - 2s 22ms/step - loss: 3.6186e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9556
#
# Epoch 00024: val_accuracy did not improve from 0.95556
# Epoch 25/30
# 76/76 [==============================] - 2s 21ms/step - loss: 3.2182e-04 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9556
#
# Epoch 00025: val_accuracy did not improve from 0.95556
# Epoch 26/30
# 76/76 [==============================] - 2s 21ms/step - loss: 2.8457e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9556
#
# Epoch 00026: val_accuracy did not improve from 0.95556
# Epoch 27/30
# 76/76 [==============================] - 2s 22ms/step - loss: 2.5596e-04 - accuracy: 1.0000 - val_loss: 0.1616 - val_accuracy: 0.9556
#
# Epoch 00027: val_accuracy did not improve from 0.95556
# Epoch 28/30
# 76/76 [==============================] - 2s 22ms/step - loss: 2.2555e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9556
#
# Epoch 00028: val_accuracy did not improve from 0.95556
# Epoch 29/30
# 76/76 [==============================] - 2s 22ms/step - loss: 2.0449e-04 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 0.9556
#
# Epoch 00029: val_accuracy did not improve from 0.95556
# Epoch 30/30
# 76/76 [==============================] - 2s 23ms/step - loss: 1.7993e-04 - accuracy: 1.0000 - val_loss: 0.1592 - val_accuracy: 0.9556
#
# Epoch 00030: val_accuracy did not improve from 0.95556
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Rock'], ['Country', 'Reggae']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 76/76 [==============================] - 2s 24ms/step - loss: 0.6616 - accuracy: 0.6498 - val_loss: 0.6369 - val_accuracy: 0.6185
#
# Epoch 00001: val_accuracy improved from -inf to 0.61852, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 2/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.5883 - accuracy: 0.6790 - val_loss: 0.6031 - val_accuracy: 0.6259
#
# Epoch 00002: val_accuracy improved from 0.61852 to 0.62593, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 3/30
# 76/76 [==============================] - 2s 24ms/step - loss: 0.5567 - accuracy: 0.7058 - val_loss: 0.6006 - val_accuracy: 0.6630
#
# Epoch 00003: val_accuracy improved from 0.62593 to 0.66296, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 4/30
# 76/76 [==============================] - 2s 23ms/step - loss: 0.5002 - accuracy: 0.7461 - val_loss: 0.5215 - val_accuracy: 0.7259
#
# Epoch 00004: val_accuracy improved from 0.66296 to 0.72593, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 5/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.4595 - accuracy: 0.7790 - val_loss: 0.7372 - val_accuracy: 0.6630
#
# Epoch 00005: val_accuracy did not improve from 0.72593
# Epoch 6/30
# 76/76 [==============================] - 2s 22ms/step - loss: 0.3971 - accuracy: 0.8218 - val_loss: 0.4362 - val_accuracy: 0.7926
#
# Epoch 00006: val_accuracy improved from 0.72593 to 0.79259, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 7/30
# 76/76 [==============================] - 2s 22ms/step - loss: 0.3476 - accuracy: 0.8519 - val_loss: 0.4337 - val_accuracy: 0.8037
#
# Epoch 00007: val_accuracy improved from 0.79259 to 0.80370, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 8/30
# 76/76 [==============================] - 2s 22ms/step - loss: 0.3200 - accuracy: 0.8593 - val_loss: 0.3537 - val_accuracy: 0.8333
#
# Epoch 00008: val_accuracy improved from 0.80370 to 0.83333, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 9/30
# 76/76 [==============================] - 2s 22ms/step - loss: 0.2301 - accuracy: 0.9037 - val_loss: 0.3541 - val_accuracy: 0.8556
#
# Epoch 00009: val_accuracy improved from 0.83333 to 0.85556, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 10/30
# 76/76 [==============================] - 2s 23ms/step - loss: 0.1906 - accuracy: 0.9226 - val_loss: 0.3124 - val_accuracy: 0.8630
#
# Epoch 00010: val_accuracy improved from 0.85556 to 0.86296, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 11/30
# 76/76 [==============================] - 2s 22ms/step - loss: 0.1433 - accuracy: 0.9412 - val_loss: 0.4715 - val_accuracy: 0.7926
#
# Epoch 00011: val_accuracy did not improve from 0.86296
# Epoch 12/30
# 76/76 [==============================] - 2s 22ms/step - loss: 0.0988 - accuracy: 0.9621 - val_loss: 0.3213 - val_accuracy: 0.8778
#
# Epoch 00012: val_accuracy improved from 0.86296 to 0.87778, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 13/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.0415 - accuracy: 0.9893 - val_loss: 0.3969 - val_accuracy: 0.8444
#
# Epoch 00013: val_accuracy did not improve from 0.87778
# Epoch 14/30
# 76/76 [==============================] - 2s 22ms/step - loss: 0.0200 - accuracy: 0.9967 - val_loss: 0.3811 - val_accuracy: 0.8741
#
# Epoch 00014: val_accuracy did not improve from 0.87778
# Epoch 15/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.0108 - accuracy: 0.9992 - val_loss: 0.3775 - val_accuracy: 0.8815
#
# Epoch 00015: val_accuracy improved from 0.87778 to 0.88148, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 16/30
# 76/76 [==============================] - 2s 21ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4410 - val_accuracy: 0.8741
#
# Epoch 00016: val_accuracy did not improve from 0.88148
# Epoch 17/30
# 76/76 [==============================] - 2s 22ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4952 - val_accuracy: 0.8593loss: 0.0014 - accuracy: 1.00 - ETA: 0s - l
#
# Epoch 00017: val_accuracy did not improve from 0.88148
# Epoch 18/30
# 76/76 [==============================] - ETA: 0s - loss: 6.4856e-04 - accuracy: 1.00 - 2s 21ms/step - loss: 6.4856e-04 - accuracy: 1.0000 - val_loss: 0.5002 - val_accuracy: 0.8704
#
# Epoch 00018: val_accuracy did not improve from 0.88148
# Epoch 19/30
# 76/76 [==============================] - 2s 21ms/step - loss: 4.7161e-04 - accuracy: 1.0000 - val_loss: 0.5080 - val_accuracy: 0.8704
#
# Epoch 00019: val_accuracy did not improve from 0.88148
# Epoch 20/30
# 76/76 [==============================] - 2s 22ms/step - loss: 3.4924e-04 - accuracy: 1.0000 - val_loss: 0.5164 - val_accuracy: 0.8630
#
# Epoch 00020: val_accuracy did not improve from 0.88148
# Epoch 21/30
# 76/76 [==============================] - 2s 21ms/step - loss: 2.8860e-04 - accuracy: 1.0000 - val_loss: 0.5211 - val_accuracy: 0.8741
#
# Epoch 00021: val_accuracy did not improve from 0.88148
# Epoch 22/30
# 76/76 [==============================] - 2s 21ms/step - loss: 2.1590e-04 - accuracy: 1.0000 - val_loss: 0.5523 - val_accuracy: 0.8630
#
# Epoch 00022: val_accuracy did not improve from 0.88148
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 23/30
# 76/76 [==============================] - 2s 21ms/step - loss: 1.7675e-04 - accuracy: 1.0000 - val_loss: 0.5401 - val_accuracy: 0.8704
#
# Epoch 00023: val_accuracy did not improve from 0.88148
# Epoch 24/30
# 76/76 [==============================] - 2s 21ms/step - loss: 1.6343e-04 - accuracy: 1.0000 - val_loss: 0.5885 - val_accuracy: 0.8519
#
# Epoch 00024: val_accuracy did not improve from 0.88148
# Epoch 25/30
# 76/76 [==============================] - 2s 22ms/step - loss: 1.4747e-04 - accuracy: 1.0000 - val_loss: 0.6036 - val_accuracy: 0.8407
#
# Epoch 00025: val_accuracy did not improve from 0.88148
# Epoch 26/30
# 76/76 [==============================] - 2s 21ms/step - loss: 1.3419e-04 - accuracy: 1.0000 - val_loss: 0.5828 - val_accuracy: 0.8667
#
# Epoch 00026: val_accuracy did not improve from 0.88148
# Epoch 27/30
# 76/76 [==============================] - 2s 22ms/step - loss: 1.2221e-04 - accuracy: 1.0000 - val_loss: 0.5749 - val_accuracy: 0.8667
#
# Epoch 00027: val_accuracy did not improve from 0.88148
# Epoch 28/30
# 76/76 [==============================] - 2s 22ms/step - loss: 1.1128e-04 - accuracy: 1.0000 - val_loss: 0.6042 - val_accuracy: 0.8519
#
# Epoch 00028: val_accuracy did not improve from 0.88148
# Epoch 29/30
# 76/76 [==============================] - 2s 23ms/step - loss: 1.0337e-04 - accuracy: 1.0000 - val_loss: 0.5813 - val_accuracy: 0.8667
#
# Epoch 00029: val_accuracy did not improve from 0.88148
# Epoch 30/30
# 76/76 [==============================] - 2s 22ms/step - loss: 9.6476e-05 - accuracy: 1.0000 - val_loss: 0.6030 - val_accuracy: 0.8667
#
# Epoch 00030: val_accuracy did not improve from 0.88148
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
