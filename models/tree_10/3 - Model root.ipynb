# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Blues', 1: 'Classical', 2: 'Country', 3: 'Disco', 4: 'Hip-Hop', 5: 'Jazz', 6: 'Metal', 7: 'Pop', 8: 'Reggae', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
print(spectogram.shape)
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Disco
# (128, 128)

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
       
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_10/model_root/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_10/model_root/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 10
n_splits = 10

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    dict_genres_list = list(dict_genres.values())
    split = [[dict_genres_list.pop(fold_no - 1)], dict_genres_list]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Blues'], ['Classical', 'Country', 'Disco', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 253/253 [==============================] - 9s 24ms/step - loss: 0.3668 - accuracy: 0.8940 - val_loss: 0.3574 - val_accuracy: 0.8888
#
# Epoch 00001: val_accuracy improved from -inf to 0.88877, saving model to ./models/tree_10/model_root/folder1\model.h5
# Epoch 2/30
# 253/253 [==============================] - 5s 22ms/step - loss: 0.3246 - accuracy: 0.9000 - val_loss: 0.3402 - val_accuracy: 0.8921
#
# Epoch 00002: val_accuracy improved from 0.88877 to 0.89210, saving model to ./models/tree_10/model_root/folder1\model.h5
# Epoch 3/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.3136 - accuracy: 0.9059 - val_loss: 0.3439 - val_accuracy: 0.8888
#
# Epoch 00003: val_accuracy did not improve from 0.89210
# Epoch 4/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.3079 - accuracy: 0.9068 - val_loss: 0.3553 - val_accuracy: 0.8888
#
# Epoch 00004: val_accuracy did not improve from 0.89210
# Epoch 5/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.3050 - accuracy: 0.9068 - val_loss: 0.3202 - val_accuracy: 0.9010
#
# Epoch 00005: val_accuracy improved from 0.89210 to 0.90100, saving model to ./models/tree_10/model_root/folder1\model.h5
# Epoch 6/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.2812 - accuracy: 0.9093 - val_loss: 0.2572 - val_accuracy: 0.9032
#
# Epoch 00006: val_accuracy improved from 0.90100 to 0.90323, saving model to ./models/tree_10/model_root/folder1\model.h5
# Epoch 7/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.2632 - accuracy: 0.9127 - val_loss: 0.2467 - val_accuracy: 0.9077
#
# Epoch 00007: val_accuracy improved from 0.90323 to 0.90768, saving model to ./models/tree_10/model_root/folder1\model.h5
# Epoch 8/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.2131 - accuracy: 0.9213 - val_loss: 0.2277 - val_accuracy: 0.9066
#
# Epoch 00008: val_accuracy did not improve from 0.90768
# Epoch 9/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.1838 - accuracy: 0.9296 - val_loss: 0.2308 - val_accuracy: 0.9166
#
# Epoch 00009: val_accuracy improved from 0.90768 to 0.91657, saving model to ./models/tree_10/model_root/folder1\model.h5
# Epoch 10/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.1753 - accuracy: 0.9300 - val_loss: 0.2012 - val_accuracy: 0.9244
#
# Epoch 00010: val_accuracy improved from 0.91657 to 0.92436, saving model to ./models/tree_10/model_root/folder1\model.h5
# Epoch 11/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.1419 - accuracy: 0.9444 - val_loss: 0.2176 - val_accuracy: 0.9210
#
# Epoch 00011: val_accuracy did not improve from 0.92436
# Epoch 12/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.1310 - accuracy: 0.9491 - val_loss: 0.2004 - val_accuracy: 0.9177
#
# Epoch 00012: val_accuracy did not improve from 0.92436
# Epoch 13/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0995 - accuracy: 0.9607 - val_loss: 0.1879 - val_accuracy: 0.9232
#
# Epoch 00013: val_accuracy did not improve from 0.92436
# Epoch 14/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0762 - accuracy: 0.9702 - val_loss: 0.1779 - val_accuracy: 0.9366
#
# Epoch 00014: val_accuracy improved from 0.92436 to 0.93660, saving model to ./models/tree_10/model_root/folder1\model.h5
# Epoch 15/30
# 253/253 [==============================] - 6s 22ms/step - loss: 0.0490 - accuracy: 0.9817 - val_loss: 0.1697 - val_accuracy: 0.9377
#
# Epoch 00015: val_accuracy improved from 0.93660 to 0.93771, saving model to ./models/tree_10/model_root/folder1\model.h5
# Epoch 16/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0345 - accuracy: 0.9890 - val_loss: 0.2036 - val_accuracy: 0.9321
#
# Epoch 00016: val_accuracy did not improve from 0.93771
# Epoch 17/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0250 - accuracy: 0.9920 - val_loss: 0.2193 - val_accuracy: 0.9422
#
# Epoch 00017: val_accuracy improved from 0.93771 to 0.94216, saving model to ./models/tree_10/model_root/folder1\model.h5
# Epoch 18/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0116 - accuracy: 0.9964 - val_loss: 0.2419 - val_accuracy: 0.9455
#
# Epoch 00018: val_accuracy improved from 0.94216 to 0.94550, saving model to ./models/tree_10/model_root/folder1\model.h5
# Epoch 19/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0104 - accuracy: 0.9968 - val_loss: 0.2185 - val_accuracy: 0.9355
#
# Epoch 00019: val_accuracy did not improve from 0.94550
# Epoch 20/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0546 - accuracy: 0.9782 - val_loss: 0.3224 - val_accuracy: 0.9188
#
# Epoch 00020: val_accuracy did not improve from 0.94550
# Epoch 21/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0241 - accuracy: 0.9902 - val_loss: 0.2631 - val_accuracy: 0.9377
#
# Epoch 00021: val_accuracy did not improve from 0.94550
# Epoch 22/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0030 - accuracy: 0.9996 - val_loss: 0.2909 - val_accuracy: 0.9422
#
# Epoch 00022: val_accuracy did not improve from 0.94550
# Epoch 23/30
# 253/253 [==============================] - 5s 20ms/step - loss: 5.4040e-04 - accuracy: 1.0000 - val_loss: 0.2802 - val_accuracy: 0.9388
#
# Epoch 00023: val_accuracy did not improve from 0.94550
# Epoch 24/30
# 253/253 [==============================] - 5s 20ms/step - loss: 3.1867e-04 - accuracy: 1.0000 - val_loss: 0.2991 - val_accuracy: 0.9433
#
# Epoch 00024: val_accuracy did not improve from 0.94550
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 25/30
# 253/253 [==============================] - 5s 20ms/step - loss: 2.2515e-04 - accuracy: 1.0000 - val_loss: 0.3094 - val_accuracy: 0.9422
#
# Epoch 00025: val_accuracy did not improve from 0.94550
# Epoch 26/30
# 253/253 [==============================] - 5s 20ms/step - loss: 1.9622e-04 - accuracy: 1.0000 - val_loss: 0.3056 - val_accuracy: 0.9422
#
# Epoch 00026: val_accuracy did not improve from 0.94550
# Epoch 27/30
# 253/253 [==============================] - 5s 20ms/step - loss: 1.6852e-04 - accuracy: 1.0000 - val_loss: 0.3130 - val_accuracy: 0.9410
#
# Epoch 00027: val_accuracy did not improve from 0.94550
# Epoch 28/30
# 253/253 [==============================] - 5s 20ms/step - loss: 1.4606e-04 - accuracy: 1.0000 - val_loss: 0.3110 - val_accuracy: 0.9422
#
# Epoch 00028: val_accuracy did not improve from 0.94550
# Epoch 29/30
# 253/253 [==============================] - 5s 20ms/step - loss: 1.2785e-04 - accuracy: 1.0000 - val_loss: 0.3228 - val_accuracy: 0.9410
#
# Epoch 00029: val_accuracy did not improve from 0.94550
# Epoch 30/30
# 253/253 [==============================] - 5s 20ms/step - loss: 1.1080e-04 - accuracy: 1.0000 - val_loss: 0.3238 - val_accuracy: 0.9410
#
# Epoch 00030: val_accuracy did not improve from 0.94550
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Classical'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 253/253 [==============================] - 6s 21ms/step - loss: 0.2262 - accuracy: 0.9200 - val_loss: 0.1051 - val_accuracy: 0.9577
#
# Epoch 00001: val_accuracy improved from -inf to 0.95773, saving model to ./models/tree_10/model_root/folder2\model.h5
# Epoch 2/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0839 - accuracy: 0.9685 - val_loss: 0.0507 - val_accuracy: 0.9778
#
# Epoch 00002: val_accuracy improved from 0.95773 to 0.97775, saving model to ./models/tree_10/model_root/folder2\model.h5
# Epoch 3/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0591 - accuracy: 0.9778 - val_loss: 0.0681 - val_accuracy: 0.9700
#
# Epoch 00003: val_accuracy did not improve from 0.97775
# Epoch 4/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0573 - accuracy: 0.9779 - val_loss: 0.0364 - val_accuracy: 0.9878
#
# Epoch 00004: val_accuracy improved from 0.97775 to 0.98776, saving model to ./models/tree_10/model_root/folder2\model.h5
# Epoch 5/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0420 - accuracy: 0.9838 - val_loss: 0.0302 - val_accuracy: 0.9900
#
# Epoch 00005: val_accuracy improved from 0.98776 to 0.98999, saving model to ./models/tree_10/model_root/folder2\model.h5
# Epoch 6/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0304 - accuracy: 0.9883 - val_loss: 0.0263 - val_accuracy: 0.9911
#
# Epoch 00006: val_accuracy improved from 0.98999 to 0.99110, saving model to ./models/tree_10/model_root/folder2\model.h5
# Epoch 7/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0217 - accuracy: 0.9913 - val_loss: 0.0350 - val_accuracy: 0.9900
#
# Epoch 00007: val_accuracy did not improve from 0.99110
# Epoch 8/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0235 - accuracy: 0.9909 - val_loss: 0.0304 - val_accuracy: 0.9911
#
# Epoch 00008: val_accuracy did not improve from 0.99110
# Epoch 9/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0196 - accuracy: 0.9925 - val_loss: 0.0275 - val_accuracy: 0.9900
#
# Epoch 00009: val_accuracy did not improve from 0.99110
# Epoch 10/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0140 - accuracy: 0.9946 - val_loss: 0.0457 - val_accuracy: 0.9833
#
# Epoch 00010: val_accuracy did not improve from 0.99110
# Epoch 11/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0052 - accuracy: 0.9974 - val_loss: 0.0255 - val_accuracy: 0.9956
#
# Epoch 00011: val_accuracy improved from 0.99110 to 0.99555, saving model to ./models/tree_10/model_root/folder2\model.h5
# Epoch 12/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0278 - accuracy: 0.9904 - val_loss: 0.0997 - val_accuracy: 0.9566
#
# Epoch 00012: val_accuracy did not improve from 0.99555
# Epoch 13/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0265 - accuracy: 0.9900 - val_loss: 0.0298 - val_accuracy: 0.9922
#
# Epoch 00013: val_accuracy did not improve from 0.99555
# Epoch 14/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0126 - accuracy: 0.9962 - val_loss: 0.0318 - val_accuracy: 0.9922
#
# Epoch 00014: val_accuracy did not improve from 0.99555
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 15/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0331 - val_accuracy: 0.9911
#
# Epoch 00015: val_accuracy did not improve from 0.99555
# Epoch 16/30
# 253/253 [==============================] - 5s 20ms/step - loss: 5.4377e-04 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9911
#
# Epoch 00016: val_accuracy did not improve from 0.99555
# Epoch 17/30
# 253/253 [==============================] - 5s 20ms/step - loss: 2.3168e-04 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.9944
#
# Epoch 00017: val_accuracy did not improve from 0.99555
# Epoch 18/30
# 253/253 [==============================] - 5s 21ms/step - loss: 1.4833e-04 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9922
#
# Epoch 00018: val_accuracy did not improve from 0.99555
# Epoch 19/30
# 253/253 [==============================] - 5s 20ms/step - loss: 1.0608e-04 - accuracy: 1.0000 - val_loss: 0.0368 - val_accuracy: 0.9922
#
# Epoch 00019: val_accuracy did not improve from 0.99555
# Epoch 20/30
# 253/253 [==============================] - 5s 21ms/step - loss: 8.1453e-05 - accuracy: 1.0000 - val_loss: 0.0378 - val_accuracy: 0.9922
#
# Epoch 00020: val_accuracy did not improve from 0.99555
# Epoch 21/30
# 253/253 [==============================] - 5s 20ms/step - loss: 6.3535e-05 - accuracy: 1.0000 - val_loss: 0.0390 - val_accuracy: 0.9922
#
# Epoch 00021: val_accuracy did not improve from 0.99555
# Epoch 22/30
# 253/253 [==============================] - 5s 20ms/step - loss: 5.1270e-05 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9922
#
# Epoch 00022: val_accuracy did not improve from 0.99555
# Epoch 23/30
# 253/253 [==============================] - 5s 20ms/step - loss: 4.1490e-05 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9922
#
# Epoch 00023: val_accuracy did not improve from 0.99555
# Epoch 24/30
# 253/253 [==============================] - 5s 20ms/step - loss: 3.4615e-05 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9922
#
# Epoch 00024: val_accuracy did not improve from 0.99555
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 25/30
# 253/253 [==============================] - 5s 19ms/step - loss: 2.8463e-05 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9933
#
# Epoch 00025: val_accuracy did not improve from 0.99555
# Epoch 26/30
# 253/253 [==============================] - 5s 19ms/step - loss: 2.6182e-05 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9922
#
# Epoch 00026: val_accuracy did not improve from 0.99555
# Epoch 27/30
# 253/253 [==============================] - 5s 19ms/step - loss: 2.3583e-05 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 0.9922
#
# Epoch 00027: val_accuracy did not improve from 0.99555
# Epoch 28/30
# 253/253 [==============================] - 5s 19ms/step - loss: 2.1363e-05 - accuracy: 1.0000 - val_loss: 0.0425 - val_accuracy: 0.9933
#
# Epoch 00028: val_accuracy did not improve from 0.99555
# Epoch 29/30
# 253/253 [==============================] - 5s 20ms/step - loss: 1.9189e-05 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 0.9933
#
# Epoch 00029: val_accuracy did not improve from 0.99555
# Epoch 30/30
# 253/253 [==============================] - 5s 19ms/step - loss: 1.7270e-05 - accuracy: 1.0000 - val_loss: 0.0444 - val_accuracy: 0.9922
#
# Epoch 00030: val_accuracy did not improve from 0.99555
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Country'], ['Blues', 'Classical', 'Disco', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 253/253 [==============================] - 6s 20ms/step - loss: 0.3205 - accuracy: 0.8989 - val_loss: 0.2833 - val_accuracy: 0.8776
#
# Epoch 00001: val_accuracy improved from -inf to 0.87764, saving model to ./models/tree_10/model_root/folder3\model.h5
# Epoch 2/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.2502 - accuracy: 0.9033 - val_loss: 0.2385 - val_accuracy: 0.9010
#
# Epoch 00002: val_accuracy improved from 0.87764 to 0.90100, saving model to ./models/tree_10/model_root/folder3\model.h5
# Epoch 3/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.1995 - accuracy: 0.9194 - val_loss: 0.1825 - val_accuracy: 0.9188
#
# Epoch 00003: val_accuracy improved from 0.90100 to 0.91880, saving model to ./models/tree_10/model_root/folder3\model.h5
# Epoch 4/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.1671 - accuracy: 0.9339 - val_loss: 0.2060 - val_accuracy: 0.9199
#
# Epoch 00004: val_accuracy improved from 0.91880 to 0.91991, saving model to ./models/tree_10/model_root/folder3\model.h5
# Epoch 5/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.1396 - accuracy: 0.9483 - val_loss: 0.1573 - val_accuracy: 0.9277
#
# Epoch 00005: val_accuracy improved from 0.91991 to 0.92770, saving model to ./models/tree_10/model_root/folder3\model.h5
# Epoch 6/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.1215 - accuracy: 0.9523 - val_loss: 0.1989 - val_accuracy: 0.9299
#
# Epoch 00006: val_accuracy improved from 0.92770 to 0.92992, saving model to ./models/tree_10/model_root/folder3\model.h5
# Epoch 7/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.1044 - accuracy: 0.9602 - val_loss: 0.2069 - val_accuracy: 0.9399
#
# Epoch 00007: val_accuracy improved from 0.92992 to 0.93993, saving model to ./models/tree_10/model_root/folder3\model.h5
# Epoch 8/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0735 - accuracy: 0.9724 - val_loss: 0.1373 - val_accuracy: 0.9477
#
# Epoch 00008: val_accuracy improved from 0.93993 to 0.94772, saving model to ./models/tree_10/model_root/folder3\model.h5
# Epoch 9/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0603 - accuracy: 0.9799 - val_loss: 0.1301 - val_accuracy: 0.9422
#
# Epoch 00009: val_accuracy did not improve from 0.94772
# Epoch 10/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0370 - accuracy: 0.9868 - val_loss: 0.1924 - val_accuracy: 0.9433
#
# Epoch 00010: val_accuracy did not improve from 0.94772
# Epoch 11/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0337 - accuracy: 0.9875 - val_loss: 0.1790 - val_accuracy: 0.9511
#
# Epoch 00011: val_accuracy improved from 0.94772 to 0.95106, saving model to ./models/tree_10/model_root/folder3\model.h5
# Epoch 12/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0224 - accuracy: 0.9921 - val_loss: 0.2607 - val_accuracy: 0.9444
#
# Epoch 00012: val_accuracy did not improve from 0.95106
# Epoch 13/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0256 - accuracy: 0.9906 - val_loss: 0.1789 - val_accuracy: 0.9366
#
# Epoch 00013: val_accuracy did not improve from 0.95106
# Epoch 14/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0264 - accuracy: 0.9897 - val_loss: 0.2188 - val_accuracy: 0.9410
#
# Epoch 00014: val_accuracy did not improve from 0.95106
# Epoch 15/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0199 - accuracy: 0.9933 - val_loss: 0.1993 - val_accuracy: 0.9444
#
# Epoch 00015: val_accuracy did not improve from 0.95106
# Epoch 16/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0194 - accuracy: 0.9937 - val_loss: 0.3042 - val_accuracy: 0.9255
#
# Epoch 00016: val_accuracy did not improve from 0.95106
# Epoch 17/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0182 - accuracy: 0.9927 - val_loss: 0.2442 - val_accuracy: 0.9388
#
# Epoch 00017: val_accuracy did not improve from 0.95106
# Epoch 18/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0152 - accuracy: 0.9944 - val_loss: 0.2730 - val_accuracy: 0.9388
#
# Epoch 00018: val_accuracy did not improve from 0.95106
# Epoch 19/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0234 - accuracy: 0.9915 - val_loss: 0.3730 - val_accuracy: 0.9355
#
# Epoch 00019: val_accuracy did not improve from 0.95106
# Epoch 20/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0274 - accuracy: 0.9901 - val_loss: 0.2963 - val_accuracy: 0.9477
#
# Epoch 00020: val_accuracy did not improve from 0.95106
# Epoch 21/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.2813 - val_accuracy: 0.9388
#
# Epoch 00021: val_accuracy did not improve from 0.95106
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 22/30
# 253/253 [==============================] - 5s 19ms/step - loss: 8.6188e-04 - accuracy: 0.9999 - val_loss: 0.3094 - val_accuracy: 0.9422
#
# Epoch 00022: val_accuracy did not improve from 0.95106
# Epoch 23/30
# 253/253 [==============================] - 5s 19ms/step - loss: 1.0632e-04 - accuracy: 1.0000 - val_loss: 0.3146 - val_accuracy: 0.9422
#
# Epoch 00023: val_accuracy did not improve from 0.95106
# Epoch 24/30
# 253/253 [==============================] - 5s 19ms/step - loss: 7.4567e-05 - accuracy: 1.0000 - val_loss: 0.3226 - val_accuracy: 0.9455
#
# Epoch 00024: val_accuracy did not improve from 0.95106
# Epoch 25/30
# 253/253 [==============================] - 5s 19ms/step - loss: 5.9755e-05 - accuracy: 1.0000 - val_loss: 0.3269 - val_accuracy: 0.9466
#
# Epoch 00025: val_accuracy did not improve from 0.95106
# Epoch 26/30
# 253/253 [==============================] - 5s 19ms/step - loss: 4.9558e-05 - accuracy: 1.0000 - val_loss: 0.3284 - val_accuracy: 0.9455
#
# Epoch 00026: val_accuracy did not improve from 0.95106
# Epoch 27/30
# 253/253 [==============================] - 5s 20ms/step - loss: 4.2061e-05 - accuracy: 1.0000 - val_loss: 0.3345 - val_accuracy: 0.9466
#
# Epoch 00027: val_accuracy did not improve from 0.95106
# Epoch 28/30
# 253/253 [==============================] - 5s 20ms/step - loss: 3.6174e-05 - accuracy: 1.0000 - val_loss: 0.3383 - val_accuracy: 0.9455
#
# Epoch 00028: val_accuracy did not improve from 0.95106
# Epoch 29/30
# 253/253 [==============================] - 5s 19ms/step - loss: 3.1315e-05 - accuracy: 1.0000 - val_loss: 0.3410 - val_accuracy: 0.9466
#
# Epoch 00029: val_accuracy did not improve from 0.95106
# Epoch 30/30
# 253/253 [==============================] - 5s 20ms/step - loss: 2.7209e-05 - accuracy: 1.0000 - val_loss: 0.3432 - val_accuracy: 0.9466
#
# Epoch 00030: val_accuracy did not improve from 0.95106
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Disco'], ['Blues', 'Classical', 'Country', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 253/253 [==============================] - 6s 21ms/step - loss: 0.3448 - accuracy: 0.8963 - val_loss: 0.3190 - val_accuracy: 0.8988
#
# Epoch 00001: val_accuracy improved from -inf to 0.89878, saving model to ./models/tree_10/model_root/folder4\model.h5
# Epoch 2/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.3129 - accuracy: 0.8999 - val_loss: 0.3054 - val_accuracy: 0.8988
#
# Epoch 00002: val_accuracy did not improve from 0.89878
# Epoch 3/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.2895 - accuracy: 0.9001 - val_loss: 0.2460 - val_accuracy: 0.9110
#
# Epoch 00003: val_accuracy improved from 0.89878 to 0.91101, saving model to ./models/tree_10/model_root/folder4\model.h5
# Epoch 4/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.2081 - accuracy: 0.9284 - val_loss: 0.1824 - val_accuracy: 0.9399
#
# Epoch 00004: val_accuracy improved from 0.91101 to 0.93993, saving model to ./models/tree_10/model_root/folder4\model.h5
# Epoch 5/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.1533 - accuracy: 0.9471 - val_loss: 0.1507 - val_accuracy: 0.9499
#
# Epoch 00005: val_accuracy improved from 0.93993 to 0.94994, saving model to ./models/tree_10/model_root/folder4\model.h5
# Epoch 6/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.1209 - accuracy: 0.9579 - val_loss: 0.1766 - val_accuracy: 0.9399
#
# Epoch 00006: val_accuracy did not improve from 0.94994
# Epoch 7/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.1026 - accuracy: 0.9661 - val_loss: 0.1995 - val_accuracy: 0.9455
#
# Epoch 00007: val_accuracy did not improve from 0.94994
# Epoch 8/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0919 - accuracy: 0.9684 - val_loss: 0.1389 - val_accuracy: 0.9555
#
# Epoch 00008: val_accuracy improved from 0.94994 to 0.95551, saving model to ./models/tree_10/model_root/folder4\model.h5
# Epoch 9/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0672 - accuracy: 0.9773 - val_loss: 0.1261 - val_accuracy: 0.9600
#
# Epoch 00009: val_accuracy improved from 0.95551 to 0.95996, saving model to ./models/tree_10/model_root/folder4\model.h5
# Epoch 10/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0605 - accuracy: 0.9792 - val_loss: 0.1694 - val_accuracy: 0.9555
#
# Epoch 00010: val_accuracy did not improve from 0.95996
# Epoch 11/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0415 - accuracy: 0.9855 - val_loss: 0.1391 - val_accuracy: 0.9555
#
# Epoch 00011: val_accuracy did not improve from 0.95996
# Epoch 12/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0284 - accuracy: 0.9909 - val_loss: 0.1650 - val_accuracy: 0.9566
#
# Epoch 00012: val_accuracy did not improve from 0.95996
# Epoch 13/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0244 - accuracy: 0.9918 - val_loss: 0.1958 - val_accuracy: 0.9511
#
# Epoch 00013: val_accuracy did not improve from 0.95996
# Epoch 14/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0131 - accuracy: 0.9954 - val_loss: 0.2176 - val_accuracy: 0.9566
#
# Epoch 00014: val_accuracy did not improve from 0.95996
# Epoch 15/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0312 - accuracy: 0.9889 - val_loss: 0.4521 - val_accuracy: 0.9288
#
# Epoch 00015: val_accuracy did not improve from 0.95996
# Epoch 16/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0374 - accuracy: 0.9868 - val_loss: 0.1719 - val_accuracy: 0.9611
#
# Epoch 00016: val_accuracy improved from 0.95996 to 0.96107, saving model to ./models/tree_10/model_root/folder4\model.h5
# Epoch 17/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0115 - accuracy: 0.9959 - val_loss: 0.2233 - val_accuracy: 0.9588
#
# Epoch 00017: val_accuracy did not improve from 0.96107
# Epoch 18/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0124 - accuracy: 0.9957 - val_loss: 0.2711 - val_accuracy: 0.9555
#
# Epoch 00018: val_accuracy did not improve from 0.96107
# Epoch 19/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0109 - accuracy: 0.9963 - val_loss: 0.2274 - val_accuracy: 0.9544
#
# Epoch 00019: val_accuracy did not improve from 0.96107
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.2231 - val_accuracy: 0.9633
#
# Epoch 00020: val_accuracy improved from 0.96107 to 0.96329, saving model to ./models/tree_10/model_root/folder4\model.h5
# Epoch 21/30
# 253/253 [==============================] - 5s 20ms/step - loss: 4.0114e-04 - accuracy: 1.0000 - val_loss: 0.2498 - val_accuracy: 0.9611
#
# Epoch 00021: val_accuracy did not improve from 0.96329
# Epoch 22/30
# 253/253 [==============================] - 5s 20ms/step - loss: 2.1822e-04 - accuracy: 1.0000 - val_loss: 0.2557 - val_accuracy: 0.9622
#
# Epoch 00022: val_accuracy did not improve from 0.96329
# Epoch 23/30
# 253/253 [==============================] - 5s 20ms/step - loss: 1.3827e-04 - accuracy: 1.0000 - val_loss: 0.2640 - val_accuracy: 0.9611
#
# Epoch 00023: val_accuracy did not improve from 0.96329
# Epoch 24/30
# 253/253 [==============================] - 5s 20ms/step - loss: 1.0568e-04 - accuracy: 1.0000 - val_loss: 0.2652 - val_accuracy: 0.9611
#
# Epoch 00024: val_accuracy did not improve from 0.96329
# Epoch 25/30
# 253/253 [==============================] - 5s 20ms/step - loss: 8.0906e-05 - accuracy: 1.0000 - val_loss: 0.2681 - val_accuracy: 0.9644
#
# Epoch 00025: val_accuracy improved from 0.96329 to 0.96440, saving model to ./models/tree_10/model_root/folder4\model.h5
# Epoch 26/30
# 253/253 [==============================] - 5s 20ms/step - loss: 6.3348e-05 - accuracy: 1.0000 - val_loss: 0.2736 - val_accuracy: 0.9644
#
# Epoch 00026: val_accuracy did not improve from 0.96440
# Epoch 27/30
# 253/253 [==============================] - 5s 20ms/step - loss: 4.9503e-05 - accuracy: 1.0000 - val_loss: 0.2782 - val_accuracy: 0.9644
#
# Epoch 00027: val_accuracy did not improve from 0.96440
# Epoch 28/30
# 253/253 [==============================] - 5s 20ms/step - loss: 3.9470e-05 - accuracy: 1.0000 - val_loss: 0.2872 - val_accuracy: 0.9644
#
# Epoch 00028: val_accuracy did not improve from 0.96440
# Epoch 29/30
# 253/253 [==============================] - 5s 19ms/step - loss: 3.1530e-05 - accuracy: 1.0000 - val_loss: 0.2886 - val_accuracy: 0.9644
#
# Epoch 00029: val_accuracy did not improve from 0.96440
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 30/30
# 253/253 [==============================] - 5s 21ms/step - loss: 2.6079e-05 - accuracy: 1.0000 - val_loss: 0.2951 - val_accuracy: 0.9644
#
# Epoch 00030: val_accuracy did not improve from 0.96440
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 5
# Genre split [['Hip-Hop'], ['Blues', 'Classical', 'Country', 'Disco', 'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 253/253 [==============================] - 6s 21ms/step - loss: 0.3309 - accuracy: 0.8996 - val_loss: 0.3167 - val_accuracy: 0.8966
#
# Epoch 00001: val_accuracy improved from -inf to 0.89655, saving model to ./models/tree_10/model_root/folder5\model.h5
# Epoch 2/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.2418 - accuracy: 0.9066 - val_loss: 0.2010 - val_accuracy: 0.9333
#
# Epoch 00002: val_accuracy improved from 0.89655 to 0.93326, saving model to ./models/tree_10/model_root/folder5\model.h5
# Epoch 3/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.2013 - accuracy: 0.9207 - val_loss: 0.1799 - val_accuracy: 0.9321
#
# Epoch 00003: val_accuracy did not improve from 0.93326
# Epoch 4/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.1772 - accuracy: 0.9300 - val_loss: 0.1983 - val_accuracy: 0.9132
#
# Epoch 00004: val_accuracy did not improve from 0.93326
# Epoch 5/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.1395 - accuracy: 0.9446 - val_loss: 0.1357 - val_accuracy: 0.9488
#
# Epoch 00005: val_accuracy improved from 0.93326 to 0.94883, saving model to ./models/tree_10/model_root/folder5\model.h5
# Epoch 6/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.1284 - accuracy: 0.9503 - val_loss: 0.1372 - val_accuracy: 0.9422
#
# Epoch 00006: val_accuracy did not improve from 0.94883
# Epoch 7/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0930 - accuracy: 0.9622 - val_loss: 0.1179 - val_accuracy: 0.9577
#
# Epoch 00007: val_accuracy improved from 0.94883 to 0.95773, saving model to ./models/tree_10/model_root/folder5\model.h5
# Epoch 8/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0802 - accuracy: 0.9675 - val_loss: 0.1238 - val_accuracy: 0.9544
#
# Epoch 00008: val_accuracy did not improve from 0.95773
# Epoch 9/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0541 - accuracy: 0.9801 - val_loss: 0.1248 - val_accuracy: 0.9633
#
# Epoch 00009: val_accuracy improved from 0.95773 to 0.96329, saving model to ./models/tree_10/model_root/folder5\model.h5
# Epoch 10/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0395 - accuracy: 0.9876 - val_loss: 0.1366 - val_accuracy: 0.9588
#
# Epoch 00010: val_accuracy did not improve from 0.96329
# Epoch 11/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0301 - accuracy: 0.9884 - val_loss: 0.1451 - val_accuracy: 0.9600
#
# Epoch 00011: val_accuracy did not improve from 0.96329
# Epoch 12/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0223 - accuracy: 0.9925 - val_loss: 0.1724 - val_accuracy: 0.9577
#
# Epoch 00012: val_accuracy did not improve from 0.96329
# Epoch 13/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0284 - accuracy: 0.9922 - val_loss: 0.1280 - val_accuracy: 0.9689
#
# Epoch 00013: val_accuracy improved from 0.96329 to 0.96885, saving model to ./models/tree_10/model_root/folder5\model.h5
# Epoch 14/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.0098 - accuracy: 0.9962 - val_loss: 0.1635 - val_accuracy: 0.9655
#
# Epoch 00014: val_accuracy did not improve from 0.96885
# Epoch 15/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0013 - accuracy: 0.9999 - val_loss: 0.1895 - val_accuracy: 0.9633
#
# Epoch 00015: val_accuracy did not improve from 0.96885
# Epoch 16/30
# 253/253 [==============================] - 5s 20ms/step - loss: 3.0882e-04 - accuracy: 1.0000 - val_loss: 0.1768 - val_accuracy: 0.9677
#
# Epoch 00016: val_accuracy did not improve from 0.96885
# Epoch 17/30
# 253/253 [==============================] - 5s 19ms/step - loss: 1.2422e-04 - accuracy: 1.0000 - val_loss: 0.1997 - val_accuracy: 0.9700
#
# Epoch 00017: val_accuracy improved from 0.96885 to 0.96997, saving model to ./models/tree_10/model_root/folder5\model.h5
# Epoch 18/30
# 253/253 [==============================] - 5s 19ms/step - loss: 8.0340e-05 - accuracy: 1.0000 - val_loss: 0.2074 - val_accuracy: 0.9700
#
# Epoch 00018: val_accuracy did not improve from 0.96997
# Epoch 19/30
# 253/253 [==============================] - 5s 19ms/step - loss: 5.8793e-05 - accuracy: 1.0000 - val_loss: 0.2180 - val_accuracy: 0.9677
#
# Epoch 00019: val_accuracy did not improve from 0.96997
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/30
# 253/253 [==============================] - 5s 19ms/step - loss: 4.5927e-05 - accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.9677
#
# Epoch 00020: val_accuracy did not improve from 0.96997
# Epoch 21/30
# 253/253 [==============================] - 5s 19ms/step - loss: 4.0710e-05 - accuracy: 1.0000 - val_loss: 0.2224 - val_accuracy: 0.9677
#
# Epoch 00021: val_accuracy did not improve from 0.96997
# Epoch 22/30
# 253/253 [==============================] - 5s 20ms/step - loss: 3.5652e-05 - accuracy: 1.0000 - val_loss: 0.2274 - val_accuracy: 0.9677
#
# Epoch 00022: val_accuracy did not improve from 0.96997
# Epoch 23/30
# 253/253 [==============================] - 5s 20ms/step - loss: 3.1066e-05 - accuracy: 1.0000 - val_loss: 0.2278 - val_accuracy: 0.9677
#
# Epoch 00023: val_accuracy did not improve from 0.96997
# Epoch 24/30
# 253/253 [==============================] - 5s 20ms/step - loss: 2.7362e-05 - accuracy: 1.0000 - val_loss: 0.2337 - val_accuracy: 0.9677
#
# Epoch 00024: val_accuracy did not improve from 0.96997
# Epoch 25/30
# 253/253 [==============================] - 5s 20ms/step - loss: 2.3088e-05 - accuracy: 1.0000 - val_loss: 0.2352 - val_accuracy: 0.9677
#
# Epoch 00025: val_accuracy did not improve from 0.96997
# Epoch 26/30
# 253/253 [==============================] - 5s 21ms/step - loss: 1.9909e-05 - accuracy: 1.0000 - val_loss: 0.2382 - val_accuracy: 0.9677
#
# Epoch 00026: val_accuracy did not improve from 0.96997
# Epoch 27/30
# 253/253 [==============================] - 5s 21ms/step - loss: 1.6898e-05 - accuracy: 1.0000 - val_loss: 0.2437 - val_accuracy: 0.9677
#
# Epoch 00027: val_accuracy did not improve from 0.96997
# Epoch 28/30
# 253/253 [==============================] - 5s 20ms/step - loss: 1.4279e-05 - accuracy: 1.0000 - val_loss: 0.2460 - val_accuracy: 0.9677
#
# Epoch 00028: val_accuracy did not improve from 0.96997
# Epoch 29/30
# 253/253 [==============================] - 5s 20ms/step - loss: 1.2037e-05 - accuracy: 1.0000 - val_loss: 0.2504 - val_accuracy: 0.9677
#
# Epoch 00029: val_accuracy did not improve from 0.96997
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 30/30
# 253/253 [==============================] - 5s 20ms/step - loss: 1.0222e-05 - accuracy: 1.0000 - val_loss: 0.2620 - val_accuracy: 0.9666
#
# Epoch 00030: val_accuracy did not improve from 0.96997
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 6
# Genre split [['Jazz'], ['Blues', 'Classical', 'Country', 'Disco', 'Hip-Hop', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 253/253 [==============================] - 6s 21ms/step - loss: 0.3595 - accuracy: 0.8959 - val_loss: 0.3658 - val_accuracy: 0.8977
#
# Epoch 00001: val_accuracy improved from -inf to 0.89766, saving model to ./models/tree_10/model_root/folder6\model.h5
# Epoch 2/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.2479 - accuracy: 0.9071 - val_loss: 0.1973 - val_accuracy: 0.9266
#
# Epoch 00002: val_accuracy improved from 0.89766 to 0.92659, saving model to ./models/tree_10/model_root/folder6\model.h5
# Epoch 3/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.1731 - accuracy: 0.9350 - val_loss: 0.1513 - val_accuracy: 0.9444
#
# Epoch 00003: val_accuracy improved from 0.92659 to 0.94438, saving model to ./models/tree_10/model_root/folder6\model.h5
# Epoch 4/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.1284 - accuracy: 0.9518 - val_loss: 0.1208 - val_accuracy: 0.9566
#
# Epoch 00004: val_accuracy improved from 0.94438 to 0.95662, saving model to ./models/tree_10/model_root/folder6\model.h5
# Epoch 5/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.1009 - accuracy: 0.9619 - val_loss: 0.1075 - val_accuracy: 0.9611
#
# Epoch 00005: val_accuracy improved from 0.95662 to 0.96107, saving model to ./models/tree_10/model_root/folder6\model.h5
# Epoch 6/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0724 - accuracy: 0.9737 - val_loss: 0.1075 - val_accuracy: 0.9611
#
# Epoch 00006: val_accuracy did not improve from 0.96107
# Epoch 7/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0581 - accuracy: 0.9765 - val_loss: 0.1645 - val_accuracy: 0.9410
#
# Epoch 00007: val_accuracy did not improve from 0.96107
# Epoch 8/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0452 - accuracy: 0.9821 - val_loss: 0.1476 - val_accuracy: 0.9600
#
# Epoch 00008: val_accuracy did not improve from 0.96107
# Epoch 9/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.0258 - accuracy: 0.9900 - val_loss: 0.1229 - val_accuracy: 0.9622
#
# Epoch 00009: val_accuracy improved from 0.96107 to 0.96218, saving model to ./models/tree_10/model_root/folder6\model.h5
# Epoch 10/30
# ...
# flatten_8 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.3912 - accuracy: 0.8957 - val_loss: 0.3044 - val_accuracy: 0.9088
#
# Epoch 00001: val_accuracy improved from -inf to 0.90879, saving model to ./models/tree_10/model_root/folder9\model.h5
# Epoch 2/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.3157 - accuracy: 0.8989 - val_loss: 0.2880 - val_accuracy: 0.9088
#
# Epoch 00002: val_accuracy did not improve from 0.90879
# Epoch 3/30
# 253/253 [==============================] - 5s 19ms/step - loss: 0.3028 - accuracy: 0.8975 - val_loss: 0.2666 - val_accuracy: 0.9088
#
# Epoch 00003: val_accuracy did not improve from 0.90879
# Epoch 4/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.2852 - accuracy: 0.8978 - val_loss: 0.2532 - val_accuracy: 0.9066
#
# Epoch 00004: val_accuracy did not improve from 0.90879
# Epoch 5/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.2487 - accuracy: 0.9079 - val_loss: 0.2373 - val_accuracy: 0.9288
#
# Epoch 00005: val_accuracy improved from 0.90879 to 0.92881, saving model to ./models/tree_10/model_root/folder9\model.h5
# Epoch 6/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.2236 - accuracy: 0.9198 - val_loss: 0.1972 - val_accuracy: 0.9321
#
# Epoch 00006: val_accuracy improved from 0.92881 to 0.93215, saving model to ./models/tree_10/model_root/folder9\model.h5
# Epoch 7/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.1820 - accuracy: 0.9352 - val_loss: 0.1658 - val_accuracy: 0.9466
#
# Epoch 00007: val_accuracy improved from 0.93215 to 0.94661, saving model to ./models/tree_10/model_root/folder9\model.h5
# Epoch 8/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.1560 - accuracy: 0.9436 - val_loss: 0.1969 - val_accuracy: 0.9377
#
# Epoch 00008: val_accuracy did not improve from 0.94661
# Epoch 9/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.1363 - accuracy: 0.9516 - val_loss: 0.1333 - val_accuracy: 0.9544
#
# Epoch 00009: val_accuracy improved from 0.94661 to 0.95439, saving model to ./models/tree_10/model_root/folder9\model.h5
# Epoch 10/30
# 253/253 [==============================] - 5s 20ms/step - loss: 0.1216 - accuracy: 0.9590 - val_loss: 0.1281 - val_accuracy: 0.9555
#
# Epoch 00010: val_accuracy improved from 0.95439 to 0.95551, saving model to ./models/tree_10/model_root/folder9\model.h5
# Epoch 11/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.1076 - accuracy: 0.9645 - val_loss: 0.1122 - val_accuracy: 0.9644
#
# Epoch 00011: val_accuracy improved from 0.95551 to 0.96440, saving model to ./models/tree_10/model_root/folder9\model.h5
# Epoch 12/30
# 253/253 [==============================] - 5s 22ms/step - loss: 0.0978 - accuracy: 0.9660 - val_loss: 0.1229 - val_accuracy: 0.9644
#
# Epoch 00012: val_accuracy did not improve from 0.96440
# Epoch 13/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0814 - accuracy: 0.9721 - val_loss: 0.1070 - val_accuracy: 0.9655
#
# Epoch 00013: val_accuracy improved from 0.96440 to 0.96552, saving model to ./models/tree_10/model_root/folder9\model.h5
# Epoch 14/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0648 - accuracy: 0.9780 - val_loss: 0.1111 - val_accuracy: 0.9677
#
# Epoch 00014: val_accuracy improved from 0.96552 to 0.96774, saving model to ./models/tree_10/model_root/folder9\model.h5
# Epoch 15/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0603 - accuracy: 0.9797 - val_loss: 0.1290 - val_accuracy: 0.9655
#
# Epoch 00015: val_accuracy did not improve from 0.96774
# Epoch 16/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0554 - accuracy: 0.9805 - val_loss: 0.1151 - val_accuracy: 0.9622
#
# Epoch 00016: val_accuracy did not improve from 0.96774
# Epoch 17/30
# 253/253 [==============================] - 5s 22ms/step - loss: 0.0415 - accuracy: 0.9864 - val_loss: 0.1134 - val_accuracy: 0.9666
#
# Epoch 00017: val_accuracy did not improve from 0.96774
# Epoch 18/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0361 - accuracy: 0.9876 - val_loss: 0.1059 - val_accuracy: 0.9666
#
# Epoch 00018: val_accuracy did not improve from 0.96774
# Epoch 19/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0354 - accuracy: 0.9873 - val_loss: 0.1773 - val_accuracy: 0.9622
#
# Epoch 00019: val_accuracy did not improve from 0.96774
# Epoch 20/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0203 - accuracy: 0.9934 - val_loss: 0.1604 - val_accuracy: 0.9499
#
# Epoch 00020: val_accuracy did not improve from 0.96774
# Epoch 21/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0150 - accuracy: 0.9953 - val_loss: 0.1488 - val_accuracy: 0.9544
#
# Epoch 00021: val_accuracy did not improve from 0.96774
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 22/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0051 - accuracy: 0.9991 - val_loss: 0.1384 - val_accuracy: 0.9666
#
# Epoch 00022: val_accuracy did not improve from 0.96774
# Epoch 23/30
# 253/253 [==============================] - 6s 22ms/step - loss: 0.0013 - accuracy: 0.9999 - val_loss: 0.1535 - val_accuracy: 0.9677
#
# Epoch 00023: val_accuracy did not improve from 0.96774
# Epoch 24/30
# 253/253 [==============================] - 5s 21ms/step - loss: 7.7127e-04 - accuracy: 1.0000 - val_loss: 0.1545 - val_accuracy: 0.9700
#
# Epoch 00024: val_accuracy improved from 0.96774 to 0.96997, saving model to ./models/tree_10/model_root/folder9\model.h5
# Epoch 25/30
# 253/253 [==============================] - 5s 21ms/step - loss: 5.4932e-04 - accuracy: 1.0000 - val_loss: 0.1628 - val_accuracy: 0.9700
#
# Epoch 00025: val_accuracy did not improve from 0.96997
# Epoch 26/30
# 253/253 [==============================] - 5s 21ms/step - loss: 4.3061e-04 - accuracy: 1.0000 - val_loss: 0.1658 - val_accuracy: 0.9711
#
# Epoch 00026: val_accuracy improved from 0.96997 to 0.97108, saving model to ./models/tree_10/model_root/folder9\model.h5
# Epoch 27/30
# 253/253 [==============================] - 5s 21ms/step - loss: 3.4763e-04 - accuracy: 1.0000 - val_loss: 0.1698 - val_accuracy: 0.9711
#
# Epoch 00027: val_accuracy did not improve from 0.97108
# Epoch 28/30
# 253/253 [==============================] - 5s 21ms/step - loss: 2.8321e-04 - accuracy: 1.0000 - val_loss: 0.1639 - val_accuracy: 0.9689
#
# Epoch 00028: val_accuracy did not improve from 0.97108
# Epoch 29/30
# 253/253 [==============================] - 5s 21ms/step - loss: 2.3650e-04 - accuracy: 1.0000 - val_loss: 0.1746 - val_accuracy: 0.9711
#
# Epoch 00029: val_accuracy did not improve from 0.97108
# Epoch 30/30
# 253/253 [==============================] - 5s 21ms/step - loss: 1.9854e-04 - accuracy: 1.0000 - val_loss: 0.1731 - val_accuracy: 0.9722
#
# Epoch 00030: val_accuracy improved from 0.97108 to 0.97219, saving model to ./models/tree_10/model_root/folder9\model.h5
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 10
# Genre split [['Rock'], ['Blues', 'Classical', 'Country', 'Disco', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Reggae']]
# Building model...
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 253/253 [==============================] - 6s 22ms/step - loss: 0.3384 - accuracy: 0.8974 - val_loss: 0.3585 - val_accuracy: 0.8910
#
# Epoch 00001: val_accuracy improved from -inf to 0.89099, saving model to ./models/tree_10/model_root/folder10\model.h5
# Epoch 2/30
# 253/253 [==============================] - 6s 22ms/step - loss: 0.3111 - accuracy: 0.9009 - val_loss: 0.3265 - val_accuracy: 0.8910
#
# Epoch 00002: val_accuracy did not improve from 0.89099
# Epoch 3/30
# 253/253 [==============================] - 6s 22ms/step - loss: 0.3032 - accuracy: 0.9006 - val_loss: 0.3135 - val_accuracy: 0.8910
#
# Epoch 00003: val_accuracy did not improve from 0.89099
# Epoch 4/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.2903 - accuracy: 0.9009 - val_loss: 0.3420 - val_accuracy: 0.8910
#
# Epoch 00004: val_accuracy did not improve from 0.89099
# Epoch 5/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.2741 - accuracy: 0.9009 - val_loss: 0.3122 - val_accuracy: 0.8910
#
# Epoch 00005: val_accuracy did not improve from 0.89099
# Epoch 6/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.2629 - accuracy: 0.9008 - val_loss: 0.2681 - val_accuracy: 0.8921
#
# Epoch 00006: val_accuracy improved from 0.89099 to 0.89210, saving model to ./models/tree_10/model_root/folder10\model.h5
# Epoch 7/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.2453 - accuracy: 0.9024 - val_loss: 0.3265 - val_accuracy: 0.8910
#
# Epoch 00007: val_accuracy did not improve from 0.89210
# Epoch 8/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.2357 - accuracy: 0.9074 - val_loss: 0.2587 - val_accuracy: 0.8910
#
# Epoch 00008: val_accuracy did not improve from 0.89210
# Epoch 9/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.2152 - accuracy: 0.9121 - val_loss: 0.2394 - val_accuracy: 0.8888
#
# Epoch 00009: val_accuracy did not improve from 0.89210
# Epoch 10/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.2009 - accuracy: 0.9178 - val_loss: 0.2468 - val_accuracy: 0.8999
#
# Epoch 00010: val_accuracy improved from 0.89210 to 0.89989, saving model to ./models/tree_10/model_root/folder10\model.h5
# Epoch 11/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.1909 - accuracy: 0.9246 - val_loss: 0.2501 - val_accuracy: 0.8954
#
# Epoch 00011: val_accuracy did not improve from 0.89989
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 12/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.1348 - accuracy: 0.9460 - val_loss: 0.2274 - val_accuracy: 0.8977
#
# Epoch 00012: val_accuracy did not improve from 0.89989
# Epoch 13/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0965 - accuracy: 0.9632 - val_loss: 0.2359 - val_accuracy: 0.9121
#
# Epoch 00013: val_accuracy improved from 0.89989 to 0.91212, saving model to ./models/tree_10/model_root/folder10\model.h5
# Epoch 14/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0755 - accuracy: 0.9718 - val_loss: 0.2319 - val_accuracy: 0.9177
#
# Epoch 00014: val_accuracy improved from 0.91212 to 0.91769, saving model to ./models/tree_10/model_root/folder10\model.h5
# Epoch 15/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0475 - accuracy: 0.9847 - val_loss: 0.2316 - val_accuracy: 0.9143
#
# Epoch 00015: val_accuracy did not improve from 0.91769
# Epoch 16/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0346 - accuracy: 0.9885 - val_loss: 0.3393 - val_accuracy: 0.9088
#
# Epoch 00016: val_accuracy did not improve from 0.91769
# Epoch 17/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0331 - accuracy: 0.9906 - val_loss: 0.3663 - val_accuracy: 0.9132loss: 0.031
#
# Epoch 00017: val_accuracy did not improve from 0.91769
# Epoch 18/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0175 - accuracy: 0.9967 - val_loss: 0.3577 - val_accuracy: 0.9166
#
# Epoch 00018: val_accuracy did not improve from 0.91769
# Epoch 19/30
# 253/253 [==============================] - 6s 24ms/step - loss: 0.0142 - accuracy: 0.9977 - val_loss: 0.2606 - val_accuracy: 0.9077
#
# Epoch 00019: val_accuracy did not improve from 0.91769
# Epoch 20/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0154 - accuracy: 0.9978 - val_loss: 0.2865 - val_accuracy: 0.9099
#
# Epoch 00020: val_accuracy did not improve from 0.91769
# Epoch 21/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0162 - accuracy: 0.9959 - val_loss: 0.3654 - val_accuracy: 0.9121
#
# Epoch 00021: val_accuracy did not improve from 0.91769
# Epoch 22/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0141 - accuracy: 0.9973 - val_loss: 0.3138 - val_accuracy: 0.9132
#
# Epoch 00022: val_accuracy did not improve from 0.91769
# Epoch 23/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0176 - accuracy: 0.9951 - val_loss: 0.3347 - val_accuracy: 0.9121
#
# Epoch 00023: val_accuracy did not improve from 0.91769
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 24/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0072 - accuracy: 0.9989 - val_loss: 0.3367 - val_accuracy: 0.9188
#
# Epoch 00024: val_accuracy improved from 0.91769 to 0.91880, saving model to ./models/tree_10/model_root/folder10\model.h5
# Epoch 25/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0058 - accuracy: 0.9985 - val_loss: 0.3284 - val_accuracy: 0.9166
#
# Epoch 00025: val_accuracy did not improve from 0.91880
# Epoch 26/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0065 - accuracy: 0.9985 - val_loss: 0.3422 - val_accuracy: 0.9110
#
# Epoch 00026: val_accuracy did not improve from 0.91880
# Epoch 27/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0058 - accuracy: 0.9985 - val_loss: 0.3660 - val_accuracy: 0.9143
#
# Epoch 00027: val_accuracy did not improve from 0.91880
# Epoch 28/30
# 253/253 [==============================] - 6s 23ms/step - loss: 0.0065 - accuracy: 0.9981 - val_loss: 0.3234 - val_accuracy: 0.9166
#
# Epoch 00028: val_accuracy did not improve from 0.91880
# Epoch 29/30
# 253/253 [==============================] - 5s 21ms/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.4034 - val_accuracy: 0.9132
#
# Epoch 00029: val_accuracy did not improve from 0.91880
# Epoch 30/30
# 253/253 [==============================] - 6s 22ms/step - loss: 0.0068 - accuracy: 0.9983 - val_loss: 0.3963 - val_accuracy: 0.9132
#
# Epoch 00030: val_accuracy did not improve from 0.91880
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
