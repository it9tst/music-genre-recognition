# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Blues':0, 'Country':2, 'Pop':7, 'Reggae':8, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Blues', 2: 'Country', 7: 'Pop', 8: 'Reggae', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((4000, 128, 128), (4000, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((500, 128, 128), (500, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Country

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation='softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_10/model_root_f1_1_1_1_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_10/model_root_f1_1_1_1_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 5
n_splits = 10

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    dict_genres_list = list(dict_genres.values())
    split = [[dict_genres_list.pop(fold_no - 1)], dict_genres_list]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Blues'], ['Country', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 6s 26ms/step - loss: 0.5722 - accuracy: 0.7933 - val_loss: 0.4921 - val_accuracy: 0.8089
#
# Epoch 00001: val_accuracy improved from -inf to 0.80889, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 2/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.4539 - accuracy: 0.8104 - val_loss: 0.3941 - val_accuracy: 0.8289
#
# Epoch 00002: val_accuracy improved from 0.80889 to 0.82889, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 3/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.4010 - accuracy: 0.8299 - val_loss: 0.3658 - val_accuracy: 0.8511
#
# Epoch 00003: val_accuracy improved from 0.82889 to 0.85111, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 4/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.3278 - accuracy: 0.8647 - val_loss: 0.2412 - val_accuracy: 0.9067
#
# Epoch 00004: val_accuracy improved from 0.85111 to 0.90667, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 5/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.2504 - accuracy: 0.8993 - val_loss: 0.2564 - val_accuracy: 0.8778
#
# Epoch 00005: val_accuracy did not improve from 0.90667
# Epoch 6/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.1955 - accuracy: 0.9207 - val_loss: 0.3049 - val_accuracy: 0.8867
#
# Epoch 00006: val_accuracy did not improve from 0.90667
# Epoch 7/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.1681 - accuracy: 0.9368 - val_loss: 0.2275 - val_accuracy: 0.9067
#
# Epoch 00007: val_accuracy did not improve from 0.90667
# Epoch 8/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.1154 - accuracy: 0.9533 - val_loss: 0.2125 - val_accuracy: 0.9089
#
# Epoch 00008: val_accuracy improved from 0.90667 to 0.90889, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 9/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0936 - accuracy: 0.9640 - val_loss: 0.1472 - val_accuracy: 0.9489
#
# Epoch 00009: val_accuracy improved from 0.90889 to 0.94889, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 10/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0546 - accuracy: 0.9820 - val_loss: 0.1457 - val_accuracy: 0.9556
#
# Epoch 00010: val_accuracy improved from 0.94889 to 0.95556, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 11/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0500 - accuracy: 0.9805 - val_loss: 0.2059 - val_accuracy: 0.9400
#
# Epoch 00011: val_accuracy did not improve from 0.95556
# Epoch 12/30
# 127/127 [==============================] - 3s 23ms/step - loss: 0.0282 - accuracy: 0.9923 - val_loss: 0.1591 - val_accuracy: 0.9511
#
# Epoch 00012: val_accuracy did not improve from 0.95556
# Epoch 13/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0351 - accuracy: 0.9881 - val_loss: 0.2410 - val_accuracy: 0.8956
#
# Epoch 00013: val_accuracy did not improve from 0.95556
# Epoch 14/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0443 - accuracy: 0.9815 - val_loss: 0.2361 - val_accuracy: 0.9267
#
# Epoch 00014: val_accuracy did not improve from 0.95556
# Epoch 15/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0205 - accuracy: 0.9933 - val_loss: 0.1998 - val_accuracy: 0.9622
#
# Epoch 00015: val_accuracy improved from 0.95556 to 0.96222, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 16/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0204 - accuracy: 0.9931 - val_loss: 0.1959 - val_accuracy: 0.9444
#
# Epoch 00016: val_accuracy did not improve from 0.96222
# Epoch 17/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0240 - accuracy: 0.9919 - val_loss: 0.2361 - val_accuracy: 0.9511
#
# Epoch 00017: val_accuracy did not improve from 0.96222
# Epoch 18/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0194 - accuracy: 0.9931 - val_loss: 0.3916 - val_accuracy: 0.9156
#
# Epoch 00018: val_accuracy did not improve from 0.96222
# Epoch 19/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 0.2089 - val_accuracy: 0.9489
#
# Epoch 00019: val_accuracy did not improve from 0.96222
# Epoch 20/30
# 127/127 [==============================] - 3s 21ms/step - loss: 4.2503e-04 - accuracy: 1.0000 - val_loss: 0.2130 - val_accuracy: 0.9533
#
# Epoch 00020: val_accuracy did not improve from 0.96222
# Epoch 21/30
# 127/127 [==============================] - 3s 22ms/step - loss: 2.1597e-04 - accuracy: 1.0000 - val_loss: 0.2142 - val_accuracy: 0.9511
#
# Epoch 00021: val_accuracy did not improve from 0.96222
# Epoch 22/30
# 127/127 [==============================] - 3s 21ms/step - loss: 1.6400e-04 - accuracy: 1.0000 - val_loss: 0.2180 - val_accuracy: 0.9511
#
# Epoch 00022: val_accuracy did not improve from 0.96222
# Epoch 23/30
# 127/127 [==============================] - 3s 22ms/step - loss: 1.3509e-04 - accuracy: 1.0000 - val_loss: 0.2182 - val_accuracy: 0.9533
#
# Epoch 00023: val_accuracy did not improve from 0.96222
# Epoch 24/30
# 127/127 [==============================] - 3s 21ms/step - loss: 1.1389e-04 - accuracy: 1.0000 - val_loss: 0.2204 - val_accuracy: 0.9556
#
# Epoch 00024: val_accuracy did not improve from 0.96222
# Epoch 25/30
# 127/127 [==============================] - 3s 22ms/step - loss: 9.6360e-05 - accuracy: 1.0000 - val_loss: 0.2245 - val_accuracy: 0.9556
#
# Epoch 00025: val_accuracy did not improve from 0.96222
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 26/30
# 127/127 [==============================] - 3s 23ms/step - loss: 8.5433e-05 - accuracy: 1.0000 - val_loss: 0.2241 - val_accuracy: 0.9533
#
# Epoch 00026: val_accuracy did not improve from 0.96222
# Epoch 27/30
# 127/127 [==============================] - 3s 22ms/step - loss: 7.9488e-05 - accuracy: 1.0000 - val_loss: 0.2239 - val_accuracy: 0.9578
#
# Epoch 00027: val_accuracy did not improve from 0.96222
# Epoch 28/30
# 127/127 [==============================] - 3s 22ms/step - loss: 7.4538e-05 - accuracy: 1.0000 - val_loss: 0.2260 - val_accuracy: 0.9556
#
# Epoch 00028: val_accuracy did not improve from 0.96222
# Epoch 29/30
# 127/127 [==============================] - 3s 23ms/step - loss: 6.9861e-05 - accuracy: 1.0000 - val_loss: 0.2276 - val_accuracy: 0.9533
#
# Epoch 00029: val_accuracy did not improve from 0.96222
# Epoch 30/30
# 127/127 [==============================] - 3s 21ms/step - loss: 6.5310e-05 - accuracy: 1.0000 - val_loss: 0.2285 - val_accuracy: 0.9533
#
# Epoch 00030: val_accuracy did not improve from 0.96222
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Country'], ['Blues', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 3s 23ms/step - loss: 0.5544 - accuracy: 0.7825 - val_loss: 0.4588 - val_accuracy: 0.8244
#
# Epoch 00001: val_accuracy improved from -inf to 0.82444, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 2/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.4443 - accuracy: 0.7968 - val_loss: 0.3627 - val_accuracy: 0.8378
#
# Epoch 00002: val_accuracy improved from 0.82444 to 0.83778, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 3/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.4055 - accuracy: 0.8091 - val_loss: 0.3470 - val_accuracy: 0.8289
#
# Epoch 00003: val_accuracy did not improve from 0.83778
# Epoch 4/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.3830 - accuracy: 0.8207 - val_loss: 0.3413 - val_accuracy: 0.8400
#
# Epoch 00004: val_accuracy improved from 0.83778 to 0.84000, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 5/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.3688 - accuracy: 0.8230 - val_loss: 0.3270 - val_accuracy: 0.8489
#
# Epoch 00005: val_accuracy improved from 0.84000 to 0.84889, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 6/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.3496 - accuracy: 0.8373 - val_loss: 0.3539 - val_accuracy: 0.8444
#
# Epoch 00006: val_accuracy did not improve from 0.84889
# Epoch 7/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.3415 - accuracy: 0.8380 - val_loss: 0.3230 - val_accuracy: 0.8489
#
# Epoch 00007: val_accuracy did not improve from 0.84889
# Epoch 8/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.3275 - accuracy: 0.8420 - val_loss: 0.3265 - val_accuracy: 0.8444
#
# Epoch 00008: val_accuracy did not improve from 0.84889
# Epoch 9/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.3075 - accuracy: 0.8637 - val_loss: 0.2974 - val_accuracy: 0.8644
#
# Epoch 00009: val_accuracy improved from 0.84889 to 0.86444, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 10/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.2849 - accuracy: 0.8657 - val_loss: 0.3180 - val_accuracy: 0.8511
#
# Epoch 00010: val_accuracy did not improve from 0.86444
# Epoch 11/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.2704 - accuracy: 0.8798 - val_loss: 0.3001 - val_accuracy: 0.8733
#
# Epoch 00011: val_accuracy improved from 0.86444 to 0.87333, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 12/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.2553 - accuracy: 0.8844 - val_loss: 0.3154 - val_accuracy: 0.8622
#
# Epoch 00012: val_accuracy did not improve from 0.87333
# Epoch 13/30
# 127/127 [==============================] - 3s 24ms/step - loss: 0.2126 - accuracy: 0.9116 - val_loss: 0.3022 - val_accuracy: 0.8644 - accura
#
# Epoch 00013: val_accuracy did not improve from 0.87333
# Epoch 14/30
# 127/127 [==============================] - 3s 23ms/step - loss: 0.1870 - accuracy: 0.9232 - val_loss: 0.3459 - val_accuracy: 0.8644
#
# Epoch 00014: val_accuracy did not improve from 0.87333
# Epoch 15/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.1525 - accuracy: 0.9370 - val_loss: 0.5016 - val_accuracy: 0.8489
#
# Epoch 00015: val_accuracy did not improve from 0.87333
# Epoch 16/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.1126 - accuracy: 0.9578 - val_loss: 0.4446 - val_accuracy: 0.8422
#
# Epoch 00016: val_accuracy did not improve from 0.87333
# Epoch 17/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0638 - accuracy: 0.9780 - val_loss: 0.4526 - val_accuracy: 0.8556
#
# Epoch 00017: val_accuracy did not improve from 0.87333
# Epoch 18/30
# 127/127 [==============================] - 3s 23ms/step - loss: 0.0479 - accuracy: 0.9857 - val_loss: 0.4819 - val_accuracy: 0.8467
#
# Epoch 00018: val_accuracy did not improve from 0.87333
# Epoch 19/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0394 - accuracy: 0.9877 - val_loss: 0.5763 - val_accuracy: 0.8533
#
# Epoch 00019: val_accuracy did not improve from 0.87333
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0113 - accuracy: 0.9995 - val_loss: 0.5593 - val_accuracy: 0.8511
#
# Epoch 00020: val_accuracy did not improve from 0.87333
# Epoch 21/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.5939 - val_accuracy: 0.8711
#
# Epoch 00021: val_accuracy did not improve from 0.87333
# Epoch 22/30
# 127/127 [==============================] - 3s 23ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.6045 - val_accuracy: 0.8578
#
# Epoch 00022: val_accuracy did not improve from 0.87333
# Epoch 23/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.6304 - val_accuracy: 0.8600
#
# Epoch 00023: val_accuracy did not improve from 0.87333
# Epoch 24/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.6432 - val_accuracy: 0.8556
#
# Epoch 00024: val_accuracy did not improve from 0.87333
# Epoch 25/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.6940 - val_accuracy: 0.8622
#
# Epoch 00025: val_accuracy did not improve from 0.87333
# Epoch 26/30
# 127/127 [==============================] - 3s 21ms/step - loss: 8.9459e-04 - accuracy: 1.0000 - val_loss: 0.7138 - val_accuracy: 0.8600
#
# Epoch 00026: val_accuracy did not improve from 0.87333
# Epoch 27/30
# 127/127 [==============================] - 3s 21ms/step - loss: 7.3529e-04 - accuracy: 1.0000 - val_loss: 0.7250 - val_accuracy: 0.8600
#
# Epoch 00027: val_accuracy did not improve from 0.87333
# Epoch 28/30
# 127/127 [==============================] - 3s 21ms/step - loss: 6.1939e-04 - accuracy: 1.0000 - val_loss: 0.7405 - val_accuracy: 0.8600
#
# Epoch 00028: val_accuracy did not improve from 0.87333
# Epoch 29/30
# 127/127 [==============================] - 3s 21ms/step - loss: 5.1670e-04 - accuracy: 1.0000 - val_loss: 0.7619 - val_accuracy: 0.8644
#
# Epoch 00029: val_accuracy did not improve from 0.87333
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 30/30
# 127/127 [==============================] - 3s 22ms/step - loss: 4.4515e-04 - accuracy: 1.0000 - val_loss: 0.7631 - val_accuracy: 0.8622
#
# Epoch 00030: val_accuracy did not improve from 0.87333
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Pop'], ['Blues', 'Country', 'Reggae', 'Rock']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 3s 23ms/step - loss: 0.5231 - accuracy: 0.7963 - val_loss: 0.4384 - val_accuracy: 0.7689
#
# Epoch 00001: val_accuracy improved from -inf to 0.76889, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder3\model.h5
# Epoch 2/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.2828 - accuracy: 0.8632 - val_loss: 0.2482 - val_accuracy: 0.8889
#
# Epoch 00002: val_accuracy improved from 0.76889 to 0.88889, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder3\model.h5
# Epoch 3/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.2265 - accuracy: 0.9007 - val_loss: 0.3177 - val_accuracy: 0.8533
#
# Epoch 00003: val_accuracy did not improve from 0.88889
# Epoch 4/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.2118 - accuracy: 0.9079 - val_loss: 0.2169 - val_accuracy: 0.9133
#
# Epoch 00004: val_accuracy improved from 0.88889 to 0.91333, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder3\model.h5
# Epoch 5/30
# 127/127 [==============================] - 3s 23ms/step - loss: 0.2057 - accuracy: 0.9131 - val_loss: 0.2059 - val_accuracy: 0.9133
#
# Epoch 00005: val_accuracy did not improve from 0.91333
# Epoch 6/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.1789 - accuracy: 0.9284 - val_loss: 0.2093 - val_accuracy: 0.9200
#
# Epoch 00006: val_accuracy improved from 0.91333 to 0.92000, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder3\model.h5
# Epoch 7/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.1582 - accuracy: 0.9353 - val_loss: 0.2613 - val_accuracy: 0.8778
#
# Epoch 00007: val_accuracy did not improve from 0.92000
# Epoch 8/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.1416 - accuracy: 0.9420 - val_loss: 0.1960 - val_accuracy: 0.9311
#
# Epoch 00008: val_accuracy improved from 0.92000 to 0.93111, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder3\model.h5
# Epoch 9/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.1347 - accuracy: 0.9454 - val_loss: 0.1908 - val_accuracy: 0.9356
#
# Epoch 00009: val_accuracy improved from 0.93111 to 0.93556, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder3\model.h5
# Epoch 10/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.1259 - accuracy: 0.9491 - val_loss: 0.1830 - val_accuracy: 0.9378
#
# Epoch 00010: val_accuracy improved from 0.93556 to 0.93778, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder3\model.h5
# Epoch 11/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.1162 - accuracy: 0.9551 - val_loss: 0.1906 - val_accuracy: 0.9378
#
# Epoch 00011: val_accuracy did not improve from 0.93778
# Epoch 12/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.1156 - accuracy: 0.9526 - val_loss: 0.1844 - val_accuracy: 0.9311
#
# Epoch 00012: val_accuracy did not improve from 0.93778
# Epoch 13/30
# 127/127 [==============================] - 3s 23ms/step - loss: 0.1066 - accuracy: 0.9558 - val_loss: 0.2252 - val_accuracy: 0.9044
#
# Epoch 00013: val_accuracy did not improve from 0.93778
# Epoch 14/30
# 127/127 [==============================] - 3s 24ms/step - loss: 0.1005 - accuracy: 0.9600 - val_loss: 0.1665 - val_accuracy: 0.9311
#
# Epoch 00014: val_accuracy did not improve from 0.93778
# Epoch 15/30
# 127/127 [==============================] - 3s 26ms/step - loss: 0.0901 - accuracy: 0.9662 - val_loss: 0.1822 - val_accuracy: 0.9400
#
# Epoch 00015: val_accuracy improved from 0.93778 to 0.94000, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder3\model.h5
# Epoch 16/30
# 127/127 [==============================] - 3s 25ms/step - loss: 0.0770 - accuracy: 0.9716 - val_loss: 0.2905 - val_accuracy: 0.9289
#
# Epoch 00016: val_accuracy did not improve from 0.94000
# Epoch 17/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0836 - accuracy: 0.9654 - val_loss: 0.3455 - val_accuracy: 0.8867
#
# Epoch 00017: val_accuracy did not improve from 0.94000
# Epoch 18/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0828 - accuracy: 0.9659 - val_loss: 0.2135 - val_accuracy: 0.9333
#
# Epoch 00018: val_accuracy did not improve from 0.94000
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 19/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0485 - accuracy: 0.9815 - val_loss: 0.2180 - val_accuracy: 0.9400
#
# Epoch 00019: val_accuracy did not improve from 0.94000
# Epoch 20/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0365 - accuracy: 0.9889 - val_loss: 0.2311 - val_accuracy: 0.9356
#
# Epoch 00020: val_accuracy did not improve from 0.94000
# Epoch 21/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0286 - accuracy: 0.9906 - val_loss: 0.2471 - val_accuracy: 0.9400
#
# Epoch 00021: val_accuracy did not improve from 0.94000
# Epoch 22/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0268 - accuracy: 0.9923 - val_loss: 0.2347 - val_accuracy: 0.9400
#
# Epoch 00022: val_accuracy did not improve from 0.94000
# Epoch 23/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0270 - accuracy: 0.9904 - val_loss: 0.2537 - val_accuracy: 0.9422
#
# Epoch 00023: val_accuracy improved from 0.94000 to 0.94222, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder3\model.h5
# Epoch 24/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0175 - accuracy: 0.9946 - val_loss: 0.2427 - val_accuracy: 0.9333
#
# Epoch 00024: val_accuracy did not improve from 0.94222
# Epoch 25/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0149 - accuracy: 0.9963 - val_loss: 0.2779 - val_accuracy: 0.9378
#
# Epoch 00025: val_accuracy did not improve from 0.94222
# Epoch 26/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0141 - accuracy: 0.9965 - val_loss: 0.3168 - val_accuracy: 0.9422
#
# Epoch 00026: val_accuracy did not improve from 0.94222
# Epoch 27/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0134 - accuracy: 0.9960 - val_loss: 0.3179 - val_accuracy: 0.9356
#
# Epoch 00027: val_accuracy did not improve from 0.94222
# Epoch 28/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0085 - accuracy: 0.9983 - val_loss: 0.2969 - val_accuracy: 0.9356
#
# Epoch 00028: val_accuracy did not improve from 0.94222
# Epoch 29/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0076 - accuracy: 0.9983 - val_loss: 0.3270 - val_accuracy: 0.9400
#
# Epoch 00029: val_accuracy did not improve from 0.94222
# Epoch 30/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.3401 - val_accuracy: 0.9400
#
# Epoch 00030: val_accuracy did not improve from 0.94222
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Reggae'], ['Blues', 'Country', 'Pop', 'Rock']]
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 3s 23ms/step - loss: 0.5462 - accuracy: 0.7854 - val_loss: 0.4264 - val_accuracy: 0.8222
#
# Epoch 00001: val_accuracy improved from -inf to 0.82222, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder4\model.h5
# Epoch 2/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.4237 - accuracy: 0.8178 - val_loss: 0.3697 - val_accuracy: 0.8822
#
# Epoch 00002: val_accuracy improved from 0.82222 to 0.88222, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder4\model.h5
# Epoch 3/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.3653 - accuracy: 0.8486 - val_loss: 0.2933 - val_accuracy: 0.8844
#
# Epoch 00003: val_accuracy improved from 0.88222 to 0.88444, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder4\model.h5
# Epoch 4/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.2953 - accuracy: 0.8884 - val_loss: 0.2367 - val_accuracy: 0.9133
#
# Epoch 00004: val_accuracy improved from 0.88444 to 0.91333, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder4\model.h5
# Epoch 5/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.2536 - accuracy: 0.9012 - val_loss: 0.2749 - val_accuracy: 0.9133
#
# Epoch 00005: val_accuracy did not improve from 0.91333
# Epoch 6/30
# 127/127 [==============================] - 3s 23ms/step - loss: 0.1806 - accuracy: 0.9356 - val_loss: 0.2568 - val_accuracy: 0.9067
#
# Epoch 00006: val_accuracy did not improve from 0.91333
# Epoch 7/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.1388 - accuracy: 0.9449 - val_loss: 0.2137 - val_accuracy: 0.9333
#
# Epoch 00007: val_accuracy improved from 0.91333 to 0.93333, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder4\model.h5
# Epoch 8/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0851 - accuracy: 0.9672 - val_loss: 0.2007 - val_accuracy: 0.9444
#
# Epoch 00008: val_accuracy improved from 0.93333 to 0.94444, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder4\model.h5
# Epoch 9/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0482 - accuracy: 0.9840 - val_loss: 0.3968 - val_accuracy: 0.9222
#
# Epoch 00009: val_accuracy did not improve from 0.94444
# Epoch 10/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0569 - accuracy: 0.9805 - val_loss: 0.3062 - val_accuracy: 0.9400
#
# Epoch 00010: val_accuracy did not improve from 0.94444
# Epoch 11/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0223 - accuracy: 0.9938 - val_loss: 0.2030 - val_accuracy: 0.9467
#
# Epoch 00011: val_accuracy improved from 0.94444 to 0.94667, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder4\model.h5
# Epoch 12/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0043 - accuracy: 0.9993 - val_loss: 0.2853 - val_accuracy: 0.9533
#
# Epoch 00012: val_accuracy improved from 0.94667 to 0.95333, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder4\model.h5
# Epoch 13/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2508 - val_accuracy: 0.9533
#
# Epoch 00013: val_accuracy did not improve from 0.95333
# Epoch 14/30
# 127/127 [==============================] - 3s 21ms/step - loss: 3.6885e-04 - accuracy: 1.0000 - val_loss: 0.2713 - val_accuracy: 0.9533
#
# Epoch 00014: val_accuracy did not improve from 0.95333
# Epoch 15/30
# 127/127 [==============================] - 3s 21ms/step - loss: 2.1880e-04 - accuracy: 1.0000 - val_loss: 0.2856 - val_accuracy: 0.9489
#
# Epoch 00015: val_accuracy did not improve from 0.95333
# Epoch 16/30
# 127/127 [==============================] - 3s 22ms/step - loss: 1.6380e-04 - accuracy: 1.0000 - val_loss: 0.2898 - val_accuracy: 0.9489
#
# Epoch 00016: val_accuracy did not improve from 0.95333
# Epoch 17/30
# 127/127 [==============================] - 3s 22ms/step - loss: 1.2824e-04 - accuracy: 1.0000 - val_loss: 0.2959 - val_accuracy: 0.9489
#
# Epoch 00017: val_accuracy did not improve from 0.95333
# Epoch 18/30
# 127/127 [==============================] - 3s 21ms/step - loss: 1.0598e-04 - accuracy: 1.0000 - val_loss: 0.2985 - val_accuracy: 0.9489
#
# Epoch 00018: val_accuracy did not improve from 0.95333
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 19/30
# 127/127 [==============================] - 3s 22ms/step - loss: 9.0050e-05 - accuracy: 1.0000 - val_loss: 0.3005 - val_accuracy: 0.9489
#
# Epoch 00019: val_accuracy did not improve from 0.95333
# Epoch 20/30
# 127/127 [==============================] - 3s 22ms/step - loss: 8.2883e-05 - accuracy: 1.0000 - val_loss: 0.3030 - val_accuracy: 0.9489
#
# Epoch 00020: val_accuracy did not improve from 0.95333
# Epoch 21/30
# 127/127 [==============================] - 3s 21ms/step - loss: 7.6564e-05 - accuracy: 1.0000 - val_loss: 0.3061 - val_accuracy: 0.9489
#
# Epoch 00021: val_accuracy did not improve from 0.95333
# Epoch 22/30
# 127/127 [==============================] - 3s 21ms/step - loss: 7.0767e-05 - accuracy: 1.0000 - val_loss: 0.3093 - val_accuracy: 0.9489
#
# Epoch 00022: val_accuracy did not improve from 0.95333
# Epoch 23/30
# 127/127 [==============================] - 3s 21ms/step - loss: 6.4747e-05 - accuracy: 1.0000 - val_loss: 0.3063 - val_accuracy: 0.9511
#
# Epoch 00023: val_accuracy did not improve from 0.95333
# Epoch 24/30
# 127/127 [==============================] - 3s 21ms/step - loss: 6.0635e-05 - accuracy: 1.0000 - val_loss: 0.3134 - val_accuracy: 0.9489
#
# Epoch 00024: val_accuracy did not improve from 0.95333
# Epoch 25/30
# 127/127 [==============================] - 3s 22ms/step - loss: 5.5899e-05 - accuracy: 1.0000 - val_loss: 0.3129 - val_accuracy: 0.9489
#
# Epoch 00025: val_accuracy did not improve from 0.95333
# Epoch 26/30
# 127/127 [==============================] - 3s 23ms/step - loss: 5.1560e-05 - accuracy: 1.0000 - val_loss: 0.3163 - val_accuracy: 0.9489
#
# Epoch 00026: val_accuracy did not improve from 0.95333
# Epoch 27/30
# 127/127 [==============================] - 3s 23ms/step - loss: 4.8134e-05 - accuracy: 1.0000 - val_loss: 0.3192 - val_accuracy: 0.9489
#
# Epoch 00027: val_accuracy did not improve from 0.95333
# Epoch 28/30
# 127/127 [==============================] - 3s 22ms/step - loss: 4.3969e-05 - accuracy: 1.0000 - val_loss: 0.3172 - val_accuracy: 0.9489
#
# Epoch 00028: val_accuracy did not improve from 0.95333
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 29/30
# 127/127 [==============================] - 3s 23ms/step - loss: 4.1201e-05 - accuracy: 1.0000 - val_loss: 0.3224 - val_accuracy: 0.9489
#
# Epoch 00029: val_accuracy did not improve from 0.95333
# Epoch 30/30
# 127/127 [==============================] - 3s 21ms/step - loss: 3.9441e-05 - accuracy: 1.0000 - val_loss: 0.3262 - val_accuracy: 0.9489
#
# Epoch 00030: val_accuracy did not improve from 0.95333
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 5
# Genre split [['Rock'], ['Blues', 'Country', 'Pop', 'Reggae']]
# Building model...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 3s 24ms/step - loss: 0.5200 - accuracy: 0.7958 - val_loss: 0.4345 - val_accuracy: 0.8067
#
# Epoch 00001: val_accuracy improved from -inf to 0.80667, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder5\model.h5
# Epoch 2/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.4486 - accuracy: 0.8084 - val_loss: 0.4661 - val_accuracy: 0.8067
#
# Epoch 00002: val_accuracy did not improve from 0.80667
# Epoch 3/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.4310 - accuracy: 0.8274 - val_loss: 0.4109 - val_accuracy: 0.8378
#
# Epoch 00003: val_accuracy improved from 0.80667 to 0.83778, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder5\model.h5
# Epoch 4/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.4214 - accuracy: 0.8242 - val_loss: 0.4573 - val_accuracy: 0.8067
#
# Epoch 00004: val_accuracy did not improve from 0.83778
# Epoch 5/30
# 127/127 [==============================] - 3s 23ms/step - loss: 0.4107 - accuracy: 0.8333 - val_loss: 0.4084 - val_accuracy: 0.8333
#
# Epoch 00005: val_accuracy did not improve from 0.83778
# Epoch 6/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.4089 - accuracy: 0.8294 - val_loss: 0.4068 - val_accuracy: 0.8467
#
# Epoch 00006: val_accuracy improved from 0.83778 to 0.84667, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder5\model.h5
# Epoch 7/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.3965 - accuracy: 0.8356 - val_loss: 0.4025 - val_accuracy: 0.8533
#
# Epoch 00007: val_accuracy improved from 0.84667 to 0.85333, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder5\model.h5
# Epoch 8/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.3868 - accuracy: 0.8375 - val_loss: 0.4111 - val_accuracy: 0.8356
#
# Epoch 00008: val_accuracy did not improve from 0.85333
# Epoch 9/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.3781 - accuracy: 0.8417 - val_loss: 0.4031 - val_accuracy: 0.8356
#
# Epoch 00009: val_accuracy did not improve from 0.85333
# Epoch 10/30
# 127/127 [==============================] - 3s 24ms/step - loss: 0.3754 - accuracy: 0.8442 - val_loss: 0.4028 - val_accuracy: 0.8489
#
# Epoch 00010: val_accuracy did not improve from 0.85333
# Epoch 11/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.3666 - accuracy: 0.8469 - val_loss: 0.4626 - val_accuracy: 0.8489
#
# Epoch 00011: val_accuracy did not improve from 0.85333
# Epoch 12/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.3639 - accuracy: 0.8494 - val_loss: 0.4394 - val_accuracy: 0.8200
#
# Epoch 00012: val_accuracy did not improve from 0.85333
# Epoch 13/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.3502 - accuracy: 0.8570 - val_loss: 0.4001 - val_accuracy: 0.8533
#
# Epoch 00013: val_accuracy did not improve from 0.85333
# Epoch 14/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.3397 - accuracy: 0.8630 - val_loss: 0.4052 - val_accuracy: 0.8400
#
# Epoch 00014: val_accuracy did not improve from 0.85333
# Epoch 15/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.3327 - accuracy: 0.8595 - val_loss: 0.4088 - val_accuracy: 0.8222
#
# Epoch 00015: val_accuracy did not improve from 0.85333
# Epoch 16/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.3045 - accuracy: 0.8741 - val_loss: 0.3638 - val_accuracy: 0.8533
#
# Epoch 00016: val_accuracy did not improve from 0.85333
# Epoch 17/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.2836 - accuracy: 0.8822 - val_loss: 0.3861 - val_accuracy: 0.8600
#
# Epoch 00017: val_accuracy improved from 0.85333 to 0.86000, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder5\model.h5
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 18/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.2445 - accuracy: 0.8998 - val_loss: 0.3578 - val_accuracy: 0.8622
#
# Epoch 00018: val_accuracy improved from 0.86000 to 0.86222, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder5\model.h5
# Epoch 19/30
# 127/127 [==============================] - 3s 23ms/step - loss: 0.2213 - accuracy: 0.9133 - val_loss: 0.3471 - val_accuracy: 0.8778
#
# Epoch 00019: val_accuracy improved from 0.86222 to 0.87778, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder5\model.h5
# Epoch 20/30
# 127/127 [==============================] - 3s 25ms/step - loss: 0.2018 - accuracy: 0.9163 - val_loss: 0.3349 - val_accuracy: 0.8778
#
# Epoch 00020: val_accuracy did not improve from 0.87778
# Epoch 21/30
# 127/127 [==============================] - 3s 24ms/step - loss: 0.1769 - accuracy: 0.9274 - val_loss: 0.4334 - val_accuracy: 0.8778
#
# Epoch 00021: val_accuracy did not improve from 0.87778
# Epoch 22/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.1592 - accuracy: 0.9402 - val_loss: 0.3361 - val_accuracy: 0.8800
#
# Epoch 00022: val_accuracy improved from 0.87778 to 0.88000, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder5\model.h5
# Epoch 23/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.1462 - accuracy: 0.9425 - val_loss: 0.3546 - val_accuracy: 0.8889
#
# Epoch 00023: val_accuracy improved from 0.88000 to 0.88889, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder5\model.h5
# Epoch 24/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.1152 - accuracy: 0.9610 - val_loss: 0.3922 - val_accuracy: 0.8844
#
# Epoch 00024: val_accuracy did not improve from 0.88889
# Epoch 25/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0988 - accuracy: 0.9672 - val_loss: 0.3770 - val_accuracy: 0.8911
#
# Epoch 00025: val_accuracy improved from 0.88889 to 0.89111, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder5\model.h5
# Epoch 26/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0668 - accuracy: 0.9790 - val_loss: 0.4194 - val_accuracy: 0.8889
#
# Epoch 00026: val_accuracy did not improve from 0.89111
# Epoch 27/30
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0485 - accuracy: 0.9872 - val_loss: 0.4920 - val_accuracy: 0.8800
#
# Epoch 00027: val_accuracy did not improve from 0.89111
# Epoch 28/30
# 127/127 [==============================] - 3s 23ms/step - loss: 0.0410 - accuracy: 0.9889 - val_loss: 0.4263 - val_accuracy: 0.8956
#
# Epoch 00028: val_accuracy improved from 0.89111 to 0.89556, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder5\model.h5
# Epoch 29/30
# 127/127 [==============================] - 3s 23ms/step - loss: 0.0263 - accuracy: 0.9953 - val_loss: 0.4258 - val_accuracy: 0.8933
#
# Epoch 00029: val_accuracy did not improve from 0.89556
# Epoch 30/30
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0125 - accuracy: 0.9985 - val_loss: 0.5153 - val_accuracy: 0.9111
#
# Epoch 00030: val_accuracy improved from 0.89556 to 0.91111, saving model to ./models/tree_10/model_root_f1_1_1_1_1/folder5\model.h5
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
