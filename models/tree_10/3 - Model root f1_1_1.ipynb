# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Blues':0, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Pop':7, 'Reggae':8, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Blues', 2: 'Country', 3: 'Disco', 4: 'Hip-Hop', 7: 'Pop', 8: 'Reggae', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((5600, 128, 128), (5600, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((700, 128, 128), (700, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Disco

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation='softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_10/model_root_f1_1_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_10/model_root_f1_1_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 7
n_splits = 10

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    dict_genres_list = list(dict_genres.values())
    split = [[dict_genres_list.pop(fold_no - 1)], dict_genres_list]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Blues'], ['Country', 'Disco', 'Hip-Hop', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 178/178 [==============================] - 7s 24ms/step - loss: 0.4498 - accuracy: 0.8543 - val_loss: 0.3852 - val_accuracy: 0.8556
#
# Epoch 00001: val_accuracy improved from -inf to 0.85556, saving model to ./models/tree_10/model_root_f1_1_1/folder1\model.h5
# Epoch 2/30
# 178/178 [==============================] - 4s 20ms/step - loss: 0.3538 - accuracy: 0.8594 - val_loss: 0.3044 - val_accuracy: 0.8571
#
# Epoch 00002: val_accuracy improved from 0.85556 to 0.85714, saving model to ./models/tree_10/model_root_f1_1_1/folder1\model.h5
# Epoch 3/30
# 178/178 [==============================] - 4s 20ms/step - loss: 0.2893 - accuracy: 0.8743 - val_loss: 0.3409 - val_accuracy: 0.8444
#
# Epoch 00003: val_accuracy did not improve from 0.85714
# Epoch 4/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2478 - accuracy: 0.8917 - val_loss: 0.2514 - val_accuracy: 0.8921
#
# Epoch 00004: val_accuracy improved from 0.85714 to 0.89206, saving model to ./models/tree_10/model_root_f1_1_1/folder1\model.h5
# Epoch 5/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2059 - accuracy: 0.9085 - val_loss: 0.2299 - val_accuracy: 0.9079
#
# Epoch 00005: val_accuracy improved from 0.89206 to 0.90794, saving model to ./models/tree_10/model_root_f1_1_1/folder1\model.h5
# Epoch 6/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1838 - accuracy: 0.9243 - val_loss: 0.1945 - val_accuracy: 0.9111
#
# Epoch 00006: val_accuracy improved from 0.90794 to 0.91111, saving model to ./models/tree_10/model_root_f1_1_1/folder1\model.h5
# Epoch 7/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1466 - accuracy: 0.9430 - val_loss: 0.1481 - val_accuracy: 0.9333
#
# Epoch 00007: val_accuracy improved from 0.91111 to 0.93333, saving model to ./models/tree_10/model_root_f1_1_1/folder1\model.h5
# Epoch 8/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.1061 - accuracy: 0.9575 - val_loss: 0.1560 - val_accuracy: 0.9349
#
# Epoch 00008: val_accuracy improved from 0.93333 to 0.93492, saving model to ./models/tree_10/model_root_f1_1_1/folder1\model.h5
# Epoch 9/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.0785 - accuracy: 0.9709 - val_loss: 0.2271 - val_accuracy: 0.9381
#
# Epoch 00009: val_accuracy improved from 0.93492 to 0.93810, saving model to ./models/tree_10/model_root_f1_1_1/folder1\model.h5
# Epoch 10/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.0601 - accuracy: 0.9788 - val_loss: 0.2020 - val_accuracy: 0.9286
#
# Epoch 00010: val_accuracy did not improve from 0.93810
# Epoch 11/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.0478 - accuracy: 0.9834 - val_loss: 0.1837 - val_accuracy: 0.9381
#
# Epoch 00011: val_accuracy did not improve from 0.93810
# Epoch 12/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0370 - accuracy: 0.9862 - val_loss: 0.1612 - val_accuracy: 0.9381
#
# Epoch 00012: val_accuracy did not improve from 0.93810
# Epoch 13/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0392 - accuracy: 0.9857 - val_loss: 0.1667 - val_accuracy: 0.9397
#
# Epoch 00013: val_accuracy improved from 0.93810 to 0.93968, saving model to ./models/tree_10/model_root_f1_1_1/folder1\model.h5
# Epoch 14/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0248 - accuracy: 0.9908 - val_loss: 0.1755 - val_accuracy: 0.9444
#
# Epoch 00014: val_accuracy improved from 0.93968 to 0.94444, saving model to ./models/tree_10/model_root_f1_1_1/folder1\model.h5
# Epoch 15/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0330 - accuracy: 0.9887 - val_loss: 0.1734 - val_accuracy: 0.9492
#
# Epoch 00015: val_accuracy improved from 0.94444 to 0.94921, saving model to ./models/tree_10/model_root_f1_1_1/folder1\model.h5
# Epoch 16/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0238 - accuracy: 0.9922 - val_loss: 0.2388 - val_accuracy: 0.9397
#
# Epoch 00016: val_accuracy did not improve from 0.94921
# Epoch 17/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0286 - accuracy: 0.9905 - val_loss: 0.1629 - val_accuracy: 0.9349
#
# Epoch 00017: val_accuracy did not improve from 0.94921
# Epoch 18/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0183 - accuracy: 0.9938 - val_loss: 0.1393 - val_accuracy: 0.9460
#
# Epoch 00018: val_accuracy did not improve from 0.94921
# Epoch 19/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.0146 - accuracy: 0.9940 - val_loss: 0.1592 - val_accuracy: 0.9444
#
# Epoch 00019: val_accuracy did not improve from 0.94921
# Epoch 20/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0138 - accuracy: 0.9954 - val_loss: 0.2391 - val_accuracy: 0.9429
#
# Epoch 00020: val_accuracy did not improve from 0.94921
# Epoch 21/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.0181 - accuracy: 0.9945 - val_loss: 0.1989 - val_accuracy: 0.9540
#
# Epoch 00021: val_accuracy improved from 0.94921 to 0.95397, saving model to ./models/tree_10/model_root_f1_1_1/folder1\model.h5
# Epoch 22/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0105 - accuracy: 0.9963 - val_loss: 0.2391 - val_accuracy: 0.9365
#
# Epoch 00022: val_accuracy did not improve from 0.95397
# Epoch 23/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0389 - accuracy: 0.9878 - val_loss: 0.1657 - val_accuracy: 0.9381
#
# Epoch 00023: val_accuracy did not improve from 0.95397
# Epoch 24/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0252 - accuracy: 0.9907 - val_loss: 0.2869 - val_accuracy: 0.9333
#
# Epoch 00024: val_accuracy did not improve from 0.95397
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 25/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.0039 - accuracy: 0.9986 - val_loss: 0.1900 - val_accuracy: 0.9492
#
# Epoch 00025: val_accuracy did not improve from 0.95397
# Epoch 26/30
# 178/178 [==============================] - 4s 21ms/step - loss: 2.7496e-04 - accuracy: 1.0000 - val_loss: 0.1840 - val_accuracy: 0.9508
#
# Epoch 00026: val_accuracy did not improve from 0.95397
# Epoch 27/30
# 178/178 [==============================] - 4s 22ms/step - loss: 1.5060e-04 - accuracy: 1.0000 - val_loss: 0.1859 - val_accuracy: 0.9508
#
# Epoch 00027: val_accuracy did not improve from 0.95397
# Epoch 28/30
# 178/178 [==============================] - 4s 22ms/step - loss: 1.1649e-04 - accuracy: 1.0000 - val_loss: 0.1861 - val_accuracy: 0.9524
#
# Epoch 00028: val_accuracy did not improve from 0.95397
# Epoch 29/30
# 178/178 [==============================] - 4s 20ms/step - loss: 9.6150e-05 - accuracy: 1.0000 - val_loss: 0.1870 - val_accuracy: 0.9524
#
# Epoch 00029: val_accuracy did not improve from 0.95397
# Epoch 30/30
# 178/178 [==============================] - 4s 21ms/step - loss: 8.1809e-05 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.9508
#
# Epoch 00030: val_accuracy did not improve from 0.95397
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Country'], ['Blues', 'Disco', 'Hip-Hop', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 178/178 [==============================] - 5s 23ms/step - loss: 0.3916 - accuracy: 0.8531 - val_loss: 0.3488 - val_accuracy: 0.8540
#
# Epoch 00001: val_accuracy improved from -inf to 0.85397, saving model to ./models/tree_10/model_root_f1_1_1/folder2\model.h5
# Epoch 2/30
# 178/178 [==============================] - 4s 20ms/step - loss: 0.2927 - accuracy: 0.8668 - val_loss: 0.2531 - val_accuracy: 0.8810
#
# Epoch 00002: val_accuracy improved from 0.85397 to 0.88095, saving model to ./models/tree_10/model_root_f1_1_1/folder2\model.h5
# Epoch 3/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2574 - accuracy: 0.8801 - val_loss: 0.2252 - val_accuracy: 0.8937
#
# Epoch 00003: val_accuracy improved from 0.88095 to 0.89365, saving model to ./models/tree_10/model_root_f1_1_1/folder2\model.h5
# Epoch 4/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2369 - accuracy: 0.8891 - val_loss: 0.2056 - val_accuracy: 0.8952
#
# Epoch 00004: val_accuracy improved from 0.89365 to 0.89524, saving model to ./models/tree_10/model_root_f1_1_1/folder2\model.h5
# Epoch 5/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2263 - accuracy: 0.9011 - val_loss: 0.2278 - val_accuracy: 0.8873
#
# Epoch 00005: val_accuracy did not improve from 0.89524
# Epoch 6/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2213 - accuracy: 0.9058 - val_loss: 0.1930 - val_accuracy: 0.9206
#
# Epoch 00006: val_accuracy improved from 0.89524 to 0.92063, saving model to ./models/tree_10/model_root_f1_1_1/folder2\model.h5
# Epoch 7/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1785 - accuracy: 0.9231 - val_loss: 0.2128 - val_accuracy: 0.9095
#
# Epoch 00007: val_accuracy did not improve from 0.92063
# Epoch 8/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1504 - accuracy: 0.9367 - val_loss: 0.2381 - val_accuracy: 0.8841
#
# Epoch 00008: val_accuracy did not improve from 0.92063
# Epoch 9/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1381 - accuracy: 0.9448 - val_loss: 0.1677 - val_accuracy: 0.9381
#
# Epoch 00009: val_accuracy improved from 0.92063 to 0.93810, saving model to ./models/tree_10/model_root_f1_1_1/folder2\model.h5
# Epoch 10/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1235 - accuracy: 0.9481 - val_loss: 0.1552 - val_accuracy: 0.9476
#
# Epoch 00010: val_accuracy improved from 0.93810 to 0.94762, saving model to ./models/tree_10/model_root_f1_1_1/folder2\model.h5
# Epoch 11/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0992 - accuracy: 0.9605 - val_loss: 0.1666 - val_accuracy: 0.9444
#
# Epoch 00011: val_accuracy did not improve from 0.94762
# Epoch 12/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.0875 - accuracy: 0.9658 - val_loss: 0.1651 - val_accuracy: 0.9413
#
# Epoch 00012: val_accuracy did not improve from 0.94762
# Epoch 13/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0618 - accuracy: 0.9774 - val_loss: 0.1751 - val_accuracy: 0.9429
#
# Epoch 00013: val_accuracy did not improve from 0.94762
# Epoch 14/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.0474 - accuracy: 0.9847 - val_loss: 0.1809 - val_accuracy: 0.9381
#
# Epoch 00014: val_accuracy did not improve from 0.94762
# Epoch 15/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0316 - accuracy: 0.9885 - val_loss: 0.2749 - val_accuracy: 0.9333
#
# Epoch 00015: val_accuracy did not improve from 0.94762
# Epoch 16/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0187 - accuracy: 0.9937 - val_loss: 0.2413 - val_accuracy: 0.9429
#
# Epoch 00016: val_accuracy did not improve from 0.94762
# Epoch 17/30
# 178/178 [==============================] - 4s 25ms/step - loss: 0.0356 - accuracy: 0.9862 - val_loss: 0.2749 - val_accuracy: 0.9317
#
# Epoch 00017: val_accuracy did not improve from 0.94762
# Epoch 18/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0370 - accuracy: 0.9859 - val_loss: 0.2058 - val_accuracy: 0.9286
#
# Epoch 00018: val_accuracy did not improve from 0.94762
# Epoch 19/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.0222 - accuracy: 0.9922 - val_loss: 0.2863 - val_accuracy: 0.9413
#
# Epoch 00019: val_accuracy did not improve from 0.94762
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/30
# 178/178 [==============================] - 4s 23ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.2694 - val_accuracy: 0.9381
#
# Epoch 00020: val_accuracy did not improve from 0.94762
# Epoch 21/30
# 178/178 [==============================] - 5s 27ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2867 - val_accuracy: 0.9397
#
# Epoch 00021: val_accuracy did not improve from 0.94762
# Epoch 22/30
# 178/178 [==============================] - 4s 22ms/step - loss: 4.7336e-04 - accuracy: 1.0000 - val_loss: 0.2872 - val_accuracy: 0.9413
#
# Epoch 00022: val_accuracy did not improve from 0.94762
# Epoch 23/30
# 178/178 [==============================] - 4s 23ms/step - loss: 3.3336e-04 - accuracy: 1.0000 - val_loss: 0.3001 - val_accuracy: 0.9397
#
# Epoch 00023: val_accuracy did not improve from 0.94762
# Epoch 24/30
# 178/178 [==============================] - 4s 22ms/step - loss: 2.5984e-04 - accuracy: 1.0000 - val_loss: 0.3035 - val_accuracy: 0.9413
#
# Epoch 00024: val_accuracy did not improve from 0.94762
# Epoch 25/30
# 178/178 [==============================] - 4s 20ms/step - loss: 2.1183e-04 - accuracy: 1.0000 - val_loss: 0.3123 - val_accuracy: 0.9397
#
# Epoch 00025: val_accuracy did not improve from 0.94762
# Epoch 26/30
# 178/178 [==============================] - 4s 24ms/step - loss: 1.7418e-04 - accuracy: 1.0000 - val_loss: 0.3202 - val_accuracy: 0.9413
#
# Epoch 00026: val_accuracy did not improve from 0.94762
# Epoch 27/30
# 178/178 [==============================] - 5s 29ms/step - loss: 1.4815e-04 - accuracy: 1.0000 - val_loss: 0.3230 - val_accuracy: 0.9413
#
# Epoch 00027: val_accuracy did not improve from 0.94762
# Epoch 28/30
# 178/178 [==============================] - 4s 24ms/step - loss: 1.2473e-04 - accuracy: 1.0000 - val_loss: 0.3269 - val_accuracy: 0.9413
#
# Epoch 00028: val_accuracy did not improve from 0.94762
# Epoch 29/30
# 178/178 [==============================] - 4s 24ms/step - loss: 1.0629e-04 - accuracy: 1.0000 - val_loss: 0.3324 - val_accuracy: 0.9413
#
# Epoch 00029: val_accuracy did not improve from 0.94762
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 30/30
# 178/178 [==============================] - 4s 23ms/step - loss: 9.1656e-05 - accuracy: 1.0000 - val_loss: 0.3338 - val_accuracy: 0.9413
#
# Epoch 00030: val_accuracy did not improve from 0.94762
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Disco'], ['Blues', 'Country', 'Hip-Hop', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 178/178 [==============================] - 5s 23ms/step - loss: 0.4397 - accuracy: 0.8503 - val_loss: 0.3659 - val_accuracy: 0.8746
#
# Epoch 00001: val_accuracy improved from -inf to 0.87460, saving model to ./models/tree_10/model_root_f1_1_1/folder3\model.h5
# Epoch 2/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.3935 - accuracy: 0.8552 - val_loss: 0.3342 - val_accuracy: 0.8746
#
# Epoch 00002: val_accuracy did not improve from 0.87460
# Epoch 3/30
# 178/178 [==============================] - 4s 20ms/step - loss: 0.3305 - accuracy: 0.8640 - val_loss: 0.2879 - val_accuracy: 0.8873
#
# Epoch 00003: val_accuracy improved from 0.87460 to 0.88730, saving model to ./models/tree_10/model_root_f1_1_1/folder3\model.h5
# Epoch 4/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2478 - accuracy: 0.9044 - val_loss: 0.1957 - val_accuracy: 0.9381
#
# Epoch 00004: val_accuracy improved from 0.88730 to 0.93810, saving model to ./models/tree_10/model_root_f1_1_1/folder3\model.h5
# Epoch 5/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2013 - accuracy: 0.9257 - val_loss: 0.1763 - val_accuracy: 0.9476
#
# Epoch 00005: val_accuracy improved from 0.93810 to 0.94762, saving model to ./models/tree_10/model_root_f1_1_1/folder3\model.h5
# Epoch 6/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1814 - accuracy: 0.9339 - val_loss: 0.1747 - val_accuracy: 0.9476
#
# Epoch 00006: val_accuracy did not improve from 0.94762
# Epoch 7/30
# 178/178 [==============================] - 4s 20ms/step - loss: 0.1649 - accuracy: 0.9429 - val_loss: 0.1636 - val_accuracy: 0.9492
#
# Epoch 00007: val_accuracy improved from 0.94762 to 0.94921, saving model to ./models/tree_10/model_root_f1_1_1/folder3\model.h5
# Epoch 8/30
# 178/178 [==============================] - 4s 20ms/step - loss: 0.1448 - accuracy: 0.9499 - val_loss: 0.1932 - val_accuracy: 0.9317
#
# Epoch 00008: val_accuracy did not improve from 0.94921
# Epoch 9/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1267 - accuracy: 0.9566 - val_loss: 0.1655 - val_accuracy: 0.9524
#
# Epoch 00009: val_accuracy improved from 0.94921 to 0.95238, saving model to ./models/tree_10/model_root_f1_1_1/folder3\model.h5
# Epoch 10/30
# 178/178 [==============================] - 4s 20ms/step - loss: 0.1039 - accuracy: 0.9638 - val_loss: 0.1619 - val_accuracy: 0.9397
#
# Epoch 00010: val_accuracy did not improve from 0.95238
# Epoch 11/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0879 - accuracy: 0.9721 - val_loss: 0.1714 - val_accuracy: 0.9397
#
# Epoch 00011: val_accuracy did not improve from 0.95238
# Epoch 12/30
# 178/178 [==============================] - 4s 23ms/step - loss: 0.0692 - accuracy: 0.9769 - val_loss: 0.1720 - val_accuracy: 0.9540
#
# Epoch 00012: val_accuracy improved from 0.95238 to 0.95397, saving model to ./models/tree_10/model_root_f1_1_1/folder3\model.h5
# Epoch 13/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0477 - accuracy: 0.9825 - val_loss: 0.1765 - val_accuracy: 0.9508
#
# Epoch 00013: val_accuracy did not improve from 0.95397
# Epoch 14/30
# 178/178 [==============================] - 4s 20ms/step - loss: 0.0632 - accuracy: 0.9767 - val_loss: 0.1791 - val_accuracy: 0.9508
#
# Epoch 00014: val_accuracy did not improve from 0.95397
# Epoch 15/30
# 178/178 [==============================] - 4s 20ms/step - loss: 0.0222 - accuracy: 0.9937 - val_loss: 0.2161 - val_accuracy: 0.9508
#
# Epoch 00015: val_accuracy did not improve from 0.95397
# Epoch 16/30
# 178/178 [==============================] - 4s 20ms/step - loss: 0.0235 - accuracy: 0.9910 - val_loss: 0.2040 - val_accuracy: 0.9508
#
# Epoch 00016: val_accuracy did not improve from 0.95397
# Epoch 17/30
# 178/178 [==============================] - 4s 20ms/step - loss: 0.0087 - accuracy: 0.9981 - val_loss: 0.2140 - val_accuracy: 0.9524
#
# Epoch 00017: val_accuracy did not improve from 0.95397
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 18/30
# 178/178 [==============================] - 4s 20ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2282 - val_accuracy: 0.9571
#
# Epoch 00018: val_accuracy improved from 0.95397 to 0.95714, saving model to ./models/tree_10/model_root_f1_1_1/folder3\model.h5
# Epoch 19/30
# 178/178 [==============================] - 4s 21ms/step - loss: 6.6477e-04 - accuracy: 1.0000 - val_loss: 0.2386 - val_accuracy: 0.9556
#
# Epoch 00019: val_accuracy did not improve from 0.95714
# Epoch 20/30
# 178/178 [==============================] - 4s 21ms/step - loss: 4.5085e-04 - accuracy: 1.0000 - val_loss: 0.2429 - val_accuracy: 0.9556
#
# Epoch 00020: val_accuracy did not improve from 0.95714
# Epoch 21/30
# 178/178 [==============================] - 4s 21ms/step - loss: 3.4999e-04 - accuracy: 1.0000 - val_loss: 0.2450 - val_accuracy: 0.9540
#
# Epoch 00021: val_accuracy did not improve from 0.95714
# Epoch 22/30
# 178/178 [==============================] - 4s 20ms/step - loss: 2.7880e-04 - accuracy: 1.0000 - val_loss: 0.2580 - val_accuracy: 0.9571
#
# Epoch 00022: val_accuracy did not improve from 0.95714
# Epoch 23/30
# 178/178 [==============================] - 4s 21ms/step - loss: 2.3309e-04 - accuracy: 1.0000 - val_loss: 0.2557 - val_accuracy: 0.9540
#
# Epoch 00023: val_accuracy did not improve from 0.95714
# Epoch 24/30
# 178/178 [==============================] - 4s 20ms/step - loss: 1.9435e-04 - accuracy: 1.0000 - val_loss: 0.2636 - val_accuracy: 0.9556
#
# Epoch 00024: val_accuracy did not improve from 0.95714
# Epoch 25/30
# 178/178 [==============================] - 4s 21ms/step - loss: 1.6504e-04 - accuracy: 1.0000 - val_loss: 0.2626 - val_accuracy: 0.9540
#
# Epoch 00025: val_accuracy did not improve from 0.95714
# Epoch 26/30
# 178/178 [==============================] - 4s 21ms/step - loss: 1.4137e-04 - accuracy: 1.0000 - val_loss: 0.2677 - val_accuracy: 0.9556
#
# Epoch 00026: val_accuracy did not improve from 0.95714
# Epoch 27/30
# 178/178 [==============================] - 4s 21ms/step - loss: 1.2303e-04 - accuracy: 1.0000 - val_loss: 0.2701 - val_accuracy: 0.9556
#
# Epoch 00027: val_accuracy did not improve from 0.95714
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 28/30
# 178/178 [==============================] - 4s 21ms/step - loss: 1.0691e-04 - accuracy: 1.0000 - val_loss: 0.2771 - val_accuracy: 0.9556
#
# Epoch 00028: val_accuracy did not improve from 0.95714
# Epoch 29/30
# 178/178 [==============================] - 4s 21ms/step - loss: 1.0149e-04 - accuracy: 1.0000 - val_loss: 0.2779 - val_accuracy: 0.9556
#
# Epoch 00029: val_accuracy did not improve from 0.95714
# Epoch 30/30
# 178/178 [==============================] - 4s 21ms/step - loss: 9.2576e-05 - accuracy: 1.0000 - val_loss: 0.2767 - val_accuracy: 0.9571
#
# Epoch 00030: val_accuracy did not improve from 0.95714
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Hip-Hop'], ['Blues', 'Country', 'Disco', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.4028 - accuracy: 0.8526 - val_loss: 0.4276 - val_accuracy: 0.8429
#
# Epoch 00001: val_accuracy improved from -inf to 0.84286, saving model to ./models/tree_10/model_root_f1_1_1/folder4\model.h5
# Epoch 2/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2889 - accuracy: 0.8674 - val_loss: 0.3451 - val_accuracy: 0.8635
#
# Epoch 00002: val_accuracy improved from 0.84286 to 0.86349, saving model to ./models/tree_10/model_root_f1_1_1/folder4\model.h5
# Epoch 3/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2252 - accuracy: 0.9007 - val_loss: 0.2777 - val_accuracy: 0.8778
#
# Epoch 00003: val_accuracy improved from 0.86349 to 0.87778, saving model to ./models/tree_10/model_root_f1_1_1/folder4\model.h5
# Epoch 4/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2049 - accuracy: 0.9108 - val_loss: 0.2366 - val_accuracy: 0.9032
#
# Epoch 00004: val_accuracy improved from 0.87778 to 0.90317, saving model to ./models/tree_10/model_root_f1_1_1/folder4\model.h5
# Epoch 5/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.1790 - accuracy: 0.9256 - val_loss: 0.2335 - val_accuracy: 0.9063
#
# Epoch 00005: val_accuracy improved from 0.90317 to 0.90635, saving model to ./models/tree_10/model_root_f1_1_1/folder4\model.h5
# Epoch 6/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1269 - accuracy: 0.9492 - val_loss: 0.1970 - val_accuracy: 0.9206
#
# Epoch 00006: val_accuracy improved from 0.90635 to 0.92063, saving model to ./models/tree_10/model_root_f1_1_1/folder4\model.h5
# Epoch 7/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1121 - accuracy: 0.9559 - val_loss: 0.2255 - val_accuracy: 0.9063
#
# Epoch 00007: val_accuracy did not improve from 0.92063
# Epoch 8/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0641 - accuracy: 0.9774 - val_loss: 0.2126 - val_accuracy: 0.9349
#
# Epoch 00008: val_accuracy improved from 0.92063 to 0.93492, saving model to ./models/tree_10/model_root_f1_1_1/folder4\model.h5
# Epoch 9/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0599 - accuracy: 0.9787 - val_loss: 0.2001 - val_accuracy: 0.9381
#
# Epoch 00009: val_accuracy improved from 0.93492 to 0.93810, saving model to ./models/tree_10/model_root_f1_1_1/folder4\model.h5
# Epoch 10/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0185 - accuracy: 0.9933 - val_loss: 0.2531 - val_accuracy: 0.9302
#
# Epoch 00010: val_accuracy did not improve from 0.93810
# Epoch 11/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0287 - accuracy: 0.9898 - val_loss: 0.3418 - val_accuracy: 0.9190
#
# Epoch 00011: val_accuracy did not improve from 0.93810
# Epoch 12/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0245 - accuracy: 0.9901 - val_loss: 0.2943 - val_accuracy: 0.9238
#
# Epoch 00012: val_accuracy did not improve from 0.93810
# Epoch 13/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3507 - val_accuracy: 0.9413
#
# Epoch 00013: val_accuracy improved from 0.93810 to 0.94127, saving model to ./models/tree_10/model_root_f1_1_1/folder4\model.h5
# Epoch 14/30
# 178/178 [==============================] - 4s 21ms/step - loss: 5.2004e-04 - accuracy: 1.0000 - val_loss: 0.3280 - val_accuracy: 0.9413
#
# Epoch 00014: val_accuracy did not improve from 0.94127
# Epoch 15/30
# 178/178 [==============================] - 4s 21ms/step - loss: 2.7326e-04 - accuracy: 1.0000 - val_loss: 0.3549 - val_accuracy: 0.9397
#
# Epoch 00015: val_accuracy did not improve from 0.94127
# Epoch 16/30
# 178/178 [==============================] - 4s 21ms/step - loss: 1.5785e-04 - accuracy: 1.0000 - val_loss: 0.3506 - val_accuracy: 0.9381
#
# Epoch 00016: val_accuracy did not improve from 0.94127
# Epoch 17/30
# 178/178 [==============================] - 4s 21ms/step - loss: 1.1916e-04 - accuracy: 1.0000 - val_loss: 0.3727 - val_accuracy: 0.9397
#
# Epoch 00017: val_accuracy did not improve from 0.94127
# Epoch 18/30
# 178/178 [==============================] - 4s 22ms/step - loss: 9.2877e-05 - accuracy: 1.0000 - val_loss: 0.3858 - val_accuracy: 0.9397
#
# Epoch 00018: val_accuracy did not improve from 0.94127
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 19/30
# 178/178 [==============================] - 4s 22ms/step - loss: 7.6321e-05 - accuracy: 1.0000 - val_loss: 0.3872 - val_accuracy: 0.9397
#
# Epoch 00019: val_accuracy did not improve from 0.94127
# Epoch 20/30
# 178/178 [==============================] - 4s 22ms/step - loss: 6.8836e-05 - accuracy: 1.0000 - val_loss: 0.3937 - val_accuracy: 0.9397
#
# Epoch 00020: val_accuracy did not improve from 0.94127
# Epoch 21/30
# 178/178 [==============================] - 4s 22ms/step - loss: 6.2363e-05 - accuracy: 1.0000 - val_loss: 0.3995 - val_accuracy: 0.9397
#
# Epoch 00021: val_accuracy did not improve from 0.94127
# Epoch 22/30
# 178/178 [==============================] - 4s 21ms/step - loss: 5.6982e-05 - accuracy: 1.0000 - val_loss: 0.4034 - val_accuracy: 0.9397
#
# Epoch 00022: val_accuracy did not improve from 0.94127
# Epoch 23/30
# 178/178 [==============================] - 4s 22ms/step - loss: 5.1294e-05 - accuracy: 1.0000 - val_loss: 0.4080 - val_accuracy: 0.9397
#
# Epoch 00023: val_accuracy did not improve from 0.94127
# Epoch 24/30
# 178/178 [==============================] - 4s 22ms/step - loss: 4.6522e-05 - accuracy: 1.0000 - val_loss: 0.4136 - val_accuracy: 0.9381
#
# Epoch 00024: val_accuracy did not improve from 0.94127
# Epoch 25/30
# 178/178 [==============================] - 4s 21ms/step - loss: 4.1913e-05 - accuracy: 1.0000 - val_loss: 0.4166 - val_accuracy: 0.9381
#
# Epoch 00025: val_accuracy did not improve from 0.94127
# Epoch 26/30
# 178/178 [==============================] - 4s 21ms/step - loss: 3.7918e-05 - accuracy: 1.0000 - val_loss: 0.4171 - val_accuracy: 0.9381
#
# Epoch 00026: val_accuracy did not improve from 0.94127
# Epoch 27/30
# 178/178 [==============================] - 4s 21ms/step - loss: 3.4534e-05 - accuracy: 1.0000 - val_loss: 0.4200 - val_accuracy: 0.9397
#
# Epoch 00027: val_accuracy did not improve from 0.94127
# Epoch 28/30
# 178/178 [==============================] - 4s 21ms/step - loss: 3.0644e-05 - accuracy: 1.0000 - val_loss: 0.4319 - val_accuracy: 0.9381
#
# Epoch 00028: val_accuracy did not improve from 0.94127
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 29/30
# 178/178 [==============================] - 4s 21ms/step - loss: 2.7770e-05 - accuracy: 1.0000 - val_loss: 0.4330 - val_accuracy: 0.9381
#
# Epoch 00029: val_accuracy did not improve from 0.94127
# Epoch 30/30
# 178/178 [==============================] - 4s 21ms/step - loss: 2.6242e-05 - accuracy: 1.0000 - val_loss: 0.4306 - val_accuracy: 0.9397
#
# Epoch 00030: val_accuracy did not improve from 0.94127
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 5
# Genre split [['Pop'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.4193 - accuracy: 0.8557 - val_loss: 0.2727 - val_accuracy: 0.8429
#
# Epoch 00001: val_accuracy improved from -inf to 0.84286, saving model to ./models/tree_10/model_root_f1_1_1/folder5\model.h5
# Epoch 2/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2363 - accuracy: 0.8949 - val_loss: 0.2531 - val_accuracy: 0.8508
#
# Epoch 00002: val_accuracy improved from 0.84286 to 0.85079, saving model to ./models/tree_10/model_root_f1_1_1/folder5\model.h5
# Epoch 3/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2024 - accuracy: 0.9157 - val_loss: 0.2153 - val_accuracy: 0.9048
#
# Epoch 00003: val_accuracy improved from 0.85079 to 0.90476, saving model to ./models/tree_10/model_root_f1_1_1/folder5\model.h5
# Epoch 4/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1872 - accuracy: 0.9236 - val_loss: 0.2112 - val_accuracy: 0.9159
#
# Epoch 00004: val_accuracy improved from 0.90476 to 0.91587, saving model to ./models/tree_10/model_root_f1_1_1/folder5\model.h5
# Epoch 5/30
# 178/178 [==============================] - 4s 20ms/step - loss: 0.1754 - accuracy: 0.9335 - val_loss: 0.2281 - val_accuracy: 0.9127
#
# Epoch 00005: val_accuracy did not improve from 0.91587
# Epoch 6/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1686 - accuracy: 0.9372 - val_loss: 0.1763 - val_accuracy: 0.9349
#
# Epoch 00006: val_accuracy improved from 0.91587 to 0.93492, saving model to ./models/tree_10/model_root_f1_1_1/folder5\model.h5
# Epoch 7/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.1691 - accuracy: 0.9347 - val_loss: 0.1623 - val_accuracy: 0.9333
#
# Epoch 00007: val_accuracy did not improve from 0.93492
# Epoch 8/30
# 178/178 [==============================] - 4s 20ms/step - loss: 0.1598 - accuracy: 0.9393 - val_loss: 0.1693 - val_accuracy: 0.9317
#
# Epoch 00008: val_accuracy did not improve from 0.93492
# Epoch 9/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1522 - accuracy: 0.9414 - val_loss: 0.2389 - val_accuracy: 0.9111
#
# Epoch 00009: val_accuracy did not improve from 0.93492
# Epoch 10/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1499 - accuracy: 0.9430 - val_loss: 0.1669 - val_accuracy: 0.9365
#
# Epoch 00010: val_accuracy improved from 0.93492 to 0.93651, saving model to ./models/tree_10/model_root_f1_1_1/folder5\model.h5
# Epoch 11/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1421 - accuracy: 0.9437 - val_loss: 0.1575 - val_accuracy: 0.9413
#
# Epoch 00011: val_accuracy improved from 0.93651 to 0.94127, saving model to ./models/tree_10/model_root_f1_1_1/folder5\model.h5
# Epoch 12/30
# 178/178 [==============================] - 4s 20ms/step - loss: 0.1347 - accuracy: 0.9474 - val_loss: 0.1542 - val_accuracy: 0.9333
#
# Epoch 00012: val_accuracy did not improve from 0.94127
# Epoch 13/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.1293 - accuracy: 0.9506 - val_loss: 0.1594 - val_accuracy: 0.9381
#
# Epoch 00013: val_accuracy did not improve from 0.94127
# Epoch 14/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1230 - accuracy: 0.9529 - val_loss: 0.1620 - val_accuracy: 0.9349
#
# Epoch 00014: val_accuracy did not improve from 0.94127
# Epoch 15/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1137 - accuracy: 0.9568 - val_loss: 0.1577 - val_accuracy: 0.9429
#
# Epoch 00015: val_accuracy improved from 0.94127 to 0.94286, saving model to ./models/tree_10/model_root_f1_1_1/folder5\model.h5
# Epoch 16/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1168 - accuracy: 0.9534 - val_loss: 0.1666 - val_accuracy: 0.9413
#
# Epoch 00016: val_accuracy did not improve from 0.94286
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 17/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0927 - accuracy: 0.9663 - val_loss: 0.1789 - val_accuracy: 0.9365
#
# Epoch 00017: val_accuracy did not improve from 0.94286
# Epoch 18/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0875 - accuracy: 0.9681 - val_loss: 0.1693 - val_accuracy: 0.9492
#
# Epoch 00018: val_accuracy improved from 0.94286 to 0.94921, saving model to ./models/tree_10/model_root_f1_1_1/folder5\model.h5
# Epoch 19/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0855 - accuracy: 0.9679 - val_loss: 0.1645 - val_accuracy: 0.9492
#
# Epoch 00019: val_accuracy did not improve from 0.94921
# Epoch 20/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.0778 - accuracy: 0.9716 - val_loss: 0.1725 - val_accuracy: 0.9460
#
# Epoch 00020: val_accuracy did not improve from 0.94921
# Epoch 21/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0720 - accuracy: 0.9739 - val_loss: 0.1718 - val_accuracy: 0.9460
#
# Epoch 00021: val_accuracy did not improve from 0.94921
# Epoch 22/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0694 - accuracy: 0.9737 - val_loss: 0.1813 - val_accuracy: 0.9413
#
# Epoch 00022: val_accuracy did not improve from 0.94921
# Epoch 23/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.0628 - accuracy: 0.9772 - val_loss: 0.1844 - val_accuracy: 0.9492
#
# Epoch 00023: val_accuracy did not improve from 0.94921
# Epoch 24/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0528 - accuracy: 0.9801 - val_loss: 0.1819 - val_accuracy: 0.9476
#
# Epoch 00024: val_accuracy did not improve from 0.94921
# Epoch 25/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0470 - accuracy: 0.9838 - val_loss: 0.1895 - val_accuracy: 0.9444
#
# Epoch 00025: val_accuracy did not improve from 0.94921
# Epoch 26/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0402 - accuracy: 0.9875 - val_loss: 0.2176 - val_accuracy: 0.9540
#
# Epoch 00026: val_accuracy improved from 0.94921 to 0.95397, saving model to ./models/tree_10/model_root_f1_1_1/folder5\model.h5
# Epoch 27/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0347 - accuracy: 0.9880 - val_loss: 0.2138 - val_accuracy: 0.9429
#
# Epoch 00027: val_accuracy did not improve from 0.95397
# Epoch 28/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0312 - accuracy: 0.9898 - val_loss: 0.2172 - val_accuracy: 0.9492
#
# Epoch 00028: val_accuracy did not improve from 0.95397
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 29/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0179 - accuracy: 0.9968 - val_loss: 0.2237 - val_accuracy: 0.9492
#
# Epoch 00029: val_accuracy did not improve from 0.95397
# Epoch 30/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0148 - accuracy: 0.9975 - val_loss: 0.2341 - val_accuracy: 0.9540
#
# Epoch 00030: val_accuracy did not improve from 0.95397
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 6
# Genre split [['Reggae'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Pop', 'Rock']]
# Building model...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.4588 - accuracy: 0.8519 - val_loss: 0.4009 - val_accuracy: 0.8635
#
# Epoch 00001: val_accuracy improved from -inf to 0.86349, saving model to ./models/tree_10/model_root_f1_1_1/folder6\model.h5
# Epoch 2/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.3979 - accuracy: 0.8564 - val_loss: 0.3554 - val_accuracy: 0.8635
#
# Epoch 00002: val_accuracy did not improve from 0.86349
# Epoch 3/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.3749 - accuracy: 0.8559 - val_loss: 0.3428 - val_accuracy: 0.8651
#
# Epoch 00003: val_accuracy improved from 0.86349 to 0.86508, saving model to ./models/tree_10/model_root_f1_1_1/folder6\model.h5
# Epoch 4/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.3428 - accuracy: 0.8684 - val_loss: 0.3240 - val_accuracy: 0.8746
#
# Epoch 00004: val_accuracy improved from 0.86508 to 0.87460, saving model to ./models/tree_10/model_root_f1_1_1/folder6\model.h5
# Epoch 5/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.3025 - accuracy: 0.8864 - val_loss: 0.2945 - val_accuracy: 0.8952
#
# Epoch 00005: val_accuracy improved from 0.87460 to 0.89524, saving model to ./models/tree_10/model_root_f1_1_1/folder6\model.h5
# Epoch 6/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2675 - accuracy: 0.8995 - val_loss: 0.2735 - val_accuracy: 0.9095
#
# Epoch 00006: val_accuracy improved from 0.89524 to 0.90952, saving model to ./models/tree_10/model_root_f1_1_1/folder6\model.h5
# Epoch 7/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2285 - accuracy: 0.9173 - val_loss: 0.3349 - val_accuracy: 0.8905
#
# Epoch 00007: val_accuracy did not improve from 0.90952
# Epoch 8/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2039 - accuracy: 0.9250 - val_loss: 0.2190 - val_accuracy: 0.9349
#
# Epoch 00008: val_accuracy improved from 0.90952 to 0.93492, saving model to ./models/tree_10/model_root_f1_1_1/folder6\model.h5
# Epoch 9/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1542 - accuracy: 0.9422 - val_loss: 0.2162 - val_accuracy: 0.9317
#
# Epoch 00009: val_accuracy did not improve from 0.93492
# Epoch 10/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1053 - accuracy: 0.9614 - val_loss: 0.2182 - val_accuracy: 0.9302
#
# Epoch 00010: val_accuracy did not improve from 0.93492
# Epoch 11/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.0753 - accuracy: 0.9746 - val_loss: 0.2122 - val_accuracy: 0.9317
#
# Epoch 00011: val_accuracy did not improve from 0.93492
# Epoch 12/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.0429 - accuracy: 0.9857 - val_loss: 0.2507 - val_accuracy: 0.9365
#
# Epoch 00012: val_accuracy improved from 0.93492 to 0.93651, saving model to ./models/tree_10/model_root_f1_1_1/folder6\model.h5
# Epoch 13/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.0250 - accuracy: 0.9922 - val_loss: 0.3322 - val_accuracy: 0.8968
#
# Epoch 00013: val_accuracy did not improve from 0.93651
# Epoch 14/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0153 - accuracy: 0.9958 - val_loss: 0.3230 - val_accuracy: 0.9429
#
# Epoch 00014: val_accuracy improved from 0.93651 to 0.94286, saving model to ./models/tree_10/model_root_f1_1_1/folder6\model.h5
# Epoch 15/30
# 178/178 [==============================] - 4s 23ms/step - loss: 0.0172 - accuracy: 0.9940 - val_loss: 0.4230 - val_accuracy: 0.9349
#
# Epoch 00015: val_accuracy did not improve from 0.94286
# Epoch 16/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0264 - accuracy: 0.9922 - val_loss: 0.2563 - val_accuracy: 0.9444
#
# Epoch 00016: val_accuracy improved from 0.94286 to 0.94444, saving model to ./models/tree_10/model_root_f1_1_1/folder6\model.h5
# Epoch 17/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0041 - accuracy: 0.9991 - val_loss: 0.2895 - val_accuracy: 0.9381
#
# Epoch 00017: val_accuracy did not improve from 0.94444
# Epoch 18/30
# 178/178 [==============================] - 4s 21ms/step - loss: 5.7835e-04 - accuracy: 1.0000 - val_loss: 0.3310 - val_accuracy: 0.9460
#
# Epoch 00018: val_accuracy improved from 0.94444 to 0.94603, saving model to ./models/tree_10/model_root_f1_1_1/folder6\model.h5
# Epoch 19/30
# 178/178 [==============================] - 4s 21ms/step - loss: 2.7900e-04 - accuracy: 1.0000 - val_loss: 0.3420 - val_accuracy: 0.9460
#
# Epoch 00019: val_accuracy did not improve from 0.94603
# Epoch 20/30
# 178/178 [==============================] - 4s 21ms/step - loss: 1.8864e-04 - accuracy: 1.0000 - val_loss: 0.3532 - val_accuracy: 0.9460
#
# Epoch 00020: val_accuracy did not improve from 0.94603
# Epoch 21/30
# 178/178 [==============================] - 4s 21ms/step - loss: 1.4613e-04 - accuracy: 1.0000 - val_loss: 0.3573 - val_accuracy: 0.9460
#
# Epoch 00021: val_accuracy did not improve from 0.94603
# Epoch 22/30
# 178/178 [==============================] - 4s 21ms/step - loss: 1.1710e-04 - accuracy: 1.0000 - val_loss: 0.3768 - val_accuracy: 0.9444
#
# Epoch 00022: val_accuracy did not improve from 0.94603
# Epoch 23/30
# 178/178 [==============================] - 4s 22ms/step - loss: 9.6241e-05 - accuracy: 1.0000 - val_loss: 0.3725 - val_accuracy: 0.9460
#
# Epoch 00023: val_accuracy did not improve from 0.94603
# Epoch 24/30
# 178/178 [==============================] - 4s 21ms/step - loss: 8.0676e-05 - accuracy: 1.0000 - val_loss: 0.3806 - val_accuracy: 0.9444
#
# Epoch 00024: val_accuracy did not improve from 0.94603
# Epoch 25/30
# 178/178 [==============================] - 4s 21ms/step - loss: 6.8355e-05 - accuracy: 1.0000 - val_loss: 0.3877 - val_accuracy: 0.9444
#
# Epoch 00025: val_accuracy did not improve from 0.94603
# Epoch 26/30
# 178/178 [==============================] - 4s 21ms/step - loss: 5.8355e-05 - accuracy: 1.0000 - val_loss: 0.3984 - val_accuracy: 0.9460
#
# Epoch 00026: val_accuracy did not improve from 0.94603
# Epoch 27/30
# 178/178 [==============================] - 4s 21ms/step - loss: 5.0526e-05 - accuracy: 1.0000 - val_loss: 0.4014 - val_accuracy: 0.9460
#
# Epoch 00027: val_accuracy did not improve from 0.94603
# Epoch 28/30
# 178/178 [==============================] - 4s 21ms/step - loss: 4.3536e-05 - accuracy: 1.0000 - val_loss: 0.4134 - val_accuracy: 0.9444
#
# Epoch 00028: val_accuracy did not improve from 0.94603
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 29/30
# 178/178 [==============================] - 4s 21ms/step - loss: 3.9005e-05 - accuracy: 1.0000 - val_loss: 0.4076 - val_accuracy: 0.9476
#
# Epoch 00029: val_accuracy improved from 0.94603 to 0.94762, saving model to ./models/tree_10/model_root_f1_1_1/folder6\model.h5
# Epoch 30/30
# 178/178 [==============================] - 4s 21ms/step - loss: 3.6007e-05 - accuracy: 1.0000 - val_loss: 0.4135 - val_accuracy: 0.9460
#
# Epoch 00030: val_accuracy did not improve from 0.94762
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 7
# Genre split [['Rock'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Pop', 'Reggae']]
# Building model...
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.4331 - accuracy: 0.8534 - val_loss: 0.3676 - val_accuracy: 0.8603
#
# Epoch 00001: val_accuracy improved from -inf to 0.86032, saving model to ./models/tree_10/model_root_f1_1_1/folder7\model.h5
# Epoch 2/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.3823 - accuracy: 0.8570 - val_loss: 0.3746 - val_accuracy: 0.8746
#
# Epoch 00002: val_accuracy improved from 0.86032 to 0.87460, saving model to ./models/tree_10/model_root_f1_1_1/folder7\model.h5
# Epoch 3/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.3678 - accuracy: 0.8610 - val_loss: 0.3274 - val_accuracy: 0.8619
#
# Epoch 00003: val_accuracy did not improve from 0.87460
# Epoch 4/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.3336 - accuracy: 0.8693 - val_loss: 0.3269 - val_accuracy: 0.8810
#
# Epoch 00004: val_accuracy improved from 0.87460 to 0.88095, saving model to ./models/tree_10/model_root_f1_1_1/folder7\model.h5
# Epoch 5/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.3132 - accuracy: 0.8771 - val_loss: 0.2903 - val_accuracy: 0.8810
#
# Epoch 00005: val_accuracy did not improve from 0.88095
# Epoch 6/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.3032 - accuracy: 0.8795 - val_loss: 0.2938 - val_accuracy: 0.8762
#
# Epoch 00006: val_accuracy did not improve from 0.88095
# Epoch 7/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2856 - accuracy: 0.8841 - val_loss: 0.2754 - val_accuracy: 0.8810
#
# Epoch 00007: val_accuracy did not improve from 0.88095
# Epoch 8/30
# 178/178 [==============================] - 4s 22ms/step - loss: 0.2681 - accuracy: 0.8877 - val_loss: 0.2752 - val_accuracy: 0.8825
#
# Epoch 00008: val_accuracy improved from 0.88095 to 0.88254, saving model to ./models/tree_10/model_root_f1_1_1/folder7\model.h5
# Epoch 9/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2501 - accuracy: 0.8942 - val_loss: 0.2268 - val_accuracy: 0.9063
#
# Epoch 00009: val_accuracy improved from 0.88254 to 0.90635, saving model to ./models/tree_10/model_root_f1_1_1/folder7\model.h5
# Epoch 10/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2347 - accuracy: 0.9030 - val_loss: 0.2341 - val_accuracy: 0.9000
#
# Epoch 00010: val_accuracy did not improve from 0.90635
# Epoch 11/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.2063 - accuracy: 0.9148 - val_loss: 0.2491 - val_accuracy: 0.9127
#
# Epoch 00011: val_accuracy improved from 0.90635 to 0.91270, saving model to ./models/tree_10/model_root_f1_1_1/folder7\model.h5
# Epoch 12/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1920 - accuracy: 0.9213 - val_loss: 0.2341 - val_accuracy: 0.8984
#
# Epoch 00012: val_accuracy did not improve from 0.91270
# Epoch 13/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1633 - accuracy: 0.9335 - val_loss: 0.2526 - val_accuracy: 0.9032
#
# Epoch 00013: val_accuracy did not improve from 0.91270
# Epoch 14/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1416 - accuracy: 0.9451 - val_loss: 0.2483 - val_accuracy: 0.9143
#
# Epoch 00014: val_accuracy improved from 0.91270 to 0.91429, saving model to ./models/tree_10/model_root_f1_1_1/folder7\model.h5
# Epoch 15/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.1019 - accuracy: 0.9624 - val_loss: 0.3339 - val_accuracy: 0.9048
#
# Epoch 00015: val_accuracy did not improve from 0.91429
# Epoch 16/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0779 - accuracy: 0.9707 - val_loss: 0.3252 - val_accuracy: 0.8857
#
# Epoch 00016: val_accuracy did not improve from 0.91429
# Epoch 17/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0697 - accuracy: 0.9746 - val_loss: 0.2992 - val_accuracy: 0.8952
#
# Epoch 00017: val_accuracy did not improve from 0.91429
# Epoch 18/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0515 - accuracy: 0.9795 - val_loss: 0.2995 - val_accuracy: 0.9206
#
# Epoch 00018: val_accuracy improved from 0.91429 to 0.92063, saving model to ./models/tree_10/model_root_f1_1_1/folder7\model.h5
# Epoch 19/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0258 - accuracy: 0.9928 - val_loss: 0.3929 - val_accuracy: 0.8984
#
# Epoch 00019: val_accuracy did not improve from 0.92063
# Epoch 20/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0087 - accuracy: 0.9984 - val_loss: 0.4777 - val_accuracy: 0.8651
#
# Epoch 00020: val_accuracy did not improve from 0.92063
# Epoch 21/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0092 - accuracy: 0.9979 - val_loss: 0.4409 - val_accuracy: 0.8984
#
# Epoch 00021: val_accuracy did not improve from 0.92063
# Epoch 22/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0363 - accuracy: 0.9896 - val_loss: 0.7402 - val_accuracy: 0.8857
#
# Epoch 00022: val_accuracy did not improve from 0.92063
# Epoch 23/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0561 - accuracy: 0.9783 - val_loss: 0.4842 - val_accuracy: 0.9000
#
# Epoch 00023: val_accuracy did not improve from 0.92063
# Epoch 24/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0070 - accuracy: 0.9991 - val_loss: 0.4584 - val_accuracy: 0.9032
#
# Epoch 00024: val_accuracy did not improve from 0.92063
# Epoch 25/30
# 178/178 [==============================] - 4s 21ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 0.4625 - val_accuracy: 0.9032
#
# Epoch 00025: val_accuracy did not improve from 0.92063
# Epoch 26/30
# 178/178 [==============================] - 4s 21ms/step - loss: 7.1789e-04 - accuracy: 1.0000 - val_loss: 0.5275 - val_accuracy: 0.9016
#
# Epoch 00026: val_accuracy did not improve from 0.92063
# Epoch 27/30
# 178/178 [==============================] - 4s 21ms/step - loss: 3.5946e-04 - accuracy: 1.0000 - val_loss: 0.5459 - val_accuracy: 0.9032
#
# Epoch 00027: val_accuracy did not improve from 0.92063
# Epoch 28/30
# 178/178 [==============================] - 4s 22ms/step - loss: 2.3786e-04 - accuracy: 1.0000 - val_loss: 0.5722 - val_accuracy: 0.9048
#
# Epoch 00028: val_accuracy did not improve from 0.92063
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 29/30
# 178/178 [==============================] - 4s 21ms/step - loss: 1.8404e-04 - accuracy: 1.0000 - val_loss: 0.5722 - val_accuracy: 0.9063
#
# Epoch 00029: val_accuracy did not improve from 0.92063
# Epoch 30/30
# 178/178 [==============================] - 4s 22ms/step - loss: 1.6171e-04 - accuracy: 1.0000 - val_loss: 0.5787 - val_accuracy: 0.9063
#
# Epoch 00030: val_accuracy did not improve from 0.92063
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
