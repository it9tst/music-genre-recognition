# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Country':2, 'Pop':7, 'Reggae':8, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {2: 'Country', 7: 'Pop', 8: 'Reggae', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((3200, 128, 128), (3200, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((400, 128, 128), (400, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Country

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation='softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_10/model_root_f1_1_1_1_1_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_10/model_root_f1_1_1_1_1_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 4
n_splits = 10

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    dict_genres_list = list(dict_genres.values())
    split = [[dict_genres_list.pop(fold_no - 1)], dict_genres_list]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Country'], ['Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 102/102 [==============================] - 6s 25ms/step - loss: 0.6068 - accuracy: 0.7352 - val_loss: 0.4576 - val_accuracy: 0.7528
#
# Epoch 00001: val_accuracy improved from -inf to 0.75278, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder1\model.h5
# Epoch 2/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.4456 - accuracy: 0.7722 - val_loss: 0.4146 - val_accuracy: 0.7778
#
# Epoch 00002: val_accuracy improved from 0.75278 to 0.77778, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder1\model.h5
# Epoch 3/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.3943 - accuracy: 0.8034 - val_loss: 0.3891 - val_accuracy: 0.7972
#
# Epoch 00003: val_accuracy improved from 0.77778 to 0.79722, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder1\model.h5
# Epoch 4/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.3579 - accuracy: 0.8185 - val_loss: 0.3698 - val_accuracy: 0.8139
#
# Epoch 00004: val_accuracy improved from 0.79722 to 0.81389, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder1\model.h5
# Epoch 5/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.3139 - accuracy: 0.8463 - val_loss: 0.3101 - val_accuracy: 0.8389
#
# Epoch 00005: val_accuracy improved from 0.81389 to 0.83889, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder1\model.h5
# Epoch 6/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.2771 - accuracy: 0.8799 - val_loss: 0.3066 - val_accuracy: 0.8528
#
# Epoch 00006: val_accuracy improved from 0.83889 to 0.85278, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder1\model.h5
# Epoch 7/30
# 102/102 [==============================] - 2s 24ms/step - loss: 0.2376 - accuracy: 0.8985 - val_loss: 0.3059 - val_accuracy: 0.8639
#
# Epoch 00007: val_accuracy improved from 0.85278 to 0.86389, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder1\model.h5
# Epoch 8/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.2187 - accuracy: 0.9059 - val_loss: 0.2885 - val_accuracy: 0.8639
#
# Epoch 00008: val_accuracy did not improve from 0.86389
# Epoch 9/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.1835 - accuracy: 0.9244 - val_loss: 0.2719 - val_accuracy: 0.8889
#
# Epoch 00009: val_accuracy improved from 0.86389 to 0.88889, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder1\model.h5
# Epoch 10/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.1585 - accuracy: 0.9380 - val_loss: 0.3073 - val_accuracy: 0.8611
#
# Epoch 00010: val_accuracy did not improve from 0.88889
# Epoch 11/30
# 102/102 [==============================] - 4s 37ms/step - loss: 0.1138 - accuracy: 0.9583 - val_loss: 0.2568 - val_accuracy: 0.8833
#
# Epoch 00011: val_accuracy did not improve from 0.88889
# Epoch 12/30
# 102/102 [==============================] - 2s 22ms/step - loss: 0.0874 - accuracy: 0.9667 - val_loss: 0.3430 - val_accuracy: 0.8917
#
# Epoch 00012: val_accuracy improved from 0.88889 to 0.89167, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder1\model.h5
# Epoch 13/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.0563 - accuracy: 0.9802 - val_loss: 0.4206 - val_accuracy: 0.8806
#
# Epoch 00013: val_accuracy did not improve from 0.89167
# Epoch 14/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.0393 - accuracy: 0.9880 - val_loss: 0.3959 - val_accuracy: 0.8833
#
# Epoch 00014: val_accuracy did not improve from 0.89167
# Epoch 15/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.0232 - accuracy: 0.9941 - val_loss: 0.3545 - val_accuracy: 0.8917
#
# Epoch 00015: val_accuracy did not improve from 0.89167
# Epoch 16/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.4982 - val_accuracy: 0.8722
#
# Epoch 00016: val_accuracy did not improve from 0.89167
# Epoch 17/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.0033 - accuracy: 0.9997 - val_loss: 0.4236 - val_accuracy: 0.9028
#
# Epoch 00017: val_accuracy improved from 0.89167 to 0.90278, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder1\model.h5
# Epoch 18/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.0055 - accuracy: 0.9981 - val_loss: 0.4728 - val_accuracy: 0.9028
#
# Epoch 00018: val_accuracy did not improve from 0.90278
# Epoch 19/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.0844 - accuracy: 0.9691 - val_loss: 0.3848 - val_accuracy: 0.8583
#
# Epoch 00019: val_accuracy did not improve from 0.90278
# Epoch 20/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.0563 - accuracy: 0.9778 - val_loss: 0.4705 - val_accuracy: 0.8722
#
# Epoch 00020: val_accuracy did not improve from 0.90278
# Epoch 21/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.0268 - accuracy: 0.9920 - val_loss: 0.3568 - val_accuracy: 0.8972
#
# Epoch 00021: val_accuracy did not improve from 0.90278
# Epoch 22/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.0124 - accuracy: 0.9954 - val_loss: 0.3838 - val_accuracy: 0.9028
#
# Epoch 00022: val_accuracy did not improve from 0.90278
# Epoch 23/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.4285 - val_accuracy: 0.8972
#
# Epoch 00023: val_accuracy did not improve from 0.90278
# Epoch 24/30
# 102/102 [==============================] - 2s 20ms/step - loss: 5.7377e-04 - accuracy: 1.0000 - val_loss: 0.4508 - val_accuracy: 0.9000
#
# Epoch 00024: val_accuracy did not improve from 0.90278
# Epoch 25/30
# 102/102 [==============================] - 2s 20ms/step - loss: 2.3147e-04 - accuracy: 1.0000 - val_loss: 0.4550 - val_accuracy: 0.8972
#
# Epoch 00025: val_accuracy did not improve from 0.90278
# Epoch 26/30
# 102/102 [==============================] - 2s 21ms/step - loss: 1.6853e-04 - accuracy: 1.0000 - val_loss: 0.4658 - val_accuracy: 0.9000
#
# Epoch 00026: val_accuracy did not improve from 0.90278
# Epoch 27/30
# 102/102 [==============================] - 2s 21ms/step - loss: 1.3334e-04 - accuracy: 1.0000 - val_loss: 0.4756 - val_accuracy: 0.9000
#
# Epoch 00027: val_accuracy did not improve from 0.90278
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 28/30
# 102/102 [==============================] - 2s 22ms/step - loss: 1.1110e-04 - accuracy: 1.0000 - val_loss: 0.4806 - val_accuracy: 0.9000
#
# Epoch 00028: val_accuracy did not improve from 0.90278
# Epoch 29/30
# 102/102 [==============================] - 2s 21ms/step - loss: 1.0227e-04 - accuracy: 1.0000 - val_loss: 0.4845 - val_accuracy: 0.9000
#
# Epoch 00029: val_accuracy did not improve from 0.90278
# Epoch 30/30
# 102/102 [==============================] - 2s 21ms/step - loss: 9.4058e-05 - accuracy: 1.0000 - val_loss: 0.4822 - val_accuracy: 0.9000
#
# Epoch 00030: val_accuracy did not improve from 0.90278
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Pop'], ['Country', 'Reggae', 'Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 102/102 [==============================] - 3s 24ms/step - loss: 0.5442 - accuracy: 0.7605 - val_loss: 0.4771 - val_accuracy: 0.6778
#
# Epoch 00001: val_accuracy improved from -inf to 0.67778, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder2\model.h5
# Epoch 2/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.3004 - accuracy: 0.8556 - val_loss: 0.3527 - val_accuracy: 0.7917
#
# Epoch 00002: val_accuracy improved from 0.67778 to 0.79167, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder2\model.h5
# Epoch 3/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.2634 - accuracy: 0.8843 - val_loss: 0.3360 - val_accuracy: 0.8333
#
# Epoch 00003: val_accuracy improved from 0.79167 to 0.83333, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder2\model.h5
# Epoch 4/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.2471 - accuracy: 0.8901 - val_loss: 0.2581 - val_accuracy: 0.8972
#
# Epoch 00004: val_accuracy improved from 0.83333 to 0.89722, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder2\model.h5
# Epoch 5/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.2434 - accuracy: 0.8963 - val_loss: 0.2878 - val_accuracy: 0.9000
#
# Epoch 00005: val_accuracy improved from 0.89722 to 0.90000, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder2\model.h5
# Epoch 6/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.2155 - accuracy: 0.9170 - val_loss: 0.3779 - val_accuracy: 0.8306
#
# Epoch 00006: val_accuracy did not improve from 0.90000
# Epoch 7/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.2132 - accuracy: 0.9173 - val_loss: 0.2323 - val_accuracy: 0.9139
#
# Epoch 00007: val_accuracy improved from 0.90000 to 0.91389, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder2\model.h5
# Epoch 8/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.1819 - accuracy: 0.9290 - val_loss: 0.2129 - val_accuracy: 0.9028
#
# Epoch 00008: val_accuracy did not improve from 0.91389
# Epoch 9/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.1639 - accuracy: 0.9373 - val_loss: 0.2245 - val_accuracy: 0.9139
#
# Epoch 00009: val_accuracy did not improve from 0.91389
# Epoch 10/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.1520 - accuracy: 0.9429 - val_loss: 0.2570 - val_accuracy: 0.9056
#
# Epoch 00010: val_accuracy did not improve from 0.91389
# Epoch 11/30
# 102/102 [==============================] - 2s 22ms/step - loss: 0.1398 - accuracy: 0.9457 - val_loss: 0.2090 - val_accuracy: 0.9167
#
# Epoch 00011: val_accuracy improved from 0.91389 to 0.91667, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder2\model.h5
# Epoch 12/30
# 102/102 [==============================] - 2s 23ms/step - loss: 0.1305 - accuracy: 0.9441 - val_loss: 0.3945 - val_accuracy: 0.8806
#
# Epoch 00012: val_accuracy did not improve from 0.91667
# Epoch 13/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.1235 - accuracy: 0.9549 - val_loss: 0.2056 - val_accuracy: 0.9194
#
# Epoch 00013: val_accuracy improved from 0.91667 to 0.91944, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder2\model.h5
# Epoch 14/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.1179 - accuracy: 0.9540 - val_loss: 0.2132 - val_accuracy: 0.9028
#
# Epoch 00014: val_accuracy did not improve from 0.91944
# Epoch 15/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.1110 - accuracy: 0.9543 - val_loss: 0.2721 - val_accuracy: 0.8806
#
# Epoch 00015: val_accuracy did not improve from 0.91944
# Epoch 16/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.1043 - accuracy: 0.9546 - val_loss: 0.2808 - val_accuracy: 0.9028
#
# Epoch 00016: val_accuracy did not improve from 0.91944
# Epoch 17/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.0931 - accuracy: 0.9623 - val_loss: 0.2280 - val_accuracy: 0.9194
#
# Epoch 00017: val_accuracy did not improve from 0.91944
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 18/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.0597 - accuracy: 0.9753 - val_loss: 0.2186 - val_accuracy: 0.9111
#
# Epoch 00018: val_accuracy did not improve from 0.91944
# Epoch 19/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.0493 - accuracy: 0.9824 - val_loss: 0.2148 - val_accuracy: 0.9167
#
# Epoch 00019: val_accuracy did not improve from 0.91944
# Epoch 20/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.0397 - accuracy: 0.9855 - val_loss: 0.2316 - val_accuracy: 0.9194
#
# Epoch 00020: val_accuracy did not improve from 0.91944
# Epoch 21/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.0345 - accuracy: 0.9877 - val_loss: 0.2532 - val_accuracy: 0.9278
#
# Epoch 00021: val_accuracy improved from 0.91944 to 0.92778, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder2\model.h5
# Epoch 22/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.0304 - accuracy: 0.9904 - val_loss: 0.2344 - val_accuracy: 0.9278
#
# Epoch 00022: val_accuracy did not improve from 0.92778
# Epoch 23/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.0278 - accuracy: 0.9883 - val_loss: 0.2141 - val_accuracy: 0.9278
#
# Epoch 00023: val_accuracy did not improve from 0.92778
# Epoch 24/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.0192 - accuracy: 0.9963 - val_loss: 0.2259 - val_accuracy: 0.9306
#
# Epoch 00024: val_accuracy improved from 0.92778 to 0.93056, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder2\model.h5
# Epoch 25/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.0165 - accuracy: 0.9957 - val_loss: 0.2442 - val_accuracy: 0.9222
#
# Epoch 00025: val_accuracy did not improve from 0.93056
# Epoch 26/30
# 102/102 [==============================] - 2s 22ms/step - loss: 0.0101 - accuracy: 0.9997 - val_loss: 0.2683 - val_accuracy: 0.9333
#
# Epoch 00026: val_accuracy improved from 0.93056 to 0.93333, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder2\model.h5
# Epoch 27/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.0069 - accuracy: 0.9994 - val_loss: 0.2682 - val_accuracy: 0.9278
#
# Epoch 00027: val_accuracy did not improve from 0.93333
# Epoch 28/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.2753 - val_accuracy: 0.9333
#
# Epoch 00028: val_accuracy did not improve from 0.93333
# Epoch 29/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.2865 - val_accuracy: 0.9333
#
# Epoch 00029: val_accuracy did not improve from 0.93333
# Epoch 30/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2994 - val_accuracy: 0.9389
#
# Epoch 00030: val_accuracy improved from 0.93333 to 0.93889, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder2\model.h5
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Reggae'], ['Country', 'Pop', 'Rock']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 102/102 [==============================] - 3s 22ms/step - loss: 0.5885 - accuracy: 0.7460 - val_loss: 0.6474 - val_accuracy: 0.7250
#
# Epoch 00001: val_accuracy improved from -inf to 0.72500, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder3\model.h5
# Epoch 2/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.4723 - accuracy: 0.7719 - val_loss: 0.4658 - val_accuracy: 0.7806
#
# Epoch 00002: val_accuracy improved from 0.72500 to 0.78056, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder3\model.h5
# Epoch 3/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.4081 - accuracy: 0.8127 - val_loss: 0.3667 - val_accuracy: 0.8278
#
# Epoch 00003: val_accuracy improved from 0.78056 to 0.82778, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder3\model.h5
# Epoch 4/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.3138 - accuracy: 0.8679 - val_loss: 0.4405 - val_accuracy: 0.8333
#
# Epoch 00004: val_accuracy improved from 0.82778 to 0.83333, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder3\model.h5
# Epoch 5/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.2371 - accuracy: 0.9062 - val_loss: 0.3623 - val_accuracy: 0.8278
#
# Epoch 00005: val_accuracy did not improve from 0.83333
# Epoch 6/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.2031 - accuracy: 0.9198 - val_loss: 0.3435 - val_accuracy: 0.8667
#
# Epoch 00006: val_accuracy improved from 0.83333 to 0.86667, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder3\model.h5
# Epoch 7/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.1476 - accuracy: 0.9460 - val_loss: 0.2127 - val_accuracy: 0.9222
#
# Epoch 00007: val_accuracy improved from 0.86667 to 0.92222, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder3\model.h5
# Epoch 8/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.1032 - accuracy: 0.9630 - val_loss: 0.2684 - val_accuracy: 0.9167
#
# Epoch 00008: val_accuracy did not improve from 0.92222
# Epoch 9/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.0698 - accuracy: 0.9784 - val_loss: 0.2935 - val_accuracy: 0.8806
#
# Epoch 00009: val_accuracy did not improve from 0.92222
# Epoch 10/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.0528 - accuracy: 0.9824 - val_loss: 0.3062 - val_accuracy: 0.9194
#
# Epoch 00010: val_accuracy did not improve from 0.92222
# Epoch 11/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.0276 - accuracy: 0.9895 - val_loss: 0.2672 - val_accuracy: 0.9167
#
# Epoch 00011: val_accuracy did not improve from 0.92222
# Epoch 12/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.0300 - accuracy: 0.9889 - val_loss: 0.3234 - val_accuracy: 0.8806
#
# Epoch 00012: val_accuracy did not improve from 0.92222
# Epoch 13/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.0202 - accuracy: 0.9935 - val_loss: 0.2706 - val_accuracy: 0.9278
#
# Epoch 00013: val_accuracy improved from 0.92222 to 0.92778, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder3\model.h5
# Epoch 14/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.0034 - accuracy: 0.9997 - val_loss: 0.3567 - val_accuracy: 0.9167
#
# Epoch 00014: val_accuracy did not improve from 0.92778
# Epoch 15/30
# 102/102 [==============================] - 2s 20ms/step - loss: 9.3217e-04 - accuracy: 1.0000 - val_loss: 0.3145 - val_accuracy: 0.9250
#
# Epoch 00015: val_accuracy did not improve from 0.92778
# Epoch 16/30
# 102/102 [==============================] - 2s 20ms/step - loss: 3.5952e-04 - accuracy: 1.0000 - val_loss: 0.3218 - val_accuracy: 0.9222
#
# Epoch 00016: val_accuracy did not improve from 0.92778
# Epoch 17/30
# 102/102 [==============================] - 2s 20ms/step - loss: 2.4220e-04 - accuracy: 1.0000 - val_loss: 0.3349 - val_accuracy: 0.9250
#
# Epoch 00017: val_accuracy did not improve from 0.92778
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 18/30
# 102/102 [==============================] - 2s 21ms/step - loss: 1.8900e-04 - accuracy: 1.0000 - val_loss: 0.3321 - val_accuracy: 0.9278
#
# Epoch 00018: val_accuracy did not improve from 0.92778
# Epoch 19/30
# 102/102 [==============================] - 2s 20ms/step - loss: 1.6879e-04 - accuracy: 1.0000 - val_loss: 0.3370 - val_accuracy: 0.9278
#
# Epoch 00019: val_accuracy did not improve from 0.92778
# Epoch 20/30
# 102/102 [==============================] - 2s 20ms/step - loss: 1.5322e-04 - accuracy: 1.0000 - val_loss: 0.3416 - val_accuracy: 0.9278
#
# Epoch 00020: val_accuracy did not improve from 0.92778
# Epoch 21/30
# 102/102 [==============================] - 2s 20ms/step - loss: 1.3762e-04 - accuracy: 1.0000 - val_loss: 0.3444 - val_accuracy: 0.9306
#
# Epoch 00021: val_accuracy improved from 0.92778 to 0.93056, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder3\model.h5
# Epoch 22/30
# 102/102 [==============================] - 2s 21ms/step - loss: 1.2358e-04 - accuracy: 1.0000 - val_loss: 0.3474 - val_accuracy: 0.9333
#
# Epoch 00022: val_accuracy improved from 0.93056 to 0.93333, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder3\model.h5
# Epoch 23/30
# 102/102 [==============================] - 2s 21ms/step - loss: 1.1383e-04 - accuracy: 1.0000 - val_loss: 0.3509 - val_accuracy: 0.9333
#
# Epoch 00023: val_accuracy did not improve from 0.93333
# Epoch 24/30
# 102/102 [==============================] - 2s 21ms/step - loss: 1.0387e-04 - accuracy: 1.0000 - val_loss: 0.3474 - val_accuracy: 0.9306
#
# Epoch 00024: val_accuracy did not improve from 0.93333
# Epoch 25/30
# 102/102 [==============================] - 2s 20ms/step - loss: 9.2864e-05 - accuracy: 1.0000 - val_loss: 0.3479 - val_accuracy: 0.9306
#
# Epoch 00025: val_accuracy did not improve from 0.93333
# Epoch 26/30
# 102/102 [==============================] - 2s 20ms/step - loss: 8.4399e-05 - accuracy: 1.0000 - val_loss: 0.3468 - val_accuracy: 0.9306
#
# Epoch 00026: val_accuracy did not improve from 0.93333
# Epoch 27/30
# 102/102 [==============================] - 2s 20ms/step - loss: 7.7664e-05 - accuracy: 1.0000 - val_loss: 0.3493 - val_accuracy: 0.9278
#
# Epoch 00027: val_accuracy did not improve from 0.93333
# Epoch 28/30
# 102/102 [==============================] - 2s 20ms/step - loss: 7.0658e-05 - accuracy: 1.0000 - val_loss: 0.3551 - val_accuracy: 0.9306
#
# Epoch 00028: val_accuracy did not improve from 0.93333
# Epoch 29/30
# 102/102 [==============================] - 2s 20ms/step - loss: 6.5726e-05 - accuracy: 1.0000 - val_loss: 0.3505 - val_accuracy: 0.9306
#
# Epoch 00029: val_accuracy did not improve from 0.93333
# Epoch 30/30
# 102/102 [==============================] - 2s 20ms/step - loss: 5.9415e-05 - accuracy: 1.0000 - val_loss: 0.3538 - val_accuracy: 0.9306
#
# Epoch 00030: val_accuracy did not improve from 0.93333
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Rock'], ['Country', 'Pop', 'Reggae']]
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 102/102 [==============================] - 3s 23ms/step - loss: 0.5615 - accuracy: 0.7472 - val_loss: 0.5947 - val_accuracy: 0.7278
#
# Epoch 00001: val_accuracy improved from -inf to 0.72778, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder4\model.h5
# Epoch 2/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.4831 - accuracy: 0.7836 - val_loss: 0.4709 - val_accuracy: 0.8083
#
# Epoch 00002: val_accuracy improved from 0.72778 to 0.80833, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder4\model.h5
# Epoch 3/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.4228 - accuracy: 0.8127 - val_loss: 0.4433 - val_accuracy: 0.7972
#
# Epoch 00003: val_accuracy did not improve from 0.80833
# Epoch 4/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.3972 - accuracy: 0.8284 - val_loss: 0.4278 - val_accuracy: 0.8139
#
# Epoch 00004: val_accuracy improved from 0.80833 to 0.81389, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder4\model.h5
# Epoch 5/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.3769 - accuracy: 0.8370 - val_loss: 0.4214 - val_accuracy: 0.8194
#
# Epoch 00005: val_accuracy improved from 0.81389 to 0.81944, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder4\model.h5
# Epoch 6/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.3708 - accuracy: 0.8367 - val_loss: 0.4031 - val_accuracy: 0.8194
#
# Epoch 00006: val_accuracy did not improve from 0.81944
# Epoch 7/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.3311 - accuracy: 0.8503 - val_loss: 0.3586 - val_accuracy: 0.8528
#
# Epoch 00007: val_accuracy improved from 0.81944 to 0.85278, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder4\model.h5
# Epoch 8/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.3103 - accuracy: 0.8664 - val_loss: 0.3155 - val_accuracy: 0.8667
#
# Epoch 00008: val_accuracy improved from 0.85278 to 0.86667, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder4\model.h5
# Epoch 9/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.2517 - accuracy: 0.8892 - val_loss: 0.2828 - val_accuracy: 0.8694
#
# Epoch 00009: val_accuracy improved from 0.86667 to 0.86944, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder4\model.h5
# Epoch 10/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.2025 - accuracy: 0.9151 - val_loss: 0.3047 - val_accuracy: 0.8722
#
# Epoch 00010: val_accuracy improved from 0.86944 to 0.87222, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder4\model.h5
# Epoch 11/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.1713 - accuracy: 0.9343 - val_loss: 0.2622 - val_accuracy: 0.8917
#
# Epoch 00011: val_accuracy improved from 0.87222 to 0.89167, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder4\model.h5
# Epoch 12/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.1377 - accuracy: 0.9457 - val_loss: 0.2697 - val_accuracy: 0.9000
#
# Epoch 00012: val_accuracy improved from 0.89167 to 0.90000, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder4\model.h5
# Epoch 13/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.1169 - accuracy: 0.9552 - val_loss: 0.3169 - val_accuracy: 0.8917
#
# Epoch 00013: val_accuracy did not improve from 0.90000
# Epoch 14/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.0699 - accuracy: 0.9735 - val_loss: 0.3150 - val_accuracy: 0.8917
#
# Epoch 00014: val_accuracy did not improve from 0.90000
# Epoch 15/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.0668 - accuracy: 0.9753 - val_loss: 0.4221 - val_accuracy: 0.8833
#
# Epoch 00015: val_accuracy did not improve from 0.90000
# Epoch 16/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.0564 - accuracy: 0.9793 - val_loss: 0.3504 - val_accuracy: 0.9111
#
# Epoch 00016: val_accuracy improved from 0.90000 to 0.91111, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder4\model.h5
# Epoch 17/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.0306 - accuracy: 0.9904 - val_loss: 0.4038 - val_accuracy: 0.8889
#
# Epoch 00017: val_accuracy did not improve from 0.91111
# Epoch 18/30
# 102/102 [==============================] - 2s 20ms/step - loss: 0.0220 - accuracy: 0.9929 - val_loss: 0.4077 - val_accuracy: 0.8917
#
# Epoch 00018: val_accuracy did not improve from 0.91111
# Epoch 19/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.0069 - accuracy: 0.9985 - val_loss: 0.3832 - val_accuracy: 0.9083
#
# Epoch 00019: val_accuracy did not improve from 0.91111
# Epoch 20/30
# 102/102 [==============================] - 2s 21ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4147 - val_accuracy: 0.9278
#
# Epoch 00020: val_accuracy improved from 0.91111 to 0.92778, saving model to ./models/tree_10/model_root_f1_1_1_1_1_1/folder4\model.h5
# Epoch 21/30
# 102/102 [==============================] - 2s 21ms/step - loss: 6.0782e-04 - accuracy: 1.0000 - val_loss: 0.4377 - val_accuracy: 0.9111
#
# Epoch 00021: val_accuracy did not improve from 0.92778
# Epoch 22/30
# 102/102 [==============================] - 2s 20ms/step - loss: 4.0072e-04 - accuracy: 1.0000 - val_loss: 0.4476 - val_accuracy: 0.9083
#
# Epoch 00022: val_accuracy did not improve from 0.92778
# Epoch 23/30
# 102/102 [==============================] - 2s 20ms/step - loss: 3.0376e-04 - accuracy: 1.0000 - val_loss: 0.4588 - val_accuracy: 0.9083
#
# Epoch 00023: val_accuracy did not improve from 0.92778
# Epoch 24/30
# 102/102 [==============================] - 2s 20ms/step - loss: 2.4520e-04 - accuracy: 1.0000 - val_loss: 0.4714 - val_accuracy: 0.9083
#
# Epoch 00024: val_accuracy did not improve from 0.92778
# Epoch 25/30
# 102/102 [==============================] - 2s 21ms/step - loss: 2.0650e-04 - accuracy: 1.0000 - val_loss: 0.4793 - val_accuracy: 0.9083
#
# Epoch 00025: val_accuracy did not improve from 0.92778
# Epoch 26/30
# 102/102 [==============================] - 2s 20ms/step - loss: 1.7364e-04 - accuracy: 1.0000 - val_loss: 0.4887 - val_accuracy: 0.9111
#
# Epoch 00026: val_accuracy did not improve from 0.92778
# Epoch 27/30
# 102/102 [==============================] - 2s 20ms/step - loss: 1.4761e-04 - accuracy: 1.0000 - val_loss: 0.4966 - val_accuracy: 0.9139
#
# Epoch 00027: val_accuracy did not improve from 0.92778
# Epoch 28/30
# 102/102 [==============================] - 2s 21ms/step - loss: 1.2678e-04 - accuracy: 1.0000 - val_loss: 0.5025 - val_accuracy: 0.9167
#
# Epoch 00028: val_accuracy did not improve from 0.92778
# Epoch 29/30
# 102/102 [==============================] - 2s 21ms/step - loss: 1.0984e-04 - accuracy: 1.0000 - val_loss: 0.5085 - val_accuracy: 0.9111
#
# Epoch 00029: val_accuracy did not improve from 0.92778
# Epoch 30/30
# 102/102 [==============================] - 2s 21ms/step - loss: 9.9206e-05 - accuracy: 1.0000 - val_loss: 0.5140 - val_accuracy: 0.9167
#
# Epoch 00030: val_accuracy did not improve from 0.92778
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
