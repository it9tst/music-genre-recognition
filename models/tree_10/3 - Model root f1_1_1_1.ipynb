# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Blues':0, 'Country':2, 'Hip-Hop':4, 'Pop':7, 'Reggae':8, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Blues', 2: 'Country', 4: 'Hip-Hop', 7: 'Pop', 8: 'Reggae', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((4800, 128, 128), (4800, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((600, 128, 128), (600, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Hip-Hop

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation='softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_10/model_root_f1_1_1_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_10/model_root_f1_1_1_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 6
n_splits = 10

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    dict_genres_list = list(dict_genres.values())
    split = [[dict_genres_list.pop(fold_no - 1)], dict_genres_list]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Blues'], ['Country', 'Hip-Hop', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 152/152 [==============================] - 7s 25ms/step - loss: 0.4843 - accuracy: 0.8290 - val_loss: 0.4311 - val_accuracy: 0.8278
#
# Epoch 00001: val_accuracy improved from -inf to 0.82778, saving model to ./models/tree_10/model_root_f1_1_1_1/folder1\model.h5
# Epoch 2/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.3830 - accuracy: 0.8451 - val_loss: 0.3469 - val_accuracy: 0.8648
#
# Epoch 00002: val_accuracy improved from 0.82778 to 0.86481, saving model to ./models/tree_10/model_root_f1_1_1_1/folder1\model.h5
# Epoch 3/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.2943 - accuracy: 0.8751 - val_loss: 0.2794 - val_accuracy: 0.8759
#
# Epoch 00003: val_accuracy improved from 0.86481 to 0.87593, saving model to ./models/tree_10/model_root_f1_1_1_1/folder1\model.h5
# Epoch 4/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.2467 - accuracy: 0.8918 - val_loss: 0.2571 - val_accuracy: 0.8815
#
# Epoch 00004: val_accuracy improved from 0.87593 to 0.88148, saving model to ./models/tree_10/model_root_f1_1_1_1/folder1\model.h5
# Epoch 5/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.1920 - accuracy: 0.9200 - val_loss: 0.2345 - val_accuracy: 0.9111
#
# Epoch 00005: val_accuracy improved from 0.88148 to 0.91111, saving model to ./models/tree_10/model_root_f1_1_1_1/folder1\model.h5
# Epoch 6/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.1483 - accuracy: 0.9387 - val_loss: 0.2908 - val_accuracy: 0.8741
#
# Epoch 00006: val_accuracy did not improve from 0.91111
# Epoch 7/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.1139 - accuracy: 0.9523 - val_loss: 0.1372 - val_accuracy: 0.9426
#
# Epoch 00007: val_accuracy improved from 0.91111 to 0.94259, saving model to ./models/tree_10/model_root_f1_1_1_1/folder1\model.h5
# Epoch 8/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.0837 - accuracy: 0.9671 - val_loss: 0.1252 - val_accuracy: 0.9426
#
# Epoch 00008: val_accuracy did not improve from 0.94259
# Epoch 9/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0791 - accuracy: 0.9691 - val_loss: 0.1153 - val_accuracy: 0.9444
#
# Epoch 00009: val_accuracy improved from 0.94259 to 0.94444, saving model to ./models/tree_10/model_root_f1_1_1_1/folder1\model.h5
# Epoch 10/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0645 - accuracy: 0.9755 - val_loss: 0.1330 - val_accuracy: 0.9352
#
# Epoch 00010: val_accuracy did not improve from 0.94444
# Epoch 11/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0460 - accuracy: 0.9835 - val_loss: 0.1675 - val_accuracy: 0.9352
#
# Epoch 00011: val_accuracy did not improve from 0.94444
# Epoch 12/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0412 - accuracy: 0.9856 - val_loss: 0.1636 - val_accuracy: 0.9519
#
# Epoch 00012: val_accuracy improved from 0.94444 to 0.95185, saving model to ./models/tree_10/model_root_f1_1_1_1/folder1\model.h5
# Epoch 13/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0121 - accuracy: 0.9959 - val_loss: 0.1575 - val_accuracy: 0.9537
#
# Epoch 00013: val_accuracy improved from 0.95185 to 0.95370, saving model to ./models/tree_10/model_root_f1_1_1_1/folder1\model.h5
# Epoch 14/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0100 - accuracy: 0.9963 - val_loss: 0.1343 - val_accuracy: 0.9537
#
# Epoch 00014: val_accuracy did not improve from 0.95370
# Epoch 15/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0109 - accuracy: 0.9955 - val_loss: 0.1563 - val_accuracy: 0.9426
#
# Epoch 00015: val_accuracy did not improve from 0.95370
# Epoch 16/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0638 - accuracy: 0.9774 - val_loss: 0.1434 - val_accuracy: 0.9537
#
# Epoch 00016: val_accuracy did not improve from 0.95370
# Epoch 17/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0116 - accuracy: 0.9967 - val_loss: 0.1725 - val_accuracy: 0.9556
#
# Epoch 00017: val_accuracy improved from 0.95370 to 0.95556, saving model to ./models/tree_10/model_root_f1_1_1_1/folder1\model.h5
# Epoch 18/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1674 - val_accuracy: 0.9574
#
# Epoch 00018: val_accuracy improved from 0.95556 to 0.95741, saving model to ./models/tree_10/model_root_f1_1_1_1/folder1\model.h5
# Epoch 19/30
# 152/152 [==============================] - 3s 21ms/step - loss: 4.4847e-04 - accuracy: 1.0000 - val_loss: 0.1542 - val_accuracy: 0.9593
#
# Epoch 00019: val_accuracy improved from 0.95741 to 0.95926, saving model to ./models/tree_10/model_root_f1_1_1_1/folder1\model.h5
# Epoch 20/30
# 152/152 [==============================] - 3s 20ms/step - loss: 2.6568e-04 - accuracy: 1.0000 - val_loss: 0.1566 - val_accuracy: 0.9574
#
# Epoch 00020: val_accuracy did not improve from 0.95926
# Epoch 21/30
# 152/152 [==============================] - 3s 21ms/step - loss: 1.4817e-04 - accuracy: 1.0000 - val_loss: 0.1557 - val_accuracy: 0.9593
#
# Epoch 00021: val_accuracy did not improve from 0.95926
# Epoch 22/30
# 152/152 [==============================] - 3s 20ms/step - loss: 1.1797e-04 - accuracy: 1.0000 - val_loss: 0.1590 - val_accuracy: 0.9593
#
# Epoch 00022: val_accuracy did not improve from 0.95926
# Epoch 23/30
# 152/152 [==============================] - 3s 21ms/step - loss: 9.5578e-05 - accuracy: 1.0000 - val_loss: 0.1611 - val_accuracy: 0.9593
#
# Epoch 00023: val_accuracy did not improve from 0.95926
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 24/30
# 152/152 [==============================] - 3s 21ms/step - loss: 8.0650e-05 - accuracy: 1.0000 - val_loss: 0.1649 - val_accuracy: 0.9593
#
# Epoch 00024: val_accuracy did not improve from 0.95926
# Epoch 25/30
# 152/152 [==============================] - 3s 21ms/step - loss: 7.4206e-05 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9593
#
# Epoch 00025: val_accuracy did not improve from 0.95926
# Epoch 26/30
# 152/152 [==============================] - 3s 22ms/step - loss: 6.8370e-05 - accuracy: 1.0000 - val_loss: 0.1632 - val_accuracy: 0.9593
#
# Epoch 00026: val_accuracy did not improve from 0.95926
# Epoch 27/30
# 152/152 [==============================] - 3s 20ms/step - loss: 6.2173e-05 - accuracy: 1.0000 - val_loss: 0.1717 - val_accuracy: 0.9593
#
# Epoch 00027: val_accuracy did not improve from 0.95926
# Epoch 28/30
# 152/152 [==============================] - 3s 20ms/step - loss: 5.6705e-05 - accuracy: 1.0000 - val_loss: 0.1725 - val_accuracy: 0.9593
#
# Epoch 00028: val_accuracy did not improve from 0.95926
# Epoch 29/30
# 152/152 [==============================] - 3s 20ms/step - loss: 5.2273e-05 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9593
#
# Epoch 00029: val_accuracy did not improve from 0.95926
# Epoch 30/30
# 152/152 [==============================] - 3s 20ms/step - loss: 4.8147e-05 - accuracy: 1.0000 - val_loss: 0.1661 - val_accuracy: 0.9593
#
# Epoch 00030: val_accuracy did not improve from 0.95926
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Country'], ['Blues', 'Hip-Hop', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 152/152 [==============================] - 4s 22ms/step - loss: 0.4395 - accuracy: 0.8253 - val_loss: 0.2964 - val_accuracy: 0.8500
#
# Epoch 00001: val_accuracy improved from -inf to 0.85000, saving model to ./models/tree_10/model_root_f1_1_1_1/folder2\model.h5
# Epoch 2/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.3149 - accuracy: 0.8512 - val_loss: 0.4186 - val_accuracy: 0.7556
#
# Epoch 00002: val_accuracy did not improve from 0.85000
# Epoch 3/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.2841 - accuracy: 0.8654 - val_loss: 0.2300 - val_accuracy: 0.9019
#
# Epoch 00003: val_accuracy improved from 0.85000 to 0.90185, saving model to ./models/tree_10/model_root_f1_1_1_1/folder2\model.h5
# Epoch 4/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.2333 - accuracy: 0.8944 - val_loss: 0.1853 - val_accuracy: 0.9204
#
# Epoch 00004: val_accuracy improved from 0.90185 to 0.92037, saving model to ./models/tree_10/model_root_f1_1_1_1/folder2\model.h5
# Epoch 5/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.1967 - accuracy: 0.9177 - val_loss: 0.1614 - val_accuracy: 0.9259
#
# Epoch 00005: val_accuracy improved from 0.92037 to 0.92593, saving model to ./models/tree_10/model_root_f1_1_1_1/folder2\model.h5
# Epoch 6/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.1760 - accuracy: 0.9270 - val_loss: 0.1927 - val_accuracy: 0.9056
#
# Epoch 00006: val_accuracy did not improve from 0.92593
# Epoch 7/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.1472 - accuracy: 0.9397 - val_loss: 0.1587 - val_accuracy: 0.9278
#
# Epoch 00007: val_accuracy improved from 0.92593 to 0.92778, saving model to ./models/tree_10/model_root_f1_1_1_1/folder2\model.h5
# Epoch 8/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.1094 - accuracy: 0.9595 - val_loss: 0.2176 - val_accuracy: 0.9000
#
# Epoch 00008: val_accuracy did not improve from 0.92778
# Epoch 9/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0946 - accuracy: 0.9626 - val_loss: 0.1294 - val_accuracy: 0.9481
#
# Epoch 00009: val_accuracy improved from 0.92778 to 0.94815, saving model to ./models/tree_10/model_root_f1_1_1_1/folder2\model.h5
# Epoch 10/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0595 - accuracy: 0.9786 - val_loss: 0.1636 - val_accuracy: 0.9389
#
# Epoch 00010: val_accuracy did not improve from 0.94815
# Epoch 11/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0390 - accuracy: 0.9846 - val_loss: 0.1689 - val_accuracy: 0.9333
#
# Epoch 00011: val_accuracy did not improve from 0.94815
# Epoch 12/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0593 - accuracy: 0.9790 - val_loss: 0.2003 - val_accuracy: 0.9296
#
# Epoch 00012: val_accuracy did not improve from 0.94815
# Epoch 13/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0279 - accuracy: 0.9893 - val_loss: 0.1903 - val_accuracy: 0.9370
#
# Epoch 00013: val_accuracy did not improve from 0.94815
# Epoch 14/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0213 - accuracy: 0.9930 - val_loss: 0.1793 - val_accuracy: 0.9370
#
# Epoch 00014: val_accuracy did not improve from 0.94815
# Epoch 15/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0309 - accuracy: 0.9881 - val_loss: 0.2170 - val_accuracy: 0.9296
#
# Epoch 00015: val_accuracy did not improve from 0.94815
# Epoch 16/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0120 - accuracy: 0.9953 - val_loss: 0.2164 - val_accuracy: 0.9389
#
# Epoch 00016: val_accuracy did not improve from 0.94815
# Epoch 17/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0026 - accuracy: 0.9998 - val_loss: 0.2113 - val_accuracy: 0.9463
#
# Epoch 00017: val_accuracy did not improve from 0.94815
# Epoch 18/30
# 152/152 [==============================] - 3s 21ms/step - loss: 3.6536e-04 - accuracy: 1.0000 - val_loss: 0.2043 - val_accuracy: 0.9426
#
# Epoch 00018: val_accuracy did not improve from 0.94815
# Epoch 19/30
# 152/152 [==============================] - 3s 20ms/step - loss: 2.1367e-04 - accuracy: 1.0000 - val_loss: 0.2049 - val_accuracy: 0.9463
#
# Epoch 00019: val_accuracy did not improve from 0.94815
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/30
# 152/152 [==============================] - 3s 20ms/step - loss: 1.1188e-04 - accuracy: 1.0000 - val_loss: 0.2054 - val_accuracy: 0.9463
#
# Epoch 00020: val_accuracy did not improve from 0.94815
# Epoch 21/30
# 152/152 [==============================] - 3s 20ms/step - loss: 9.7381e-05 - accuracy: 1.0000 - val_loss: 0.2068 - val_accuracy: 0.9481
#
# Epoch 00021: val_accuracy did not improve from 0.94815
# Epoch 22/30
# 152/152 [==============================] - 3s 21ms/step - loss: 8.6281e-05 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9481
#
# Epoch 00022: val_accuracy did not improve from 0.94815
# Epoch 23/30
# 152/152 [==============================] - 3s 21ms/step - loss: 7.6790e-05 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9481
#
# Epoch 00023: val_accuracy did not improve from 0.94815
# Epoch 24/30
# 152/152 [==============================] - 3s 21ms/step - loss: 6.8662e-05 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9481
#
# Epoch 00024: val_accuracy did not improve from 0.94815
# Epoch 25/30
# 152/152 [==============================] - 3s 20ms/step - loss: 6.1777e-05 - accuracy: 1.0000 - val_loss: 0.2129 - val_accuracy: 0.9500
#
# Epoch 00025: val_accuracy improved from 0.94815 to 0.95000, saving model to ./models/tree_10/model_root_f1_1_1_1/folder2\model.h5
# Epoch 26/30
# 152/152 [==============================] - 3s 20ms/step - loss: 5.5546e-05 - accuracy: 1.0000 - val_loss: 0.2139 - val_accuracy: 0.9500
#
# Epoch 00026: val_accuracy did not improve from 0.95000
# Epoch 27/30
# 152/152 [==============================] - 3s 20ms/step - loss: 5.0055e-05 - accuracy: 1.0000 - val_loss: 0.2163 - val_accuracy: 0.9500
#
# Epoch 00027: val_accuracy did not improve from 0.95000
# Epoch 28/30
# 152/152 [==============================] - 3s 21ms/step - loss: 4.5338e-05 - accuracy: 1.0000 - val_loss: 0.2168 - val_accuracy: 0.9481
#
# Epoch 00028: val_accuracy did not improve from 0.95000
# Epoch 29/30
# 152/152 [==============================] - 4s 23ms/step - loss: 4.0843e-05 - accuracy: 1.0000 - val_loss: 0.2184 - val_accuracy: 0.9481
#
# Epoch 00029: val_accuracy did not improve from 0.95000
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 30/30
# 152/152 [==============================] - 3s 20ms/step - loss: 3.7343e-05 - accuracy: 1.0000 - val_loss: 0.2190 - val_accuracy: 0.9481
#
# Epoch 00030: val_accuracy did not improve from 0.95000
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Hip-Hop'], ['Blues', 'Country', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 152/152 [==============================] - 4s 22ms/step - loss: 0.4734 - accuracy: 0.8296 - val_loss: 0.7590 - val_accuracy: 0.8204
#
# Epoch 00001: val_accuracy improved from -inf to 0.82037, saving model to ./models/tree_10/model_root_f1_1_1_1/folder3\model.h5
# Epoch 2/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.3662 - accuracy: 0.8389 - val_loss: 0.2863 - val_accuracy: 0.8889
#
# Epoch 00002: val_accuracy improved from 0.82037 to 0.88889, saving model to ./models/tree_10/model_root_f1_1_1_1/folder3\model.h5
# Epoch 3/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.2836 - accuracy: 0.8856 - val_loss: 0.2476 - val_accuracy: 0.8944
#
# Epoch 00003: val_accuracy improved from 0.88889 to 0.89444, saving model to ./models/tree_10/model_root_f1_1_1_1/folder3\model.h5
# Epoch 4/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.2630 - accuracy: 0.8866 - val_loss: 0.2299 - val_accuracy: 0.9093
#
# Epoch 00004: val_accuracy improved from 0.89444 to 0.90926, saving model to ./models/tree_10/model_root_f1_1_1_1/folder3\model.h5
# Epoch 5/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.2278 - accuracy: 0.9062 - val_loss: 0.2118 - val_accuracy: 0.9056
#
# Epoch 00005: val_accuracy did not improve from 0.90926
# Epoch 6/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.1897 - accuracy: 0.9251 - val_loss: 0.1935 - val_accuracy: 0.9204
#
# Epoch 00006: val_accuracy improved from 0.90926 to 0.92037, saving model to ./models/tree_10/model_root_f1_1_1_1/folder3\model.h5
# Epoch 7/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.1461 - accuracy: 0.9455 - val_loss: 0.1256 - val_accuracy: 0.9537
#
# Epoch 00007: val_accuracy improved from 0.92037 to 0.95370, saving model to ./models/tree_10/model_root_f1_1_1_1/folder3\model.h5
# Epoch 8/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.1233 - accuracy: 0.9539 - val_loss: 0.1428 - val_accuracy: 0.9463
#
# Epoch 00008: val_accuracy did not improve from 0.95370
# Epoch 9/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0923 - accuracy: 0.9669 - val_loss: 0.1191 - val_accuracy: 0.9463
#
# Epoch 00009: val_accuracy did not improve from 0.95370
# Epoch 10/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0744 - accuracy: 0.9743 - val_loss: 0.1112 - val_accuracy: 0.9611
#
# Epoch 00010: val_accuracy improved from 0.95370 to 0.96111, saving model to ./models/tree_10/model_root_f1_1_1_1/folder3\model.h5
# Epoch 11/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0577 - accuracy: 0.9772 - val_loss: 0.1037 - val_accuracy: 0.9704
#
# Epoch 00011: val_accuracy improved from 0.96111 to 0.97037, saving model to ./models/tree_10/model_root_f1_1_1_1/folder3\model.h5
# Epoch 12/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0239 - accuracy: 0.9928 - val_loss: 0.1557 - val_accuracy: 0.9667
#
# Epoch 00012: val_accuracy did not improve from 0.97037
# Epoch 13/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0218 - accuracy: 0.9932 - val_loss: 0.2677 - val_accuracy: 0.9278
#
# Epoch 00013: val_accuracy did not improve from 0.97037
# Epoch 14/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0219 - accuracy: 0.9924 - val_loss: 0.1399 - val_accuracy: 0.9648
#
# Epoch 00014: val_accuracy did not improve from 0.97037
# Epoch 15/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0025 - accuracy: 0.9998 - val_loss: 0.1356 - val_accuracy: 0.9667
#
# Epoch 00015: val_accuracy did not improve from 0.97037
# Epoch 16/30
# 152/152 [==============================] - 3s 20ms/step - loss: 6.8749e-04 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9704
#
# Epoch 00016: val_accuracy did not improve from 0.97037
# Epoch 17/30
# 152/152 [==============================] - 3s 21ms/step - loss: 2.4403e-04 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9722
#
# Epoch 00017: val_accuracy improved from 0.97037 to 0.97222, saving model to ./models/tree_10/model_root_f1_1_1_1/folder3\model.h5
# Epoch 18/30
# 152/152 [==============================] - 3s 20ms/step - loss: 1.6691e-04 - accuracy: 1.0000 - val_loss: 0.1439 - val_accuracy: 0.9722
#
# Epoch 00018: val_accuracy did not improve from 0.97222
# Epoch 19/30
# 152/152 [==============================] - 3s 20ms/step - loss: 1.2999e-04 - accuracy: 1.0000 - val_loss: 0.1452 - val_accuracy: 0.9722
#
# Epoch 00019: val_accuracy did not improve from 0.97222
# Epoch 20/30
# 152/152 [==============================] - 3s 21ms/step - loss: 1.0372e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9722
#
# Epoch 00020: val_accuracy did not improve from 0.97222
# Epoch 21/30
# 152/152 [==============================] - 3s 21ms/step - loss: 8.3280e-05 - accuracy: 1.0000 - val_loss: 0.1546 - val_accuracy: 0.9704
#
# Epoch 00021: val_accuracy did not improve from 0.97222
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 22/30
# 152/152 [==============================] - 3s 21ms/step - loss: 7.0554e-05 - accuracy: 1.0000 - val_loss: 0.1537 - val_accuracy: 0.9722
#
# Epoch 00022: val_accuracy did not improve from 0.97222
# Epoch 23/30
# 152/152 [==============================] - 3s 21ms/step - loss: 6.4660e-05 - accuracy: 1.0000 - val_loss: 0.1554 - val_accuracy: 0.9722
#
# Epoch 00023: val_accuracy did not improve from 0.97222
# Epoch 24/30
# 152/152 [==============================] - 3s 21ms/step - loss: 5.9233e-05 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.9722
#
# Epoch 00024: val_accuracy did not improve from 0.97222
# Epoch 25/30
# 152/152 [==============================] - 3s 21ms/step - loss: 5.4025e-05 - accuracy: 1.0000 - val_loss: 0.1588 - val_accuracy: 0.9722
#
# Epoch 00025: val_accuracy did not improve from 0.97222
# Epoch 26/30
# 152/152 [==============================] - 3s 21ms/step - loss: 4.9585e-05 - accuracy: 1.0000 - val_loss: 0.1582 - val_accuracy: 0.9722
#
# Epoch 00026: val_accuracy did not improve from 0.97222
# Epoch 27/30
# 152/152 [==============================] - 3s 21ms/step - loss: 4.5348e-05 - accuracy: 1.0000 - val_loss: 0.1588 - val_accuracy: 0.9722
#
# Epoch 00027: val_accuracy did not improve from 0.97222
# Epoch 28/30
# 152/152 [==============================] - 3s 21ms/step - loss: 4.1398e-05 - accuracy: 1.0000 - val_loss: 0.1607 - val_accuracy: 0.9722
#
# Epoch 00028: val_accuracy did not improve from 0.97222
# Epoch 29/30
# 152/152 [==============================] - 3s 22ms/step - loss: 3.8013e-05 - accuracy: 1.0000 - val_loss: 0.1613 - val_accuracy: 0.9722
#
# Epoch 00029: val_accuracy did not improve from 0.97222
# Epoch 30/30
# 152/152 [==============================] - 3s 22ms/step - loss: 3.4522e-05 - accuracy: 1.0000 - val_loss: 0.1630 - val_accuracy: 0.9722
#
# Epoch 00030: val_accuracy did not improve from 0.97222
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Pop'], ['Blues', 'Country', 'Hip-Hop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 152/152 [==============================] - 4s 23ms/step - loss: 0.4204 - accuracy: 0.8307 - val_loss: 0.2553 - val_accuracy: 0.8944
#
# Epoch 00001: val_accuracy improved from -inf to 0.89444, saving model to ./models/tree_10/model_root_f1_1_1_1/folder4\model.h5
# Epoch 2/30
# 152/152 [==============================] - 4s 23ms/step - loss: 0.2405 - accuracy: 0.8934 - val_loss: 0.2058 - val_accuracy: 0.9019
#
# Epoch 00002: val_accuracy improved from 0.89444 to 0.90185, saving model to ./models/tree_10/model_root_f1_1_1_1/folder4\model.h5
# Epoch 3/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.2211 - accuracy: 0.9049 - val_loss: 0.2219 - val_accuracy: 0.8981
#
# Epoch 00003: val_accuracy did not improve from 0.90185
# Epoch 4/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.2113 - accuracy: 0.9082 - val_loss: 0.1801 - val_accuracy: 0.9407
#
# Epoch 00004: val_accuracy improved from 0.90185 to 0.94074, saving model to ./models/tree_10/model_root_f1_1_1_1/folder4\model.h5
# Epoch 5/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.1956 - accuracy: 0.9214 - val_loss: 0.2113 - val_accuracy: 0.9148
#
# Epoch 00005: val_accuracy did not improve from 0.94074
# Epoch 6/30
# 152/152 [==============================] - 4s 24ms/step - loss: 0.1868 - accuracy: 0.9235 - val_loss: 0.1814 - val_accuracy: 0.9204
#
# Epoch 00006: val_accuracy did not improve from 0.94074
# Epoch 7/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.1712 - accuracy: 0.9325 - val_loss: 0.1900 - val_accuracy: 0.9259
#
# Epoch 00007: val_accuracy did not improve from 0.94074
# Epoch 8/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.1687 - accuracy: 0.9348 - val_loss: 0.1697 - val_accuracy: 0.9315
#
# Epoch 00008: val_accuracy did not improve from 0.94074
# Epoch 9/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.1604 - accuracy: 0.9362 - val_loss: 0.1551 - val_accuracy: 0.9426
#
# Epoch 00009: val_accuracy improved from 0.94074 to 0.94259, saving model to ./models/tree_10/model_root_f1_1_1_1/folder4\model.h5
# Epoch 10/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.1413 - accuracy: 0.9426 - val_loss: 0.1665 - val_accuracy: 0.9370
#
# Epoch 00010: val_accuracy did not improve from 0.94259
# Epoch 11/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.1485 - accuracy: 0.9395 - val_loss: 0.1551 - val_accuracy: 0.9407
#
# Epoch 00011: val_accuracy did not improve from 0.94259
# Epoch 12/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.1301 - accuracy: 0.9479 - val_loss: 0.1534 - val_accuracy: 0.9444
#
# Epoch 00012: val_accuracy improved from 0.94259 to 0.94444, saving model to ./models/tree_10/model_root_f1_1_1_1/folder4\model.h5
# Epoch 13/30
# 152/152 [==============================] - 3s 23ms/step - loss: 0.1283 - accuracy: 0.9477 - val_loss: 0.1787 - val_accuracy: 0.9222
#
# Epoch 00013: val_accuracy did not improve from 0.94444
# Epoch 14/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.1177 - accuracy: 0.9533 - val_loss: 0.1648 - val_accuracy: 0.9481
#
# Epoch 00014: val_accuracy improved from 0.94444 to 0.94815, saving model to ./models/tree_10/model_root_f1_1_1_1/folder4\model.h5
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 15/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.1000 - accuracy: 0.9603 - val_loss: 0.1633 - val_accuracy: 0.9370
#
# Epoch 00015: val_accuracy did not improve from 0.94815
# Epoch 16/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0848 - accuracy: 0.9691 - val_loss: 0.1487 - val_accuracy: 0.9463
#
# Epoch 00016: val_accuracy did not improve from 0.94815
# Epoch 17/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.0758 - accuracy: 0.9720 - val_loss: 0.1725 - val_accuracy: 0.9500
#
# Epoch 00017: val_accuracy improved from 0.94815 to 0.95000, saving model to ./models/tree_10/model_root_f1_1_1_1/folder4\model.h5
# Epoch 18/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0713 - accuracy: 0.9743 - val_loss: 0.1507 - val_accuracy: 0.9370
#
# Epoch 00018: val_accuracy did not improve from 0.95000
# Epoch 19/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.0625 - accuracy: 0.9794 - val_loss: 0.1559 - val_accuracy: 0.9463
#
# Epoch 00019: val_accuracy did not improve from 0.95000
# Epoch 20/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0524 - accuracy: 0.9807 - val_loss: 0.1758 - val_accuracy: 0.9481
#
# Epoch 00020: val_accuracy did not improve from 0.95000
# Epoch 21/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.0461 - accuracy: 0.9846 - val_loss: 0.1995 - val_accuracy: 0.9444
#
# Epoch 00021: val_accuracy did not improve from 0.95000
# Epoch 22/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.0388 - accuracy: 0.9866 - val_loss: 0.1836 - val_accuracy: 0.9370
#
# Epoch 00022: val_accuracy did not improve from 0.95000
# Epoch 23/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0314 - accuracy: 0.9905 - val_loss: 0.2059 - val_accuracy: 0.9407
#
# Epoch 00023: val_accuracy did not improve from 0.95000
# Epoch 24/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0261 - accuracy: 0.9936 - val_loss: 0.2178 - val_accuracy: 0.9352
#
# Epoch 00024: val_accuracy did not improve from 0.95000
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 25/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.0169 - accuracy: 0.9959 - val_loss: 0.2149 - val_accuracy: 0.9370
#
# Epoch 00025: val_accuracy did not improve from 0.95000
# Epoch 26/30
# 152/152 [==============================] - 4s 24ms/step - loss: 0.0123 - accuracy: 0.9977 - val_loss: 0.2209 - val_accuracy: 0.9352
#
# Epoch 00026: val_accuracy did not improve from 0.95000
# Epoch 27/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.0106 - accuracy: 0.9986 - val_loss: 0.2070 - val_accuracy: 0.9519
#
# Epoch 00027: val_accuracy improved from 0.95000 to 0.95185, saving model to ./models/tree_10/model_root_f1_1_1_1/folder4\model.h5
# Epoch 28/30
# 152/152 [==============================] - 4s 23ms/step - loss: 0.0079 - accuracy: 0.9986 - val_loss: 0.2296 - val_accuracy: 0.9481
#
# Epoch 00028: val_accuracy did not improve from 0.95185
# Epoch 29/30
# 152/152 [==============================] - 4s 24ms/step - loss: 0.0066 - accuracy: 0.9992 - val_loss: 0.2552 - val_accuracy: 0.9463
#
# Epoch 00029: val_accuracy did not improve from 0.95185
# Epoch 30/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0054 - accuracy: 0.9996 - val_loss: 0.2425 - val_accuracy: 0.9352
#
# Epoch 00030: val_accuracy did not improve from 0.95185
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 5
# Genre split [['Reggae'], ['Blues', 'Country', 'Hip-Hop', 'Pop', 'Rock']]
# Building model...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 152/152 [==============================] - 4s 23ms/step - loss: 0.4968 - accuracy: 0.8226 - val_loss: 0.4084 - val_accuracy: 0.8519
#
# Epoch 00001: val_accuracy improved from -inf to 0.85185, saving model to ./models/tree_10/model_root_f1_1_1_1/folder5\model.h5
# Epoch 2/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.4248 - accuracy: 0.8313 - val_loss: 0.3651 - val_accuracy: 0.8519
#
# Epoch 00002: val_accuracy did not improve from 0.85185
# Epoch 3/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.3849 - accuracy: 0.8379 - val_loss: 0.3509 - val_accuracy: 0.8463
#
# Epoch 00003: val_accuracy did not improve from 0.85185
# Epoch 4/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.3380 - accuracy: 0.8580 - val_loss: 0.3090 - val_accuracy: 0.8778
#
# Epoch 00004: val_accuracy improved from 0.85185 to 0.87778, saving model to ./models/tree_10/model_root_f1_1_1_1/folder5\model.h5
# Epoch 5/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.2432 - accuracy: 0.9105 - val_loss: 0.2613 - val_accuracy: 0.9000
#
# Epoch 00005: val_accuracy improved from 0.87778 to 0.90000, saving model to ./models/tree_10/model_root_f1_1_1_1/folder5\model.h5
# Epoch 6/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.1903 - accuracy: 0.9302 - val_loss: 0.2260 - val_accuracy: 0.9093
#
# Epoch 00006: val_accuracy improved from 0.90000 to 0.90926, saving model to ./models/tree_10/model_root_f1_1_1_1/folder5\model.h5
# Epoch 7/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.1523 - accuracy: 0.9471 - val_loss: 0.1911 - val_accuracy: 0.9278
#
# Epoch 00007: val_accuracy improved from 0.90926 to 0.92778, saving model to ./models/tree_10/model_root_f1_1_1_1/folder5\model.h5
# Epoch 8/30
# 152/152 [==============================] - 4s 23ms/step - loss: 0.1187 - accuracy: 0.9582 - val_loss: 0.1688 - val_accuracy: 0.9333
#
# Epoch 00008: val_accuracy improved from 0.92778 to 0.93333, saving model to ./models/tree_10/model_root_f1_1_1_1/folder5\model.h5
# Epoch 9/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.0866 - accuracy: 0.9679 - val_loss: 0.2116 - val_accuracy: 0.9278
#
# Epoch 00009: val_accuracy did not improve from 0.93333
# Epoch 10/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0675 - accuracy: 0.9753 - val_loss: 0.2558 - val_accuracy: 0.9222
#
# Epoch 00010: val_accuracy did not improve from 0.93333
# Epoch 11/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0473 - accuracy: 0.9835 - val_loss: 0.2601 - val_accuracy: 0.9111
#
# Epoch 00011: val_accuracy did not improve from 0.93333
# Epoch 12/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0372 - accuracy: 0.9858 - val_loss: 0.1636 - val_accuracy: 0.9463
#
# Epoch 00012: val_accuracy improved from 0.93333 to 0.94630, saving model to ./models/tree_10/model_root_f1_1_1_1/folder5\model.h5
# Epoch 13/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.0454 - accuracy: 0.9821 - val_loss: 0.2199 - val_accuracy: 0.9296
#
# Epoch 00013: val_accuracy did not improve from 0.94630
# Epoch 14/30
# 152/152 [==============================] - 4s 23ms/step - loss: 0.0161 - accuracy: 0.9953 - val_loss: 0.1964 - val_accuracy: 0.9444
#
# Epoch 00014: val_accuracy did not improve from 0.94630
# Epoch 15/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.0026 - accuracy: 0.9996 - val_loss: 0.1706 - val_accuracy: 0.9537
#
# Epoch 00015: val_accuracy improved from 0.94630 to 0.95370, saving model to ./models/tree_10/model_root_f1_1_1_1/folder5\model.h5
# Epoch 16/30
# 152/152 [==============================] - 3s 23ms/step - loss: 5.2273e-04 - accuracy: 1.0000 - val_loss: 0.1732 - val_accuracy: 0.9519
#
# Epoch 00016: val_accuracy did not improve from 0.95370
# Epoch 17/30
# 152/152 [==============================] - 3s 22ms/step - loss: 2.3602e-04 - accuracy: 1.0000 - val_loss: 0.1858 - val_accuracy: 0.9537
#
# Epoch 00017: val_accuracy did not improve from 0.95370
# Epoch 18/30
# 152/152 [==============================] - 3s 21ms/step - loss: 1.7333e-04 - accuracy: 1.0000 - val_loss: 0.1950 - val_accuracy: 0.9500
#
# Epoch 00018: val_accuracy did not improve from 0.95370
# Epoch 19/30
# 152/152 [==============================] - 3s 21ms/step - loss: 1.2905e-04 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 0.9519
#
# Epoch 00019: val_accuracy did not improve from 0.95370
# Epoch 20/30
# 152/152 [==============================] - 3s 21ms/step - loss: 1.0536e-04 - accuracy: 1.0000 - val_loss: 0.1948 - val_accuracy: 0.9519
#
# Epoch 00020: val_accuracy did not improve from 0.95370
# Epoch 21/30
# 152/152 [==============================] - 3s 21ms/step - loss: 8.8080e-05 - accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9500
#
# Epoch 00021: val_accuracy did not improve from 0.95370
# Epoch 22/30
# 152/152 [==============================] - 3s 22ms/step - loss: 7.4802e-05 - accuracy: 1.0000 - val_loss: 0.2010 - val_accuracy: 0.9519
#
# Epoch 00022: val_accuracy did not improve from 0.95370
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 23/30
# 152/152 [==============================] - 3s 23ms/step - loss: 6.4747e-05 - accuracy: 1.0000 - val_loss: 0.2061 - val_accuracy: 0.9500
#
# Epoch 00023: val_accuracy did not improve from 0.95370
# Epoch 24/30
# 152/152 [==============================] - 3s 22ms/step - loss: 6.0463e-05 - accuracy: 1.0000 - val_loss: 0.2092 - val_accuracy: 0.9500
#
# Epoch 00024: val_accuracy did not improve from 0.95370
# Epoch 25/30
# 152/152 [==============================] - 3s 21ms/step - loss: 5.5848e-05 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9500
#
# Epoch 00025: val_accuracy did not improve from 0.95370
# Epoch 26/30
# 152/152 [==============================] - 3s 22ms/step - loss: 5.1780e-05 - accuracy: 1.0000 - val_loss: 0.2090 - val_accuracy: 0.9500
#
# Epoch 00026: val_accuracy did not improve from 0.95370
# Epoch 27/30
# 152/152 [==============================] - 3s 21ms/step - loss: 4.7950e-05 - accuracy: 1.0000 - val_loss: 0.2131 - val_accuracy: 0.9500
#
# Epoch 00027: val_accuracy did not improve from 0.95370
# Epoch 28/30
# 152/152 [==============================] - 3s 21ms/step - loss: 4.4354e-05 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9500
#
# Epoch 00028: val_accuracy did not improve from 0.95370
# Epoch 29/30
# 152/152 [==============================] - 3s 21ms/step - loss: 4.1020e-05 - accuracy: 1.0000 - val_loss: 0.2172 - val_accuracy: 0.9500
#
# Epoch 00029: val_accuracy did not improve from 0.95370
# Epoch 30/30
# 152/152 [==============================] - 3s 22ms/step - loss: 3.7899e-05 - accuracy: 1.0000 - val_loss: 0.2135 - val_accuracy: 0.9500
#
# Epoch 00030: val_accuracy did not improve from 0.95370
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 6
# Genre split [['Rock'], ['Blues', 'Country', 'Hip-Hop', 'Pop', 'Reggae']]
# Building model...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 152/152 [==============================] - 4s 23ms/step - loss: 0.4737 - accuracy: 0.8307 - val_loss: 0.3844 - val_accuracy: 0.8537
#
# Epoch 00001: val_accuracy improved from -inf to 0.85370, saving model to ./models/tree_10/model_root_f1_1_1_1/folder6\model.h5
# Epoch 2/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.4026 - accuracy: 0.8362 - val_loss: 0.3418 - val_accuracy: 0.8704
#
# Epoch 00002: val_accuracy improved from 0.85370 to 0.87037, saving model to ./models/tree_10/model_root_f1_1_1_1/folder6\model.h5
# Epoch 3/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.3764 - accuracy: 0.8438 - val_loss: 0.3494 - val_accuracy: 0.8704
#
# Epoch 00003: val_accuracy did not improve from 0.87037
# Epoch 4/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.3618 - accuracy: 0.8549 - val_loss: 0.3209 - val_accuracy: 0.8796
#
# Epoch 00004: val_accuracy improved from 0.87037 to 0.87963, saving model to ./models/tree_10/model_root_f1_1_1_1/folder6\model.h5
# Epoch 5/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.3497 - accuracy: 0.8599 - val_loss: 0.3121 - val_accuracy: 0.8778
#
# Epoch 00005: val_accuracy did not improve from 0.87963
# Epoch 6/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.3485 - accuracy: 0.8531 - val_loss: 0.3054 - val_accuracy: 0.8741
#
# Epoch 00006: val_accuracy did not improve from 0.87963
# Epoch 7/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.3378 - accuracy: 0.8626 - val_loss: 0.3095 - val_accuracy: 0.8796
#
# Epoch 00007: val_accuracy did not improve from 0.87963
# Epoch 8/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.3191 - accuracy: 0.8665 - val_loss: 0.2836 - val_accuracy: 0.8870
#
# Epoch 00008: val_accuracy improved from 0.87963 to 0.88704, saving model to ./models/tree_10/model_root_f1_1_1_1/folder6\model.h5
# Epoch 9/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.2939 - accuracy: 0.8720 - val_loss: 0.3066 - val_accuracy: 0.8870
#
# Epoch 00009: val_accuracy did not improve from 0.88704
# Epoch 10/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.2736 - accuracy: 0.8825 - val_loss: 0.2675 - val_accuracy: 0.8907
#
# Epoch 00010: val_accuracy improved from 0.88704 to 0.89074, saving model to ./models/tree_10/model_root_f1_1_1_1/folder6\model.h5
# Epoch 11/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.2643 - accuracy: 0.8850 - val_loss: 0.2372 - val_accuracy: 0.9037
#
# Epoch 00011: val_accuracy improved from 0.89074 to 0.90370, saving model to ./models/tree_10/model_root_f1_1_1_1/folder6\model.h5
# Epoch 12/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.2466 - accuracy: 0.8949 - val_loss: 0.2499 - val_accuracy: 0.8926
#
# Epoch 00012: val_accuracy did not improve from 0.90370
# Epoch 13/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.2265 - accuracy: 0.9035 - val_loss: 0.2533 - val_accuracy: 0.9037
#
# Epoch 00013: val_accuracy did not improve from 0.90370
# Epoch 14/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.1920 - accuracy: 0.9208 - val_loss: 0.3421 - val_accuracy: 0.8870
#
# Epoch 00014: val_accuracy did not improve from 0.90370
# Epoch 15/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.1675 - accuracy: 0.9346 - val_loss: 0.2470 - val_accuracy: 0.9000
#
# Epoch 00015: val_accuracy did not improve from 0.90370
# Epoch 16/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.1384 - accuracy: 0.9459 - val_loss: 0.2101 - val_accuracy: 0.9241
#
# Epoch 00016: val_accuracy improved from 0.90370 to 0.92407, saving model to ./models/tree_10/model_root_f1_1_1_1/folder6\model.h5
# Epoch 17/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.1143 - accuracy: 0.9547 - val_loss: 0.2319 - val_accuracy: 0.9093
#
# Epoch 00017: val_accuracy did not improve from 0.92407
# Epoch 18/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0788 - accuracy: 0.9712 - val_loss: 0.2346 - val_accuracy: 0.9056
#
# Epoch 00018: val_accuracy did not improve from 0.92407
# Epoch 19/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0567 - accuracy: 0.9798 - val_loss: 0.2488 - val_accuracy: 0.9204
#
# Epoch 00019: val_accuracy did not improve from 0.92407
# Epoch 20/30
# 152/152 [==============================] - 3s 22ms/step - loss: 0.0272 - accuracy: 0.9930 - val_loss: 0.3216 - val_accuracy: 0.9222
#
# Epoch 00020: val_accuracy did not improve from 0.92407
# Epoch 21/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0195 - accuracy: 0.9936 - val_loss: 0.3356 - val_accuracy: 0.9111
#
# Epoch 00021: val_accuracy did not improve from 0.92407
# Epoch 22/30
# 152/152 [==============================] - 3s 20ms/step - loss: 0.0115 - accuracy: 0.9981 - val_loss: 0.3536 - val_accuracy: 0.9222
#
# Epoch 00022: val_accuracy did not improve from 0.92407
# Epoch 23/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0082 - accuracy: 0.9981 - val_loss: 0.2546 - val_accuracy: 0.9296
#
# Epoch 00023: val_accuracy improved from 0.92407 to 0.92963, saving model to ./models/tree_10/model_root_f1_1_1_1/folder6\model.h5
# Epoch 24/30
# 152/152 [==============================] - 3s 19ms/step - loss: 0.0472 - accuracy: 0.9827 - val_loss: 0.2646 - val_accuracy: 0.9074
#
# Epoch 00024: val_accuracy did not improve from 0.92963
# Epoch 25/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0199 - accuracy: 0.9936 - val_loss: 0.2956 - val_accuracy: 0.9241
#
# Epoch 00025: val_accuracy did not improve from 0.92963
# Epoch 26/30
# 152/152 [==============================] - 3s 21ms/step - loss: 0.0036 - accuracy: 0.9998 - val_loss: 0.3002 - val_accuracy: 0.9315
#
# Epoch 00026: val_accuracy improved from 0.92963 to 0.93148, saving model to ./models/tree_10/model_root_f1_1_1_1/folder6\model.h5
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 27/30
# 152/152 [==============================] - 3s 20ms/step - loss: 9.0622e-04 - accuracy: 1.0000 - val_loss: 0.3213 - val_accuracy: 0.9333
#
# Epoch 00027: val_accuracy improved from 0.93148 to 0.93333, saving model to ./models/tree_10/model_root_f1_1_1_1/folder6\model.h5
# Epoch 28/30
# 152/152 [==============================] - 3s 20ms/step - loss: 5.5001e-04 - accuracy: 1.0000 - val_loss: 0.3162 - val_accuracy: 0.9333
#
# Epoch 00028: val_accuracy did not improve from 0.93333
# Epoch 29/30
# 152/152 [==============================] - 3s 20ms/step - loss: 4.1859e-04 - accuracy: 1.0000 - val_loss: 0.3273 - val_accuracy: 0.9333
#
# Epoch 00029: val_accuracy did not improve from 0.93333
# Epoch 30/30
# 152/152 [==============================] - 3s 21ms/step - loss: 3.4050e-04 - accuracy: 1.0000 - val_loss: 0.3267 - val_accuracy: 0.9333
#
# Epoch 00030: val_accuracy did not improve from 0.93333
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
