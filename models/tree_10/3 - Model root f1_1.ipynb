# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Blues':0, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Pop':7, 'Reggae':8, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Blues', 2: 'Country', 3: 'Disco', 4: 'Hip-Hop', 5: 'Jazz', 7: 'Pop', 8: 'Reggae', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((6390, 128, 128), (6390, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((800, 128, 128), (800, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Disco

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation='softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_10/model_root_f1_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_10/model_root_f1_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 8
n_splits = 10

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    dict_genres_list = list(dict_genres.values())
    split = [[dict_genres_list.pop(fold_no - 1)], dict_genres_list]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Blues'], ['Country', 'Disco', 'Hip-Hop', 'Jazz', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 203/203 [==============================] - 8s 23ms/step - loss: 0.4353 - accuracy: 0.8665 - val_loss: 0.3809 - val_accuracy: 0.8720
#
# Epoch 00001: val_accuracy improved from -inf to 0.87204, saving model to ./models/tree_10/model_root_f1_1/folder1\model.h5
# Epoch 2/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.3632 - accuracy: 0.8758 - val_loss: 0.3510 - val_accuracy: 0.8720
#
# Epoch 00002: val_accuracy did not improve from 0.87204
# Epoch 3/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.3234 - accuracy: 0.8768 - val_loss: 0.2919 - val_accuracy: 0.8776
#
# Epoch 00003: val_accuracy improved from 0.87204 to 0.87761, saving model to ./models/tree_10/model_root_f1_1/folder1\model.h5
# Epoch 4/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.2777 - accuracy: 0.8869 - val_loss: 0.3345 - val_accuracy: 0.8720
#
# Epoch 00004: val_accuracy did not improve from 0.87761
# Epoch 5/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.2374 - accuracy: 0.9026 - val_loss: 0.2245 - val_accuracy: 0.8985
#
# Epoch 00005: val_accuracy improved from 0.87761 to 0.89847, saving model to ./models/tree_10/model_root_f1_1/folder1\model.h5
# Epoch 6/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.2107 - accuracy: 0.9098 - val_loss: 0.2404 - val_accuracy: 0.8943
#
# Epoch 00006: val_accuracy did not improve from 0.89847
# Epoch 7/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1881 - accuracy: 0.9243 - val_loss: 0.2303 - val_accuracy: 0.8985
#
# Epoch 00007: val_accuracy did not improve from 0.89847
# Epoch 8/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1566 - accuracy: 0.9396 - val_loss: 0.1893 - val_accuracy: 0.9193
#
# Epoch 00008: val_accuracy improved from 0.89847 to 0.91933, saving model to ./models/tree_10/model_root_f1_1/folder1\model.h5
# Epoch 9/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1400 - accuracy: 0.9434 - val_loss: 0.2061 - val_accuracy: 0.9166
#
# Epoch 00009: val_accuracy did not improve from 0.91933
# Epoch 10/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1318 - accuracy: 0.9479 - val_loss: 0.1959 - val_accuracy: 0.9152
#
# Epoch 00010: val_accuracy did not improve from 0.91933
# Epoch 11/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0986 - accuracy: 0.9607 - val_loss: 0.2232 - val_accuracy: 0.9082
#
# Epoch 00011: val_accuracy did not improve from 0.91933
# Epoch 12/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0874 - accuracy: 0.9654 - val_loss: 0.1960 - val_accuracy: 0.9152
#
# Epoch 00012: val_accuracy did not improve from 0.91933
# Epoch 13/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0673 - accuracy: 0.9733 - val_loss: 0.1827 - val_accuracy: 0.9179
#
# Epoch 00013: val_accuracy did not improve from 0.91933
# Epoch 14/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0596 - accuracy: 0.9782 - val_loss: 0.1826 - val_accuracy: 0.9346
#
# Epoch 00014: val_accuracy improved from 0.91933 to 0.93463, saving model to ./models/tree_10/model_root_f1_1/folder1\model.h5
# Epoch 15/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0458 - accuracy: 0.9832 - val_loss: 0.1966 - val_accuracy: 0.9263
#
# Epoch 00015: val_accuracy did not improve from 0.93463
# Epoch 16/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0332 - accuracy: 0.9892 - val_loss: 0.1844 - val_accuracy: 0.9346
#
# Epoch 00016: val_accuracy did not improve from 0.93463
# Epoch 17/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0174 - accuracy: 0.9946 - val_loss: 0.2069 - val_accuracy: 0.9277
#
# Epoch 00017: val_accuracy did not improve from 0.93463
# Epoch 18/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0124 - accuracy: 0.9963 - val_loss: 0.2179 - val_accuracy: 0.9318
#
# Epoch 00018: val_accuracy did not improve from 0.93463
# Epoch 19/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0404 - accuracy: 0.9847 - val_loss: 0.1891 - val_accuracy: 0.9471
#
# Epoch 00019: val_accuracy improved from 0.93463 to 0.94715, saving model to ./models/tree_10/model_root_f1_1/folder1\model.h5
# Epoch 20/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0162 - accuracy: 0.9955 - val_loss: 0.2281 - val_accuracy: 0.9263
#
# Epoch 00020: val_accuracy did not improve from 0.94715
# Epoch 21/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0176 - accuracy: 0.9932 - val_loss: 0.2906 - val_accuracy: 0.9360
#
# Epoch 00021: val_accuracy did not improve from 0.94715
# Epoch 22/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0137 - accuracy: 0.9955 - val_loss: 0.3389 - val_accuracy: 0.9249
#
# Epoch 00022: val_accuracy did not improve from 0.94715
# Epoch 23/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0137 - accuracy: 0.9952 - val_loss: 0.3382 - val_accuracy: 0.9110
#
# Epoch 00023: val_accuracy did not improve from 0.94715
# Epoch 24/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0218 - accuracy: 0.9917 - val_loss: 0.2814 - val_accuracy: 0.9360
#
# Epoch 00024: val_accuracy did not improve from 0.94715
# Epoch 25/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.2606 - val_accuracy: 0.9235
#
# Epoch 00025: val_accuracy did not improve from 0.94715
# Epoch 26/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0072 - accuracy: 0.9980 - val_loss: 0.3933 - val_accuracy: 0.9277
#
# Epoch 00026: val_accuracy did not improve from 0.94715
# Epoch 27/30
# 203/203 [==============================] - 4s 21ms/step - loss: 0.0134 - accuracy: 0.9955 - val_loss: 0.3234 - val_accuracy: 0.9291
#
# Epoch 00027: val_accuracy did not improve from 0.94715
# Epoch 28/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0669 - accuracy: 0.9785 - val_loss: 0.2993 - val_accuracy: 0.9277
#
# Epoch 00028: val_accuracy did not improve from 0.94715
# Epoch 29/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0137 - accuracy: 0.9952 - val_loss: 0.2725 - val_accuracy: 0.9402
#
# Epoch 00029: val_accuracy did not improve from 0.94715
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 30/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.2194 - val_accuracy: 0.9471
#
# Epoch 00030: val_accuracy did not improve from 0.94715
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Country'], ['Blues', 'Disco', 'Hip-Hop', 'Jazz', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 203/203 [==============================] - 5s 21ms/step - loss: 0.3406 - accuracy: 0.8745 - val_loss: 0.3361 - val_accuracy: 0.8665
#
# Epoch 00001: val_accuracy improved from -inf to 0.86648, saving model to ./models/tree_10/model_root_f1_1/folder2\model.h5
# Epoch 2/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.2660 - accuracy: 0.8895 - val_loss: 0.3077 - val_accuracy: 0.8693
#
# Epoch 00002: val_accuracy improved from 0.86648 to 0.86926, saving model to ./models/tree_10/model_root_f1_1/folder2\model.h5
# Epoch 3/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.2340 - accuracy: 0.8994 - val_loss: 0.2451 - val_accuracy: 0.8846
#
# Epoch 00003: val_accuracy improved from 0.86926 to 0.88456, saving model to ./models/tree_10/model_root_f1_1/folder2\model.h5
# Epoch 4/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1931 - accuracy: 0.9184 - val_loss: 0.2156 - val_accuracy: 0.9110
#
# Epoch 00004: val_accuracy improved from 0.88456 to 0.91099, saving model to ./models/tree_10/model_root_f1_1/folder2\model.h5
# Epoch 5/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.1583 - accuracy: 0.9379 - val_loss: 0.2223 - val_accuracy: 0.9054
#
# Epoch 00005: val_accuracy did not improve from 0.91099
# Epoch 6/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1303 - accuracy: 0.9481 - val_loss: 0.2163 - val_accuracy: 0.9207
#
# Epoch 00006: val_accuracy improved from 0.91099 to 0.92072, saving model to ./models/tree_10/model_root_f1_1/folder2\model.h5
# Epoch 7/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1063 - accuracy: 0.9580 - val_loss: 0.2205 - val_accuracy: 0.9082
#
# Epoch 00007: val_accuracy did not improve from 0.92072
# Epoch 8/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.0669 - accuracy: 0.9743 - val_loss: 0.2310 - val_accuracy: 0.9277
#
# Epoch 00008: val_accuracy improved from 0.92072 to 0.92768, saving model to ./models/tree_10/model_root_f1_1/folder2\model.h5
# Epoch 9/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0500 - accuracy: 0.9801 - val_loss: 0.2321 - val_accuracy: 0.9388
#
# Epoch 00009: val_accuracy improved from 0.92768 to 0.93880, saving model to ./models/tree_10/model_root_f1_1/folder2\model.h5
# Epoch 10/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0344 - accuracy: 0.9866 - val_loss: 0.2993 - val_accuracy: 0.9263
#
# Epoch 00010: val_accuracy did not improve from 0.93880
# Epoch 11/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.0193 - accuracy: 0.9920 - val_loss: 0.3697 - val_accuracy: 0.9291
#
# Epoch 00011: val_accuracy did not improve from 0.93880
# Epoch 12/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.0372 - accuracy: 0.9862 - val_loss: 0.3287 - val_accuracy: 0.8971
#
# Epoch 00012: val_accuracy did not improve from 0.93880
# Epoch 13/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.0239 - accuracy: 0.9909 - val_loss: 0.3520 - val_accuracy: 0.9179
#
# Epoch 00013: val_accuracy did not improve from 0.93880
# Epoch 14/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0254 - accuracy: 0.9898 - val_loss: 0.4059 - val_accuracy: 0.9305
#
# Epoch 00014: val_accuracy did not improve from 0.93880
# Epoch 15/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.0262 - accuracy: 0.9896 - val_loss: 0.4323 - val_accuracy: 0.9207
#
# Epoch 00015: val_accuracy did not improve from 0.93880
# Epoch 16/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.0284 - accuracy: 0.9904 - val_loss: 0.3560 - val_accuracy: 0.9277
#
# Epoch 00016: val_accuracy did not improve from 0.93880
# Epoch 17/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.4235 - val_accuracy: 0.9305
#
# Epoch 00017: val_accuracy did not improve from 0.93880
# Epoch 18/30
# 203/203 [==============================] - 4s 20ms/step - loss: 2.5504e-04 - accuracy: 1.0000 - val_loss: 0.4296 - val_accuracy: 0.9305
#
# Epoch 00018: val_accuracy did not improve from 0.93880
# Epoch 19/30
# 203/203 [==============================] - 4s 19ms/step - loss: 9.0921e-05 - accuracy: 1.0000 - val_loss: 0.4408 - val_accuracy: 0.9305
#
# Epoch 00019: val_accuracy did not improve from 0.93880
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/30
# 203/203 [==============================] - 4s 19ms/step - loss: 6.8676e-05 - accuracy: 1.0000 - val_loss: 0.4480 - val_accuracy: 0.9305
#
# Epoch 00020: val_accuracy did not improve from 0.93880
# Epoch 21/30
# 203/203 [==============================] - 4s 20ms/step - loss: 6.0248e-05 - accuracy: 1.0000 - val_loss: 0.4550 - val_accuracy: 0.9305
#
# Epoch 00021: val_accuracy did not improve from 0.93880
# Epoch 22/30
# 203/203 [==============================] - 4s 20ms/step - loss: 5.3395e-05 - accuracy: 1.0000 - val_loss: 0.4591 - val_accuracy: 0.9305
#
# Epoch 00022: val_accuracy did not improve from 0.93880
# Epoch 23/30
# 203/203 [==============================] - 4s 19ms/step - loss: 4.7376e-05 - accuracy: 1.0000 - val_loss: 0.4628 - val_accuracy: 0.9305
#
# Epoch 00023: val_accuracy did not improve from 0.93880
# Epoch 24/30
# 203/203 [==============================] - 4s 19ms/step - loss: 4.2164e-05 - accuracy: 1.0000 - val_loss: 0.4650 - val_accuracy: 0.9291
#
# Epoch 00024: val_accuracy did not improve from 0.93880
# Epoch 25/30
# 203/203 [==============================] - 4s 19ms/step - loss: 3.7403e-05 - accuracy: 1.0000 - val_loss: 0.4703 - val_accuracy: 0.9305
#
# Epoch 00025: val_accuracy did not improve from 0.93880
# Epoch 26/30
# 203/203 [==============================] - 4s 20ms/step - loss: 3.3084e-05 - accuracy: 1.0000 - val_loss: 0.4714 - val_accuracy: 0.9318
#
# Epoch 00026: val_accuracy did not improve from 0.93880
# Epoch 27/30
# 203/203 [==============================] - 4s 19ms/step - loss: 2.9264e-05 - accuracy: 1.0000 - val_loss: 0.4783 - val_accuracy: 0.9305
#
# Epoch 00027: val_accuracy did not improve from 0.93880
# Epoch 28/30
# 203/203 [==============================] - 4s 20ms/step - loss: 2.5938e-05 - accuracy: 1.0000 - val_loss: 0.4805 - val_accuracy: 0.9305
#
# Epoch 00028: val_accuracy did not improve from 0.93880
# Epoch 29/30
# 203/203 [==============================] - 4s 19ms/step - loss: 2.2796e-05 - accuracy: 1.0000 - val_loss: 0.4833 - val_accuracy: 0.9305
#
# Epoch 00029: val_accuracy did not improve from 0.93880
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 30/30
# 203/203 [==============================] - 4s 20ms/step - loss: 2.0183e-05 - accuracy: 1.0000 - val_loss: 0.4842 - val_accuracy: 0.9291
#
# Epoch 00030: val_accuracy did not improve from 0.93880
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Disco'], ['Blues', 'Country', 'Hip-Hop', 'Jazz', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 203/203 [==============================] - 5s 21ms/step - loss: 0.5085 - accuracy: 0.8646 - val_loss: 0.3560 - val_accuracy: 0.8748
#
# Epoch 00001: val_accuracy improved from -inf to 0.87483, saving model to ./models/tree_10/model_root_f1_1/folder3\model.h5
# Epoch 2/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.3540 - accuracy: 0.8747 - val_loss: 0.3424 - val_accuracy: 0.8748
#
# Epoch 00002: val_accuracy did not improve from 0.87483
# Epoch 3/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.3404 - accuracy: 0.8750 - val_loss: 0.3184 - val_accuracy: 0.8748
#
# Epoch 00003: val_accuracy did not improve from 0.87483
# Epoch 4/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.3171 - accuracy: 0.8744 - val_loss: 0.3503 - val_accuracy: 0.8748
#
# Epoch 00004: val_accuracy did not improve from 0.87483
# Epoch 5/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.2804 - accuracy: 0.8841 - val_loss: 0.2501 - val_accuracy: 0.9068
#
# Epoch 00005: val_accuracy improved from 0.87483 to 0.90681, saving model to ./models/tree_10/model_root_f1_1/folder3\model.h5
# Epoch 6/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.2340 - accuracy: 0.9056 - val_loss: 0.2877 - val_accuracy: 0.8971
#
# Epoch 00006: val_accuracy did not improve from 0.90681
# Epoch 7/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.2096 - accuracy: 0.9198 - val_loss: 0.1776 - val_accuracy: 0.9346
#
# Epoch 00007: val_accuracy improved from 0.90681 to 0.93463, saving model to ./models/tree_10/model_root_f1_1/folder3\model.h5
# Epoch 8/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1745 - accuracy: 0.9342 - val_loss: 0.1754 - val_accuracy: 0.9416
#
# Epoch 00008: val_accuracy improved from 0.93463 to 0.94159, saving model to ./models/tree_10/model_root_f1_1/folder3\model.h5
# Epoch 9/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.1545 - accuracy: 0.9473 - val_loss: 0.1832 - val_accuracy: 0.9360
#
# Epoch 00009: val_accuracy did not improve from 0.94159
# Epoch 10/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1329 - accuracy: 0.9512 - val_loss: 0.1608 - val_accuracy: 0.9388
#
# Epoch 00010: val_accuracy did not improve from 0.94159
# Epoch 11/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0959 - accuracy: 0.9692 - val_loss: 0.1434 - val_accuracy: 0.9402
#
# Epoch 00011: val_accuracy did not improve from 0.94159
# Epoch 12/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0874 - accuracy: 0.9705 - val_loss: 0.1496 - val_accuracy: 0.9360
#
# Epoch 00012: val_accuracy did not improve from 0.94159
# Epoch 13/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0721 - accuracy: 0.9748 - val_loss: 0.1550 - val_accuracy: 0.9527
#
# Epoch 00013: val_accuracy improved from 0.94159 to 0.95271, saving model to ./models/tree_10/model_root_f1_1/folder3\model.h5
# Epoch 14/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0599 - accuracy: 0.9781 - val_loss: 0.1260 - val_accuracy: 0.9485
#
# Epoch 00014: val_accuracy did not improve from 0.95271
# Epoch 15/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0374 - accuracy: 0.9879 - val_loss: 0.1530 - val_accuracy: 0.9471
#
# Epoch 00015: val_accuracy did not improve from 0.95271
# Epoch 16/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0204 - accuracy: 0.9930 - val_loss: 0.1572 - val_accuracy: 0.9527
#
# Epoch 00016: val_accuracy did not improve from 0.95271
# Epoch 17/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.0221 - accuracy: 0.9926 - val_loss: 0.1626 - val_accuracy: 0.9499
#
# Epoch 00017: val_accuracy did not improve from 0.95271
# Epoch 18/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.0180 - accuracy: 0.9940 - val_loss: 0.2308 - val_accuracy: 0.9541
#
# Epoch 00018: val_accuracy improved from 0.95271 to 0.95410, saving model to ./models/tree_10/model_root_f1_1/folder3\model.h5
# Epoch 19/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0197 - accuracy: 0.9930 - val_loss: 0.2681 - val_accuracy: 0.9388
#
# Epoch 00019: val_accuracy did not improve from 0.95410
# Epoch 20/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.0136 - accuracy: 0.9951 - val_loss: 0.1740 - val_accuracy: 0.9527
#
# Epoch 00020: val_accuracy did not improve from 0.95410
# Epoch 21/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.0138 - accuracy: 0.9961 - val_loss: 0.2883 - val_accuracy: 0.9513
#
# Epoch 00021: val_accuracy did not improve from 0.95410
# Epoch 22/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.0320 - accuracy: 0.9892 - val_loss: 0.2240 - val_accuracy: 0.9513
#
# Epoch 00022: val_accuracy did not improve from 0.95410
# Epoch 23/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.0148 - accuracy: 0.9947 - val_loss: 0.2795 - val_accuracy: 0.9527
#
# Epoch 00023: val_accuracy did not improve from 0.95410
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 24/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.1901 - val_accuracy: 0.9527
#
# Epoch 00024: val_accuracy did not improve from 0.95410
# Epoch 25/30
# 203/203 [==============================] - 4s 20ms/step - loss: 5.2407e-04 - accuracy: 1.0000 - val_loss: 0.2009 - val_accuracy: 0.9569
#
# Epoch 00025: val_accuracy improved from 0.95410 to 0.95688, saving model to ./models/tree_10/model_root_f1_1/folder3\model.h5
# Epoch 26/30
# 203/203 [==============================] - 4s 19ms/step - loss: 2.6111e-04 - accuracy: 1.0000 - val_loss: 0.1985 - val_accuracy: 0.9569
#
# Epoch 00026: val_accuracy did not improve from 0.95688
# Epoch 27/30
# 203/203 [==============================] - 4s 20ms/step - loss: 1.9924e-04 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9569
#
# Epoch 00027: val_accuracy did not improve from 0.95688
# Epoch 28/30
# 203/203 [==============================] - 4s 20ms/step - loss: 1.6035e-04 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.9569
#
# Epoch 00028: val_accuracy did not improve from 0.95688
# Epoch 29/30
# 203/203 [==============================] - 4s 19ms/step - loss: 1.3212e-04 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9555
#
# Epoch 00029: val_accuracy did not improve from 0.95688
# Epoch 30/30
# 203/203 [==============================] - 4s 19ms/step - loss: 1.1251e-04 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9555
#
# Epoch 00030: val_accuracy did not improve from 0.95688
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Hip-Hop'], ['Blues', 'Country', 'Disco', 'Jazz', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 203/203 [==============================] - 5s 21ms/step - loss: 0.3712 - accuracy: 0.8643 - val_loss: 0.2615 - val_accuracy: 0.8860
#
# Epoch 00001: val_accuracy improved from -inf to 0.88595, saving model to ./models/tree_10/model_root_f1_1/folder4\model.h5
# Epoch 2/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.2633 - accuracy: 0.8835 - val_loss: 0.2371 - val_accuracy: 0.9054
#
# Epoch 00002: val_accuracy improved from 0.88595 to 0.90542, saving model to ./models/tree_10/model_root_f1_1/folder4\model.h5
# Epoch 3/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.2287 - accuracy: 0.9081 - val_loss: 0.1815 - val_accuracy: 0.9318
#
# Epoch 00003: val_accuracy improved from 0.90542 to 0.93185, saving model to ./models/tree_10/model_root_f1_1/folder4\model.h5
# Epoch 4/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.1799 - accuracy: 0.9281 - val_loss: 0.1585 - val_accuracy: 0.9374
#
# Epoch 00004: val_accuracy improved from 0.93185 to 0.93741, saving model to ./models/tree_10/model_root_f1_1/folder4\model.h5
# Epoch 5/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1516 - accuracy: 0.9382 - val_loss: 0.1417 - val_accuracy: 0.9430
#
# Epoch 00005: val_accuracy improved from 0.93741 to 0.94298, saving model to ./models/tree_10/model_root_f1_1/folder4\model.h5
# Epoch 6/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1113 - accuracy: 0.9544 - val_loss: 0.1371 - val_accuracy: 0.9471
#
# Epoch 00006: val_accuracy improved from 0.94298 to 0.94715, saving model to ./models/tree_10/model_root_f1_1/folder4\model.h5
# Epoch 7/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.0924 - accuracy: 0.9638 - val_loss: 0.2142 - val_accuracy: 0.9054
#
# Epoch 00007: val_accuracy did not improve from 0.94715
# Epoch 8/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.0600 - accuracy: 0.9774 - val_loss: 0.2174 - val_accuracy: 0.9444
#
# Epoch 00008: val_accuracy did not improve from 0.94715
# Epoch 9/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.0474 - accuracy: 0.9838 - val_loss: 0.1499 - val_accuracy: 0.9513
#
# Epoch 00009: val_accuracy improved from 0.94715 to 0.95132, saving model to ./models/tree_10/model_root_f1_1/folder4\model.h5
# Epoch 10/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.0177 - accuracy: 0.9947 - val_loss: 0.1595 - val_accuracy: 0.9597
#
# Epoch 00010: val_accuracy improved from 0.95132 to 0.95967, saving model to ./models/tree_10/model_root_f1_1/folder4\model.h5
# Epoch 11/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0070 - accuracy: 0.9981 - val_loss: 0.1784 - val_accuracy: 0.9638
#
# Epoch 00011: val_accuracy improved from 0.95967 to 0.96384, saving model to ./models/tree_10/model_root_f1_1/folder4\model.h5
# Epoch 12/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0381 - accuracy: 0.9841 - val_loss: 0.3496 - val_accuracy: 0.9193
#
# Epoch 00012: val_accuracy did not improve from 0.96384
# Epoch 13/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0153 - accuracy: 0.9951 - val_loss: 0.1576 - val_accuracy: 0.9541
#
# Epoch 00013: val_accuracy did not improve from 0.96384
# Epoch 14/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2312 - val_accuracy: 0.9597
#
# Epoch 00014: val_accuracy did not improve from 0.96384
# Epoch 15/30
# 203/203 [==============================] - 4s 20ms/step - loss: 2.7817e-04 - accuracy: 1.0000 - val_loss: 0.2362 - val_accuracy: 0.9583
#
# Epoch 00015: val_accuracy did not improve from 0.96384
# Epoch 16/30
# 203/203 [==============================] - 4s 20ms/step - loss: 1.1918e-04 - accuracy: 1.0000 - val_loss: 0.2342 - val_accuracy: 0.9569
#
# Epoch 00016: val_accuracy did not improve from 0.96384
# Epoch 17/30
# 203/203 [==============================] - 4s 20ms/step - loss: 7.9113e-05 - accuracy: 1.0000 - val_loss: 0.2423 - val_accuracy: 0.9555
#
# Epoch 00017: val_accuracy did not improve from 0.96384
# Epoch 18/30
# 203/203 [==============================] - 4s 19ms/step - loss: 5.5370e-05 - accuracy: 1.0000 - val_loss: 0.2581 - val_accuracy: 0.9583
#
# Epoch 00018: val_accuracy did not improve from 0.96384
# Epoch 19/30
# 203/203 [==============================] - 4s 19ms/step - loss: 4.0754e-05 - accuracy: 1.0000 - val_loss: 0.2685 - val_accuracy: 0.9583
#
# Epoch 00019: val_accuracy did not improve from 0.96384
# Epoch 20/30
# 203/203 [==============================] - 4s 19ms/step - loss: 3.2077e-05 - accuracy: 1.0000 - val_loss: 0.2722 - val_accuracy: 0.9583
#
# Epoch 00020: val_accuracy did not improve from 0.96384
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/30
# 203/203 [==============================] - 4s 20ms/step - loss: 2.5887e-05 - accuracy: 1.0000 - val_loss: 0.2795 - val_accuracy: 0.9583
#
# Epoch 00021: val_accuracy did not improve from 0.96384
# Epoch 22/30
# 203/203 [==============================] - 4s 19ms/step - loss: 2.3092e-05 - accuracy: 1.0000 - val_loss: 0.2840 - val_accuracy: 0.9597
#
# Epoch 00022: val_accuracy did not improve from 0.96384
# Epoch 23/30
# 203/203 [==============================] - 4s 20ms/step - loss: 2.0854e-05 - accuracy: 1.0000 - val_loss: 0.2864 - val_accuracy: 0.9583
#
# Epoch 00023: val_accuracy did not improve from 0.96384
# Epoch 24/30
# 203/203 [==============================] - 4s 20ms/step - loss: 1.8713e-05 - accuracy: 1.0000 - val_loss: 0.2856 - val_accuracy: 0.9569
#
# Epoch 00024: val_accuracy did not improve from 0.96384
# Epoch 25/30
# 203/203 [==============================] - 4s 20ms/step - loss: 1.6835e-05 - accuracy: 1.0000 - val_loss: 0.2936 - val_accuracy: 0.9569
#
# Epoch 00025: val_accuracy did not improve from 0.96384
# Epoch 26/30
# 203/203 [==============================] - 4s 19ms/step - loss: 1.5142e-05 - accuracy: 1.0000 - val_loss: 0.2966 - val_accuracy: 0.9583
#
# Epoch 00026: val_accuracy did not improve from 0.96384
# Epoch 27/30
# 203/203 [==============================] - 4s 19ms/step - loss: 1.3605e-05 - accuracy: 1.0000 - val_loss: 0.2970 - val_accuracy: 0.9583
#
# Epoch 00027: val_accuracy did not improve from 0.96384
# Epoch 28/30
# 203/203 [==============================] - 4s 19ms/step - loss: 1.2246e-05 - accuracy: 1.0000 - val_loss: 0.3010 - val_accuracy: 0.9583
#
# Epoch 00028: val_accuracy did not improve from 0.96384
# Epoch 29/30
# 203/203 [==============================] - 4s 20ms/step - loss: 1.0925e-05 - accuracy: 1.0000 - val_loss: 0.2989 - val_accuracy: 0.9569
#
# Epoch 00029: val_accuracy did not improve from 0.96384
# Epoch 30/30
# 203/203 [==============================] - 4s 19ms/step - loss: 9.8783e-06 - accuracy: 1.0000 - val_loss: 0.3003 - val_accuracy: 0.9569
#
# Epoch 00030: val_accuracy did not improve from 0.96384
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 5
# Genre split [['Jazz'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 203/203 [==============================] - 5s 21ms/step - loss: 0.3722 - accuracy: 0.8782 - val_loss: 0.2703 - val_accuracy: 0.8943
#
# Epoch 00001: val_accuracy improved from -inf to 0.89430, saving model to ./models/tree_10/model_root_f1_1/folder5\model.h5
# Epoch 2/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.2290 - accuracy: 0.9034 - val_loss: 0.1689 - val_accuracy: 0.9346
#
# Epoch 00002: val_accuracy improved from 0.89430 to 0.93463, saving model to ./models/tree_10/model_root_f1_1/folder5\model.h5
# Epoch 3/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1603 - accuracy: 0.9331 - val_loss: 0.1286 - val_accuracy: 0.9555
#
# Epoch 00003: val_accuracy improved from 0.93463 to 0.95549, saving model to ./models/tree_10/model_root_f1_1/folder5\model.h5
# Epoch 4/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1214 - accuracy: 0.9513 - val_loss: 0.1269 - val_accuracy: 0.9555
#
# Epoch 00004: val_accuracy did not improve from 0.95549
# Epoch 5/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.0853 - accuracy: 0.9654 - val_loss: 0.1180 - val_accuracy: 0.9624
#
# Epoch 00005: val_accuracy improved from 0.95549 to 0.96245, saving model to ./models/tree_10/model_root_f1_1/folder5\model.h5
# Epoch 6/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0788 - accuracy: 0.9705 - val_loss: 0.1163 - val_accuracy: 0.9597
#
# Epoch 00006: val_accuracy did not improve from 0.96245
# Epoch 7/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0745 - accuracy: 0.9705 - val_loss: 0.1387 - val_accuracy: 0.9444
#
# Epoch 00007: val_accuracy did not improve from 0.96245
# Epoch 8/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0398 - accuracy: 0.9858 - val_loss: 0.0987 - val_accuracy: 0.9624
#
# Epoch 00008: val_accuracy did not improve from 0.96245
# Epoch 9/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0326 - accuracy: 0.9862 - val_loss: 0.1035 - val_accuracy: 0.9722
#
# Epoch 00009: val_accuracy improved from 0.96245 to 0.97218, saving model to ./models/tree_10/model_root_f1_1/folder5\model.h5
# Epoch 10/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0279 - accuracy: 0.9892 - val_loss: 0.0978 - val_accuracy: 0.9666
#
# Epoch 00010: val_accuracy did not improve from 0.97218
# Epoch 11/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.0201 - accuracy: 0.9932 - val_loss: 0.1202 - val_accuracy: 0.9555
#
# Epoch 00011: val_accuracy did not improve from 0.97218
# Epoch 12/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0153 - accuracy: 0.9957 - val_loss: 0.1071 - val_accuracy: 0.9638
#
# Epoch 00012: val_accuracy did not improve from 0.97218
# Epoch 13/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.0862 - val_accuracy: 0.9750
#
# Epoch 00013: val_accuracy improved from 0.97218 to 0.97497, saving model to ./models/tree_10/model_root_f1_1/folder5\model.h5
# Epoch 14/30
# 203/203 [==============================] - 4s 20ms/step - loss: 4.0973e-04 - accuracy: 1.0000 - val_loss: 0.0984 - val_accuracy: 0.9791
#
# Epoch 00014: val_accuracy improved from 0.97497 to 0.97914, saving model to ./models/tree_10/model_root_f1_1/folder5\model.h5
# Epoch 15/30
# 203/203 [==============================] - 4s 20ms/step - loss: 1.6894e-04 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 0.9791
#
# Epoch 00015: val_accuracy did not improve from 0.97914
# Epoch 16/30
# 203/203 [==============================] - 4s 19ms/step - loss: 1.1714e-04 - accuracy: 1.0000 - val_loss: 0.1089 - val_accuracy: 0.9791
#
# Epoch 00016: val_accuracy did not improve from 0.97914
# Epoch 17/30
# 203/203 [==============================] - 4s 20ms/step - loss: 8.8663e-05 - accuracy: 1.0000 - val_loss: 0.1140 - val_accuracy: 0.9805
#
# Epoch 00017: val_accuracy improved from 0.97914 to 0.98053, saving model to ./models/tree_10/model_root_f1_1/folder5\model.h5
# Epoch 18/30
# 203/203 [==============================] - 4s 20ms/step - loss: 6.8245e-05 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9805
#
# Epoch 00018: val_accuracy did not improve from 0.98053
# Epoch 19/30
# 203/203 [==============================] - 4s 20ms/step - loss: 5.3953e-05 - accuracy: 1.0000 - val_loss: 0.1180 - val_accuracy: 0.9819
#
# Epoch 00019: val_accuracy improved from 0.98053 to 0.98192, saving model to ./models/tree_10/model_root_f1_1/folder5\model.h5
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/30
# 203/203 [==============================] - 4s 21ms/step - loss: 4.3542e-05 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 0.9819
#
# Epoch 00020: val_accuracy did not improve from 0.98192
# Epoch 21/30
# 203/203 [==============================] - 4s 20ms/step - loss: 3.9257e-05 - accuracy: 1.0000 - val_loss: 0.1210 - val_accuracy: 0.9819
#
# Epoch 00021: val_accuracy did not improve from 0.98192
# Epoch 22/30
# 203/203 [==============================] - 4s 20ms/step - loss: 3.5139e-05 - accuracy: 1.0000 - val_loss: 0.1211 - val_accuracy: 0.9819
#
# Epoch 00022: val_accuracy did not improve from 0.98192
# Epoch 23/30
# 203/203 [==============================] - 4s 20ms/step - loss: 3.1824e-05 - accuracy: 1.0000 - val_loss: 0.1235 - val_accuracy: 0.9819
#
# Epoch 00023: val_accuracy did not improve from 0.98192
# Epoch 24/30
# 203/203 [==============================] - 4s 20ms/step - loss: 2.8522e-05 - accuracy: 1.0000 - val_loss: 0.1266 - val_accuracy: 0.9805
#
# Epoch 00024: val_accuracy did not improve from 0.98192
# Epoch 25/30
# 203/203 [==============================] - 4s 20ms/step - loss: 2.5331e-05 - accuracy: 1.0000 - val_loss: 0.1282 - val_accuracy: 0.9805
#
# Epoch 00025: val_accuracy did not improve from 0.98192
# Epoch 26/30
# 203/203 [==============================] - 4s 20ms/step - loss: 2.2762e-05 - accuracy: 1.0000 - val_loss: 0.1282 - val_accuracy: 0.9819
#
# Epoch 00026: val_accuracy did not improve from 0.98192
# Epoch 27/30
# 203/203 [==============================] - 4s 20ms/step - loss: 2.0184e-05 - accuracy: 1.0000 - val_loss: 0.1296 - val_accuracy: 0.9805
#
# Epoch 00027: val_accuracy did not improve from 0.98192
# Epoch 28/30
# 203/203 [==============================] - 4s 20ms/step - loss: 1.8239e-05 - accuracy: 1.0000 - val_loss: 0.1324 - val_accuracy: 0.9805
#
# Epoch 00028: val_accuracy did not improve from 0.98192
# Epoch 29/30
# 203/203 [==============================] - 4s 20ms/step - loss: 1.6162e-05 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9791
#
# Epoch 00029: val_accuracy did not improve from 0.98192
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 30/30
# 203/203 [==============================] - 4s 20ms/step - loss: 1.4263e-05 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9791
#
# Epoch 00030: val_accuracy did not improve from 0.98192
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 6
# Genre split [['Pop'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Jazz', 'Reggae', 'Rock']]
# Building model...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 203/203 [==============================] - 5s 21ms/step - loss: 0.3277 - accuracy: 0.8770 - val_loss: 0.2142 - val_accuracy: 0.9166
#
# Epoch 00001: val_accuracy improved from -inf to 0.91655, saving model to ./models/tree_10/model_root_f1_1/folder6\model.h5
# Epoch 2/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1985 - accuracy: 0.9206 - val_loss: 0.1923 - val_accuracy: 0.9263
#
# Epoch 00002: val_accuracy improved from 0.91655 to 0.92629, saving model to ./models/tree_10/model_root_f1_1/folder6\model.h5
# Epoch 3/30
# 203/203 [==============================] - 5s 22ms/step - loss: 0.1778 - accuracy: 0.9312 - val_loss: 0.1836 - val_accuracy: 0.9318
#
# Epoch 00003: val_accuracy improved from 0.92629 to 0.93185, saving model to ./models/tree_10/model_root_f1_1/folder6\model.h5
# Epoch 4/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1668 - accuracy: 0.9320 - val_loss: 0.1767 - val_accuracy: 0.9360
#
# Epoch 00004: val_accuracy improved from 0.93185 to 0.93602, saving model to ./models/tree_10/model_root_f1_1/folder6\model.h5
# Epoch 5/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1588 - accuracy: 0.9390 - val_loss: 0.1965 - val_accuracy: 0.9263
#
# Epoch 00005: val_accuracy did not improve from 0.93602
# Epoch 6/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1517 - accuracy: 0.9434 - val_loss: 0.1757 - val_accuracy: 0.9388
#
# Epoch 00006: val_accuracy improved from 0.93602 to 0.93880, saving model to ./models/tree_10/model_root_f1_1/folder6\model.h5
# Epoch 7/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1438 - accuracy: 0.9467 - val_loss: 0.1842 - val_accuracy: 0.9318
#
# Epoch 00007: val_accuracy did not improve from 0.93880
# Epoch 8/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1388 - accuracy: 0.9507 - val_loss: 0.1676 - val_accuracy: 0.9291
#
# Epoch 00008: val_accuracy did not improve from 0.93880
# Epoch 9/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1337 - accuracy: 0.9504 - val_loss: 0.1685 - val_accuracy: 0.9318
#
# Epoch 00009: val_accuracy did not improve from 0.93880
# Epoch 10/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1269 - accuracy: 0.9541 - val_loss: 0.1789 - val_accuracy: 0.9235
#
# Epoch 00010: val_accuracy did not improve from 0.93880
# Epoch 11/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1233 - accuracy: 0.9549 - val_loss: 0.1783 - val_accuracy: 0.9374
#
# ...
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 203/203 [==============================] - 5s 21ms/step - loss: 0.4072 - accuracy: 0.8703 - val_loss: 0.3407 - val_accuracy: 0.8818
#
# Epoch 00001: val_accuracy improved from -inf to 0.88178, saving model to ./models/tree_10/model_root_f1_1/folder7\model.h5
# Epoch 2/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.3145 - accuracy: 0.8858 - val_loss: 0.2439 - val_accuracy: 0.9096
#
# Epoch 00002: val_accuracy improved from 0.88178 to 0.90960, saving model to ./models/tree_10/model_root_f1_1/folder7\model.h5
# Epoch 3/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.2267 - accuracy: 0.9183 - val_loss: 0.2409 - val_accuracy: 0.9193
#
# Epoch 00003: val_accuracy improved from 0.90960 to 0.91933, saving model to ./models/tree_10/model_root_f1_1/folder7\model.h5
# Epoch 4/30
# 203/203 [==============================] - 4s 21ms/step - loss: 0.2020 - accuracy: 0.9284 - val_loss: 0.3081 - val_accuracy: 0.9166
#
# Epoch 00004: val_accuracy did not improve from 0.91933
# Epoch 5/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1582 - accuracy: 0.9450 - val_loss: 0.1511 - val_accuracy: 0.9527
#
# Epoch 00005: val_accuracy improved from 0.91933 to 0.95271, saving model to ./models/tree_10/model_root_f1_1/folder7\model.h5
# Epoch 6/30
# 203/203 [==============================] - 4s 21ms/step - loss: 0.1182 - accuracy: 0.9629 - val_loss: 0.1421 - val_accuracy: 0.9471
#
# Epoch 00006: val_accuracy did not improve from 0.95271
# Epoch 7/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0890 - accuracy: 0.9703 - val_loss: 0.1416 - val_accuracy: 0.9555
#
# Epoch 00007: val_accuracy improved from 0.95271 to 0.95549, saving model to ./models/tree_10/model_root_f1_1/folder7\model.h5
# Epoch 8/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0629 - accuracy: 0.9796 - val_loss: 0.1264 - val_accuracy: 0.9583
#
# Epoch 00008: val_accuracy improved from 0.95549 to 0.95828, saving model to ./models/tree_10/model_root_f1_1/folder7\model.h5
# Epoch 9/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0369 - accuracy: 0.9879 - val_loss: 0.1469 - val_accuracy: 0.9597
#
# Epoch 00009: val_accuracy improved from 0.95828 to 0.95967, saving model to ./models/tree_10/model_root_f1_1/folder7\model.h5
# Epoch 10/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0333 - accuracy: 0.9867 - val_loss: 0.2088 - val_accuracy: 0.9485
#
# Epoch 00010: val_accuracy did not improve from 0.95967
# Epoch 11/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0313 - accuracy: 0.9879 - val_loss: 0.2147 - val_accuracy: 0.9235
#
# Epoch 00011: val_accuracy did not improve from 0.95967
# Epoch 12/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0072 - accuracy: 0.9986 - val_loss: 0.3173 - val_accuracy: 0.9499
#
# Epoch 00012: val_accuracy did not improve from 0.95967
# Epoch 13/30
# 203/203 [==============================] - 4s 21ms/step - loss: 0.0249 - accuracy: 0.9915 - val_loss: 0.2012 - val_accuracy: 0.9458
#
# Epoch 00013: val_accuracy did not improve from 0.95967
# Epoch 14/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0294 - accuracy: 0.9906 - val_loss: 0.1524 - val_accuracy: 0.9666
#
# Epoch 00014: val_accuracy improved from 0.95967 to 0.96662, saving model to ./models/tree_10/model_root_f1_1/folder7\model.h5
# Epoch 15/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0222 - accuracy: 0.9920 - val_loss: 0.1569 - val_accuracy: 0.9611
#
# Epoch 00015: val_accuracy did not improve from 0.96662
# Epoch 16/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1603 - val_accuracy: 0.9652
#
# Epoch 00016: val_accuracy did not improve from 0.96662
# Epoch 17/30
# 203/203 [==============================] - 4s 20ms/step - loss: 2.1513e-04 - accuracy: 1.0000 - val_loss: 0.1742 - val_accuracy: 0.9694
#
# Epoch 00017: val_accuracy improved from 0.96662 to 0.96940, saving model to ./models/tree_10/model_root_f1_1/folder7\model.h5
# Epoch 18/30
# 203/203 [==============================] - 4s 21ms/step - loss: 9.7805e-05 - accuracy: 1.0000 - val_loss: 0.1828 - val_accuracy: 0.9680
#
# Epoch 00018: val_accuracy did not improve from 0.96940
# Epoch 19/30
# 203/203 [==============================] - 4s 21ms/step - loss: 7.1222e-05 - accuracy: 1.0000 - val_loss: 0.1852 - val_accuracy: 0.9680
#
# Epoch 00019: val_accuracy did not improve from 0.96940
# Epoch 20/30
# 203/203 [==============================] - 4s 21ms/step - loss: 5.5320e-05 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 0.9680
#
# Epoch 00020: val_accuracy did not improve from 0.96940
# Epoch 21/30
# 203/203 [==============================] - 4s 20ms/step - loss: 4.4994e-05 - accuracy: 1.0000 - val_loss: 0.1906 - val_accuracy: 0.9680
#
# Epoch 00021: val_accuracy did not improve from 0.96940
# Epoch 22/30
# 203/203 [==============================] - 4s 20ms/step - loss: 3.7080e-05 - accuracy: 1.0000 - val_loss: 0.1930 - val_accuracy: 0.9680
#
# Epoch 00022: val_accuracy did not improve from 0.96940
# Epoch 23/30
# 203/203 [==============================] - 4s 20ms/step - loss: 3.0893e-05 - accuracy: 1.0000 - val_loss: 0.1958 - val_accuracy: 0.9680
#
# Epoch 00023: val_accuracy did not improve from 0.96940
# Epoch 24/30
# 203/203 [==============================] - 4s 20ms/step - loss: 2.5923e-05 - accuracy: 1.0000 - val_loss: 0.1964 - val_accuracy: 0.9680
#
# Epoch 00024: val_accuracy did not improve from 0.96940
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 25/30
# 203/203 [==============================] - 4s 20ms/step - loss: 2.2280e-05 - accuracy: 1.0000 - val_loss: 0.1988 - val_accuracy: 0.9680
#
# Epoch 00025: val_accuracy did not improve from 0.96940
# Epoch 26/30
# 203/203 [==============================] - 4s 20ms/step - loss: 2.0570e-05 - accuracy: 1.0000 - val_loss: 0.1997 - val_accuracy: 0.9680
#
# Epoch 00026: val_accuracy did not improve from 0.96940
# Epoch 27/30
# 203/203 [==============================] - 4s 20ms/step - loss: 1.8893e-05 - accuracy: 1.0000 - val_loss: 0.2026 - val_accuracy: 0.9680
#
# Epoch 00027: val_accuracy did not improve from 0.96940
# Epoch 28/30
# 203/203 [==============================] - 4s 21ms/step - loss: 1.7264e-05 - accuracy: 1.0000 - val_loss: 0.2016 - val_accuracy: 0.9680
#
# Epoch 00028: val_accuracy did not improve from 0.96940
# Epoch 29/30
# 203/203 [==============================] - 4s 20ms/step - loss: 1.5591e-05 - accuracy: 1.0000 - val_loss: 0.2063 - val_accuracy: 0.9680
#
# Epoch 00029: val_accuracy did not improve from 0.96940
# Epoch 30/30
# 203/203 [==============================] - 4s 21ms/step - loss: 1.4179e-05 - accuracy: 1.0000 - val_loss: 0.2065 - val_accuracy: 0.9680
#
# Epoch 00030: val_accuracy did not improve from 0.96940
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 8
# Genre split [['Rock'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Jazz', 'Pop', 'Reggae']]
# Building model...
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 203/203 [==============================] - 5s 22ms/step - loss: 0.3761 - accuracy: 0.8724 - val_loss: 0.3228 - val_accuracy: 0.8693
#
# Epoch 00001: val_accuracy improved from -inf to 0.86926, saving model to ./models/tree_10/model_root_f1_1/folder8\model.h5
# Epoch 2/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.3409 - accuracy: 0.8785 - val_loss: 0.3169 - val_accuracy: 0.8693
#
# Epoch 00002: val_accuracy did not improve from 0.86926
# Epoch 3/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.3279 - accuracy: 0.8824 - val_loss: 0.2978 - val_accuracy: 0.8957
#
# Epoch 00003: val_accuracy improved from 0.86926 to 0.89569, saving model to ./models/tree_10/model_root_f1_1/folder8\model.h5
# Epoch 4/30
# 203/203 [==============================] - 4s 21ms/step - loss: 0.3221 - accuracy: 0.8839 - val_loss: 0.3058 - val_accuracy: 0.8762
#
# Epoch 00004: val_accuracy did not improve from 0.89569
# Epoch 5/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.3227 - accuracy: 0.8853 - val_loss: 0.2950 - val_accuracy: 0.8804
#
# Epoch 00005: val_accuracy did not improve from 0.89569
# Epoch 6/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.3082 - accuracy: 0.8847 - val_loss: 0.2710 - val_accuracy: 0.8971
#
# Epoch 00006: val_accuracy improved from 0.89569 to 0.89708, saving model to ./models/tree_10/model_root_f1_1/folder8\model.h5
# Epoch 7/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.2915 - accuracy: 0.8884 - val_loss: 0.2673 - val_accuracy: 0.8971
#
# Epoch 00007: val_accuracy did not improve from 0.89708
# Epoch 8/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.2724 - accuracy: 0.8928 - val_loss: 0.2661 - val_accuracy: 0.8846
#
# Epoch 00008: val_accuracy did not improve from 0.89708
# Epoch 9/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.2579 - accuracy: 0.8965 - val_loss: 0.2421 - val_accuracy: 0.8971
#
# Epoch 00009: val_accuracy did not improve from 0.89708
# Epoch 10/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.2438 - accuracy: 0.9009 - val_loss: 0.2494 - val_accuracy: 0.8971
#
# Epoch 00010: val_accuracy did not improve from 0.89708
# Epoch 11/30
# 203/203 [==============================] - 4s 21ms/step - loss: 0.2267 - accuracy: 0.9050 - val_loss: 0.2074 - val_accuracy: 0.9193s - loss: 0.2279 - accuracy
#
# Epoch 00011: val_accuracy improved from 0.89708 to 0.91933, saving model to ./models/tree_10/model_root_f1_1/folder8\model.h5
# Epoch 12/30
# 203/203 [==============================] - 4s 21ms/step - loss: 0.2160 - accuracy: 0.9125 - val_loss: 0.2052 - val_accuracy: 0.9166
#
# Epoch 00012: val_accuracy did not improve from 0.91933
# Epoch 13/30
# 203/203 [==============================] - 4s 21ms/step - loss: 0.1973 - accuracy: 0.9207 - val_loss: 0.1999 - val_accuracy: 0.9179
#
# Epoch 00013: val_accuracy did not improve from 0.91933
# Epoch 14/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1816 - accuracy: 0.9238 - val_loss: 0.1893 - val_accuracy: 0.9193
#
# Epoch 00014: val_accuracy did not improve from 0.91933
# Epoch 15/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1645 - accuracy: 0.9360 - val_loss: 0.1666 - val_accuracy: 0.9291
#
# Epoch 00015: val_accuracy improved from 0.91933 to 0.92907, saving model to ./models/tree_10/model_root_f1_1/folder8\model.h5
# Epoch 16/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.1503 - accuracy: 0.9400 - val_loss: 0.1927 - val_accuracy: 0.9166
#
# Epoch 00016: val_accuracy did not improve from 0.92907
# Epoch 17/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1291 - accuracy: 0.9464 - val_loss: 0.1999 - val_accuracy: 0.9152
#
# Epoch 00017: val_accuracy did not improve from 0.92907
# Epoch 18/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.1142 - accuracy: 0.9572 - val_loss: 0.1602 - val_accuracy: 0.9332
#
# Epoch 00018: val_accuracy improved from 0.92907 to 0.93324, saving model to ./models/tree_10/model_root_f1_1/folder8\model.h5
# Epoch 19/30
# 203/203 [==============================] - 4s 22ms/step - loss: 0.0897 - accuracy: 0.9643 - val_loss: 0.1935 - val_accuracy: 0.9291
#
# Epoch 00019: val_accuracy did not improve from 0.93324
# Epoch 20/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0682 - accuracy: 0.9750 - val_loss: 0.1927 - val_accuracy: 0.9332
#
# Epoch 00020: val_accuracy did not improve from 0.93324
# Epoch 21/30
# 203/203 [==============================] - 4s 19ms/step - loss: 0.0539 - accuracy: 0.9807 - val_loss: 0.2261 - val_accuracy: 0.9305
#
# Epoch 00021: val_accuracy did not improve from 0.93324
# Epoch 22/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0482 - accuracy: 0.9835 - val_loss: 0.2450 - val_accuracy: 0.9388
#
# Epoch 00022: val_accuracy improved from 0.93324 to 0.93880, saving model to ./models/tree_10/model_root_f1_1/folder8\model.h5
# Epoch 23/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0315 - accuracy: 0.9883 - val_loss: 0.2740 - val_accuracy: 0.9388
#
# Epoch 00023: val_accuracy did not improve from 0.93880
# Epoch 24/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0273 - accuracy: 0.9912 - val_loss: 0.2434 - val_accuracy: 0.9416
#
# Epoch 00024: val_accuracy improved from 0.93880 to 0.94159, saving model to ./models/tree_10/model_root_f1_1/folder8\model.h5
# Epoch 25/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0175 - accuracy: 0.9941 - val_loss: 0.2692 - val_accuracy: 0.9332
#
# Epoch 00025: val_accuracy did not improve from 0.94159
# Epoch 26/30
# 203/203 [==============================] - 4s 21ms/step - loss: 0.0379 - accuracy: 0.9873 - val_loss: 0.2816 - val_accuracy: 0.9305
#
# Epoch 00026: val_accuracy did not improve from 0.94159
# Epoch 27/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0256 - accuracy: 0.9909 - val_loss: 0.2793 - val_accuracy: 0.9402
#
# Epoch 00027: val_accuracy did not improve from 0.94159
# Epoch 28/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0057 - accuracy: 0.9991 - val_loss: 0.3203 - val_accuracy: 0.9374
#
# Epoch 00028: val_accuracy did not improve from 0.94159
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 29/30
# 203/203 [==============================] - 4s 20ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.3290 - val_accuracy: 0.9360
#
# Epoch 00029: val_accuracy did not improve from 0.94159
# Epoch 30/30
# 203/203 [==============================] - 4s 19ms/step - loss: 6.9412e-04 - accuracy: 1.0000 - val_loss: 0.3250 - val_accuracy: 0.9360
#
# Epoch 00030: val_accuracy did not improve from 0.94159
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
