# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Blues':0, 'Classical':1, 'Hip-Hop':4, 'Jazz' :5, 'Reggae' :8}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Blues', 1: 'Classical', 4: 'Hip-Hop', 5: 'Jazz', 8: 'Reggae'}

# %%
npzfile = np.load('data/all_targets_sets_train.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7992, 128, 128) (7992, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((3969, 128, 128), (3969, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (999, 128, 128) (999, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((501, 128, 128), (501, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Jazz

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_7/model_root_f1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_7/model_root_f1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def create_split(elem):
    splits = list(set_partitions(elem, 2))
    _splits = []
    for i in range(len(splits)):
        try:
            if len(splits[i][0]) != 1 and len(splits[i][1]) != 1:
                _splits.append(splits[i])
        except:
            continue
    
    return _splits, len(_splits)

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

genre_splits, num_splits = create_split(list(dict_genres.values()))
print("Num splits {}".format(num_splits))

if num_splits > 8:
    n_splits = num_splits
else:
    n_splits = 8

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)

    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Num splits 10
# Folder num 1
# Genre split [['Blues', 'Classical'], ['Hip-Hop', 'Jazz', 'Reggae']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 126/126 [==============================] - 7s 29ms/step - loss: 0.7566 - accuracy: 0.5886 - val_loss: 0.6771 - val_accuracy: 0.5973
#
# Epoch 00001: val_accuracy improved from -inf to 0.59732, saving model to ./models/tree_7/model_root_f1/folder1\model.h5
# Epoch 2/30
# 126/126 [==============================] - 3s 20ms/step - loss: 0.6738 - accuracy: 0.5983 - val_loss: 0.6596 - val_accuracy: 0.6667
#
# Epoch 00002: val_accuracy improved from 0.59732 to 0.66667, saving model to ./models/tree_7/model_root_f1/folder1\model.h5
# Epoch 3/30
# 126/126 [==============================] - 3s 24ms/step - loss: 0.6771 - accuracy: 0.5921 - val_loss: 0.6746 - val_accuracy: 0.5973
#
# Epoch 00003: val_accuracy did not improve from 0.66667
# Epoch 4/30
# 126/126 [==============================] - 2s 19ms/step - loss: 0.6779 - accuracy: 0.5918 - val_loss: 0.6704 - val_accuracy: 0.6085
#
# Epoch 00004: val_accuracy did not improve from 0.66667
# Epoch 5/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6720 - accuracy: 0.6122 - val_loss: 0.6744 - val_accuracy: 0.5973
#
# Epoch 00005: val_accuracy did not improve from 0.66667
# Epoch 6/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6753 - accuracy: 0.5993 - val_loss: 0.6742 - val_accuracy: 0.5973
#
# Epoch 00006: val_accuracy did not improve from 0.66667
# Epoch 7/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6752 - accuracy: 0.5966 - val_loss: 0.6742 - val_accuracy: 0.5973
#
# Epoch 00007: val_accuracy did not improve from 0.66667
# Epoch 8/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6751 - accuracy: 0.5966 - val_loss: 0.6745 - val_accuracy: 0.5973
#
# Epoch 00008: val_accuracy did not improve from 0.66667
# Epoch 9/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6753 - accuracy: 0.5966 - val_loss: 0.6750 - val_accuracy: 0.5973
#
# Epoch 00009: val_accuracy did not improve from 0.66667
# Epoch 10/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6748 - accuracy: 0.5966 - val_loss: 0.6737 - val_accuracy: 0.5973
#
# Epoch 00010: val_accuracy did not improve from 0.66667
# Epoch 11/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6746 - accuracy: 0.5983 - val_loss: 0.6746 - val_accuracy: 0.5973
#
# Epoch 00011: val_accuracy did not improve from 0.66667
# Epoch 12/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6749 - accuracy: 0.5966 - val_loss: 0.6740 - val_accuracy: 0.5973
#
# Epoch 00012: val_accuracy did not improve from 0.66667
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 13/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6746 - accuracy: 0.5966 - val_loss: 0.6739 - val_accuracy: 0.5973s - - ETA: 0s - loss: 0.6764 - accu - ETA: 0s - loss: 0.6761 - accuracy: 0.
#
# Epoch 00013: val_accuracy did not improve from 0.66667
# Epoch 14/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6507 - accuracy: 0.6269 - val_loss: 0.5858 - val_accuracy: 0.70250.6726 - accura - ETA: 1s - loss: 0 - ETA: 0s - loss: 0.6616
#
# Epoch 00014: val_accuracy improved from 0.66667 to 0.70246, saving model to ./models/tree_7/model_root_f1/folder1\model.h5
# Epoch 15/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.5624 - accuracy: 0.7107 - val_loss: 0.5137 - val_accuracy: 0.7785
#
# Epoch 00015: val_accuracy improved from 0.70246 to 0.77852, saving model to ./models/tree_7/model_root_f1/folder1\model.h5
# Epoch 16/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.4505 - accuracy: 0.7840 - val_loss: 0.3477 - val_accuracy: 0.8322
#
# Epoch 00016: val_accuracy improved from 0.77852 to 0.83221, saving model to ./models/tree_7/model_root_f1/folder1\model.h5
# Epoch 17/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.3324 - accuracy: 0.8531 - val_loss: 0.2664 - val_accuracy: 0.8814
#
# Epoch 00017: val_accuracy improved from 0.83221 to 0.88143, saving model to ./models/tree_7/model_root_f1/folder1\model.h5
# Epoch 18/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.2651 - accuracy: 0.8854 - val_loss: 0.2598 - val_accuracy: 0.8949
#
# Epoch 00018: val_accuracy improved from 0.88143 to 0.89485, saving model to ./models/tree_7/model_root_f1/folder1\model.h5
# Epoch 19/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1897 - accuracy: 0.9227 - val_loss: 0.3545 - val_accuracy: 0.8389
#
# Epoch 00019: val_accuracy did not improve from 0.89485
# Epoch 20/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1575 - accuracy: 0.9381 - val_loss: 0.2576 - val_accuracy: 0.8993
#
# Epoch 00020: val_accuracy improved from 0.89485 to 0.89933, saving model to ./models/tree_7/model_root_f1/folder1\model.h5
# Epoch 21/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0959 - accuracy: 0.9645 - val_loss: 0.2568 - val_accuracy: 0.9083
#
# Epoch 00021: val_accuracy improved from 0.89933 to 0.90828, saving model to ./models/tree_7/model_root_f1/folder1\model.h5
# Epoch 22/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0692 - accuracy: 0.9741 - val_loss: 0.1817 - val_accuracy: 0.9441
#
# Epoch 00022: val_accuracy improved from 0.90828 to 0.94407, saving model to ./models/tree_7/model_root_f1/folder1\model.h5
# Epoch 23/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0384 - accuracy: 0.9876 - val_loss: 0.1665 - val_accuracy: 0.9530
#
# Epoch 00023: val_accuracy improved from 0.94407 to 0.95302, saving model to ./models/tree_7/model_root_f1/folder1\model.h5
# Epoch 24/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0221 - accuracy: 0.9945 - val_loss: 0.1718 - val_accuracy: 0.9575
#
# Epoch 00024: val_accuracy improved from 0.95302 to 0.95749, saving model to ./models/tree_7/model_root_f1/folder1\model.h5
# Epoch 25/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0113 - accuracy: 0.9983 - val_loss: 0.2089 - val_accuracy: 0.9418
#
# Epoch 00025: val_accuracy did not improve from 0.95749
# Epoch 26/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0131 - accuracy: 0.9973 - val_loss: 0.2093 - val_accuracy: 0.9485
#
# Epoch 00026: val_accuracy did not improve from 0.95749
# Epoch 27/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0066 - accuracy: 0.9988 - val_loss: 0.2074 - val_accuracy: 0.9485
#
# Epoch 00027: val_accuracy did not improve from 0.95749
# Epoch 28/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.1978 - val_accuracy: 0.9597
#
# Epoch 00028: val_accuracy improved from 0.95749 to 0.95973, saving model to ./models/tree_7/model_root_f1/folder1\model.h5
# Epoch 29/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2089 - val_accuracy: 0.9575
#
# Epoch 00029: val_accuracy did not improve from 0.95973
# Epoch 30/30
# 126/126 [==============================] - 2s 18ms/step - loss: 6.4990e-04 - accuracy: 1.0000 - val_loss: 0.2039 - val_accuracy: 0.9530
#
# Epoch 00030: val_accuracy did not improve from 0.95973
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Blues', 'Classical', 'Hip-Hop'], ['Jazz', 'Reggae']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 126/126 [==============================] - 3s 19ms/step - loss: 0.8386 - accuracy: 0.5869 - val_loss: 0.6645 - val_accuracy: 0.6197
#
# Epoch 00001: val_accuracy improved from -inf to 0.61969, saving model to ./models/tree_7/model_root_f1/folder2\model.h5
# Epoch 2/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6753 - accuracy: 0.5991 - val_loss: 0.6661 - val_accuracy: 0.6197loss: 0.6
#
# Epoch 00002: val_accuracy did not improve from 0.61969
# Epoch 3/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6738 - accuracy: 0.5991 - val_loss: 0.6728 - val_accuracy: 0.6197
#
# Epoch 00003: val_accuracy did not improve from 0.61969
# Epoch 4/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6741 - accuracy: 0.5991 - val_loss: 0.6648 - val_accuracy: 0.6197
#
# Epoch 00004: val_accuracy did not improve from 0.61969
# Epoch 5/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6738 - accuracy: 0.5991 - val_loss: 0.6648 - val_accuracy: 0.6197s - loss: 0 - ETA
#
# Epoch 00005: val_accuracy did not improve from 0.61969
# Epoch 6/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6741 - accuracy: 0.5991 - val_loss: 0.6651 - val_accuracy: 0.6197
#
# Epoch 00006: val_accuracy did not improve from 0.61969
# Epoch 7/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6740 - accuracy: 0.5991 - val_loss: 0.6646 - val_accuracy: 0.6197
#
# Epoch 00007: val_accuracy did not improve from 0.61969
# Epoch 8/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6748 - accuracy: 0.5991 - val_loss: 0.6645 - val_accuracy: 0.6197
#
# Epoch 00008: val_accuracy did not improve from 0.61969
# Epoch 9/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6738 - accuracy: 0.5991 - val_loss: 0.6643 - val_accuracy: 0.6197
#
# Epoch 00009: val_accuracy did not improve from 0.61969
# Epoch 10/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6740 - accuracy: 0.5991 - val_loss: 0.6650 - val_accuracy: 0.6197
#
# Epoch 00010: val_accuracy did not improve from 0.61969
# Epoch 11/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6737 - accuracy: 0.5991 - val_loss: 0.6647 - val_accuracy: 0.6197
#
# Epoch 00011: val_accuracy did not improve from 0.61969
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 12/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6739 - accuracy: 0.5991 - val_loss: 0.6654 - val_accuracy: 0.6197
#
# Epoch 00012: val_accuracy did not improve from 0.61969
# Epoch 13/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6737 - accuracy: 0.5991 - val_loss: 0.6651 - val_accuracy: 0.6197
#
# Epoch 00013: val_accuracy did not improve from 0.61969
# Epoch 14/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6735 - accuracy: 0.5991 - val_loss: 0.6666 - val_accuracy: 0.6197
#
# Epoch 00014: val_accuracy did not improve from 0.61969
# Epoch 15/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6737 - accuracy: 0.5991 - val_loss: 0.6650 - val_accuracy: 0.6197
#
# Epoch 00015: val_accuracy did not improve from 0.61969
# Epoch 16/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6737 - accuracy: 0.5991 - val_loss: 0.6650 - val_accuracy: 0.6197
#
# Epoch 00016: val_accuracy did not improve from 0.61969
# Epoch 17/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6741 - accuracy: 0.5991 - val_loss: 0.6651 - val_accuracy: 0.6197
#
# Epoch 00017: val_accuracy did not improve from 0.61969
# Epoch 18/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6736 - accuracy: 0.5991 - val_loss: 0.6644 - val_accuracy: 0.6197
#
# Epoch 00018: val_accuracy did not improve from 0.61969
# Epoch 19/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6741 - accuracy: 0.5991 - val_loss: 0.6652 - val_accuracy: 0.6197
#
# Epoch 00019: val_accuracy did not improve from 0.61969
# Epoch 20/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6736 - accuracy: 0.5991 - val_loss: 0.6650 - val_accuracy: 0.6197
#
# Epoch 00020: val_accuracy did not improve from 0.61969
# Epoch 21/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6736 - accuracy: 0.5991 - val_loss: 0.6656 - val_accuracy: 0.6197
#
# Epoch 00021: val_accuracy did not improve from 0.61969
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 22/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6736 - accuracy: 0.5991 - val_loss: 0.6654 - val_accuracy: 0.6197
#
# Epoch 00022: val_accuracy did not improve from 0.61969
# Epoch 23/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6735 - accuracy: 0.5991 - val_loss: 0.6651 - val_accuracy: 0.6197
#
# Epoch 00023: val_accuracy did not improve from 0.61969
# Epoch 24/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6736 - accuracy: 0.5991 - val_loss: 0.6651 - val_accuracy: 0.6197
#
# Epoch 00024: val_accuracy did not improve from 0.61969
# Epoch 25/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6736 - accuracy: 0.5991 - val_loss: 0.6655 - val_accuracy: 0.6197
#
# Epoch 00025: val_accuracy did not improve from 0.61969
# Epoch 26/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6736 - accuracy: 0.5991 - val_loss: 0.6653 - val_accuracy: 0.6197
#
# Epoch 00026: val_accuracy did not improve from 0.61969
# Epoch 27/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6735 - accuracy: 0.5991 - val_loss: 0.6647 - val_accuracy: 0.6197
#
# Epoch 00027: val_accuracy did not improve from 0.61969
# Epoch 28/30
# 126/126 [==============================] - 2s 19ms/step - loss: 0.6736 - accuracy: 0.5991 - val_loss: 0.6649 - val_accuracy: 0.6197
#
# Epoch 00028: val_accuracy did not improve from 0.61969
# Epoch 29/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6736 - accuracy: 0.5991 - val_loss: 0.6654 - val_accuracy: 0.6197
#
# Epoch 00029: val_accuracy did not improve from 0.61969
# Epoch 30/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6736 - accuracy: 0.5991 - val_loss: 0.6652 - val_accuracy: 0.6197
#
# Epoch 00030: val_accuracy did not improve from 0.61969
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Classical', 'Hip-Hop'], ['Blues', 'Jazz', 'Reggae']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 126/126 [==============================] - 3s 19ms/step - loss: 0.6876 - accuracy: 0.6033 - val_loss: 0.5710 - val_accuracy: 0.6957
#
# Epoch 00001: val_accuracy improved from -inf to 0.69575, saving model to ./models/tree_7/model_root_f1/folder3\model.h5
# Epoch 2/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.5107 - accuracy: 0.7445 - val_loss: 0.4979 - val_accuracy: 0.7383
#
# Epoch 00002: val_accuracy improved from 0.69575 to 0.73826, saving model to ./models/tree_7/model_root_f1/folder3\model.h5
# Epoch 3/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.3243 - accuracy: 0.8658 - val_loss: 0.3913 - val_accuracy: 0.8523
#
# Epoch 00003: val_accuracy improved from 0.73826 to 0.85235, saving model to ./models/tree_7/model_root_f1/folder3\model.h5
# Epoch 4/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.2430 - accuracy: 0.9070 - val_loss: 0.3257 - val_accuracy: 0.8949
#
# Epoch 00004: val_accuracy improved from 0.85235 to 0.89485, saving model to ./models/tree_7/model_root_f1/folder3\model.h5
# Epoch 5/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1968 - accuracy: 0.9197 - val_loss: 0.2719 - val_accuracy: 0.8881
#
# Epoch 00005: val_accuracy did not improve from 0.89485
# Epoch 6/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1336 - accuracy: 0.9461 - val_loss: 0.2932 - val_accuracy: 0.8926
#
# Epoch 00006: val_accuracy did not improve from 0.89485
# Epoch 7/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1224 - accuracy: 0.9543 - val_loss: 0.2887 - val_accuracy: 0.9016
#
# Epoch 00007: val_accuracy improved from 0.89485 to 0.90157, saving model to ./models/tree_7/model_root_f1/folder3\model.h5
# Epoch 8/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.0587 - accuracy: 0.9796 - val_loss: 0.2744 - val_accuracy: 0.9217
#
# Epoch 00008: val_accuracy improved from 0.90157 to 0.92170, saving model to ./models/tree_7/model_root_f1/folder3\model.h5
# Epoch 9/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.0482 - accuracy: 0.9836 - val_loss: 0.3431 - val_accuracy: 0.8971
#
# Epoch 00009: val_accuracy did not improve from 0.92170
# Epoch 10/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.0492 - accuracy: 0.9824 - val_loss: 0.2864 - val_accuracy: 0.8971
#
# Epoch 00010: val_accuracy did not improve from 0.92170
# Epoch 11/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0258 - accuracy: 0.9906 - val_loss: 0.3041 - val_accuracy: 0.9105
#
# Epoch 00011: val_accuracy did not improve from 0.92170
# Epoch 12/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0129 - accuracy: 0.9963 - val_loss: 0.3631 - val_accuracy: 0.9128
#
# Epoch 00012: val_accuracy did not improve from 0.92170
# Epoch 13/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3660 - val_accuracy: 0.9150
#
# Epoch 00013: val_accuracy did not improve from 0.92170
# Epoch 14/30
# 126/126 [==============================] - 2s 17ms/step - loss: 7.3625e-04 - accuracy: 1.0000 - val_loss: 0.3715 - val_accuracy: 0.9172
#
# Epoch 00014: val_accuracy did not improve from 0.92170
# Epoch 15/30
# 126/126 [==============================] - 2s 17ms/step - loss: 2.9009e-04 - accuracy: 1.0000 - val_loss: 0.3862 - val_accuracy: 0.9172
#
# Epoch 00015: val_accuracy did not improve from 0.92170
# Epoch 16/30
# 126/126 [==============================] - 2s 17ms/step - loss: 2.0454e-04 - accuracy: 1.0000 - val_loss: 0.4031 - val_accuracy: 0.9195
#
# Epoch 00016: val_accuracy did not improve from 0.92170
# Epoch 17/30
# 126/126 [==============================] - 2s 17ms/step - loss: 1.6201e-04 - accuracy: 1.0000 - val_loss: 0.4161 - val_accuracy: 0.9195
#
# Epoch 00017: val_accuracy did not improve from 0.92170
# Epoch 18/30
# 126/126 [==============================] - 2s 17ms/step - loss: 1.3353e-04 - accuracy: 1.0000 - val_loss: 0.4195 - val_accuracy: 0.9195
#
# Epoch 00018: val_accuracy did not improve from 0.92170
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 19/30
# 126/126 [==============================] - 2s 17ms/step - loss: 1.1018e-04 - accuracy: 1.0000 - val_loss: 0.4283 - val_accuracy: 0.9195ETA: 1s - loss: - ETA: 0s - loss: 1.0
#
# Epoch 00019: val_accuracy did not improve from 0.92170
# Epoch 20/30
# 126/126 [==============================] - 2s 18ms/step - loss: 1.0210e-04 - accuracy: 1.0000 - val_loss: 0.4316 - val_accuracy: 0.9195
#
# Epoch 00020: val_accuracy did not improve from 0.92170
# Epoch 21/30
# 126/126 [==============================] - 2s 17ms/step - loss: 9.4194e-05 - accuracy: 1.0000 - val_loss: 0.4344 - val_accuracy: 0.92179.0783e-05 -
#
# Epoch 00021: val_accuracy did not improve from 0.92170
# Epoch 22/30
# 126/126 [==============================] - 2s 17ms/step - loss: 8.6646e-05 - accuracy: 1.0000 - val_loss: 0.4382 - val_accuracy: 0.9217
#
# Epoch 00022: val_accuracy did not improve from 0.92170
# Epoch 23/30
# 126/126 [==============================] - 2s 17ms/step - loss: 8.0002e-05 - accuracy: 1.0000 - val_loss: 0.4418 - val_accuracy: 0.9217
#
# Epoch 00023: val_accuracy did not improve from 0.92170
# Epoch 24/30
# 126/126 [==============================] - 2s 18ms/step - loss: 7.3884e-05 - accuracy: 1.0000 - val_loss: 0.4480 - val_accuracy: 0.9217
#
# Epoch 00024: val_accuracy did not improve from 0.92170
# Epoch 25/30
# 126/126 [==============================] - 2s 17ms/step - loss: 6.8838e-05 - accuracy: 1.0000 - val_loss: 0.4500 - val_accuracy: 0.9217loss: 6.8833e-0
#
# Epoch 00025: val_accuracy did not improve from 0.92170
# Epoch 26/30
# 126/126 [==============================] - 2s 17ms/step - loss: 6.2885e-05 - accuracy: 1.0000 - val_loss: 0.4542 - val_accuracy: 0.9217
#
# Epoch 00026: val_accuracy did not improve from 0.92170
# Epoch 27/30
# 126/126 [==============================] - 2s 18ms/step - loss: 5.8538e-05 - accuracy: 1.0000 - val_loss: 0.4579 - val_accuracy: 0.9217
#
# Epoch 00027: val_accuracy did not improve from 0.92170
# Epoch 28/30
# 126/126 [==============================] - 2s 17ms/step - loss: 5.3977e-05 - accuracy: 1.0000 - val_loss: 0.4598 - val_accuracy: 0.9217- l
#
# Epoch 00028: val_accuracy did not improve from 0.92170
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 29/30
# 126/126 [==============================] - 2s 17ms/step - loss: 5.0135e-05 - accuracy: 1.0000 - val_loss: 0.4624 - val_accuracy: 0.9217
#
# Epoch 00029: val_accuracy did not improve from 0.92170
# Epoch 30/30
# 126/126 [==============================] - 2s 17ms/step - loss: 4.8103e-05 - accuracy: 1.0000 - val_loss: 0.4642 - val_accuracy: 0.9217
#
# Epoch 00030: val_accuracy did not improve from 0.92170
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Blues', 'Hip-Hop'], ['Classical', 'Jazz', 'Reggae']]
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 126/126 [==============================] - 3s 19ms/step - loss: 0.7717 - accuracy: 0.5923 - val_loss: 0.6652 - val_accuracy: 0.6197
#
# Epoch 00001: val_accuracy improved from -inf to 0.61969, saving model to ./models/tree_7/model_root_f1/folder4\model.h5
# Epoch 2/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6822 - accuracy: 0.5993 - val_loss: 0.6718 - val_accuracy: 0.6197
#
# Epoch 00002: val_accuracy did not improve from 0.61969
# Epoch 3/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6800 - accuracy: 0.5918 - val_loss: 0.6651 - val_accuracy: 0.6197
#
# Epoch 00003: val_accuracy did not improve from 0.61969
# Epoch 4/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6741 - accuracy: 0.5993 - val_loss: 0.6643 - val_accuracy: 0.6197  - ETA: 0s - loss: 0.6764 -
#
# Epoch 00004: val_accuracy did not improve from 0.61969
# Epoch 5/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6744 - accuracy: 0.5993 - val_loss: 0.6652 - val_accuracy: 0.6197
#
# Epoch 00005: val_accuracy did not improve from 0.61969
# Epoch 6/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6740 - accuracy: 0.5993 - val_loss: 0.6652 - val_accuracy: 0.6197
#
# Epoch 00006: val_accuracy did not improve from 0.61969
# Epoch 7/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6742 - accuracy: 0.5993 - val_loss: 0.6658 - val_accuracy: 0.6197
#
# Epoch 00007: val_accuracy did not improve from 0.61969
# Epoch 8/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6735 - accuracy: 0.5993 - val_loss: 0.6668 - val_accuracy: 0.6197
#
# Epoch 00008: val_accuracy did not improve from 0.61969
# Epoch 9/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6742 - accuracy: 0.5993 - val_loss: 0.6647 - val_accuracy: 0.6197s - loss: 0.6737 - accuracy
#
# Epoch 00009: val_accuracy did not improve from 0.61969
# Epoch 10/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6745 - accuracy: 0.5993 - val_loss: 0.6667 - val_accuracy: 0.6197
#
# Epoch 00010: val_accuracy did not improve from 0.61969
# Epoch 11/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6736 - accuracy: 0.5993 - val_loss: 0.6645 - val_accuracy: 0.6197
#
# Epoch 00011: val_accuracy did not improve from 0.61969
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 12/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6738 - accuracy: 0.5993 - val_loss: 0.6651 - val_accuracy: 0.6197
#
# Epoch 00012: val_accuracy did not improve from 0.61969
# Epoch 13/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6737 - accuracy: 0.5993 - val_loss: 0.6657 - val_accuracy: 0.6197 - accuracy
#
# Epoch 00013: val_accuracy did not improve from 0.61969
# Epoch 14/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6735 - accuracy: 0.5993 - val_loss: 0.6674 - val_accuracy: 0.6197
#
# Epoch 00014: val_accuracy did not improve from 0.61969
# Epoch 15/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6739 - accuracy: 0.5993 - val_loss: 0.6651 - val_accuracy: 0.6197
#
# Epoch 00015: val_accuracy did not improve from 0.61969
# Epoch 16/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6737 - accuracy: 0.5993 - val_loss: 0.6656 - val_accuracy: 0.6197
#
# Epoch 00016: val_accuracy did not improve from 0.61969
# Epoch 17/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6735 - accuracy: 0.5993 - val_loss: 0.6652 - val_accuracy: 0.6197
#
# Epoch 00017: val_accuracy did not improve from 0.61969
# Epoch 18/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6735 - accuracy: 0.5993 - val_loss: 0.6658 - val_accuracy: 0.6197
#
# Epoch 00018: val_accuracy did not improve from 0.61969
# Epoch 19/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6735 - accuracy: 0.5993 - val_loss: 0.6643 - val_accuracy: 0.6197
#
# Epoch 00019: val_accuracy did not improve from 0.61969
# Epoch 20/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6737 - accuracy: 0.5993 - val_loss: 0.6646 - val_accuracy: 0.6197
#
# Epoch 00020: val_accuracy did not improve from 0.61969
# Epoch 21/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6737 - accuracy: 0.5993 - val_loss: 0.6648 - val_accuracy: 0.6197
#
# Epoch 00021: val_accuracy did not improve from 0.61969
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 22/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6735 - accuracy: 0.5993 - val_loss: 0.6656 - val_accuracy: 0.6197
#
# Epoch 00022: val_accuracy did not improve from 0.61969
# Epoch 23/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6735 - accuracy: 0.5993 - val_loss: 0.6658 - val_accuracy: 0.6197
#
# Epoch 00023: val_accuracy did not improve from 0.61969
# Epoch 24/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6734 - accuracy: 0.5993 - val_loss: 0.6652 - val_accuracy: 0.6197
#
# Epoch 00024: val_accuracy did not improve from 0.61969
# Epoch 25/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6736 - accuracy: 0.5993 - val_loss: 0.6650 - val_accuracy: 0.6197
#
# Epoch 00025: val_accuracy did not improve from 0.61969
# Epoch 26/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6734 - accuracy: 0.5993 - val_loss: 0.6652 - val_accuracy: 0.6197
#
# Epoch 00026: val_accuracy did not improve from 0.61969
# Epoch 27/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6734 - accuracy: 0.5993 - val_loss: 0.6648 - val_accuracy: 0.6197
#
# Epoch 00027: val_accuracy did not improve from 0.61969
# Epoch 28/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6734 - accuracy: 0.5993 - val_loss: 0.6655 - val_accuracy: 0.6197
#
# Epoch 00028: val_accuracy did not improve from 0.61969
# Epoch 29/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6734 - accuracy: 0.5993 - val_loss: 0.6646 - val_accuracy: 0.619763 -
#
# Epoch 00029: val_accuracy did not improve from 0.61969
# Epoch 30/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6735 - accuracy: 0.5993 - val_loss: 0.6656 - val_accuracy: 0.6197
#
# Epoch 00030: val_accuracy did not improve from 0.61969
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 5
# Genre split [['Classical', 'Hip-Hop', 'Jazz'], ['Blues', 'Reggae']]
# Building model...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 126/126 [==============================] - 3s 19ms/step - loss: 0.8015 - accuracy: 0.5926 - val_loss: 0.6105 - val_accuracy: 0.6197
#
# Epoch 00001: val_accuracy improved from -inf to 0.61969, saving model to ./models/tree_7/model_root_f1/folder5\model.h5
# Epoch 2/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.5730 - accuracy: 0.6779 - val_loss: 0.5315 - val_accuracy: 0.7226
#
# Epoch 00002: val_accuracy improved from 0.61969 to 0.72260, saving model to ./models/tree_7/model_root_f1/folder5\model.h5
# Epoch 3/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.5013 - accuracy: 0.7487 - val_loss: 0.4197 - val_accuracy: 0.7897loss:
#
# Epoch 00003: val_accuracy improved from 0.72260 to 0.78971, saving model to ./models/tree_7/model_root_f1/folder5\model.h5
# Epoch 4/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.4696 - accuracy: 0.7668 - val_loss: 0.4054 - val_accuracy: 0.8054
#
# Epoch 00004: val_accuracy improved from 0.78971 to 0.80537, saving model to ./models/tree_7/model_root_f1/folder5\model.h5
# Epoch 5/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.4193 - accuracy: 0.8143 - val_loss: 0.3813 - val_accuracy: 0.8166
#
# Epoch 00005: val_accuracy improved from 0.80537 to 0.81655, saving model to ./models/tree_7/model_root_f1/folder5\model.h5
# Epoch 6/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.3909 - accuracy: 0.8198 - val_loss: 0.3629 - val_accuracy: 0.8367
#
# Epoch 00006: val_accuracy improved from 0.81655 to 0.83669, saving model to ./models/tree_7/model_root_f1/folder5\model.h5
# Epoch 7/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.3625 - accuracy: 0.8387 - val_loss: 0.3180 - val_accuracy: 0.8568
#
# Epoch 00007: val_accuracy improved from 0.83669 to 0.85682, saving model to ./models/tree_7/model_root_f1/folder5\model.h5
# Epoch 8/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.3342 - accuracy: 0.8566 - val_loss: 0.3325 - val_accuracy: 0.8523
#
# Epoch 00008: val_accuracy did not improve from 0.85682
# Epoch 9/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.3236 - accuracy: 0.8615 - val_loss: 0.3022 - val_accuracy: 0.8546
#
# Epoch 00009: val_accuracy did not improve from 0.85682
# Epoch 10/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.2926 - accuracy: 0.8735 - val_loss: 0.3315 - val_accuracy: 0.8501
#
# Epoch 00010: val_accuracy did not improve from 0.85682
# Epoch 11/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.2675 - accuracy: 0.8869 - val_loss: 0.3160 - val_accuracy: 0.8814
#
# Epoch 00011: val_accuracy improved from 0.85682 to 0.88143, saving model to ./models/tree_7/model_root_f1/folder5\model.h5
# Epoch 12/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.2645 - accuracy: 0.8869 - val_loss: 0.2492 - val_accuracy: 0.8993
#
# Epoch 00012: val_accuracy improved from 0.88143 to 0.89933, saving model to ./models/tree_7/model_root_f1/folder5\model.h5
# Epoch 13/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.2341 - accuracy: 0.9008 - val_loss: 0.2695 - val_accuracy: 0.9016
#
# Epoch 00013: val_accuracy improved from 0.89933 to 0.90157, saving model to ./models/tree_7/model_root_f1/folder5\model.h5
# Epoch 14/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.2024 - accuracy: 0.9170 - val_loss: 0.2575 - val_accuracy: 0.8949
#
# Epoch 00014: val_accuracy did not improve from 0.90157
# Epoch 15/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1879 - accuracy: 0.9215 - val_loss: 0.2409 - val_accuracy: 0.9060
#
# Epoch 00015: val_accuracy improved from 0.90157 to 0.90604, saving model to ./models/tree_7/model_root_f1/folder5\model.h5
# Epoch 16/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1787 - accuracy: 0.9284 - val_loss: 0.2108 - val_accuracy: 0.9329
#
# Epoch 00016: val_accuracy improved from 0.90604 to 0.93289, saving model to ./models/tree_7/model_root_f1/folder5\model.h5
# Epoch 17/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1597 - accuracy: 0.9379 - val_loss: 0.2417 - val_accuracy: 0.9105
#
# Epoch 00017: val_accuracy did not improve from 0.93289
# Epoch 18/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1538 - accuracy: 0.9391 - val_loss: 0.2377 - val_accuracy: 0.9105
#
# Epoch 00018: val_accuracy did not improve from 0.93289
# Epoch 19/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1427 - accuracy: 0.9426 - val_loss: 0.2612 - val_accuracy: 0.8926
#
# Epoch 00019: val_accuracy did not improve from 0.93289
# Epoch 20/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1311 - accuracy: 0.9495 - val_loss: 0.2122 - val_accuracy: 0.9284
#
# Epoch 00020: val_accuracy did not improve from 0.93289
# Epoch 21/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1249 - accuracy: 0.9513 - val_loss: 0.2735 - val_accuracy: 0.9128
#
# Epoch 00021: val_accuracy did not improve from 0.93289
# Epoch 22/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1000 - accuracy: 0.9607 - val_loss: 0.2395 - val_accuracy: 0.9195
#
# Epoch 00022: val_accuracy did not improve from 0.93289
# Epoch 23/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0885 - accuracy: 0.9674 - val_loss: 0.2514 - val_accuracy: 0.9172
#
# Epoch 00023: val_accuracy did not improve from 0.93289
# Epoch 24/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0711 - accuracy: 0.9739 - val_loss: 0.2473 - val_accuracy: 0.9060
#
# Epoch 00024: val_accuracy did not improve from 0.93289
# Epoch 25/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0771 - accuracy: 0.9709 - val_loss: 0.2829 - val_accuracy: 0.9083
#
# Epoch 00025: val_accuracy did not improve from 0.93289
# Epoch 26/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0798 - accuracy: 0.9707 - val_loss: 0.3177 - val_accuracy: 0.8971
#
# Epoch 00026: val_accuracy did not improve from 0.93289
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 27/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0390 - accuracy: 0.9873 - val_loss: 0.2490 - val_accuracy: 0.9284
#
# Epoch 00027: val_accuracy did not improve from 0.93289
# Epoch 28/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0199 - accuracy: 0.9955 - val_loss: 0.2472 - val_accuracy: 0.9284
#
# Epoch 00028: val_accuracy did not improve from 0.93289
# Epoch 29/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0127 - accuracy: 0.9988 - val_loss: 0.2838 - val_accuracy: 0.9239
#
# Epoch 00029: val_accuracy did not improve from 0.93289
# Epoch 30/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0093 - accuracy: 0.9998 - val_loss: 0.2867 - val_accuracy: 0.9172
#
# Epoch 00030: val_accuracy did not improve from 0.93289
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 6
# Genre split [['Blues', 'Hip-Hop', 'Jazz'], ['Classical', 'Reggae']]
# Building model...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 126/126 [==============================] - 3s 19ms/step - loss: 0.7475 - accuracy: 0.5866 - val_loss: 0.6705 - val_accuracy: 0.5861
#
# Epoch 00001: val_accuracy improved from -inf to 0.58613, saving model to ./models/tree_7/model_root_f1/folder6\model.h5
# Epoch 2/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.6283 - accuracy: 0.6592 - val_loss: 0.5248 - val_accuracy: 0.7562
#
# Epoch 00002: val_accuracy improved from 0.58613 to 0.75615, saving model to ./models/tree_7/model_root_f1/folder6\model.h5
# Epoch 3/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.5228 - accuracy: 0.7504 - val_loss: 0.6163 - val_accuracy: 0.6443
#
# Epoch 00003: val_accuracy did not improve from 0.75615
# Epoch 4/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.5134 - accuracy: 0.7621 - val_loss: 0.4737 - val_accuracy: 0.7987
#
# Epoch 00004: val_accuracy improved from 0.75615 to 0.79866, saving model to ./models/tree_7/model_root_f1/folder6\model.h5
# Epoch 5/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.4736 - accuracy: 0.7800 - val_loss: 0.4751 - val_accuracy: 0.7718
#
# Epoch 00005: val_accuracy did not improve from 0.79866
# Epoch 6/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.4277 - accuracy: 0.8121 - val_loss: 0.3861 - val_accuracy: 0.8233
#
# Epoch 00006: val_accuracy improved from 0.79866 to 0.82327, saving model to ./models/tree_7/model_root_f1/folder6\model.h5
# Epoch 7/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.3894 - accuracy: 0.8280 - val_loss: 0.4265 - val_accuracy: 0.7897
#
# Epoch 00007: val_accuracy did not improve from 0.82327
# Epoch 8/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.3433 - accuracy: 0.8519 - val_loss: 0.3585 - val_accuracy: 0.8300
#
# Epoch 00008: val_accuracy improved from 0.82327 to 0.82998, saving model to ./models/tree_7/model_root_f1/folder6\model.h5
# Epoch 9/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.3309 - accuracy: 0.8598 - val_loss: 0.3084 - val_accuracy: 0.8568
#
# Epoch 00009: val_accuracy improved from 0.82998 to 0.85682, saving model to ./models/tree_7/model_root_f1/folder6\model.h5
# Epoch 10/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.3013 - accuracy: 0.8712 - val_loss: 0.3432 - val_accuracy: 0.8658
#
# Epoch 00010: val_accuracy improved from 0.85682 to 0.86577, saving model to ./models/tree_7/model_root_f1/folder6\model.h5
# Epoch 11/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.2522 - accuracy: 0.8899 - val_loss: 0.2710 - val_accuracy: 0.8702
#
# Epoch 00011: val_accuracy improved from 0.86577 to 0.87025, saving model to ./models/tree_7/model_root_f1/folder6\model.h5
# Epoch 12/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.2335 - accuracy: 0.9026 - val_loss: 0.2414 - val_accuracy: 0.9016
#
# ...
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 126/126 [==============================] - 3s 19ms/step - loss: 0.6285 - accuracy: 0.6649 - val_loss: 0.3809 - val_accuracy: 0.8277
#
# Epoch 00001: val_accuracy improved from -inf to 0.82774, saving model to ./models/tree_7/model_root_f1/folder9\model.h5
# Epoch 2/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.3263 - accuracy: 0.8519 - val_loss: 0.2493 - val_accuracy: 0.8904
#
# Epoch 00002: val_accuracy improved from 0.82774 to 0.89038, saving model to ./models/tree_7/model_root_f1/folder9\model.h5
# Epoch 3/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1853 - accuracy: 0.9264 - val_loss: 0.2414 - val_accuracy: 0.9060
#
# Epoch 00003: val_accuracy improved from 0.89038 to 0.90604, saving model to ./models/tree_7/model_root_f1/folder9\model.h5
# Epoch 4/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1612 - accuracy: 0.9381 - val_loss: 0.1569 - val_accuracy: 0.9396
#
# Epoch 00004: val_accuracy improved from 0.90604 to 0.93960, saving model to ./models/tree_7/model_root_f1/folder9\model.h5
# Epoch 5/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1201 - accuracy: 0.9535 - val_loss: 0.1287 - val_accuracy: 0.9553
#
# Epoch 00005: val_accuracy improved from 0.93960 to 0.95526, saving model to ./models/tree_7/model_root_f1/folder9\model.h5
# Epoch 6/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0848 - accuracy: 0.9667 - val_loss: 0.1642 - val_accuracy: 0.9396
#
# Epoch 00006: val_accuracy did not improve from 0.95526
# Epoch 7/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0632 - accuracy: 0.9791 - val_loss: 0.2259 - val_accuracy: 0.9128 - accu
#
# Epoch 00007: val_accuracy did not improve from 0.95526
# Epoch 8/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0528 - accuracy: 0.9816 - val_loss: 0.1263 - val_accuracy: 0.9620
#
# Epoch 00008: val_accuracy improved from 0.95526 to 0.96197, saving model to ./models/tree_7/model_root_f1/folder9\model.h5
# Epoch 9/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0349 - accuracy: 0.9876 - val_loss: 0.1215 - val_accuracy: 0.9687
#
# Epoch 00009: val_accuracy improved from 0.96197 to 0.96868, saving model to ./models/tree_7/model_root_f1/folder9\model.h5
# Epoch 10/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0429 - accuracy: 0.9836 - val_loss: 0.1559 - val_accuracy: 0.9620
#
# Epoch 00010: val_accuracy did not improve from 0.96868
# Epoch 11/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0404 - accuracy: 0.9848 - val_loss: 0.1393 - val_accuracy: 0.9553
#
# Epoch 00011: val_accuracy did not improve from 0.96868
# Epoch 12/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0397 - accuracy: 0.9878 - val_loss: 0.1513 - val_accuracy: 0.9508
#
# Epoch 00012: val_accuracy did not improve from 0.96868
# Epoch 13/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0169 - accuracy: 0.9950 - val_loss: 0.1193 - val_accuracy: 0.9754
#
# Epoch 00013: val_accuracy improved from 0.96868 to 0.97539, saving model to ./models/tree_7/model_root_f1/folder9\model.h5
# Epoch 14/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0112 - accuracy: 0.9968 - val_loss: 0.1373 - val_accuracy: 0.9687
#
# Epoch 00014: val_accuracy did not improve from 0.97539
# Epoch 15/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.1139 - val_accuracy: 0.9754
#
# Epoch 00015: val_accuracy did not improve from 0.97539
# Epoch 16/30
# 126/126 [==============================] - 2s 18ms/step - loss: 6.1377e-04 - accuracy: 1.0000 - val_loss: 0.1109 - val_accuracy: 0.9799
#
# Epoch 00016: val_accuracy improved from 0.97539 to 0.97987, saving model to ./models/tree_7/model_root_f1/folder9\model.h5
# Epoch 17/30
# 126/126 [==============================] - 2s 18ms/step - loss: 2.9371e-04 - accuracy: 1.0000 - val_loss: 0.1234 - val_accuracy: 0.9776
#
# Epoch 00017: val_accuracy did not improve from 0.97987
# Epoch 18/30
# 126/126 [==============================] - 2s 18ms/step - loss: 1.7904e-04 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9799
#
# Epoch 00018: val_accuracy did not improve from 0.97987
# Epoch 19/30
# 126/126 [==============================] - 2s 18ms/step - loss: 1.3489e-04 - accuracy: 1.0000 - val_loss: 0.1276 - val_accuracy: 0.9776
#
# Epoch 00019: val_accuracy did not improve from 0.97987
# Epoch 20/30
# 126/126 [==============================] - 2s 18ms/step - loss: 1.0991e-04 - accuracy: 1.0000 - val_loss: 0.1276 - val_accuracy: 0.9776
#
# Epoch 00020: val_accuracy did not improve from 0.97987
# Epoch 21/30
# 126/126 [==============================] - 2s 18ms/step - loss: 8.9163e-05 - accuracy: 1.0000 - val_loss: 0.1322 - val_accuracy: 0.9776
#
# Epoch 00021: val_accuracy did not improve from 0.97987
# Epoch 22/30
# 126/126 [==============================] - ETA: 0s - loss: 7.3325e-05 - accuracy: 1.0000 ETA: 0s - loss: 7.340 - 2s 17ms/step - loss: 7.2882e-05 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9776
#
# Epoch 00022: val_accuracy did not improve from 0.97987
# Epoch 23/30
# 126/126 [==============================] - 2s 18ms/step - loss: 6.1613e-05 - accuracy: 1.0000 - val_loss: 0.1444 - val_accuracy: 0.9776
#
# Epoch 00023: val_accuracy did not improve from 0.97987
# Epoch 24/30
# 126/126 [==============================] - 2s 18ms/step - loss: 5.0044e-05 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9776
#
# Epoch 00024: val_accuracy did not improve from 0.97987
# Epoch 25/30
# 126/126 [==============================] - 2s 18ms/step - loss: 3.9742e-05 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9776
#
# Epoch 00025: val_accuracy did not improve from 0.97987
# Epoch 26/30
# 126/126 [==============================] - 2s 18ms/step - loss: 3.2268e-05 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9754
#
# Epoch 00026: val_accuracy did not improve from 0.97987
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 27/30
# 126/126 [==============================] - 2s 18ms/step - loss: 2.5829e-05 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9754
#
# Epoch 00027: val_accuracy did not improve from 0.97987
# Epoch 28/30
# 126/126 [==============================] - 2s 18ms/step - loss: 2.3315e-05 - accuracy: 1.0000 - val_loss: 0.1533 - val_accuracy: 0.9754
#
# Epoch 00028: val_accuracy did not improve from 0.97987
# Epoch 29/30
# 126/126 [==============================] - 2s 18ms/step - loss: 2.0206e-05 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.9754
#
# Epoch 00029: val_accuracy did not improve from 0.97987
# Epoch 30/30
# 126/126 [==============================] - 2s 18ms/step - loss: 1.7958e-05 - accuracy: 1.0000 - val_loss: 0.1583 - val_accuracy: 0.9754
#
# Epoch 00030: val_accuracy did not improve from 0.97987
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 10
# Genre split [['Blues', 'Jazz'], ['Classical', 'Hip-Hop', 'Reggae']]
# Building model...
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 126/126 [==============================] - 3s 19ms/step - loss: 0.7406 - accuracy: 0.5871 - val_loss: 0.6666 - val_accuracy: 0.5973
#
# Epoch 00001: val_accuracy improved from -inf to 0.59732, saving model to ./models/tree_7/model_root_f1/folder10\model.h5
# Epoch 2/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.6457 - accuracy: 0.6336 - val_loss: 0.5483 - val_accuracy: 0.7047
#
# Epoch 00002: val_accuracy improved from 0.59732 to 0.70470, saving model to ./models/tree_7/model_root_f1/folder10\model.h5
# Epoch 3/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.5446 - accuracy: 0.7293 - val_loss: 0.7836 - val_accuracy: 0.6913
#
# Epoch 00003: val_accuracy did not improve from 0.70470
# Epoch 4/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.4743 - accuracy: 0.7800 - val_loss: 0.4053 - val_accuracy: 0.8031
#
# Epoch 00004: val_accuracy improved from 0.70470 to 0.80313, saving model to ./models/tree_7/model_root_f1/folder10\model.h5
# Epoch 5/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.3405 - accuracy: 0.8501 - val_loss: 0.3885 - val_accuracy: 0.8277
#
# Epoch 00005: val_accuracy improved from 0.80313 to 0.82774, saving model to ./models/tree_7/model_root_f1/folder10\model.h5
# Epoch 6/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.2852 - accuracy: 0.8812 - val_loss: 0.2958 - val_accuracy: 0.8770
#
# Epoch 00006: val_accuracy improved from 0.82774 to 0.87696, saving model to ./models/tree_7/model_root_f1/folder10\model.h5
# Epoch 7/30
# 126/126 [==============================] - 2s 17ms/step - loss: 0.2303 - accuracy: 0.9088 - val_loss: 0.2283 - val_accuracy: 0.9038
#
# Epoch 00007: val_accuracy improved from 0.87696 to 0.90380, saving model to ./models/tree_7/model_root_f1/folder10\model.h5
# Epoch 8/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1872 - accuracy: 0.9215 - val_loss: 0.2428 - val_accuracy: 0.8814
#
# Epoch 00008: val_accuracy did not improve from 0.90380
# Epoch 9/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1534 - accuracy: 0.9386 - val_loss: 0.1711 - val_accuracy: 0.9262
#
# Epoch 00009: val_accuracy improved from 0.90380 to 0.92617, saving model to ./models/tree_7/model_root_f1/folder10\model.h5
# Epoch 10/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1177 - accuracy: 0.9540 - val_loss: 0.2305 - val_accuracy: 0.9016
#
# Epoch 00010: val_accuracy did not improve from 0.92617
# Epoch 11/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1093 - accuracy: 0.9558 - val_loss: 0.1822 - val_accuracy: 0.9172
#
# Epoch 00011: val_accuracy did not improve from 0.92617
# Epoch 12/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.1060 - accuracy: 0.9555 - val_loss: 0.1784 - val_accuracy: 0.9396
#
# Epoch 00012: val_accuracy improved from 0.92617 to 0.93960, saving model to ./models/tree_7/model_root_f1/folder10\model.h5
# Epoch 13/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0611 - accuracy: 0.9771 - val_loss: 0.1834 - val_accuracy: 0.9351
#
# Epoch 00013: val_accuracy did not improve from 0.93960
# Epoch 14/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0489 - accuracy: 0.9819 - val_loss: 0.2516 - val_accuracy: 0.9083
#
# Epoch 00014: val_accuracy did not improve from 0.93960
# Epoch 15/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0364 - accuracy: 0.9876 - val_loss: 0.1714 - val_accuracy: 0.9508
#
# Epoch 00015: val_accuracy improved from 0.93960 to 0.95078, saving model to ./models/tree_7/model_root_f1/folder10\model.h5
# Epoch 16/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0178 - accuracy: 0.9953 - val_loss: 0.2780 - val_accuracy: 0.9262
#
# Epoch 00016: val_accuracy did not improve from 0.95078
# Epoch 17/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0158 - accuracy: 0.9950 - val_loss: 0.2382 - val_accuracy: 0.9351
#
# Epoch 00017: val_accuracy did not improve from 0.95078
# Epoch 18/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0273 - accuracy: 0.9925 - val_loss: 0.2597 - val_accuracy: 0.9217
#
# Epoch 00018: val_accuracy did not improve from 0.95078
# Epoch 19/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0591 - accuracy: 0.9806 - val_loss: 0.1941 - val_accuracy: 0.9374
#
# Epoch 00019: val_accuracy did not improve from 0.95078
# Epoch 20/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0056 - accuracy: 0.9995 - val_loss: 0.3144 - val_accuracy: 0.9284 0s - loss: 0
#
# Epoch 00020: val_accuracy did not improve from 0.95078
# Epoch 21/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0250 - accuracy: 0.9913 - val_loss: 0.2107 - val_accuracy: 0.9418
#
# Epoch 00021: val_accuracy did not improve from 0.95078
# Epoch 22/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0229 - accuracy: 0.9930 - val_loss: 0.4298 - val_accuracy: 0.8792
#
# Epoch 00022: val_accuracy did not improve from 0.95078
# Epoch 23/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0534 - accuracy: 0.9804 - val_loss: 0.2952 - val_accuracy: 0.9262
#
# Epoch 00023: val_accuracy did not improve from 0.95078
# Epoch 24/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0328 - accuracy: 0.9881 - val_loss: 0.2248 - val_accuracy: 0.9485
#
# Epoch 00024: val_accuracy did not improve from 0.95078
# Epoch 25/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0341 - accuracy: 0.9886 - val_loss: 0.2656 - val_accuracy: 0.9217
#
# Epoch 00025: val_accuracy did not improve from 0.95078
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 26/30
# 126/126 [==============================] - 2s 18ms/step - loss: 0.0074 - accuracy: 0.9980 - val_loss: 0.1813 - val_accuracy: 0.9418
#
# Epoch 00026: val_accuracy did not improve from 0.95078
# Epoch 27/30
# 126/126 [==============================] - 2s 18ms/step - loss: 9.0981e-04 - accuracy: 1.0000 - val_loss: 0.1914 - val_accuracy: 0.9396
#
# Epoch 00027: val_accuracy did not improve from 0.95078
# Epoch 28/30
# 126/126 [==============================] - 2s 18ms/step - loss: 6.8122e-04 - accuracy: 1.0000 - val_loss: 0.1943 - val_accuracy: 0.9418
#
# Epoch 00028: val_accuracy did not improve from 0.95078
# Epoch 29/30
# 126/126 [==============================] - 2s 18ms/step - loss: 5.1873e-04 - accuracy: 1.0000 - val_loss: 0.1961 - val_accuracy: 0.9441
#
# Epoch 00029: val_accuracy did not improve from 0.95078
# Epoch 30/30
# 126/126 [==============================] - 2s 18ms/step - loss: 3.9800e-04 - accuracy: 1.0000 - val_loss: 0.1997 - val_accuracy: 0.9418
#
# Epoch 00030: val_accuracy did not improve from 0.95078
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
