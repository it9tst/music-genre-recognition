# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7}
dict_genres = {'Electronic':0, 'Experimental':1, 'Hip-Hop':3, 'International' :5}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Electronic', 1: 'Experimental', 3: 'Hip-Hop', 5: 'International'}

# %%
npzfile = np.load('data/shuffled_train.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394,)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=8).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((3195, 640, 128), (3195, 8))

# %%
npzfile = np.load('data/shuffled_valid.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=8).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((400, 640, 128), (400, 8))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Experimental

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

BATCH_SIZE = 64
EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 640
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_1/model_root_f2/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_1/model_root_f2/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
def create_split(elem, c):
    splits = []
    for i in range(c):
        equal = False
        np.random.shuffle(elem)
        new_split = list(chunks(elem, int(len(elem)/2)))
        for split in splits:
            if set(new_split[0]) == set(split[0]) and set(new_split[0]) == set(split[1]):
                equal = True
                break
            
        if equal:
            i-=1
            continue
        
        splits.append(new_split)
        
    return splits

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 3

kfold = KFold(n_splits=8, shuffle=True)
genre_splits = create_split(list(dict_genres.values()), num_splits)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)

    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['International', 'Experimental'], ['Electronic', 'Hip-Hop']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 18s 143ms/step - loss: 1.4716 - accuracy: 0.5132 - val_loss: 0.6846 - val_accuracy: 0.6778
#
# Epoch 00001: val_accuracy improved from -inf to 0.67778, saving model to ./models/model_root_f2/folder1\model.h5
# Epoch 2/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6732 - accuracy: 0.5768 - val_loss: 0.6406 - val_accuracy: 0.6133
#
# Epoch 00002: val_accuracy did not improve from 0.67778
# Epoch 3/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.5838 - accuracy: 0.7237 - val_loss: 0.5706 - val_accuracy: 0.7822
#
# Epoch 00003: val_accuracy improved from 0.67778 to 0.78222, saving model to ./models/model_root_f2/folder1\model.h5
# Epoch 4/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.5145 - accuracy: 0.7714 - val_loss: 0.5039 - val_accuracy: 0.8044
#
# Epoch 00004: val_accuracy improved from 0.78222 to 0.80444, saving model to ./models/model_root_f2/folder1\model.h5
# Epoch 5/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.4751 - accuracy: 0.7990 - val_loss: 0.5085 - val_accuracy: 0.7844
#
# Epoch 00005: val_accuracy did not improve from 0.80444
# Epoch 6/30
# 50/50 [==============================] - 6s 125ms/step - loss: 0.4427 - accuracy: 0.8099 - val_loss: 0.4777 - val_accuracy: 0.8133
#
# Epoch 00006: val_accuracy improved from 0.80444 to 0.81333, saving model to ./models/model_root_f2/folder1\model.h5
# Epoch 7/30
# 50/50 [==============================] - 7s 132ms/step - loss: 0.4084 - accuracy: 0.8232 - val_loss: 0.4648 - val_accuracy: 0.8244
#
# Epoch 00007: val_accuracy improved from 0.81333 to 0.82444, saving model to ./models/model_root_f2/folder1\model.h5
# Epoch 8/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.3760 - accuracy: 0.8334 - val_loss: 0.5039 - val_accuracy: 0.8178
#
# Epoch 00008: val_accuracy did not improve from 0.82444
# Epoch 9/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.3573 - accuracy: 0.8442 - val_loss: 0.5105 - val_accuracy: 0.7867
#
# Epoch 00009: val_accuracy did not improve from 0.82444
# Epoch 10/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.3562 - accuracy: 0.8448 - val_loss: 0.4452 - val_accuracy: 0.8311
#
# Epoch 00010: val_accuracy improved from 0.82444 to 0.83111, saving model to ./models/model_root_f2/folder1\model.h5
# Epoch 11/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.2870 - accuracy: 0.8814 - val_loss: 0.6268 - val_accuracy: 0.7778
#
# Epoch 00011: val_accuracy did not improve from 0.83111
# Epoch 12/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.2606 - accuracy: 0.8922 - val_loss: 0.5724 - val_accuracy: 0.8089
#
# Epoch 00012: val_accuracy did not improve from 0.83111
# Epoch 13/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.2222 - accuracy: 0.9107 - val_loss: 0.5015 - val_accuracy: 0.7933
#
# Epoch 00013: val_accuracy did not improve from 0.83111
# Epoch 14/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.1921 - accuracy: 0.9218 - val_loss: 0.6243 - val_accuracy: 0.8111
#
# Epoch 00014: val_accuracy did not improve from 0.83111
# Epoch 15/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.1412 - accuracy: 0.9479 - val_loss: 0.6160 - val_accuracy: 0.8222
#
# Epoch 00015: val_accuracy did not improve from 0.83111
# Epoch 16/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.1130 - accuracy: 0.9577 - val_loss: 0.6639 - val_accuracy: 0.8400
#
# Epoch 00016: val_accuracy improved from 0.83111 to 0.84000, saving model to ./models/model_root_f2/folder1\model.h5
# Epoch 17/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0781 - accuracy: 0.9739 - val_loss: 0.7326 - val_accuracy: 0.8133
#
# Epoch 00017: val_accuracy did not improve from 0.84000
# Epoch 18/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.0637 - accuracy: 0.9828 - val_loss: 0.8640 - val_accuracy: 0.8311
#
# Epoch 00018: val_accuracy did not improve from 0.84000
# Epoch 19/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.0311 - accuracy: 0.9917 - val_loss: 0.9194 - val_accuracy: 0.8133
#
# Epoch 00019: val_accuracy did not improve from 0.84000
# Epoch 20/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.0523 - accuracy: 0.9806 - val_loss: 0.8599 - val_accuracy: 0.8067
#
# Epoch 00020: val_accuracy did not improve from 0.84000
# Epoch 21/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0333 - accuracy: 0.9921 - val_loss: 0.7926 - val_accuracy: 0.8222
#
# Epoch 00021: val_accuracy did not improve from 0.84000
# Epoch 22/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.0114 - accuracy: 0.9984 - val_loss: 0.9739 - val_accuracy: 0.8156
#
# Epoch 00022: val_accuracy did not improve from 0.84000
# Epoch 23/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0087 - accuracy: 0.9990 - val_loss: 0.9809 - val_accuracy: 0.8111
#
# Epoch 00023: val_accuracy did not improve from 0.84000
# Epoch 24/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0049 - accuracy: 0.9994 - val_loss: 1.2255 - val_accuracy: 0.8133
#
# Epoch 00024: val_accuracy did not improve from 0.84000
# Epoch 25/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0066 - accuracy: 0.9994 - val_loss: 1.0793 - val_accuracy: 0.8178
#
# Epoch 00025: val_accuracy did not improve from 0.84000
# Epoch 26/30
# 50/50 [==============================] - 7s 131ms/step - loss: 0.0072 - accuracy: 0.9990 - val_loss: 1.3981 - val_accuracy: 0.8022
#
# Epoch 00026: val_accuracy did not improve from 0.84000
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 27/30
# 50/50 [==============================] - 7s 143ms/step - loss: 0.0040 - accuracy: 0.9997 - val_loss: 1.0893 - val_accuracy: 0.8133
#
# Epoch 00027: val_accuracy did not improve from 0.84000
# Epoch 28/30
# 50/50 [==============================] - 6s 126ms/step - loss: 0.0035 - accuracy: 0.9994 - val_loss: 1.1500 - val_accuracy: 0.8111
#
# Epoch 00028: val_accuracy did not improve from 0.84000
# Epoch 29/30
# 50/50 [==============================] - 6s 126ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 1.1520 - val_accuracy: 0.8111
#
# Epoch 00029: val_accuracy did not improve from 0.84000
# Epoch 30/30
# 50/50 [==============================] - 6s 124ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 1.1991 - val_accuracy: 0.8178
#
# Epoch 00030: val_accuracy did not improve from 0.84000
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Hip-Hop', 'International'], ['Experimental', 'Electronic']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 8s 135ms/step - loss: 1.3081 - accuracy: 0.5141 - val_loss: 0.6868 - val_accuracy: 0.5333
#
# Epoch 00001: val_accuracy improved from -inf to 0.53333, saving model to ./models/model_root_f2/folder2\model.h5
# Epoch 2/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6844 - accuracy: 0.5399 - val_loss: 0.6986 - val_accuracy: 0.5333
#
# Epoch 00002: val_accuracy did not improve from 0.53333
# Epoch 3/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6843 - accuracy: 0.5679 - val_loss: 0.6458 - val_accuracy: 0.7333
#
# Epoch 00003: val_accuracy improved from 0.53333 to 0.73333, saving model to ./models/model_root_f2/folder2\model.h5
# Epoch 4/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6368 - accuracy: 0.6207 - val_loss: 0.5584 - val_accuracy: 0.7200
#
# Epoch 00004: val_accuracy did not improve from 0.73333
# Epoch 5/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6583 - accuracy: 0.6032 - val_loss: 0.5392 - val_accuracy: 0.7578
#
# Epoch 00005: val_accuracy improved from 0.73333 to 0.75778, saving model to ./models/model_root_f2/folder2\model.h5
# Epoch 6/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.5990 - accuracy: 0.6862 - val_loss: 0.5866 - val_accuracy: 0.6889
#
# Epoch 00006: val_accuracy did not improve from 0.75778
# Epoch 7/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.5908 - accuracy: 0.6789 - val_loss: 0.5293 - val_accuracy: 0.7089
#
# Epoch 00007: val_accuracy did not improve from 0.75778
# Epoch 8/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.5219 - accuracy: 0.7364 - val_loss: 0.8462 - val_accuracy: 0.5711
#
# Epoch 00008: val_accuracy did not improve from 0.75778
# Epoch 9/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.5371 - accuracy: 0.7323 - val_loss: 0.4793 - val_accuracy: 0.7711
#
# Epoch 00009: val_accuracy improved from 0.75778 to 0.77111, saving model to ./models/model_root_f2/folder2\model.h5
# Epoch 10/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.4848 - accuracy: 0.7568 - val_loss: 0.4604 - val_accuracy: 0.8067
#
# Epoch 00010: val_accuracy improved from 0.77111 to 0.80667, saving model to ./models/model_root_f2/folder2\model.h5
# Epoch 11/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.4759 - accuracy: 0.7704 - val_loss: 0.4549 - val_accuracy: 0.7911
#
# Epoch 00011: val_accuracy did not improve from 0.80667
# Epoch 12/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.4329 - accuracy: 0.7997 - val_loss: 0.5663 - val_accuracy: 0.7778
#
# Epoch 00012: val_accuracy did not improve from 0.80667
# Epoch 13/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.3998 - accuracy: 0.8203 - val_loss: 0.4828 - val_accuracy: 0.7756
#
# Epoch 00013: val_accuracy did not improve from 0.80667
# Epoch 14/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.3533 - accuracy: 0.8455 - val_loss: 0.4664 - val_accuracy: 0.7911
#
# Epoch 00014: val_accuracy did not improve from 0.80667
# Epoch 15/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.3369 - accuracy: 0.8566 - val_loss: 0.4721 - val_accuracy: 0.7911
#
# Epoch 00015: val_accuracy did not improve from 0.80667
# Epoch 16/30
# 50/50 [==============================] - 7s 136ms/step - loss: 0.3044 - accuracy: 0.8658 - val_loss: 0.5160 - val_accuracy: 0.7733
#
# Epoch 00016: val_accuracy did not improve from 0.80667
# Epoch 17/30
# 50/50 [==============================] - 7s 138ms/step - loss: 0.2658 - accuracy: 0.8938 - val_loss: 0.4735 - val_accuracy: 0.8089
#
# Epoch 00017: val_accuracy improved from 0.80667 to 0.80889, saving model to ./models/model_root_f2/folder2\model.h5
# Epoch 18/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.2630 - accuracy: 0.8890 - val_loss: 0.6095 - val_accuracy: 0.7222
#
# Epoch 00018: val_accuracy did not improve from 0.80889
# Epoch 19/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.2392 - accuracy: 0.9065 - val_loss: 0.6025 - val_accuracy: 0.7778
#
# Epoch 00019: val_accuracy did not improve from 0.80889
# Epoch 20/30
# 50/50 [==============================] - 6s 126ms/step - loss: 0.1637 - accuracy: 0.9320 - val_loss: 0.6799 - val_accuracy: 0.7644
#
# Epoch 00020: val_accuracy did not improve from 0.80889
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.0971 - accuracy: 0.9707 - val_loss: 0.7377 - val_accuracy: 0.7578
#
# Epoch 00021: val_accuracy did not improve from 0.80889
# Epoch 22/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.0691 - accuracy: 0.9819 - val_loss: 0.8189 - val_accuracy: 0.7822
#
# Epoch 00022: val_accuracy did not improve from 0.80889
# Epoch 23/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0500 - accuracy: 0.9901 - val_loss: 0.9088 - val_accuracy: 0.7622
#
# Epoch 00023: val_accuracy did not improve from 0.80889
# Epoch 24/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.0374 - accuracy: 0.9952 - val_loss: 0.9203 - val_accuracy: 0.7778
#
# Epoch 00024: val_accuracy did not improve from 0.80889
# Epoch 25/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0296 - accuracy: 0.9955 - val_loss: 0.9864 - val_accuracy: 0.7822
#
# Epoch 00025: val_accuracy did not improve from 0.80889
# Epoch 26/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0235 - accuracy: 0.9978 - val_loss: 1.0561 - val_accuracy: 0.7800
#
# Epoch 00026: val_accuracy did not improve from 0.80889
# Epoch 27/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0140 - accuracy: 0.9987 - val_loss: 1.1674 - val_accuracy: 0.7778
#
# Epoch 00027: val_accuracy did not improve from 0.80889
# Epoch 28/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0218 - accuracy: 0.9965 - val_loss: 1.1773 - val_accuracy: 0.7689
#
# Epoch 00028: val_accuracy did not improve from 0.80889
# Epoch 29/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0092 - accuracy: 0.9997 - val_loss: 1.2404 - val_accuracy: 0.7800
#
# Epoch 00029: val_accuracy did not improve from 0.80889
# Epoch 30/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.0105 - accuracy: 0.9990 - val_loss: 1.2646 - val_accuracy: 0.7844
#
# Epoch 00030: val_accuracy did not improve from 0.80889
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Electronic', 'Experimental'], ['Hip-Hop', 'International']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 7s 130ms/step - loss: 1.0089 - accuracy: 0.5482 - val_loss: 0.6835 - val_accuracy: 0.5378
#
# Epoch 00001: val_accuracy improved from -inf to 0.53778, saving model to ./models/model_root_f2/folder3\model.h5
# Epoch 2/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6589 - accuracy: 0.6003 - val_loss: 0.6754 - val_accuracy: 0.5778
#
# Epoch 00002: val_accuracy improved from 0.53778 to 0.57778, saving model to ./models/model_root_f2/folder3\model.h5
# Epoch 3/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.5647 - accuracy: 0.7075 - val_loss: 0.5121 - val_accuracy: 0.7378
#
# Epoch 00003: val_accuracy improved from 0.57778 to 0.73778, saving model to ./models/model_root_f2/folder3\model.h5
# Epoch 4/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.4911 - accuracy: 0.7644 - val_loss: 0.5407 - val_accuracy: 0.7378
#
# Epoch 00004: val_accuracy did not improve from 0.73778
# Epoch 5/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.4781 - accuracy: 0.7692 - val_loss: 0.5052 - val_accuracy: 0.7756
#
# Epoch 00005: val_accuracy improved from 0.73778 to 0.77556, saving model to ./models/model_root_f2/folder3\model.h5
# Epoch 6/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.4819 - accuracy: 0.7704 - val_loss: 0.6911 - val_accuracy: 0.6400
#
# Epoch 00006: val_accuracy did not improve from 0.77556
# Epoch 7/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.5123 - accuracy: 0.7548 - val_loss: 0.4668 - val_accuracy: 0.7889
#
# Epoch 00007: val_accuracy improved from 0.77556 to 0.78889, saving model to ./models/model_root_f2/folder3\model.h5
# Epoch 8/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.4468 - accuracy: 0.7946 - val_loss: 0.5240 - val_accuracy: 0.7578
#
# Epoch 00008: val_accuracy did not improve from 0.78889
# Epoch 9/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.3941 - accuracy: 0.8223 - val_loss: 0.4908 - val_accuracy: 0.7933
#
# Epoch 00009: val_accuracy improved from 0.78889 to 0.79333, saving model to ./models/model_root_f2/folder3\model.h5
# Epoch 10/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.3632 - accuracy: 0.8397 - val_loss: 0.5077 - val_accuracy: 0.7778
#
# Epoch 00010: val_accuracy did not improve from 0.79333
# Epoch 11/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.3372 - accuracy: 0.8499 - val_loss: 0.4874 - val_accuracy: 0.8022
#
# Epoch 00011: val_accuracy improved from 0.79333 to 0.80222, saving model to ./models/model_root_f2/folder3\model.h5
# Epoch 12/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.2860 - accuracy: 0.8674 - val_loss: 0.5398 - val_accuracy: 0.8000
#
# Epoch 00012: val_accuracy did not improve from 0.80222
# Epoch 13/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.2428 - accuracy: 0.9002 - val_loss: 0.5689 - val_accuracy: 0.7889
#
# Epoch 00013: val_accuracy did not improve from 0.80222
# Epoch 14/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.2141 - accuracy: 0.9122 - val_loss: 0.6456 - val_accuracy: 0.7778
#
# Epoch 00014: val_accuracy did not improve from 0.80222
# Epoch 15/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.1629 - accuracy: 0.9393 - val_loss: 0.7634 - val_accuracy: 0.7289
#
# Epoch 00015: val_accuracy did not improve from 0.80222
# Epoch 16/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.1736 - accuracy: 0.9342 - val_loss: 0.8334 - val_accuracy: 0.7556
#
# Epoch 00016: val_accuracy did not improve from 0.80222
# Epoch 17/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.1453 - accuracy: 0.9444 - val_loss: 0.8236 - val_accuracy: 0.7578
#
# Epoch 00017: val_accuracy did not improve from 0.80222
# Epoch 18/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.1012 - accuracy: 0.9660 - val_loss: 0.7874 - val_accuracy: 0.7889
#
# Epoch 00018: val_accuracy did not improve from 0.80222
# Epoch 19/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0723 - accuracy: 0.9768 - val_loss: 0.9528 - val_accuracy: 0.7600
#
# Epoch 00019: val_accuracy did not improve from 0.80222
# Epoch 20/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.0535 - accuracy: 0.9835 - val_loss: 1.0889 - val_accuracy: 0.7667
#
# Epoch 00020: val_accuracy did not improve from 0.80222
# Epoch 21/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.0261 - accuracy: 0.9940 - val_loss: 0.9736 - val_accuracy: 0.7622
#
# Epoch 00021: val_accuracy did not improve from 0.80222
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 22/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0160 - accuracy: 0.9984 - val_loss: 1.0512 - val_accuracy: 0.7733
#
# Epoch 00022: val_accuracy did not improve from 0.80222
# Epoch 23/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0070 - accuracy: 0.9997 - val_loss: 1.0938 - val_accuracy: 0.7822
#
# Epoch 00023: val_accuracy did not improve from 0.80222
# Epoch 24/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.0062 - accuracy: 0.9997 - val_loss: 1.1575 - val_accuracy: 0.7822
#
# Epoch 00024: val_accuracy did not improve from 0.80222
# Epoch 25/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.0071 - accuracy: 0.9994 - val_loss: 1.1560 - val_accuracy: 0.7711
#
# Epoch 00025: val_accuracy did not improve from 0.80222
# Epoch 26/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.0042 - accuracy: 0.9997 - val_loss: 1.1435 - val_accuracy: 0.7778
#
# Epoch 00026: val_accuracy did not improve from 0.80222
# Epoch 27/30
# 50/50 [==============================] - 6s 125ms/step - loss: 0.0062 - accuracy: 0.9994 - val_loss: 1.1590 - val_accuracy: 0.7800
#
# Epoch 00027: val_accuracy did not improve from 0.80222
# Epoch 28/30
# 50/50 [==============================] - 6s 125ms/step - loss: 0.0061 - accuracy: 0.9994 - val_loss: 1.1788 - val_accuracy: 0.7822
#
# Epoch 00028: val_accuracy did not improve from 0.80222
# Epoch 29/30
# 50/50 [==============================] - 6s 128ms/step - loss: 0.0042 - accuracy: 0.9997 - val_loss: 1.1991 - val_accuracy: 0.7822
#
# Epoch 00029: val_accuracy did not improve from 0.80222
# Epoch 30/30
# 50/50 [==============================] - 6s 125ms/step - loss: 0.0033 - accuracy: 0.9997 - val_loss: 1.1994 - val_accuracy: 0.7889
#
# Epoch 00030: val_accuracy did not improve from 0.80222
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Experimental', 'Electronic'], ['Hip-Hop', 'International']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 8s 141ms/step - loss: 1.1692 - accuracy: 0.5502 - val_loss: 0.6591 - val_accuracy: 0.7149
#
# Epoch 00001: val_accuracy improved from -inf to 0.71492, saving model to ./models/model_root_f2/folder4\model.h5
# Epoch 2/30
# 50/50 [==============================] - 6s 124ms/step - loss: 0.6851 - accuracy: 0.5744 - val_loss: 0.6529 - val_accuracy: 0.6192
#
# Epoch 00002: val_accuracy did not improve from 0.71492
# Epoch 3/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6213 - accuracy: 0.6599 - val_loss: 0.5827 - val_accuracy: 0.6993
#
# Epoch 00003: val_accuracy did not improve from 0.71492
# Epoch 4/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6051 - accuracy: 0.6745 - val_loss: 0.5987 - val_accuracy: 0.7194
#
# Epoch 00004: val_accuracy improved from 0.71492 to 0.71938, saving model to ./models/model_root_f2/folder4\model.h5
# Epoch 5/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6409 - accuracy: 0.6405 - val_loss: 0.6167 - val_accuracy: 0.6860
#
# Epoch 00005: val_accuracy did not improve from 0.71938
# Epoch 6/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.5941 - accuracy: 0.6799 - val_loss: 0.5019 - val_accuracy: 0.7528
#
# Epoch 00006: val_accuracy improved from 0.71938 to 0.75278, saving model to ./models/model_root_f2/folder4\model.h5
# Epoch 7/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.5292 - accuracy: 0.7406 - val_loss: 0.4928 - val_accuracy: 0.7840
#
# Epoch 00007: val_accuracy improved from 0.75278 to 0.78396, saving model to ./models/model_root_f2/folder4\model.h5
# Epoch 8/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.5286 - accuracy: 0.7359 - val_loss: 0.4605 - val_accuracy: 0.7817
#
# Epoch 00008: val_accuracy did not improve from 0.78396
# Epoch 9/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.4760 - accuracy: 0.7746 - val_loss: 0.4314 - val_accuracy: 0.8062
#
# Epoch 00009: val_accuracy improved from 0.78396 to 0.80624, saving model to ./models/model_root_f2/folder4\model.h5
# Epoch 10/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.4626 - accuracy: 0.7816 - val_loss: 0.5956 - val_accuracy: 0.6904
#
# Epoch 00010: val_accuracy did not improve from 0.80624
# Epoch 11/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.4841 - accuracy: 0.7645 - val_loss: 0.4989 - val_accuracy: 0.7706
#
# Epoch 00011: val_accuracy did not improve from 0.80624
# Epoch 12/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.4419 - accuracy: 0.7956 - val_loss: 0.4295 - val_accuracy: 0.8107
#
# Epoch 00012: val_accuracy improved from 0.80624 to 0.81069, saving model to ./models/model_root_f2/folder4\model.h5
# Epoch 13/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.4221 - accuracy: 0.7978 - val_loss: 0.3946 - val_accuracy: 0.8241
#
# Epoch 00013: val_accuracy improved from 0.81069 to 0.82405, saving model to ./models/model_root_f2/folder4\model.h5
# Epoch 14/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.3994 - accuracy: 0.8226 - val_loss: 0.3991 - val_accuracy: 0.8241
#
# Epoch 00014: val_accuracy did not improve from 0.82405
# Epoch 15/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.3914 - accuracy: 0.8293 - val_loss: 0.4226 - val_accuracy: 0.8062
#
# Epoch 00015: val_accuracy did not improve from 0.82405
# Epoch 16/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.3356 - accuracy: 0.8573 - val_loss: 0.4174 - val_accuracy: 0.8285
#
# Epoch 00016: val_accuracy improved from 0.82405 to 0.82851, saving model to ./models/model_root_f2/folder4\model.h5
# Epoch 17/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.2930 - accuracy: 0.8681 - val_loss: 0.4130 - val_accuracy: 0.8352
#
# Epoch 00017: val_accuracy improved from 0.82851 to 0.83519, saving model to ./models/model_root_f2/folder4\model.h5
# Epoch 18/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.2775 - accuracy: 0.8830 - val_loss: 0.4295 - val_accuracy: 0.8307
#
# Epoch 00018: val_accuracy did not improve from 0.83519
# Epoch 19/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.2110 - accuracy: 0.9167 - val_loss: 0.4547 - val_accuracy: 0.8174
#
# Epoch 00019: val_accuracy did not improve from 0.83519
# Epoch 20/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.2004 - accuracy: 0.9215 - val_loss: 0.5103 - val_accuracy: 0.8307
#
# Epoch 00020: val_accuracy did not improve from 0.83519
# Epoch 21/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.1635 - accuracy: 0.9371 - val_loss: 0.6108 - val_accuracy: 0.8062
#
# Epoch 00021: val_accuracy did not improve from 0.83519
# Epoch 22/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.1313 - accuracy: 0.9504 - val_loss: 0.6917 - val_accuracy: 0.7795
#
# Epoch 00022: val_accuracy did not improve from 0.83519
# Epoch 23/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.1121 - accuracy: 0.9628 - val_loss: 0.6107 - val_accuracy: 0.8174
#
# Epoch 00023: val_accuracy did not improve from 0.83519
# Epoch 24/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0670 - accuracy: 0.9819 - val_loss: 0.8596 - val_accuracy: 0.7817
#
# Epoch 00024: val_accuracy did not improve from 0.83519
# Epoch 25/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0671 - accuracy: 0.9774 - val_loss: 0.9693 - val_accuracy: 0.7817
#
# Epoch 00025: val_accuracy did not improve from 0.83519
# Epoch 26/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0283 - accuracy: 0.9943 - val_loss: 0.8170 - val_accuracy: 0.8151
#
# Epoch 00026: val_accuracy did not improve from 0.83519
# Epoch 27/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0187 - accuracy: 0.9975 - val_loss: 1.1368 - val_accuracy: 0.7639
#
# Epoch 00027: val_accuracy did not improve from 0.83519
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 28/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.0189 - accuracy: 0.9952 - val_loss: 0.9725 - val_accuracy: 0.7951
#
# Epoch 00028: val_accuracy did not improve from 0.83519
# Epoch 29/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.0079 - accuracy: 0.9990 - val_loss: 0.9749 - val_accuracy: 0.7951
#
# Epoch 00029: val_accuracy did not improve from 0.83519
# Epoch 30/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0048 - accuracy: 0.9997 - val_loss: 1.0347 - val_accuracy: 0.7951
#
# Epoch 00030: val_accuracy did not improve from 0.83519
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 5
# Genre split [['Hip-Hop', 'Experimental'], ['International', 'Electronic']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 7s 128ms/step - loss: 1.5751 - accuracy: 0.5254 - val_loss: 0.6927 - val_accuracy: 0.4878
#
# Epoch 00001: val_accuracy improved from -inf to 0.48775, saving model to ./models/model_root_f2/folder5\model.h5
# Epoch 2/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6920 - accuracy: 0.5270 - val_loss: 0.6684 - val_accuracy: 0.6058
#
# Epoch 00002: val_accuracy improved from 0.48775 to 0.60579, saving model to ./models/model_root_f2/folder5\model.h5
# Epoch 3/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6724 - accuracy: 0.5963 - val_loss: 0.6290 - val_accuracy: 0.6325
#
# Epoch 00003: val_accuracy improved from 0.60579 to 0.63252, saving model to ./models/model_root_f2/folder5\model.h5
# Epoch 4/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6626 - accuracy: 0.6100 - val_loss: 0.6783 - val_accuracy: 0.5367
#
# Epoch 00004: val_accuracy did not improve from 0.63252
# Epoch 5/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6523 - accuracy: 0.6128 - val_loss: 0.6032 - val_accuracy: 0.6615
#
# Epoch 00005: val_accuracy improved from 0.63252 to 0.66147, saving model to ./models/model_root_f2/folder5\model.h5
# Epoch 6/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6447 - accuracy: 0.6364 - val_loss: 0.6442 - val_accuracy: 0.5768
#
# Epoch 00006: val_accuracy did not improve from 0.66147
# Epoch 7/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6172 - accuracy: 0.6599 - val_loss: 0.5839 - val_accuracy: 0.6793
#
# Epoch 00007: val_accuracy improved from 0.66147 to 0.67929, saving model to ./models/model_root_f2/folder5\model.h5
# Epoch 8/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.5825 - accuracy: 0.6983 - val_loss: 0.6346 - val_accuracy: 0.5880
#
# Epoch 00008: val_accuracy did not improve from 0.67929
# Epoch 9/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.5755 - accuracy: 0.7022 - val_loss: 0.5502 - val_accuracy: 0.7506
#
# Epoch 00009: val_accuracy improved from 0.67929 to 0.75056, saving model to ./models/model_root_f2/folder5\model.h5
# Epoch 10/30
# 50/50 [==============================] - 6s 124ms/step - loss: 0.5659 - accuracy: 0.7085 - val_loss: 0.5522 - val_accuracy: 0.7082
#
# Epoch 00010: val_accuracy did not improve from 0.75056
# Epoch 11/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.5447 - accuracy: 0.7187 - val_loss: 0.5599 - val_accuracy: 0.6860
#
# Epoch 00011: val_accuracy did not improve from 0.75056
# Epoch 12/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.5148 - accuracy: 0.7540 - val_loss: 0.5410 - val_accuracy: 0.7216
#
# Epoch 00012: val_accuracy did not improve from 0.75056
# Epoch 13/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.4579 - accuracy: 0.7889 - val_loss: 0.7185 - val_accuracy: 0.6370
#
# Epoch 00013: val_accuracy did not improve from 0.75056
# Epoch 14/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.4204 - accuracy: 0.8048 - val_loss: 0.5170 - val_accuracy: 0.7483
#
# Epoch 00014: val_accuracy did not improve from 0.75056
# Epoch 15/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.3772 - accuracy: 0.8350 - val_loss: 0.6533 - val_accuracy: 0.6904
#
# Epoch 00015: val_accuracy did not improve from 0.75056
# Epoch 16/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.3152 - accuracy: 0.8671 - val_loss: 0.6439 - val_accuracy: 0.6837
#
# Epoch 00016: val_accuracy did not improve from 0.75056
# Epoch 17/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.2659 - accuracy: 0.8875 - val_loss: 0.6576 - val_accuracy: 0.7261
#
# Epoch 00017: val_accuracy did not improve from 0.75056
# Epoch 18/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.2398 - accuracy: 0.9015 - val_loss: 0.8063 - val_accuracy: 0.6481
#
# Epoch 00018: val_accuracy did not improve from 0.75056
# Epoch 19/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.1688 - accuracy: 0.9358 - val_loss: 1.0338 - val_accuracy: 0.6481
#
# Epoch 00019: val_accuracy did not improve from 0.75056
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0896 - accuracy: 0.9720 - val_loss: 0.9216 - val_accuracy: 0.7283
#
# Epoch 00020: val_accuracy did not improve from 0.75056
# Epoch 21/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0524 - accuracy: 0.9886 - val_loss: 1.0405 - val_accuracy: 0.7171
#
# Epoch 00021: val_accuracy did not improve from 0.75056
# Epoch 22/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0408 - accuracy: 0.9921 - val_loss: 1.1385 - val_accuracy: 0.7149
#
# Epoch 00022: val_accuracy did not improve from 0.75056
# Epoch 23/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.0212 - accuracy: 0.9975 - val_loss: 1.2824 - val_accuracy: 0.6949
#
# Epoch 00023: val_accuracy did not improve from 0.75056
# Epoch 24/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0134 - accuracy: 0.9994 - val_loss: 1.3024 - val_accuracy: 0.6949
#
# Epoch 00024: val_accuracy did not improve from 0.75056
# Epoch 25/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.0083 - accuracy: 0.9997 - val_loss: 1.4666 - val_accuracy: 0.6904
#
# Epoch 00025: val_accuracy did not improve from 0.75056
# Epoch 26/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.0058 - accuracy: 0.9997 - val_loss: 1.3907 - val_accuracy: 0.7216
#
# Epoch 00026: val_accuracy did not improve from 0.75056
# Epoch 27/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.0048 - accuracy: 0.9997 - val_loss: 1.5101 - val_accuracy: 0.7016
#
# Epoch 00027: val_accuracy did not improve from 0.75056
# Epoch 28/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.0030 - accuracy: 0.9997 - val_loss: 1.5383 - val_accuracy: 0.7060
#
# Epoch 00028: val_accuracy did not improve from 0.75056
# Epoch 29/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.5859 - val_accuracy: 0.7060
#
# Epoch 00029: val_accuracy did not improve from 0.75056
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 30/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.6311 - val_accuracy: 0.6971
#
# Epoch 00030: val_accuracy did not improve from 0.75056
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 6
# Genre split [['Electronic', 'International'], ['Experimental', 'Hip-Hop']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 7s 128ms/step - loss: 2.1169 - accuracy: 0.4774 - val_loss: 0.6895 - val_accuracy: 0.5323
#
# Epoch 00001: val_accuracy improved from -inf to 0.53229, saving model to ./models/model_root_f2/folder6\model.h5
# Epoch 2/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.7006 - accuracy: 0.5178 - val_loss: 0.6929 - val_accuracy: 0.5345
#
# Epoch 00002: val_accuracy improved from 0.53229 to 0.53452, saving model to ./models/model_root_f2/folder6\model.h5
# Epoch 3/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6934 - accuracy: 0.5048 - val_loss: 0.6949 - val_accuracy: 0.4677
#
# Epoch 00003: val_accuracy did not improve from 0.53452
# Epoch 4/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6953 - accuracy: 0.4987 - val_loss: 0.6986 - val_accuracy: 0.4677
#
# Epoch 00004: val_accuracy did not improve from 0.53452
# Epoch 5/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6942 - accuracy: 0.4936 - val_loss: 0.6922 - val_accuracy: 0.5323
#
# Epoch 00005: val_accuracy did not improve from 0.53452
# Epoch 6/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6938 - accuracy: 0.4857 - val_loss: 0.6914 - val_accuracy: 0.5323
#
# Epoch 00006: val_accuracy did not improve from 0.53452
# Epoch 7/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6937 - accuracy: 0.4911 - val_loss: 0.6973 - val_accuracy: 0.4677
#
# Epoch 00007: val_accuracy did not improve from 0.53452
# Epoch 8/30
# 50/50 [==============================] - 6s 124ms/step - loss: 0.6936 - accuracy: 0.4949 - val_loss: 0.6934 - val_accuracy: 0.4677
#
# Epoch 00008: val_accuracy did not improve from 0.53452
# Epoch 9/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6933 - accuracy: 0.4984 - val_loss: 0.6941 - val_accuracy: 0.4677
#
# Epoch 00009: val_accuracy did not improve from 0.53452
# Epoch 10/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6930 - accuracy: 0.5070 - val_loss: 0.7055 - val_accuracy: 0.4677
#
# Epoch 00010: val_accuracy did not improve from 0.53452
# Epoch 11/30
# 50/50 [==============================] - 6s 124ms/step - loss: 0.6896 - accuracy: 0.5216 - val_loss: 0.6863 - val_accuracy: 0.5991
#
# Epoch 00011: val_accuracy improved from 0.53452 to 0.59911, saving model to ./models/model_root_f2/folder6\model.h5
# Epoch 12/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6940 - accuracy: 0.5057 - val_loss: 0.6951 - val_accuracy: 0.4677
#
# Epoch 00012: val_accuracy did not improve from 0.59911
# Epoch 13/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6969 - accuracy: 0.4952 - val_loss: 0.6936 - val_accuracy: 0.4677
#
# Epoch 00013: val_accuracy did not improve from 0.59911
# Epoch 14/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6933 - accuracy: 0.4962 - val_loss: 0.6967 - val_accuracy: 0.4677
#
# Epoch 00014: val_accuracy did not improve from 0.59911
# Epoch 15/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6937 - accuracy: 0.5048 - val_loss: 0.6941 - val_accuracy: 0.4677
#
# Epoch 00015: val_accuracy did not improve from 0.59911
# Epoch 16/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6933 - accuracy: 0.5051 - val_loss: 0.6935 - val_accuracy: 0.4677
#
# Epoch 00016: val_accuracy did not improve from 0.59911
# Epoch 17/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6937 - accuracy: 0.4930 - val_loss: 0.6927 - val_accuracy: 0.5323
#
# Epoch 00017: val_accuracy did not improve from 0.59911
# Epoch 18/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6932 - accuracy: 0.4905 - val_loss: 0.6934 - val_accuracy: 0.4655
#
# Epoch 00018: val_accuracy did not improve from 0.59911
# Epoch 19/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6932 - accuracy: 0.4975 - val_loss: 0.6934 - val_accuracy: 0.4677
#
# Epoch 00019: val_accuracy did not improve from 0.59911
# Epoch 20/30
# 50/50 [==============================] - 6s 124ms/step - loss: 0.6931 - accuracy: 0.5057 - val_loss: 0.6936 - val_accuracy: 0.4677
#
# Epoch 00020: val_accuracy did not improve from 0.59911
# Epoch 21/30
# 50/50 [==============================] - 6s 124ms/step - loss: 0.6933 - accuracy: 0.5051 - val_loss: 0.6942 - val_accuracy: 0.4677
#
# Epoch 00021: val_accuracy did not improve from 0.59911
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 22/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6931 - accuracy: 0.5051 - val_loss: 0.6937 - val_accuracy: 0.4677
#
# Epoch 00022: val_accuracy did not improve from 0.59911
# Epoch 23/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6931 - accuracy: 0.5051 - val_loss: 0.6938 - val_accuracy: 0.4677
#
# Epoch 00023: val_accuracy did not improve from 0.59911
# Epoch 24/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6931 - accuracy: 0.5051 - val_loss: 0.6936 - val_accuracy: 0.4677
#
# Epoch 00024: val_accuracy did not improve from 0.59911
# Epoch 25/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6931 - accuracy: 0.5051 - val_loss: 0.6938 - val_accuracy: 0.4677
#
# Epoch 00025: val_accuracy did not improve from 0.59911
# Epoch 26/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6931 - accuracy: 0.5051 - val_loss: 0.6940 - val_accuracy: 0.4677
#
# Epoch 00026: val_accuracy did not improve from 0.59911
# Epoch 27/30
# 50/50 [==============================] - 6s 124ms/step - loss: 0.6931 - accuracy: 0.5051 - val_loss: 0.6939 - val_accuracy: 0.4677
#
# Epoch 00027: val_accuracy did not improve from 0.59911
# Epoch 28/30
# 50/50 [==============================] - 6s 124ms/step - loss: 0.6931 - accuracy: 0.5051 - val_loss: 0.6940 - val_accuracy: 0.4677
#
# Epoch 00028: val_accuracy did not improve from 0.59911
# Epoch 29/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6932 - accuracy: 0.5051 - val_loss: 0.6942 - val_accuracy: 0.4677
#
# Epoch 00029: val_accuracy did not improve from 0.59911
# Epoch 30/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6931 - accuracy: 0.5051 - val_loss: 0.6938 - val_accuracy: 0.4677
#
# Epoch 00030: val_accuracy did not improve from 0.59911
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 7
# Genre split [['Experimental', 'Hip-Hop'], ['International', 'Electronic']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 7s 129ms/step - loss: 1.5058 - accuracy: 0.4940 - val_loss: 0.6981 - val_accuracy: 0.4788
#
# Epoch 00001: val_accuracy improved from -inf to 0.47884, saving model to ./models/model_root_f2/folder7\model.h5
# Epoch 2/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6954 - accuracy: 0.5200 - val_loss: 0.6925 - val_accuracy: 0.4989
#
# Epoch 00002: val_accuracy improved from 0.47884 to 0.49889, saving model to ./models/model_root_f2/folder7\model.h5
# Epoch 3/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6916 - accuracy: 0.5242 - val_loss: 0.6978 - val_accuracy: 0.5212
#
# Epoch 00003: val_accuracy improved from 0.49889 to 0.52116, saving model to ./models/model_root_f2/folder7\model.h5
# Epoch 4/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.7004 - accuracy: 0.5140 - val_loss: 0.6941 - val_accuracy: 0.4811
#
# Epoch 00004: val_accuracy did not improve from 0.52116
# Epoch 5/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6938 - accuracy: 0.5143 - val_loss: 0.6923 - val_accuracy: 0.5212
#
# Epoch 00005: val_accuracy did not improve from 0.52116
# Epoch 6/30
# 50/50 [==============================] - 6s 124ms/step - loss: 0.6954 - accuracy: 0.5232 - val_loss: 0.6954 - val_accuracy: 0.4788
#
# Epoch 00006: val_accuracy did not improve from 0.52116
# Epoch 7/30
# 50/50 [==============================] - 7s 136ms/step - loss: 0.6917 - accuracy: 0.5175 - val_loss: 0.6879 - val_accuracy: 0.5367
#
# Epoch 00007: val_accuracy improved from 0.52116 to 0.53675, saving model to ./models/model_root_f2/folder7\model.h5
# Epoch 8/30
# 50/50 [==============================] - 6s 130ms/step - loss: 0.7123 - accuracy: 0.5149 - val_loss: 0.6952 - val_accuracy: 0.5212
#
# Epoch 00008: val_accuracy did not improve from 0.53675
# Epoch 9/30
# 50/50 [==============================] - 6s 130ms/step - loss: 0.6888 - accuracy: 0.5343 - val_loss: 0.7145 - val_accuracy: 0.5345
#
# Epoch 00009: val_accuracy did not improve from 0.53675
# Epoch 10/30
# 50/50 [==============================] - 6s 129ms/step - loss: 0.6798 - accuracy: 0.5830 - val_loss: 0.6863 - val_accuracy: 0.5635
#
# Epoch 00010: val_accuracy improved from 0.53675 to 0.56347, saving model to ./models/model_root_f2/folder7\model.h5
# Epoch 11/30
# 50/50 [==============================] - 6s 130ms/step - loss: 0.6689 - accuracy: 0.5957 - val_loss: 0.7077 - val_accuracy: 0.5791
#
# Epoch 00011: val_accuracy improved from 0.56347 to 0.57906, saving model to ./models/model_root_f2/folder7\model.h5
# Epoch 12/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6791 - accuracy: 0.5807 - val_loss: 0.6734 - val_accuracy: 0.5746
#
# Epoch 00012: val_accuracy did not improve from 0.57906
# Epoch 13/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6639 - accuracy: 0.6157 - val_loss: 0.6749 - val_accuracy: 0.6058
#
# Epoch 00013: val_accuracy improved from 0.57906 to 0.60579, saving model to ./models/model_root_f2/folder7\model.h5
# Epoch 14/30
# 50/50 [==============================] - 7s 131ms/step - loss: 0.6630 - accuracy: 0.6093 - val_loss: 0.6579 - val_accuracy: 0.6214
#
# Epoch 00014: val_accuracy improved from 0.60579 to 0.62138, saving model to ./models/model_root_f2/folder7\model.h5
# Epoch 15/30
# 50/50 [==============================] - 7s 140ms/step - loss: 0.6639 - accuracy: 0.6036 - val_loss: 0.7136 - val_accuracy: 0.5122
#
# Epoch 00015: val_accuracy did not improve from 0.62138
# Epoch 16/30
# 50/50 [==============================] - 7s 138ms/step - loss: 0.6471 - accuracy: 0.6217 - val_loss: 0.6473 - val_accuracy: 0.6347
#
# Epoch 00016: val_accuracy improved from 0.62138 to 0.63474, saving model to ./models/model_root_f2/folder7\model.h5
# Epoch 17/30
# 50/50 [==============================] - 7s 138ms/step - loss: 0.6103 - accuracy: 0.6688 - val_loss: 0.6559 - val_accuracy: 0.6526
#
# Epoch 00017: val_accuracy improved from 0.63474 to 0.65256, saving model to ./models/model_root_f2/folder7\model.h5
# Epoch 18/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.5962 - accuracy: 0.6723 - val_loss: 0.6588 - val_accuracy: 0.6481
#
# Epoch 00018: val_accuracy did not improve from 0.65256
# Epoch 19/30
# 50/50 [==============================] - 6s 121ms/step - loss: 0.5912 - accuracy: 0.6856 - val_loss: 0.7025 - val_accuracy: 0.5657
#
# Epoch 00019: val_accuracy did not improve from 0.65256
# Epoch 20/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6054 - accuracy: 0.6707 - val_loss: 0.6514 - val_accuracy: 0.6414
#
# Epoch 00020: val_accuracy did not improve from 0.65256
# Epoch 21/30
# 50/50 [==============================] - 7s 132ms/step - loss: 0.5748 - accuracy: 0.6952 - val_loss: 0.6353 - val_accuracy: 0.6682
#
# Epoch 00021: val_accuracy improved from 0.65256 to 0.66815, saving model to ./models/model_root_f2/folder7\model.h5
# Epoch 22/30
# 50/50 [==============================] - 7s 135ms/step - loss: 0.5557 - accuracy: 0.7231 - val_loss: 0.6923 - val_accuracy: 0.6526
#
# Epoch 00022: val_accuracy did not improve from 0.66815
# Epoch 23/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.5288 - accuracy: 0.7301 - val_loss: 0.6478 - val_accuracy: 0.6637
#
# Epoch 00023: val_accuracy did not improve from 0.66815
# Epoch 24/30
# 50/50 [==============================] - 7s 134ms/step - loss: 0.5216 - accuracy: 0.7419 - val_loss: 0.6337 - val_accuracy: 0.6993
#
# Epoch 00024: val_accuracy improved from 0.66815 to 0.69933, saving model to ./models/model_root_f2/folder7\model.h5
# Epoch 25/30
# 50/50 [==============================] - 7s 138ms/step - loss: 0.5210 - accuracy: 0.7387 - val_loss: 0.7156 - val_accuracy: 0.6370
#
# Epoch 00025: val_accuracy did not improve from 0.69933
# Epoch 26/30
# 50/50 [==============================] - 7s 136ms/step - loss: 0.4756 - accuracy: 0.7657 - val_loss: 0.7028 - val_accuracy: 0.6370
#
# Epoch 00026: val_accuracy did not improve from 0.69933
# Epoch 27/30
# 50/50 [==============================] - 7s 135ms/step - loss: 0.4435 - accuracy: 0.7912 - val_loss: 0.6889 - val_accuracy: 0.6258
#
# Epoch 00027: val_accuracy did not improve from 0.69933
# Epoch 28/30
# 50/50 [==============================] - 7s 137ms/step - loss: 0.4028 - accuracy: 0.8121 - val_loss: 0.6938 - val_accuracy: 0.6748
#
# Epoch 00028: val_accuracy did not improve from 0.69933
# Epoch 29/30
# 50/50 [==============================] - 6s 125ms/step - loss: 0.3886 - accuracy: 0.8175 - val_loss: 0.6312 - val_accuracy: 0.6548
#
# Epoch 00029: val_accuracy did not improve from 0.69933
# Epoch 30/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.3366 - accuracy: 0.8512 - val_loss: 0.6635 - val_accuracy: 0.6771
#
# Epoch 00030: val_accuracy did not improve from 0.69933
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 8
# Genre split [['Experimental', 'Hip-Hop'], ['Electronic', 'International']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 7s 130ms/step - loss: 1.9225 - accuracy: 0.5219 - val_loss: 0.6848 - val_accuracy: 0.5501
#
# Epoch 00001: val_accuracy improved from -inf to 0.55011, saving model to ./models/model_root_f2/folder8\model.h5
# Epoch 2/30
# 50/50 [==============================] - 7s 140ms/step - loss: 0.6815 - accuracy: 0.5690 - val_loss: 0.6567 - val_accuracy: 0.5969
#
# Epoch 00002: val_accuracy improved from 0.55011 to 0.59688, saving model to ./models/model_root_f2/folder8\model.h5
# Epoch 3/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6852 - accuracy: 0.5432 - val_loss: 0.6583 - val_accuracy: 0.6481
#
# Epoch 00003: val_accuracy improved from 0.59688 to 0.64811, saving model to ./models/model_root_f2/folder8\model.h5
# Epoch 4/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6597 - accuracy: 0.6100 - val_loss: 0.6773 - val_accuracy: 0.5657
#
# Epoch 00004: val_accuracy did not improve from 0.64811
# Epoch 5/30
# 50/50 [==============================] - 6s 124ms/step - loss: 0.6741 - accuracy: 0.5833 - val_loss: 0.6562 - val_accuracy: 0.6370
#
# Epoch 00005: val_accuracy did not improve from 0.64811
# Epoch 6/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6541 - accuracy: 0.6157 - val_loss: 0.6161 - val_accuracy: 0.6837
#
# Epoch 00006: val_accuracy improved from 0.64811 to 0.68374, saving model to ./models/model_root_f2/folder8\model.h5
# Epoch 7/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6587 - accuracy: 0.6141 - val_loss: 0.6320 - val_accuracy: 0.6748
#
# Epoch 00007: val_accuracy did not improve from 0.68374
# Epoch 8/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6334 - accuracy: 0.6405 - val_loss: 0.6238 - val_accuracy: 0.6748
#
# Epoch 00008: val_accuracy did not improve from 0.68374
# Epoch 9/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6404 - accuracy: 0.6322 - val_loss: 0.6718 - val_accuracy: 0.6013
#
# Epoch 00009: val_accuracy did not improve from 0.68374
# Epoch 10/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.6283 - accuracy: 0.6507 - val_loss: 0.6808 - val_accuracy: 0.5835
#
# Epoch 00010: val_accuracy did not improve from 0.68374
# Epoch 11/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.6107 - accuracy: 0.6672 - val_loss: 0.6672 - val_accuracy: 0.6169
#
# Epoch 00011: val_accuracy did not improve from 0.68374
# Epoch 12/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.5859 - accuracy: 0.6891 - val_loss: 0.5905 - val_accuracy: 0.7016
#
# Epoch 00012: val_accuracy improved from 0.68374 to 0.70156, saving model to ./models/model_root_f2/folder8\model.h5
# Epoch 13/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.5832 - accuracy: 0.6901 - val_loss: 0.6114 - val_accuracy: 0.6726
#
# Epoch 00013: val_accuracy did not improve from 0.70156
# Epoch 14/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.5564 - accuracy: 0.7142 - val_loss: 0.6012 - val_accuracy: 0.6837
#
# Epoch 00014: val_accuracy did not improve from 0.70156
# Epoch 15/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.5307 - accuracy: 0.7390 - val_loss: 0.8095 - val_accuracy: 0.6414
#
# Epoch 00015: val_accuracy did not improve from 0.70156
# Epoch 16/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.5436 - accuracy: 0.7308 - val_loss: 0.7179 - val_accuracy: 0.6258
#
# Epoch 00016: val_accuracy did not improve from 0.70156
# Epoch 17/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.5039 - accuracy: 0.7508 - val_loss: 0.5763 - val_accuracy: 0.7283
#
# Epoch 00017: val_accuracy improved from 0.70156 to 0.72829, saving model to ./models/model_root_f2/folder8\model.h5
# Epoch 18/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.4708 - accuracy: 0.7740 - val_loss: 0.6549 - val_accuracy: 0.6993
#
# Epoch 00018: val_accuracy did not improve from 0.72829
# Epoch 19/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.4580 - accuracy: 0.7845 - val_loss: 0.6149 - val_accuracy: 0.7127
#
# Epoch 00019: val_accuracy did not improve from 0.72829
# Epoch 20/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.4223 - accuracy: 0.8112 - val_loss: 0.6463 - val_accuracy: 0.6526
#
# Epoch 00020: val_accuracy did not improve from 0.72829
# Epoch 21/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.3899 - accuracy: 0.8296 - val_loss: 0.6613 - val_accuracy: 0.6993
#
# Epoch 00021: val_accuracy did not improve from 0.72829
# Epoch 22/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.3851 - accuracy: 0.8296 - val_loss: 0.7727 - val_accuracy: 0.6815
#
# Epoch 00022: val_accuracy did not improve from 0.72829
# Epoch 23/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.3452 - accuracy: 0.8547 - val_loss: 0.6544 - val_accuracy: 0.6882
#
# Epoch 00023: val_accuracy did not improve from 0.72829
# Epoch 24/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.3339 - accuracy: 0.8563 - val_loss: 0.6799 - val_accuracy: 0.6592
#
# Epoch 00024: val_accuracy did not improve from 0.72829
# Epoch 25/30
# 50/50 [==============================] - 6s 124ms/step - loss: 0.2668 - accuracy: 0.8916 - val_loss: 0.8783 - val_accuracy: 0.7105
#
# Epoch 00025: val_accuracy did not improve from 0.72829
# Epoch 26/30
# 50/50 [==============================] - 6s 124ms/step - loss: 0.2316 - accuracy: 0.9078 - val_loss: 0.8250 - val_accuracy: 0.6815
#
# Epoch 00026: val_accuracy did not improve from 0.72829
# Epoch 27/30
# 50/50 [==============================] - 6s 124ms/step - loss: 0.2087 - accuracy: 0.9212 - val_loss: 1.0249 - val_accuracy: 0.6459
#
# Epoch 00027: val_accuracy did not improve from 0.72829
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 28/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.1654 - accuracy: 0.9425 - val_loss: 0.9181 - val_accuracy: 0.6927
#
# Epoch 00028: val_accuracy did not improve from 0.72829
# Epoch 29/30
# 50/50 [==============================] - 6s 122ms/step - loss: 0.1042 - accuracy: 0.9682 - val_loss: 0.8782 - val_accuracy: 0.7439
#
# Epoch 00029: val_accuracy improved from 0.72829 to 0.74388, saving model to ./models/model_root_f2/folder8\model.h5
# Epoch 30/30
# 50/50 [==============================] - 6s 123ms/step - loss: 0.0762 - accuracy: 0.9825 - val_loss: 0.9136 - val_accuracy: 0.7506
#
# Epoch 00030: val_accuracy improved from 0.74388 to 0.75056, saving model to ./models/model_root_f2/folder8\model.h5
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
