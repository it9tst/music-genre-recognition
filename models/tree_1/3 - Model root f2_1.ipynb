# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7}
dict_genres = {'Electronic':0, 'Hip-Hop' :3}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Electronic', 3: 'Hip-Hop'}

# %%
npzfile = np.load('data/shuffled_train.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394,)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=8).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((1596, 640, 128), (1596, 8))

# %%
npzfile = np.load('data/shuffled_valid.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=8).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((200, 640, 128), (200, 8))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Electronic

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

BATCH_SIZE = 64
EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 640
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_1/model_root_f2_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_1/model_root_f2_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
def create_split(elem, c):
    splits = []
    for i in range(c):
        equal = False
        np.random.shuffle(elem)
        new_split = list(chunks(elem, int(len(elem)/2)))
        for split in splits:
            if set(new_split[0]) == set(split[0]) and set(new_split[0]) == set(split[1]):
                equal = True
                break
            
        if equal:
            i-=1
            continue
        
        splits.append(new_split)
        
    return splits

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 1

kfold = KFold(n_splits=8, shuffle=True)
genre_splits = create_split(list(dict_genres.values()), num_splits)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)

    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Electronic'], ['Hip-Hop']]
# Building model...
# Training...
# Epoch 1/30
# 22/22 [==============================] - 15s 187ms/step - loss: 2.0463 - accuracy: 0.5160 - val_loss: 0.6897 - val_accuracy: 0.5434
#
# Epoch 00001: val_accuracy improved from -inf to 0.54343, saving model to ./models/model_root_f2_1/folder1\model.h5
# Epoch 2/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6926 - accuracy: 0.5434 - val_loss: 0.6784 - val_accuracy: 0.5746
#
# Epoch 00002: val_accuracy improved from 0.54343 to 0.57461, saving model to ./models/model_root_f2_1/folder1\model.h5
# Epoch 3/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6760 - accuracy: 0.5828 - val_loss: 1.0690 - val_accuracy: 0.5434
#
# Epoch 00003: val_accuracy did not improve from 0.57461
# Epoch 4/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.7122 - accuracy: 0.5249 - val_loss: 0.6932 - val_accuracy: 0.4633
#
# Epoch 00004: val_accuracy did not improve from 0.57461
# Epoch 5/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.6925 - accuracy: 0.5219 - val_loss: 0.6970 - val_accuracy: 0.4566
#
# Epoch 00005: val_accuracy did not improve from 0.57461
# Epoch 6/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6913 - accuracy: 0.5137 - val_loss: 0.7032 - val_accuracy: 0.4566
#
# Epoch 00006: val_accuracy did not improve from 0.57461
# Epoch 7/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6934 - accuracy: 0.5145 - val_loss: 0.6931 - val_accuracy: 0.4543
#
# Epoch 00007: val_accuracy did not improve from 0.57461
# Epoch 8/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6911 - accuracy: 0.4892 - val_loss: 0.6838 - val_accuracy: 0.5434
#
# Epoch 00008: val_accuracy did not improve from 0.57461
# Epoch 9/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6869 - accuracy: 0.5174 - val_loss: 0.6945 - val_accuracy: 0.4633
#
# Epoch 00009: val_accuracy did not improve from 0.57461
# Epoch 10/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6941 - accuracy: 0.5182 - val_loss: 0.6934 - val_accuracy: 0.4655
#
# Epoch 00010: val_accuracy did not improve from 0.57461
# Epoch 11/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.8158 - accuracy: 0.5412 - val_loss: 0.7435 - val_accuracy: 0.4566
#
# Epoch 00011: val_accuracy did not improve from 0.57461
# Epoch 12/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.7030 - accuracy: 0.4996 - val_loss: 0.6989 - val_accuracy: 0.4566
#
# Epoch 00012: val_accuracy did not improve from 0.57461
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 13/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.6942 - accuracy: 0.5137 - val_loss: 0.6942 - val_accuracy: 0.4566
#
# Epoch 00013: val_accuracy did not improve from 0.57461
# Epoch 14/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.6929 - accuracy: 0.5137 - val_loss: 0.6944 - val_accuracy: 0.4566
#
# Epoch 00014: val_accuracy did not improve from 0.57461
# Epoch 15/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.6929 - accuracy: 0.5137 - val_loss: 0.6944 - val_accuracy: 0.4566
#
# Epoch 00015: val_accuracy did not improve from 0.57461
# Epoch 16/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.6929 - accuracy: 0.5137 - val_loss: 0.6946 - val_accuracy: 0.4566
#
# Epoch 00016: val_accuracy did not improve from 0.57461
# Epoch 17/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.6929 - accuracy: 0.5137 - val_loss: 0.6946 - val_accuracy: 0.4566
#
# Epoch 00017: val_accuracy did not improve from 0.57461
# Epoch 18/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.6928 - accuracy: 0.5137 - val_loss: 0.6947 - val_accuracy: 0.4566
#
# Epoch 00018: val_accuracy did not improve from 0.57461
# Epoch 19/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.6928 - accuracy: 0.5137 - val_loss: 0.6948 - val_accuracy: 0.4566
#
# Epoch 00019: val_accuracy did not improve from 0.57461
# Epoch 20/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.6928 - accuracy: 0.5137 - val_loss: 0.6947 - val_accuracy: 0.4566
#
# Epoch 00020: val_accuracy did not improve from 0.57461
# Epoch 21/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.6928 - accuracy: 0.5137 - val_loss: 0.6948 - val_accuracy: 0.4566
#
# Epoch 00021: val_accuracy did not improve from 0.57461
# Epoch 22/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.6928 - accuracy: 0.5137 - val_loss: 0.6949 - val_accuracy: 0.4566
#
# Epoch 00022: val_accuracy did not improve from 0.57461
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 23/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.6928 - accuracy: 0.5137 - val_loss: 0.6950 - val_accuracy: 0.4566
#
# Epoch 00023: val_accuracy did not improve from 0.57461
# Epoch 24/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.6928 - accuracy: 0.5137 - val_loss: 0.6950 - val_accuracy: 0.4566
#
# Epoch 00024: val_accuracy did not improve from 0.57461
# Epoch 25/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.6928 - accuracy: 0.5137 - val_loss: 0.6950 - val_accuracy: 0.4566
#
# Epoch 00025: val_accuracy did not improve from 0.57461
# Epoch 26/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.6928 - accuracy: 0.5137 - val_loss: 0.6950 - val_accuracy: 0.4566
#
# Epoch 00026: val_accuracy did not improve from 0.57461
# Epoch 27/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.6928 - accuracy: 0.5137 - val_loss: 0.6951 - val_accuracy: 0.4566
#
# Epoch 00027: val_accuracy did not improve from 0.57461
# Epoch 28/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.6928 - accuracy: 0.5137 - val_loss: 0.6951 - val_accuracy: 0.4566
#
# Epoch 00028: val_accuracy did not improve from 0.57461
# Epoch 29/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.6928 - accuracy: 0.5137 - val_loss: 0.6951 - val_accuracy: 0.4566
#
# Epoch 00029: val_accuracy did not improve from 0.57461
# Epoch 30/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.6928 - accuracy: 0.5137 - val_loss: 0.6951 - val_accuracy: 0.4566
#
# Epoch 00030: val_accuracy did not improve from 0.57461
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Electronic'], ['Hip-Hop']]
# Building model...
# Training...
# Epoch 1/30
# 22/22 [==============================] - 4s 167ms/step - loss: 2.4045 - accuracy: 0.4907 - val_loss: 0.6985 - val_accuracy: 0.4811
#
# Epoch 00001: val_accuracy improved from -inf to 0.48107, saving model to ./models/model_root_f2_1/folder2\model.h5
# Epoch 2/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6987 - accuracy: 0.4892 - val_loss: 0.6882 - val_accuracy: 0.5924
#
# Epoch 00002: val_accuracy improved from 0.48107 to 0.59243, saving model to ./models/model_root_f2_1/folder2\model.h5
# Epoch 3/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6869 - accuracy: 0.5442 - val_loss: 0.6850 - val_accuracy: 0.4788
#
# Epoch 00003: val_accuracy did not improve from 0.59243
# Epoch 4/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6800 - accuracy: 0.5553 - val_loss: 0.6837 - val_accuracy: 0.5189
#
# Epoch 00004: val_accuracy did not improve from 0.59243
# Epoch 5/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6998 - accuracy: 0.5516 - val_loss: 0.7105 - val_accuracy: 0.4811
#
# Epoch 00005: val_accuracy did not improve from 0.59243
# Epoch 6/30
# 22/22 [==============================] - 3s 155ms/step - loss: 0.6977 - accuracy: 0.4937 - val_loss: 0.6937 - val_accuracy: 0.4788
#
# Epoch 00006: val_accuracy did not improve from 0.59243
# Epoch 7/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6946 - accuracy: 0.4818 - val_loss: 0.6916 - val_accuracy: 0.5078
#
# Epoch 00007: val_accuracy did not improve from 0.59243
# Epoch 8/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6933 - accuracy: 0.5353 - val_loss: 0.6969 - val_accuracy: 0.4811
#
# Epoch 00008: val_accuracy did not improve from 0.59243
# Epoch 9/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6959 - accuracy: 0.4981 - val_loss: 0.6906 - val_accuracy: 0.5546
#
# Epoch 00009: val_accuracy did not improve from 0.59243
# Epoch 10/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6811 - accuracy: 0.5664 - val_loss: 0.6817 - val_accuracy: 0.5835
#
# Epoch 00010: val_accuracy did not improve from 0.59243
# Epoch 11/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6798 - accuracy: 0.5768 - val_loss: 1.1530 - val_accuracy: 0.5434
#
# Epoch 00011: val_accuracy did not improve from 0.59243
# Epoch 12/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.7024 - accuracy: 0.5471 - val_loss: 0.6733 - val_accuracy: 0.5746
#
# Epoch 00012: val_accuracy did not improve from 0.59243
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 13/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6529 - accuracy: 0.5880 - val_loss: 0.6681 - val_accuracy: 0.6058
#
# Epoch 00013: val_accuracy improved from 0.59243 to 0.60579, saving model to ./models/model_root_f2_1/folder2\model.h5
# Epoch 14/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6372 - accuracy: 0.6073 - val_loss: 0.6677 - val_accuracy: 0.5969
#
# Epoch 00014: val_accuracy did not improve from 0.60579
# Epoch 15/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6277 - accuracy: 0.6266 - val_loss: 0.6685 - val_accuracy: 0.5969
#
# Epoch 00015: val_accuracy did not improve from 0.60579
# Epoch 16/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6232 - accuracy: 0.6325 - val_loss: 0.6596 - val_accuracy: 0.5813
#
# Epoch 00016: val_accuracy did not improve from 0.60579
# Epoch 17/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.6118 - accuracy: 0.6585 - val_loss: 0.6394 - val_accuracy: 0.6013
#
# Epoch 00017: val_accuracy did not improve from 0.60579
# Epoch 18/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.5857 - accuracy: 0.6823 - val_loss: 0.5816 - val_accuracy: 0.7350
#
# Epoch 00018: val_accuracy improved from 0.60579 to 0.73497, saving model to ./models/model_root_f2_1/folder2\model.h5
# Epoch 19/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.5774 - accuracy: 0.6852 - val_loss: 1.0381 - val_accuracy: 0.5924
#
# Epoch 00019: val_accuracy did not improve from 0.73497
# Epoch 20/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.5578 - accuracy: 0.7238 - val_loss: 0.5564 - val_accuracy: 0.7461
#
# Epoch 00020: val_accuracy improved from 0.73497 to 0.74610, saving model to ./models/model_root_f2_1/folder2\model.h5
# Epoch 21/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.5231 - accuracy: 0.7394 - val_loss: 0.6061 - val_accuracy: 0.6637
#
# Epoch 00021: val_accuracy did not improve from 0.74610
# Epoch 22/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.5119 - accuracy: 0.7275 - val_loss: 0.5550 - val_accuracy: 0.7439
#
# Epoch 00022: val_accuracy did not improve from 0.74610
# Epoch 23/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.4750 - accuracy: 0.7565 - val_loss: 0.5195 - val_accuracy: 0.7751
#
# Epoch 00023: val_accuracy improved from 0.74610 to 0.77506, saving model to ./models/model_root_f2_1/folder2\model.h5
# Epoch 24/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.4441 - accuracy: 0.7884 - val_loss: 0.5222 - val_accuracy: 0.7639
#
# Epoch 00024: val_accuracy did not improve from 0.77506
# Epoch 25/30
# 22/22 [==============================] - 3s 155ms/step - loss: 0.4303 - accuracy: 0.7958 - val_loss: 0.5362 - val_accuracy: 0.7795
#
# Epoch 00025: val_accuracy improved from 0.77506 to 0.77951, saving model to ./models/model_root_f2_1/folder2\model.h5
# Epoch 26/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.4045 - accuracy: 0.8159 - val_loss: 0.6698 - val_accuracy: 0.7261
#
# Epoch 00026: val_accuracy did not improve from 0.77951
# Epoch 27/30
# 22/22 [==============================] - 3s 155ms/step - loss: 0.3781 - accuracy: 0.8263 - val_loss: 0.7093 - val_accuracy: 0.6793
#
# Epoch 00027: val_accuracy did not improve from 0.77951
# Epoch 28/30
# 22/22 [==============================] - 3s 155ms/step - loss: 0.4332 - accuracy: 0.7944 - val_loss: 0.5231 - val_accuracy: 0.7751
#
# Epoch 00028: val_accuracy did not improve from 0.77951
# Epoch 29/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.3786 - accuracy: 0.8144 - val_loss: 0.6079 - val_accuracy: 0.7595
#
# Epoch 00029: val_accuracy did not improve from 0.77951
# Epoch 30/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.3410 - accuracy: 0.8523 - val_loss: 0.5201 - val_accuracy: 0.7840
#
# Epoch 00030: val_accuracy improved from 0.77951 to 0.78396, saving model to ./models/model_root_f2_1/folder2\model.h5
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Hip-Hop'], ['Electronic']]
# Building model...
# Training...
# Epoch 1/30
# 22/22 [==============================] - 4s 166ms/step - loss: 3.1924 - accuracy: 0.5048 - val_loss: 0.8040 - val_accuracy: 0.5033
#
# Epoch 00001: val_accuracy improved from -inf to 0.50334, saving model to ./models/model_root_f2_1/folder3\model.h5
# Epoch 2/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.7223 - accuracy: 0.4885 - val_loss: 0.6927 - val_accuracy: 0.5033
#
# Epoch 00002: val_accuracy did not improve from 0.50334
# Epoch 3/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6932 - accuracy: 0.5071 - val_loss: 0.6926 - val_accuracy: 0.4967
#
# Epoch 00003: val_accuracy did not improve from 0.50334
# Epoch 4/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6916 - accuracy: 0.4959 - val_loss: 0.6916 - val_accuracy: 0.5056
#
# Epoch 00004: val_accuracy improved from 0.50334 to 0.50557, saving model to ./models/model_root_f2_1/folder3\model.h5
# Epoch 5/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6952 - accuracy: 0.4900 - val_loss: 0.6911 - val_accuracy: 0.4967
#
# Epoch 00005: val_accuracy did not improve from 0.50557
# Epoch 6/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6792 - accuracy: 0.5182 - val_loss: 0.6813 - val_accuracy: 0.5724
#
# Epoch 00006: val_accuracy improved from 0.50557 to 0.57238, saving model to ./models/model_root_f2_1/folder3\model.h5
# Epoch 7/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6944 - accuracy: 0.5137 - val_loss: 0.6926 - val_accuracy: 0.5033
#
# Epoch 00007: val_accuracy did not improve from 0.57238
# Epoch 8/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6922 - accuracy: 0.5011 - val_loss: 0.6919 - val_accuracy: 0.5857
#
# Epoch 00008: val_accuracy improved from 0.57238 to 0.58575, saving model to ./models/model_root_f2_1/folder3\model.h5
# Epoch 9/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6912 - accuracy: 0.5598 - val_loss: 0.6877 - val_accuracy: 0.5167
#
# Epoch 00009: val_accuracy did not improve from 0.58575
# Epoch 10/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.6883 - accuracy: 0.5605 - val_loss: 0.6908 - val_accuracy: 0.5412
#
# Epoch 00010: val_accuracy did not improve from 0.58575
# Epoch 11/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.6911 - accuracy: 0.5212 - val_loss: 0.6987 - val_accuracy: 0.5033
#
# Epoch 00011: val_accuracy did not improve from 0.58575
# Epoch 12/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6943 - accuracy: 0.5085 - val_loss: 0.9327 - val_accuracy: 0.4967
#
# Epoch 00012: val_accuracy did not improve from 0.58575
# Epoch 13/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.7010 - accuracy: 0.5330 - val_loss: 0.6877 - val_accuracy: 0.4967
#
# Epoch 00013: val_accuracy did not improve from 0.58575
# Epoch 14/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.9999 - accuracy: 0.5197 - val_loss: 0.8564 - val_accuracy: 0.5033
#
# Epoch 00014: val_accuracy did not improve from 0.58575
# Epoch 15/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.7193 - accuracy: 0.4929 - val_loss: 0.6932 - val_accuracy: 0.4967
#
# Epoch 00015: val_accuracy did not improve from 0.58575
# Epoch 16/30
# 22/22 [==============================] - 4s 161ms/step - loss: 0.6960 - accuracy: 0.5019 - val_loss: 0.6933 - val_accuracy: 0.4967
#
# Epoch 00016: val_accuracy did not improve from 0.58575
# Epoch 17/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.6932 - accuracy: 0.5019 - val_loss: 0.6932 - val_accuracy: 0.4967
#
# Epoch 00017: val_accuracy did not improve from 0.58575
# Epoch 18/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.6932 - accuracy: 0.5019 - val_loss: 0.6932 - val_accuracy: 0.4967
#
# Epoch 00018: val_accuracy did not improve from 0.58575
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 19/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6932 - accuracy: 0.5019 - val_loss: 0.6930 - val_accuracy: 0.4967
#
# Epoch 00019: val_accuracy did not improve from 0.58575
# Epoch 20/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.6917 - accuracy: 0.5019 - val_loss: 0.6897 - val_accuracy: 0.4967
#
# Epoch 00020: val_accuracy did not improve from 0.58575
# Epoch 21/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6858 - accuracy: 0.5041 - val_loss: 0.6624 - val_accuracy: 0.6080
#
# Epoch 00021: val_accuracy improved from 0.58575 to 0.60802, saving model to ./models/model_root_f2_1/folder3\model.h5
# Epoch 22/30
# 22/22 [==============================] - 3s 160ms/step - loss: 0.6664 - accuracy: 0.5798 - val_loss: 0.6631 - val_accuracy: 0.6013
#
# Epoch 00022: val_accuracy did not improve from 0.60802
# Epoch 23/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6498 - accuracy: 0.6043 - val_loss: 0.6451 - val_accuracy: 0.6147
#
# Epoch 00023: val_accuracy improved from 0.60802 to 0.61470, saving model to ./models/model_root_f2_1/folder3\model.h5
# Epoch 24/30
# 22/22 [==============================] - 4s 167ms/step - loss: 0.6473 - accuracy: 0.6206 - val_loss: 0.6524 - val_accuracy: 0.6013
#
# Epoch 00024: val_accuracy did not improve from 0.61470
# Epoch 25/30
# 22/22 [==============================] - 3s 157ms/step - loss: 0.6426 - accuracy: 0.6236 - val_loss: 0.6413 - val_accuracy: 0.6236
#
# Epoch 00025: val_accuracy improved from 0.61470 to 0.62361, saving model to ./models/model_root_f2_1/folder3\model.h5
# Epoch 26/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6450 - accuracy: 0.6221 - val_loss: 0.6603 - val_accuracy: 0.5880
#
# Epoch 00026: val_accuracy did not improve from 0.62361
# Epoch 27/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6503 - accuracy: 0.6169 - val_loss: 0.6706 - val_accuracy: 0.6169
#
# Epoch 00027: val_accuracy did not improve from 0.62361
# Epoch 28/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6403 - accuracy: 0.6474 - val_loss: 0.6477 - val_accuracy: 0.6214
#
# Epoch 00028: val_accuracy did not improve from 0.62361
# Epoch 29/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6347 - accuracy: 0.6533 - val_loss: 0.6523 - val_accuracy: 0.6147
#
# Epoch 00029: val_accuracy did not improve from 0.62361
# Epoch 30/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6357 - accuracy: 0.6563 - val_loss: 0.6415 - val_accuracy: 0.6347
#
# Epoch 00030: val_accuracy improved from 0.62361 to 0.63474, saving model to ./models/model_root_f2_1/folder3\model.h5
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Hip-Hop'], ['Electronic']]
# Building model...
# Training...
# Epoch 1/30
# 22/22 [==============================] - 4s 167ms/step - loss: 2.9882 - accuracy: 0.5108 - val_loss: 0.7426 - val_accuracy: 0.5189
#
# Epoch 00001: val_accuracy improved from -inf to 0.51893, saving model to ./models/model_root_f2_1/folder4\model.h5
# Epoch 2/30
# 22/22 [==============================] - 3s 155ms/step - loss: 0.7039 - accuracy: 0.5063 - val_loss: 0.7779 - val_accuracy: 0.4811
#
# Epoch 00002: val_accuracy did not improve from 0.51893
# Epoch 3/30
# 22/22 [==============================] - 3s 155ms/step - loss: 0.6767 - accuracy: 0.5442 - val_loss: 0.6420 - val_accuracy: 0.6214
#
# Epoch 00003: val_accuracy improved from 0.51893 to 0.62138, saving model to ./models/model_root_f2_1/folder4\model.h5
# Epoch 4/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6719 - accuracy: 0.5724 - val_loss: 0.6332 - val_accuracy: 0.6303
#
# Epoch 00004: val_accuracy improved from 0.62138 to 0.63029, saving model to ./models/model_root_f2_1/folder4\model.h5
# Epoch 5/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6601 - accuracy: 0.6013 - val_loss: 0.6606 - val_accuracy: 0.6036
#
# Epoch 00005: val_accuracy did not improve from 0.63029
# Epoch 6/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6532 - accuracy: 0.6013 - val_loss: 0.7537 - val_accuracy: 0.5323
#
# Epoch 00006: val_accuracy did not improve from 0.63029
# Epoch 7/30
# 22/22 [==============================] - 3s 156ms/step - loss: 0.6983 - accuracy: 0.5071 - val_loss: 0.6939 - val_accuracy: 0.4811
#
# Epoch 00007: val_accuracy did not improve from 0.63029
# Epoch 8/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6657 - accuracy: 0.5768 - val_loss: 0.6873 - val_accuracy: 0.5234
#
# Epoch 00008: val_accuracy did not improve from 0.63029
# Epoch 9/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6957 - accuracy: 0.4929 - val_loss: 0.6925 - val_accuracy: 0.5167
#
# Epoch 00009: val_accuracy did not improve from 0.63029
# Epoch 10/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.6936 - accuracy: 0.4863 - val_loss: 0.6935 - val_accuracy: 0.4811
#
# Epoch 00010: val_accuracy did not improve from 0.63029
# Epoch 11/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.6931 - accuracy: 0.4959 - val_loss: 0.6927 - val_accuracy: 0.5546
#
# Epoch 00011: val_accuracy did not improve from 0.63029
# Epoch 12/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6915 - accuracy: 0.5316 - val_loss: 0.6877 - val_accuracy: 0.6325
#
# Epoch 00012: val_accuracy improved from 0.63029 to 0.63252, saving model to ./models/model_root_f2_1/folder4\model.h5
# Epoch 13/30
# 22/22 [==============================] - 3s 155ms/step - loss: 0.6860 - accuracy: 0.5338 - val_loss: 0.6698 - val_accuracy: 0.6080
#
# Epoch 00013: val_accuracy did not improve from 0.63252
# Epoch 14/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6582 - accuracy: 0.5932 - val_loss: 0.6322 - val_accuracy: 0.6281
#
# Epoch 00014: val_accuracy did not improve from 0.63252
# Epoch 15/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6516 - accuracy: 0.6013 - val_loss: 0.7621 - val_accuracy: 0.5457
#
# Epoch 00015: val_accuracy did not improve from 0.63252
# Epoch 16/30
# 22/22 [==============================] - 3s 159ms/step - loss: 0.6694 - accuracy: 0.5850 - val_loss: 0.6424 - val_accuracy: 0.6147
#
# Epoch 00016: val_accuracy did not improve from 0.63252
# Epoch 17/30
# 22/22 [==============================] - 4s 161ms/step - loss: 0.6533 - accuracy: 0.5976 - val_loss: 0.6586 - val_accuracy: 0.6036
#
# Epoch 00017: val_accuracy did not improve from 0.63252
# Epoch 18/30
# 22/22 [==============================] - 4s 166ms/step - loss: 0.6477 - accuracy: 0.5984 - val_loss: 0.6334 - val_accuracy: 0.6325
#
# Epoch 00018: val_accuracy did not improve from 0.63252
# Epoch 19/30
# 22/22 [==============================] - 4s 162ms/step - loss: 0.6328 - accuracy: 0.6303 - val_loss: 0.6273 - val_accuracy: 0.6370
#
# Epoch 00019: val_accuracy improved from 0.63252 to 0.63697, saving model to ./models/model_root_f2_1/folder4\model.h5
# Epoch 20/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6441 - accuracy: 0.6162 - val_loss: 0.6492 - val_accuracy: 0.6125
#
# Epoch 00020: val_accuracy did not improve from 0.63697
# Epoch 21/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.6415 - accuracy: 0.6229 - val_loss: 0.6352 - val_accuracy: 0.6236
#
# Epoch 00021: val_accuracy did not improve from 0.63697
# Epoch 22/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.7616 - accuracy: 0.5716 - val_loss: 0.6627 - val_accuracy: 0.5969
#
# Epoch 00022: val_accuracy did not improve from 0.63697
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 23/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.6607 - accuracy: 0.5939 - val_loss: 0.6257 - val_accuracy: 0.6236
#
# Epoch 00023: val_accuracy did not improve from 0.63697
# Epoch 24/30
# 22/22 [==============================] - 3s 155ms/step - loss: 0.6403 - accuracy: 0.6162 - val_loss: 0.6277 - val_accuracy: 0.6258
#
# Epoch 00024: val_accuracy did not improve from 0.63697
# Epoch 25/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.6211 - accuracy: 0.6370 - val_loss: 0.6429 - val_accuracy: 0.6392
#
# Epoch 00025: val_accuracy improved from 0.63697 to 0.63920, saving model to ./models/model_root_f2_1/folder4\model.h5
# Epoch 26/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.6117 - accuracy: 0.6422 - val_loss: 0.6301 - val_accuracy: 0.6414
#
# Epoch 00026: val_accuracy improved from 0.63920 to 0.64143, saving model to ./models/model_root_f2_1/folder4\model.h5
# Epoch 27/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.6062 - accuracy: 0.6422 - val_loss: 0.6445 - val_accuracy: 0.6615
#
# Epoch 00027: val_accuracy improved from 0.64143 to 0.66147, saving model to ./models/model_root_f2_1/folder4\model.h5
# Epoch 28/30
# 22/22 [==============================] - 3s 156ms/step - loss: 0.6003 - accuracy: 0.6533 - val_loss: 0.6384 - val_accuracy: 0.6437
#
# Epoch 00028: val_accuracy did not improve from 0.66147
# Epoch 29/30
# 22/22 [==============================] - 3s 157ms/step - loss: 0.5961 - accuracy: 0.6600 - val_loss: 0.6370 - val_accuracy: 0.6592
#
# Epoch 00029: val_accuracy did not improve from 0.66147
# Epoch 30/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.5925 - accuracy: 0.6696 - val_loss: 0.6265 - val_accuracy: 0.6570
#
# Epoch 00030: val_accuracy did not improve from 0.66147
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
