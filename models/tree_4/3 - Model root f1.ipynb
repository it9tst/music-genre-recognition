# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.layers import Bidirectional, concatenate, GRU, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7}
dict_genres = {'Experimental':1, 'Folk':2, 'Pop':6, 'Rock' :7}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {1: 'Experimental', 2: 'Folk', 6: 'Pop', 7: 'Rock'}

# %%
npzfile = np.load('data/shuffled_train.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394,)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=8).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((3198, 640, 128), (3198, 8))

# %%
npzfile = np.load('data/shuffled_valid.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=8).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((400, 640, 128), (400, 8))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Pop

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=16 
nb_filters2=32 
nb_filters3=64
nb_filters4=64
nb_filters5=64
ksize_1 = (3,5)
ksize_2 = (3,1)
pool_size_1= (2,2) 
pool_size_2= (4,4)
pool_size_3 = (4,2)

lstm_count = 64

BATCH_SIZE = 64
EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize_1, strides=1, padding='valid', activation='elu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize_2, strides=1, padding='valid', activation='elu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize_2, strides=1, padding='valid', activation='elu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize_2, strides=1, padding='valid', activation='elu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_2)(conv_4)
    
    conv_5 = Conv2D(filters = nb_filters4, kernel_size = ksize_2, strides=1, padding='valid', activation='elu', name='conv_5')(pool_4)
    pool_5 = MaxPooling2D(pool_size_3)(conv_5)
    
    flatten1 = Flatten()(pool_5)
    
    ### Recurrent Block
    # Pooling layer
    pool_lstm1 = MaxPooling2D(pool_size_3, name='pool_lstm')(layer)
    
    # Embedding layer
    squeezed = Lambda(lambda x: K.squeeze(x, axis = -1))(pool_lstm1)
    
    # Bidirectional GRU
    lstm = Bidirectional(GRU(lstm_count))(squeezed)  #default merge mode is concat
    
    # Concat Output
    concat = concatenate([flatten1, lstm], axis = -1, name='concat')
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(concat)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.0005)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 640
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_4/model_root_f1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_4/model_root_f1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
def create_split(elem, c):
    splits = []
    for i in range(c):
        equal = False
        np.random.shuffle(elem)
        new_split = list(chunks(elem, int(len(elem)/2)))
        for split in splits:
            if set(new_split[0]) == set(split[0]) and set(new_split[0]) == set(split[1]):
                equal = True
                break
            
        if equal:
            i-=1
            continue
        
        splits.append(new_split)
        
    return splits

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 3

kfold = KFold(n_splits=8, shuffle=True)
genre_splits = create_split(list(dict_genres.values()), num_splits)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)

    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Folk', 'Rock'], ['Pop', 'Experimental']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 18s 110ms/step - loss: 0.7111 - accuracy: 0.5610 - val_loss: 0.6327 - val_accuracy: 0.6556
#
# Epoch 00001: val_accuracy improved from -inf to 0.65556, saving model to ./models/tree_4/model_root_f1/folder1\model.h5
# Epoch 2/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.6167 - accuracy: 0.6655 - val_loss: 0.6750 - val_accuracy: 0.5489
#
# Epoch 00002: val_accuracy did not improve from 0.65556
# Epoch 3/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5942 - accuracy: 0.6820 - val_loss: 0.5718 - val_accuracy: 0.7244
#
# Epoch 00003: val_accuracy improved from 0.65556 to 0.72444, saving model to ./models/tree_4/model_root_f1/folder1\model.h5
# Epoch 4/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5740 - accuracy: 0.7030 - val_loss: 0.5751 - val_accuracy: 0.6889
#
# Epoch 00004: val_accuracy did not improve from 0.72444
# Epoch 5/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5576 - accuracy: 0.7132 - val_loss: 0.5601 - val_accuracy: 0.7200
#
# Epoch 00005: val_accuracy did not improve from 0.72444
# Epoch 6/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5507 - accuracy: 0.7259 - val_loss: 0.5924 - val_accuracy: 0.6711
#
# Epoch 00006: val_accuracy did not improve from 0.72444
# Epoch 7/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5363 - accuracy: 0.7348 - val_loss: 0.5468 - val_accuracy: 0.7467
#
# Epoch 00007: val_accuracy improved from 0.72444 to 0.74667, saving model to ./models/tree_4/model_root_f1/folder1\model.h5
# Epoch 8/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5165 - accuracy: 0.7513 - val_loss: 0.5320 - val_accuracy: 0.7511
#
# Epoch 00008: val_accuracy improved from 0.74667 to 0.75111, saving model to ./models/tree_4/model_root_f1/folder1\model.h5
# Epoch 9/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5142 - accuracy: 0.7519 - val_loss: 0.5585 - val_accuracy: 0.7311
#
# Epoch 00009: val_accuracy did not improve from 0.75111
# Epoch 10/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5045 - accuracy: 0.7544 - val_loss: 0.5451 - val_accuracy: 0.7378
#
# Epoch 00010: val_accuracy did not improve from 0.75111
# Epoch 11/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4862 - accuracy: 0.7697 - val_loss: 0.5299 - val_accuracy: 0.7556
#
# Epoch 00011: val_accuracy improved from 0.75111 to 0.75556, saving model to ./models/tree_4/model_root_f1/folder1\model.h5
# Epoch 12/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4713 - accuracy: 0.7786 - val_loss: 0.5266 - val_accuracy: 0.7622
#
# Epoch 00012: val_accuracy improved from 0.75556 to 0.76222, saving model to ./models/tree_4/model_root_f1/folder1\model.h5
# Epoch 13/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4611 - accuracy: 0.7799 - val_loss: 0.5349 - val_accuracy: 0.7622
#
# Epoch 00013: val_accuracy did not improve from 0.76222
# Epoch 14/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4630 - accuracy: 0.7745 - val_loss: 0.5363 - val_accuracy: 0.7622
#
# Epoch 00014: val_accuracy did not improve from 0.76222
# Epoch 15/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4616 - accuracy: 0.7878 - val_loss: 0.5295 - val_accuracy: 0.7733
#
# Epoch 00015: val_accuracy improved from 0.76222 to 0.77333, saving model to ./models/tree_4/model_root_f1/folder1\model.h5
# Epoch 16/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4149 - accuracy: 0.8180 - val_loss: 0.5233 - val_accuracy: 0.7600
#
# Epoch 00016: val_accuracy did not improve from 0.77333
# Epoch 17/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4097 - accuracy: 0.8189 - val_loss: 0.5390 - val_accuracy: 0.7556
#
# Epoch 00017: val_accuracy did not improve from 0.77333
# Epoch 18/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3946 - accuracy: 0.8383 - val_loss: 0.5454 - val_accuracy: 0.7511
#
# Epoch 00018: val_accuracy did not improve from 0.77333
# Epoch 19/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3871 - accuracy: 0.8370 - val_loss: 0.5907 - val_accuracy: 0.7044
#
# Epoch 00019: val_accuracy did not improve from 0.77333
# Epoch 20/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3645 - accuracy: 0.8526 - val_loss: 0.5586 - val_accuracy: 0.7511
#
# Epoch 00020: val_accuracy did not improve from 0.77333
# Epoch 21/30
# 50/50 [==============================] - 4s 85ms/step - loss: 0.3419 - accuracy: 0.8590 - val_loss: 0.5451 - val_accuracy: 0.7644
#
# Epoch 00021: val_accuracy did not improve from 0.77333
# Epoch 22/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3072 - accuracy: 0.8914 - val_loss: 0.5527 - val_accuracy: 0.7644
#
# Epoch 00022: val_accuracy did not improve from 0.77333
# Epoch 23/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2996 - accuracy: 0.8837 - val_loss: 0.6332 - val_accuracy: 0.6889
#
# Epoch 00023: val_accuracy did not improve from 0.77333
# Epoch 24/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2748 - accuracy: 0.9028 - val_loss: 0.5791 - val_accuracy: 0.7444
#
# Epoch 00024: val_accuracy did not improve from 0.77333
# Epoch 25/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2654 - accuracy: 0.9003 - val_loss: 0.5769 - val_accuracy: 0.7533
#
# Epoch 00025: val_accuracy did not improve from 0.77333
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 26/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2171 - accuracy: 0.9457 - val_loss: 0.5833 - val_accuracy: 0.7467
#
# Epoch 00026: val_accuracy did not improve from 0.77333
# Epoch 27/30
# 50/50 [==============================] - 4s 89ms/step - loss: 0.2044 - accuracy: 0.9508 - val_loss: 0.5903 - val_accuracy: 0.7444
#
# Epoch 00027: val_accuracy did not improve from 0.77333
# Epoch 28/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.1880 - accuracy: 0.9571 - val_loss: 0.6011 - val_accuracy: 0.7489
#
# Epoch 00028: val_accuracy did not improve from 0.77333
# Epoch 29/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.1792 - accuracy: 0.9632 - val_loss: 0.6054 - val_accuracy: 0.7422
#
# Epoch 00029: val_accuracy did not improve from 0.77333
# Epoch 30/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.1639 - accuracy: 0.9689 - val_loss: 0.6123 - val_accuracy: 0.7467
#
# Epoch 00030: val_accuracy did not improve from 0.77333
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Pop', 'Experimental'], ['Rock', 'Folk']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 7s 98ms/step - loss: 0.6923 - accuracy: 0.5616 - val_loss: 0.6332 - val_accuracy: 0.6511
#
# Epoch 00001: val_accuracy improved from -inf to 0.65111, saving model to ./models/tree_4/model_root_f1/folder2\model.h5
# Epoch 2/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.6152 - accuracy: 0.6623 - val_loss: 0.5987 - val_accuracy: 0.7000
#
# Epoch 00002: val_accuracy improved from 0.65111 to 0.70000, saving model to ./models/tree_4/model_root_f1/folder2\model.h5
# Epoch 3/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5965 - accuracy: 0.6820 - val_loss: 0.5820 - val_accuracy: 0.7311
#
# Epoch 00003: val_accuracy improved from 0.70000 to 0.73111, saving model to ./models/tree_4/model_root_f1/folder2\model.h5
# Epoch 4/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5726 - accuracy: 0.7036 - val_loss: 0.5653 - val_accuracy: 0.7311
#
# Epoch 00004: val_accuracy did not improve from 0.73111
# Epoch 5/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5551 - accuracy: 0.7220 - val_loss: 0.5865 - val_accuracy: 0.6556
#
# Epoch 00005: val_accuracy did not improve from 0.73111
# Epoch 6/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5416 - accuracy: 0.7322 - val_loss: 0.5713 - val_accuracy: 0.7244
#
# Epoch 00006: val_accuracy did not improve from 0.73111
# Epoch 7/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5316 - accuracy: 0.7382 - val_loss: 0.5830 - val_accuracy: 0.7133
#
# Epoch 00007: val_accuracy did not improve from 0.73111
# Epoch 8/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5183 - accuracy: 0.7503 - val_loss: 0.5509 - val_accuracy: 0.7378
#
# Epoch 00008: val_accuracy improved from 0.73111 to 0.73778, saving model to ./models/tree_4/model_root_f1/folder2\model.h5
# Epoch 9/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5124 - accuracy: 0.7564 - val_loss: 0.5500 - val_accuracy: 0.7289
#
# Epoch 00009: val_accuracy did not improve from 0.73778
# Epoch 10/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4912 - accuracy: 0.7595 - val_loss: 0.5450 - val_accuracy: 0.7089
#
# Epoch 00010: val_accuracy did not improve from 0.73778
# Epoch 11/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4773 - accuracy: 0.7827 - val_loss: 0.5428 - val_accuracy: 0.7156
#
# Epoch 00011: val_accuracy did not improve from 0.73778
# Epoch 12/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4602 - accuracy: 0.7919 - val_loss: 0.5439 - val_accuracy: 0.7400
#
# Epoch 00012: val_accuracy improved from 0.73778 to 0.74000, saving model to ./models/tree_4/model_root_f1/folder2\model.h5
# Epoch 13/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4419 - accuracy: 0.7980 - val_loss: 0.5930 - val_accuracy: 0.6711
#
# Epoch 00013: val_accuracy did not improve from 0.74000
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 14/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4164 - accuracy: 0.8221 - val_loss: 0.5450 - val_accuracy: 0.7133
#
# Epoch 00014: val_accuracy did not improve from 0.74000
# Epoch 15/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4021 - accuracy: 0.8301 - val_loss: 0.5758 - val_accuracy: 0.7289
#
# Epoch 00015: val_accuracy did not improve from 0.74000
# Epoch 16/30
# 50/50 [==============================] - 4s 85ms/step - loss: 0.3939 - accuracy: 0.8285 - val_loss: 0.5456 - val_accuracy: 0.7311
#
# Epoch 00016: val_accuracy did not improve from 0.74000
# Epoch 17/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3878 - accuracy: 0.8351 - val_loss: 0.5670 - val_accuracy: 0.7444
#
# Epoch 00017: val_accuracy improved from 0.74000 to 0.74444, saving model to ./models/tree_4/model_root_f1/folder2\model.h5
# Epoch 18/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3682 - accuracy: 0.8520 - val_loss: 0.5744 - val_accuracy: 0.7378
#
# Epoch 00018: val_accuracy did not improve from 0.74444
# Epoch 19/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3705 - accuracy: 0.8482 - val_loss: 0.5619 - val_accuracy: 0.7089
#
# Epoch 00019: val_accuracy did not improve from 0.74444
# Epoch 20/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3468 - accuracy: 0.8647 - val_loss: 0.5686 - val_accuracy: 0.7200
#
# Epoch 00020: val_accuracy did not improve from 0.74444
# Epoch 21/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3333 - accuracy: 0.8691 - val_loss: 0.5645 - val_accuracy: 0.7311
#
# Epoch 00021: val_accuracy did not improve from 0.74444
# Epoch 22/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3256 - accuracy: 0.8790 - val_loss: 0.5585 - val_accuracy: 0.7422
#
# Epoch 00022: val_accuracy did not improve from 0.74444
# Epoch 23/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3101 - accuracy: 0.8872 - val_loss: 0.5672 - val_accuracy: 0.7556
#
# Epoch 00023: val_accuracy improved from 0.74444 to 0.75556, saving model to ./models/tree_4/model_root_f1/folder2\model.h5
# Epoch 24/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2961 - accuracy: 0.8999 - val_loss: 0.5720 - val_accuracy: 0.7267
#
# Epoch 00024: val_accuracy did not improve from 0.75556
# Epoch 25/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2932 - accuracy: 0.8945 - val_loss: 0.5813 - val_accuracy: 0.7133
#
# Epoch 00025: val_accuracy did not improve from 0.75556
# Epoch 26/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2678 - accuracy: 0.9117 - val_loss: 0.5716 - val_accuracy: 0.7378
#
# Epoch 00026: val_accuracy did not improve from 0.75556
# Epoch 27/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2526 - accuracy: 0.9225 - val_loss: 0.6002 - val_accuracy: 0.7444
#
# Epoch 00027: val_accuracy did not improve from 0.75556
# Epoch 28/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2484 - accuracy: 0.9247 - val_loss: 0.5796 - val_accuracy: 0.7378
#
# Epoch 00028: val_accuracy did not improve from 0.75556
# Epoch 29/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2335 - accuracy: 0.9269 - val_loss: 0.6081 - val_accuracy: 0.7089
#
# Epoch 00029: val_accuracy did not improve from 0.75556
# Epoch 30/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2278 - accuracy: 0.9273 - val_loss: 0.6340 - val_accuracy: 0.6956
#
# Epoch 00030: val_accuracy did not improve from 0.75556
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Folk', 'Pop'], ['Experimental', 'Rock']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 8s 100ms/step - loss: 0.6680 - accuracy: 0.6239 - val_loss: 0.6734 - val_accuracy: 0.5867
#
# Epoch 00001: val_accuracy improved from -inf to 0.58667, saving model to ./models/tree_4/model_root_f1/folder3\model.h5
# Epoch 2/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5939 - accuracy: 0.6903 - val_loss: 0.5556 - val_accuracy: 0.7378
#
# Epoch 00002: val_accuracy improved from 0.58667 to 0.73778, saving model to ./models/tree_4/model_root_f1/folder3\model.h5
# Epoch 3/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5584 - accuracy: 0.7255 - val_loss: 0.5715 - val_accuracy: 0.7178
#
# Epoch 00003: val_accuracy did not improve from 0.73778
# Epoch 4/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5464 - accuracy: 0.7220 - val_loss: 0.6376 - val_accuracy: 0.6600
#
# Epoch 00004: val_accuracy did not improve from 0.73778
# Epoch 5/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5431 - accuracy: 0.7271 - val_loss: 0.5310 - val_accuracy: 0.7556
#
# Epoch 00005: val_accuracy improved from 0.73778 to 0.75556, saving model to ./models/tree_4/model_root_f1/folder3\model.h5
# Epoch 6/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5004 - accuracy: 0.7551 - val_loss: 0.5244 - val_accuracy: 0.7422
#
# Epoch 00006: val_accuracy did not improve from 0.75556
# Epoch 7/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.5032 - accuracy: 0.7544 - val_loss: 0.6286 - val_accuracy: 0.6622
#
# Epoch 00007: val_accuracy did not improve from 0.75556
# Epoch 8/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4874 - accuracy: 0.7672 - val_loss: 0.5215 - val_accuracy: 0.7511
#
# Epoch 00008: val_accuracy did not improve from 0.75556
# Epoch 9/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4699 - accuracy: 0.7767 - val_loss: 0.5650 - val_accuracy: 0.7244
#
# Epoch 00009: val_accuracy did not improve from 0.75556
# Epoch 10/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4647 - accuracy: 0.7884 - val_loss: 0.5269 - val_accuracy: 0.7378
#
# Epoch 00010: val_accuracy did not improve from 0.75556
# Epoch 11/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4455 - accuracy: 0.7910 - val_loss: 0.5436 - val_accuracy: 0.7311
#
# Epoch 00011: val_accuracy did not improve from 0.75556
# Epoch 12/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4433 - accuracy: 0.7961 - val_loss: 0.5389 - val_accuracy: 0.7400
#
# Epoch 00012: val_accuracy did not improve from 0.75556
# Epoch 13/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4275 - accuracy: 0.8110 - val_loss: 0.6202 - val_accuracy: 0.6889
#
# Epoch 00013: val_accuracy did not improve from 0.75556
# Epoch 14/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4134 - accuracy: 0.8272 - val_loss: 0.5273 - val_accuracy: 0.7378
#
# Epoch 00014: val_accuracy did not improve from 0.75556
# Epoch 15/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3998 - accuracy: 0.8227 - val_loss: 0.5279 - val_accuracy: 0.7333
#
# Epoch 00015: val_accuracy did not improve from 0.75556
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 16/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3721 - accuracy: 0.8472 - val_loss: 0.5340 - val_accuracy: 0.7511
#
# Epoch 00016: val_accuracy did not improve from 0.75556
# Epoch 17/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3578 - accuracy: 0.8545 - val_loss: 0.5168 - val_accuracy: 0.7400
#
# Epoch 00017: val_accuracy did not improve from 0.75556
# Epoch 18/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3500 - accuracy: 0.8679 - val_loss: 0.5257 - val_accuracy: 0.7311
#
# Epoch 00018: val_accuracy did not improve from 0.75556
# Epoch 19/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3359 - accuracy: 0.8694 - val_loss: 0.5268 - val_accuracy: 0.7333
#
# Epoch 00019: val_accuracy did not improve from 0.75556
# Epoch 20/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3227 - accuracy: 0.8809 - val_loss: 0.5280 - val_accuracy: 0.7511
#
# Epoch 00020: val_accuracy did not improve from 0.75556
# Epoch 21/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3142 - accuracy: 0.8847 - val_loss: 0.5246 - val_accuracy: 0.7400
#
# Epoch 00021: val_accuracy did not improve from 0.75556
# Epoch 22/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3007 - accuracy: 0.8968 - val_loss: 0.5400 - val_accuracy: 0.7422
#
# Epoch 00022: val_accuracy did not improve from 0.75556
# Epoch 23/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2870 - accuracy: 0.9063 - val_loss: 0.5279 - val_accuracy: 0.7422
#
# Epoch 00023: val_accuracy did not improve from 0.75556
# Epoch 24/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2808 - accuracy: 0.9063 - val_loss: 0.5295 - val_accuracy: 0.7356
#
# Epoch 00024: val_accuracy did not improve from 0.75556
# Epoch 25/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2596 - accuracy: 0.9276 - val_loss: 0.5380 - val_accuracy: 0.7378
#
# Epoch 00025: val_accuracy did not improve from 0.75556
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 26/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2428 - accuracy: 0.9346 - val_loss: 0.5488 - val_accuracy: 0.7356
#
# Epoch 00026: val_accuracy did not improve from 0.75556
# Epoch 27/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2348 - accuracy: 0.9390 - val_loss: 0.5534 - val_accuracy: 0.7133
#
# Epoch 00027: val_accuracy did not improve from 0.75556
# Epoch 28/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2326 - accuracy: 0.9355 - val_loss: 0.5419 - val_accuracy: 0.7400
#
# Epoch 00028: val_accuracy did not improve from 0.75556
# Epoch 29/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2223 - accuracy: 0.9441 - val_loss: 0.5450 - val_accuracy: 0.7311
#
# Epoch 00029: val_accuracy did not improve from 0.75556
# Epoch 30/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.2163 - accuracy: 0.9457 - val_loss: 0.5493 - val_accuracy: 0.7356
#
# Epoch 00030: val_accuracy did not improve from 0.75556
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
