# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.layers import Bidirectional, concatenate, GRU, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7}
dict_genres = {'Electronic':0, 'Hip-Hop':3, 'Instrumental':4, 'International' :5}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Electronic', 3: 'Hip-Hop', 4: 'Instrumental', 5: 'International'}

# %%
npzfile = np.load('data/shuffled_train.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394,)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=8).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((3196, 640, 128), (3196, 8))

# %%
npzfile = np.load('data/shuffled_valid.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=8).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((400, 640, 128), (400, 8))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Instrumental

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=16 
nb_filters2=32 
nb_filters3=64
nb_filters4=64
nb_filters5=64
ksize_1 = (3,5)
ksize_2 = (3,1)
pool_size_1= (2,2) 
pool_size_2= (4,4)
pool_size_3 = (4,2)

lstm_count = 64

BATCH_SIZE = 64
EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize_1, strides=1, padding='valid', activation='elu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize_2, strides=1, padding='valid', activation='elu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize_2, strides=1, padding='valid', activation='elu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize_2, strides=1, padding='valid', activation='elu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_2)(conv_4)
    
    conv_5 = Conv2D(filters = nb_filters4, kernel_size = ksize_2, strides=1, padding='valid', activation='elu', name='conv_5')(pool_4)
    pool_5 = MaxPooling2D(pool_size_3)(conv_5)
    
    flatten1 = Flatten()(pool_5)
    
    ### Recurrent Block
    # Pooling layer
    pool_lstm1 = MaxPooling2D(pool_size_3, name='pool_lstm')(layer)
    
    # Embedding layer
    squeezed = Lambda(lambda x: K.squeeze(x, axis = -1))(pool_lstm1)
    
    # Bidirectional GRU
    lstm = Bidirectional(GRU(lstm_count))(squeezed)  #default merge mode is concat
    
    # Concat Output
    concat = concatenate([flatten1, lstm], axis = -1, name='concat')
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(concat)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.0005)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 640
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_4/model_root_f2/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_4/model_root_f2/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
def create_split(elem, c):
    splits = []
    for i in range(c):
        equal = False
        np.random.shuffle(elem)
        new_split = list(chunks(elem, int(len(elem)/2)))
        for split in splits:
            if set(new_split[0]) == set(split[0]) and set(new_split[0]) == set(split[1]):
                equal = True
                break
            
        if equal:
            i-=1
            continue
        
        splits.append(new_split)
        
    return splits

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 3

kfold = KFold(n_splits=8, shuffle=True)
genre_splits = create_split(list(dict_genres.values()), num_splits)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)

    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Hip-Hop', 'International'], ['Electronic', 'Instrumental']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 17s 111ms/step - loss: 0.6367 - accuracy: 0.6376 - val_loss: 0.5647 - val_accuracy: 0.7089
#
# Epoch 00001: val_accuracy improved from -inf to 0.70889, saving model to ./models/tree_4/model_root_f2/folder1\model.h5
# Epoch 2/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.5602 - accuracy: 0.7181 - val_loss: 0.5409 - val_accuracy: 0.7356
#
# Epoch 00002: val_accuracy improved from 0.70889 to 0.73556, saving model to ./models/tree_4/model_root_f2/folder1\model.h5
# Epoch 3/30
# 50/50 [==============================] - 4s 85ms/step - loss: 0.5166 - accuracy: 0.7508 - val_loss: 0.4954 - val_accuracy: 0.7422
#
# Epoch 00003: val_accuracy improved from 0.73556 to 0.74222, saving model to ./models/tree_4/model_root_f2/folder1\model.h5
# Epoch 4/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.4840 - accuracy: 0.7753 - val_loss: 0.4662 - val_accuracy: 0.7889
#
# Epoch 00004: val_accuracy improved from 0.74222 to 0.78889, saving model to ./models/tree_4/model_root_f2/folder1\model.h5
# Epoch 5/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.4455 - accuracy: 0.8004 - val_loss: 0.4398 - val_accuracy: 0.8267
#
# Epoch 00005: val_accuracy improved from 0.78889 to 0.82667, saving model to ./models/tree_4/model_root_f2/folder1\model.h5
# Epoch 6/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.4254 - accuracy: 0.7912 - val_loss: 0.4519 - val_accuracy: 0.7733
#
# Epoch 00006: val_accuracy did not improve from 0.82667
# Epoch 7/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.4380 - accuracy: 0.7966 - val_loss: 0.4272 - val_accuracy: 0.7822
#
# Epoch 00007: val_accuracy did not improve from 0.82667
# Epoch 8/30
# 50/50 [==============================] - 6s 128ms/step - loss: 0.3821 - accuracy: 0.8347 - val_loss: 0.4095 - val_accuracy: 0.8222
#
# Epoch 00008: val_accuracy did not improve from 0.82667
# Epoch 9/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.3642 - accuracy: 0.8373 - val_loss: 0.4390 - val_accuracy: 0.8244
#
# Epoch 00009: val_accuracy did not improve from 0.82667
# Epoch 10/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.3542 - accuracy: 0.8449 - val_loss: 0.4949 - val_accuracy: 0.7689
#
# Epoch 00010: val_accuracy did not improve from 0.82667
# Epoch 11/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3381 - accuracy: 0.8608 - val_loss: 0.4140 - val_accuracy: 0.8200
#
# Epoch 00011: val_accuracy did not improve from 0.82667
# Epoch 12/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.3241 - accuracy: 0.8627 - val_loss: 0.3966 - val_accuracy: 0.8133
#
# Epoch 00012: val_accuracy did not improve from 0.82667
# Epoch 13/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.2998 - accuracy: 0.8757 - val_loss: 0.3910 - val_accuracy: 0.8133
#
# Epoch 00013: val_accuracy did not improve from 0.82667
# Epoch 14/30
# 50/50 [==============================] - 4s 85ms/step - loss: 0.2785 - accuracy: 0.8913 - val_loss: 0.3871 - val_accuracy: 0.8156
#
# Epoch 00014: val_accuracy did not improve from 0.82667
# Epoch 15/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2641 - accuracy: 0.8992 - val_loss: 0.3831 - val_accuracy: 0.8222
#
# Epoch 00015: val_accuracy did not improve from 0.82667
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 16/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2401 - accuracy: 0.9094 - val_loss: 0.3758 - val_accuracy: 0.8178
#
# Epoch 00016: val_accuracy did not improve from 0.82667
# Epoch 17/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2338 - accuracy: 0.9145 - val_loss: 0.3681 - val_accuracy: 0.8356
#
# Epoch 00017: val_accuracy improved from 0.82667 to 0.83556, saving model to ./models/tree_4/model_root_f2/folder1\model.h5
# Epoch 18/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.2179 - accuracy: 0.9243 - val_loss: 0.3776 - val_accuracy: 0.8222
#
# Epoch 00018: val_accuracy did not improve from 0.83556
# Epoch 19/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.2134 - accuracy: 0.9259 - val_loss: 0.3706 - val_accuracy: 0.8244
#
# Epoch 00019: val_accuracy did not improve from 0.83556
# Epoch 20/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.2027 - accuracy: 0.9307 - val_loss: 0.3745 - val_accuracy: 0.8422
#
# Epoch 00020: val_accuracy improved from 0.83556 to 0.84222, saving model to ./models/tree_4/model_root_f2/folder1\model.h5
# Epoch 21/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.1870 - accuracy: 0.9450 - val_loss: 0.3904 - val_accuracy: 0.8333
#
# Epoch 00021: val_accuracy did not improve from 0.84222
# Epoch 22/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.1913 - accuracy: 0.9393 - val_loss: 0.3827 - val_accuracy: 0.8333
#
# Epoch 00022: val_accuracy did not improve from 0.84222
# Epoch 23/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.1810 - accuracy: 0.9412 - val_loss: 0.3819 - val_accuracy: 0.8311
#
# Epoch 00023: val_accuracy did not improve from 0.84222
# Epoch 24/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.1780 - accuracy: 0.9418 - val_loss: 0.3804 - val_accuracy: 0.8400
#
# Epoch 00024: val_accuracy did not improve from 0.84222
# Epoch 25/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.1793 - accuracy: 0.9364 - val_loss: 0.3822 - val_accuracy: 0.8444
#
# Epoch 00025: val_accuracy improved from 0.84222 to 0.84444, saving model to ./models/tree_4/model_root_f2/folder1\model.h5
# Epoch 26/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.1499 - accuracy: 0.9641 - val_loss: 0.3811 - val_accuracy: 0.8378
#
# Epoch 00026: val_accuracy did not improve from 0.84444
# Epoch 27/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.1433 - accuracy: 0.9660 - val_loss: 0.3929 - val_accuracy: 0.8267
#
# Epoch 00027: val_accuracy did not improve from 0.84444
# Epoch 28/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.1540 - accuracy: 0.9558 - val_loss: 0.3878 - val_accuracy: 0.8400
#
# Epoch 00028: val_accuracy did not improve from 0.84444
# Epoch 29/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.1326 - accuracy: 0.9704 - val_loss: 0.3962 - val_accuracy: 0.8378
#
# Epoch 00029: val_accuracy did not improve from 0.84444
# Epoch 30/30
# 50/50 [==============================] - 4s 87ms/step - loss: 0.1241 - accuracy: 0.9704 - val_loss: 0.4058 - val_accuracy: 0.8333
#
# Epoch 00030: val_accuracy did not improve from 0.84444
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Hip-Hop', 'Electronic'], ['Instrumental', 'International']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 8s 100ms/step - loss: 0.5771 - accuracy: 0.7022 - val_loss: 0.5184 - val_accuracy: 0.7533
#
# Epoch 00001: val_accuracy improved from -inf to 0.75333, saving model to ./models/tree_4/model_root_f2/folder2\model.h5
# Epoch 2/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.5110 - accuracy: 0.7600 - val_loss: 0.5086 - val_accuracy: 0.7711
#
# Epoch 00002: val_accuracy improved from 0.75333 to 0.77111, saving model to ./models/tree_4/model_root_f2/folder2\model.h5
# Epoch 3/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.4817 - accuracy: 0.7781 - val_loss: 0.4922 - val_accuracy: 0.7689
#
# Epoch 00003: val_accuracy did not improve from 0.77111
# Epoch 4/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.4674 - accuracy: 0.7934 - val_loss: 0.4878 - val_accuracy: 0.7667
#
# Epoch 00004: val_accuracy did not improve from 0.77111
# Epoch 5/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.4440 - accuracy: 0.7937 - val_loss: 0.4849 - val_accuracy: 0.7667
#
# Epoch 00005: val_accuracy did not improve from 0.77111
# Epoch 6/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.4424 - accuracy: 0.8004 - val_loss: 0.5018 - val_accuracy: 0.7444
#
# Epoch 00006: val_accuracy did not improve from 0.77111
# Epoch 7/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.4241 - accuracy: 0.8118 - val_loss: 0.5150 - val_accuracy: 0.7600
#
# Epoch 00007: val_accuracy did not improve from 0.77111
# Epoch 8/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.4029 - accuracy: 0.8245 - val_loss: 0.4741 - val_accuracy: 0.8000
#
# Epoch 00008: val_accuracy improved from 0.77111 to 0.80000, saving model to ./models/tree_4/model_root_f2/folder2\model.h5
# Epoch 9/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.3870 - accuracy: 0.8357 - val_loss: 0.4710 - val_accuracy: 0.7800
#
# Epoch 00009: val_accuracy did not improve from 0.80000
# Epoch 10/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.3725 - accuracy: 0.8414 - val_loss: 0.5685 - val_accuracy: 0.7200
#
# Epoch 00010: val_accuracy did not improve from 0.80000
# Epoch 11/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.3689 - accuracy: 0.8411 - val_loss: 0.5254 - val_accuracy: 0.7489
#
# Epoch 00011: val_accuracy did not improve from 0.80000
# Epoch 12/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.3404 - accuracy: 0.8551 - val_loss: 0.4649 - val_accuracy: 0.7867
#
# Epoch 00012: val_accuracy did not improve from 0.80000
# Epoch 13/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.3201 - accuracy: 0.8627 - val_loss: 0.5177 - val_accuracy: 0.7600
#
# Epoch 00013: val_accuracy did not improve from 0.80000
# Epoch 14/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.2973 - accuracy: 0.8779 - val_loss: 0.4609 - val_accuracy: 0.7956
#
# Epoch 00014: val_accuracy did not improve from 0.80000
# Epoch 15/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.2812 - accuracy: 0.8846 - val_loss: 0.6676 - val_accuracy: 0.7067
#
# Epoch 00015: val_accuracy did not improve from 0.80000
# Epoch 16/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.2579 - accuracy: 0.8999 - val_loss: 0.4641 - val_accuracy: 0.7956
#
# Epoch 00016: val_accuracy did not improve from 0.80000
# Epoch 17/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.2347 - accuracy: 0.9132 - val_loss: 0.4797 - val_accuracy: 0.7956
#
# Epoch 00017: val_accuracy did not improve from 0.80000
# Epoch 18/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.2156 - accuracy: 0.9266 - val_loss: 0.4933 - val_accuracy: 0.8000
#
# Epoch 00018: val_accuracy did not improve from 0.80000
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 19/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.1818 - accuracy: 0.9479 - val_loss: 0.4985 - val_accuracy: 0.7978
#
# Epoch 00019: val_accuracy did not improve from 0.80000
# Epoch 20/30
# 50/50 [==============================] - 4s 84ms/step - loss: 0.1658 - accuracy: 0.9555 - val_loss: 0.4914 - val_accuracy: 0.8022
#
# Epoch 00020: val_accuracy improved from 0.80000 to 0.80222, saving model to ./models/tree_4/model_root_f2/folder2\model.h5
# Epoch 21/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.1630 - accuracy: 0.9561 - val_loss: 0.4823 - val_accuracy: 0.7978
#
# Epoch 00021: val_accuracy did not improve from 0.80222
# Epoch 22/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.1463 - accuracy: 0.9628 - val_loss: 0.4950 - val_accuracy: 0.7978
#
# Epoch 00022: val_accuracy did not improve from 0.80222
# Epoch 23/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.1377 - accuracy: 0.9682 - val_loss: 0.5155 - val_accuracy: 0.8022
#
# Epoch 00023: val_accuracy did not improve from 0.80222
# Epoch 24/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.1234 - accuracy: 0.9736 - val_loss: 0.5151 - val_accuracy: 0.7911
#
# Epoch 00024: val_accuracy did not improve from 0.80222
# Epoch 25/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.1167 - accuracy: 0.9787 - val_loss: 0.6455 - val_accuracy: 0.7378
#
# Epoch 00025: val_accuracy did not improve from 0.80222
# Epoch 26/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.1119 - accuracy: 0.9777 - val_loss: 0.5771 - val_accuracy: 0.7867
#
# Epoch 00026: val_accuracy did not improve from 0.80222
# Epoch 27/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.1011 - accuracy: 0.9832 - val_loss: 0.5187 - val_accuracy: 0.7978
#
# Epoch 00027: val_accuracy did not improve from 0.80222
# Epoch 28/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.0880 - accuracy: 0.9882 - val_loss: 0.5453 - val_accuracy: 0.7956
#
# Epoch 00028: val_accuracy did not improve from 0.80222
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 29/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.0783 - accuracy: 0.9892 - val_loss: 0.5307 - val_accuracy: 0.7911
#
# Epoch 00029: val_accuracy did not improve from 0.80222
# Epoch 30/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.0784 - accuracy: 0.9911 - val_loss: 0.5401 - val_accuracy: 0.7889
#
# Epoch 00030: val_accuracy did not improve from 0.80222
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Hip-Hop', 'International'], ['Instrumental', 'Electronic']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 8s 96ms/step - loss: 0.6499 - accuracy: 0.6211 - val_loss: 0.6012 - val_accuracy: 0.6622
#
# Epoch 00001: val_accuracy improved from -inf to 0.66222, saving model to ./models/tree_4/model_root_f2/folder3\model.h5
# Epoch 2/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.5651 - accuracy: 0.6990 - val_loss: 0.6512 - val_accuracy: 0.6089
#
# Epoch 00002: val_accuracy did not improve from 0.66222
# Epoch 3/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.5218 - accuracy: 0.7381 - val_loss: 0.5373 - val_accuracy: 0.7267
#
# Epoch 00003: val_accuracy improved from 0.66222 to 0.72667, saving model to ./models/tree_4/model_root_f2/folder3\model.h5
# Epoch 4/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.5001 - accuracy: 0.7549 - val_loss: 0.5512 - val_accuracy: 0.7244
#
# Epoch 00004: val_accuracy did not improve from 0.72667
# Epoch 5/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.4633 - accuracy: 0.7918 - val_loss: 0.5198 - val_accuracy: 0.7444
#
# Epoch 00005: val_accuracy improved from 0.72667 to 0.74444, saving model to ./models/tree_4/model_root_f2/folder3\model.h5
# Epoch 6/30
# 50/50 [==============================] - 4s 82ms/step - loss: 0.4422 - accuracy: 0.7978 - val_loss: 0.5703 - val_accuracy: 0.7333
#
# Epoch 00006: val_accuracy did not improve from 0.74444
# Epoch 7/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.4434 - accuracy: 0.7978 - val_loss: 0.5116 - val_accuracy: 0.7622
#
# Epoch 00007: val_accuracy improved from 0.74444 to 0.76222, saving model to ./models/tree_4/model_root_f2/folder3\model.h5
# Epoch 8/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.4201 - accuracy: 0.8083 - val_loss: 0.5044 - val_accuracy: 0.7622
#
# Epoch 00008: val_accuracy did not improve from 0.76222
# Epoch 9/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.3895 - accuracy: 0.8258 - val_loss: 0.4904 - val_accuracy: 0.7711
#
# Epoch 00009: val_accuracy improved from 0.76222 to 0.77111, saving model to ./models/tree_4/model_root_f2/folder3\model.h5
# Epoch 10/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.3688 - accuracy: 0.8395 - val_loss: 0.4901 - val_accuracy: 0.7644
#
# Epoch 00010: val_accuracy did not improve from 0.77111
# Epoch 11/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.3739 - accuracy: 0.8350 - val_loss: 0.5018 - val_accuracy: 0.7644
#
# Epoch 00011: val_accuracy did not improve from 0.77111
# Epoch 12/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.3511 - accuracy: 0.8481 - val_loss: 0.4861 - val_accuracy: 0.7689
#
# Epoch 00012: val_accuracy did not improve from 0.77111
# Epoch 13/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.3394 - accuracy: 0.8541 - val_loss: 0.4631 - val_accuracy: 0.7867
#
# Epoch 00013: val_accuracy improved from 0.77111 to 0.78667, saving model to ./models/tree_4/model_root_f2/folder3\model.h5
# Epoch 14/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.3268 - accuracy: 0.8573 - val_loss: 0.4676 - val_accuracy: 0.7667
#
# Epoch 00014: val_accuracy did not improve from 0.78667
# Epoch 15/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.3223 - accuracy: 0.8630 - val_loss: 0.5455 - val_accuracy: 0.7511
#
# Epoch 00015: val_accuracy did not improve from 0.78667
# Epoch 16/30
# 50/50 [==============================] - 4s 82ms/step - loss: 0.3178 - accuracy: 0.8668 - val_loss: 0.5084 - val_accuracy: 0.7667
#
# Epoch 00016: val_accuracy did not improve from 0.78667
# Epoch 17/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.2970 - accuracy: 0.8741 - val_loss: 0.4611 - val_accuracy: 0.7844
#
# Epoch 00017: val_accuracy did not improve from 0.78667
# Epoch 18/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.2779 - accuracy: 0.8853 - val_loss: 0.4632 - val_accuracy: 0.7889
#
# Epoch 00018: val_accuracy improved from 0.78667 to 0.78889, saving model to ./models/tree_4/model_root_f2/folder3\model.h5
# Epoch 19/30
# 50/50 [==============================] - 4s 82ms/step - loss: 0.2586 - accuracy: 0.9011 - val_loss: 0.4640 - val_accuracy: 0.7822
#
# Epoch 00019: val_accuracy did not improve from 0.78889
# Epoch 20/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.2755 - accuracy: 0.8856 - val_loss: 0.4893 - val_accuracy: 0.7822
#
# Epoch 00020: val_accuracy did not improve from 0.78889
# Epoch 21/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.2271 - accuracy: 0.9145 - val_loss: 0.4872 - val_accuracy: 0.7844
#
# Epoch 00021: val_accuracy did not improve from 0.78889
# Epoch 22/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.2170 - accuracy: 0.9269 - val_loss: 0.5182 - val_accuracy: 0.7711
#
# Epoch 00022: val_accuracy did not improve from 0.78889
# Epoch 23/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.1958 - accuracy: 0.9332 - val_loss: 0.5033 - val_accuracy: 0.7689
#
# Epoch 00023: val_accuracy did not improve from 0.78889
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 24/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.1812 - accuracy: 0.9364 - val_loss: 0.5068 - val_accuracy: 0.7778
#
# Epoch 00024: val_accuracy did not improve from 0.78889
# Epoch 25/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.1668 - accuracy: 0.9482 - val_loss: 0.4681 - val_accuracy: 0.7956
#
# Epoch 00025: val_accuracy improved from 0.78889 to 0.79556, saving model to ./models/tree_4/model_root_f2/folder3\model.h5
# Epoch 26/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.1635 - accuracy: 0.9514 - val_loss: 0.5328 - val_accuracy: 0.7778
#
# Epoch 00026: val_accuracy did not improve from 0.79556
# Epoch 27/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.1488 - accuracy: 0.9577 - val_loss: 0.4957 - val_accuracy: 0.7800
#
# Epoch 00027: val_accuracy did not improve from 0.79556
# Epoch 28/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.1448 - accuracy: 0.9596 - val_loss: 0.5295 - val_accuracy: 0.7933
#
# Epoch 00028: val_accuracy did not improve from 0.79556
# Epoch 29/30
# 50/50 [==============================] - 4s 83ms/step - loss: 0.1420 - accuracy: 0.9580 - val_loss: 0.4893 - val_accuracy: 0.7844
#
# Epoch 00029: val_accuracy did not improve from 0.79556
# Epoch 30/30
# 50/50 [==============================] - 4s 82ms/step - loss: 0.1280 - accuracy: 0.9698 - val_loss: 0.4881 - val_accuracy: 0.7911
#
# Epoch 00030: val_accuracy did not improve from 0.79556
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
