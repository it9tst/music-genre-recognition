# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Country':2, 'Metal':6, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {2: 'Country', 6: 'Metal', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((2400, 128, 128), (2400, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((300, 128, 128), (300, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Country

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_9/model_root_f1_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_9/model_root_f1_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def create_split(elem):
    splits = list(set_partitions(elem, 2))
    
    return splits, len(splits)

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

genre_splits, num_splits = create_split(list(dict_genres.values()))
print("Num splits {}".format(num_splits))

if num_splits > 8:
    n_splits = num_splits
else:
    n_splits = 8

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Num splits 3
# Folder num 1
# Genre split [['Country'], ['Metal', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 74/74 [==============================] - 7s 27ms/step - loss: 0.6767 - accuracy: 0.6876 - val_loss: 0.4630 - val_accuracy: 0.7515
#
# Epoch 00001: val_accuracy improved from -inf to 0.75148, saving model to ./models/tree_9/model_root_f1_1/folder1\model.h5
# Epoch 2/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.4887 - accuracy: 0.7532 - val_loss: 0.6267 - val_accuracy: 0.7367
#
# Epoch 00002: val_accuracy did not improve from 0.75148
# Epoch 3/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.5565 - accuracy: 0.7273 - val_loss: 0.5326 - val_accuracy: 0.7071
#
# Epoch 00003: val_accuracy did not improve from 0.75148
# Epoch 4/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.4756 - accuracy: 0.7684 - val_loss: 0.4192 - val_accuracy: 0.7899
#
# Epoch 00004: val_accuracy improved from 0.75148 to 0.78994, saving model to ./models/tree_9/model_root_f1_1/folder1\model.h5
# Epoch 5/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.4052 - accuracy: 0.8078 - val_loss: 0.3987 - val_accuracy: 0.8225
#
# Epoch 00005: val_accuracy improved from 0.78994 to 0.82249, saving model to ./models/tree_9/model_root_f1_1/folder1\model.h5
# Epoch 6/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.3740 - accuracy: 0.8281 - val_loss: 0.4762 - val_accuracy: 0.7959
#
# Epoch 00006: val_accuracy did not improve from 0.82249
# Epoch 7/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.3994 - accuracy: 0.8103 - val_loss: 0.3808 - val_accuracy: 0.8402
#
# Epoch 00007: val_accuracy improved from 0.82249 to 0.84024, saving model to ./models/tree_9/model_root_f1_1/folder1\model.h5
# Epoch 8/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.3758 - accuracy: 0.8277 - val_loss: 0.3425 - val_accuracy: 0.8639
#
# Epoch 00008: val_accuracy improved from 0.84024 to 0.86391, saving model to ./models/tree_9/model_root_f1_1/folder1\model.h5
# Epoch 9/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.3440 - accuracy: 0.8484 - val_loss: 0.3326 - val_accuracy: 0.8373
#
# Epoch 00009: val_accuracy did not improve from 0.86391
# Epoch 10/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.3239 - accuracy: 0.8522 - val_loss: 0.3277 - val_accuracy: 0.8639
#
# Epoch 00010: val_accuracy did not improve from 0.86391
# Epoch 11/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.3377 - accuracy: 0.8421 - val_loss: 0.3241 - val_accuracy: 0.8639
#
# Epoch 00011: val_accuracy did not improve from 0.86391
# Epoch 12/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.3211 - accuracy: 0.8556 - val_loss: 0.3004 - val_accuracy: 0.8609
#
# Epoch 00012: val_accuracy did not improve from 0.86391
# Epoch 13/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.3211 - accuracy: 0.8586 - val_loss: 0.3399 - val_accuracy: 0.8432
#
# Epoch 00013: val_accuracy did not improve from 0.86391
# Epoch 14/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.3167 - accuracy: 0.8556 - val_loss: 0.3050 - val_accuracy: 0.8550
#
# Epoch 00014: val_accuracy did not improve from 0.86391
# Epoch 15/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.3170 - accuracy: 0.8565 - val_loss: 0.2902 - val_accuracy: 0.8728
#
# Epoch 00015: val_accuracy improved from 0.86391 to 0.87278, saving model to ./models/tree_9/model_root_f1_1/folder1\model.h5
# Epoch 16/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.3047 - accuracy: 0.8645 - val_loss: 0.3730 - val_accuracy: 0.8284
#
# Epoch 00016: val_accuracy did not improve from 0.87278
# Epoch 17/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.2916 - accuracy: 0.8730 - val_loss: 0.2981 - val_accuracy: 0.8669
#
# Epoch 00017: val_accuracy did not improve from 0.87278
# Epoch 18/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.2754 - accuracy: 0.8831 - val_loss: 0.2568 - val_accuracy: 0.8994
#
# Epoch 00018: val_accuracy improved from 0.87278 to 0.89941, saving model to ./models/tree_9/model_root_f1_1/folder1\model.h5
# Epoch 19/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.2678 - accuracy: 0.8853 - val_loss: 0.2695 - val_accuracy: 0.8669
#
# Epoch 00019: val_accuracy did not improve from 0.89941
# Epoch 20/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.2492 - accuracy: 0.8954 - val_loss: 0.2462 - val_accuracy: 0.8876
#
# Epoch 00020: val_accuracy did not improve from 0.89941
# Epoch 21/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.2310 - accuracy: 0.8984 - val_loss: 0.2126 - val_accuracy: 0.9112
#
# Epoch 00021: val_accuracy improved from 0.89941 to 0.91124, saving model to ./models/tree_9/model_root_f1_1/folder1\model.h5
# Epoch 22/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.1972 - accuracy: 0.9174 - val_loss: 0.1959 - val_accuracy: 0.9053
#
# Epoch 00022: val_accuracy did not improve from 0.91124
# Epoch 23/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.1663 - accuracy: 0.9297 - val_loss: 0.1761 - val_accuracy: 0.9201
#
# Epoch 00023: val_accuracy improved from 0.91124 to 0.92012, saving model to ./models/tree_9/model_root_f1_1/folder1\model.h5
# Epoch 24/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.1608 - accuracy: 0.9327 - val_loss: 0.1927 - val_accuracy: 0.9349
#
# Epoch 00024: val_accuracy improved from 0.92012 to 0.93491, saving model to ./models/tree_9/model_root_f1_1/folder1\model.h5
# Epoch 25/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.1549 - accuracy: 0.9348 - val_loss: 0.2158 - val_accuracy: 0.8935
#
# Epoch 00025: val_accuracy did not improve from 0.93491
# Epoch 26/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.1189 - accuracy: 0.9594 - val_loss: 0.2300 - val_accuracy: 0.9201
#
# Epoch 00026: val_accuracy did not improve from 0.93491
# Epoch 27/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.1104 - accuracy: 0.9568 - val_loss: 0.1784 - val_accuracy: 0.9349
#
# Epoch 00027: val_accuracy did not improve from 0.93491
# Epoch 28/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0969 - accuracy: 0.9640 - val_loss: 0.1880 - val_accuracy: 0.9201
#
# Epoch 00028: val_accuracy did not improve from 0.93491
# Epoch 29/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0832 - accuracy: 0.9708 - val_loss: 0.1876 - val_accuracy: 0.9438
#
# Epoch 00029: val_accuracy improved from 0.93491 to 0.94379, saving model to ./models/tree_9/model_root_f1_1/folder1\model.h5
# Epoch 30/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0571 - accuracy: 0.9780 - val_loss: 0.1783 - val_accuracy: 0.9320
#
# Epoch 00030: val_accuracy did not improve from 0.94379
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Country', 'Metal'], ['Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 74/74 [==============================] - 2s 20ms/step - loss: 0.7527 - accuracy: 0.6461 - val_loss: 0.6305 - val_accuracy: 0.6746
#
# Epoch 00001: val_accuracy improved from -inf to 0.67456, saving model to ./models/tree_9/model_root_f1_1/folder2\model.h5
# Epoch 2/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.6476 - accuracy: 0.6655 - val_loss: 0.6374 - val_accuracy: 0.6746
#
# Epoch 00002: val_accuracy did not improve from 0.67456
# Epoch 3/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.6391 - accuracy: 0.6655 - val_loss: 0.6210 - val_accuracy: 0.6746
#
# Epoch 00003: val_accuracy did not improve from 0.67456
# Epoch 4/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.6098 - accuracy: 0.6605 - val_loss: 0.6126 - val_accuracy: 0.6746
#
# Epoch 00004: val_accuracy did not improve from 0.67456
# Epoch 5/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.6032 - accuracy: 0.6660 - val_loss: 0.6005 - val_accuracy: 0.6479
#
# Epoch 00005: val_accuracy did not improve from 0.67456
# Epoch 6/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.5830 - accuracy: 0.6787 - val_loss: 0.5811 - val_accuracy: 0.6953
#
# Epoch 00006: val_accuracy improved from 0.67456 to 0.69527, saving model to ./models/tree_9/model_root_f1_1/folder2\model.h5
# Epoch 7/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.5638 - accuracy: 0.6897 - val_loss: 0.5755 - val_accuracy: 0.6953
#
# Epoch 00007: val_accuracy did not improve from 0.69527
# Epoch 8/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.5620 - accuracy: 0.7079 - val_loss: 0.5665 - val_accuracy: 0.7160
#
# Epoch 00008: val_accuracy improved from 0.69527 to 0.71598, saving model to ./models/tree_9/model_root_f1_1/folder2\model.h5
# Epoch 9/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.5436 - accuracy: 0.7142 - val_loss: 0.5678 - val_accuracy: 0.6923
#
# Epoch 00009: val_accuracy did not improve from 0.71598
# Epoch 10/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.5431 - accuracy: 0.7155 - val_loss: 0.5531 - val_accuracy: 0.7160
#
# Epoch 00010: val_accuracy did not improve from 0.71598
# Epoch 11/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.5174 - accuracy: 0.7333 - val_loss: 0.5509 - val_accuracy: 0.6982
#
# Epoch 00011: val_accuracy did not improve from 0.71598
# Epoch 12/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.5095 - accuracy: 0.7392 - val_loss: 0.5392 - val_accuracy: 0.7249
#
# Epoch 00012: val_accuracy improved from 0.71598 to 0.72485, saving model to ./models/tree_9/model_root_f1_1/folder2\model.h5
# Epoch 13/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.5063 - accuracy: 0.7477 - val_loss: 0.5430 - val_accuracy: 0.7278
#
# Epoch 00013: val_accuracy improved from 0.72485 to 0.72781, saving model to ./models/tree_9/model_root_f1_1/folder2\model.h5
# Epoch 14/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.5132 - accuracy: 0.7413 - val_loss: 0.5241 - val_accuracy: 0.7249
#
# Epoch 00014: val_accuracy did not improve from 0.72781
# Epoch 15/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.4892 - accuracy: 0.7489 - val_loss: 0.5377 - val_accuracy: 0.7012
#
# Epoch 00015: val_accuracy did not improve from 0.72781
# Epoch 16/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.4553 - accuracy: 0.7807 - val_loss: 0.4726 - val_accuracy: 0.7574
#
# Epoch 00016: val_accuracy improved from 0.72781 to 0.75740, saving model to ./models/tree_9/model_root_f1_1/folder2\model.h5
# Epoch 17/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.4181 - accuracy: 0.8023 - val_loss: 0.4763 - val_accuracy: 0.7604
#
# Epoch 00017: val_accuracy improved from 0.75740 to 0.76036, saving model to ./models/tree_9/model_root_f1_1/folder2\model.h5
# Epoch 18/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.4213 - accuracy: 0.8006 - val_loss: 0.5326 - val_accuracy: 0.7426
#
# Epoch 00018: val_accuracy did not improve from 0.76036
# Epoch 19/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.3805 - accuracy: 0.8209 - val_loss: 0.4315 - val_accuracy: 0.7751
#
# Epoch 00019: val_accuracy improved from 0.76036 to 0.77515, saving model to ./models/tree_9/model_root_f1_1/folder2\model.h5
# Epoch 20/30
# 74/74 [==============================] - ETA: 0s - loss: 0.3597 - accuracy: 0.84 - 1s 17ms/step - loss: 0.3597 - accuracy: 0.8493 - val_loss: 0.4099 - val_accuracy: 0.8166
#
# Epoch 00020: val_accuracy improved from 0.77515 to 0.81657, saving model to ./models/tree_9/model_root_f1_1/folder2\model.h5
# Epoch 21/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.3065 - accuracy: 0.8704 - val_loss: 0.3798 - val_accuracy: 0.8373
#
# Epoch 00021: val_accuracy improved from 0.81657 to 0.83728, saving model to ./models/tree_9/model_root_f1_1/folder2\model.h5
# Epoch 22/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.2715 - accuracy: 0.8895 - val_loss: 0.4343 - val_accuracy: 0.8314
#
# Epoch 00022: val_accuracy did not improve from 0.83728
# Epoch 23/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.2420 - accuracy: 0.9005 - val_loss: 0.3792 - val_accuracy: 0.8254
#
# Epoch 00023: val_accuracy did not improve from 0.83728
# Epoch 24/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.2294 - accuracy: 0.8988 - val_loss: 0.4114 - val_accuracy: 0.8136
#
# Epoch 00024: val_accuracy did not improve from 0.83728
# Epoch 25/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.2058 - accuracy: 0.9179 - val_loss: 0.3931 - val_accuracy: 0.8373
#
# Epoch 00025: val_accuracy did not improve from 0.83728
# Epoch 26/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.1843 - accuracy: 0.9259 - val_loss: 0.3797 - val_accuracy: 0.8373
#
# Epoch 00026: val_accuracy did not improve from 0.83728
# Epoch 27/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.1264 - accuracy: 0.9530 - val_loss: 0.4632 - val_accuracy: 0.8432
#
# Epoch 00027: val_accuracy improved from 0.83728 to 0.84320, saving model to ./models/tree_9/model_root_f1_1/folder2\model.h5
# Epoch 28/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.1122 - accuracy: 0.9589 - val_loss: 0.5758 - val_accuracy: 0.7929
#
# Epoch 00028: val_accuracy did not improve from 0.84320
# Epoch 29/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0715 - accuracy: 0.9776 - val_loss: 0.4141 - val_accuracy: 0.8462
#
# Epoch 00029: val_accuracy improved from 0.84320 to 0.84615, saving model to ./models/tree_9/model_root_f1_1/folder2\model.h5
# Epoch 30/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0519 - accuracy: 0.9894 - val_loss: 0.4776 - val_accuracy: 0.8432
#
# Epoch 00030: val_accuracy did not improve from 0.84615
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Metal'], ['Country', 'Rock']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 74/74 [==============================] - 2s 20ms/step - loss: 0.4844 - accuracy: 0.7866 - val_loss: 0.2494 - val_accuracy: 0.9024
#
# Epoch 00001: val_accuracy improved from -inf to 0.90237, saving model to ./models/tree_9/model_root_f1_1/folder3\model.h5
# Epoch 2/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.2185 - accuracy: 0.9170 - val_loss: 0.1965 - val_accuracy: 0.9290
#
# Epoch 00002: val_accuracy improved from 0.90237 to 0.92899, saving model to ./models/tree_9/model_root_f1_1/folder3\model.h5
# Epoch 3/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.1789 - accuracy: 0.9276 - val_loss: 0.2190 - val_accuracy: 0.9231
#
# Epoch 00003: val_accuracy did not improve from 0.92899
# Epoch 4/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.1695 - accuracy: 0.9369 - val_loss: 0.1717 - val_accuracy: 0.9467
#
# Epoch 00004: val_accuracy improved from 0.92899 to 0.94675, saving model to ./models/tree_9/model_root_f1_1/folder3\model.h5
# Epoch 5/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.1252 - accuracy: 0.9572 - val_loss: 0.1532 - val_accuracy: 0.9556
#
# Epoch 00005: val_accuracy improved from 0.94675 to 0.95562, saving model to ./models/tree_9/model_root_f1_1/folder3\model.h5
# Epoch 6/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.1385 - accuracy: 0.9467 - val_loss: 0.1223 - val_accuracy: 0.9527
#
# Epoch 00006: val_accuracy did not improve from 0.95562
# Epoch 7/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.1076 - accuracy: 0.9640 - val_loss: 0.1146 - val_accuracy: 0.9675
#
# Epoch 00007: val_accuracy improved from 0.95562 to 0.96746, saving model to ./models/tree_9/model_root_f1_1/folder3\model.h5
# Epoch 8/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.1111 - accuracy: 0.9560 - val_loss: 0.1405 - val_accuracy: 0.9586
#
# Epoch 00008: val_accuracy did not improve from 0.96746
# Epoch 9/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.1009 - accuracy: 0.9632 - val_loss: 0.1064 - val_accuracy: 0.9675
#
# Epoch 00009: val_accuracy did not improve from 0.96746
# Epoch 10/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0932 - accuracy: 0.9640 - val_loss: 0.0938 - val_accuracy: 0.9615
#
# Epoch 00010: val_accuracy did not improve from 0.96746
# Epoch 11/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0766 - accuracy: 0.9716 - val_loss: 0.0844 - val_accuracy: 0.9645
#
# Epoch 00011: val_accuracy did not improve from 0.96746
# Epoch 12/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0819 - accuracy: 0.9678 - val_loss: 0.0718 - val_accuracy: 0.9675
#
# Epoch 00012: val_accuracy did not improve from 0.96746
# Epoch 13/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0685 - accuracy: 0.9716 - val_loss: 0.0920 - val_accuracy: 0.9615
#
# Epoch 00013: val_accuracy did not improve from 0.96746
# Epoch 14/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0622 - accuracy: 0.9763 - val_loss: 0.0701 - val_accuracy: 0.9645
#
# Epoch 00014: val_accuracy did not improve from 0.96746
# Epoch 15/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0428 - accuracy: 0.9848 - val_loss: 0.1102 - val_accuracy: 0.9675
#
# Epoch 00015: val_accuracy did not improve from 0.96746
# Epoch 16/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0480 - accuracy: 0.9822 - val_loss: 0.0964 - val_accuracy: 0.9645
#
# Epoch 00016: val_accuracy did not improve from 0.96746
# Epoch 17/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0326 - accuracy: 0.9898 - val_loss: 0.0943 - val_accuracy: 0.9645
#
# Epoch 00017: val_accuracy did not improve from 0.96746
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 18/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0265 - accuracy: 0.9903 - val_loss: 0.0826 - val_accuracy: 0.9645
#
# Epoch 00018: val_accuracy did not improve from 0.96746
# Epoch 19/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0178 - accuracy: 0.9949 - val_loss: 0.0833 - val_accuracy: 0.9615
#
# Epoch 00019: val_accuracy did not improve from 0.96746
# Epoch 20/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0140 - accuracy: 0.9958 - val_loss: 0.1108 - val_accuracy: 0.9675
#
# Epoch 00020: val_accuracy did not improve from 0.96746
# Epoch 21/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0154 - accuracy: 0.9941 - val_loss: 0.0869 - val_accuracy: 0.9704
#
# Epoch 00021: val_accuracy improved from 0.96746 to 0.97041, saving model to ./models/tree_9/model_root_f1_1/folder3\model.h5
# Epoch 22/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0153 - accuracy: 0.9953 - val_loss: 0.0812 - val_accuracy: 0.9734
#
# Epoch 00022: val_accuracy improved from 0.97041 to 0.97337, saving model to ./models/tree_9/model_root_f1_1/folder3\model.h5
# Epoch 23/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0122 - accuracy: 0.9953 - val_loss: 0.0894 - val_accuracy: 0.9675
#
# Epoch 00023: val_accuracy did not improve from 0.97337
# Epoch 24/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0112 - accuracy: 0.9958 - val_loss: 0.0803 - val_accuracy: 0.9675
#
# Epoch 00024: val_accuracy did not improve from 0.97337
# Epoch 25/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0120 - accuracy: 0.9966 - val_loss: 0.1144 - val_accuracy: 0.9675
#
# Epoch 00025: val_accuracy did not improve from 0.97337
# Epoch 26/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0110 - accuracy: 0.9966 - val_loss: 0.0902 - val_accuracy: 0.9704
#
# Epoch 00026: val_accuracy did not improve from 0.97337
# Epoch 27/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0130 - accuracy: 0.9953 - val_loss: 0.1111 - val_accuracy: 0.9645
#
# Epoch 00027: val_accuracy did not improve from 0.97337
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 28/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0151 - accuracy: 0.9962 - val_loss: 0.1029 - val_accuracy: 0.9704
#
# Epoch 00028: val_accuracy did not improve from 0.97337
# Epoch 29/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0078 - accuracy: 0.9958 - val_loss: 0.0983 - val_accuracy: 0.9675
#
# Epoch 00029: val_accuracy did not improve from 0.97337
# Epoch 30/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0109 - accuracy: 0.9953 - val_loss: 0.1098 - val_accuracy: 0.9586
#
# Epoch 00030: val_accuracy did not improve from 0.97337
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
