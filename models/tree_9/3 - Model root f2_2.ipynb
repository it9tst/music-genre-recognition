# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Blues':0, 'Classical':1, 'Jazz':5}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Blues', 1: 'Classical', 5: 'Jazz'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((2390, 128, 128), (2390, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((300, 128, 128), (300, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Classical

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_9/model_root_f2_2/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_9/model_root_f2_2/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def create_split(elem):
    splits = list(set_partitions(elem, 2))
    
    return splits, len(splits)

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

genre_splits, num_splits = create_split(list(dict_genres.values()))
print("Num splits {}".format(num_splits))

if num_splits > 8:
    n_splits = num_splits
else:
    n_splits = 8

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Num splits 3
# Folder num 1
# Genre split [['Blues'], ['Classical', 'Jazz']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 74/74 [==============================] - 5s 24ms/step - loss: 0.7432 - accuracy: 0.6604 - val_loss: 0.5476 - val_accuracy: 0.6973
#
# Epoch 00001: val_accuracy improved from -inf to 0.69733, saving model to ./models/tree_9/model_root_f2_2/folder1\model.h5
# Epoch 2/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.4331 - accuracy: 0.8100 - val_loss: 0.3393 - val_accuracy: 0.8546
#
# Epoch 00002: val_accuracy improved from 0.69733 to 0.85460, saving model to ./models/tree_9/model_root_f2_2/folder1\model.h5
# Epoch 3/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.3640 - accuracy: 0.8419 - val_loss: 0.3237 - val_accuracy: 0.8754
#
# Epoch 00003: val_accuracy improved from 0.85460 to 0.87537, saving model to ./models/tree_9/model_root_f2_2/folder1\model.h5
# Epoch 4/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.2942 - accuracy: 0.8759 - val_loss: 0.2102 - val_accuracy: 0.9258
#
# Epoch 00004: val_accuracy improved from 0.87537 to 0.92582, saving model to ./models/tree_9/model_root_f2_2/folder1\model.h5
# Epoch 5/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.2577 - accuracy: 0.8916 - val_loss: 0.2403 - val_accuracy: 0.8932
#
# Epoch 00005: val_accuracy did not improve from 0.92582
# Epoch 6/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.2285 - accuracy: 0.8980 - val_loss: 0.2548 - val_accuracy: 0.8783
#
# Epoch 00006: val_accuracy did not improve from 0.92582
# Epoch 7/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.2035 - accuracy: 0.9146 - val_loss: 0.1638 - val_accuracy: 0.9407
#
# Epoch 00007: val_accuracy improved from 0.92582 to 0.94065, saving model to ./models/tree_9/model_root_f2_2/folder1\model.h5
# Epoch 8/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.1832 - accuracy: 0.9227 - val_loss: 0.2603 - val_accuracy: 0.8694
#
# Epoch 00008: val_accuracy did not improve from 0.94065
# Epoch 9/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.1658 - accuracy: 0.9290 - val_loss: 0.1552 - val_accuracy: 0.9288
#
# Epoch 00009: val_accuracy did not improve from 0.94065
# Epoch 10/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.1380 - accuracy: 0.9380 - val_loss: 0.1313 - val_accuracy: 0.9525
#
# Epoch 00010: val_accuracy improved from 0.94065 to 0.95252, saving model to ./models/tree_9/model_root_f2_2/folder1\model.h5
# Epoch 11/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.1240 - accuracy: 0.9465 - val_loss: 0.1795 - val_accuracy: 0.9228
#
# Epoch 00011: val_accuracy did not improve from 0.95252
# Epoch 12/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.1054 - accuracy: 0.9550 - val_loss: 0.1269 - val_accuracy: 0.9525
#
# Epoch 00012: val_accuracy did not improve from 0.95252
# Epoch 13/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.1040 - accuracy: 0.9537 - val_loss: 0.1459 - val_accuracy: 0.9436
#
# Epoch 00013: val_accuracy did not improve from 0.95252
# Epoch 14/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0899 - accuracy: 0.9647 - val_loss: 0.1532 - val_accuracy: 0.9407
#
# Epoch 00014: val_accuracy did not improve from 0.95252
# Epoch 15/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0858 - accuracy: 0.9622 - val_loss: 0.1143 - val_accuracy: 0.9466
#
# Epoch 00015: val_accuracy did not improve from 0.95252
# Epoch 16/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0672 - accuracy: 0.9754 - val_loss: 0.1126 - val_accuracy: 0.9496
#
# Epoch 00016: val_accuracy did not improve from 0.95252
# Epoch 17/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0577 - accuracy: 0.9796 - val_loss: 0.1344 - val_accuracy: 0.9347
#
# Epoch 00017: val_accuracy did not improve from 0.95252
# Epoch 18/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0510 - accuracy: 0.9788 - val_loss: 0.1120 - val_accuracy: 0.9614
#
# Epoch 00018: val_accuracy improved from 0.95252 to 0.96142, saving model to ./models/tree_9/model_root_f2_2/folder1\model.h5
# Epoch 19/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0502 - accuracy: 0.9809 - val_loss: 0.1721 - val_accuracy: 0.9407
#
# Epoch 00019: val_accuracy did not improve from 0.96142
# Epoch 20/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0311 - accuracy: 0.9890 - val_loss: 0.2427 - val_accuracy: 0.9318
#
# Epoch 00020: val_accuracy did not improve from 0.96142
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0184 - accuracy: 0.9953 - val_loss: 0.1392 - val_accuracy: 0.9525
#
# Epoch 00021: val_accuracy did not improve from 0.96142
# Epoch 22/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0102 - accuracy: 0.9983 - val_loss: 0.1607 - val_accuracy: 0.9496
#
# Epoch 00022: val_accuracy did not improve from 0.96142
# Epoch 23/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0086 - accuracy: 0.9992 - val_loss: 0.1194 - val_accuracy: 0.9555
#
# Epoch 00023: val_accuracy did not improve from 0.96142
# Epoch 24/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0064 - accuracy: 0.9992 - val_loss: 0.1565 - val_accuracy: 0.9555
#
# Epoch 00024: val_accuracy did not improve from 0.96142
# Epoch 25/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0059 - accuracy: 0.9996 - val_loss: 0.1429 - val_accuracy: 0.9525
#
# Epoch 00025: val_accuracy did not improve from 0.96142
# Epoch 26/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0050 - accuracy: 0.9996 - val_loss: 0.1329 - val_accuracy: 0.9555
#
# Epoch 00026: val_accuracy did not improve from 0.96142
# Epoch 27/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9555
#
# Epoch 00027: val_accuracy did not improve from 0.96142
# Epoch 28/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0032 - accuracy: 0.9996 - val_loss: 0.1277 - val_accuracy: 0.9496
#
# Epoch 00028: val_accuracy did not improve from 0.96142
# Epoch 29/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9525
#
# Epoch 00029: val_accuracy did not improve from 0.96142
# Epoch 30/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9555
#
# Epoch 00030: val_accuracy did not improve from 0.96142
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Blues', 'Classical'], ['Jazz']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 74/74 [==============================] - 2s 20ms/step - loss: 0.7526 - accuracy: 0.6515 - val_loss: 0.6338 - val_accuracy: 0.6736
#
# Epoch 00001: val_accuracy improved from -inf to 0.67359, saving model to ./models/tree_9/model_root_f2_2/folder2\model.h5
# Epoch 2/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.6354 - accuracy: 0.6685 - val_loss: 0.6219 - val_accuracy: 0.6736
#
# Epoch 00002: val_accuracy did not improve from 0.67359
# Epoch 3/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.6332 - accuracy: 0.6685 - val_loss: 0.6364 - val_accuracy: 0.6736
#
# Epoch 00003: val_accuracy did not improve from 0.67359
# Epoch 4/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.6333 - accuracy: 0.6664 - val_loss: 0.5662 - val_accuracy: 0.7300
#
# Epoch 00004: val_accuracy improved from 0.67359 to 0.72997, saving model to ./models/tree_9/model_root_f2_2/folder2\model.h5
# Epoch 5/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.5990 - accuracy: 0.6889 - val_loss: 0.4938 - val_accuracy: 0.7567
#
# Epoch 00005: val_accuracy improved from 0.72997 to 0.75668, saving model to ./models/tree_9/model_root_f2_2/folder2\model.h5
# Epoch 6/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.4956 - accuracy: 0.7739 - val_loss: 0.4320 - val_accuracy: 0.8042
#
# Epoch 00006: val_accuracy improved from 0.75668 to 0.80415, saving model to ./models/tree_9/model_root_f2_2/folder2\model.h5
# Epoch 7/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.4212 - accuracy: 0.8147 - val_loss: 0.3794 - val_accuracy: 0.8249
#
# Epoch 00007: val_accuracy improved from 0.80415 to 0.82493, saving model to ./models/tree_9/model_root_f2_2/folder2\model.h5
# Epoch 8/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.3637 - accuracy: 0.8398 - val_loss: 0.3201 - val_accuracy: 0.8605
#
# Epoch 00008: val_accuracy improved from 0.82493 to 0.86053, saving model to ./models/tree_9/model_root_f2_2/folder2\model.h5
# Epoch 9/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.3143 - accuracy: 0.8742 - val_loss: 0.3406 - val_accuracy: 0.8457
#
# Epoch 00009: val_accuracy did not improve from 0.86053
# Epoch 10/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.2835 - accuracy: 0.8959 - val_loss: 0.3228 - val_accuracy: 0.8665
#
# Epoch 00010: val_accuracy improved from 0.86053 to 0.86647, saving model to ./models/tree_9/model_root_f2_2/folder2\model.h5
# Epoch 11/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.2300 - accuracy: 0.9176 - val_loss: 0.2148 - val_accuracy: 0.9258
#
# Epoch 00011: val_accuracy improved from 0.86647 to 0.92582, saving model to ./models/tree_9/model_root_f2_2/folder2\model.h5
# Epoch 12/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.1670 - accuracy: 0.9448 - val_loss: 0.2532 - val_accuracy: 0.8902
#
# Epoch 00012: val_accuracy did not improve from 0.92582
# Epoch 13/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.1585 - accuracy: 0.9460 - val_loss: 0.2280 - val_accuracy: 0.9021
#
# Epoch 00013: val_accuracy did not improve from 0.92582
# Epoch 14/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.1263 - accuracy: 0.9618 - val_loss: 0.1806 - val_accuracy: 0.9407
#
# Epoch 00014: val_accuracy improved from 0.92582 to 0.94065, saving model to ./models/tree_9/model_root_f2_2/folder2\model.h5
# Epoch 15/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0862 - accuracy: 0.9758 - val_loss: 0.1873 - val_accuracy: 0.9377
#
# Epoch 00015: val_accuracy did not improve from 0.94065
# Epoch 16/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0672 - accuracy: 0.9762 - val_loss: 0.2400 - val_accuracy: 0.9288
#
# Epoch 00016: val_accuracy did not improve from 0.94065
# Epoch 17/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0719 - accuracy: 0.9771 - val_loss: 0.1778 - val_accuracy: 0.9377
#
# Epoch 00017: val_accuracy did not improve from 0.94065
# Epoch 18/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0398 - accuracy: 0.9885 - val_loss: 0.1808 - val_accuracy: 0.9525
#
# Epoch 00018: val_accuracy improved from 0.94065 to 0.95252, saving model to ./models/tree_9/model_root_f2_2/folder2\model.h5
# Epoch 19/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0380 - accuracy: 0.9898 - val_loss: 0.2114 - val_accuracy: 0.9377
#
# Epoch 00019: val_accuracy did not improve from 0.95252
# Epoch 20/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0264 - accuracy: 0.9949 - val_loss: 0.1799 - val_accuracy: 0.9347
#
# Epoch 00020: val_accuracy did not improve from 0.95252
# Epoch 21/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0651 - accuracy: 0.9754 - val_loss: 0.2043 - val_accuracy: 0.9377
#
# Epoch 00021: val_accuracy did not improve from 0.95252
# Epoch 22/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0341 - accuracy: 0.9881 - val_loss: 0.2185 - val_accuracy: 0.9407
#
# Epoch 00022: val_accuracy did not improve from 0.95252
# Epoch 23/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0243 - accuracy: 0.9928 - val_loss: 0.2034 - val_accuracy: 0.9525
#
# Epoch 00023: val_accuracy did not improve from 0.95252
# Epoch 24/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0149 - accuracy: 0.9945 - val_loss: 0.2352 - val_accuracy: 0.9347
#
# Epoch 00024: val_accuracy did not improve from 0.95252
# Epoch 25/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.1916 - val_accuracy: 0.9555
#
# Epoch 00025: val_accuracy improved from 0.95252 to 0.95549, saving model to ./models/tree_9/model_root_f2_2/folder2\model.h5
# Epoch 26/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1987 - val_accuracy: 0.9585
#
# Epoch 00026: val_accuracy improved from 0.95549 to 0.95846, saving model to ./models/tree_9/model_root_f2_2/folder2\model.h5
# Epoch 27/30
# 74/74 [==============================] - 1s 18ms/step - loss: 8.5826e-04 - accuracy: 1.0000 - val_loss: 0.2058 - val_accuracy: 0.9585
#
# Epoch 00027: val_accuracy did not improve from 0.95846
# Epoch 28/30
# 74/74 [==============================] - 1s 17ms/step - loss: 6.5633e-04 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9585
#
# Epoch 00028: val_accuracy did not improve from 0.95846
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 29/30
# 74/74 [==============================] - 1s 18ms/step - loss: 5.2406e-04 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9614
#
# Epoch 00029: val_accuracy improved from 0.95846 to 0.96142, saving model to ./models/tree_9/model_root_f2_2/folder2\model.h5
# Epoch 30/30
# 74/74 [==============================] - 1s 18ms/step - loss: 4.7897e-04 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9585
#
# Epoch 00030: val_accuracy did not improve from 0.96142
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Classical'], ['Blues', 'Jazz']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 74/74 [==============================] - 2s 26ms/step - loss: 0.5129 - accuracy: 0.7574 - val_loss: 0.3945 - val_accuracy: 0.8214
#
# Epoch 00001: val_accuracy improved from -inf to 0.82143, saving model to ./models/tree_9/model_root_f2_2/folder3\model.h5
# Epoch 2/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.2650 - accuracy: 0.8900 - val_loss: 0.2597 - val_accuracy: 0.8988
#
# Epoch 00002: val_accuracy improved from 0.82143 to 0.89881, saving model to ./models/tree_9/model_root_f2_2/folder3\model.h5
# Epoch 3/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.2373 - accuracy: 0.8976 - val_loss: 0.2363 - val_accuracy: 0.8988
#
# Epoch 00003: val_accuracy did not improve from 0.89881
# Epoch 4/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.1826 - accuracy: 0.9333 - val_loss: 0.2637 - val_accuracy: 0.8720
#
# Epoch 00004: val_accuracy did not improve from 0.89881
# Epoch 5/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.1845 - accuracy: 0.9252 - val_loss: 0.2634 - val_accuracy: 0.8899
#
# Epoch 00005: val_accuracy did not improve from 0.89881
# Epoch 6/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.1451 - accuracy: 0.9452 - val_loss: 0.1850 - val_accuracy: 0.9375
#
# Epoch 00006: val_accuracy improved from 0.89881 to 0.93750, saving model to ./models/tree_9/model_root_f2_2/folder3\model.h5
# Epoch 7/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.1401 - accuracy: 0.9435 - val_loss: 0.1564 - val_accuracy: 0.9375
#
# Epoch 00007: val_accuracy did not improve from 0.93750
# Epoch 8/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.1167 - accuracy: 0.9516 - val_loss: 0.1447 - val_accuracy: 0.9405
#
# Epoch 00008: val_accuracy improved from 0.93750 to 0.94048, saving model to ./models/tree_9/model_root_f2_2/folder3\model.h5
# Epoch 9/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0944 - accuracy: 0.9609 - val_loss: 0.1405 - val_accuracy: 0.9464
#
# Epoch 00009: val_accuracy improved from 0.94048 to 0.94643, saving model to ./models/tree_9/model_root_f2_2/folder3\model.h5
# Epoch 10/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.1102 - accuracy: 0.9575 - val_loss: 0.1404 - val_accuracy: 0.9554
#
# Epoch 00010: val_accuracy improved from 0.94643 to 0.95536, saving model to ./models/tree_9/model_root_f2_2/folder3\model.h5
# Epoch 11/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0742 - accuracy: 0.9703 - val_loss: 0.1098 - val_accuracy: 0.9583
#
# Epoch 00011: val_accuracy improved from 0.95536 to 0.95833, saving model to ./models/tree_9/model_root_f2_2/folder3\model.h5
# Epoch 12/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0779 - accuracy: 0.9686 - val_loss: 0.1551 - val_accuracy: 0.9435
#
# Epoch 00012: val_accuracy did not improve from 0.95833
# Epoch 13/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0671 - accuracy: 0.9741 - val_loss: 0.0860 - val_accuracy: 0.9673
#
# Epoch 00013: val_accuracy improved from 0.95833 to 0.96726, saving model to ./models/tree_9/model_root_f2_2/folder3\model.h5
# Epoch 14/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0467 - accuracy: 0.9792 - val_loss: 0.1445 - val_accuracy: 0.9345
#
# Epoch 00014: val_accuracy did not improve from 0.96726
# Epoch 15/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0438 - accuracy: 0.9856 - val_loss: 0.1236 - val_accuracy: 0.9375
#
# Epoch 00015: val_accuracy did not improve from 0.96726
# Epoch 16/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0304 - accuracy: 0.9890 - val_loss: 0.1017 - val_accuracy: 0.9643
#
# Epoch 00016: val_accuracy did not improve from 0.96726
# Epoch 17/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0256 - accuracy: 0.9902 - val_loss: 0.0909 - val_accuracy: 0.9792
#
# Epoch 00017: val_accuracy improved from 0.96726 to 0.97917, saving model to ./models/tree_9/model_root_f2_2/folder3\model.h5
# Epoch 18/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0289 - accuracy: 0.9890 - val_loss: 0.1222 - val_accuracy: 0.9583
#
# Epoch 00018: val_accuracy did not improve from 0.97917
# Epoch 19/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0391 - accuracy: 0.9860 - val_loss: 0.1175 - val_accuracy: 0.9702
#
# Epoch 00019: val_accuracy did not improve from 0.97917
# Epoch 20/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0342 - accuracy: 0.9873 - val_loss: 0.1265 - val_accuracy: 0.9673
#
# Epoch 00020: val_accuracy did not improve from 0.97917
# Epoch 21/30
# 74/74 [==============================] - 4s 52ms/step - loss: 0.0219 - accuracy: 0.9919 - val_loss: 0.1103 - val_accuracy: 0.9762
#
# Epoch 00021: val_accuracy did not improve from 0.97917
# Epoch 22/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0153 - accuracy: 0.9945 - val_loss: 0.1069 - val_accuracy: 0.9702
#
# Epoch 00022: val_accuracy did not improve from 0.97917
# Epoch 23/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0053 - accuracy: 0.9996 - val_loss: 0.0970 - val_accuracy: 0.9732
#
# Epoch 00023: val_accuracy did not improve from 0.97917
# Epoch 24/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1012 - val_accuracy: 0.9792
#
# Epoch 00024: val_accuracy did not improve from 0.97917
# Epoch 25/30
# 74/74 [==============================] - 1s 18ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1032 - val_accuracy: 0.9762
#
# Epoch 00025: val_accuracy did not improve from 0.97917
# Epoch 26/30
# 74/74 [==============================] - 1s 17ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1145 - val_accuracy: 0.9732
#
# Epoch 00026: val_accuracy did not improve from 0.97917
# Epoch 27/30
# 74/74 [==============================] - 1s 18ms/step - loss: 6.6666e-04 - accuracy: 1.0000 - val_loss: 0.1210 - val_accuracy: 0.9732
#
# Epoch 00027: val_accuracy did not improve from 0.97917
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 28/30
# 74/74 [==============================] - 1s 17ms/step - loss: 3.7243e-04 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9792
#
# Epoch 00028: val_accuracy did not improve from 0.97917
# Epoch 29/30
# 74/74 [==============================] - 1s 18ms/step - loss: 3.3383e-04 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 0.9762
#
# Epoch 00029: val_accuracy did not improve from 0.97917
# Epoch 30/30
# 74/74 [==============================] - 1s 17ms/step - loss: 3.2044e-04 - accuracy: 1.0000 - val_loss: 0.1199 - val_accuracy: 0.9821
#
# Epoch 00030: val_accuracy improved from 0.97917 to 0.98214, saving model to ./models/tree_9/model_root_f2_2/folder3\model.h5
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
