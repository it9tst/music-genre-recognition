# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Country':2, 'Disco':3, 'Metal':6, 'Pop':7, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {2: 'Country', 3: 'Disco', 6: 'Metal', 7: 'Pop', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((4000, 128, 128), (4000, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((500, 128, 128), (500, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Disco

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_9/model_root_f1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_9/model_root_f1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def create_split(elem):
    splits = list(set_partitions(elem, 2))
    _splits = []
    for i in range(len(splits)):
        try:
            if len(splits[i][0]) != 1 and len(splits[i][1]) != 1:
                _splits.append(splits[i])
        except:
            continue
    
    return _splits, len(_splits)

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

genre_splits, num_splits = create_split(list(dict_genres.values()))
print("Num splits {}".format(num_splits))

if num_splits > 8:
    n_splits = num_splits
else:
    n_splits = 8

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Num splits 10
# Folder num 1
# Genre split [['Country', 'Disco'], ['Metal', 'Pop', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 7s 23ms/step - loss: 0.7123 - accuracy: 0.5864 - val_loss: 0.6705 - val_accuracy: 0.5800
#
# Epoch 00001: val_accuracy improved from -inf to 0.58000, saving model to ./models/tree_9/model_root_f1/folder1\model.h5
# Epoch 2/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6552 - accuracy: 0.6170 - val_loss: 0.6803 - val_accuracy: 0.5800
#
# Epoch 00002: val_accuracy did not improve from 0.58000
# Epoch 3/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6733 - accuracy: 0.6022 - val_loss: 0.6819 - val_accuracy: 0.5800
#
# Epoch 00003: val_accuracy did not improve from 0.58000
# Epoch 4/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6741 - accuracy: 0.6022 - val_loss: 0.6852 - val_accuracy: 0.5800
#
# Epoch 00004: val_accuracy did not improve from 0.58000
# Epoch 5/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6733 - accuracy: 0.6022 - val_loss: 0.6813 - val_accuracy: 0.5800
#
# Epoch 00005: val_accuracy did not improve from 0.58000
# Epoch 6/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6733 - accuracy: 0.6022 - val_loss: 0.6834 - val_accuracy: 0.5800
#
# Epoch 00006: val_accuracy did not improve from 0.58000
# Epoch 7/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6734 - accuracy: 0.6022 - val_loss: 0.6819 - val_accuracy: 0.5800
#
# Epoch 00007: val_accuracy did not improve from 0.58000
# Epoch 8/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6727 - accuracy: 0.6022 - val_loss: 0.6818 - val_accuracy: 0.5800
#
# Epoch 00008: val_accuracy did not improve from 0.58000
# Epoch 9/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6728 - accuracy: 0.6022 - val_loss: 0.6803 - val_accuracy: 0.5800
#
# Epoch 00009: val_accuracy did not improve from 0.58000
# Epoch 10/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6729 - accuracy: 0.6022 - val_loss: 0.6839 - val_accuracy: 0.5800
#
# Epoch 00010: val_accuracy did not improve from 0.58000
# Epoch 11/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6730 - accuracy: 0.6022 - val_loss: 0.6827 - val_accuracy: 0.5800
#
# Epoch 00011: val_accuracy did not improve from 0.58000
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 12/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6725 - accuracy: 0.6022 - val_loss: 0.6822 - val_accuracy: 0.5800
#
# Epoch 00012: val_accuracy did not improve from 0.58000
# Epoch 13/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6727 - accuracy: 0.6022 - val_loss: 0.6814 - val_accuracy: 0.5800
#
# Epoch 00013: val_accuracy did not improve from 0.58000
# Epoch 14/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6725 - accuracy: 0.6022 - val_loss: 0.6838 - val_accuracy: 0.5800
#
# Epoch 00014: val_accuracy did not improve from 0.58000
# Epoch 15/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6728 - accuracy: 0.6022 - val_loss: 0.6811 - val_accuracy: 0.5800
#
# Epoch 00015: val_accuracy did not improve from 0.58000
# Epoch 16/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6723 - accuracy: 0.6022 - val_loss: 0.6825 - val_accuracy: 0.5800
#
# Epoch 00016: val_accuracy did not improve from 0.58000
# Epoch 17/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6725 - accuracy: 0.6022 - val_loss: 0.6826 - val_accuracy: 0.5800
#
# Epoch 00017: val_accuracy did not improve from 0.58000
# Epoch 18/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6725 - accuracy: 0.6022 - val_loss: 0.6815 - val_accuracy: 0.5800
#
# Epoch 00018: val_accuracy did not improve from 0.58000
# Epoch 19/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6726 - accuracy: 0.6022 - val_loss: 0.6815 - val_accuracy: 0.5800
#
# Epoch 00019: val_accuracy did not improve from 0.58000
# Epoch 20/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6726 - accuracy: 0.6022 - val_loss: 0.6806 - val_accuracy: 0.5800
#
# Epoch 00020: val_accuracy did not improve from 0.58000
# Epoch 21/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6726 - accuracy: 0.6022 - val_loss: 0.6804 - val_accuracy: 0.5800
#
# Epoch 00021: val_accuracy did not improve from 0.58000
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 22/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6723 - accuracy: 0.6022 - val_loss: 0.6818 - val_accuracy: 0.5800
#
# Epoch 00022: val_accuracy did not improve from 0.58000
# Epoch 23/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6723 - accuracy: 0.6022 - val_loss: 0.6810 - val_accuracy: 0.5800
#
# Epoch 00023: val_accuracy did not improve from 0.58000
# Epoch 24/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6724 - accuracy: 0.6022 - val_loss: 0.6813 - val_accuracy: 0.5800
#
# Epoch 00024: val_accuracy did not improve from 0.58000
# Epoch 25/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6722 - accuracy: 0.6022 - val_loss: 0.6817 - val_accuracy: 0.5800
#
# Epoch 00025: val_accuracy did not improve from 0.58000
# Epoch 26/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6723 - accuracy: 0.6022 - val_loss: 0.6808 - val_accuracy: 0.5800
#
# Epoch 00026: val_accuracy did not improve from 0.58000
# Epoch 27/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6723 - accuracy: 0.6022 - val_loss: 0.6809 - val_accuracy: 0.5800
#
# Epoch 00027: val_accuracy did not improve from 0.58000
# Epoch 28/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6723 - accuracy: 0.6022 - val_loss: 0.6809 - val_accuracy: 0.5800
#
# Epoch 00028: val_accuracy did not improve from 0.58000
# Epoch 29/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6725 - accuracy: 0.6022 - val_loss: 0.6814 - val_accuracy: 0.5800
#
# Epoch 00029: val_accuracy did not improve from 0.58000
# Epoch 30/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6726 - accuracy: 0.6022 - val_loss: 0.6812 - val_accuracy: 0.5800
#
# Epoch 00030: val_accuracy did not improve from 0.58000
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Country', 'Disco', 'Metal'], ['Pop', 'Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 3s 19ms/step - loss: 0.7358 - accuracy: 0.6368 - val_loss: 0.6453 - val_accuracy: 0.6889
#
# Epoch 00001: val_accuracy improved from -inf to 0.68889, saving model to ./models/tree_9/model_root_f1/folder2\model.h5
# Epoch 2/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6539 - accuracy: 0.6200 - val_loss: 0.6103 - val_accuracy: 0.6578
#
# Epoch 00002: val_accuracy did not improve from 0.68889
# Epoch 3/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6079 - accuracy: 0.6756 - val_loss: 0.6070 - val_accuracy: 0.6600
#
# Epoch 00003: val_accuracy did not improve from 0.68889
# Epoch 4/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6005 - accuracy: 0.6864 - val_loss: 0.6132 - val_accuracy: 0.7044
#
# Epoch 00004: val_accuracy improved from 0.68889 to 0.70444, saving model to ./models/tree_9/model_root_f1/folder2\model.h5
# Epoch 5/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.5899 - accuracy: 0.7005 - val_loss: 0.6235 - val_accuracy: 0.7200
#
# Epoch 00005: val_accuracy improved from 0.70444 to 0.72000, saving model to ./models/tree_9/model_root_f1/folder2\model.h5
# Epoch 6/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.5659 - accuracy: 0.7198 - val_loss: 0.5908 - val_accuracy: 0.6378
#
# Epoch 00006: val_accuracy did not improve from 0.72000
# Epoch 7/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.5546 - accuracy: 0.7222 - val_loss: 0.5863 - val_accuracy: 0.7244
#
# Epoch 00007: val_accuracy improved from 0.72000 to 0.72444, saving model to ./models/tree_9/model_root_f1/folder2\model.h5
# Epoch 8/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.5488 - accuracy: 0.7153 - val_loss: 0.6052 - val_accuracy: 0.7089
#
# Epoch 00008: val_accuracy did not improve from 0.72444
# Epoch 9/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.5431 - accuracy: 0.7215 - val_loss: 0.5736 - val_accuracy: 0.7000
#
# Epoch 00009: val_accuracy did not improve from 0.72444
# Epoch 10/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.5415 - accuracy: 0.7309 - val_loss: 0.5620 - val_accuracy: 0.7222
#
# Epoch 00010: val_accuracy did not improve from 0.72444
# Epoch 11/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.5234 - accuracy: 0.7304 - val_loss: 0.5556 - val_accuracy: 0.6756
#
# Epoch 00011: val_accuracy did not improve from 0.72444
# Epoch 12/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.5221 - accuracy: 0.7390 - val_loss: 0.5579 - val_accuracy: 0.7111
#
# Epoch 00012: val_accuracy did not improve from 0.72444
# Epoch 13/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.5083 - accuracy: 0.7528 - val_loss: 0.5567 - val_accuracy: 0.7267
#
# Epoch 00013: val_accuracy improved from 0.72444 to 0.72667, saving model to ./models/tree_9/model_root_f1/folder2\model.h5
# Epoch 14/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.4980 - accuracy: 0.7533 - val_loss: 0.5379 - val_accuracy: 0.6956
#
# Epoch 00014: val_accuracy did not improve from 0.72667
# Epoch 15/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.4920 - accuracy: 0.7570 - val_loss: 0.5377 - val_accuracy: 0.7267
#
# Epoch 00015: val_accuracy did not improve from 0.72667
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 16/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.4772 - accuracy: 0.7691 - val_loss: 0.5313 - val_accuracy: 0.7133
#
# Epoch 00016: val_accuracy did not improve from 0.72667
# Epoch 17/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.4646 - accuracy: 0.7723 - val_loss: 0.5385 - val_accuracy: 0.7311
#
# Epoch 00017: val_accuracy improved from 0.72667 to 0.73111, saving model to ./models/tree_9/model_root_f1/folder2\model.h5
# Epoch 18/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.4609 - accuracy: 0.7756 - val_loss: 0.5336 - val_accuracy: 0.7244
#
# Epoch 00018: val_accuracy did not improve from 0.73111
# Epoch 19/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.4530 - accuracy: 0.7790 - val_loss: 0.5199 - val_accuracy: 0.7356
#
# Epoch 00019: val_accuracy improved from 0.73111 to 0.73556, saving model to ./models/tree_9/model_root_f1/folder2\model.h5
# Epoch 20/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.4398 - accuracy: 0.7886 - val_loss: 0.5288 - val_accuracy: 0.7378
#
# Epoch 00020: val_accuracy improved from 0.73556 to 0.73778, saving model to ./models/tree_9/model_root_f1/folder2\model.h5
# Epoch 21/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.4294 - accuracy: 0.7988 - val_loss: 0.5132 - val_accuracy: 0.7400
#
# Epoch 00021: val_accuracy improved from 0.73778 to 0.74000, saving model to ./models/tree_9/model_root_f1/folder2\model.h5
# Epoch 22/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.4018 - accuracy: 0.8116 - val_loss: 0.4771 - val_accuracy: 0.7689
#
# Epoch 00022: val_accuracy improved from 0.74000 to 0.76889, saving model to ./models/tree_9/model_root_f1/folder2\model.h5
# Epoch 23/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.3918 - accuracy: 0.8136 - val_loss: 0.5073 - val_accuracy: 0.7600
#
# Epoch 00023: val_accuracy did not improve from 0.76889
# Epoch 24/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.3731 - accuracy: 0.8281 - val_loss: 0.4439 - val_accuracy: 0.7889
#
# Epoch 00024: val_accuracy improved from 0.76889 to 0.78889, saving model to ./models/tree_9/model_root_f1/folder2\model.h5
# Epoch 25/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.3518 - accuracy: 0.8412 - val_loss: 0.4755 - val_accuracy: 0.7822
#
# Epoch 00025: val_accuracy did not improve from 0.78889
# Epoch 26/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.3410 - accuracy: 0.8504 - val_loss: 0.4410 - val_accuracy: 0.7778
#
# Epoch 00026: val_accuracy did not improve from 0.78889
# Epoch 27/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.3166 - accuracy: 0.8627 - val_loss: 0.4292 - val_accuracy: 0.8044
#
# Epoch 00027: val_accuracy improved from 0.78889 to 0.80444, saving model to ./models/tree_9/model_root_f1/folder2\model.h5
# Epoch 28/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.3024 - accuracy: 0.8630 - val_loss: 0.3935 - val_accuracy: 0.8222
#
# Epoch 00028: val_accuracy improved from 0.80444 to 0.82222, saving model to ./models/tree_9/model_root_f1/folder2\model.h5
# Epoch 29/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.2866 - accuracy: 0.8753 - val_loss: 0.4451 - val_accuracy: 0.7978
#
# Epoch 00029: val_accuracy did not improve from 0.82222
# Epoch 30/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.2629 - accuracy: 0.8886 - val_loss: 0.3787 - val_accuracy: 0.8267
#
# Epoch 00030: val_accuracy improved from 0.82222 to 0.82667, saving model to ./models/tree_9/model_root_f1/folder2\model.h5
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Disco', 'Metal'], ['Country', 'Pop', 'Rock']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 3s 20ms/step - loss: 0.6407 - accuracy: 0.6847 - val_loss: 0.4818 - val_accuracy: 0.7956
#
# Epoch 00001: val_accuracy improved from -inf to 0.79556, saving model to ./models/tree_9/model_root_f1/folder3\model.h5
# Epoch 2/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.4728 - accuracy: 0.7933 - val_loss: 0.4756 - val_accuracy: 0.7978
#
# Epoch 00002: val_accuracy improved from 0.79556 to 0.79778, saving model to ./models/tree_9/model_root_f1/folder3\model.h5
# Epoch 3/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.4464 - accuracy: 0.8119 - val_loss: 0.4701 - val_accuracy: 0.7933
#
# Epoch 00003: val_accuracy did not improve from 0.79778
# Epoch 4/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.4176 - accuracy: 0.8195 - val_loss: 0.4726 - val_accuracy: 0.7556
#
# Epoch 00004: val_accuracy did not improve from 0.79778
# Epoch 5/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.3466 - accuracy: 0.8625 - val_loss: 0.3290 - val_accuracy: 0.8667
#
# Epoch 00005: val_accuracy improved from 0.79778 to 0.86667, saving model to ./models/tree_9/model_root_f1/folder3\model.h5
# Epoch 6/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.3153 - accuracy: 0.8701 - val_loss: 0.2719 - val_accuracy: 0.8844
#
# Epoch 00006: val_accuracy improved from 0.86667 to 0.88444, saving model to ./models/tree_9/model_root_f1/folder3\model.h5
# Epoch 7/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.2762 - accuracy: 0.8978 - val_loss: 0.2949 - val_accuracy: 0.8667
#
# Epoch 00007: val_accuracy did not improve from 0.88444
# Epoch 8/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.2308 - accuracy: 0.9119 - val_loss: 0.2007 - val_accuracy: 0.9200
#
# Epoch 00008: val_accuracy improved from 0.88444 to 0.92000, saving model to ./models/tree_9/model_root_f1/folder3\model.h5
# Epoch 9/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.2032 - accuracy: 0.9225 - val_loss: 0.2488 - val_accuracy: 0.9067
#
# Epoch 00009: val_accuracy did not improve from 0.92000
# Epoch 10/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.2093 - accuracy: 0.9200 - val_loss: 0.2131 - val_accuracy: 0.9111
#
# Epoch 00010: val_accuracy did not improve from 0.92000
# Epoch 11/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1674 - accuracy: 0.9368 - val_loss: 0.2391 - val_accuracy: 0.9111
#
# Epoch 00011: val_accuracy did not improve from 0.92000
# Epoch 12/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1416 - accuracy: 0.9454 - val_loss: 0.2087 - val_accuracy: 0.9244
#
# Epoch 00012: val_accuracy improved from 0.92000 to 0.92444, saving model to ./models/tree_9/model_root_f1/folder3\model.h5
# Epoch 13/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1120 - accuracy: 0.9620 - val_loss: 0.2509 - val_accuracy: 0.9067
#
# Epoch 00013: val_accuracy did not improve from 0.92444
# Epoch 14/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1019 - accuracy: 0.9654 - val_loss: 0.2346 - val_accuracy: 0.9022
#
# Epoch 00014: val_accuracy did not improve from 0.92444
# Epoch 15/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0899 - accuracy: 0.9677 - val_loss: 0.2716 - val_accuracy: 0.9111
#
# Epoch 00015: val_accuracy did not improve from 0.92444
# Epoch 16/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0720 - accuracy: 0.9726 - val_loss: 0.2114 - val_accuracy: 0.9156
#
# Epoch 00016: val_accuracy did not improve from 0.92444
# Epoch 17/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0437 - accuracy: 0.9849 - val_loss: 0.2064 - val_accuracy: 0.9356
#
# Epoch 00017: val_accuracy improved from 0.92444 to 0.93556, saving model to ./models/tree_9/model_root_f1/folder3\model.h5
# Epoch 18/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0263 - accuracy: 0.9919 - val_loss: 0.2190 - val_accuracy: 0.9356
#
# Epoch 00018: val_accuracy did not improve from 0.93556
# Epoch 19/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0389 - accuracy: 0.9872 - val_loss: 0.3509 - val_accuracy: 0.8978
#
# Epoch 00019: val_accuracy did not improve from 0.93556
# Epoch 20/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0386 - accuracy: 0.9859 - val_loss: 0.2342 - val_accuracy: 0.9400
#
# Epoch 00020: val_accuracy improved from 0.93556 to 0.94000, saving model to ./models/tree_9/model_root_f1/folder3\model.h5
# Epoch 21/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0268 - accuracy: 0.9921 - val_loss: 0.2739 - val_accuracy: 0.9311
#
# Epoch 00021: val_accuracy did not improve from 0.94000
# Epoch 22/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0269 - accuracy: 0.9926 - val_loss: 0.2237 - val_accuracy: 0.9356
#
# Epoch 00022: val_accuracy did not improve from 0.94000
# Epoch 23/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0168 - accuracy: 0.9953 - val_loss: 0.2549 - val_accuracy: 0.9378
#
# Epoch 00023: val_accuracy did not improve from 0.94000
# Epoch 24/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0137 - accuracy: 0.9968 - val_loss: 0.2536 - val_accuracy: 0.9422
#
# Epoch 00024: val_accuracy improved from 0.94000 to 0.94222, saving model to ./models/tree_9/model_root_f1/folder3\model.h5
# Epoch 25/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0326 - accuracy: 0.9896 - val_loss: 0.2785 - val_accuracy: 0.9333
#
# Epoch 00025: val_accuracy did not improve from 0.94222
# Epoch 26/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0479 - accuracy: 0.9852 - val_loss: 0.2994 - val_accuracy: 0.9178
#
# Epoch 00026: val_accuracy did not improve from 0.94222
# Epoch 27/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0264 - accuracy: 0.9906 - val_loss: 0.3286 - val_accuracy: 0.9267
#
# Epoch 00027: val_accuracy did not improve from 0.94222
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 28/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0107 - accuracy: 0.9963 - val_loss: 0.2880 - val_accuracy: 0.9333
#
# Epoch 00028: val_accuracy did not improve from 0.94222
# Epoch 29/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0078 - accuracy: 0.9980 - val_loss: 0.2748 - val_accuracy: 0.9356
#
# Epoch 00029: val_accuracy did not improve from 0.94222
# Epoch 30/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0102 - accuracy: 0.9968 - val_loss: 0.3583 - val_accuracy: 0.9200
#
# Epoch 00030: val_accuracy did not improve from 0.94222
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Country', 'Metal'], ['Disco', 'Pop', 'Rock']]
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 3s 19ms/step - loss: 0.6899 - accuracy: 0.6272 - val_loss: 0.6021 - val_accuracy: 0.6644
#
# Epoch 00001: val_accuracy improved from -inf to 0.66444, saving model to ./models/tree_9/model_root_f1/folder4\model.h5
# Epoch 2/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.4972 - accuracy: 0.7519 - val_loss: 0.4573 - val_accuracy: 0.7911
#
# Epoch 00002: val_accuracy improved from 0.66444 to 0.79111, saving model to ./models/tree_9/model_root_f1/folder4\model.h5
# Epoch 3/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.4241 - accuracy: 0.7852 - val_loss: 0.4850 - val_accuracy: 0.7422
#
# Epoch 00003: val_accuracy did not improve from 0.79111
# Epoch 4/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.3796 - accuracy: 0.8116 - val_loss: 0.4057 - val_accuracy: 0.8200
#
# Epoch 00004: val_accuracy improved from 0.79111 to 0.82000, saving model to ./models/tree_9/model_root_f1/folder4\model.h5
# Epoch 5/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.3518 - accuracy: 0.8346 - val_loss: 0.3936 - val_accuracy: 0.8156
#
# Epoch 00005: val_accuracy did not improve from 0.82000
# Epoch 6/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.3006 - accuracy: 0.8583 - val_loss: 0.4045 - val_accuracy: 0.8422
#
# Epoch 00006: val_accuracy improved from 0.82000 to 0.84222, saving model to ./models/tree_9/model_root_f1/folder4\model.h5
# Epoch 7/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.2828 - accuracy: 0.8728 - val_loss: 0.3474 - val_accuracy: 0.8422
#
# Epoch 00007: val_accuracy did not improve from 0.84222
# Epoch 8/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.2506 - accuracy: 0.8931 - val_loss: 0.4189 - val_accuracy: 0.8200
#
# Epoch 00008: val_accuracy did not improve from 0.84222
# Epoch 9/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.2188 - accuracy: 0.9096 - val_loss: 0.4611 - val_accuracy: 0.7778
#
# Epoch 00009: val_accuracy did not improve from 0.84222
# Epoch 10/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1818 - accuracy: 0.9217 - val_loss: 0.3991 - val_accuracy: 0.8444
#
# Epoch 00010: val_accuracy improved from 0.84222 to 0.84444, saving model to ./models/tree_9/model_root_f1/folder4\model.h5
# Epoch 11/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1405 - accuracy: 0.9435 - val_loss: 0.3918 - val_accuracy: 0.8622
#
# Epoch 00011: val_accuracy improved from 0.84444 to 0.86222, saving model to ./models/tree_9/model_root_f1/folder4\model.h5
# Epoch 12/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1223 - accuracy: 0.9501 - val_loss: 0.4519 - val_accuracy: 0.8511
#
# Epoch 00012: val_accuracy did not improve from 0.86222
# Epoch 13/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1116 - accuracy: 0.9551 - val_loss: 0.3194 - val_accuracy: 0.8978
#
# Epoch 00013: val_accuracy improved from 0.86222 to 0.89778, saving model to ./models/tree_9/model_root_f1/folder4\model.h5
# Epoch 14/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0709 - accuracy: 0.9760 - val_loss: 0.4114 - val_accuracy: 0.8578
#
# Epoch 00014: val_accuracy did not improve from 0.89778
# Epoch 15/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0534 - accuracy: 0.9815 - val_loss: 0.4348 - val_accuracy: 0.8822
#
# Epoch 00015: val_accuracy did not improve from 0.89778
# Epoch 16/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0541 - accuracy: 0.9795 - val_loss: 0.4654 - val_accuracy: 0.8622
#
# Epoch 00016: val_accuracy did not improve from 0.89778
# Epoch 17/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0535 - accuracy: 0.9795 - val_loss: 0.5038 - val_accuracy: 0.8867
#
# Epoch 00017: val_accuracy did not improve from 0.89778
# Epoch 18/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0523 - accuracy: 0.9795 - val_loss: 0.4698 - val_accuracy: 0.8978
#
# Epoch 00018: val_accuracy did not improve from 0.89778
# Epoch 19/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0257 - accuracy: 0.9941 - val_loss: 0.4804 - val_accuracy: 0.8911
#
# Epoch 00019: val_accuracy did not improve from 0.89778
# Epoch 20/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0160 - accuracy: 0.9965 - val_loss: 0.5287 - val_accuracy: 0.8711
#
# Epoch 00020: val_accuracy did not improve from 0.89778
# Epoch 21/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0319 - accuracy: 0.9886 - val_loss: 0.4536 - val_accuracy: 0.8756
#
# Epoch 00021: val_accuracy did not improve from 0.89778
# Epoch 22/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0224 - accuracy: 0.9931 - val_loss: 0.5860 - val_accuracy: 0.8689
#
# Epoch 00022: val_accuracy did not improve from 0.89778
# Epoch 23/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0599 - accuracy: 0.9785 - val_loss: 0.5092 - val_accuracy: 0.8644
#
# Epoch 00023: val_accuracy did not improve from 0.89778
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 24/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0258 - accuracy: 0.9919 - val_loss: 0.5286 - val_accuracy: 0.8778
#
# Epoch 00024: val_accuracy did not improve from 0.89778
# Epoch 25/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0133 - accuracy: 0.9965 - val_loss: 0.5315 - val_accuracy: 0.8800
#
# Epoch 00025: val_accuracy did not improve from 0.89778
# Epoch 26/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0122 - accuracy: 0.9956 - val_loss: 0.5514 - val_accuracy: 0.8778
#
# Epoch 00026: val_accuracy did not improve from 0.89778
# Epoch 27/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0129 - accuracy: 0.9970 - val_loss: 0.5888 - val_accuracy: 0.8667
#
# Epoch 00027: val_accuracy did not improve from 0.89778
# Epoch 28/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.6221 - val_accuracy: 0.8956
#
# Epoch 00028: val_accuracy did not improve from 0.89778
# Epoch 29/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0102 - accuracy: 0.9968 - val_loss: 0.6333 - val_accuracy: 0.8933
#
# Epoch 00029: val_accuracy did not improve from 0.89778
# Epoch 30/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0102 - accuracy: 0.9968 - val_loss: 0.6249 - val_accuracy: 0.8422
#
# Epoch 00030: val_accuracy did not improve from 0.89778
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 5
# Genre split [['Disco', 'Metal', 'Pop'], ['Country', 'Rock']]
# Building model...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 3s 19ms/step - loss: 0.7489 - accuracy: 0.6156 - val_loss: 0.6202 - val_accuracy: 0.6533
#
# Epoch 00001: val_accuracy improved from -inf to 0.65333, saving model to ./models/tree_9/model_root_f1/folder5\model.h5
# Epoch 2/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.5275 - accuracy: 0.7570 - val_loss: 0.5264 - val_accuracy: 0.7356
#
# Epoch 00002: val_accuracy improved from 0.65333 to 0.73556, saving model to ./models/tree_9/model_root_f1/folder5\model.h5
# Epoch 3/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.4783 - accuracy: 0.7758 - val_loss: 0.3988 - val_accuracy: 0.8200
#
# Epoch 00003: val_accuracy improved from 0.73556 to 0.82000, saving model to ./models/tree_9/model_root_f1/folder5\model.h5
# Epoch 4/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.4011 - accuracy: 0.8202 - val_loss: 0.4128 - val_accuracy: 0.8333
#
# Epoch 00004: val_accuracy improved from 0.82000 to 0.83333, saving model to ./models/tree_9/model_root_f1/folder5\model.h5
# Epoch 5/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.3510 - accuracy: 0.8393 - val_loss: 0.3087 - val_accuracy: 0.8733
#
# Epoch 00005: val_accuracy improved from 0.83333 to 0.87333, saving model to ./models/tree_9/model_root_f1/folder5\model.h5
# Epoch 6/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.3130 - accuracy: 0.8726 - val_loss: 0.2742 - val_accuracy: 0.8978
#
# Epoch 00006: val_accuracy improved from 0.87333 to 0.89778, saving model to ./models/tree_9/model_root_f1/folder5\model.h5
# Epoch 7/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.2805 - accuracy: 0.8785 - val_loss: 0.2966 - val_accuracy: 0.8844
#
# Epoch 00007: val_accuracy did not improve from 0.89778
# Epoch 8/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.2615 - accuracy: 0.8852 - val_loss: 0.2816 - val_accuracy: 0.8733
#
# Epoch 00008: val_accuracy did not improve from 0.89778
# Epoch 9/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.2226 - accuracy: 0.9116 - val_loss: 0.2751 - val_accuracy: 0.8933
#
# Epoch 00009: val_accuracy did not improve from 0.89778
# Epoch 10/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1793 - accuracy: 0.9299 - val_loss: 0.2511 - val_accuracy: 0.8956
#
# Epoch 00010: val_accuracy did not improve from 0.89778
# Epoch 11/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1432 - accuracy: 0.9444 - val_loss: 0.2323 - val_accuracy: 0.8956
#
# Epoch 00011: val_accuracy did not improve from 0.89778
# Epoch 12/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1073 - accuracy: 0.9598 - val_loss: 0.2228 - val_accuracy: 0.9133
#
# Epoch 00012: val_accuracy improved from 0.89778 to 0.91333, saving model to ./models/tree_9/model_root_f1/folder5\model.h5
# Epoch 13/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0717 - accuracy: 0.9758 - val_loss: 0.2485 - val_accuracy: 0.9067
#
# Epoch 00013: val_accuracy did not improve from 0.91333
# Epoch 14/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0580 - accuracy: 0.9800 - val_loss: 0.2725 - val_accuracy: 0.9222
#
# Epoch 00014: val_accuracy improved from 0.91333 to 0.92222, saving model to ./models/tree_9/model_root_f1/folder5\model.h5
# Epoch 15/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0464 - accuracy: 0.9862 - val_loss: 0.2426 - val_accuracy: 0.9178
#
# Epoch 00015: val_accuracy did not improve from 0.92222
# Epoch 16/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0314 - accuracy: 0.9919 - val_loss: 0.2512 - val_accuracy: 0.9111
#
# Epoch 00016: val_accuracy did not improve from 0.92222
# Epoch 17/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0312 - accuracy: 0.9919 - val_loss: 0.2681 - val_accuracy: 0.9267
#
# Epoch 00017: val_accuracy improved from 0.92222 to 0.92667, saving model to ./models/tree_9/model_root_f1/folder5\model.h5
# Epoch 18/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0232 - accuracy: 0.9936 - val_loss: 0.2346 - val_accuracy: 0.9289
#
# Epoch 00018: val_accuracy improved from 0.92667 to 0.92889, saving model to ./models/tree_9/model_root_f1/folder5\model.h5
# Epoch 19/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0739 - accuracy: 0.9731 - val_loss: 0.3153 - val_accuracy: 0.9178
#
# Epoch 00019: val_accuracy did not improve from 0.92889
# Epoch 20/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0392 - accuracy: 0.9869 - val_loss: 0.2902 - val_accuracy: 0.9089
#
# Epoch 00020: val_accuracy did not improve from 0.92889
# Epoch 21/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0287 - accuracy: 0.9941 - val_loss: 0.3003 - val_accuracy: 0.9200
#
# Epoch 00021: val_accuracy did not improve from 0.92889
# Epoch 22/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0271 - accuracy: 0.9926 - val_loss: 0.3593 - val_accuracy: 0.9289
#
# Epoch 00022: val_accuracy did not improve from 0.92889
# Epoch 23/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0208 - accuracy: 0.9938 - val_loss: 0.3524 - val_accuracy: 0.9200
#
# Epoch 00023: val_accuracy did not improve from 0.92889
# Epoch 24/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0222 - accuracy: 0.9943 - val_loss: 0.3536 - val_accuracy: 0.9267
#
# Epoch 00024: val_accuracy did not improve from 0.92889
# Epoch 25/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0414 - accuracy: 0.9872 - val_loss: 0.4932 - val_accuracy: 0.8867
#
# Epoch 00025: val_accuracy did not improve from 0.92889
# Epoch 26/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0289 - accuracy: 0.9926 - val_loss: 0.3474 - val_accuracy: 0.9178
#
# Epoch 00026: val_accuracy did not improve from 0.92889
# Epoch 27/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0162 - accuracy: 0.9956 - val_loss: 0.3313 - val_accuracy: 0.9133
#
# Epoch 00027: val_accuracy did not improve from 0.92889
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 28/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0101 - accuracy: 0.9968 - val_loss: 0.2971 - val_accuracy: 0.9178
#
# Epoch 00028: val_accuracy did not improve from 0.92889
# Epoch 29/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0123 - accuracy: 0.9956 - val_loss: 0.2631 - val_accuracy: 0.9178
#
# Epoch 00029: val_accuracy did not improve from 0.92889
# Epoch 30/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.3964 - val_accuracy: 0.9178
#
# Epoch 00030: val_accuracy did not improve from 0.92889
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 6
# Genre split [['Country', 'Metal', 'Pop'], ['Disco', 'Rock']]
# Building model...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 3s 19ms/step - loss: 0.7265 - accuracy: 0.5864 - val_loss: 0.6810 - val_accuracy: 0.6022
#
# Epoch 00001: val_accuracy improved from -inf to 0.60222, saving model to ./models/tree_9/model_root_f1/folder6\model.h5
# Epoch 2/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6770 - accuracy: 0.5995 - val_loss: 0.6729 - val_accuracy: 0.6022
#
# Epoch 00002: val_accuracy did not improve from 0.60222
# Epoch 3/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6778 - accuracy: 0.5975 - val_loss: 0.6712 - val_accuracy: 0.6022
#
# Epoch 00003: val_accuracy did not improve from 0.60222
# Epoch 4/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6675 - accuracy: 0.6027 - val_loss: 0.6631 - val_accuracy: 0.6000
#
# Epoch 00004: val_accuracy did not improve from 0.60222
# Epoch 5/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6533 - accuracy: 0.6170 - val_loss: 0.6585 - val_accuracy: 0.6044
#
# Epoch 00005: val_accuracy improved from 0.60222 to 0.60444, saving model to ./models/tree_9/model_root_f1/folder6\model.h5
# Epoch 6/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6378 - accuracy: 0.6402 - val_loss: 0.6024 - val_accuracy: 0.6644
#
# Epoch 00006: val_accuracy improved from 0.60444 to 0.66444, saving model to ./models/tree_9/model_root_f1/folder6\model.h5
# Epoch 7/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6054 - accuracy: 0.6679 - val_loss: 0.6021 - val_accuracy: 0.6467
#
# Epoch 00007: val_accuracy did not improve from 0.66444
# Epoch 8/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.5624 - accuracy: 0.7109 - val_loss: 0.5482 - val_accuracy: 0.7422
#
# Epoch 00008: val_accuracy improved from 0.66444 to 0.74222, saving model to ./models/tree_9/model_root_f1/folder6\model.h5
# Epoch 9/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.4872 - accuracy: 0.7568 - val_loss: 0.4784 - val_accuracy: 0.7711
#
# Epoch 00009: val_accuracy improved from 0.74222 to 0.77111, saving model to ./models/tree_9/model_root_f1/folder6\model.h5
# Epoch 10/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.4316 - accuracy: 0.7948 - val_loss: 0.4494 - val_accuracy: 0.7800
#
# Epoch 00010: val_accuracy improved from 0.77111 to 0.78000, saving model to ./models/tree_9/model_root_f1/folder6\model.h5
# Epoch 11/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.3837 - accuracy: 0.8262 - val_loss: 0.4342 - val_accuracy: 0.7889
#
# Epoch 00011: val_accuracy improved from 0.78000 to 0.78889, saving model to ./models/tree_9/model_root_f1/folder6\model.h5
# Epoch 12/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.3393 - accuracy: 0.8486 - val_loss: 0.4136 - val_accuracy: 0.8222
#
# Epoch 00012: val_accuracy improved from 0.78889 to 0.82222, saving model to ./models/tree_9/model_root_f1/folder6\model.h5
# Epoch 13/30
# ...
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 3s 19ms/step - loss: 0.7196 - accuracy: 0.5832 - val_loss: 0.6421 - val_accuracy: 0.6400
#
# Epoch 00001: val_accuracy improved from -inf to 0.64000, saving model to ./models/tree_9/model_root_f1/folder9\model.h5
# Epoch 2/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.5214 - accuracy: 0.7360 - val_loss: 0.5085 - val_accuracy: 0.7622
#
# Epoch 00002: val_accuracy improved from 0.64000 to 0.76222, saving model to ./models/tree_9/model_root_f1/folder9\model.h5
# Epoch 3/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.4029 - accuracy: 0.8128 - val_loss: 0.4080 - val_accuracy: 0.8267
#
# Epoch 00003: val_accuracy improved from 0.76222 to 0.82667, saving model to ./models/tree_9/model_root_f1/folder9\model.h5
# Epoch 4/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.2937 - accuracy: 0.8728 - val_loss: 0.2698 - val_accuracy: 0.9000
#
# Epoch 00004: val_accuracy improved from 0.82667 to 0.90000, saving model to ./models/tree_9/model_root_f1/folder9\model.h5
# Epoch 5/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.2222 - accuracy: 0.9081 - val_loss: 0.3310 - val_accuracy: 0.8756
#
# Epoch 00005: val_accuracy did not improve from 0.90000
# Epoch 6/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1995 - accuracy: 0.9202 - val_loss: 0.2144 - val_accuracy: 0.9178
#
# Epoch 00006: val_accuracy improved from 0.90000 to 0.91778, saving model to ./models/tree_9/model_root_f1/folder9\model.h5
# Epoch 7/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1839 - accuracy: 0.9242 - val_loss: 0.3092 - val_accuracy: 0.8756
#
# Epoch 00007: val_accuracy did not improve from 0.91778
# Epoch 8/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1449 - accuracy: 0.9425 - val_loss: 0.1968 - val_accuracy: 0.9267
#
# Epoch 00008: val_accuracy improved from 0.91778 to 0.92667, saving model to ./models/tree_9/model_root_f1/folder9\model.h5
# Epoch 9/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1496 - accuracy: 0.9388 - val_loss: 0.2160 - val_accuracy: 0.9289
#
# Epoch 00009: val_accuracy improved from 0.92667 to 0.92889, saving model to ./models/tree_9/model_root_f1/folder9\model.h5
# Epoch 10/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1096 - accuracy: 0.9585 - val_loss: 0.1775 - val_accuracy: 0.9400
#
# Epoch 00010: val_accuracy improved from 0.92889 to 0.94000, saving model to ./models/tree_9/model_root_f1/folder9\model.h5
# Epoch 11/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0991 - accuracy: 0.9615 - val_loss: 0.2033 - val_accuracy: 0.9311
#
# Epoch 00011: val_accuracy did not improve from 0.94000
# Epoch 12/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0870 - accuracy: 0.9664 - val_loss: 0.1960 - val_accuracy: 0.9311
#
# Epoch 00012: val_accuracy did not improve from 0.94000
# Epoch 13/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0695 - accuracy: 0.9746 - val_loss: 0.2168 - val_accuracy: 0.9200
#
# Epoch 00013: val_accuracy did not improve from 0.94000
# Epoch 14/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0627 - accuracy: 0.9746 - val_loss: 0.2052 - val_accuracy: 0.9422
#
# Epoch 00014: val_accuracy improved from 0.94000 to 0.94222, saving model to ./models/tree_9/model_root_f1/folder9\model.h5
# Epoch 15/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0535 - accuracy: 0.9815 - val_loss: 0.2448 - val_accuracy: 0.9222
#
# Epoch 00015: val_accuracy did not improve from 0.94222
# Epoch 16/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0524 - accuracy: 0.9810 - val_loss: 0.2758 - val_accuracy: 0.9200
#
# Epoch 00016: val_accuracy did not improve from 0.94222
# Epoch 17/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0385 - accuracy: 0.9857 - val_loss: 0.3342 - val_accuracy: 0.9133
#
# Epoch 00017: val_accuracy did not improve from 0.94222
# Epoch 18/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0423 - accuracy: 0.9849 - val_loss: 0.2189 - val_accuracy: 0.9444
#
# Epoch 00018: val_accuracy improved from 0.94222 to 0.94444, saving model to ./models/tree_9/model_root_f1/folder9\model.h5
# Epoch 19/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 0.2692 - val_accuracy: 0.9178
#
# Epoch 00019: val_accuracy did not improve from 0.94444
# Epoch 20/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0081 - accuracy: 0.9983 - val_loss: 0.2379 - val_accuracy: 0.9467
#
# Epoch 00020: val_accuracy improved from 0.94444 to 0.94667, saving model to ./models/tree_9/model_root_f1/folder9\model.h5
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.2487 - val_accuracy: 0.9467
#
# Epoch 00021: val_accuracy did not improve from 0.94667
# Epoch 22/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2637 - val_accuracy: 0.9467
#
# Epoch 00022: val_accuracy did not improve from 0.94667
# Epoch 23/30
# 127/127 [==============================] - 2s 18ms/step - loss: 7.8828e-04 - accuracy: 1.0000 - val_loss: 0.2781 - val_accuracy: 0.9467
#
# Epoch 00023: val_accuracy did not improve from 0.94667
# Epoch 24/30
# 127/127 [==============================] - 2s 18ms/step - loss: 6.3297e-04 - accuracy: 1.0000 - val_loss: 0.2858 - val_accuracy: 0.9467
#
# Epoch 00024: val_accuracy did not improve from 0.94667
# Epoch 25/30
# 127/127 [==============================] - 2s 18ms/step - loss: 5.3854e-04 - accuracy: 1.0000 - val_loss: 0.2944 - val_accuracy: 0.9400
#
# Epoch 00025: val_accuracy did not improve from 0.94667
# Epoch 26/30
# 127/127 [==============================] - 2s 18ms/step - loss: 4.5558e-04 - accuracy: 1.0000 - val_loss: 0.3016 - val_accuracy: 0.9444
#
# Epoch 00026: val_accuracy did not improve from 0.94667
# Epoch 27/30
# 127/127 [==============================] - 2s 18ms/step - loss: 3.9314e-04 - accuracy: 1.0000 - val_loss: 0.3066 - val_accuracy: 0.9400
#
# Epoch 00027: val_accuracy did not improve from 0.94667
# Epoch 28/30
# 127/127 [==============================] - 2s 18ms/step - loss: 3.3286e-04 - accuracy: 1.0000 - val_loss: 0.3152 - val_accuracy: 0.9378
#
# Epoch 00028: val_accuracy did not improve from 0.94667
# Epoch 29/30
# 127/127 [==============================] - 2s 18ms/step - loss: 2.9416e-04 - accuracy: 1.0000 - val_loss: 0.3189 - val_accuracy: 0.9400
#
# Epoch 00029: val_accuracy did not improve from 0.94667
# Epoch 30/30
# 127/127 [==============================] - 2s 18ms/step - loss: 2.6074e-04 - accuracy: 1.0000 - val_loss: 0.3263 - val_accuracy: 0.9400
#
# Epoch 00030: val_accuracy did not improve from 0.94667
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 10
# Genre split [['Country', 'Pop'], ['Disco', 'Metal', 'Rock']]
# Building model...
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 3s 19ms/step - loss: 0.6608 - accuracy: 0.6558 - val_loss: 0.6745 - val_accuracy: 0.6067
#
# Epoch 00001: val_accuracy improved from -inf to 0.60667, saving model to ./models/tree_9/model_root_f1/folder10\model.h5
# Epoch 2/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6747 - accuracy: 0.5993 - val_loss: 0.6707 - val_accuracy: 0.6067
#
# Epoch 00002: val_accuracy did not improve from 0.60667
# Epoch 3/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6739 - accuracy: 0.5993 - val_loss: 0.6716 - val_accuracy: 0.6067
#
# Epoch 00003: val_accuracy did not improve from 0.60667
# Epoch 4/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6749 - accuracy: 0.5993 - val_loss: 0.6726 - val_accuracy: 0.6067
#
# Epoch 00004: val_accuracy did not improve from 0.60667
# Epoch 5/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6749 - accuracy: 0.5993 - val_loss: 0.6740 - val_accuracy: 0.6067
#
# Epoch 00005: val_accuracy did not improve from 0.60667
# Epoch 6/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6739 - accuracy: 0.5993 - val_loss: 0.6706 - val_accuracy: 0.6067
#
# Epoch 00006: val_accuracy did not improve from 0.60667
# Epoch 7/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6757 - accuracy: 0.5993 - val_loss: 0.6703 - val_accuracy: 0.6067
#
# Epoch 00007: val_accuracy did not improve from 0.60667
# Epoch 8/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6738 - accuracy: 0.5993 - val_loss: 0.6725 - val_accuracy: 0.6067
#
# Epoch 00008: val_accuracy did not improve from 0.60667
# Epoch 9/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6736 - accuracy: 0.5993 - val_loss: 0.6703 - val_accuracy: 0.6067
#
# Epoch 00009: val_accuracy did not improve from 0.60667
# Epoch 10/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6738 - accuracy: 0.5993 - val_loss: 0.6704 - val_accuracy: 0.6067
#
# Epoch 00010: val_accuracy did not improve from 0.60667
# Epoch 11/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6738 - accuracy: 0.5993 - val_loss: 0.6702 - val_accuracy: 0.6067
#
# Epoch 00011: val_accuracy did not improve from 0.60667
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 12/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6739 - accuracy: 0.5993 - val_loss: 0.6707 - val_accuracy: 0.6067
#
# Epoch 00012: val_accuracy did not improve from 0.60667
# Epoch 13/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6736 - accuracy: 0.5993 - val_loss: 0.6706 - val_accuracy: 0.6067
#
# Epoch 00013: val_accuracy did not improve from 0.60667
# Epoch 14/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6737 - accuracy: 0.5993 - val_loss: 0.6703 - val_accuracy: 0.6067
#
# Epoch 00014: val_accuracy did not improve from 0.60667
# Epoch 15/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6738 - accuracy: 0.5993 - val_loss: 0.6702 - val_accuracy: 0.6067
#
# Epoch 00015: val_accuracy did not improve from 0.60667
# Epoch 16/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6741 - accuracy: 0.5993 - val_loss: 0.6702 - val_accuracy: 0.6067
#
# Epoch 00016: val_accuracy did not improve from 0.60667
# Epoch 17/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6739 - accuracy: 0.5993 - val_loss: 0.6704 - val_accuracy: 0.6067
#
# Epoch 00017: val_accuracy did not improve from 0.60667
# Epoch 18/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6737 - accuracy: 0.5993 - val_loss: 0.6710 - val_accuracy: 0.6067
#
# Epoch 00018: val_accuracy did not improve from 0.60667
# Epoch 19/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6738 - accuracy: 0.5993 - val_loss: 0.6719 - val_accuracy: 0.6067
#
# Epoch 00019: val_accuracy did not improve from 0.60667
# Epoch 20/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6737 - accuracy: 0.5993 - val_loss: 0.6703 - val_accuracy: 0.6067
#
# Epoch 00020: val_accuracy did not improve from 0.60667
# Epoch 21/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6736 - accuracy: 0.5993 - val_loss: 0.6703 - val_accuracy: 0.6067
#
# Epoch 00021: val_accuracy did not improve from 0.60667
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 22/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6735 - accuracy: 0.5993 - val_loss: 0.6704 - val_accuracy: 0.6067
#
# Epoch 00022: val_accuracy did not improve from 0.60667
# Epoch 23/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6735 - accuracy: 0.5993 - val_loss: 0.6703 - val_accuracy: 0.6067
#
# Epoch 00023: val_accuracy did not improve from 0.60667
# Epoch 24/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6736 - accuracy: 0.5993 - val_loss: 0.6703 - val_accuracy: 0.6067
#
# Epoch 00024: val_accuracy did not improve from 0.60667
# Epoch 25/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6736 - accuracy: 0.5993 - val_loss: 0.6702 - val_accuracy: 0.6067
#
# Epoch 00025: val_accuracy did not improve from 0.60667
# Epoch 26/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6735 - accuracy: 0.5993 - val_loss: 0.6703 - val_accuracy: 0.6067
#
# Epoch 00026: val_accuracy did not improve from 0.60667
# Epoch 27/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6736 - accuracy: 0.5993 - val_loss: 0.6706 - val_accuracy: 0.6067
#
# Epoch 00027: val_accuracy did not improve from 0.60667
# Epoch 28/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6735 - accuracy: 0.5993 - val_loss: 0.6704 - val_accuracy: 0.6067
#
# Epoch 00028: val_accuracy did not improve from 0.60667
# Epoch 29/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6734 - accuracy: 0.5993 - val_loss: 0.6705 - val_accuracy: 0.6067
#
# Epoch 00029: val_accuracy did not improve from 0.60667
# Epoch 30/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6736 - accuracy: 0.5993 - val_loss: 0.6706 - val_accuracy: 0.6067
#
# Epoch 00030: val_accuracy did not improve from 0.60667
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
