# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Blues':0, 'Classical':1, 'Hip-Hop':4, 'Jazz':5, 'Reggae':8}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Blues', 1: 'Classical', 4: 'Hip-Hop', 5: 'Jazz', 8: 'Reggae'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((3990, 128, 128), (3990, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((500, 128, 128), (500, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Classical

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_9/model_root_f2/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_9/model_root_f2/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def create_split(elem):
    splits = list(set_partitions(elem, 2))
    _splits = []
    for i in range(len(splits)):
        try:
            if len(splits[i][0]) != 1 and len(splits[i][1]) != 1:
                _splits.append(splits[i])
        except:
            continue
    
    return _splits, len(_splits)

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

genre_splits, num_splits = create_split(list(dict_genres.values()))
print("Num splits {}".format(num_splits))

if num_splits > 8:
    n_splits = num_splits
else:
    n_splits = 8

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Num splits 10
# Folder num 1
# Genre split [['Blues', 'Classical'], ['Hip-Hop', 'Jazz', 'Reggae']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 15s 25ms/step - loss: 0.7147 - accuracy: 0.6404 - val_loss: 0.5099 - val_accuracy: 0.7483
#
# Epoch 00001: val_accuracy improved from -inf to 0.74833, saving model to ./models/tree_9/model_root_f2/folder1\model.h5
# Epoch 2/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.5171 - accuracy: 0.7372 - val_loss: 0.5852 - val_accuracy: 0.7127
#
# Epoch 00002: val_accuracy did not improve from 0.74833
# Epoch 3/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.3902 - accuracy: 0.8243 - val_loss: 0.3503 - val_accuracy: 0.8753
#
# Epoch 00003: val_accuracy improved from 0.74833 to 0.87528, saving model to ./models/tree_9/model_root_f2/folder1\model.h5
# Epoch 4/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.3112 - accuracy: 0.8577 - val_loss: 0.2546 - val_accuracy: 0.8864
#
# Epoch 00004: val_accuracy improved from 0.87528 to 0.88641, saving model to ./models/tree_9/model_root_f2/folder1\model.h5
# Epoch 5/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.2344 - accuracy: 0.9008 - val_loss: 0.1983 - val_accuracy: 0.9198
#
# Epoch 00005: val_accuracy improved from 0.88641 to 0.91982, saving model to ./models/tree_9/model_root_f2/folder1\model.h5
# Epoch 6/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.1800 - accuracy: 0.9258 - val_loss: 0.1874 - val_accuracy: 0.9287
#
# Epoch 00006: val_accuracy improved from 0.91982 to 0.92873, saving model to ./models/tree_9/model_root_f2/folder1\model.h5
# Epoch 7/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.1399 - accuracy: 0.9421 - val_loss: 0.1948 - val_accuracy: 0.9198
#
# Epoch 00007: val_accuracy did not improve from 0.92873
# Epoch 8/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.1160 - accuracy: 0.9525 - val_loss: 0.1722 - val_accuracy: 0.9488
#
# Epoch 00008: val_accuracy improved from 0.92873 to 0.94878, saving model to ./models/tree_9/model_root_f2/folder1\model.h5
# Epoch 9/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0776 - accuracy: 0.9691 - val_loss: 0.2548 - val_accuracy: 0.9109
#
# Epoch 00009: val_accuracy did not improve from 0.94878
# Epoch 10/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0734 - accuracy: 0.9730 - val_loss: 0.2226 - val_accuracy: 0.9198
#
# Epoch 00010: val_accuracy did not improve from 0.94878
# Epoch 11/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0424 - accuracy: 0.9852 - val_loss: 0.2679 - val_accuracy: 0.9220
#
# Epoch 00011: val_accuracy did not improve from 0.94878
# Epoch 12/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0175 - accuracy: 0.9953 - val_loss: 0.1977 - val_accuracy: 0.9488
#
# Epoch 00012: val_accuracy did not improve from 0.94878
# Epoch 13/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0095 - accuracy: 0.9978 - val_loss: 0.2499 - val_accuracy: 0.9421
#
# Epoch 00013: val_accuracy did not improve from 0.94878
# Epoch 14/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0075 - accuracy: 0.9985 - val_loss: 0.2435 - val_accuracy: 0.9510
#
# Epoch 00014: val_accuracy improved from 0.94878 to 0.95100, saving model to ./models/tree_9/model_root_f2/folder1\model.h5
# Epoch 15/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.2756 - val_accuracy: 0.9465
#
# Epoch 00015: val_accuracy did not improve from 0.95100
# Epoch 16/30
# 127/127 [==============================] - 2s 17ms/step - loss: 5.5255e-04 - accuracy: 1.0000 - val_loss: 0.2829 - val_accuracy: 0.9488
#
# Epoch 00016: val_accuracy did not improve from 0.95100
# Epoch 17/30
# 127/127 [==============================] - 2s 18ms/step - loss: 2.8234e-04 - accuracy: 1.0000 - val_loss: 0.2872 - val_accuracy: 0.9488
#
# Epoch 00017: val_accuracy did not improve from 0.95100
# Epoch 18/30
# 127/127 [==============================] - 2s 17ms/step - loss: 2.3817e-04 - accuracy: 1.0000 - val_loss: 0.2892 - val_accuracy: 0.9510
#
# Epoch 00018: val_accuracy did not improve from 0.95100
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 19/30
# 127/127 [==============================] - 2s 18ms/step - loss: 1.7248e-04 - accuracy: 1.0000 - val_loss: 0.2873 - val_accuracy: 0.9510
#
# Epoch 00019: val_accuracy did not improve from 0.95100
# Epoch 20/30
# 127/127 [==============================] - 2s 18ms/step - loss: 1.5674e-04 - accuracy: 1.0000 - val_loss: 0.2905 - val_accuracy: 0.9510
#
# Epoch 00020: val_accuracy did not improve from 0.95100
# Epoch 21/30
# 127/127 [==============================] - 2s 17ms/step - loss: 1.4364e-04 - accuracy: 1.0000 - val_loss: 0.2919 - val_accuracy: 0.9510
#
# Epoch 00021: val_accuracy did not improve from 0.95100
# Epoch 22/30
# 127/127 [==============================] - 2s 17ms/step - loss: 1.3198e-04 - accuracy: 1.0000 - val_loss: 0.2937 - val_accuracy: 0.9510
#
# Epoch 00022: val_accuracy did not improve from 0.95100
# Epoch 23/30
# 127/127 [==============================] - 2s 18ms/step - loss: 1.2056e-04 - accuracy: 1.0000 - val_loss: 0.2983 - val_accuracy: 0.9510
#
# Epoch 00023: val_accuracy did not improve from 0.95100
# Epoch 24/30
# 127/127 [==============================] - 2s 17ms/step - loss: 1.1244e-04 - accuracy: 1.0000 - val_loss: 0.2974 - val_accuracy: 0.9510
#
# Epoch 00024: val_accuracy did not improve from 0.95100
# Epoch 25/30
# 127/127 [==============================] - 2s 18ms/step - loss: 1.0331e-04 - accuracy: 1.0000 - val_loss: 0.2997 - val_accuracy: 0.9510
#
# Epoch 00025: val_accuracy did not improve from 0.95100
# Epoch 26/30
# 127/127 [==============================] - 2s 18ms/step - loss: 9.6553e-05 - accuracy: 1.0000 - val_loss: 0.3021 - val_accuracy: 0.9510
#
# Epoch 00026: val_accuracy did not improve from 0.95100
# Epoch 27/30
# 127/127 [==============================] - 2s 18ms/step - loss: 8.7756e-05 - accuracy: 1.0000 - val_loss: 0.3051 - val_accuracy: 0.9510
#
# Epoch 00027: val_accuracy did not improve from 0.95100
# Epoch 28/30
# 127/127 [==============================] - 2s 18ms/step - loss: 8.1024e-05 - accuracy: 1.0000 - val_loss: 0.3079 - val_accuracy: 0.9510
#
# Epoch 00028: val_accuracy did not improve from 0.95100
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 29/30
# 127/127 [==============================] - 2s 17ms/step - loss: 7.5555e-05 - accuracy: 1.0000 - val_loss: 0.3066 - val_accuracy: 0.9510
#
# Epoch 00029: val_accuracy did not improve from 0.95100
# Epoch 30/30
# 127/127 [==============================] - 2s 18ms/step - loss: 7.2582e-05 - accuracy: 1.0000 - val_loss: 0.3076 - val_accuracy: 0.9510
#
# Epoch 00030: val_accuracy did not improve from 0.95100
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Blues', 'Classical', 'Hip-Hop'], ['Jazz', 'Reggae']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 3s 19ms/step - loss: 0.7483 - accuracy: 0.5917 - val_loss: 0.6730 - val_accuracy: 0.6036
#
# Epoch 00001: val_accuracy improved from -inf to 0.60356, saving model to ./models/tree_9/model_root_f2/folder2\model.h5
# Epoch 2/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6800 - accuracy: 0.6011 - val_loss: 0.6718 - val_accuracy: 0.6036
#
# Epoch 00002: val_accuracy did not improve from 0.60356
# Epoch 3/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6760 - accuracy: 0.5966 - val_loss: 0.6716 - val_accuracy: 0.6036
#
# Epoch 00003: val_accuracy did not improve from 0.60356
# Epoch 4/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.6678 - accuracy: 0.5979 - val_loss: 0.6610 - val_accuracy: 0.5991
#
# Epoch 00004: val_accuracy did not improve from 0.60356
# Epoch 5/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6394 - accuracy: 0.6236 - val_loss: 0.6576 - val_accuracy: 0.6036
#
# Epoch 00005: val_accuracy did not improve from 0.60356
# Epoch 6/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6130 - accuracy: 0.6503 - val_loss: 0.6033 - val_accuracy: 0.6437
#
# Epoch 00006: val_accuracy improved from 0.60356 to 0.64365, saving model to ./models/tree_9/model_root_f2/folder2\model.h5
# Epoch 7/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.5548 - accuracy: 0.7082 - val_loss: 0.4967 - val_accuracy: 0.7350
#
# Epoch 00007: val_accuracy improved from 0.64365 to 0.73497, saving model to ./models/tree_9/model_root_f2/folder2\model.h5
# Epoch 8/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.5100 - accuracy: 0.7610 - val_loss: 0.4534 - val_accuracy: 0.7795
#
# Epoch 00008: val_accuracy improved from 0.73497 to 0.77951, saving model to ./models/tree_9/model_root_f2/folder2\model.h5
# Epoch 9/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.4206 - accuracy: 0.8077 - val_loss: 0.4365 - val_accuracy: 0.8085
#
# Epoch 00009: val_accuracy improved from 0.77951 to 0.80846, saving model to ./models/tree_9/model_root_f2/folder2\model.h5
# Epoch 10/30
# 127/127 [==============================] - 5s 39ms/step - loss: 0.3576 - accuracy: 0.8446 - val_loss: 0.3716 - val_accuracy: 0.8374
#
# Epoch 00010: val_accuracy improved from 0.80846 to 0.83742, saving model to ./models/tree_9/model_root_f2/folder2\model.h5
# Epoch 11/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.2847 - accuracy: 0.8859 - val_loss: 0.3375 - val_accuracy: 0.8486
#
# Epoch 00011: val_accuracy improved from 0.83742 to 0.84855, saving model to ./models/tree_9/model_root_f2/folder2\model.h5
# Epoch 12/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.2112 - accuracy: 0.9114 - val_loss: 0.2719 - val_accuracy: 0.8775
#
# Epoch 00012: val_accuracy improved from 0.84855 to 0.87751, saving model to ./models/tree_9/model_root_f2/folder2\model.h5
# Epoch 13/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1244 - accuracy: 0.9560 - val_loss: 0.2568 - val_accuracy: 0.8909
#
# Epoch 00013: val_accuracy improved from 0.87751 to 0.89087, saving model to ./models/tree_9/model_root_f2/folder2\model.h5
# Epoch 14/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0811 - accuracy: 0.9696 - val_loss: 0.3395 - val_accuracy: 0.8664
#
# Epoch 00014: val_accuracy did not improve from 0.89087
# Epoch 15/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0823 - accuracy: 0.9691 - val_loss: 0.3148 - val_accuracy: 0.8797
#
# Epoch 00015: val_accuracy did not improve from 0.89087
# Epoch 16/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0634 - accuracy: 0.9767 - val_loss: 0.3186 - val_accuracy: 0.8864
#
# Epoch 00016: val_accuracy did not improve from 0.89087
# Epoch 17/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0187 - accuracy: 0.9963 - val_loss: 0.3236 - val_accuracy: 0.9042
#
# Epoch 00017: val_accuracy improved from 0.89087 to 0.90423, saving model to ./models/tree_9/model_root_f2/folder2\model.h5
# Epoch 18/30
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0143 - accuracy: 0.9970 - val_loss: 0.3150 - val_accuracy: 0.9087
#
# Epoch 00018: val_accuracy improved from 0.90423 to 0.90869, saving model to ./models/tree_9/model_root_f2/folder2\model.h5
# Epoch 19/30
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0031 - accuracy: 0.9998 - val_loss: 0.3445 - val_accuracy: 0.9176
#
# Epoch 00019: val_accuracy improved from 0.90869 to 0.91759, saving model to ./models/tree_9/model_root_f2/folder2\model.h5
# Epoch 20/30
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3445 - val_accuracy: 0.8998
#
# Epoch 00020: val_accuracy did not improve from 0.91759
# Epoch 21/30
# 127/127 [==============================] - 3s 22ms/step - loss: 6.9983e-04 - accuracy: 1.0000 - val_loss: 0.3584 - val_accuracy: 0.9154
#
# Epoch 00021: val_accuracy did not improve from 0.91759
# Epoch 22/30
# 127/127 [==============================] - 3s 21ms/step - loss: 4.7213e-04 - accuracy: 1.0000 - val_loss: 0.3701 - val_accuracy: 0.9065
#
# Epoch 00022: val_accuracy did not improve from 0.91759
# Epoch 23/30
# 127/127 [==============================] - 3s 22ms/step - loss: 3.7331e-04 - accuracy: 1.0000 - val_loss: 0.3805 - val_accuracy: 0.9087
#
# Epoch 00023: val_accuracy did not improve from 0.91759
# Epoch 24/30
# 127/127 [==============================] - 2s 19ms/step - loss: 2.9150e-04 - accuracy: 1.0000 - val_loss: 0.3911 - val_accuracy: 0.9087
#
# Epoch 00024: val_accuracy did not improve from 0.91759
# Epoch 25/30
# 127/127 [==============================] - 2s 19ms/step - loss: 2.4341e-04 - accuracy: 1.0000 - val_loss: 0.3954 - val_accuracy: 0.9087
#
# Epoch 00025: val_accuracy did not improve from 0.91759
# Epoch 26/30
# 127/127 [==============================] - 2s 18ms/step - loss: 1.9978e-04 - accuracy: 1.0000 - val_loss: 0.4031 - val_accuracy: 0.9042
#
# Epoch 00026: val_accuracy did not improve from 0.91759
# Epoch 27/30
# 127/127 [==============================] - 2s 19ms/step - loss: 1.6855e-04 - accuracy: 1.0000 - val_loss: 0.4100 - val_accuracy: 0.9065
#
# Epoch 00027: val_accuracy did not improve from 0.91759
# Epoch 28/30
# 127/127 [==============================] - 2s 18ms/step - loss: 1.4331e-04 - accuracy: 1.0000 - val_loss: 0.4116 - val_accuracy: 0.9087
#
# Epoch 00028: val_accuracy did not improve from 0.91759
# Epoch 29/30
# 127/127 [==============================] - 2s 19ms/step - loss: 1.1882e-04 - accuracy: 1.0000 - val_loss: 0.4190 - val_accuracy: 0.9087
#
# Epoch 00029: val_accuracy did not improve from 0.91759
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 30/30
# 127/127 [==============================] - 2s 18ms/step - loss: 9.9428e-05 - accuracy: 1.0000 - val_loss: 0.4249 - val_accuracy: 0.9087
#
# Epoch 00030: val_accuracy did not improve from 0.91759
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Classical', 'Hip-Hop'], ['Blues', 'Jazz', 'Reggae']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 3s 19ms/step - loss: 0.7820 - accuracy: 0.5949 - val_loss: 0.6819 - val_accuracy: 0.5746
#
# Epoch 00001: val_accuracy improved from -inf to 0.57461, saving model to ./models/tree_9/model_root_f2/folder3\model.h5
# Epoch 2/30
# 127/127 [==============================] - ETA: 0s - loss: 0.6751 - accuracy: 0.60 - 2s 17ms/step - loss: 0.6756 - accuracy: 0.5986 - val_loss: 0.6845 - val_accuracy: 0.5746
#
# Epoch 00002: val_accuracy did not improve from 0.57461
# Epoch 3/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6738 - accuracy: 0.6018 - val_loss: 0.6856 - val_accuracy: 0.5746
#
# Epoch 00003: val_accuracy did not improve from 0.57461
# Epoch 4/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6744 - accuracy: 0.6018 - val_loss: 0.6840 - val_accuracy: 0.5746
#
# Epoch 00004: val_accuracy did not improve from 0.57461
# Epoch 5/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6734 - accuracy: 0.6018 - val_loss: 0.6837 - val_accuracy: 0.5746
#
# Epoch 00005: val_accuracy did not improve from 0.57461
# Epoch 6/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6731 - accuracy: 0.6018 - val_loss: 0.6777 - val_accuracy: 0.5746
#
# Epoch 00006: val_accuracy did not improve from 0.57461
# Epoch 7/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6520 - accuracy: 0.6112 - val_loss: 0.8501 - val_accuracy: 0.5746
#
# Epoch 00007: val_accuracy did not improve from 0.57461
# Epoch 8/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.5790 - accuracy: 0.6899 - val_loss: 0.5156 - val_accuracy: 0.7082
#
# Epoch 00008: val_accuracy improved from 0.57461 to 0.70824, saving model to ./models/tree_9/model_root_f2/folder3\model.h5
# Epoch 9/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.4608 - accuracy: 0.7859 - val_loss: 0.4161 - val_accuracy: 0.8129
#
# Epoch 00009: val_accuracy improved from 0.70824 to 0.81292, saving model to ./models/tree_9/model_root_f2/folder3\model.h5
# Epoch 10/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.3656 - accuracy: 0.8419 - val_loss: 0.3903 - val_accuracy: 0.8129
#
# Epoch 00010: val_accuracy did not improve from 0.81292
# Epoch 11/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.3300 - accuracy: 0.8575 - val_loss: 0.2995 - val_accuracy: 0.8753
#
# Epoch 00011: val_accuracy improved from 0.81292 to 0.87528, saving model to ./models/tree_9/model_root_f2/folder3\model.h5
# Epoch 12/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.2609 - accuracy: 0.8933 - val_loss: 0.2825 - val_accuracy: 0.8775
#
# Epoch 00012: val_accuracy improved from 0.87528 to 0.87751, saving model to ./models/tree_9/model_root_f2/folder3\model.h5
# Epoch 13/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.2362 - accuracy: 0.9030 - val_loss: 0.2809 - val_accuracy: 0.8753
#
# Epoch 00013: val_accuracy did not improve from 0.87751
# Epoch 14/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1987 - accuracy: 0.9218 - val_loss: 0.2869 - val_accuracy: 0.8864
#
# Epoch 00014: val_accuracy improved from 0.87751 to 0.88641, saving model to ./models/tree_9/model_root_f2/folder3\model.h5
# Epoch 15/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.1797 - accuracy: 0.9272 - val_loss: 0.2382 - val_accuracy: 0.9065
#
# Epoch 00015: val_accuracy improved from 0.88641 to 0.90646, saving model to ./models/tree_9/model_root_f2/folder3\model.h5
# Epoch 16/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.1648 - accuracy: 0.9381 - val_loss: 0.2240 - val_accuracy: 0.9131
#
# Epoch 00016: val_accuracy improved from 0.90646 to 0.91314, saving model to ./models/tree_9/model_root_f2/folder3\model.h5
# Epoch 17/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1482 - accuracy: 0.9399 - val_loss: 0.2549 - val_accuracy: 0.9109
#
# Epoch 00017: val_accuracy did not improve from 0.91314
# Epoch 18/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.1021 - accuracy: 0.9641 - val_loss: 0.3089 - val_accuracy: 0.8753
#
# Epoch 00018: val_accuracy did not improve from 0.91314
# Epoch 19/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0845 - accuracy: 0.9693 - val_loss: 0.2182 - val_accuracy: 0.9176
#
# Epoch 00019: val_accuracy improved from 0.91314 to 0.91759, saving model to ./models/tree_9/model_root_f2/folder3\model.h5
# Epoch 20/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0959 - accuracy: 0.9611 - val_loss: 0.3744 - val_accuracy: 0.8708
#
# Epoch 00020: val_accuracy did not improve from 0.91759
# Epoch 21/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0673 - accuracy: 0.9760 - val_loss: 0.2625 - val_accuracy: 0.9065
#
# Epoch 00021: val_accuracy did not improve from 0.91759
# Epoch 22/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0417 - accuracy: 0.9886 - val_loss: 0.2375 - val_accuracy: 0.9198
#
# Epoch 00022: val_accuracy improved from 0.91759 to 0.91982, saving model to ./models/tree_9/model_root_f2/folder3\model.h5
# Epoch 23/30
# 127/127 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.98 - 2s 17ms/step - loss: 0.0311 - accuracy: 0.9896 - val_loss: 0.2203 - val_accuracy: 0.9287
#
# Epoch 00023: val_accuracy improved from 0.91982 to 0.92873, saving model to ./models/tree_9/model_root_f2/folder3\model.h5
# Epoch 24/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0345 - accuracy: 0.9891 - val_loss: 0.4731 - val_accuracy: 0.8731
#
# Epoch 00024: val_accuracy did not improve from 0.92873
# Epoch 25/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0380 - accuracy: 0.9866 - val_loss: 0.2685 - val_accuracy: 0.9265
#
# Epoch 00025: val_accuracy did not improve from 0.92873
# Epoch 26/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0562 - accuracy: 0.9785 - val_loss: 0.2945 - val_accuracy: 0.9087
#
# Epoch 00026: val_accuracy did not improve from 0.92873
# Epoch 27/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0207 - accuracy: 0.9951 - val_loss: 0.3110 - val_accuracy: 0.9154
#
# Epoch 00027: val_accuracy did not improve from 0.92873
# Epoch 28/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0349 - accuracy: 0.9889 - val_loss: 0.2786 - val_accuracy: 0.9265
#
# Epoch 00028: val_accuracy did not improve from 0.92873
# Epoch 29/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0248 - accuracy: 0.9916 - val_loss: 0.5550 - val_accuracy: 0.8731
#
# Epoch 00029: val_accuracy did not improve from 0.92873
# Epoch 30/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0308 - accuracy: 0.9891 - val_loss: 0.2474 - val_accuracy: 0.9287
#
# Epoch 00030: val_accuracy did not improve from 0.92873
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Blues', 'Hip-Hop'], ['Classical', 'Jazz', 'Reggae']]
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 3s 19ms/step - loss: 0.7111 - accuracy: 0.6187 - val_loss: 0.5548 - val_accuracy: 0.7283
#
# Epoch 00001: val_accuracy improved from -inf to 0.72829, saving model to ./models/tree_9/model_root_f2/folder4\model.h5
# Epoch 2/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.5379 - accuracy: 0.7231 - val_loss: 0.4020 - val_accuracy: 0.8062
#
# Epoch 00002: val_accuracy improved from 0.72829 to 0.80624, saving model to ./models/tree_9/model_root_f2/folder4\model.h5
# Epoch 3/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.4503 - accuracy: 0.7810 - val_loss: 0.3795 - val_accuracy: 0.8218
#
# Epoch 00003: val_accuracy improved from 0.80624 to 0.82183, saving model to ./models/tree_9/model_root_f2/folder4\model.h5
# Epoch 4/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.3948 - accuracy: 0.8137 - val_loss: 0.3724 - val_accuracy: 0.8307
#
# Epoch 00004: val_accuracy improved from 0.82183 to 0.83073, saving model to ./models/tree_9/model_root_f2/folder4\model.h5
# Epoch 5/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.3450 - accuracy: 0.8426 - val_loss: 0.3342 - val_accuracy: 0.8374
#
# Epoch 00005: val_accuracy improved from 0.83073 to 0.83742, saving model to ./models/tree_9/model_root_f2/folder4\model.h5
# Epoch 6/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.3184 - accuracy: 0.8604 - val_loss: 0.3468 - val_accuracy: 0.8352
#
# Epoch 00006: val_accuracy did not improve from 0.83742
# Epoch 7/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.2854 - accuracy: 0.8745 - val_loss: 0.2853 - val_accuracy: 0.8597
#
# Epoch 00007: val_accuracy improved from 0.83742 to 0.85969, saving model to ./models/tree_9/model_root_f2/folder4\model.h5
# Epoch 8/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.2502 - accuracy: 0.8931 - val_loss: 0.3781 - val_accuracy: 0.8463
#
# Epoch 00008: val_accuracy did not improve from 0.85969
# Epoch 9/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.1978 - accuracy: 0.9159 - val_loss: 0.2446 - val_accuracy: 0.8976
#
# Epoch 00009: val_accuracy improved from 0.85969 to 0.89755, saving model to ./models/tree_9/model_root_f2/folder4\model.h5
# Epoch 10/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1669 - accuracy: 0.9357 - val_loss: 0.4460 - val_accuracy: 0.8330
#
# Epoch 00010: val_accuracy did not improve from 0.89755
# Epoch 11/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1333 - accuracy: 0.9431 - val_loss: 0.2457 - val_accuracy: 0.9176
#
# Epoch 00011: val_accuracy improved from 0.89755 to 0.91759, saving model to ./models/tree_9/model_root_f2/folder4\model.h5
# Epoch 12/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1003 - accuracy: 0.9564 - val_loss: 0.2721 - val_accuracy: 0.9065
#
# Epoch 00012: val_accuracy did not improve from 0.91759
# Epoch 13/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0714 - accuracy: 0.9743 - val_loss: 0.8626 - val_accuracy: 0.7238
#
# Epoch 00013: val_accuracy did not improve from 0.91759
# Epoch 14/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.1065 - accuracy: 0.9579 - val_loss: 0.4332 - val_accuracy: 0.8775
#
# Epoch 00014: val_accuracy did not improve from 0.91759
# Epoch 15/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0404 - accuracy: 0.9866 - val_loss: 0.3161 - val_accuracy: 0.9087
#
# Epoch 00015: val_accuracy did not improve from 0.91759
# Epoch 16/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0187 - accuracy: 0.9948 - val_loss: 0.3271 - val_accuracy: 0.9176
#
# Epoch 00016: val_accuracy did not improve from 0.91759
# Epoch 17/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0066 - accuracy: 0.9993 - val_loss: 0.2825 - val_accuracy: 0.9131
#
# Epoch 00017: val_accuracy did not improve from 0.91759
# Epoch 18/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.3159 - val_accuracy: 0.9310
#
# Epoch 00018: val_accuracy improved from 0.91759 to 0.93096, saving model to ./models/tree_9/model_root_f2/folder4\model.h5
# Epoch 19/30
# 127/127 [==============================] - 2s 17ms/step - loss: 8.2999e-04 - accuracy: 1.0000 - val_loss: 0.3477 - val_accuracy: 0.9287
#
# Epoch 00019: val_accuracy did not improve from 0.93096
# Epoch 20/30
# 127/127 [==============================] - 2s 18ms/step - loss: 5.1632e-04 - accuracy: 1.0000 - val_loss: 0.3523 - val_accuracy: 0.9354
#
# Epoch 00020: val_accuracy improved from 0.93096 to 0.93541, saving model to ./models/tree_9/model_root_f2/folder4\model.h5
# Epoch 21/30
# 127/127 [==============================] - 2s 18ms/step - loss: 4.0511e-04 - accuracy: 1.0000 - val_loss: 0.3499 - val_accuracy: 0.9332
#
# Epoch 00021: val_accuracy did not improve from 0.93541
# Epoch 22/30
# 127/127 [==============================] - 2s 17ms/step - loss: 3.1994e-04 - accuracy: 1.0000 - val_loss: 0.3597 - val_accuracy: 0.9376
#
# Epoch 00022: val_accuracy improved from 0.93541 to 0.93764, saving model to ./models/tree_9/model_root_f2/folder4\model.h5
# Epoch 23/30
# 127/127 [==============================] - 2s 18ms/step - loss: 2.6360e-04 - accuracy: 1.0000 - val_loss: 0.3740 - val_accuracy: 0.9332
#
# Epoch 00023: val_accuracy did not improve from 0.93764
# Epoch 24/30
# 127/127 [==============================] - 2s 18ms/step - loss: 2.2109e-04 - accuracy: 1.0000 - val_loss: 0.3822 - val_accuracy: 0.9265
#
# Epoch 00024: val_accuracy did not improve from 0.93764
# Epoch 25/30
# 127/127 [==============================] - 2s 18ms/step - loss: 1.9389e-04 - accuracy: 1.0000 - val_loss: 0.3759 - val_accuracy: 0.9354
#
# Epoch 00025: val_accuracy did not improve from 0.93764
# Epoch 26/30
# 127/127 [==============================] - 2s 18ms/step - loss: 1.6723e-04 - accuracy: 1.0000 - val_loss: 0.3785 - val_accuracy: 0.9332
#
# Epoch 00026: val_accuracy did not improve from 0.93764
# Epoch 27/30
# 127/127 [==============================] - 2s 18ms/step - loss: 1.4475e-04 - accuracy: 1.0000 - val_loss: 0.3863 - val_accuracy: 0.9310
#
# Epoch 00027: val_accuracy did not improve from 0.93764
# Epoch 28/30
# 127/127 [==============================] - 2s 17ms/step - loss: 1.2619e-04 - accuracy: 1.0000 - val_loss: 0.3869 - val_accuracy: 0.9310
#
# Epoch 00028: val_accuracy did not improve from 0.93764
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 29/30
# 127/127 [==============================] - 2s 18ms/step - loss: 1.1262e-04 - accuracy: 1.0000 - val_loss: 0.3914 - val_accuracy: 0.9332
#
# Epoch 00029: val_accuracy did not improve from 0.93764
# Epoch 30/30
# 127/127 [==============================] - 2s 17ms/step - loss: 1.0536e-04 - accuracy: 1.0000 - val_loss: 0.3896 - val_accuracy: 0.9332
#
# Epoch 00030: val_accuracy did not improve from 0.93764
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 5
# Genre split [['Classical', 'Hip-Hop', 'Jazz'], ['Blues', 'Reggae']]
# Building model...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 3s 19ms/step - loss: 0.7441 - accuracy: 0.5887 - val_loss: 0.6836 - val_accuracy: 0.5880
#
# Epoch 00001: val_accuracy improved from -inf to 0.58797, saving model to ./models/tree_9/model_root_f2/folder5\model.h5
# Epoch 2/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6068 - accuracy: 0.6491 - val_loss: 0.5743 - val_accuracy: 0.6414
#
# Epoch 00002: val_accuracy improved from 0.58797 to 0.64143, saving model to ./models/tree_9/model_root_f2/folder5\model.h5
# Epoch 3/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.5090 - accuracy: 0.7357 - val_loss: 0.7348 - val_accuracy: 0.6615
#
# Epoch 00003: val_accuracy improved from 0.64143 to 0.66147, saving model to ./models/tree_9/model_root_f2/folder5\model.h5
# Epoch 4/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.3785 - accuracy: 0.8265 - val_loss: 0.5624 - val_accuracy: 0.7706
#
# Epoch 00004: val_accuracy improved from 0.66147 to 0.77060, saving model to ./models/tree_9/model_root_f2/folder5\model.h5
# Epoch 5/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.3320 - accuracy: 0.8500 - val_loss: 0.3899 - val_accuracy: 0.8263
#
# Epoch 00005: val_accuracy improved from 0.77060 to 0.82628, saving model to ./models/tree_9/model_root_f2/folder5\model.h5
# Epoch 6/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.2756 - accuracy: 0.8859 - val_loss: 0.3277 - val_accuracy: 0.8664
#
# Epoch 00006: val_accuracy improved from 0.82628 to 0.86637, saving model to ./models/tree_9/model_root_f2/folder5\model.h5
# Epoch 7/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.2179 - accuracy: 0.9112 - val_loss: 0.3332 - val_accuracy: 0.8374
#
# Epoch 00007: val_accuracy did not improve from 0.86637
# Epoch 8/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.1674 - accuracy: 0.9319 - val_loss: 0.3858 - val_accuracy: 0.8597
#
# Epoch 00008: val_accuracy did not improve from 0.86637
# Epoch 9/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.1344 - accuracy: 0.9461 - val_loss: 0.3135 - val_accuracy: 0.9087
#
# Epoch 00009: val_accuracy improved from 0.86637 to 0.90869, saving model to ./models/tree_9/model_root_f2/folder5\model.h5
# Epoch 10/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.1014 - accuracy: 0.9602 - val_loss: 0.4473 - val_accuracy: 0.8552
#
# Epoch 00010: val_accuracy did not improve from 0.90869
# Epoch 11/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0792 - accuracy: 0.9706 - val_loss: 0.3697 - val_accuracy: 0.8976
#
# Epoch 00011: val_accuracy did not improve from 0.90869
# Epoch 12/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0475 - accuracy: 0.9832 - val_loss: 0.3150 - val_accuracy: 0.8931
#
# Epoch 00012: val_accuracy did not improve from 0.90869
# Epoch 13/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0397 - accuracy: 0.9889 - val_loss: 0.3640 - val_accuracy: 0.8953
#
# Epoch 00013: val_accuracy did not improve from 0.90869
# Epoch 14/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0714 - accuracy: 0.9740 - val_loss: 0.3809 - val_accuracy: 0.8998
#
# Epoch 00014: val_accuracy did not improve from 0.90869
# Epoch 15/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0301 - accuracy: 0.9886 - val_loss: 0.4372 - val_accuracy: 0.8842
#
# Epoch 00015: val_accuracy did not improve from 0.90869
# Epoch 16/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0087 - accuracy: 0.9983 - val_loss: 0.3394 - val_accuracy: 0.9154
#
# Epoch 00016: val_accuracy improved from 0.90869 to 0.91537, saving model to ./models/tree_9/model_root_f2/folder5\model.h5
# Epoch 17/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0198 - accuracy: 0.9938 - val_loss: 0.3718 - val_accuracy: 0.9220
#
# Epoch 00017: val_accuracy improved from 0.91537 to 0.92205, saving model to ./models/tree_9/model_root_f2/folder5\model.h5
# Epoch 18/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0043 - accuracy: 0.9998 - val_loss: 0.3980 - val_accuracy: 0.9220
#
# Epoch 00018: val_accuracy did not improve from 0.92205
# Epoch 19/30
# 127/127 [==============================] - 2s 17ms/step - loss: 9.9118e-04 - accuracy: 0.9998 - val_loss: 0.4258 - val_accuracy: 0.9087
#
# Epoch 00019: val_accuracy did not improve from 0.92205
# Epoch 20/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4052 - val_accuracy: 0.9287
#
# Epoch 00020: val_accuracy improved from 0.92205 to 0.92873, saving model to ./models/tree_9/model_root_f2/folder5\model.h5
# Epoch 21/30
# 127/127 [==============================] - 2s 17ms/step - loss: 2.9919e-04 - accuracy: 1.0000 - val_loss: 0.4072 - val_accuracy: 0.9220
#
# Epoch 00021: val_accuracy did not improve from 0.92873
# Epoch 22/30
# 127/127 [==============================] - 2s 17ms/step - loss: 2.2646e-04 - accuracy: 1.0000 - val_loss: 0.4179 - val_accuracy: 0.9287
#
# Epoch 00022: val_accuracy did not improve from 0.92873
# Epoch 23/30
# 127/127 [==============================] - 2s 17ms/step - loss: 1.9270e-04 - accuracy: 1.0000 - val_loss: 0.4150 - val_accuracy: 0.9310
#
# Epoch 00023: val_accuracy improved from 0.92873 to 0.93096, saving model to ./models/tree_9/model_root_f2/folder5\model.h5
# Epoch 24/30
# 127/127 [==============================] - 2s 17ms/step - loss: 1.6148e-04 - accuracy: 1.0000 - val_loss: 0.4323 - val_accuracy: 0.9220
#
# Epoch 00024: val_accuracy did not improve from 0.93096
# Epoch 25/30
# 127/127 [==============================] - 2s 17ms/step - loss: 1.3912e-04 - accuracy: 1.0000 - val_loss: 0.4350 - val_accuracy: 0.9243
#
# Epoch 00025: val_accuracy did not improve from 0.93096
# Epoch 26/30
# 127/127 [==============================] - 2s 17ms/step - loss: 1.2018e-04 - accuracy: 1.0000 - val_loss: 0.4360 - val_accuracy: 0.9265
#
# Epoch 00026: val_accuracy did not improve from 0.93096
# Epoch 27/30
# 127/127 [==============================] - 2s 17ms/step - loss: 1.0594e-04 - accuracy: 1.0000 - val_loss: 0.4457 - val_accuracy: 0.9265
#
# Epoch 00027: val_accuracy did not improve from 0.93096
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 28/30
# 127/127 [==============================] - 2s 17ms/step - loss: 9.1540e-05 - accuracy: 1.0000 - val_loss: 0.4455 - val_accuracy: 0.9243
#
# Epoch 00028: val_accuracy did not improve from 0.93096
# Epoch 29/30
# 127/127 [==============================] - 2s 17ms/step - loss: 8.5916e-05 - accuracy: 1.0000 - val_loss: 0.4521 - val_accuracy: 0.9243
#
# Epoch 00029: val_accuracy did not improve from 0.93096
# Epoch 30/30
# 127/127 [==============================] - 2s 17ms/step - loss: 8.0000e-05 - accuracy: 1.0000 - val_loss: 0.4589 - val_accuracy: 0.9243
#
# Epoch 00030: val_accuracy did not improve from 0.93096
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 6
# Genre split [['Blues', 'Hip-Hop', 'Jazz'], ['Classical', 'Reggae']]
# Building model...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 3s 19ms/step - loss: 0.7070 - accuracy: 0.5964 - val_loss: 0.5944 - val_accuracy: 0.6325
#
# Epoch 00001: val_accuracy improved from -inf to 0.63252, saving model to ./models/tree_9/model_root_f2/folder6\model.h5
# Epoch 2/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.5290 - accuracy: 0.7491 - val_loss: 0.4762 - val_accuracy: 0.7840
#
# Epoch 00002: val_accuracy improved from 0.63252 to 0.78396, saving model to ./models/tree_9/model_root_f2/folder6\model.h5
# Epoch 3/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.4471 - accuracy: 0.7978 - val_loss: 0.4173 - val_accuracy: 0.8062
#
# Epoch 00003: val_accuracy improved from 0.78396 to 0.80624, saving model to ./models/tree_9/model_root_f2/folder6\model.h5
# Epoch 4/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.4242 - accuracy: 0.8057 - val_loss: 0.4232 - val_accuracy: 0.8062
#
# Epoch 00004: val_accuracy did not improve from 0.80624
# Epoch 5/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.3796 - accuracy: 0.8293 - val_loss: 0.3751 - val_accuracy: 0.8151
#
# Epoch 00005: val_accuracy improved from 0.80624 to 0.81514, saving model to ./models/tree_9/model_root_f2/folder6\model.h5
# Epoch 6/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.3396 - accuracy: 0.8483 - val_loss: 0.3193 - val_accuracy: 0.8619
#
# Epoch 00006: val_accuracy improved from 0.81514 to 0.86192, saving model to ./models/tree_9/model_root_f2/folder6\model.h5
# Epoch 7/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.2938 - accuracy: 0.8763 - val_loss: 0.3146 - val_accuracy: 0.8731
#
# Epoch 00007: val_accuracy improved from 0.86192 to 0.87305, saving model to ./models/tree_9/model_root_f2/folder6\model.h5
# Epoch 8/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.2481 - accuracy: 0.8963 - val_loss: 0.2782 - val_accuracy: 0.8886
#
# ...
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 3s 19ms/step - loss: 0.6361 - accuracy: 0.6756 - val_loss: 0.3053 - val_accuracy: 0.8820
#
# Epoch 00001: val_accuracy improved from -inf to 0.88196, saving model to ./models/tree_9/model_root_f2/folder9\model.h5
# Epoch 2/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.3254 - accuracy: 0.8575 - val_loss: 0.2458 - val_accuracy: 0.9109
#
# Epoch 00002: val_accuracy improved from 0.88196 to 0.91091, saving model to ./models/tree_9/model_root_f2/folder9\model.h5
# Epoch 3/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.2468 - accuracy: 0.8973 - val_loss: 0.2275 - val_accuracy: 0.9087
#
# Epoch 00003: val_accuracy did not improve from 0.91091
# Epoch 4/30
# 127/127 [==============================] - ETA: 0s - loss: 0.1808 - accuracy: 0.92 - 2s 18ms/step - loss: 0.1792 - accuracy: 0.9280 - val_loss: 0.1513 - val_accuracy: 0.9287
#
# Epoch 00004: val_accuracy improved from 0.91091 to 0.92873, saving model to ./models/tree_9/model_root_f2/folder9\model.h5
# Epoch 5/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1418 - accuracy: 0.9485 - val_loss: 0.1196 - val_accuracy: 0.9510
#
# Epoch 00005: val_accuracy improved from 0.92873 to 0.95100, saving model to ./models/tree_9/model_root_f2/folder9\model.h5
# Epoch 6/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0991 - accuracy: 0.9604 - val_loss: 0.1700 - val_accuracy: 0.9243
#
# Epoch 00006: val_accuracy did not improve from 0.95100
# Epoch 7/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0833 - accuracy: 0.9681 - val_loss: 0.1179 - val_accuracy: 0.9532
#
# Epoch 00007: val_accuracy improved from 0.95100 to 0.95323, saving model to ./models/tree_9/model_root_f2/folder9\model.h5
# Epoch 8/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0510 - accuracy: 0.9797 - val_loss: 0.1028 - val_accuracy: 0.9555
#
# Epoch 00008: val_accuracy improved from 0.95323 to 0.95546, saving model to ./models/tree_9/model_root_f2/folder9\model.h5
# Epoch 9/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0423 - accuracy: 0.9842 - val_loss: 0.0932 - val_accuracy: 0.9577
#
# Epoch 00009: val_accuracy improved from 0.95546 to 0.95768, saving model to ./models/tree_9/model_root_f2/folder9\model.h5
# Epoch 10/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0424 - accuracy: 0.9864 - val_loss: 0.1193 - val_accuracy: 0.9532
#
# Epoch 00010: val_accuracy did not improve from 0.95768
# Epoch 11/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0288 - accuracy: 0.9891 - val_loss: 0.1465 - val_accuracy: 0.9465
#
# Epoch 00011: val_accuracy did not improve from 0.95768
# Epoch 12/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0330 - accuracy: 0.9864 - val_loss: 0.2294 - val_accuracy: 0.9354
#
# Epoch 00012: val_accuracy did not improve from 0.95768
# Epoch 13/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0197 - accuracy: 0.9933 - val_loss: 0.1445 - val_accuracy: 0.9555
#
# Epoch 00013: val_accuracy did not improve from 0.95768
# Epoch 14/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0200 - accuracy: 0.9918 - val_loss: 0.1074 - val_accuracy: 0.9644
#
# Epoch 00014: val_accuracy improved from 0.95768 to 0.96437, saving model to ./models/tree_9/model_root_f2/folder9\model.h5
# Epoch 15/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0129 - accuracy: 0.9943 - val_loss: 0.2004 - val_accuracy: 0.9443
#
# Epoch 00015: val_accuracy did not improve from 0.96437
# Epoch 16/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.1339 - val_accuracy: 0.9577
#
# Epoch 00016: val_accuracy did not improve from 0.96437
# Epoch 17/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9666
#
# Epoch 00017: val_accuracy improved from 0.96437 to 0.96659, saving model to ./models/tree_9/model_root_f2/folder9\model.h5
# Epoch 18/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9666
#
# Epoch 00018: val_accuracy did not improve from 0.96659
# Epoch 19/30
# 127/127 [==============================] - 2s 18ms/step - loss: 2.4393e-04 - accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9666
#
# Epoch 00019: val_accuracy did not improve from 0.96659
# Epoch 20/30
# 127/127 [==============================] - 2s 18ms/step - loss: 1.6770e-04 - accuracy: 1.0000 - val_loss: 0.1251 - val_accuracy: 0.9666
#
# Epoch 00020: val_accuracy did not improve from 0.96659
# Epoch 21/30
# 127/127 [==============================] - 2s 18ms/step - loss: 1.1571e-04 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9644
#
# Epoch 00021: val_accuracy did not improve from 0.96659
# Epoch 22/30
# 127/127 [==============================] - 2s 18ms/step - loss: 9.4653e-05 - accuracy: 1.0000 - val_loss: 0.1274 - val_accuracy: 0.9688
#
# Epoch 00022: val_accuracy improved from 0.96659 to 0.96882, saving model to ./models/tree_9/model_root_f2/folder9\model.h5
# Epoch 23/30
# 127/127 [==============================] - 2s 18ms/step - loss: 7.9788e-05 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9644
#
# Epoch 00023: val_accuracy did not improve from 0.96882
# Epoch 24/30
# 127/127 [==============================] - 2s 18ms/step - loss: 7.0284e-05 - accuracy: 1.0000 - val_loss: 0.1266 - val_accuracy: 0.9666
#
# Epoch 00024: val_accuracy did not improve from 0.96882
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 25/30
# 127/127 [==============================] - 2s 18ms/step - loss: 6.0467e-05 - accuracy: 1.0000 - val_loss: 0.1264 - val_accuracy: 0.9666
#
# Epoch 00025: val_accuracy did not improve from 0.96882
# Epoch 26/30
# 127/127 [==============================] - 2s 18ms/step - loss: 5.6958e-05 - accuracy: 1.0000 - val_loss: 0.1284 - val_accuracy: 0.9688
#
# Epoch 00026: val_accuracy did not improve from 0.96882
# Epoch 27/30
# 127/127 [==============================] - 2s 18ms/step - loss: 5.3832e-05 - accuracy: 1.0000 - val_loss: 0.1270 - val_accuracy: 0.9666
#
# Epoch 00027: val_accuracy did not improve from 0.96882
# Epoch 28/30
# 127/127 [==============================] - 3s 20ms/step - loss: 5.0654e-05 - accuracy: 1.0000 - val_loss: 0.1276 - val_accuracy: 0.9688
#
# Epoch 00028: val_accuracy did not improve from 0.96882
# Epoch 29/30
# 127/127 [==============================] - 2s 18ms/step - loss: 4.7496e-05 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 0.9666
#
# Epoch 00029: val_accuracy did not improve from 0.96882
# Epoch 30/30
# 127/127 [==============================] - 2s 18ms/step - loss: 4.4504e-05 - accuracy: 1.0000 - val_loss: 0.1286 - val_accuracy: 0.9688
#
# Epoch 00030: val_accuracy did not improve from 0.96882
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 10
# Genre split [['Blues', 'Jazz'], ['Classical', 'Hip-Hop', 'Reggae']]
# Building model...
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 127/127 [==============================] - 3s 19ms/step - loss: 0.7556 - accuracy: 0.5865 - val_loss: 0.6820 - val_accuracy: 0.6058
#
# Epoch 00001: val_accuracy improved from -inf to 0.60579, saving model to ./models/tree_9/model_root_f2/folder10\model.h5
# Epoch 2/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.6722 - accuracy: 0.5961 - val_loss: 0.6210 - val_accuracy: 0.6147
#
# Epoch 00002: val_accuracy improved from 0.60579 to 0.61470, saving model to ./models/tree_9/model_root_f2/folder10\model.h5
# Epoch 3/30
# 127/127 [==============================] - 2s 19ms/step - loss: 0.5489 - accuracy: 0.7132 - val_loss: 0.4961 - val_accuracy: 0.7327
#
# Epoch 00003: val_accuracy improved from 0.61470 to 0.73274, saving model to ./models/tree_9/model_root_f2/folder10\model.h5
# Epoch 4/30
# 127/127 [==============================] - 3s 27ms/step - loss: 0.4289 - accuracy: 0.7869 - val_loss: 0.3727 - val_accuracy: 0.8218
#
# Epoch 00004: val_accuracy improved from 0.73274 to 0.82183, saving model to ./models/tree_9/model_root_f2/folder10\model.h5
# Epoch 5/30
# 127/127 [==============================] - 4s 33ms/step - loss: 0.3155 - accuracy: 0.8664 - val_loss: 0.2731 - val_accuracy: 0.8842
#
# Epoch 00005: val_accuracy improved from 0.82183 to 0.88419, saving model to ./models/tree_9/model_root_f2/folder10\model.h5
# Epoch 6/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.2473 - accuracy: 0.8968 - val_loss: 0.2619 - val_accuracy: 0.8820
#
# Epoch 00006: val_accuracy did not improve from 0.88419
# Epoch 7/30
# 127/127 [==============================] - 2s 17ms/step - loss: 0.2462 - accuracy: 0.8966 - val_loss: 0.2411 - val_accuracy: 0.9042
#
# Epoch 00007: val_accuracy improved from 0.88419 to 0.90423, saving model to ./models/tree_9/model_root_f2/folder10\model.h5
# Epoch 8/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1897 - accuracy: 0.9223 - val_loss: 0.1839 - val_accuracy: 0.9287
#
# Epoch 00008: val_accuracy improved from 0.90423 to 0.92873, saving model to ./models/tree_9/model_root_f2/folder10\model.h5
# Epoch 9/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1671 - accuracy: 0.9342 - val_loss: 0.1753 - val_accuracy: 0.9332
#
# Epoch 00009: val_accuracy improved from 0.92873 to 0.93318, saving model to ./models/tree_9/model_root_f2/folder10\model.h5
# Epoch 10/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1161 - accuracy: 0.9552 - val_loss: 0.1908 - val_accuracy: 0.9287
#
# Epoch 00010: val_accuracy did not improve from 0.93318
# Epoch 11/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.1014 - accuracy: 0.9597 - val_loss: 0.1660 - val_accuracy: 0.9465
#
# Epoch 00011: val_accuracy improved from 0.93318 to 0.94655, saving model to ./models/tree_9/model_root_f2/folder10\model.h5
# Epoch 12/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0756 - accuracy: 0.9720 - val_loss: 0.1672 - val_accuracy: 0.9332
#
# Epoch 00012: val_accuracy did not improve from 0.94655
# Epoch 13/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0570 - accuracy: 0.9790 - val_loss: 0.1433 - val_accuracy: 0.9488
#
# Epoch 00013: val_accuracy improved from 0.94655 to 0.94878, saving model to ./models/tree_9/model_root_f2/folder10\model.h5
# Epoch 14/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0491 - accuracy: 0.9824 - val_loss: 0.1719 - val_accuracy: 0.9399
#
# Epoch 00014: val_accuracy did not improve from 0.94878
# Epoch 15/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0282 - accuracy: 0.9896 - val_loss: 0.1694 - val_accuracy: 0.9354
#
# Epoch 00015: val_accuracy did not improve from 0.94878
# Epoch 16/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0217 - accuracy: 0.9923 - val_loss: 0.1287 - val_accuracy: 0.9488
#
# Epoch 00016: val_accuracy did not improve from 0.94878
# Epoch 17/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0331 - accuracy: 0.9886 - val_loss: 0.1441 - val_accuracy: 0.9599
#
# Epoch 00017: val_accuracy improved from 0.94878 to 0.95991, saving model to ./models/tree_9/model_root_f2/folder10\model.h5
# Epoch 18/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0486 - accuracy: 0.9829 - val_loss: 0.4292 - val_accuracy: 0.8753
#
# Epoch 00018: val_accuracy did not improve from 0.95991
# Epoch 19/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0527 - accuracy: 0.9797 - val_loss: 0.1533 - val_accuracy: 0.9510
#
# Epoch 00019: val_accuracy did not improve from 0.95991
# Epoch 20/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0268 - accuracy: 0.9908 - val_loss: 0.1399 - val_accuracy: 0.9421
#
# Epoch 00020: val_accuracy did not improve from 0.95991
# Epoch 21/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.2703 - val_accuracy: 0.9332
#
# Epoch 00021: val_accuracy did not improve from 0.95991
# Epoch 22/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0375 - accuracy: 0.9856 - val_loss: 0.1647 - val_accuracy: 0.9443
#
# Epoch 00022: val_accuracy did not improve from 0.95991
# Epoch 23/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0038 - accuracy: 0.9995 - val_loss: 0.1788 - val_accuracy: 0.9421
#
# Epoch 00023: val_accuracy did not improve from 0.95991
# Epoch 24/30
# 127/127 [==============================] - 2s 18ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1664 - val_accuracy: 0.9465
#
# Epoch 00024: val_accuracy did not improve from 0.95991
# Epoch 25/30
# 127/127 [==============================] - 2s 18ms/step - loss: 4.6237e-04 - accuracy: 1.0000 - val_loss: 0.1670 - val_accuracy: 0.9443
#
# Epoch 00025: val_accuracy did not improve from 0.95991
# Epoch 26/30
# 127/127 [==============================] - 2s 18ms/step - loss: 2.9707e-04 - accuracy: 1.0000 - val_loss: 0.1739 - val_accuracy: 0.9488
#
# Epoch 00026: val_accuracy did not improve from 0.95991
# Epoch 27/30
# 127/127 [==============================] - 2s 18ms/step - loss: 2.3100e-04 - accuracy: 1.0000 - val_loss: 0.1802 - val_accuracy: 0.9488
#
# Epoch 00027: val_accuracy did not improve from 0.95991
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 28/30
# 127/127 [==============================] - 2s 18ms/step - loss: 1.8976e-04 - accuracy: 1.0000 - val_loss: 0.1810 - val_accuracy: 0.9510
#
# Epoch 00028: val_accuracy did not improve from 0.95991
# Epoch 29/30
# 127/127 [==============================] - 2s 18ms/step - loss: 1.6622e-04 - accuracy: 1.0000 - val_loss: 0.1852 - val_accuracy: 0.9465
#
# Epoch 00029: val_accuracy did not improve from 0.95991
# Epoch 30/30
# 127/127 [==============================] - 2s 18ms/step - loss: 1.5053e-04 - accuracy: 1.0000 - val_loss: 0.1857 - val_accuracy: 0.9510
#
# Epoch 00030: val_accuracy did not improve from 0.95991
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
