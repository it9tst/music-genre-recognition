# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7}
dict_genres = {'Folk':2, 'Instrumental':4, 'Pop':6, 'Rock' :7}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {2: 'Folk', 4: 'Instrumental', 6: 'Pop', 7: 'Rock'}

# %%
npzfile = np.load('data/shuffled_train.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394,)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=8).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((3199, 640, 128), (3199, 8))

# %%
npzfile = np.load('data/shuffled_valid.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=8).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((400, 640, 128), (400, 8))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Pop

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

BATCH_SIZE = 64
EPOCH_COUNT = 50

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding= 'valid', activation='elu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding= 'valid', activation='elu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding= 'valid', activation='elu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding= 'valid', activation='elu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 640
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_5/model_root_f2/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_5/model_root_f2/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
def create_split(elem, c):
    splits = []
    for i in range(c):
        equal = False
        np.random.shuffle(elem)
        new_split = list(chunks(elem, int(len(elem)/2)))
        for split in splits:
            if set(new_split[0]) == set(split[0]) and set(new_split[0]) == set(split[1]):
                equal = True
                break
            
        if equal:
            i-=1
            continue
        
        splits.append(new_split)
        
    return splits

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 3

kfold = KFold(n_splits=8, shuffle=True)
genre_splits = create_split(list(dict_genres.values()), num_splits)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)

    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Rock', 'Folk'], ['Instrumental', 'Pop']]
# Building model...
# Training...
# Epoch 1/50
# 50/50 [==============================] - 40s 257ms/step - loss: 3.7143 - accuracy: 0.5456 - val_loss: 0.6598 - val_accuracy: 0.5933
#
# Epoch 00001: val_accuracy improved from -inf to 0.59333, saving model to ./models/tree_5/model_root_f2/folder1\model.h5
# Epoch 2/50
# 50/50 [==============================] - 9s 174ms/step - loss: 0.6249 - accuracy: 0.6427 - val_loss: 0.6208 - val_accuracy: 0.6267
#
# Epoch 00002: val_accuracy improved from 0.59333 to 0.62667, saving model to ./models/tree_5/model_root_f2/folder1\model.h5
# Epoch 3/50
# 50/50 [==============================] - 9s 174ms/step - loss: 0.5924 - accuracy: 0.6818 - val_loss: 0.6253 - val_accuracy: 0.6622
#
# Epoch 00003: val_accuracy improved from 0.62667 to 0.66222, saving model to ./models/tree_5/model_root_f2/folder1\model.h5
# Epoch 4/50
# 50/50 [==============================] - 13s 271ms/step - loss: 0.5195 - accuracy: 0.7529 - val_loss: 0.5521 - val_accuracy: 0.7000
#
# Epoch 00004: val_accuracy improved from 0.66222 to 0.70000, saving model to ./models/tree_5/model_root_f2/folder1\model.h5
# Epoch 5/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.4597 - accuracy: 0.7987 - val_loss: 0.5527 - val_accuracy: 0.7044
#
# Epoch 00005: val_accuracy improved from 0.70000 to 0.70444, saving model to ./models/tree_5/model_root_f2/folder1\model.h5
# Epoch 6/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.4259 - accuracy: 0.8136 - val_loss: 0.6138 - val_accuracy: 0.6733
#
# Epoch 00006: val_accuracy did not improve from 0.70444
# Epoch 7/50
# 50/50 [==============================] - 9s 174ms/step - loss: 0.3700 - accuracy: 0.8504 - val_loss: 0.5591 - val_accuracy: 0.7244
#
# Epoch 00007: val_accuracy improved from 0.70444 to 0.72444, saving model to ./models/tree_5/model_root_f2/folder1\model.h5
# Epoch 8/50
# 50/50 [==============================] - 12s 242ms/step - loss: 0.2834 - accuracy: 0.9108 - val_loss: 0.5669 - val_accuracy: 0.7022
#
# Epoch 00008: val_accuracy did not improve from 0.72444
# Epoch 9/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.2325 - accuracy: 0.9359 - val_loss: 0.5717 - val_accuracy: 0.7133
#
# Epoch 00009: val_accuracy did not improve from 0.72444
# Epoch 10/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.1565 - accuracy: 0.9733 - val_loss: 0.6274 - val_accuracy: 0.6933
#
# Epoch 00010: val_accuracy did not improve from 0.72444
# Epoch 11/50
# 50/50 [==============================] - 9s 176ms/step - loss: 0.0995 - accuracy: 0.9886 - val_loss: 0.6370 - val_accuracy: 0.7200
#
# Epoch 00011: val_accuracy did not improve from 0.72444
# Epoch 12/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0626 - accuracy: 0.9971 - val_loss: 0.6398 - val_accuracy: 0.7067
#
# Epoch 00012: val_accuracy did not improve from 0.72444
# Epoch 13/50
# 50/50 [==============================] - 9s 175ms/step - loss: 0.0380 - accuracy: 0.9984 - val_loss: 0.7117 - val_accuracy: 0.7111
#
# Epoch 00013: val_accuracy did not improve from 0.72444
# Epoch 14/50
# 50/50 [==============================] - 9s 176ms/step - loss: 0.0238 - accuracy: 0.9997 - val_loss: 0.7182 - val_accuracy: 0.7133
#
# Epoch 00014: val_accuracy did not improve from 0.72444
# Epoch 15/50
# 50/50 [==============================] - 9s 175ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.7752 - val_accuracy: 0.7044
#
# Epoch 00015: val_accuracy did not improve from 0.72444
# Epoch 16/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.8153 - val_accuracy: 0.7089
#
# Epoch 00016: val_accuracy did not improve from 0.72444
# Epoch 17/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.8656 - val_accuracy: 0.7044
#
# Epoch 00017: val_accuracy did not improve from 0.72444
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 18/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.8646 - val_accuracy: 0.7022
#
# Epoch 00018: val_accuracy did not improve from 0.72444
# Epoch 19/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.8722 - val_accuracy: 0.7067
#
# Epoch 00019: val_accuracy did not improve from 0.72444
# Epoch 20/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.8830 - val_accuracy: 0.7067
#
# Epoch 00020: val_accuracy did not improve from 0.72444
# Epoch 21/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.8965 - val_accuracy: 0.7111
#
# Epoch 00021: val_accuracy did not improve from 0.72444
# Epoch 22/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.9156 - val_accuracy: 0.7111
#
# Epoch 00022: val_accuracy did not improve from 0.72444
# Epoch 23/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.9205 - val_accuracy: 0.7089
#
# Epoch 00023: val_accuracy did not improve from 0.72444
# Epoch 24/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.9420 - val_accuracy: 0.7067
#
# Epoch 00024: val_accuracy did not improve from 0.72444
# Epoch 25/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.9553 - val_accuracy: 0.7067
#
# Epoch 00025: val_accuracy did not improve from 0.72444
# Epoch 26/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.9633 - val_accuracy: 0.7067
#
# Epoch 00026: val_accuracy did not improve from 0.72444
# Epoch 27/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.9772 - val_accuracy: 0.7067
#
# Epoch 00027: val_accuracy did not improve from 0.72444
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 28/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.9798 - val_accuracy: 0.7067
#
# Epoch 00028: val_accuracy did not improve from 0.72444
# Epoch 29/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.9872 - val_accuracy: 0.7067
#
# Epoch 00029: val_accuracy did not improve from 0.72444
# Epoch 30/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.0022 - val_accuracy: 0.7089
#
# Epoch 00030: val_accuracy did not improve from 0.72444
# Epoch 31/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.9971 - val_accuracy: 0.7044
#
# Epoch 00031: val_accuracy did not improve from 0.72444
# Epoch 32/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.0039 - val_accuracy: 0.7067
#
# Epoch 00032: val_accuracy did not improve from 0.72444
# Epoch 33/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.0088 - val_accuracy: 0.7067
#
# Epoch 00033: val_accuracy did not improve from 0.72444
# Epoch 34/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.0144 - val_accuracy: 0.7089
#
# Epoch 00034: val_accuracy did not improve from 0.72444
# Epoch 35/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.0243 - val_accuracy: 0.7067
#
# Epoch 00035: val_accuracy did not improve from 0.72444
# Epoch 36/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.0341 - val_accuracy: 0.7067
#
# Epoch 00036: val_accuracy did not improve from 0.72444
# Epoch 37/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.0315 - val_accuracy: 0.7089
#
# Epoch 00037: val_accuracy did not improve from 0.72444
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 38/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.0346 - val_accuracy: 0.7089
#
# Epoch 00038: val_accuracy did not improve from 0.72444
# Epoch 39/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.0367 - val_accuracy: 0.7089
#
# Epoch 00039: val_accuracy did not improve from 0.72444
# Epoch 40/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.0419 - val_accuracy: 0.7044
#
# Epoch 00040: val_accuracy did not improve from 0.72444
# Epoch 41/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.0443 - val_accuracy: 0.7089
#
# Epoch 00041: val_accuracy did not improve from 0.72444
# Epoch 42/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.0471 - val_accuracy: 0.7067
#
# Epoch 00042: val_accuracy did not improve from 0.72444
# Epoch 43/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.0507 - val_accuracy: 0.7089
#
# Epoch 00043: val_accuracy did not improve from 0.72444
# Epoch 44/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.0538 - val_accuracy: 0.7044
#
# Epoch 00044: val_accuracy did not improve from 0.72444
# Epoch 45/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.0556 - val_accuracy: 0.7111
#
# Epoch 00045: val_accuracy did not improve from 0.72444
# Epoch 46/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.0633 - val_accuracy: 0.7044
#
# Epoch 00046: val_accuracy did not improve from 0.72444
# Epoch 47/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.0617 - val_accuracy: 0.7089
#
# Epoch 00047: val_accuracy did not improve from 0.72444
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 48/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.0658 - val_accuracy: 0.7044
#
# Epoch 00048: val_accuracy did not improve from 0.72444
# Epoch 49/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.0667 - val_accuracy: 0.7089
#
# Epoch 00049: val_accuracy did not improve from 0.72444
# Epoch 50/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.0685 - val_accuracy: 0.7089
#
# Epoch 00050: val_accuracy did not improve from 0.72444
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Instrumental', 'Folk'], ['Rock', 'Pop']]
# Building model...
# Training...
# Epoch 1/50
# 50/50 [==============================] - 10s 180ms/step - loss: 5.1877 - accuracy: 0.6011 - val_loss: 0.5774 - val_accuracy: 0.7222
#
# Epoch 00001: val_accuracy improved from -inf to 0.72222, saving model to ./models/tree_5/model_root_f2/folder2\model.h5
# Epoch 2/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.5231 - accuracy: 0.7526 - val_loss: 0.4975 - val_accuracy: 0.7556
#
# Epoch 00002: val_accuracy improved from 0.72222 to 0.75556, saving model to ./models/tree_5/model_root_f2/folder2\model.h5
# Epoch 3/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.4652 - accuracy: 0.7761 - val_loss: 0.4848 - val_accuracy: 0.7822
#
# Epoch 00003: val_accuracy improved from 0.75556 to 0.78222, saving model to ./models/tree_5/model_root_f2/folder2\model.h5
# Epoch 4/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.4408 - accuracy: 0.7974 - val_loss: 0.5442 - val_accuracy: 0.7511
#
# Epoch 00004: val_accuracy did not improve from 0.78222
# Epoch 5/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.4402 - accuracy: 0.7987 - val_loss: 0.4959 - val_accuracy: 0.7511
#
# Epoch 00005: val_accuracy did not improve from 0.78222
# Epoch 6/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.4011 - accuracy: 0.8276 - val_loss: 0.5536 - val_accuracy: 0.7200
#
# Epoch 00006: val_accuracy did not improve from 0.78222
# Epoch 7/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.3626 - accuracy: 0.8520 - val_loss: 0.4776 - val_accuracy: 0.7756
#
# Epoch 00007: val_accuracy did not improve from 0.78222
# Epoch 8/50
# 50/50 [==============================] - 9s 174ms/step - loss: 0.3338 - accuracy: 0.8663 - val_loss: 0.5093 - val_accuracy: 0.7467
#
# Epoch 00008: val_accuracy did not improve from 0.78222
# Epoch 9/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.3196 - accuracy: 0.8730 - val_loss: 0.5625 - val_accuracy: 0.7711
#
# Epoch 00009: val_accuracy did not improve from 0.78222
# Epoch 10/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.2623 - accuracy: 0.9136 - val_loss: 0.4935 - val_accuracy: 0.7756
#
# Epoch 00010: val_accuracy did not improve from 0.78222
# Epoch 11/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.2158 - accuracy: 0.9368 - val_loss: 0.4959 - val_accuracy: 0.7956
#
# Epoch 00011: val_accuracy improved from 0.78222 to 0.79556, saving model to ./models/tree_5/model_root_f2/folder2\model.h5
# Epoch 12/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.1747 - accuracy: 0.9536 - val_loss: 0.5540 - val_accuracy: 0.7689
#
# Epoch 00012: val_accuracy did not improve from 0.79556
# Epoch 13/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.1270 - accuracy: 0.9717 - val_loss: 0.6400 - val_accuracy: 0.7178
#
# Epoch 00013: val_accuracy did not improve from 0.79556
# Epoch 14/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.1046 - accuracy: 0.9787 - val_loss: 0.6375 - val_accuracy: 0.7600
#
# Epoch 00014: val_accuracy did not improve from 0.79556
# Epoch 15/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0644 - accuracy: 0.9924 - val_loss: 0.6108 - val_accuracy: 0.7644
#
# Epoch 00015: val_accuracy did not improve from 0.79556
# Epoch 16/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0440 - accuracy: 0.9968 - val_loss: 0.6467 - val_accuracy: 0.7778
#
# Epoch 00016: val_accuracy did not improve from 0.79556
# Epoch 17/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0342 - accuracy: 0.9975 - val_loss: 0.7245 - val_accuracy: 0.7733
#
# Epoch 00017: val_accuracy did not improve from 0.79556
# Epoch 18/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0249 - accuracy: 0.9987 - val_loss: 0.7267 - val_accuracy: 0.7622
#
# Epoch 00018: val_accuracy did not improve from 0.79556
# Epoch 19/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0198 - accuracy: 0.9994 - val_loss: 0.7792 - val_accuracy: 0.7644
#
# Epoch 00019: val_accuracy did not improve from 0.79556
# Epoch 20/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0124 - accuracy: 0.9997 - val_loss: 0.8103 - val_accuracy: 0.7644
#
# Epoch 00020: val_accuracy did not improve from 0.79556
# Epoch 21/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0102 - accuracy: 0.9997 - val_loss: 0.8324 - val_accuracy: 0.7689
#
# Epoch 00021: val_accuracy did not improve from 0.79556
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 22/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0076 - accuracy: 0.9997 - val_loss: 0.8431 - val_accuracy: 0.7689
#
# Epoch 00022: val_accuracy did not improve from 0.79556
# Epoch 23/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0066 - accuracy: 0.9997 - val_loss: 0.8569 - val_accuracy: 0.7711
#
# Epoch 00023: val_accuracy did not improve from 0.79556
# Epoch 24/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0060 - accuracy: 0.9997 - val_loss: 0.8936 - val_accuracy: 0.7689
#
# Epoch 00024: val_accuracy did not improve from 0.79556
# Epoch 25/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.8927 - val_accuracy: 0.7644
#
# Epoch 00025: val_accuracy did not improve from 0.79556
# Epoch 26/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0051 - accuracy: 0.9997 - val_loss: 0.9004 - val_accuracy: 0.7667
#
# Epoch 00026: val_accuracy did not improve from 0.79556
# Epoch 27/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0045 - accuracy: 0.9997 - val_loss: 0.9199 - val_accuracy: 0.7644
#
# Epoch 00027: val_accuracy did not improve from 0.79556
# Epoch 28/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0041 - accuracy: 0.9997 - val_loss: 0.9244 - val_accuracy: 0.7644
#
# Epoch 00028: val_accuracy did not improve from 0.79556
# Epoch 29/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.9436 - val_accuracy: 0.7644
#
# Epoch 00029: val_accuracy did not improve from 0.79556
# Epoch 30/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.9606 - val_accuracy: 0.7667
#
# Epoch 00030: val_accuracy did not improve from 0.79556
# Epoch 31/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.9588 - val_accuracy: 0.7689
#
# Epoch 00031: val_accuracy did not improve from 0.79556
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 32/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.9733 - val_accuracy: 0.7667
#
# Epoch 00032: val_accuracy did not improve from 0.79556
# Epoch 33/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.9761 - val_accuracy: 0.7689
#
# Epoch 00033: val_accuracy did not improve from 0.79556
# Epoch 34/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.9822 - val_accuracy: 0.7689
#
# Epoch 00034: val_accuracy did not improve from 0.79556
# Epoch 35/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.9926 - val_accuracy: 0.7689
#
# Epoch 00035: val_accuracy did not improve from 0.79556
# Epoch 36/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.9945 - val_accuracy: 0.7644
#
# Epoch 00036: val_accuracy did not improve from 0.79556
# Epoch 37/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.0026 - val_accuracy: 0.7689
#
# Epoch 00037: val_accuracy did not improve from 0.79556
# Epoch 38/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.0064 - val_accuracy: 0.7689
#
# Epoch 00038: val_accuracy did not improve from 0.79556
# Epoch 39/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.0132 - val_accuracy: 0.7689
#
# Epoch 00039: val_accuracy did not improve from 0.79556
# Epoch 40/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.0224 - val_accuracy: 0.7667
#
# Epoch 00040: val_accuracy did not improve from 0.79556
# Epoch 41/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.0268 - val_accuracy: 0.7667
#
# Epoch 00041: val_accuracy did not improve from 0.79556
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 42/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.0305 - val_accuracy: 0.7667
#
# Epoch 00042: val_accuracy did not improve from 0.79556
# Epoch 43/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.0344 - val_accuracy: 0.7689
#
# Epoch 00043: val_accuracy did not improve from 0.79556
# Epoch 44/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.0380 - val_accuracy: 0.7667
#
# Epoch 00044: val_accuracy did not improve from 0.79556
# Epoch 45/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.0393 - val_accuracy: 0.7644
#
# Epoch 00045: val_accuracy did not improve from 0.79556
# Epoch 46/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.0475 - val_accuracy: 0.7644
#
# Epoch 00046: val_accuracy did not improve from 0.79556
# Epoch 47/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.0461 - val_accuracy: 0.7644
#
# Epoch 00047: val_accuracy did not improve from 0.79556
# Epoch 48/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.0475 - val_accuracy: 0.7644
#
# Epoch 00048: val_accuracy did not improve from 0.79556
# Epoch 49/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.0523 - val_accuracy: 0.7689
#
# Epoch 00049: val_accuracy did not improve from 0.79556
# Epoch 50/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.0550 - val_accuracy: 0.7644
#
# Epoch 00050: val_accuracy did not improve from 0.79556
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Instrumental', 'Folk'], ['Rock', 'Pop']]
# Building model...
# Training...
# Epoch 1/50
# 50/50 [==============================] - 9s 177ms/step - loss: 3.8451 - accuracy: 0.5903 - val_loss: 0.5019 - val_accuracy: 0.7689
#
# Epoch 00001: val_accuracy improved from -inf to 0.76889, saving model to ./models/tree_5/model_root_f2/folder3\model.h5
# Epoch 2/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.4924 - accuracy: 0.7650 - val_loss: 0.4888 - val_accuracy: 0.7422
#
# Epoch 00002: val_accuracy did not improve from 0.76889
# Epoch 3/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.4571 - accuracy: 0.7917 - val_loss: 0.5225 - val_accuracy: 0.7533
#
# Epoch 00003: val_accuracy did not improve from 0.76889
# Epoch 4/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.4453 - accuracy: 0.7993 - val_loss: 0.5029 - val_accuracy: 0.7644
#
# Epoch 00004: val_accuracy did not improve from 0.76889
# Epoch 5/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.4026 - accuracy: 0.8250 - val_loss: 0.5051 - val_accuracy: 0.7711
#
# Epoch 00005: val_accuracy improved from 0.76889 to 0.77111, saving model to ./models/tree_5/model_root_f2/folder3\model.h5
# Epoch 6/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.3587 - accuracy: 0.8571 - val_loss: 0.6363 - val_accuracy: 0.7044
#
# Epoch 00006: val_accuracy did not improve from 0.77111
# Epoch 7/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.3404 - accuracy: 0.8622 - val_loss: 0.4682 - val_accuracy: 0.7867
#
# Epoch 00007: val_accuracy improved from 0.77111 to 0.78667, saving model to ./models/tree_5/model_root_f2/folder3\model.h5
# Epoch 8/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.2871 - accuracy: 0.8990 - val_loss: 0.5785 - val_accuracy: 0.7311
#
# Epoch 00008: val_accuracy did not improve from 0.78667
# Epoch 9/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.2474 - accuracy: 0.9244 - val_loss: 0.4632 - val_accuracy: 0.7778
#
# Epoch 00009: val_accuracy did not improve from 0.78667
# Epoch 10/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.2127 - accuracy: 0.9393 - val_loss: 0.4603 - val_accuracy: 0.7778
#
# Epoch 00010: val_accuracy did not improve from 0.78667
# Epoch 11/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.1571 - accuracy: 0.9679 - val_loss: 0.5216 - val_accuracy: 0.7822
#
# Epoch 00011: val_accuracy did not improve from 0.78667
# Epoch 12/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.1158 - accuracy: 0.9765 - val_loss: 0.5081 - val_accuracy: 0.7467
#
# Epoch 00012: val_accuracy did not improve from 0.78667
# Epoch 13/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0909 - accuracy: 0.9857 - val_loss: 0.5337 - val_accuracy: 0.7644
#
# Epoch 00013: val_accuracy did not improve from 0.78667
# Epoch 14/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0596 - accuracy: 0.9930 - val_loss: 0.6337 - val_accuracy: 0.7467
#
# Epoch 00014: val_accuracy did not improve from 0.78667
# Epoch 15/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0430 - accuracy: 0.9971 - val_loss: 0.6161 - val_accuracy: 0.7556
#
# Epoch 00015: val_accuracy did not improve from 0.78667
# Epoch 16/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0359 - accuracy: 0.9971 - val_loss: 0.6264 - val_accuracy: 0.7511
#
# Epoch 00016: val_accuracy did not improve from 0.78667
# Epoch 17/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0245 - accuracy: 0.9987 - val_loss: 0.6160 - val_accuracy: 0.7600
#
# Epoch 00017: val_accuracy did not improve from 0.78667
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 18/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0169 - accuracy: 0.9994 - val_loss: 0.6629 - val_accuracy: 0.7578
#
# Epoch 00018: val_accuracy did not improve from 0.78667
# Epoch 19/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0153 - accuracy: 0.9994 - val_loss: 0.6617 - val_accuracy: 0.7578
#
# Epoch 00019: val_accuracy did not improve from 0.78667
# Epoch 20/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0132 - accuracy: 0.9994 - val_loss: 0.7162 - val_accuracy: 0.7444
#
# Epoch 00020: val_accuracy did not improve from 0.78667
# Epoch 21/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0117 - accuracy: 0.9994 - val_loss: 0.7078 - val_accuracy: 0.7511
#
# Epoch 00021: val_accuracy did not improve from 0.78667
# Epoch 22/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0107 - accuracy: 0.9994 - val_loss: 0.7380 - val_accuracy: 0.7489
#
# Epoch 00022: val_accuracy did not improve from 0.78667
# Epoch 23/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0092 - accuracy: 0.9994 - val_loss: 0.7415 - val_accuracy: 0.7511
#
# Epoch 00023: val_accuracy did not improve from 0.78667
# Epoch 24/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0083 - accuracy: 0.9994 - val_loss: 0.7302 - val_accuracy: 0.7556
#
# Epoch 00024: val_accuracy did not improve from 0.78667
# Epoch 25/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0073 - accuracy: 0.9994 - val_loss: 0.7689 - val_accuracy: 0.7556
#
# Epoch 00025: val_accuracy did not improve from 0.78667
# Epoch 26/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0070 - accuracy: 0.9997 - val_loss: 0.7914 - val_accuracy: 0.7467
#
# Epoch 00026: val_accuracy did not improve from 0.78667
# Epoch 27/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.7772 - val_accuracy: 0.7533
#
# Epoch 00027: val_accuracy did not improve from 0.78667
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 28/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.7723 - val_accuracy: 0.7600
#
# Epoch 00028: val_accuracy did not improve from 0.78667
# Epoch 29/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.7862 - val_accuracy: 0.7600
#
# Epoch 00029: val_accuracy did not improve from 0.78667
# Epoch 30/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.7994 - val_accuracy: 0.7533
#
# Epoch 00030: val_accuracy did not improve from 0.78667
# Epoch 31/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.8074 - val_accuracy: 0.7533
#
# Epoch 00031: val_accuracy did not improve from 0.78667
# Epoch 32/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.8019 - val_accuracy: 0.7578
#
# Epoch 00032: val_accuracy did not improve from 0.78667
# Epoch 33/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.8217 - val_accuracy: 0.7533
#
# Epoch 00033: val_accuracy did not improve from 0.78667
# Epoch 34/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.8061 - val_accuracy: 0.7556
#
# Epoch 00034: val_accuracy did not improve from 0.78667
# Epoch 35/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.8221 - val_accuracy: 0.7578
#
# Epoch 00035: val_accuracy did not improve from 0.78667
# Epoch 36/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.8398 - val_accuracy: 0.7533
#
# Epoch 00036: val_accuracy did not improve from 0.78667
# Epoch 37/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.8349 - val_accuracy: 0.7578
#
# Epoch 00037: val_accuracy did not improve from 0.78667
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 38/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.8464 - val_accuracy: 0.7533
#
# Epoch 00038: val_accuracy did not improve from 0.78667
# Epoch 39/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.8435 - val_accuracy: 0.7533
#
# Epoch 00039: val_accuracy did not improve from 0.78667
# Epoch 40/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.8462 - val_accuracy: 0.7533
#
# Epoch 00040: val_accuracy did not improve from 0.78667
# Epoch 41/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.8350 - val_accuracy: 0.7556
#
# Epoch 00041: val_accuracy did not improve from 0.78667
# Epoch 42/50
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.8588 - val_accuracy: 0.7533
#
# Epoch 00042: val_accuracy did not improve from 0.78667
# Epoch 43/50
# 50/50 [==============================] - 10s 199ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.8502 - val_accuracy: 0.7556
#
# Epoch 00043: val_accuracy did not improve from 0.78667
# Epoch 44/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.8705 - val_accuracy: 0.7511
#
# Epoch 00044: val_accuracy did not improve from 0.78667
# Epoch 45/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.8657 - val_accuracy: 0.7511
#
# Epoch 00045: val_accuracy did not improve from 0.78667
# Epoch 46/50
# 50/50 [==============================] - 9s 176ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.8534 - val_accuracy: 0.7556
#
# Epoch 00046: val_accuracy did not improve from 0.78667
# Epoch 47/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.8690 - val_accuracy: 0.7511
#
# Epoch 00047: val_accuracy did not improve from 0.78667
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 48/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.8699 - val_accuracy: 0.7556
#
# Epoch 00048: val_accuracy did not improve from 0.78667
# Epoch 49/50
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.8754 - val_accuracy: 0.7533
#
# Epoch 00049: val_accuracy did not improve from 0.78667
# Epoch 50/50
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.8744 - val_accuracy: 0.7533
#
# Epoch 00050: val_accuracy did not improve from 0.78667
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
