# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7}
dict_genres = {'Experimental':1, 'International' :5}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {1: 'Experimental', 5: 'International'}

# %%
npzfile = np.load('data/shuffled_train.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394,)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=8).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((1599, 640, 128), (1599, 8))

# %%
npzfile = np.load('data/shuffled_valid.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=8).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((200, 640, 128), (200, 8))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Experimental

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

BATCH_SIZE = 64
EPOCH_COUNT = 50

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding= 'valid', activation='elu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding= 'valid', activation='elu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding= 'valid', activation='elu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding= 'valid', activation='elu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 640
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_5/model_root_f1_2/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_5/model_root_f1_2/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
def create_split(elem, c):
    splits = []
    for i in range(c):
        equal = False
        np.random.shuffle(elem)
        new_split = list(chunks(elem, int(len(elem)/2)))
        for split in splits:
            if set(new_split[0]) == set(split[0]) and set(new_split[0]) == set(split[1]):
                equal = True
                break
            
        if equal:
            i-=1
            continue
        
        splits.append(new_split)
        
    return splits

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 1

kfold = KFold(n_splits=8, shuffle=True)
genre_splits = create_split(list(dict_genres.values()), num_splits)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)

    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['International'], ['Experimental']]
# Building model...
# Training...
# Epoch 1/50
# 25/25 [==============================] - 12s 235ms/step - loss: 9.8481 - accuracy: 0.5057 - val_loss: 1.2875 - val_accuracy: 0.4711
#
# Epoch 00001: val_accuracy improved from -inf to 0.47111, saving model to ./models/tree_5/model_root_f1_2/folder1\model.h5
# Epoch 2/50
# 25/25 [==============================] - 4s 169ms/step - loss: 0.7695 - accuracy: 0.6061 - val_loss: 0.5032 - val_accuracy: 0.8222
#
# Epoch 00002: val_accuracy improved from 0.47111 to 0.82222, saving model to ./models/tree_5/model_root_f1_2/folder1\model.h5
# Epoch 3/50
# 25/25 [==============================] - 4s 169ms/step - loss: 0.5208 - accuracy: 0.7497 - val_loss: 0.5246 - val_accuracy: 0.6978
#
# Epoch 00003: val_accuracy did not improve from 0.82222
# Epoch 4/50
# 25/25 [==============================] - 4s 169ms/step - loss: 0.4898 - accuracy: 0.7675 - val_loss: 0.4415 - val_accuracy: 0.8178
#
# Epoch 00004: val_accuracy did not improve from 0.82222
# Epoch 5/50
# 25/25 [==============================] - 4s 169ms/step - loss: 0.4506 - accuracy: 0.7910 - val_loss: 0.4390 - val_accuracy: 0.8089
#
# Epoch 00005: val_accuracy did not improve from 0.82222
# Epoch 6/50
# 25/25 [==============================] - 4s 169ms/step - loss: 0.4080 - accuracy: 0.8310 - val_loss: 0.4193 - val_accuracy: 0.8578
#
# Epoch 00006: val_accuracy improved from 0.82222 to 0.85778, saving model to ./models/tree_5/model_root_f1_2/folder1\model.h5
# Epoch 7/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.4092 - accuracy: 0.8126 - val_loss: 0.4314 - val_accuracy: 0.8578
#
# Epoch 00007: val_accuracy did not improve from 0.85778
# Epoch 8/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.3520 - accuracy: 0.8628 - val_loss: 0.4005 - val_accuracy: 0.8444
#
# Epoch 00008: val_accuracy did not improve from 0.85778
# Epoch 9/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.3047 - accuracy: 0.8901 - val_loss: 0.3901 - val_accuracy: 0.8356
#
# Epoch 00009: val_accuracy did not improve from 0.85778
# Epoch 10/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.3046 - accuracy: 0.8831 - val_loss: 0.4263 - val_accuracy: 0.8489
#
# Epoch 00010: val_accuracy did not improve from 0.85778
# Epoch 11/50
# 25/25 [==============================] - 4s 169ms/step - loss: 0.2553 - accuracy: 0.9180 - val_loss: 0.4036 - val_accuracy: 0.8667
#
# Epoch 00011: val_accuracy improved from 0.85778 to 0.86667, saving model to ./models/tree_5/model_root_f1_2/folder1\model.h5
# Epoch 12/50
# 25/25 [==============================] - 4s 172ms/step - loss: 0.2325 - accuracy: 0.9174 - val_loss: 0.4427 - val_accuracy: 0.8400
#
# Epoch 00012: val_accuracy did not improve from 0.86667
# Epoch 13/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.2134 - accuracy: 0.9352 - val_loss: 0.4111 - val_accuracy: 0.8578
#
# Epoch 00013: val_accuracy did not improve from 0.86667
# Epoch 14/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.1592 - accuracy: 0.9670 - val_loss: 0.3679 - val_accuracy: 0.8756
#
# Epoch 00014: val_accuracy improved from 0.86667 to 0.87556, saving model to ./models/tree_5/model_root_f1_2/folder1\model.h5
# Epoch 15/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.1368 - accuracy: 0.9746 - val_loss: 0.4298 - val_accuracy: 0.8578
#
# Epoch 00015: val_accuracy did not improve from 0.87556
# Epoch 16/50
# 25/25 [==============================] - 4s 171ms/step - loss: 0.1151 - accuracy: 0.9790 - val_loss: 0.5047 - val_accuracy: 0.7822
#
# Epoch 00016: val_accuracy did not improve from 0.87556
# Epoch 17/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.1150 - accuracy: 0.9701 - val_loss: 0.3913 - val_accuracy: 0.8622
#
# Epoch 00017: val_accuracy did not improve from 0.87556
# Epoch 18/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0793 - accuracy: 0.9924 - val_loss: 0.4651 - val_accuracy: 0.8311
#
# Epoch 00018: val_accuracy did not improve from 0.87556
# Epoch 19/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0619 - accuracy: 0.9956 - val_loss: 0.3990 - val_accuracy: 0.8622
#
# Epoch 00019: val_accuracy did not improve from 0.87556
# Epoch 20/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0673 - accuracy: 0.9879 - val_loss: 0.4192 - val_accuracy: 0.8489
#
# Epoch 00020: val_accuracy did not improve from 0.87556
# Epoch 21/50
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0584 - accuracy: 0.9917 - val_loss: 0.4923 - val_accuracy: 0.8444
#
# Epoch 00021: val_accuracy did not improve from 0.87556
# Epoch 22/50
# 25/25 [==============================] - 4s 169ms/step - loss: 0.0366 - accuracy: 0.9987 - val_loss: 0.4597 - val_accuracy: 0.8533
#
# Epoch 00022: val_accuracy did not improve from 0.87556
# Epoch 23/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0289 - accuracy: 0.9994 - val_loss: 0.4590 - val_accuracy: 0.8489
#
# Epoch 00023: val_accuracy did not improve from 0.87556
# Epoch 24/50
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0256 - accuracy: 1.0000 - val_loss: 0.4681 - val_accuracy: 0.8667
#
# Epoch 00024: val_accuracy did not improve from 0.87556
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 25/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.4417 - val_accuracy: 0.8533
#
# Epoch 00025: val_accuracy did not improve from 0.87556
# Epoch 26/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.4714 - val_accuracy: 0.8667
#
# Epoch 00026: val_accuracy did not improve from 0.87556
# Epoch 27/50
# 25/25 [==============================] - 4s 172ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.4734 - val_accuracy: 0.8578
#
# Epoch 00027: val_accuracy did not improve from 0.87556
# Epoch 28/50
# 25/25 [==============================] - 4s 172ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.4925 - val_accuracy: 0.8622
#
# Epoch 00028: val_accuracy did not improve from 0.87556
# Epoch 29/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.4893 - val_accuracy: 0.8622
#
# Epoch 00029: val_accuracy did not improve from 0.87556
# Epoch 30/50
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.5036 - val_accuracy: 0.8622
#
# Epoch 00030: val_accuracy did not improve from 0.87556
# Epoch 31/50
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.4952 - val_accuracy: 0.8578
#
# Epoch 00031: val_accuracy did not improve from 0.87556
# Epoch 32/50
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.4963 - val_accuracy: 0.8533
#
# Epoch 00032: val_accuracy did not improve from 0.87556
# Epoch 33/50
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.5128 - val_accuracy: 0.8622
#
# Epoch 00033: val_accuracy did not improve from 0.87556
# Epoch 34/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.5040 - val_accuracy: 0.8533
#
# Epoch 00034: val_accuracy did not improve from 0.87556
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 35/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.5168 - val_accuracy: 0.8578
#
# Epoch 00035: val_accuracy did not improve from 0.87556
# Epoch 36/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.5222 - val_accuracy: 0.8622
#
# Epoch 00036: val_accuracy did not improve from 0.87556
# Epoch 37/50
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.5204 - val_accuracy: 0.8578
#
# Epoch 00037: val_accuracy did not improve from 0.87556
# Epoch 38/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.5260 - val_accuracy: 0.8578
#
# Epoch 00038: val_accuracy did not improve from 0.87556
# Epoch 39/50
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.5153 - val_accuracy: 0.8578
#
# Epoch 00039: val_accuracy did not improve from 0.87556
# Epoch 40/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.5294 - val_accuracy: 0.8578
#
# Epoch 00040: val_accuracy did not improve from 0.87556
# Epoch 41/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.5181 - val_accuracy: 0.8578
#
# Epoch 00041: val_accuracy did not improve from 0.87556
# Epoch 42/50
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.5329 - val_accuracy: 0.8533
#
# Epoch 00042: val_accuracy did not improve from 0.87556
# Epoch 43/50
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.5367 - val_accuracy: 0.8578
#
# Epoch 00043: val_accuracy did not improve from 0.87556
# Epoch 44/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.5319 - val_accuracy: 0.8533
#
# Epoch 00044: val_accuracy did not improve from 0.87556
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 45/50
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.5292 - val_accuracy: 0.8533
#
# Epoch 00045: val_accuracy did not improve from 0.87556
# Epoch 46/50
# 25/25 [==============================] - 4s 172ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.5437 - val_accuracy: 0.8533
#
# Epoch 00046: val_accuracy did not improve from 0.87556
# Epoch 47/50
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.5419 - val_accuracy: 0.8533
#
# Epoch 00047: val_accuracy did not improve from 0.87556
# Epoch 48/50
# 25/25 [==============================] - 4s 172ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.5550 - val_accuracy: 0.8622
#
# Epoch 00048: val_accuracy did not improve from 0.87556
# Epoch 49/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.5407 - val_accuracy: 0.8533
#
# Epoch 00049: val_accuracy did not improve from 0.87556
# Epoch 50/50
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.5387 - val_accuracy: 0.8533
#
# Epoch 00050: val_accuracy did not improve from 0.87556
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
