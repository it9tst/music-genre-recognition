# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7}
dict_genres = {'Electronic':0, 'Experimental':1, 'International':5, 'Pop' :6}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Electronic', 1: 'Experimental', 5: 'International', 6: 'Pop'}

# %%
npzfile = np.load('data/shuffled_train.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394,)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=8).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((3198, 640, 128), (3198, 8))

# %%
npzfile = np.load('data/shuffled_valid.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=8).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((400, 640, 128), (400, 8))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Pop

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

BATCH_SIZE = 64
EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 640
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_2/model_root_f1_1_1_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_2/model_root_f1_1_1_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
def create_split(elem, c):
    splits = []
    for i in range(c):
        equal = False
        np.random.shuffle(elem)
        new_split = list(chunks(elem, int(len(elem)/2)))
        for split in splits:
            if set(new_split[0]) == set(split[0]) and set(new_split[0]) == set(split[1]):
                equal = True
                break
            
        if equal:
            i-=1
            continue
        
        splits.append(new_split)
        
    return splits

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 4

kfold = KFold(n_splits=8, shuffle=True)
genre_splits = create_split(list(dict_genres.values()), num_splits)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    dict_genres_list = list(dict_genres.values())
    split = [[dict_genres_list.pop(fold_no - 1)], dict_genres_list]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)

    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Electronic'], ['Experimental', 'International', 'Pop']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 21s 182ms/step - loss: 0.9491 - accuracy: 0.7195 - val_loss: 0.5215 - val_accuracy: 0.7911
#
# Epoch 00001: val_accuracy improved from -inf to 0.79111, saving model to ./models/tree_2/model_root_f1_1_1_1/folder1\model.h5
# Epoch 2/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.5745 - accuracy: 0.7443 - val_loss: 0.5096 - val_accuracy: 0.7911
#
# Epoch 00002: val_accuracy did not improve from 0.79111
# Epoch 3/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.5756 - accuracy: 0.7414 - val_loss: 0.5123 - val_accuracy: 0.7911
#
# Epoch 00003: val_accuracy did not improve from 0.79111
# Epoch 4/30
# 50/50 [==============================] - 7s 148ms/step - loss: 0.5766 - accuracy: 0.7443 - val_loss: 0.5164 - val_accuracy: 0.7911
#
# Epoch 00004: val_accuracy did not improve from 0.79111
# Epoch 5/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.5541 - accuracy: 0.7452 - val_loss: 0.5137 - val_accuracy: 0.7911
#
# Epoch 00005: val_accuracy did not improve from 0.79111
# Epoch 6/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.4957 - accuracy: 0.7764 - val_loss: 0.6573 - val_accuracy: 0.7200
#
# Epoch 00006: val_accuracy did not improve from 0.79111
# Epoch 7/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.4665 - accuracy: 0.7868 - val_loss: 0.4223 - val_accuracy: 0.8178
#
# Epoch 00007: val_accuracy improved from 0.79111 to 0.81778, saving model to ./models/tree_2/model_root_f1_1_1_1/folder1\model.h5
# Epoch 8/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.4563 - accuracy: 0.7970 - val_loss: 0.4348 - val_accuracy: 0.8022
#
# Epoch 00008: val_accuracy did not improve from 0.81778
# Epoch 9/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.4341 - accuracy: 0.8040 - val_loss: 0.4831 - val_accuracy: 0.8089
#
# Epoch 00009: val_accuracy did not improve from 0.81778
# Epoch 10/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.4129 - accuracy: 0.8135 - val_loss: 0.3974 - val_accuracy: 0.8200
#
# Epoch 00010: val_accuracy improved from 0.81778 to 0.82000, saving model to ./models/tree_2/model_root_f1_1_1_1/folder1\model.h5
# Epoch 11/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.3856 - accuracy: 0.8288 - val_loss: 0.4898 - val_accuracy: 0.7956
#
# Epoch 00011: val_accuracy did not improve from 0.82000
# Epoch 12/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.3794 - accuracy: 0.8294 - val_loss: 0.4406 - val_accuracy: 0.8111
#
# Epoch 00012: val_accuracy did not improve from 0.82000
# Epoch 13/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.3526 - accuracy: 0.8440 - val_loss: 0.4024 - val_accuracy: 0.8222
#
# Epoch 00013: val_accuracy improved from 0.82000 to 0.82222, saving model to ./models/tree_2/model_root_f1_1_1_1/folder1\model.h5
# Epoch 14/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.3575 - accuracy: 0.8428 - val_loss: 0.4179 - val_accuracy: 0.8378
#
# Epoch 00014: val_accuracy improved from 0.82222 to 0.83778, saving model to ./models/tree_2/model_root_f1_1_1_1/folder1\model.h5
# Epoch 15/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.3137 - accuracy: 0.8618 - val_loss: 0.5029 - val_accuracy: 0.7911
#
# Epoch 00015: val_accuracy did not improve from 0.83778
# Epoch 16/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.2803 - accuracy: 0.8799 - val_loss: 0.4993 - val_accuracy: 0.8156
#
# Epoch 00016: val_accuracy did not improve from 0.83778
# Epoch 17/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.2549 - accuracy: 0.8964 - val_loss: 0.4642 - val_accuracy: 0.8311
#
# Epoch 00017: val_accuracy did not improve from 0.83778
# Epoch 18/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.2023 - accuracy: 0.9168 - val_loss: 0.5878 - val_accuracy: 0.8267
#
# Epoch 00018: val_accuracy did not improve from 0.83778
# Epoch 19/30
# 50/50 [==============================] - 8s 152ms/step - loss: 0.1569 - accuracy: 0.9428 - val_loss: 0.6199 - val_accuracy: 0.8044
#
# Epoch 00019: val_accuracy did not improve from 0.83778
# Epoch 20/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.1437 - accuracy: 0.9466 - val_loss: 0.9465 - val_accuracy: 0.8133
#
# Epoch 00020: val_accuracy did not improve from 0.83778
# Epoch 21/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.1159 - accuracy: 0.9578 - val_loss: 0.8274 - val_accuracy: 0.7711
#
# Epoch 00021: val_accuracy did not improve from 0.83778
# Epoch 22/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0865 - accuracy: 0.9692 - val_loss: 1.2579 - val_accuracy: 0.7489
#
# Epoch 00022: val_accuracy did not improve from 0.83778
# Epoch 23/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.1022 - accuracy: 0.9635 - val_loss: 0.9599 - val_accuracy: 0.7867
#
# Epoch 00023: val_accuracy did not improve from 0.83778
# Epoch 24/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0267 - accuracy: 0.9924 - val_loss: 1.0961 - val_accuracy: 0.8022
#
# Epoch 00024: val_accuracy did not improve from 0.83778
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 25/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0124 - accuracy: 0.9981 - val_loss: 1.2038 - val_accuracy: 0.7911
#
# Epoch 00025: val_accuracy did not improve from 0.83778
# Epoch 26/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0083 - accuracy: 0.9987 - val_loss: 1.2809 - val_accuracy: 0.7889
#
# Epoch 00026: val_accuracy did not improve from 0.83778
# Epoch 27/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0070 - accuracy: 0.9990 - val_loss: 1.3130 - val_accuracy: 0.7822
#
# Epoch 00027: val_accuracy did not improve from 0.83778
# Epoch 28/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0053 - accuracy: 0.9994 - val_loss: 1.4133 - val_accuracy: 0.8133
#
# Epoch 00028: val_accuracy did not improve from 0.83778
# Epoch 29/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0058 - accuracy: 0.9990 - val_loss: 1.4784 - val_accuracy: 0.7733
#
# Epoch 00029: val_accuracy did not improve from 0.83778
# Epoch 30/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0047 - accuracy: 0.9994 - val_loss: 1.4175 - val_accuracy: 0.8222
#
# Epoch 00030: val_accuracy did not improve from 0.83778
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Experimental'], ['Electronic', 'International', 'Pop']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 8s 157ms/step - loss: 0.9073 - accuracy: 0.7335 - val_loss: 0.5283 - val_accuracy: 0.7800
#
# Epoch 00001: val_accuracy improved from -inf to 0.78000, saving model to ./models/tree_2/model_root_f1_1_1_1/folder2\model.h5
# Epoch 2/30
# 50/50 [==============================] - 8s 150ms/step - loss: 0.5393 - accuracy: 0.7497 - val_loss: 0.4800 - val_accuracy: 0.7800
#
# Epoch 00002: val_accuracy did not improve from 0.78000
# Epoch 3/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.4992 - accuracy: 0.7710 - val_loss: 0.4822 - val_accuracy: 0.7867
#
# Epoch 00003: val_accuracy improved from 0.78000 to 0.78667, saving model to ./models/tree_2/model_root_f1_1_1_1/folder2\model.h5
# Epoch 4/30
# 50/50 [==============================] - 9s 188ms/step - loss: 0.5020 - accuracy: 0.7789 - val_loss: 0.4722 - val_accuracy: 0.7844
#
# Epoch 00004: val_accuracy did not improve from 0.78667
# Epoch 5/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.4883 - accuracy: 0.7795 - val_loss: 0.4436 - val_accuracy: 0.8022
#
# Epoch 00005: val_accuracy improved from 0.78667 to 0.80222, saving model to ./models/tree_2/model_root_f1_1_1_1/folder2\model.h5
# Epoch 6/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.4602 - accuracy: 0.7989 - val_loss: 0.4328 - val_accuracy: 0.8200
#
# Epoch 00006: val_accuracy improved from 0.80222 to 0.82000, saving model to ./models/tree_2/model_root_f1_1_1_1/folder2\model.h5
# Epoch 7/30
# 50/50 [==============================] - 8s 152ms/step - loss: 0.4478 - accuracy: 0.8107 - val_loss: 0.4038 - val_accuracy: 0.8333
#
# Epoch 00007: val_accuracy improved from 0.82000 to 0.83333, saving model to ./models/tree_2/model_root_f1_1_1_1/folder2\model.h5
# Epoch 8/30
# 50/50 [==============================] - 8s 153ms/step - loss: 0.4278 - accuracy: 0.8154 - val_loss: 0.4253 - val_accuracy: 0.8200
#
# Epoch 00008: val_accuracy did not improve from 0.83333
# Epoch 9/30
# 50/50 [==============================] - 8s 152ms/step - loss: 0.4212 - accuracy: 0.8231 - val_loss: 0.3997 - val_accuracy: 0.8311
#
# Epoch 00009: val_accuracy did not improve from 0.83333
# Epoch 10/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.3810 - accuracy: 0.8424 - val_loss: 0.3862 - val_accuracy: 0.8533
#
# Epoch 00010: val_accuracy improved from 0.83333 to 0.85333, saving model to ./models/tree_2/model_root_f1_1_1_1/folder2\model.h5
# Epoch 11/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.3677 - accuracy: 0.8501 - val_loss: 0.4008 - val_accuracy: 0.8378
#
# Epoch 00011: val_accuracy did not improve from 0.85333
# Epoch 12/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.3467 - accuracy: 0.8609 - val_loss: 0.4090 - val_accuracy: 0.8422
#
# Epoch 00012: val_accuracy did not improve from 0.85333
# Epoch 13/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.3124 - accuracy: 0.8733 - val_loss: 0.4260 - val_accuracy: 0.8244
#
# Epoch 00013: val_accuracy did not improve from 0.85333
# Epoch 14/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.2667 - accuracy: 0.8961 - val_loss: 0.4963 - val_accuracy: 0.7933
#
# Epoch 00014: val_accuracy did not improve from 0.85333
# Epoch 15/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.2120 - accuracy: 0.9171 - val_loss: 0.5071 - val_accuracy: 0.8156
#
# Epoch 00015: val_accuracy did not improve from 0.85333
# Epoch 16/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.1773 - accuracy: 0.9263 - val_loss: 0.6421 - val_accuracy: 0.8133
#
# Epoch 00016: val_accuracy did not improve from 0.85333
# Epoch 17/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.1385 - accuracy: 0.9498 - val_loss: 0.7220 - val_accuracy: 0.7333
#
# Epoch 00017: val_accuracy did not improve from 0.85333
# Epoch 18/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0963 - accuracy: 0.9670 - val_loss: 0.9020 - val_accuracy: 0.8244
#
# Epoch 00018: val_accuracy did not improve from 0.85333
# Epoch 19/30
# 50/50 [==============================] - 8s 152ms/step - loss: 0.0718 - accuracy: 0.9765 - val_loss: 1.1252 - val_accuracy: 0.8111
#
# Epoch 00019: val_accuracy did not improve from 0.85333
# Epoch 20/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0731 - accuracy: 0.9771 - val_loss: 0.9484 - val_accuracy: 0.8111
#
# Epoch 00020: val_accuracy did not improve from 0.85333
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0221 - accuracy: 0.9978 - val_loss: 1.0096 - val_accuracy: 0.8000
#
# Epoch 00021: val_accuracy did not improve from 0.85333
# Epoch 22/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 1.0901 - val_accuracy: 0.7911
#
# Epoch 00022: val_accuracy did not improve from 0.85333
# Epoch 23/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.1800 - val_accuracy: 0.7956
#
# Epoch 00023: val_accuracy did not improve from 0.85333
# Epoch 24/30
# 50/50 [==============================] - 8s 152ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.2480 - val_accuracy: 0.7978
#
# Epoch 00024: val_accuracy did not improve from 0.85333
# Epoch 25/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.2531 - val_accuracy: 0.7889
#
# Epoch 00025: val_accuracy did not improve from 0.85333
# Epoch 26/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.3004 - val_accuracy: 0.7867
#
# Epoch 00026: val_accuracy did not improve from 0.85333
# Epoch 27/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.3622 - val_accuracy: 0.7933
#
# Epoch 00027: val_accuracy did not improve from 0.85333
# Epoch 28/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.4004 - val_accuracy: 0.7933
#
# Epoch 00028: val_accuracy did not improve from 0.85333
# Epoch 29/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.4082 - val_accuracy: 0.7911
#
# Epoch 00029: val_accuracy did not improve from 0.85333
# Epoch 30/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.4331 - val_accuracy: 0.7911
#
# Epoch 00030: val_accuracy did not improve from 0.85333
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['International'], ['Electronic', 'Experimental', 'Pop']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 9s 156ms/step - loss: 1.8172 - accuracy: 0.7097 - val_loss: 0.5691 - val_accuracy: 0.7622
#
# Epoch 00001: val_accuracy improved from -inf to 0.76222, saving model to ./models/tree_2/model_root_f1_1_1_1/folder3\model.h5
# Epoch 2/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.5714 - accuracy: 0.7481 - val_loss: 0.5500 - val_accuracy: 0.7622
#
# Epoch 00002: val_accuracy did not improve from 0.76222
# Epoch 3/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.5591 - accuracy: 0.7481 - val_loss: 0.5828 - val_accuracy: 0.7622
#
# Epoch 00003: val_accuracy did not improve from 0.76222
# Epoch 4/30
# 50/50 [==============================] - 8s 150ms/step - loss: 0.5500 - accuracy: 0.7459 - val_loss: 0.5091 - val_accuracy: 0.7711
#
# Epoch 00004: val_accuracy improved from 0.76222 to 0.77111, saving model to ./models/tree_2/model_root_f1_1_1_1/folder3\model.h5
# Epoch 5/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.5290 - accuracy: 0.7583 - val_loss: 0.5015 - val_accuracy: 0.7800
#
# Epoch 00005: val_accuracy improved from 0.77111 to 0.78000, saving model to ./models/tree_2/model_root_f1_1_1_1/folder3\model.h5
# Epoch 6/30
# 50/50 [==============================] - 8s 150ms/step - loss: 0.5143 - accuracy: 0.7656 - val_loss: 0.5786 - val_accuracy: 0.7756
#
# Epoch 00006: val_accuracy did not improve from 0.78000
# Epoch 7/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.4973 - accuracy: 0.7843 - val_loss: 0.4275 - val_accuracy: 0.8200
#
# Epoch 00007: val_accuracy improved from 0.78000 to 0.82000, saving model to ./models/tree_2/model_root_f1_1_1_1/folder3\model.h5
# Epoch 8/30
# 50/50 [==============================] - 8s 150ms/step - loss: 0.4423 - accuracy: 0.8069 - val_loss: 0.4169 - val_accuracy: 0.8311
#
# Epoch 00008: val_accuracy improved from 0.82000 to 0.83111, saving model to ./models/tree_2/model_root_f1_1_1_1/folder3\model.h5
# Epoch 9/30
# 50/50 [==============================] - 8s 150ms/step - loss: 0.4307 - accuracy: 0.8145 - val_loss: 0.4227 - val_accuracy: 0.8356
#
# Epoch 00009: val_accuracy improved from 0.83111 to 0.83556, saving model to ./models/tree_2/model_root_f1_1_1_1/folder3\model.h5
# Epoch 10/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.4276 - accuracy: 0.8126 - val_loss: 0.4151 - val_accuracy: 0.8244
#
# Epoch 00010: val_accuracy did not improve from 0.83556
# Epoch 11/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.4118 - accuracy: 0.8247 - val_loss: 0.4341 - val_accuracy: 0.8089
#
# Epoch 00011: val_accuracy did not improve from 0.83556
# Epoch 12/30
# 50/50 [==============================] - 8s 150ms/step - loss: 0.4055 - accuracy: 0.8205 - val_loss: 0.4933 - val_accuracy: 0.8333
#
# Epoch 00012: val_accuracy did not improve from 0.83556
# Epoch 13/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.3845 - accuracy: 0.8367 - val_loss: 0.3644 - val_accuracy: 0.8444
#
# Epoch 00013: val_accuracy improved from 0.83556 to 0.84444, saving model to ./models/tree_2/model_root_f1_1_1_1/folder3\model.h5
# Epoch 14/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.6305 - accuracy: 0.7757 - val_loss: 0.6332 - val_accuracy: 0.6578
#
# Epoch 00014: val_accuracy did not improve from 0.84444
# Epoch 15/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.6170 - accuracy: 0.7306 - val_loss: 0.5639 - val_accuracy: 0.7622
#
# Epoch 00015: val_accuracy did not improve from 0.84444
# Epoch 16/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.5792 - accuracy: 0.7481 - val_loss: 0.5552 - val_accuracy: 0.7622
#
# Epoch 00016: val_accuracy did not improve from 0.84444
# Epoch 17/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.5640 - accuracy: 0.7481 - val_loss: 0.5480 - val_accuracy: 0.7622
#
# Epoch 00017: val_accuracy did not improve from 0.84444
# Epoch 18/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.5738 - accuracy: 0.7481 - val_loss: 0.5522 - val_accuracy: 0.7622
#
# Epoch 00018: val_accuracy did not improve from 0.84444
# Epoch 19/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.5439 - accuracy: 0.7481 - val_loss: 0.5209 - val_accuracy: 0.7622
#
# Epoch 00019: val_accuracy did not improve from 0.84444
# Epoch 20/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.5056 - accuracy: 0.7713 - val_loss: 0.4289 - val_accuracy: 0.8289
#
# Epoch 00020: val_accuracy did not improve from 0.84444
# Epoch 21/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.4402 - accuracy: 0.8040 - val_loss: 0.4329 - val_accuracy: 0.8156
#
# Epoch 00021: val_accuracy did not improve from 0.84444
# Epoch 22/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.4510 - accuracy: 0.8075 - val_loss: 0.4177 - val_accuracy: 0.8267
#
# Epoch 00022: val_accuracy did not improve from 0.84444
# Epoch 23/30
# 50/50 [==============================] - 8s 150ms/step - loss: 0.4234 - accuracy: 0.8262 - val_loss: 0.4024 - val_accuracy: 0.8311
#
# Epoch 00023: val_accuracy did not improve from 0.84444
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 24/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.4003 - accuracy: 0.8297 - val_loss: 0.4032 - val_accuracy: 0.8444
#
# Epoch 00024: val_accuracy did not improve from 0.84444
# Epoch 25/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.3917 - accuracy: 0.8355 - val_loss: 0.3914 - val_accuracy: 0.8289
#
# Epoch 00025: val_accuracy did not improve from 0.84444
# Epoch 26/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.3894 - accuracy: 0.8409 - val_loss: 0.4065 - val_accuracy: 0.8244
#
# Epoch 00026: val_accuracy did not improve from 0.84444
# Epoch 27/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.3877 - accuracy: 0.8389 - val_loss: 0.3830 - val_accuracy: 0.8556
#
# Epoch 00027: val_accuracy improved from 0.84444 to 0.85556, saving model to ./models/tree_2/model_root_f1_1_1_1/folder3\model.h5
# Epoch 28/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.3871 - accuracy: 0.8383 - val_loss: 0.4232 - val_accuracy: 0.8133
#
# Epoch 00028: val_accuracy did not improve from 0.85556
# Epoch 29/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.3844 - accuracy: 0.8428 - val_loss: 0.3950 - val_accuracy: 0.8311
#
# Epoch 00029: val_accuracy did not improve from 0.85556
# Epoch 30/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.3846 - accuracy: 0.8380 - val_loss: 0.3984 - val_accuracy: 0.8267
#
# Epoch 00030: val_accuracy did not improve from 0.85556
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Pop'], ['Electronic', 'Experimental', 'International']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 8s 157ms/step - loss: 1.3124 - accuracy: 0.7084 - val_loss: 0.5583 - val_accuracy: 0.7578
#
# Epoch 00001: val_accuracy improved from -inf to 0.75778, saving model to ./models/tree_2/model_root_f1_1_1_1/folder4\model.h5
# Epoch 2/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.5699 - accuracy: 0.7487 - val_loss: 0.5470 - val_accuracy: 0.7578
#
# Epoch 00002: val_accuracy did not improve from 0.75778
# Epoch 3/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.5610 - accuracy: 0.7487 - val_loss: 0.5491 - val_accuracy: 0.7578
#
# Epoch 00003: val_accuracy did not improve from 0.75778
# Epoch 4/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.5536 - accuracy: 0.7487 - val_loss: 0.5495 - val_accuracy: 0.7578
#
# Epoch 00004: val_accuracy did not improve from 0.75778
# Epoch 5/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.5363 - accuracy: 0.7478 - val_loss: 0.5278 - val_accuracy: 0.7578
#
# Epoch 00005: val_accuracy did not improve from 0.75778
# Epoch 6/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.5354 - accuracy: 0.7478 - val_loss: 0.5429 - val_accuracy: 0.7511
#
# Epoch 00006: val_accuracy did not improve from 0.75778
# Epoch 7/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.5495 - accuracy: 0.7468 - val_loss: 0.5467 - val_accuracy: 0.7511
#
# Epoch 00007: val_accuracy did not improve from 0.75778
# Epoch 8/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.5462 - accuracy: 0.7386 - val_loss: 0.5669 - val_accuracy: 0.7578
#
# Epoch 00008: val_accuracy did not improve from 0.75778
# Epoch 9/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.5264 - accuracy: 0.7430 - val_loss: 0.5207 - val_accuracy: 0.7533
#
# Epoch 00009: val_accuracy did not improve from 0.75778
# Epoch 10/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.5198 - accuracy: 0.7465 - val_loss: 0.4996 - val_accuracy: 0.7467
#
# Epoch 00010: val_accuracy did not improve from 0.75778
# Epoch 11/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.5090 - accuracy: 0.7478 - val_loss: 0.5114 - val_accuracy: 0.7467
#
# Epoch 00011: val_accuracy did not improve from 0.75778
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 12/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.4830 - accuracy: 0.7633 - val_loss: 0.4806 - val_accuracy: 0.7778
#
# Epoch 00012: val_accuracy improved from 0.75778 to 0.77778, saving model to ./models/tree_2/model_root_f1_1_1_1/folder4\model.h5
# Epoch 13/30
# 50/50 [==============================] - 7s 149ms/step - loss: 0.4743 - accuracy: 0.7703 - val_loss: 0.4950 - val_accuracy: 0.7467
#
# Epoch 00013: val_accuracy did not improve from 0.77778
# Epoch 14/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.4706 - accuracy: 0.7799 - val_loss: 0.4949 - val_accuracy: 0.7644
#
# Epoch 00014: val_accuracy did not improve from 0.77778
# Epoch 15/30
# 50/50 [==============================] - 8s 152ms/step - loss: 0.4615 - accuracy: 0.7840 - val_loss: 0.4798 - val_accuracy: 0.7800
#
# Epoch 00015: val_accuracy improved from 0.77778 to 0.78000, saving model to ./models/tree_2/model_root_f1_1_1_1/folder4\model.h5
# Epoch 16/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.4580 - accuracy: 0.7907 - val_loss: 0.4952 - val_accuracy: 0.7622
#
# Epoch 00016: val_accuracy did not improve from 0.78000
# Epoch 17/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.4412 - accuracy: 0.7989 - val_loss: 0.5123 - val_accuracy: 0.7511
#
# Epoch 00017: val_accuracy did not improve from 0.78000
# Epoch 18/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.4527 - accuracy: 0.7907 - val_loss: 0.4817 - val_accuracy: 0.7578
#
# Epoch 00018: val_accuracy did not improve from 0.78000
# Epoch 19/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.4231 - accuracy: 0.8135 - val_loss: 0.5540 - val_accuracy: 0.7444
#
# Epoch 00019: val_accuracy did not improve from 0.78000
# Epoch 20/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.4053 - accuracy: 0.8237 - val_loss: 0.5124 - val_accuracy: 0.7867
#
# Epoch 00020: val_accuracy improved from 0.78000 to 0.78667, saving model to ./models/tree_2/model_root_f1_1_1_1/folder4\model.h5
# Epoch 21/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.3883 - accuracy: 0.8272 - val_loss: 0.5077 - val_accuracy: 0.7578
#
# Epoch 00021: val_accuracy did not improve from 0.78667
# Epoch 22/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.3755 - accuracy: 0.8323 - val_loss: 0.4948 - val_accuracy: 0.7711
#
# Epoch 00022: val_accuracy did not improve from 0.78667
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 23/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.3345 - accuracy: 0.8637 - val_loss: 0.5364 - val_accuracy: 0.7756
#
# Epoch 00023: val_accuracy did not improve from 0.78667
# Epoch 24/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.3171 - accuracy: 0.8634 - val_loss: 0.5411 - val_accuracy: 0.7356
#
# Epoch 00024: val_accuracy did not improve from 0.78667
# Epoch 25/30
# 50/50 [==============================] - 8s 150ms/step - loss: 0.3030 - accuracy: 0.8771 - val_loss: 0.5384 - val_accuracy: 0.7756
#
# Epoch 00025: val_accuracy did not improve from 0.78667
# Epoch 26/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.2806 - accuracy: 0.8850 - val_loss: 0.5350 - val_accuracy: 0.7756
#
# Epoch 00026: val_accuracy did not improve from 0.78667
# Epoch 27/30
# 50/50 [==============================] - 7s 150ms/step - loss: 0.2678 - accuracy: 0.8936 - val_loss: 0.5940 - val_accuracy: 0.7533
#
# Epoch 00027: val_accuracy did not improve from 0.78667
# Epoch 28/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.2499 - accuracy: 0.8993 - val_loss: 0.6247 - val_accuracy: 0.7511
#
# Epoch 00028: val_accuracy did not improve from 0.78667
# Epoch 29/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.2206 - accuracy: 0.9145 - val_loss: 0.6421 - val_accuracy: 0.7222
#
# Epoch 00029: val_accuracy did not improve from 0.78667
# Epoch 30/30
# 50/50 [==============================] - 8s 151ms/step - loss: 0.1972 - accuracy: 0.9282 - val_loss: 0.5965 - val_accuracy: 0.7511
#
# Epoch 00030: val_accuracy did not improve from 0.78667
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
