# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7}
dict_genres = {'Electronic':0, 'Experimental':1, 'Pop' :6}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Electronic', 1: 'Experimental', 6: 'Pop'}

# %%
npzfile = np.load('data/shuffled_train.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394,)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=8).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((2398, 640, 128), (2398, 8))

# %%
npzfile = np.load('data/shuffled_valid.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=8).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((300, 640, 128), (300, 8))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Pop

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

BATCH_SIZE = 64
EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 640
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_2/model_root_f1_1_1_1_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_2/model_root_f1_1_1_1_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
def create_split(elem, c):
    splits = []
    for i in range(c):
        equal = False
        np.random.shuffle(elem)
        new_split = list(chunks(elem, int(len(elem)/2)))
        for split in splits:
            if set(new_split[0]) == set(split[0]) and set(new_split[0]) == set(split[1]):
                equal = True
                break
            
        if equal:
            i-=1
            continue
        
        splits.append(new_split)
        
    return splits

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 3

kfold = KFold(n_splits=8, shuffle=True)
genre_splits = create_split(list(dict_genres.values()), num_splits)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    dict_genres_list = list(dict_genres.values())
    split = [[dict_genres_list.pop(fold_no - 1)], dict_genres_list]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)

    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Electronic'], ['Experimental', 'Pop']]
# Building model...
# Training...
# Epoch 1/30
# 37/37 [==============================] - 19s 228ms/step - loss: 1.4832 - accuracy: 0.6076 - val_loss: 0.6519 - val_accuracy: 0.7101
#
# Epoch 00001: val_accuracy improved from -inf to 0.71006, saving model to ./models/tree_2/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 2/30
# 37/37 [==============================] - 6s 149ms/step - loss: 0.6442 - accuracy: 0.6614 - val_loss: 0.5975 - val_accuracy: 0.7101
#
# Epoch 00002: val_accuracy did not improve from 0.71006
# Epoch 3/30
# 37/37 [==============================] - 5s 148ms/step - loss: 0.6109 - accuracy: 0.6814 - val_loss: 0.5539 - val_accuracy: 0.7781
#
# Epoch 00003: val_accuracy improved from 0.71006 to 0.77811, saving model to ./models/tree_2/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 4/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.5245 - accuracy: 0.7691 - val_loss: 0.5915 - val_accuracy: 0.7485
#
# Epoch 00004: val_accuracy did not improve from 0.77811
# Epoch 5/30
# 37/37 [==============================] - 5s 149ms/step - loss: 0.5117 - accuracy: 0.7644 - val_loss: 0.5193 - val_accuracy: 0.8018
#
# Epoch 00005: val_accuracy improved from 0.77811 to 0.80178, saving model to ./models/tree_2/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 6/30
# 37/37 [==============================] - 5s 149ms/step - loss: 0.4723 - accuracy: 0.7822 - val_loss: 0.4848 - val_accuracy: 0.7988
#
# Epoch 00006: val_accuracy did not improve from 0.80178
# Epoch 7/30
# 37/37 [==============================] - 5s 148ms/step - loss: 0.4684 - accuracy: 0.7979 - val_loss: 0.5021 - val_accuracy: 0.7988
#
# Epoch 00007: val_accuracy did not improve from 0.80178
# Epoch 8/30
# 37/37 [==============================] - 5s 149ms/step - loss: 0.4581 - accuracy: 0.7945 - val_loss: 0.5641 - val_accuracy: 0.7663
#
# Epoch 00008: val_accuracy did not improve from 0.80178
# Epoch 9/30
# 37/37 [==============================] - 6s 149ms/step - loss: 0.4622 - accuracy: 0.7903 - val_loss: 0.4706 - val_accuracy: 0.7959
#
# Epoch 00009: val_accuracy did not improve from 0.80178
# Epoch 10/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.4283 - accuracy: 0.8136 - val_loss: 0.4722 - val_accuracy: 0.8047
#
# Epoch 00010: val_accuracy improved from 0.80178 to 0.80473, saving model to ./models/tree_2/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 11/30
# 37/37 [==============================] - 5s 149ms/step - loss: 0.4278 - accuracy: 0.8110 - val_loss: 0.5080 - val_accuracy: 0.8018
#
# Epoch 00011: val_accuracy did not improve from 0.80473
# Epoch 12/30
# 37/37 [==============================] - 6s 149ms/step - loss: 0.4024 - accuracy: 0.8305 - val_loss: 0.4620 - val_accuracy: 0.8018
#
# Epoch 00012: val_accuracy did not improve from 0.80473
# Epoch 13/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.3914 - accuracy: 0.8309 - val_loss: 0.4691 - val_accuracy: 0.7870
#
# Epoch 00013: val_accuracy did not improve from 0.80473
# Epoch 14/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.3837 - accuracy: 0.8335 - val_loss: 0.5106 - val_accuracy: 0.8077
#
# Epoch 00014: val_accuracy improved from 0.80473 to 0.80769, saving model to ./models/tree_2/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 15/30
# 37/37 [==============================] - 6s 149ms/step - loss: 0.3814 - accuracy: 0.8339 - val_loss: 0.5133 - val_accuracy: 0.8077
#
# Epoch 00015: val_accuracy did not improve from 0.80769
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 16/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.3476 - accuracy: 0.8475 - val_loss: 0.5003 - val_accuracy: 0.8107
#
# Epoch 00016: val_accuracy improved from 0.80769 to 0.81065, saving model to ./models/tree_2/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 17/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.3106 - accuracy: 0.8758 - val_loss: 0.5125 - val_accuracy: 0.7959
#
# Epoch 00017: val_accuracy did not improve from 0.81065
# Epoch 18/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.2874 - accuracy: 0.8843 - val_loss: 0.5056 - val_accuracy: 0.7929
#
# Epoch 00018: val_accuracy did not improve from 0.81065
# Epoch 19/30
# 37/37 [==============================] - 6s 152ms/step - loss: 0.2697 - accuracy: 0.8877 - val_loss: 0.5892 - val_accuracy: 0.7751
#
# Epoch 00019: val_accuracy did not improve from 0.81065
# Epoch 20/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.2641 - accuracy: 0.8915 - val_loss: 0.5319 - val_accuracy: 0.7840
#
# Epoch 00020: val_accuracy did not improve from 0.81065
# Epoch 21/30
# 37/37 [==============================] - 6s 149ms/step - loss: 0.2311 - accuracy: 0.9119 - val_loss: 0.5367 - val_accuracy: 0.7899
#
# Epoch 00021: val_accuracy did not improve from 0.81065
# Epoch 22/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.2173 - accuracy: 0.9114 - val_loss: 0.5853 - val_accuracy: 0.8107
#
# Epoch 00022: val_accuracy did not improve from 0.81065
# Epoch 23/30
# 37/37 [==============================] - 6s 149ms/step - loss: 0.2024 - accuracy: 0.9263 - val_loss: 0.7029 - val_accuracy: 0.7870
#
# Epoch 00023: val_accuracy did not improve from 0.81065
# Epoch 24/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.1809 - accuracy: 0.9288 - val_loss: 0.7397 - val_accuracy: 0.7751
#
# Epoch 00024: val_accuracy did not improve from 0.81065
# Epoch 25/30
# 37/37 [==============================] - 6s 151ms/step - loss: 0.1525 - accuracy: 0.9424 - val_loss: 0.7294 - val_accuracy: 0.7870
#
# Epoch 00025: val_accuracy did not improve from 0.81065
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 26/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.1155 - accuracy: 0.9636 - val_loss: 0.7496 - val_accuracy: 0.7988
#
# Epoch 00026: val_accuracy did not improve from 0.81065
# Epoch 27/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0977 - accuracy: 0.9699 - val_loss: 0.7974 - val_accuracy: 0.7870
#
# Epoch 00027: val_accuracy did not improve from 0.81065
# Epoch 28/30
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0866 - accuracy: 0.9716 - val_loss: 0.8557 - val_accuracy: 0.7663
#
# Epoch 00028: val_accuracy did not improve from 0.81065
# Epoch 29/30
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0829 - accuracy: 0.9750 - val_loss: 0.9331 - val_accuracy: 0.7781
#
# Epoch 00029: val_accuracy did not improve from 0.81065
# Epoch 30/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.0666 - accuracy: 0.9822 - val_loss: 1.0139 - val_accuracy: 0.7840
#
# Epoch 00030: val_accuracy did not improve from 0.81065
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Experimental'], ['Electronic', 'Pop']]
# Building model...
# Training...
# Epoch 1/30
# 37/37 [==============================] - 6s 158ms/step - loss: 1.3552 - accuracy: 0.6153 - val_loss: 0.6444 - val_accuracy: 0.6538
#
# Epoch 00001: val_accuracy improved from -inf to 0.65385, saving model to ./models/tree_2/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 2/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.6207 - accuracy: 0.6691 - val_loss: 0.6219 - val_accuracy: 0.6538
#
# Epoch 00002: val_accuracy did not improve from 0.65385
# Epoch 3/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.6005 - accuracy: 0.6860 - val_loss: 0.6298 - val_accuracy: 0.6568
#
# Epoch 00003: val_accuracy improved from 0.65385 to 0.65680, saving model to ./models/tree_2/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 4/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.5892 - accuracy: 0.6780 - val_loss: 0.6221 - val_accuracy: 0.7249
#
# Epoch 00004: val_accuracy improved from 0.65680 to 0.72485, saving model to ./models/tree_2/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 5/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.5705 - accuracy: 0.7030 - val_loss: 0.5594 - val_accuracy: 0.7308
#
# Epoch 00005: val_accuracy improved from 0.72485 to 0.73077, saving model to ./models/tree_2/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 6/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.5123 - accuracy: 0.7631 - val_loss: 0.5217 - val_accuracy: 0.7692
#
# Epoch 00006: val_accuracy improved from 0.73077 to 0.76923, saving model to ./models/tree_2/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 7/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.5082 - accuracy: 0.7665 - val_loss: 0.5517 - val_accuracy: 0.7426
#
# Epoch 00007: val_accuracy did not improve from 0.76923
# Epoch 8/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.4838 - accuracy: 0.7792 - val_loss: 0.4789 - val_accuracy: 0.7929
#
# Epoch 00008: val_accuracy improved from 0.76923 to 0.79290, saving model to ./models/tree_2/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 9/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.4585 - accuracy: 0.7907 - val_loss: 0.5049 - val_accuracy: 0.7574
#
# Epoch 00009: val_accuracy did not improve from 0.79290
# Epoch 10/30
# 37/37 [==============================] - 6s 151ms/step - loss: 0.4338 - accuracy: 0.8157 - val_loss: 0.6677 - val_accuracy: 0.6243
#
# Epoch 00010: val_accuracy did not improve from 0.79290
# Epoch 11/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.4240 - accuracy: 0.8140 - val_loss: 0.5986 - val_accuracy: 0.7604
#
# Epoch 00011: val_accuracy did not improve from 0.79290
# Epoch 12/30
# 37/37 [==============================] - 6s 151ms/step - loss: 0.3893 - accuracy: 0.8373 - val_loss: 0.5586 - val_accuracy: 0.7633
#
# Epoch 00012: val_accuracy did not improve from 0.79290
# Epoch 13/30
# 37/37 [==============================] - 6s 151ms/step - loss: 0.3634 - accuracy: 0.8411 - val_loss: 0.5195 - val_accuracy: 0.8107
#
# Epoch 00013: val_accuracy improved from 0.79290 to 0.81065, saving model to ./models/tree_2/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 14/30
# 37/37 [==============================] - 6s 151ms/step - loss: 0.3116 - accuracy: 0.8674 - val_loss: 0.5927 - val_accuracy: 0.7988
#
# Epoch 00014: val_accuracy did not improve from 0.81065
# Epoch 15/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.2670 - accuracy: 0.8881 - val_loss: 0.5898 - val_accuracy: 0.7751
#
# Epoch 00015: val_accuracy did not improve from 0.81065
# Epoch 16/30
# 37/37 [==============================] - 6s 151ms/step - loss: 0.2539 - accuracy: 0.9008 - val_loss: 0.5981 - val_accuracy: 0.7959
#
# Epoch 00016: val_accuracy did not improve from 0.81065
# Epoch 17/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.2001 - accuracy: 0.9242 - val_loss: 0.6565 - val_accuracy: 0.7663
#
# Epoch 00017: val_accuracy did not improve from 0.81065
# Epoch 18/30
# 37/37 [==============================] - 6s 151ms/step - loss: 0.1357 - accuracy: 0.9538 - val_loss: 0.8223 - val_accuracy: 0.7308
#
# Epoch 00018: val_accuracy did not improve from 0.81065
# Epoch 19/30
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0931 - accuracy: 0.9699 - val_loss: 0.9288 - val_accuracy: 0.7130
#
# Epoch 00019: val_accuracy did not improve from 0.81065
# Epoch 20/30
# 37/37 [==============================] - 6s 151ms/step - loss: 0.1085 - accuracy: 0.9581 - val_loss: 0.8191 - val_accuracy: 0.7604
#
# Epoch 00020: val_accuracy did not improve from 0.81065
# Epoch 21/30
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0638 - accuracy: 0.9822 - val_loss: 0.9357 - val_accuracy: 0.7574
#
# Epoch 00021: val_accuracy did not improve from 0.81065
# Epoch 22/30
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0304 - accuracy: 0.9941 - val_loss: 1.0475 - val_accuracy: 0.7751
#
# Epoch 00022: val_accuracy did not improve from 0.81065
# Epoch 23/30
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0258 - accuracy: 0.9945 - val_loss: 1.0357 - val_accuracy: 0.7574
#
# Epoch 00023: val_accuracy did not improve from 0.81065
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 24/30
# 37/37 [==============================] - 7s 184ms/step - loss: 0.0146 - accuracy: 0.9975 - val_loss: 1.1219 - val_accuracy: 0.7781
#
# Epoch 00024: val_accuracy did not improve from 0.81065
# Epoch 25/30
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0108 - accuracy: 0.9992 - val_loss: 1.2261 - val_accuracy: 0.7811
#
# Epoch 00025: val_accuracy did not improve from 0.81065
# Epoch 26/30
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0054 - accuracy: 0.9996 - val_loss: 1.2559 - val_accuracy: 0.7633
#
# Epoch 00026: val_accuracy did not improve from 0.81065
# Epoch 27/30
# 37/37 [==============================] - 6s 152ms/step - loss: 0.0037 - accuracy: 0.9996 - val_loss: 1.2962 - val_accuracy: 0.7663
#
# Epoch 00027: val_accuracy did not improve from 0.81065
# Epoch 28/30
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 1.3407 - val_accuracy: 0.7604
#
# Epoch 00028: val_accuracy did not improve from 0.81065
# Epoch 29/30
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 1.3695 - val_accuracy: 0.7840
#
# Epoch 00029: val_accuracy did not improve from 0.81065
# Epoch 30/30
# 37/37 [==============================] - 6s 151ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 1.4044 - val_accuracy: 0.7663
#
# Epoch 00030: val_accuracy did not improve from 0.81065
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Pop'], ['Electronic', 'Experimental']]
# Building model...
# Training...
# Epoch 1/30
# 37/37 [==============================] - 9s 237ms/step - loss: 1.4230 - accuracy: 0.6260 - val_loss: 0.6270 - val_accuracy: 0.6973
#
# Epoch 00001: val_accuracy improved from -inf to 0.69733, saving model to ./models/tree_2/model_root_f1_1_1_1_1/folder3\model.h5
# Epoch 2/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.6472 - accuracy: 0.6620 - val_loss: 0.6067 - val_accuracy: 0.6973
#
# Epoch 00002: val_accuracy did not improve from 0.69733
# Epoch 3/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.6391 - accuracy: 0.6620 - val_loss: 0.6193 - val_accuracy: 0.6973
#
# Epoch 00003: val_accuracy did not improve from 0.69733
# Epoch 4/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.6386 - accuracy: 0.6620 - val_loss: 0.6105 - val_accuracy: 0.6973
#
# Epoch 00004: val_accuracy did not improve from 0.69733
# Epoch 5/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.6389 - accuracy: 0.6620 - val_loss: 0.6058 - val_accuracy: 0.6973
#
# Epoch 00005: val_accuracy did not improve from 0.69733
# Epoch 6/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.6349 - accuracy: 0.6586 - val_loss: 0.6468 - val_accuracy: 0.7122
#
# Epoch 00006: val_accuracy improved from 0.69733 to 0.71217, saving model to ./models/tree_2/model_root_f1_1_1_1_1/folder3\model.h5
# Epoch 7/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.6087 - accuracy: 0.6692 - val_loss: 0.5298 - val_accuracy: 0.6914
#
# Epoch 00007: val_accuracy did not improve from 0.71217
# Epoch 8/30
# 37/37 [==============================] - 6s 151ms/step - loss: 0.6101 - accuracy: 0.6557 - val_loss: 0.6349 - val_accuracy: 0.6973
#
# Epoch 00008: val_accuracy did not improve from 0.71217
# Epoch 9/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.7003 - accuracy: 0.6324 - val_loss: 0.6050 - val_accuracy: 0.6973
#
# Epoch 00009: val_accuracy did not improve from 0.71217
# Epoch 10/30
# 37/37 [==============================] - 6s 150ms/step - loss: 0.6389 - accuracy: 0.6620 - val_loss: 0.5994 - val_accuracy: 0.6973
#
# Epoch 00010: val_accuracy did not improve from 0.71217
# Epoch 11/30
# 37/37 [==============================] - 6s 149ms/step - loss: 0.6337 - accuracy: 0.6599 - val_loss: 0.6233 - val_accuracy: 0.6973
#
# Epoch 00011: val_accuracy did not improve from 0.71217
# Epoch 12/30
# 37/37 [==============================] - 5s 148ms/step - loss: 0.6611 - accuracy: 0.6620 - val_loss: 0.6107 - val_accuracy: 0.6973
#
# Epoch 00012: val_accuracy did not improve from 0.71217
# Epoch 13/30
# 37/37 [==============================] - 5s 149ms/step - loss: 0.6457 - accuracy: 0.6616 - val_loss: 0.6199 - val_accuracy: 0.6973
#
# Epoch 00013: val_accuracy did not improve from 0.71217
# Epoch 14/30
# 37/37 [==============================] - 5s 148ms/step - loss: 0.6416 - accuracy: 0.6620 - val_loss: 0.6132 - val_accuracy: 0.6973
#
# Epoch 00014: val_accuracy did not improve from 0.71217
# Epoch 15/30
# 37/37 [==============================] - 5s 147ms/step - loss: 0.6443 - accuracy: 0.6620 - val_loss: 0.6139 - val_accuracy: 0.6973
#
# Epoch 00015: val_accuracy did not improve from 0.71217
# Epoch 16/30
# 37/37 [==============================] - 5s 147ms/step - loss: 0.6399 - accuracy: 0.6620 - val_loss: 0.6202 - val_accuracy: 0.6973
#
# Epoch 00016: val_accuracy did not improve from 0.71217
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 17/30
# 37/37 [==============================] - 5s 148ms/step - loss: 0.6398 - accuracy: 0.6620 - val_loss: 0.6128 - val_accuracy: 0.6973
#
# Epoch 00017: val_accuracy did not improve from 0.71217
# Epoch 18/30
# 37/37 [==============================] - 6s 149ms/step - loss: 0.6495 - accuracy: 0.6624 - val_loss: 0.6150 - val_accuracy: 0.6973
#
# Epoch 00018: val_accuracy did not improve from 0.71217
# Epoch 19/30
# 37/37 [==============================] - 5s 148ms/step - loss: 0.6399 - accuracy: 0.6620 - val_loss: 0.6131 - val_accuracy: 0.6973
#
# Epoch 00019: val_accuracy did not improve from 0.71217
# Epoch 20/30
# 37/37 [==============================] - 6s 149ms/step - loss: 0.6406 - accuracy: 0.6620 - val_loss: 0.6159 - val_accuracy: 0.6973
#
# Epoch 00020: val_accuracy did not improve from 0.71217
# Epoch 21/30
# 37/37 [==============================] - 5s 148ms/step - loss: 0.6390 - accuracy: 0.6620 - val_loss: 0.6215 - val_accuracy: 0.6973
#
# Epoch 00021: val_accuracy did not improve from 0.71217
# Epoch 22/30
# 37/37 [==============================] - 5s 149ms/step - loss: 0.6448 - accuracy: 0.6620 - val_loss: 0.6170 - val_accuracy: 0.6973
#
# Epoch 00022: val_accuracy did not improve from 0.71217
# Epoch 23/30
# 37/37 [==============================] - 6s 149ms/step - loss: 0.6400 - accuracy: 0.6620 - val_loss: 0.6167 - val_accuracy: 0.6973
#
# Epoch 00023: val_accuracy did not improve from 0.71217
# Epoch 24/30
# 37/37 [==============================] - 5s 147ms/step - loss: 0.6409 - accuracy: 0.6616 - val_loss: 0.6173 - val_accuracy: 0.6973
#
# Epoch 00024: val_accuracy did not improve from 0.71217
# Epoch 25/30
# 37/37 [==============================] - 5s 147ms/step - loss: 0.6402 - accuracy: 0.6620 - val_loss: 0.6137 - val_accuracy: 0.6973
#
# Epoch 00025: val_accuracy did not improve from 0.71217
# Epoch 26/30
# 37/37 [==============================] - 5s 149ms/step - loss: 0.6412 - accuracy: 0.6620 - val_loss: 0.6142 - val_accuracy: 0.6973
#
# Epoch 00026: val_accuracy did not improve from 0.71217
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 27/30
# 37/37 [==============================] - 5s 146ms/step - loss: 0.6408 - accuracy: 0.6620 - val_loss: 0.6164 - val_accuracy: 0.6973
#
# Epoch 00027: val_accuracy did not improve from 0.71217
# Epoch 28/30
# 37/37 [==============================] - 5s 148ms/step - loss: 0.6399 - accuracy: 0.6620 - val_loss: 0.6148 - val_accuracy: 0.6973
#
# Epoch 00028: val_accuracy did not improve from 0.71217
# Epoch 29/30
# 37/37 [==============================] - 5s 147ms/step - loss: 0.6405 - accuracy: 0.6620 - val_loss: 0.6147 - val_accuracy: 0.6973
#
# Epoch 00029: val_accuracy did not improve from 0.71217
# Epoch 30/30
# 37/37 [==============================] - 5s 146ms/step - loss: 0.6399 - accuracy: 0.6620 - val_loss: 0.6167 - val_accuracy: 0.6973
#
# Epoch 00030: val_accuracy did not improve from 0.71217
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
