# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7}
dict_genres = {'Folk':2, 'Rock' :7}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {2: 'Folk', 7: 'Rock'}

# %%
npzfile = np.load('data/shuffled_train.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394,)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=8).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((1599, 640, 128), (1599, 8))

# %%
npzfile = np.load('data/shuffled_valid.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=8).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((200, 640, 128), (200, 8))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Folk

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 64
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=8
nb_filters2=16
nb_filters3=32
nb_filters4=64
ksize = (3,3)
pool_size= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, kernel_initializer = glorot_uniform(seed=9), name='conv_1')(layer)
    batch_1 = BatchNormalization(axis = 3)(conv_1)
    activ_1 = Activation('relu')(batch_1)
    pool_1 = MaxPooling2D(pool_size)(activ_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, kernel_initializer = glorot_uniform(seed=9), name='conv_2')(pool_1)
    batch_2 = BatchNormalization(axis = 3)(conv_2)
    activ_2 = Activation('relu')(batch_2)
    pool_2 = MaxPooling2D(pool_size)(activ_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, kernel_initializer = glorot_uniform(seed=9), name='conv_3')(pool_2)
    batch_3 = BatchNormalization(axis = 3)(conv_3)
    activ_3 = Activation('relu')(batch_3)
    pool_3 = MaxPooling2D(pool_size)(activ_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, kernel_initializer = glorot_uniform(seed=9), name='conv_4')(pool_3)
    batch_4 = BatchNormalization(axis = 3)(conv_4)
    activ_4 = Activation('relu')(batch_4)
    pool_4 = MaxPooling2D(pool_size)(activ_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds', kernel_initializer = glorot_uniform(seed=9))(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.00005)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 640
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_6/model_root_f2_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_6/model_root_f2_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
def create_split(elem, c):
    splits = []
    for i in range(c):
        equal = False
        np.random.shuffle(elem)
        new_split = list(chunks(elem, int(len(elem)/2)))
        for split in splits:
            if set(new_split[0]) == set(split[0]) and set(new_split[0]) == set(split[1]):
                equal = True
                break
            
        if equal:
            i-=1
            continue
        
        splits.append(new_split)
        
    return splits

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 1

kfold = KFold(n_splits=8, shuffle=True)
genre_splits = create_split(list(dict_genres.values()), num_splits)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)

    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Folk'], ['Rock']]
# Building model...
# Training...
# Epoch 1/30
# 25/25 [==============================] - 9s 101ms/step - loss: 0.5599 - accuracy: 0.7808 - val_loss: 0.9463 - val_accuracy: 0.4667
#
# Epoch 00001: val_accuracy improved from -inf to 0.46667, saving model to ./models/tree_6/model_root_f2_1/folder1\model.h5
# Epoch 2/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.4109 - accuracy: 0.8405 - val_loss: 0.6899 - val_accuracy: 0.4756
#
# Epoch 00002: val_accuracy improved from 0.46667 to 0.47556, saving model to ./models/tree_6/model_root_f2_1/folder1\model.h5
# Epoch 3/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.3713 - accuracy: 0.8431 - val_loss: 0.6143 - val_accuracy: 0.5911
#
# Epoch 00003: val_accuracy improved from 0.47556 to 0.59111, saving model to ./models/tree_6/model_root_f2_1/folder1\model.h5
# Epoch 4/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.3680 - accuracy: 0.8463 - val_loss: 0.5325 - val_accuracy: 0.7467
#
# Epoch 00004: val_accuracy improved from 0.59111 to 0.74667, saving model to ./models/tree_6/model_root_f2_1/folder1\model.h5
# Epoch 5/30
# 25/25 [==============================] - 2s 60ms/step - loss: 0.3457 - accuracy: 0.8551 - val_loss: 0.4699 - val_accuracy: 0.7911
#
# Epoch 00005: val_accuracy improved from 0.74667 to 0.79111, saving model to ./models/tree_6/model_root_f2_1/folder1\model.h5
# Epoch 6/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.2988 - accuracy: 0.8748 - val_loss: 0.4144 - val_accuracy: 0.8444
#
# Epoch 00006: val_accuracy improved from 0.79111 to 0.84444, saving model to ./models/tree_6/model_root_f2_1/folder1\model.h5
# Epoch 7/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.2992 - accuracy: 0.8723 - val_loss: 0.3881 - val_accuracy: 0.8489
#
# Epoch 00007: val_accuracy improved from 0.84444 to 0.84889, saving model to ./models/tree_6/model_root_f2_1/folder1\model.h5
# Epoch 8/30
# 25/25 [==============================] - 2s 62ms/step - loss: 0.2736 - accuracy: 0.8856 - val_loss: 0.3664 - val_accuracy: 0.8489
#
# Epoch 00008: val_accuracy did not improve from 0.84889
# Epoch 9/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.2669 - accuracy: 0.8907 - val_loss: 0.3504 - val_accuracy: 0.8667
#
# Epoch 00009: val_accuracy improved from 0.84889 to 0.86667, saving model to ./models/tree_6/model_root_f2_1/folder1\model.h5
# Epoch 10/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.2616 - accuracy: 0.8945 - val_loss: 0.3530 - val_accuracy: 0.8622
#
# Epoch 00010: val_accuracy did not improve from 0.86667
# Epoch 11/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.2415 - accuracy: 0.8983 - val_loss: 0.3806 - val_accuracy: 0.8356
#
# Epoch 00011: val_accuracy did not improve from 0.86667
# Epoch 12/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.2412 - accuracy: 0.8933 - val_loss: 0.3632 - val_accuracy: 0.8756
#
# Epoch 00012: val_accuracy improved from 0.86667 to 0.87556, saving model to ./models/tree_6/model_root_f2_1/folder1\model.h5
# Epoch 13/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.2202 - accuracy: 0.9072 - val_loss: 0.3564 - val_accuracy: 0.8711
#
# Epoch 00013: val_accuracy did not improve from 0.87556
# Epoch 14/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.2204 - accuracy: 0.9104 - val_loss: 0.3647 - val_accuracy: 0.8667
#
# Epoch 00014: val_accuracy did not improve from 0.87556
# Epoch 15/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.1918 - accuracy: 0.9295 - val_loss: 0.3684 - val_accuracy: 0.8711
#
# Epoch 00015: val_accuracy did not improve from 0.87556
# Epoch 16/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.1867 - accuracy: 0.9327 - val_loss: 0.3765 - val_accuracy: 0.8578
#
# Epoch 00016: val_accuracy did not improve from 0.87556
# Epoch 17/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.1724 - accuracy: 0.9441 - val_loss: 0.3746 - val_accuracy: 0.8578
#
# Epoch 00017: val_accuracy did not improve from 0.87556
# Epoch 18/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.1646 - accuracy: 0.9511 - val_loss: 0.3831 - val_accuracy: 0.8533
#
# Epoch 00018: val_accuracy did not improve from 0.87556
# Epoch 19/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.1590 - accuracy: 0.9454 - val_loss: 0.3799 - val_accuracy: 0.8578
#
# Epoch 00019: val_accuracy did not improve from 0.87556
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 20/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.1511 - accuracy: 0.9543 - val_loss: 0.3931 - val_accuracy: 0.8533
#
# Epoch 00020: val_accuracy did not improve from 0.87556
# Epoch 21/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.1460 - accuracy: 0.9574 - val_loss: 0.3839 - val_accuracy: 0.8667
#
# Epoch 00021: val_accuracy did not improve from 0.87556
# Epoch 22/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.1420 - accuracy: 0.9625 - val_loss: 0.3876 - val_accuracy: 0.8622
#
# Epoch 00022: val_accuracy did not improve from 0.87556
# Epoch 23/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.1405 - accuracy: 0.9587 - val_loss: 0.3893 - val_accuracy: 0.8622
#
# Epoch 00023: val_accuracy did not improve from 0.87556
# Epoch 24/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.1395 - accuracy: 0.9574 - val_loss: 0.3930 - val_accuracy: 0.8622
#
# Epoch 00024: val_accuracy did not improve from 0.87556
# Epoch 25/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.1338 - accuracy: 0.9619 - val_loss: 0.4037 - val_accuracy: 0.8533
#
# Epoch 00025: val_accuracy did not improve from 0.87556
# Epoch 26/30
# 25/25 [==============================] - 2s 62ms/step - loss: 0.1297 - accuracy: 0.9644 - val_loss: 0.3985 - val_accuracy: 0.8622
#
# Epoch 00026: val_accuracy did not improve from 0.87556
# Epoch 27/30
# 25/25 [==============================] - 2s 62ms/step - loss: 0.1293 - accuracy: 0.9682 - val_loss: 0.3964 - val_accuracy: 0.8667
#
# Epoch 00027: val_accuracy did not improve from 0.87556
# Epoch 28/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.1217 - accuracy: 0.9733 - val_loss: 0.4074 - val_accuracy: 0.8489
#
# Epoch 00028: val_accuracy did not improve from 0.87556
# Epoch 29/30
# 25/25 [==============================] - 2s 61ms/step - loss: 0.1207 - accuracy: 0.9701 - val_loss: 0.4006 - val_accuracy: 0.8622
#
# Epoch 00029: val_accuracy did not improve from 0.87556
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 30/30
# 25/25 [==============================] - 1s 60ms/step - loss: 0.1177 - accuracy: 0.9778 - val_loss: 0.4064 - val_accuracy: 0.8533
#
# Epoch 00030: val_accuracy did not improve from 0.87556
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
