# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7}
dict_genres = {'Electronic':0, 'Hip-Hop':3, 'International':5, 'Pop' :6}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Electronic', 3: 'Hip-Hop', 5: 'International', 6: 'Pop'}

# %%
npzfile = np.load('data/shuffled_train.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394,)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=8).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((3196, 640, 128), (3196, 8))

# %%
npzfile = np.load('data/shuffled_valid.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=8).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((400, 640, 128), (400, 8))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Pop

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 64
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=8
nb_filters2=16
nb_filters3=32
nb_filters4=64
ksize = (3,3)
pool_size= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, kernel_initializer = glorot_uniform(seed=9), name='conv_1')(layer)
    batch_1 = BatchNormalization(axis = 3)(conv_1)
    activ_1 = Activation('relu')(batch_1)
    pool_1 = MaxPooling2D(pool_size)(activ_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, kernel_initializer = glorot_uniform(seed=9), name='conv_2')(pool_1)
    batch_2 = BatchNormalization(axis = 3)(conv_2)
    activ_2 = Activation('relu')(batch_2)
    pool_2 = MaxPooling2D(pool_size)(activ_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, kernel_initializer = glorot_uniform(seed=9), name='conv_3')(pool_2)
    batch_3 = BatchNormalization(axis = 3)(conv_3)
    activ_3 = Activation('relu')(batch_3)
    pool_3 = MaxPooling2D(pool_size)(activ_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, kernel_initializer = glorot_uniform(seed=9), name='conv_4')(pool_3)
    batch_4 = BatchNormalization(axis = 3)(conv_4)
    activ_4 = Activation('relu')(batch_4)
    pool_4 = MaxPooling2D(pool_size)(activ_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds', kernel_initializer = glorot_uniform(seed=9))(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.00005)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 640
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_6/model_root_f1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_6/model_root_f1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
def create_split(elem, c):
    splits = []
    for i in range(c):
        equal = False
        np.random.shuffle(elem)
        new_split = list(chunks(elem, int(len(elem)/2)))
        for split in splits:
            if set(new_split[0]) == set(split[0]) and set(new_split[0]) == set(split[1]):
                equal = True
                break
            
        if equal:
            i-=1
            continue
        
        splits.append(new_split)
        
    return splits

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 3

kfold = KFold(n_splits=8, shuffle=True)
genre_splits = create_split(list(dict_genres.values()), num_splits)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)

    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['International', 'Pop'], ['Hip-Hop', 'Electronic']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 15s 80ms/step - loss: 0.7865 - accuracy: 0.5760 - val_loss: 0.7188 - val_accuracy: 0.4911
#
# Epoch 00001: val_accuracy improved from -inf to 0.49111, saving model to ./models/tree_6/model_root_f1/folder1\model.h5
# Epoch 2/30
# 50/50 [==============================] - 3s 63ms/step - loss: 0.6461 - accuracy: 0.6573 - val_loss: 0.7217 - val_accuracy: 0.5000
#
# Epoch 00002: val_accuracy improved from 0.49111 to 0.50000, saving model to ./models/tree_6/model_root_f1/folder1\model.h5
# Epoch 3/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.5949 - accuracy: 0.6980 - val_loss: 0.7630 - val_accuracy: 0.5089
#
# Epoch 00003: val_accuracy improved from 0.50000 to 0.50889, saving model to ./models/tree_6/model_root_f1/folder1\model.h5
# Epoch 4/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.5530 - accuracy: 0.7206 - val_loss: 0.6921 - val_accuracy: 0.5600
#
# Epoch 00004: val_accuracy improved from 0.50889 to 0.56000, saving model to ./models/tree_6/model_root_f1/folder1\model.h5
# Epoch 5/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.5173 - accuracy: 0.7476 - val_loss: 0.6514 - val_accuracy: 0.6311
#
# Epoch 00005: val_accuracy improved from 0.56000 to 0.63111, saving model to ./models/tree_6/model_root_f1/folder1\model.h5
# Epoch 6/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.4953 - accuracy: 0.7606 - val_loss: 0.6340 - val_accuracy: 0.6556
#
# Epoch 00006: val_accuracy improved from 0.63111 to 0.65556, saving model to ./models/tree_6/model_root_f1/folder1\model.h5
# Epoch 7/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.4689 - accuracy: 0.7781 - val_loss: 0.6010 - val_accuracy: 0.7111
#
# Epoch 00007: val_accuracy improved from 0.65556 to 0.71111, saving model to ./models/tree_6/model_root_f1/folder1\model.h5
# Epoch 8/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.4549 - accuracy: 0.7915 - val_loss: 0.6034 - val_accuracy: 0.7200
#
# Epoch 00008: val_accuracy improved from 0.71111 to 0.72000, saving model to ./models/tree_6/model_root_f1/folder1\model.h5
# Epoch 9/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.4320 - accuracy: 0.8010 - val_loss: 0.6004 - val_accuracy: 0.7244
#
# Epoch 00009: val_accuracy improved from 0.72000 to 0.72444, saving model to ./models/tree_6/model_root_f1/folder1\model.h5
# Epoch 10/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.4185 - accuracy: 0.8118 - val_loss: 0.6884 - val_accuracy: 0.6689
#
# Epoch 00010: val_accuracy did not improve from 0.72444
# Epoch 11/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.3859 - accuracy: 0.8325 - val_loss: 0.6181 - val_accuracy: 0.7200
#
# Epoch 00011: val_accuracy did not improve from 0.72444
# Epoch 12/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.3689 - accuracy: 0.8468 - val_loss: 0.6123 - val_accuracy: 0.7178
#
# Epoch 00012: val_accuracy did not improve from 0.72444
# Epoch 13/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.3582 - accuracy: 0.8579 - val_loss: 0.6136 - val_accuracy: 0.7156
#
# Epoch 00013: val_accuracy did not improve from 0.72444
# Epoch 14/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.3355 - accuracy: 0.8735 - val_loss: 0.6166 - val_accuracy: 0.7156
#
# Epoch 00014: val_accuracy did not improve from 0.72444
# Epoch 15/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.3219 - accuracy: 0.8760 - val_loss: 0.6128 - val_accuracy: 0.7356
#
# Epoch 00015: val_accuracy improved from 0.72444 to 0.73556, saving model to ./models/tree_6/model_root_f1/folder1\model.h5
# Epoch 16/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.3129 - accuracy: 0.8856 - val_loss: 0.6413 - val_accuracy: 0.7111
#
# Epoch 00016: val_accuracy did not improve from 0.73556
# Epoch 17/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2962 - accuracy: 0.8872 - val_loss: 0.6097 - val_accuracy: 0.7333
#
# Epoch 00017: val_accuracy did not improve from 0.73556
# Epoch 18/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2930 - accuracy: 0.8951 - val_loss: 0.6081 - val_accuracy: 0.7444
#
# Epoch 00018: val_accuracy improved from 0.73556 to 0.74444, saving model to ./models/tree_6/model_root_f1/folder1\model.h5
# Epoch 19/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2722 - accuracy: 0.9072 - val_loss: 0.6113 - val_accuracy: 0.7333
#
# Epoch 00019: val_accuracy did not improve from 0.74444
# Epoch 20/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2607 - accuracy: 0.9161 - val_loss: 0.6198 - val_accuracy: 0.7333
#
# Epoch 00020: val_accuracy did not improve from 0.74444
# Epoch 21/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2491 - accuracy: 0.9263 - val_loss: 0.6101 - val_accuracy: 0.7400
#
# Epoch 00021: val_accuracy did not improve from 0.74444
# Epoch 22/30
# 50/50 [==============================] - 3s 63ms/step - loss: 0.2421 - accuracy: 0.9285 - val_loss: 0.6128 - val_accuracy: 0.7378
#
# Epoch 00022: val_accuracy did not improve from 0.74444
# Epoch 23/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2398 - accuracy: 0.9259 - val_loss: 0.6192 - val_accuracy: 0.7356
#
# Epoch 00023: val_accuracy did not improve from 0.74444
# Epoch 24/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2253 - accuracy: 0.9364 - val_loss: 0.6153 - val_accuracy: 0.7422
#
# Epoch 00024: val_accuracy did not improve from 0.74444
# Epoch 25/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2123 - accuracy: 0.9476 - val_loss: 0.6247 - val_accuracy: 0.7311
#
# Epoch 00025: val_accuracy did not improve from 0.74444
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 26/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2031 - accuracy: 0.9504 - val_loss: 0.6248 - val_accuracy: 0.7333
#
# Epoch 00026: val_accuracy did not improve from 0.74444
# Epoch 27/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.1985 - accuracy: 0.9565 - val_loss: 0.6261 - val_accuracy: 0.7267
#
# Epoch 00027: val_accuracy did not improve from 0.74444
# Epoch 28/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.1904 - accuracy: 0.9587 - val_loss: 0.6190 - val_accuracy: 0.7356
#
# Epoch 00028: val_accuracy did not improve from 0.74444
# Epoch 29/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.1864 - accuracy: 0.9622 - val_loss: 0.6195 - val_accuracy: 0.7400
#
# Epoch 00029: val_accuracy did not improve from 0.74444
# Epoch 30/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.1840 - accuracy: 0.9615 - val_loss: 0.6291 - val_accuracy: 0.7444
#
# Epoch 00030: val_accuracy did not improve from 0.74444
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Pop', 'Electronic'], ['International', 'Hip-Hop']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 4s 71ms/step - loss: 0.8507 - accuracy: 0.5509 - val_loss: 0.7804 - val_accuracy: 0.5067
#
# Epoch 00001: val_accuracy improved from -inf to 0.50667, saving model to ./models/tree_6/model_root_f1/folder2\model.h5
# Epoch 2/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.6773 - accuracy: 0.6395 - val_loss: 0.9095 - val_accuracy: 0.5067
#
# Epoch 00002: val_accuracy did not improve from 0.50667
# Epoch 3/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.6277 - accuracy: 0.6707 - val_loss: 0.8614 - val_accuracy: 0.5111
#
# Epoch 00003: val_accuracy improved from 0.50667 to 0.51111, saving model to ./models/tree_6/model_root_f1/folder2\model.h5
# Epoch 4/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.5796 - accuracy: 0.6983 - val_loss: 0.8517 - val_accuracy: 0.5289
#
# Epoch 00004: val_accuracy improved from 0.51111 to 0.52889, saving model to ./models/tree_6/model_root_f1/folder2\model.h5
# Epoch 5/30
# 50/50 [==============================] - 3s 63ms/step - loss: 0.5618 - accuracy: 0.7206 - val_loss: 0.9835 - val_accuracy: 0.5311
#
# Epoch 00005: val_accuracy improved from 0.52889 to 0.53111, saving model to ./models/tree_6/model_root_f1/folder2\model.h5
# Epoch 6/30
# 50/50 [==============================] - 3s 63ms/step - loss: 0.5305 - accuracy: 0.7333 - val_loss: 0.6560 - val_accuracy: 0.6333
#
# Epoch 00006: val_accuracy improved from 0.53111 to 0.63333, saving model to ./models/tree_6/model_root_f1/folder2\model.h5
# Epoch 7/30
# 50/50 [==============================] - 3s 63ms/step - loss: 0.5234 - accuracy: 0.7416 - val_loss: 0.8534 - val_accuracy: 0.5800
#
# Epoch 00007: val_accuracy did not improve from 0.63333
# Epoch 8/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.4791 - accuracy: 0.7765 - val_loss: 0.6548 - val_accuracy: 0.6733
#
# Epoch 00008: val_accuracy improved from 0.63333 to 0.67333, saving model to ./models/tree_6/model_root_f1/folder2\model.h5
# Epoch 9/30
# 50/50 [==============================] - 3s 63ms/step - loss: 0.4528 - accuracy: 0.7921 - val_loss: 0.6336 - val_accuracy: 0.6711
#
# Epoch 00009: val_accuracy did not improve from 0.67333
# Epoch 10/30
# 50/50 [==============================] - 3s 63ms/step - loss: 0.4323 - accuracy: 0.8023 - val_loss: 0.6319 - val_accuracy: 0.6800ss: 0.4259 - accu
#
# Epoch 00010: val_accuracy improved from 0.67333 to 0.68000, saving model to ./models/tree_6/model_root_f1/folder2\model.h5
# Epoch 11/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.4047 - accuracy: 0.8277 - val_loss: 0.7559 - val_accuracy: 0.6422
#
# Epoch 00011: val_accuracy did not improve from 0.68000
# Epoch 12/30
# 50/50 [==============================] - 3s 61ms/step - loss: 0.4019 - accuracy: 0.8220 - val_loss: 0.6406 - val_accuracy: 0.6867
#
# Epoch 00012: val_accuracy improved from 0.68000 to 0.68667, saving model to ./models/tree_6/model_root_f1/folder2\model.h5
# Epoch 13/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.3743 - accuracy: 0.8449 - val_loss: 0.6018 - val_accuracy: 0.7178
#
# Epoch 00013: val_accuracy improved from 0.68667 to 0.71778, saving model to ./models/tree_6/model_root_f1/folder2\model.h5
# Epoch 14/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.3632 - accuracy: 0.8506 - val_loss: 0.6200 - val_accuracy: 0.7111
#
# Epoch 00014: val_accuracy did not improve from 0.71778
# Epoch 15/30
# 50/50 [==============================] - 3s 61ms/step - loss: 0.3465 - accuracy: 0.8614 - val_loss: 0.6859 - val_accuracy: 0.6644
#
# Epoch 00015: val_accuracy did not improve from 0.71778
# Epoch 16/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.3357 - accuracy: 0.8725 - val_loss: 0.5982 - val_accuracy: 0.7267
#
# Epoch 00016: val_accuracy improved from 0.71778 to 0.72667, saving model to ./models/tree_6/model_root_f1/folder2\model.h5
# Epoch 17/30
# 50/50 [==============================] - 3s 61ms/step - loss: 0.3272 - accuracy: 0.8735 - val_loss: 0.5851 - val_accuracy: 0.7356
#
# Epoch 00017: val_accuracy improved from 0.72667 to 0.73556, saving model to ./models/tree_6/model_root_f1/folder2\model.h5
# Epoch 18/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.3054 - accuracy: 0.8929 - val_loss: 0.5899 - val_accuracy: 0.7356
#
# Epoch 00018: val_accuracy did not improve from 0.73556
# Epoch 19/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2981 - accuracy: 0.8967 - val_loss: 0.6999 - val_accuracy: 0.6711
#
# Epoch 00019: val_accuracy did not improve from 0.73556
# Epoch 20/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2948 - accuracy: 0.8907 - val_loss: 0.6168 - val_accuracy: 0.7133
#
# Epoch 00020: val_accuracy did not improve from 0.73556
# Epoch 21/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2832 - accuracy: 0.8999 - val_loss: 0.5897 - val_accuracy: 0.7333
#
# Epoch 00021: val_accuracy did not improve from 0.73556
# Epoch 22/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2602 - accuracy: 0.9266 - val_loss: 0.5842 - val_accuracy: 0.7422
#
# Epoch 00022: val_accuracy improved from 0.73556 to 0.74222, saving model to ./models/tree_6/model_root_f1/folder2\model.h5
# Epoch 23/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2582 - accuracy: 0.9151 - val_loss: 0.6004 - val_accuracy: 0.7244
#
# Epoch 00023: val_accuracy did not improve from 0.74222
# Epoch 24/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2635 - accuracy: 0.9132 - val_loss: 0.5998 - val_accuracy: 0.7356
#
# Epoch 00024: val_accuracy did not improve from 0.74222
# Epoch 25/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2312 - accuracy: 0.9387 - val_loss: 0.5925 - val_accuracy: 0.7378
#
# Epoch 00025: val_accuracy did not improve from 0.74222
# Epoch 26/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2311 - accuracy: 0.9329 - val_loss: 0.5904 - val_accuracy: 0.7400
#
# Epoch 00026: val_accuracy did not improve from 0.74222
# Epoch 27/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2189 - accuracy: 0.9428 - val_loss: 0.6027 - val_accuracy: 0.7311
#
# Epoch 00027: val_accuracy did not improve from 0.74222
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 28/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2072 - accuracy: 0.9536 - val_loss: 0.6012 - val_accuracy: 0.7289
#
# Epoch 00028: val_accuracy did not improve from 0.74222
# Epoch 29/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2033 - accuracy: 0.9565 - val_loss: 0.6087 - val_accuracy: 0.7244
#
# Epoch 00029: val_accuracy did not improve from 0.74222
# Epoch 30/30
# 50/50 [==============================] - 3s 61ms/step - loss: 0.1998 - accuracy: 0.9558 - val_loss: 0.6044 - val_accuracy: 0.7333
#
# Epoch 00030: val_accuracy did not improve from 0.74222
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Pop', 'Hip-Hop'], ['Electronic', 'International']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 4s 71ms/step - loss: 0.8649 - accuracy: 0.5388 - val_loss: 0.6991 - val_accuracy: 0.4889
#
# Epoch 00001: val_accuracy improved from -inf to 0.48889, saving model to ./models/tree_6/model_root_f1/folder3\model.h5
# Epoch 2/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.7161 - accuracy: 0.6036 - val_loss: 0.7008 - val_accuracy: 0.5222
#
# Epoch 00002: val_accuracy improved from 0.48889 to 0.52222, saving model to ./models/tree_6/model_root_f1/folder3\model.h5
# Epoch 3/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.6628 - accuracy: 0.6351 - val_loss: 0.6983 - val_accuracy: 0.5289
#
# Epoch 00003: val_accuracy improved from 0.52222 to 0.52889, saving model to ./models/tree_6/model_root_f1/folder3\model.h5
# Epoch 4/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.6264 - accuracy: 0.6650 - val_loss: 0.6683 - val_accuracy: 0.5978
#
# Epoch 00004: val_accuracy improved from 0.52889 to 0.59778, saving model to ./models/tree_6/model_root_f1/folder3\model.h5
# Epoch 5/30
# 50/50 [==============================] - 3s 63ms/step - loss: 0.5910 - accuracy: 0.6939 - val_loss: 0.6466 - val_accuracy: 0.6111
#
# Epoch 00005: val_accuracy improved from 0.59778 to 0.61111, saving model to ./models/tree_6/model_root_f1/folder3\model.h5
# Epoch 6/30
# 50/50 [==============================] - 3s 63ms/step - loss: 0.5754 - accuracy: 0.7047 - val_loss: 0.6442 - val_accuracy: 0.6378
#
# Epoch 00006: val_accuracy improved from 0.61111 to 0.63778, saving model to ./models/tree_6/model_root_f1/folder3\model.h5
# Epoch 7/30
# 50/50 [==============================] - 3s 63ms/step - loss: 0.5300 - accuracy: 0.7394 - val_loss: 0.6388 - val_accuracy: 0.6222
#
# Epoch 00007: val_accuracy did not improve from 0.63778
# Epoch 8/30
# 50/50 [==============================] - 3s 63ms/step - loss: 0.5095 - accuracy: 0.7479 - val_loss: 0.6331 - val_accuracy: 0.6333
#
# Epoch 00008: val_accuracy did not improve from 0.63778
# Epoch 9/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.4881 - accuracy: 0.7657 - val_loss: 0.6465 - val_accuracy: 0.6289
#
# Epoch 00009: val_accuracy did not improve from 0.63778
# Epoch 10/30
# 50/50 [==============================] - 3s 63ms/step - loss: 0.4718 - accuracy: 0.7807 - val_loss: 0.6301 - val_accuracy: 0.6644
#
# Epoch 00010: val_accuracy improved from 0.63778 to 0.66444, saving model to ./models/tree_6/model_root_f1/folder3\model.h5
# Epoch 11/30
# 50/50 [==============================] - 3s 63ms/step - loss: 0.4596 - accuracy: 0.7905 - val_loss: 0.6261 - val_accuracy: 0.6578
#
# Epoch 00011: val_accuracy did not improve from 0.66444
# Epoch 12/30
# 50/50 [==============================] - 3s 63ms/step - loss: 0.4407 - accuracy: 0.8010 - val_loss: 0.6230 - val_accuracy: 0.6756
#
# Epoch 00012: val_accuracy improved from 0.66444 to 0.67556, saving model to ./models/tree_6/model_root_f1/folder3\model.h5
# Epoch 13/30
# 50/50 [==============================] - 3s 63ms/step - loss: 0.4170 - accuracy: 0.8229 - val_loss: 0.6599 - val_accuracy: 0.6400
#
# Epoch 00013: val_accuracy did not improve from 0.67556
# Epoch 14/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.4083 - accuracy: 0.8264 - val_loss: 0.6418 - val_accuracy: 0.6844
#
# Epoch 00014: val_accuracy improved from 0.67556 to 0.68444, saving model to ./models/tree_6/model_root_f1/folder3\model.h5
# Epoch 15/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.3850 - accuracy: 0.8433 - val_loss: 0.6231 - val_accuracy: 0.6800
#
# Epoch 00015: val_accuracy did not improve from 0.68444
# Epoch 16/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.3738 - accuracy: 0.8528 - val_loss: 0.6154 - val_accuracy: 0.6756
#
# Epoch 00016: val_accuracy did not improve from 0.68444
# Epoch 17/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.3597 - accuracy: 0.8649 - val_loss: 0.6336 - val_accuracy: 0.6711
#
# Epoch 00017: val_accuracy did not improve from 0.68444
# Epoch 18/30
# 50/50 [==============================] - 3s 63ms/step - loss: 0.3435 - accuracy: 0.8754 - val_loss: 0.6358 - val_accuracy: 0.6667
#
# Epoch 00018: val_accuracy did not improve from 0.68444
# Epoch 19/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.3386 - accuracy: 0.8744 - val_loss: 0.6139 - val_accuracy: 0.6667
#
# Epoch 00019: val_accuracy did not improve from 0.68444
# Epoch 20/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.3195 - accuracy: 0.8894 - val_loss: 0.6456 - val_accuracy: 0.6667
#
# Epoch 00020: val_accuracy did not improve from 0.68444
# Epoch 21/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.3099 - accuracy: 0.8983 - val_loss: 0.6404 - val_accuracy: 0.6756
#
# Epoch 00021: val_accuracy did not improve from 0.68444
# Epoch 22/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.3121 - accuracy: 0.8894 - val_loss: 0.6176 - val_accuracy: 0.6711
#
# Epoch 00022: val_accuracy did not improve from 0.68444
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 23/30
# 50/50 [==============================] - 3s 63ms/step - loss: 0.2809 - accuracy: 0.9158 - val_loss: 0.6361 - val_accuracy: 0.6778
#
# Epoch 00023: val_accuracy did not improve from 0.68444
# Epoch 24/30
# 50/50 [==============================] - 3s 63ms/step - loss: 0.2745 - accuracy: 0.9259 - val_loss: 0.6165 - val_accuracy: 0.6778
#
# Epoch 00024: val_accuracy did not improve from 0.68444
# Epoch 25/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2703 - accuracy: 0.9224 - val_loss: 0.6149 - val_accuracy: 0.6822
#
# Epoch 00025: val_accuracy did not improve from 0.68444
# Epoch 26/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2634 - accuracy: 0.9282 - val_loss: 0.6142 - val_accuracy: 0.6689
#
# Epoch 00026: val_accuracy did not improve from 0.68444
# Epoch 27/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2604 - accuracy: 0.9313 - val_loss: 0.6164 - val_accuracy: 0.6956
#
# Epoch 00027: val_accuracy improved from 0.68444 to 0.69556, saving model to ./models/tree_6/model_root_f1/folder3\model.h5
# Epoch 28/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2526 - accuracy: 0.9367 - val_loss: 0.6222 - val_accuracy: 0.6956
#
# Epoch 00028: val_accuracy did not improve from 0.69556
# Epoch 29/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2509 - accuracy: 0.9412 - val_loss: 0.6313 - val_accuracy: 0.6978
#
# Epoch 00029: val_accuracy improved from 0.69556 to 0.69778, saving model to ./models/tree_6/model_root_f1/folder3\model.h5
# Epoch 30/30
# 50/50 [==============================] - 3s 62ms/step - loss: 0.2442 - accuracy: 0.9406 - val_loss: 0.6261 - val_accuracy: 0.6756
#
# Epoch 00030: val_accuracy did not improve from 0.69778
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
