# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7}
dict_genres = {'Experimental':1, 'Folk':2, 'Instrumental':4, 'Rock' :7}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {1: 'Experimental', 2: 'Folk', 4: 'Instrumental', 7: 'Rock'}

# %%
npzfile = np.load('data/shuffled_train.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394,)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=8).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((3198, 640, 128), (3198, 8))

# %%
npzfile = np.load('data/shuffled_valid.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=8).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((400, 640, 128), (400, 8))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Experimental

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 64
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=8
nb_filters2=16
nb_filters3=32
nb_filters4=64
ksize = (3,3)
pool_size= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, kernel_initializer = glorot_uniform(seed=9), name='conv_1')(layer)
    batch_1 = BatchNormalization(axis = 3)(conv_1)
    activ_1 = Activation('relu')(batch_1)
    pool_1 = MaxPooling2D(pool_size)(activ_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, kernel_initializer = glorot_uniform(seed=9), name='conv_2')(pool_1)
    batch_2 = BatchNormalization(axis = 3)(conv_2)
    activ_2 = Activation('relu')(batch_2)
    pool_2 = MaxPooling2D(pool_size)(activ_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, kernel_initializer = glorot_uniform(seed=9), name='conv_3')(pool_2)
    batch_3 = BatchNormalization(axis = 3)(conv_3)
    activ_3 = Activation('relu')(batch_3)
    pool_3 = MaxPooling2D(pool_size)(activ_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, kernel_initializer = glorot_uniform(seed=9), name='conv_4')(pool_3)
    batch_4 = BatchNormalization(axis = 3)(conv_4)
    activ_4 = Activation('relu')(batch_4)
    pool_4 = MaxPooling2D(pool_size)(activ_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds', kernel_initializer = glorot_uniform(seed=9))(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.00005)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 640
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_6/model_root_f2/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_6/model_root_f2/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
def create_split(elem, c):
    splits = []
    for i in range(c):
        equal = False
        np.random.shuffle(elem)
        new_split = list(chunks(elem, int(len(elem)/2)))
        for split in splits:
            if set(new_split[0]) == set(split[0]) and set(new_split[0]) == set(split[1]):
                equal = True
                break
            
        if equal:
            i-=1
            continue
        
        splits.append(new_split)
        
    return splits

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 3

kfold = KFold(n_splits=8, shuffle=True)
genre_splits = create_split(list(dict_genres.values()), num_splits)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)

    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Rock', 'Instrumental'], ['Experimental', 'Folk']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 16s 89ms/step - loss: 0.8304 - accuracy: 0.5591 - val_loss: 0.7164 - val_accuracy: 0.5511
#
# Epoch 00001: val_accuracy improved from -inf to 0.55111, saving model to ./models/tree_6/model_root_f2/folder1\model.h5
# Epoch 2/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.6862 - accuracy: 0.6258 - val_loss: 0.7175 - val_accuracy: 0.5556
#
# Epoch 00002: val_accuracy improved from 0.55111 to 0.55556, saving model to ./models/tree_6/model_root_f2/folder1\model.h5
# Epoch 3/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.6326 - accuracy: 0.6569 - val_loss: 0.7239 - val_accuracy: 0.5667
#
# Epoch 00003: val_accuracy improved from 0.55556 to 0.56667, saving model to ./models/tree_6/model_root_f2/folder1\model.h5
# Epoch 4/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.6031 - accuracy: 0.6776 - val_loss: 0.6666 - val_accuracy: 0.5889
#
# Epoch 00004: val_accuracy improved from 0.56667 to 0.58889, saving model to ./models/tree_6/model_root_f2/folder1\model.h5
# Epoch 5/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.5814 - accuracy: 0.7020 - val_loss: 0.6567 - val_accuracy: 0.5933
#
# Epoch 00005: val_accuracy improved from 0.58889 to 0.59333, saving model to ./models/tree_6/model_root_f2/folder1\model.h5
# Epoch 6/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.5434 - accuracy: 0.7230 - val_loss: 0.6524 - val_accuracy: 0.6244
#
# Epoch 00006: val_accuracy improved from 0.59333 to 0.62444, saving model to ./models/tree_6/model_root_f2/folder1\model.h5
# Epoch 7/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.5219 - accuracy: 0.7360 - val_loss: 0.6574 - val_accuracy: 0.6267
#
# Epoch 00007: val_accuracy improved from 0.62444 to 0.62667, saving model to ./models/tree_6/model_root_f2/folder1\model.h5
# Epoch 8/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.4969 - accuracy: 0.7579 - val_loss: 0.6622 - val_accuracy: 0.6444
#
# Epoch 00008: val_accuracy improved from 0.62667 to 0.64444, saving model to ./models/tree_6/model_root_f2/folder1\model.h5
# Epoch 9/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.4769 - accuracy: 0.7691 - val_loss: 0.6494 - val_accuracy: 0.6444
#
# Epoch 00009: val_accuracy did not improve from 0.64444
# Epoch 10/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.4521 - accuracy: 0.7932 - val_loss: 0.6571 - val_accuracy: 0.6289
#
# Epoch 00010: val_accuracy did not improve from 0.64444
# Epoch 11/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.4421 - accuracy: 0.7954 - val_loss: 0.6410 - val_accuracy: 0.6556 accuracy - ETA: 0s - loss: 0.438
#
# Epoch 00011: val_accuracy improved from 0.64444 to 0.65556, saving model to ./models/tree_6/model_root_f2/folder1\model.h5
# Epoch 12/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.4253 - accuracy: 0.8062 - val_loss: 0.6600 - val_accuracy: 0.6444- loss: 0.4264 - accuracy: 0.
#
# Epoch 00012: val_accuracy did not improve from 0.65556
# Epoch 13/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.3983 - accuracy: 0.8320 - val_loss: 0.6964 - val_accuracy: 0.6533s - loss: 0.3949 - ac
#
# Epoch 00013: val_accuracy did not improve from 0.65556
# Epoch 14/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.3807 - accuracy: 0.8447 - val_loss: 0.6433 - val_accuracy: 0.6689
#
# Epoch 00014: val_accuracy improved from 0.65556 to 0.66889, saving model to ./models/tree_6/model_root_f2/folder1\model.h5
# Epoch 15/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.3693 - accuracy: 0.8571 - val_loss: 0.7191 - val_accuracy: 0.6556
#
# Epoch 00015: val_accuracy did not improve from 0.66889
# Epoch 16/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.3525 - accuracy: 0.8609 - val_loss: 0.6450 - val_accuracy: 0.6733
#
# Epoch 00016: val_accuracy improved from 0.66889 to 0.67333, saving model to ./models/tree_6/model_root_f2/folder1\model.h5
# Epoch 17/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.3390 - accuracy: 0.8742 - val_loss: 0.6341 - val_accuracy: 0.6800
#
# Epoch 00017: val_accuracy improved from 0.67333 to 0.68000, saving model to ./models/tree_6/model_root_f2/folder1\model.h5
# Epoch 18/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.3288 - accuracy: 0.8793 - val_loss: 0.6402 - val_accuracy: 0.6889
#
# Epoch 00018: val_accuracy improved from 0.68000 to 0.68889, saving model to ./models/tree_6/model_root_f2/folder1\model.h5
# Epoch 19/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.3209 - accuracy: 0.8825 - val_loss: 0.7566 - val_accuracy: 0.6444
#
# Epoch 00019: val_accuracy did not improve from 0.68889
# Epoch 20/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.3075 - accuracy: 0.8860 - val_loss: 0.7156 - val_accuracy: 0.6533
#
# Epoch 00020: val_accuracy did not improve from 0.68889
# Epoch 21/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2896 - accuracy: 0.9037 - val_loss: 0.6352 - val_accuracy: 0.6889
#
# Epoch 00021: val_accuracy did not improve from 0.68889
# Epoch 22/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2821 - accuracy: 0.9050 - val_loss: 0.6481 - val_accuracy: 0.6778
#
# Epoch 00022: val_accuracy did not improve from 0.68889
# Epoch 23/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2715 - accuracy: 0.9111 - val_loss: 0.6402 - val_accuracy: 0.6889
#
# Epoch 00023: val_accuracy did not improve from 0.68889
# Epoch 24/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2646 - accuracy: 0.9145 - val_loss: 0.6540 - val_accuracy: 0.6956
#
# Epoch 00024: val_accuracy improved from 0.68889 to 0.69556, saving model to ./models/tree_6/model_root_f2/folder1\model.h5
# Epoch 25/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2533 - accuracy: 0.9253 - val_loss: 0.6802 - val_accuracy: 0.6778
#
# Epoch 00025: val_accuracy did not improve from 0.69556
# Epoch 26/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2496 - accuracy: 0.9234 - val_loss: 0.6318 - val_accuracy: 0.7022
#
# Epoch 00026: val_accuracy improved from 0.69556 to 0.70222, saving model to ./models/tree_6/model_root_f2/folder1\model.h5
# Epoch 27/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.2375 - accuracy: 0.9282 - val_loss: 0.6580 - val_accuracy: 0.6978
#
# Epoch 00027: val_accuracy did not improve from 0.70222
# Epoch 28/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.2324 - accuracy: 0.9387 - val_loss: 0.6403 - val_accuracy: 0.6956
#
# Epoch 00028: val_accuracy did not improve from 0.70222
# Epoch 29/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.2295 - accuracy: 0.9342 - val_loss: 0.6495 - val_accuracy: 0.6978
#
# Epoch 00029: val_accuracy did not improve from 0.70222
# Epoch 30/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.2089 - accuracy: 0.9495 - val_loss: 0.7196 - val_accuracy: 0.6844
#
# Epoch 00030: val_accuracy did not improve from 0.70222
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Rock', 'Instrumental'], ['Folk', 'Experimental']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 4s 75ms/step - loss: 0.8145 - accuracy: 0.5486 - val_loss: 0.7036 - val_accuracy: 0.5267
#
# Epoch 00001: val_accuracy improved from -inf to 0.52667, saving model to ./models/tree_6/model_root_f2/folder2\model.h5
# Epoch 2/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.7027 - accuracy: 0.6137 - val_loss: 0.7657 - val_accuracy: 0.5178
#
# Epoch 00002: val_accuracy did not improve from 0.52667
# Epoch 3/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.6612 - accuracy: 0.6401 - val_loss: 0.7431 - val_accuracy: 0.5267
#
# Epoch 00003: val_accuracy did not improve from 0.52667
# Epoch 4/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.6057 - accuracy: 0.6738 - val_loss: 0.6725 - val_accuracy: 0.5667
#
# Epoch 00004: val_accuracy improved from 0.52667 to 0.56667, saving model to ./models/tree_6/model_root_f2/folder2\model.h5
# Epoch 5/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.5782 - accuracy: 0.6925 - val_loss: 0.6201 - val_accuracy: 0.6489
#
# Epoch 00005: val_accuracy improved from 0.56667 to 0.64889, saving model to ./models/tree_6/model_root_f2/folder2\model.h5
# Epoch 6/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.5521 - accuracy: 0.7141 - val_loss: 0.6033 - val_accuracy: 0.6622
#
# Epoch 00006: val_accuracy improved from 0.64889 to 0.66222, saving model to ./models/tree_6/model_root_f2/folder2\model.h5
# Epoch 7/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.5213 - accuracy: 0.7443 - val_loss: 0.5774 - val_accuracy: 0.7067
#
# Epoch 00007: val_accuracy improved from 0.66222 to 0.70667, saving model to ./models/tree_6/model_root_f2/folder2\model.h5
# Epoch 8/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.4997 - accuracy: 0.7497 - val_loss: 0.6513 - val_accuracy: 0.6422
#
# Epoch 00008: val_accuracy did not improve from 0.70667
# Epoch 9/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.4978 - accuracy: 0.7614 - val_loss: 0.5747 - val_accuracy: 0.7200
#
# Epoch 00009: val_accuracy improved from 0.70667 to 0.72000, saving model to ./models/tree_6/model_root_f2/folder2\model.h5
# Epoch 10/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.4630 - accuracy: 0.7837 - val_loss: 0.5884 - val_accuracy: 0.7089
#
# Epoch 00010: val_accuracy did not improve from 0.72000
# Epoch 11/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.4435 - accuracy: 0.8021 - val_loss: 0.5764 - val_accuracy: 0.6822
#
# Epoch 00011: val_accuracy did not improve from 0.72000
# Epoch 12/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.4273 - accuracy: 0.8024 - val_loss: 0.5714 - val_accuracy: 0.7178
#
# Epoch 00012: val_accuracy did not improve from 0.72000
# Epoch 13/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.4114 - accuracy: 0.8215 - val_loss: 0.5740 - val_accuracy: 0.7178
#
# Epoch 00013: val_accuracy did not improve from 0.72000
# Epoch 14/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.3954 - accuracy: 0.8323 - val_loss: 0.5962 - val_accuracy: 0.6933
#
# Epoch 00014: val_accuracy did not improve from 0.72000
# Epoch 15/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.3871 - accuracy: 0.8342 - val_loss: 0.5865 - val_accuracy: 0.7200
#
# Epoch 00015: val_accuracy did not improve from 0.72000
# Epoch 16/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.3591 - accuracy: 0.8567 - val_loss: 0.5984 - val_accuracy: 0.7022
#
# Epoch 00016: val_accuracy did not improve from 0.72000
# Epoch 17/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.3470 - accuracy: 0.8628 - val_loss: 0.5793 - val_accuracy: 0.7067
#
# Epoch 00017: val_accuracy did not improve from 0.72000
# Epoch 18/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.3395 - accuracy: 0.8720 - val_loss: 0.6458 - val_accuracy: 0.6844
#
# Epoch 00018: val_accuracy did not improve from 0.72000
# Epoch 19/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.3262 - accuracy: 0.8739 - val_loss: 0.5897 - val_accuracy: 0.7067
#
# Epoch 00019: val_accuracy did not improve from 0.72000
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 20/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.3134 - accuracy: 0.8841 - val_loss: 0.5848 - val_accuracy: 0.7111
#
# Epoch 00020: val_accuracy did not improve from 0.72000
# Epoch 21/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.3028 - accuracy: 0.8929 - val_loss: 0.5821 - val_accuracy: 0.7178
#
# Epoch 00021: val_accuracy did not improve from 0.72000
# Epoch 22/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2931 - accuracy: 0.9028 - val_loss: 0.5760 - val_accuracy: 0.7067
#
# Epoch 00022: val_accuracy did not improve from 0.72000
# Epoch 23/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.2904 - accuracy: 0.9095 - val_loss: 0.5782 - val_accuracy: 0.7111
#
# Epoch 00023: val_accuracy did not improve from 0.72000
# Epoch 24/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2874 - accuracy: 0.9060 - val_loss: 0.5789 - val_accuracy: 0.7200
#
# Epoch 00024: val_accuracy did not improve from 0.72000
# Epoch 25/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.2775 - accuracy: 0.9095 - val_loss: 0.5776 - val_accuracy: 0.7222
#
# Epoch 00025: val_accuracy improved from 0.72000 to 0.72222, saving model to ./models/tree_6/model_root_f2/folder2\model.h5
# Epoch 26/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2828 - accuracy: 0.9050 - val_loss: 0.5724 - val_accuracy: 0.7200
#
# Epoch 00026: val_accuracy did not improve from 0.72222
# Epoch 27/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2733 - accuracy: 0.9066 - val_loss: 0.5921 - val_accuracy: 0.7156
#
# Epoch 00027: val_accuracy did not improve from 0.72222
# Epoch 28/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2633 - accuracy: 0.9241 - val_loss: 0.5778 - val_accuracy: 0.7333
#
# Epoch 00028: val_accuracy improved from 0.72222 to 0.73333, saving model to ./models/tree_6/model_root_f2/folder2\model.h5
# Epoch 29/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2597 - accuracy: 0.9206 - val_loss: 0.5813 - val_accuracy: 0.7200
#
# Epoch 00029: val_accuracy did not improve from 0.73333
# Epoch 30/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.2540 - accuracy: 0.9244 - val_loss: 0.5803 - val_accuracy: 0.7089
#
# Epoch 00030: val_accuracy did not improve from 0.73333
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Instrumental', 'Experimental'], ['Rock', 'Folk']]
# Building model...
# Training...
# Epoch 1/30
# 50/50 [==============================] - 4s 74ms/step - loss: 0.8524 - accuracy: 0.5388 - val_loss: 0.7841 - val_accuracy: 0.5111
#
# Epoch 00001: val_accuracy improved from -inf to 0.51111, saving model to ./models/tree_6/model_root_f2/folder3\model.h5
# Epoch 2/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.6706 - accuracy: 0.6407 - val_loss: 0.8360 - val_accuracy: 0.5133: 0.6741 - ac
#
# Epoch 00002: val_accuracy improved from 0.51111 to 0.51333, saving model to ./models/tree_6/model_root_f2/folder3\model.h5
# Epoch 3/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.6190 - accuracy: 0.6773 - val_loss: 0.9361 - val_accuracy: 0.5133
#
# Epoch 00003: val_accuracy did not improve from 0.51333
# Epoch 4/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.5642 - accuracy: 0.7132 - val_loss: 0.8869 - val_accuracy: 0.5178
#
# Epoch 00004: val_accuracy improved from 0.51333 to 0.51778, saving model to ./models/tree_6/model_root_f2/folder3\model.h5
# Epoch 5/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.5419 - accuracy: 0.7252 - val_loss: 0.7513 - val_accuracy: 0.5533
#
# Epoch 00005: val_accuracy improved from 0.51778 to 0.55333, saving model to ./models/tree_6/model_root_f2/folder3\model.h5
# Epoch 6/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.5005 - accuracy: 0.7589 - val_loss: 0.6406 - val_accuracy: 0.6222
#
# Epoch 00006: val_accuracy improved from 0.55333 to 0.62222, saving model to ./models/tree_6/model_root_f2/folder3\model.h5
# Epoch 7/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.4809 - accuracy: 0.7678 - val_loss: 0.6175 - val_accuracy: 0.6733
#
# Epoch 00007: val_accuracy improved from 0.62222 to 0.67333, saving model to ./models/tree_6/model_root_f2/folder3\model.h5
# Epoch 8/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.4527 - accuracy: 0.7856 - val_loss: 0.5991 - val_accuracy: 0.7156
#
# Epoch 00008: val_accuracy improved from 0.67333 to 0.71556, saving model to ./models/tree_6/model_root_f2/folder3\model.h5
# Epoch 9/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.4308 - accuracy: 0.8030 - val_loss: 0.6111 - val_accuracy: 0.6933
#
# Epoch 00009: val_accuracy did not improve from 0.71556
# Epoch 10/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.4112 - accuracy: 0.8183 - val_loss: 0.6095 - val_accuracy: 0.70224114 - accuracy: 0.81
#
# Epoch 00010: val_accuracy did not improve from 0.71556
# Epoch 11/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.4067 - accuracy: 0.8116 - val_loss: 0.6422 - val_accuracy: 0.7000
#
# Epoch 00011: val_accuracy did not improve from 0.71556
# Epoch 12/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.3787 - accuracy: 0.8412 - val_loss: 0.6000 - val_accuracy: 0.7222
#
# Epoch 00012: val_accuracy improved from 0.71556 to 0.72222, saving model to ./models/tree_6/model_root_f2/folder3\model.h5
# Epoch 13/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.3621 - accuracy: 0.8456 - val_loss: 0.5890 - val_accuracy: 0.7156
#
# Epoch 00013: val_accuracy did not improve from 0.72222
# Epoch 14/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.3539 - accuracy: 0.8558 - val_loss: 0.5900 - val_accuracy: 0.7244
#
# Epoch 00014: val_accuracy improved from 0.72222 to 0.72444, saving model to ./models/tree_6/model_root_f2/folder3\model.h5
# Epoch 15/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.3351 - accuracy: 0.8694 - val_loss: 0.6003 - val_accuracy: 0.7178
#
# Epoch 00015: val_accuracy did not improve from 0.72444
# Epoch 16/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.3171 - accuracy: 0.8761 - val_loss: 0.5859 - val_accuracy: 0.7244
#
# Epoch 00016: val_accuracy did not improve from 0.72444
# Epoch 17/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.3074 - accuracy: 0.8844 - val_loss: 0.5936 - val_accuracy: 0.7156
#
# Epoch 00017: val_accuracy did not improve from 0.72444
# Epoch 18/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2953 - accuracy: 0.8926 - val_loss: 0.5652 - val_accuracy: 0.7289
#
# Epoch 00018: val_accuracy improved from 0.72444 to 0.72889, saving model to ./models/tree_6/model_root_f2/folder3\model.h5
# Epoch 19/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.2889 - accuracy: 0.8949 - val_loss: 0.5758 - val_accuracy: 0.7178
#
# Epoch 00019: val_accuracy did not improve from 0.72889
# Epoch 20/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2731 - accuracy: 0.9006 - val_loss: 0.5769 - val_accuracy: 0.7489
#
# Epoch 00020: val_accuracy improved from 0.72889 to 0.74889, saving model to ./models/tree_6/model_root_f2/folder3\model.h5
# Epoch 21/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2707 - accuracy: 0.9034 - val_loss: 0.5635 - val_accuracy: 0.7356
#
# Epoch 00021: val_accuracy did not improve from 0.74889
# Epoch 22/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.2558 - accuracy: 0.9142 - val_loss: 0.5910 - val_accuracy: 0.7089
#
# Epoch 00022: val_accuracy did not improve from 0.74889
# Epoch 23/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2463 - accuracy: 0.9203 - val_loss: 0.5676 - val_accuracy: 0.7333acy: 0.
#
# Epoch 00023: val_accuracy did not improve from 0.74889
# Epoch 24/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2389 - accuracy: 0.9212 - val_loss: 0.5667 - val_accuracy: 0.7533
#
# Epoch 00024: val_accuracy improved from 0.74889 to 0.75333, saving model to ./models/tree_6/model_root_f2/folder3\model.h5
# Epoch 25/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2281 - accuracy: 0.9263 - val_loss: 0.5610 - val_accuracy: 0.7556
#
# Epoch 00025: val_accuracy improved from 0.75333 to 0.75556, saving model to ./models/tree_6/model_root_f2/folder3\model.h5
# Epoch 26/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2210 - accuracy: 0.9342 - val_loss: 0.5596 - val_accuracy: 0.7444
#
# Epoch 00026: val_accuracy did not improve from 0.75556
# Epoch 27/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.2090 - accuracy: 0.9396 - val_loss: 0.5618 - val_accuracy: 0.7378
#
# Epoch 00027: val_accuracy did not improve from 0.75556
# Epoch 28/30
# 50/50 [==============================] - 3s 66ms/step - loss: 0.1987 - accuracy: 0.9460 - val_loss: 0.5630 - val_accuracy: 0.7489
#
# Epoch 00028: val_accuracy did not improve from 0.75556
# Epoch 29/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.1913 - accuracy: 0.9514 - val_loss: 0.5558 - val_accuracy: 0.7467
#
# Epoch 00029: val_accuracy did not improve from 0.75556
# Epoch 30/30
# 50/50 [==============================] - 3s 65ms/step - loss: 0.1843 - accuracy: 0.9593 - val_loss: 0.5748 - val_accuracy: 0.7267
#
# Epoch 00030: val_accuracy did not improve from 0.75556
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
