# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Classical':1, 'Disco':3, 'Hip-Hop':4, 'Metal':6, 'Pop':7}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {1: 'Classical', 3: 'Disco', 4: 'Hip-Hop', 6: 'Metal', 7: 'Pop'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((4000, 128, 128), (4000, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((500, 128, 128), (500, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Classical

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 25

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_8/model_root_f2/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_8/model_root_f2/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def create_split(elem):
    splits = list(set_partitions(elem, 2))
    _splits = []
    for i in range(len(splits)):
        try:
            if len(splits[i][0]) != 1 and len(splits[i][1]) != 1:
                _splits.append(splits[i])
        except:
            continue
    
    return _splits, len(_splits)

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

genre_splits, num_splits = create_split(list(dict_genres.values()))
print("Num splits {}".format(num_splits))

if num_splits > 8:
    n_splits = num_splits
else:
    n_splits = 8

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Num splits 10
# Folder num 1
# Genre split [['Classical', 'Disco'], ['Hip-Hop', 'Metal', 'Pop']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 127/127 [==============================] - 6s 24ms/step - loss: 0.6943 - accuracy: 0.6659 - val_loss: 0.5051 - val_accuracy: 0.7533
#
# Epoch 00001: val_accuracy improved from -inf to 0.75333, saving model to ./models/tree_8/model_root_f2/folder1\model.h5
# Epoch 2/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.4554 - accuracy: 0.7820 - val_loss: 0.4036 - val_accuracy: 0.8311
#
# Epoch 00002: val_accuracy improved from 0.75333 to 0.83111, saving model to ./models/tree_8/model_root_f2/folder1\model.h5
# Epoch 3/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.3755 - accuracy: 0.8306 - val_loss: 0.3754 - val_accuracy: 0.8311
#
# Epoch 00003: val_accuracy did not improve from 0.83111
# Epoch 4/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.3356 - accuracy: 0.8538 - val_loss: 0.3394 - val_accuracy: 0.8689
#
# Epoch 00004: val_accuracy improved from 0.83111 to 0.86889, saving model to ./models/tree_8/model_root_f2/folder1\model.h5
# Epoch 5/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.2988 - accuracy: 0.8726 - val_loss: 0.3270 - val_accuracy: 0.8467
#
# Epoch 00005: val_accuracy did not improve from 0.86889
# Epoch 6/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.2785 - accuracy: 0.8785 - val_loss: 0.2901 - val_accuracy: 0.8889
#
# Epoch 00006: val_accuracy improved from 0.86889 to 0.88889, saving model to ./models/tree_8/model_root_f2/folder1\model.h5
# Epoch 7/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.2622 - accuracy: 0.8832 - val_loss: 0.2770 - val_accuracy: 0.8800
#
# Epoch 00007: val_accuracy did not improve from 0.88889
# Epoch 8/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.2613 - accuracy: 0.8938 - val_loss: 0.2608 - val_accuracy: 0.8911
#
# Epoch 00008: val_accuracy improved from 0.88889 to 0.89111, saving model to ./models/tree_8/model_root_f2/folder1\model.h5
# Epoch 9/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.2115 - accuracy: 0.9121 - val_loss: 0.2799 - val_accuracy: 0.8933
#
# Epoch 00009: val_accuracy improved from 0.89111 to 0.89333, saving model to ./models/tree_8/model_root_f2/folder1\model.h5
# Epoch 10/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1889 - accuracy: 0.9235 - val_loss: 0.2293 - val_accuracy: 0.9022
#
# Epoch 00010: val_accuracy improved from 0.89333 to 0.90222, saving model to ./models/tree_8/model_root_f2/folder1\model.h5
# Epoch 11/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1948 - accuracy: 0.9170 - val_loss: 0.2991 - val_accuracy: 0.8689
#
# Epoch 00011: val_accuracy did not improve from 0.90222
# Epoch 12/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1725 - accuracy: 0.9279 - val_loss: 0.2260 - val_accuracy: 0.9111
#
# Epoch 00012: val_accuracy improved from 0.90222 to 0.91111, saving model to ./models/tree_8/model_root_f2/folder1\model.h5
# Epoch 13/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.1537 - accuracy: 0.9356 - val_loss: 0.2614 - val_accuracy: 0.9089
#
# Epoch 00013: val_accuracy did not improve from 0.91111
# Epoch 14/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1284 - accuracy: 0.9481 - val_loss: 0.1898 - val_accuracy: 0.9289
#
# Epoch 00014: val_accuracy improved from 0.91111 to 0.92889, saving model to ./models/tree_8/model_root_f2/folder1\model.h5
# Epoch 15/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.1438 - accuracy: 0.9370 - val_loss: 0.2142 - val_accuracy: 0.9178
#
# Epoch 00015: val_accuracy did not improve from 0.92889
# Epoch 16/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1051 - accuracy: 0.9553 - val_loss: 0.2383 - val_accuracy: 0.9156
#
# Epoch 00016: val_accuracy did not improve from 0.92889
# Epoch 17/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1098 - accuracy: 0.9578 - val_loss: 0.1959 - val_accuracy: 0.9311
#
# Epoch 00017: val_accuracy improved from 0.92889 to 0.93111, saving model to ./models/tree_8/model_root_f2/folder1\model.h5
# Epoch 18/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0850 - accuracy: 0.9662 - val_loss: 0.2396 - val_accuracy: 0.9156
#
# Epoch 00018: val_accuracy did not improve from 0.93111
# Epoch 19/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0575 - accuracy: 0.9773 - val_loss: 0.1958 - val_accuracy: 0.9289
#
# Epoch 00019: val_accuracy did not improve from 0.93111
# Epoch 20/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0540 - accuracy: 0.9793 - val_loss: 0.2231 - val_accuracy: 0.9222
#
# Epoch 00020: val_accuracy did not improve from 0.93111
# Epoch 21/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0420 - accuracy: 0.9847 - val_loss: 0.2883 - val_accuracy: 0.9200
#
# Epoch 00021: val_accuracy did not improve from 0.93111
# Epoch 22/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0353 - accuracy: 0.9889 - val_loss: 0.2275 - val_accuracy: 0.9156
#
# Epoch 00022: val_accuracy did not improve from 0.93111
# Epoch 23/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0319 - accuracy: 0.9886 - val_loss: 0.2759 - val_accuracy: 0.9222
#
# Epoch 00023: val_accuracy did not improve from 0.93111
# Epoch 24/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0281 - accuracy: 0.9894 - val_loss: 0.2301 - val_accuracy: 0.9378
#
# Epoch 00024: val_accuracy improved from 0.93111 to 0.93778, saving model to ./models/tree_8/model_root_f2/folder1\model.h5
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 25/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0099 - accuracy: 0.9968 - val_loss: 0.2589 - val_accuracy: 0.9467
#
# Epoch 00025: val_accuracy improved from 0.93778 to 0.94667, saving model to ./models/tree_8/model_root_f2/folder1\model.h5
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Classical', 'Disco', 'Hip-Hop'], ['Metal', 'Pop']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.7082 - accuracy: 0.6348 - val_loss: 0.5582 - val_accuracy: 0.7089
#
# Epoch 00001: val_accuracy improved from -inf to 0.70889, saving model to ./models/tree_8/model_root_f2/folder2\model.h5
# Epoch 2/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.5655 - accuracy: 0.7279 - val_loss: 0.4891 - val_accuracy: 0.7867
#
# Epoch 00002: val_accuracy improved from 0.70889 to 0.78667, saving model to ./models/tree_8/model_root_f2/folder2\model.h5
# Epoch 3/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.5209 - accuracy: 0.7440 - val_loss: 0.4790 - val_accuracy: 0.7844
#
# Epoch 00003: val_accuracy did not improve from 0.78667
# Epoch 4/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.4555 - accuracy: 0.7847 - val_loss: 0.4835 - val_accuracy: 0.7711
#
# Epoch 00004: val_accuracy did not improve from 0.78667
# Epoch 5/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.4450 - accuracy: 0.7985 - val_loss: 0.4217 - val_accuracy: 0.8222
#
# Epoch 00005: val_accuracy improved from 0.78667 to 0.82222, saving model to ./models/tree_8/model_root_f2/folder2\model.h5
# Epoch 6/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.3876 - accuracy: 0.8289 - val_loss: 0.3540 - val_accuracy: 0.8644
#
# Epoch 00006: val_accuracy improved from 0.82222 to 0.86444, saving model to ./models/tree_8/model_root_f2/folder2\model.h5
# Epoch 7/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.3493 - accuracy: 0.8511 - val_loss: 0.3376 - val_accuracy: 0.8622
#
# Epoch 00007: val_accuracy did not improve from 0.86444
# Epoch 8/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.2938 - accuracy: 0.8748 - val_loss: 0.2744 - val_accuracy: 0.8800
#
# Epoch 00008: val_accuracy improved from 0.86444 to 0.88000, saving model to ./models/tree_8/model_root_f2/folder2\model.h5
# Epoch 9/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.2776 - accuracy: 0.8857 - val_loss: 0.2663 - val_accuracy: 0.8956
#
# Epoch 00009: val_accuracy improved from 0.88000 to 0.89556, saving model to ./models/tree_8/model_root_f2/folder2\model.h5
# Epoch 10/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.2284 - accuracy: 0.9069 - val_loss: 0.2956 - val_accuracy: 0.8756
#
# Epoch 00010: val_accuracy did not improve from 0.89556
# Epoch 11/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.2111 - accuracy: 0.9116 - val_loss: 0.2271 - val_accuracy: 0.9178
#
# Epoch 00011: val_accuracy improved from 0.89556 to 0.91778, saving model to ./models/tree_8/model_root_f2/folder2\model.h5
# Epoch 12/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1775 - accuracy: 0.9326 - val_loss: 0.2489 - val_accuracy: 0.8956
#
# Epoch 00012: val_accuracy did not improve from 0.91778
# Epoch 13/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1700 - accuracy: 0.9316 - val_loss: 0.3890 - val_accuracy: 0.8511
#
# Epoch 00013: val_accuracy did not improve from 0.91778
# Epoch 14/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1499 - accuracy: 0.9427 - val_loss: 0.1881 - val_accuracy: 0.9200
#
# Epoch 00014: val_accuracy improved from 0.91778 to 0.92000, saving model to ./models/tree_8/model_root_f2/folder2\model.h5
# Epoch 15/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1239 - accuracy: 0.9521 - val_loss: 0.2235 - val_accuracy: 0.9067
#
# Epoch 00015: val_accuracy did not improve from 0.92000
# Epoch 16/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1052 - accuracy: 0.9612 - val_loss: 0.1995 - val_accuracy: 0.9289
#
# Epoch 00016: val_accuracy improved from 0.92000 to 0.92889, saving model to ./models/tree_8/model_root_f2/folder2\model.h5
# Epoch 17/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0828 - accuracy: 0.9711 - val_loss: 0.1653 - val_accuracy: 0.9311
#
# Epoch 00017: val_accuracy improved from 0.92889 to 0.93111, saving model to ./models/tree_8/model_root_f2/folder2\model.h5
# Epoch 18/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0637 - accuracy: 0.9783 - val_loss: 0.2376 - val_accuracy: 0.9133
#
# Epoch 00018: val_accuracy did not improve from 0.93111
# Epoch 19/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0967 - accuracy: 0.9637 - val_loss: 0.1750 - val_accuracy: 0.9267
#
# Epoch 00019: val_accuracy did not improve from 0.93111
# Epoch 20/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0462 - accuracy: 0.9835 - val_loss: 0.2894 - val_accuracy: 0.9089
#
# Epoch 00020: val_accuracy did not improve from 0.93111
# Epoch 21/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0283 - accuracy: 0.9909 - val_loss: 0.1936 - val_accuracy: 0.9333
#
# Epoch 00021: val_accuracy improved from 0.93111 to 0.93333, saving model to ./models/tree_8/model_root_f2/folder2\model.h5
# Epoch 22/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0106 - accuracy: 0.9985 - val_loss: 0.2446 - val_accuracy: 0.9267
#
# Epoch 00022: val_accuracy did not improve from 0.93333
# Epoch 23/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0192 - accuracy: 0.9933 - val_loss: 0.2237 - val_accuracy: 0.9244
#
# Epoch 00023: val_accuracy did not improve from 0.93333
# Epoch 24/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0290 - accuracy: 0.9916 - val_loss: 0.3439 - val_accuracy: 0.8978
#
# Epoch 00024: val_accuracy did not improve from 0.93333
# Epoch 25/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0345 - accuracy: 0.9886 - val_loss: 0.2122 - val_accuracy: 0.9333
#
# Epoch 00025: val_accuracy did not improve from 0.93333
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Disco', 'Hip-Hop'], ['Classical', 'Metal', 'Pop']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.7216 - accuracy: 0.6049 - val_loss: 0.5894 - val_accuracy: 0.6644
#
# Epoch 00001: val_accuracy improved from -inf to 0.66444, saving model to ./models/tree_8/model_root_f2/folder3\model.h5
# Epoch 2/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.5830 - accuracy: 0.6699 - val_loss: 0.6637 - val_accuracy: 0.6378
#
# Epoch 00002: val_accuracy did not improve from 0.66444
# Epoch 3/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.5463 - accuracy: 0.7195 - val_loss: 0.4723 - val_accuracy: 0.7556
#
# Epoch 00003: val_accuracy improved from 0.66444 to 0.75556, saving model to ./models/tree_8/model_root_f2/folder3\model.h5
# Epoch 4/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.4376 - accuracy: 0.7941 - val_loss: 0.4006 - val_accuracy: 0.8178
#
# Epoch 00004: val_accuracy improved from 0.75556 to 0.81778, saving model to ./models/tree_8/model_root_f2/folder3\model.h5
# Epoch 5/25
# 127/127 [==============================] - 2s 19ms/step - loss: 0.3696 - accuracy: 0.8365 - val_loss: 0.3353 - val_accuracy: 0.8511
#
# Epoch 00005: val_accuracy improved from 0.81778 to 0.85111, saving model to ./models/tree_8/model_root_f2/folder3\model.h5
# Epoch 6/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.2945 - accuracy: 0.8763 - val_loss: 0.3116 - val_accuracy: 0.8756
#
# Epoch 00006: val_accuracy improved from 0.85111 to 0.87556, saving model to ./models/tree_8/model_root_f2/folder3\model.h5
# Epoch 7/25
# 127/127 [==============================] - 3s 23ms/step - loss: 0.2521 - accuracy: 0.8973 - val_loss: 0.2432 - val_accuracy: 0.8956
#
# Epoch 00007: val_accuracy improved from 0.87556 to 0.89556, saving model to ./models/tree_8/model_root_f2/folder3\model.h5
# Epoch 8/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.2109 - accuracy: 0.9202 - val_loss: 0.2578 - val_accuracy: 0.9067
#
# Epoch 00008: val_accuracy improved from 0.89556 to 0.90667, saving model to ./models/tree_8/model_root_f2/folder3\model.h5
# Epoch 9/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.1940 - accuracy: 0.9230 - val_loss: 0.2403 - val_accuracy: 0.9022
#
# Epoch 00009: val_accuracy did not improve from 0.90667
# Epoch 10/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1617 - accuracy: 0.9388 - val_loss: 0.2393 - val_accuracy: 0.9089
#
# Epoch 00010: val_accuracy improved from 0.90667 to 0.90889, saving model to ./models/tree_8/model_root_f2/folder3\model.h5
# Epoch 11/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.1348 - accuracy: 0.9514 - val_loss: 0.2922 - val_accuracy: 0.8867
#
# Epoch 00011: val_accuracy did not improve from 0.90889
# Epoch 12/25
# 127/127 [==============================] - 3s 24ms/step - loss: 0.1050 - accuracy: 0.9642 - val_loss: 0.2409 - val_accuracy: 0.9156
#
# Epoch 00012: val_accuracy improved from 0.90889 to 0.91556, saving model to ./models/tree_8/model_root_f2/folder3\model.h5
# Epoch 13/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.0910 - accuracy: 0.9659 - val_loss: 0.2287 - val_accuracy: 0.9222
#
# Epoch 00013: val_accuracy improved from 0.91556 to 0.92222, saving model to ./models/tree_8/model_root_f2/folder3\model.h5
# Epoch 14/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.0681 - accuracy: 0.9751 - val_loss: 0.3224 - val_accuracy: 0.9067
#
# Epoch 00014: val_accuracy did not improve from 0.92222
# Epoch 15/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.0479 - accuracy: 0.9822 - val_loss: 0.3162 - val_accuracy: 0.9067
#
# Epoch 00015: val_accuracy did not improve from 0.92222
# Epoch 16/25
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0536 - accuracy: 0.9810 - val_loss: 0.3081 - val_accuracy: 0.9067
#
# Epoch 00016: val_accuracy did not improve from 0.92222
# Epoch 17/25
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0168 - accuracy: 0.9963 - val_loss: 0.3059 - val_accuracy: 0.9067
#
# Epoch 00017: val_accuracy did not improve from 0.92222
# Epoch 18/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.0317 - accuracy: 0.9904 - val_loss: 0.3518 - val_accuracy: 0.9111
#
# Epoch 00018: val_accuracy did not improve from 0.92222
# Epoch 19/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.0378 - accuracy: 0.9872 - val_loss: 0.3481 - val_accuracy: 0.9000
#
# Epoch 00019: val_accuracy did not improve from 0.92222
# Epoch 20/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0169 - accuracy: 0.9951 - val_loss: 0.3993 - val_accuracy: 0.9089
#
# Epoch 00020: val_accuracy did not improve from 0.92222
# Epoch 21/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0132 - accuracy: 0.9963 - val_loss: 0.4311 - val_accuracy: 0.8933
#
# Epoch 00021: val_accuracy did not improve from 0.92222
# Epoch 22/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.0183 - accuracy: 0.9933 - val_loss: 0.5113 - val_accuracy: 0.8911
#
# Epoch 00022: val_accuracy did not improve from 0.92222
# Epoch 23/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0096 - accuracy: 0.9973 - val_loss: 0.4833 - val_accuracy: 0.9022
#
# Epoch 00023: val_accuracy did not improve from 0.92222
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 24/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.0077 - accuracy: 0.9980 - val_loss: 0.4328 - val_accuracy: 0.9022
#
# Epoch 00024: val_accuracy did not improve from 0.92222
# Epoch 25/25
# 127/127 [==============================] - 2s 20ms/step - loss: 7.3591e-04 - accuracy: 1.0000 - val_loss: 0.4418 - val_accuracy: 0.9044
#
# Epoch 00025: val_accuracy did not improve from 0.92222
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Classical', 'Hip-Hop'], ['Disco', 'Metal', 'Pop']]
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.6694 - accuracy: 0.6405 - val_loss: 0.5272 - val_accuracy: 0.7622
#
# Epoch 00001: val_accuracy improved from -inf to 0.76222, saving model to ./models/tree_8/model_root_f2/folder4\model.h5
# Epoch 2/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.4915 - accuracy: 0.7760 - val_loss: 0.4518 - val_accuracy: 0.7711
#
# Epoch 00002: val_accuracy improved from 0.76222 to 0.77111, saving model to ./models/tree_8/model_root_f2/folder4\model.h5
# Epoch 3/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.4124 - accuracy: 0.8170 - val_loss: 0.4051 - val_accuracy: 0.8333
#
# Epoch 00003: val_accuracy improved from 0.77111 to 0.83333, saving model to ./models/tree_8/model_root_f2/folder4\model.h5
# Epoch 4/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.3400 - accuracy: 0.8560 - val_loss: 0.2897 - val_accuracy: 0.8911
#
# Epoch 00004: val_accuracy improved from 0.83333 to 0.89111, saving model to ./models/tree_8/model_root_f2/folder4\model.h5
# Epoch 5/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.2688 - accuracy: 0.8933 - val_loss: 0.2404 - val_accuracy: 0.9022
#
# Epoch 00005: val_accuracy improved from 0.89111 to 0.90222, saving model to ./models/tree_8/model_root_f2/folder4\model.h5
# Epoch 6/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.1939 - accuracy: 0.9257 - val_loss: 0.2113 - val_accuracy: 0.9133
#
# Epoch 00006: val_accuracy improved from 0.90222 to 0.91333, saving model to ./models/tree_8/model_root_f2/folder4\model.h5
# Epoch 7/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1739 - accuracy: 0.9328 - val_loss: 0.3074 - val_accuracy: 0.8911
#
# Epoch 00007: val_accuracy did not improve from 0.91333
# Epoch 8/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1494 - accuracy: 0.9400 - val_loss: 0.1819 - val_accuracy: 0.9400
#
# Epoch 00008: val_accuracy improved from 0.91333 to 0.94000, saving model to ./models/tree_8/model_root_f2/folder4\model.h5
# Epoch 9/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.1293 - accuracy: 0.9481 - val_loss: 0.2042 - val_accuracy: 0.9133
#
# Epoch 00009: val_accuracy did not improve from 0.94000
# Epoch 10/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1043 - accuracy: 0.9590 - val_loss: 0.1464 - val_accuracy: 0.9511
#
# Epoch 00010: val_accuracy improved from 0.94000 to 0.95111, saving model to ./models/tree_8/model_root_f2/folder4\model.h5
# Epoch 11/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0689 - accuracy: 0.9733 - val_loss: 0.1414 - val_accuracy: 0.9422
#
# Epoch 00011: val_accuracy did not improve from 0.95111
# Epoch 12/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0394 - accuracy: 0.9874 - val_loss: 0.1410 - val_accuracy: 0.9578
#
# Epoch 00012: val_accuracy improved from 0.95111 to 0.95778, saving model to ./models/tree_8/model_root_f2/folder4\model.h5
# Epoch 13/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0330 - accuracy: 0.9904 - val_loss: 0.1855 - val_accuracy: 0.9444
#
# Epoch 00013: val_accuracy did not improve from 0.95778
# Epoch 14/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0720 - accuracy: 0.9704 - val_loss: 0.1425 - val_accuracy: 0.9333
#
# Epoch 00014: val_accuracy did not improve from 0.95778
# Epoch 15/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0318 - accuracy: 0.9894 - val_loss: 0.1286 - val_accuracy: 0.9533
#
# Epoch 00015: val_accuracy did not improve from 0.95778
# Epoch 16/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0300 - accuracy: 0.9899 - val_loss: 0.1492 - val_accuracy: 0.9556
#
# Epoch 00016: val_accuracy did not improve from 0.95778
# Epoch 17/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0123 - accuracy: 0.9963 - val_loss: 0.2683 - val_accuracy: 0.9156
#
# Epoch 00017: val_accuracy did not improve from 0.95778
# Epoch 18/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.0384 - accuracy: 0.9862 - val_loss: 0.2069 - val_accuracy: 0.9333
#
# Epoch 00018: val_accuracy did not improve from 0.95778
# Epoch 19/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0198 - accuracy: 0.9921 - val_loss: 0.3496 - val_accuracy: 0.9222
#
# Epoch 00019: val_accuracy did not improve from 0.95778
# Epoch 20/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0517 - accuracy: 0.9822 - val_loss: 0.1819 - val_accuracy: 0.9311
#
# Epoch 00020: val_accuracy did not improve from 0.95778
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0098 - accuracy: 0.9963 - val_loss: 0.1611 - val_accuracy: 0.9578
#
# Epoch 00021: val_accuracy did not improve from 0.95778
# Epoch 22/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9578
#
# Epoch 00022: val_accuracy did not improve from 0.95778
# Epoch 23/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1597 - val_accuracy: 0.9578
#
# Epoch 00023: val_accuracy did not improve from 0.95778
# Epoch 24/25
# 127/127 [==============================] - 3s 20ms/step - loss: 6.6213e-04 - accuracy: 1.0000 - val_loss: 0.1634 - val_accuracy: 0.9556
#
# Epoch 00024: val_accuracy did not improve from 0.95778
# Epoch 25/25
# 127/127 [==============================] - 2s 20ms/step - loss: 5.1799e-04 - accuracy: 1.0000 - val_loss: 0.1690 - val_accuracy: 0.9556
#
# Epoch 00025: val_accuracy did not improve from 0.95778
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 5
# Genre split [['Disco', 'Hip-Hop', 'Metal'], ['Classical', 'Pop']]
# Building model...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.5060 - accuracy: 0.7620 - val_loss: 0.2827 - val_accuracy: 0.8889
#
# Epoch 00001: val_accuracy improved from -inf to 0.88889, saving model to ./models/tree_8/model_root_f2/folder5\model.h5
# Epoch 2/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.2653 - accuracy: 0.8726 - val_loss: 0.2632 - val_accuracy: 0.8556
#
# Epoch 00002: val_accuracy did not improve from 0.88889
# Epoch 3/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.2347 - accuracy: 0.8886 - val_loss: 0.2151 - val_accuracy: 0.9067
#
# Epoch 00003: val_accuracy improved from 0.88889 to 0.90667, saving model to ./models/tree_8/model_root_f2/folder5\model.h5
# Epoch 4/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.2110 - accuracy: 0.9074 - val_loss: 0.2100 - val_accuracy: 0.8933
#
# Epoch 00004: val_accuracy did not improve from 0.90667
# Epoch 5/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1748 - accuracy: 0.9254 - val_loss: 0.1903 - val_accuracy: 0.9222
#
# Epoch 00005: val_accuracy improved from 0.90667 to 0.92222, saving model to ./models/tree_8/model_root_f2/folder5\model.h5
# Epoch 6/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1552 - accuracy: 0.9341 - val_loss: 0.1901 - val_accuracy: 0.9244
#
# Epoch 00006: val_accuracy improved from 0.92222 to 0.92444, saving model to ./models/tree_8/model_root_f2/folder5\model.h5
# Epoch 7/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.1395 - accuracy: 0.9407 - val_loss: 0.2057 - val_accuracy: 0.9044
#
# Epoch 00007: val_accuracy did not improve from 0.92444
# Epoch 8/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1258 - accuracy: 0.9447 - val_loss: 0.1566 - val_accuracy: 0.9289
#
# Epoch 00008: val_accuracy improved from 0.92444 to 0.92889, saving model to ./models/tree_8/model_root_f2/folder5\model.h5
# Epoch 9/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1063 - accuracy: 0.9563 - val_loss: 0.1692 - val_accuracy: 0.9200
#
# Epoch 00009: val_accuracy did not improve from 0.92889
# Epoch 10/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0913 - accuracy: 0.9620 - val_loss: 0.1481 - val_accuracy: 0.9356
#
# Epoch 00010: val_accuracy improved from 0.92889 to 0.93556, saving model to ./models/tree_8/model_root_f2/folder5\model.h5
# Epoch 11/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0759 - accuracy: 0.9689 - val_loss: 0.1691 - val_accuracy: 0.9289
#
# Epoch 00011: val_accuracy did not improve from 0.93556
# Epoch 12/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0838 - accuracy: 0.9681 - val_loss: 0.1441 - val_accuracy: 0.9378
#
# Epoch 00012: val_accuracy improved from 0.93556 to 0.93778, saving model to ./models/tree_8/model_root_f2/folder5\model.h5
# Epoch 13/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0564 - accuracy: 0.9793 - val_loss: 0.1095 - val_accuracy: 0.9511
#
# Epoch 00013: val_accuracy improved from 0.93778 to 0.95111, saving model to ./models/tree_8/model_root_f2/folder5\model.h5
# Epoch 14/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0408 - accuracy: 0.9854 - val_loss: 0.1575 - val_accuracy: 0.9467
#
# Epoch 00014: val_accuracy did not improve from 0.95111
# Epoch 15/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0457 - accuracy: 0.9827 - val_loss: 0.1414 - val_accuracy: 0.9400
#
# Epoch 00015: val_accuracy did not improve from 0.95111
# Epoch 16/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0285 - accuracy: 0.9891 - val_loss: 0.1041 - val_accuracy: 0.9489
#
# Epoch 00016: val_accuracy did not improve from 0.95111
# Epoch 17/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0196 - accuracy: 0.9926 - val_loss: 0.1571 - val_accuracy: 0.9467
#
# Epoch 00017: val_accuracy did not improve from 0.95111
# Epoch 18/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0236 - accuracy: 0.9916 - val_loss: 0.1674 - val_accuracy: 0.9533
#
# Epoch 00018: val_accuracy improved from 0.95111 to 0.95333, saving model to ./models/tree_8/model_root_f2/folder5\model.h5
# Epoch 19/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0118 - accuracy: 0.9956 - val_loss: 0.3270 - val_accuracy: 0.9067
#
# Epoch 00019: val_accuracy did not improve from 0.95333
# Epoch 20/25
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0150 - accuracy: 0.9956 - val_loss: 0.1740 - val_accuracy: 0.9356
#
# Epoch 00020: val_accuracy did not improve from 0.95333
# Epoch 21/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.9422
#
# Epoch 00021: val_accuracy did not improve from 0.95333
# Epoch 22/25
# 127/127 [==============================] - 3s 20ms/step - loss: 6.0066e-04 - accuracy: 1.0000 - val_loss: 0.1457 - val_accuracy: 0.9467
#
# Epoch 00022: val_accuracy did not improve from 0.95333
# Epoch 23/25
# 127/127 [==============================] - 3s 20ms/step - loss: 3.4664e-04 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9444
#
# Epoch 00023: val_accuracy did not improve from 0.95333
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 24/25
# 127/127 [==============================] - 2s 19ms/step - loss: 2.5733e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9444
#
# Epoch 00024: val_accuracy did not improve from 0.95333
# Epoch 25/25
# 127/127 [==============================] - 3s 20ms/step - loss: 2.2426e-04 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9422
#
# Epoch 00025: val_accuracy did not improve from 0.95333
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 6
# Genre split [['Classical', 'Hip-Hop', 'Metal'], ['Disco', 'Pop']]
# Building model...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.7307 - accuracy: 0.5862 - val_loss: 0.6633 - val_accuracy: 0.5756
#
# Epoch 00001: val_accuracy improved from -inf to 0.57556, saving model to ./models/tree_8/model_root_f2/folder6\model.h5
# Epoch 2/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.6298 - accuracy: 0.6380 - val_loss: 0.6209 - val_accuracy: 0.7422
#
# Epoch 00002: val_accuracy improved from 0.57556 to 0.74222, saving model to ./models/tree_8/model_root_f2/folder6\model.h5
# Epoch 3/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.5872 - accuracy: 0.6773 - val_loss: 0.5747 - val_accuracy: 0.6711
#
# Epoch 00003: val_accuracy did not improve from 0.74222
# Epoch 4/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.4975 - accuracy: 0.7501 - val_loss: 0.4253 - val_accuracy: 0.7933
#
# Epoch 00004: val_accuracy improved from 0.74222 to 0.79333, saving model to ./models/tree_8/model_root_f2/folder6\model.h5
# Epoch 5/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.4275 - accuracy: 0.8022 - val_loss: 0.3875 - val_accuracy: 0.8156
#
# Epoch 00005: val_accuracy improved from 0.79333 to 0.81556, saving model to ./models/tree_8/model_root_f2/folder6\model.h5
# Epoch 6/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.3945 - accuracy: 0.8237 - val_loss: 0.3862 - val_accuracy: 0.8133
#
# Epoch 00006: val_accuracy did not improve from 0.81556
# Epoch 7/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.3718 - accuracy: 0.8395 - val_loss: 0.3722 - val_accuracy: 0.8222
#
# Epoch 00007: val_accuracy improved from 0.81556 to 0.82222, saving model to ./models/tree_8/model_root_f2/folder6\model.h5
# Epoch 8/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.3451 - accuracy: 0.8536 - val_loss: 0.3190 - val_accuracy: 0.8422
#
# Epoch 00008: val_accuracy improved from 0.82222 to 0.84222, saving model to ./models/tree_8/model_root_f2/folder6\model.h5
# Epoch 9/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.3403 - accuracy: 0.8553 - val_loss: 0.3885 - val_accuracy: 0.8289
#
# Epoch 00009: val_accuracy did not improve from 0.84222
# Epoch 10/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.3394 - accuracy: 0.8595 - val_loss: 0.2973 - val_accuracy: 0.8556
#
# Epoch 00010: val_accuracy improved from 0.84222 to 0.85556, saving model to ./models/tree_8/model_root_f2/folder6\model.h5
# Epoch 11/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.3062 - accuracy: 0.8746 - val_loss: 0.2886 - val_accuracy: 0.8600
#
# Epoch 00011: val_accuracy improved from 0.85556 to 0.86000, saving model to ./models/tree_8/model_root_f2/folder6\model.h5
# Epoch 12/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.2845 - accuracy: 0.8820 - val_loss: 0.2658 - val_accuracy: 0.8956
#
# Epoch 00012: val_accuracy improved from 0.86000 to 0.89556, saving model to ./models/tree_8/model_root_f2/folder6\model.h5
# Epoch 13/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.2557 - accuracy: 0.8958 - val_loss: 0.2199 - val_accuracy: 0.9222
#
# Epoch 00013: val_accuracy improved from 0.89556 to 0.92222, saving model to ./models/tree_8/model_root_f2/folder6\model.h5
# Epoch 14/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.2235 - accuracy: 0.9136 - val_loss: 0.1650 - val_accuracy: 0.9467
#
# Epoch 00014: val_accuracy improved from 0.92222 to 0.94667, saving model to ./models/tree_8/model_root_f2/folder6\model.h5
# Epoch 15/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1858 - accuracy: 0.9299 - val_loss: 0.1664 - val_accuracy: 0.9422
#
# Epoch 00015: val_accuracy did not improve from 0.94667
# Epoch 16/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1593 - accuracy: 0.9385 - val_loss: 0.1744 - val_accuracy: 0.9289
#
# Epoch 00016: val_accuracy did not improve from 0.94667
# Epoch 17/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1522 - accuracy: 0.9395 - val_loss: 0.1488 - val_accuracy: 0.9422
#
# Epoch 00017: val_accuracy did not improve from 0.94667
# Epoch 18/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.1274 - accuracy: 0.9514 - val_loss: 0.1395 - val_accuracy: 0.9578
#
# Epoch 00018: val_accuracy improved from 0.94667 to 0.95778, saving model to ./models/tree_8/model_root_f2/folder6\model.h5
# Epoch 19/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.1191 - accuracy: 0.9551 - val_loss: 0.1274 - val_accuracy: 0.9556
#
# Epoch 00019: val_accuracy did not improve from 0.95778
# Epoch 20/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0904 - accuracy: 0.9659 - val_loss: 0.1122 - val_accuracy: 0.9667
#
# Epoch 00020: val_accuracy improved from 0.95778 to 0.96667, saving model to ./models/tree_8/model_root_f2/folder6\model.h5
# Epoch 21/25
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0688 - accuracy: 0.9770 - val_loss: 0.1725 - val_accuracy: 0.9400
#
# Epoch 00021: val_accuracy did not improve from 0.96667
# Epoch 22/25
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0614 - accuracy: 0.9785 - val_loss: 0.1283 - val_accuracy: 0.9578
#
# Epoch 00022: val_accuracy did not improve from 0.96667
# Epoch 23/25
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0534 - accuracy: 0.9783 - val_loss: 0.1329 - val_accuracy: 0.9556
#
# Epoch 00023: val_accuracy did not improve from 0.96667
# Epoch 24/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0395 - accuracy: 0.9857 - val_loss: 0.1589 - val_accuracy: 0.9489
#
# Epoch 00024: val_accuracy did not improve from 0.96667
# Epoch 25/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.0405 - accuracy: 0.9854 - val_loss: 0.1379 - val_accuracy: 0.9644
#
# Epoch 00025: val_accuracy did not improve from 0.96667
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 7
# Genre split [['Hip-Hop', 'Metal'], ['Classical', 'Disco', 'Pop']]
# Building model...
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 6, 6, 512)         0
# ...
#
# Epoch 00024: val_accuracy improved from 0.96222 to 0.96444, saving model to ./models/tree_8/model_root_f2/folder8\model.h5
# Epoch 25/25
# 127/127 [==============================] - 3s 20ms/step - loss: 4.3223e-04 - accuracy: 1.0000 - val_loss: 0.1630 - val_accuracy: 0.9600
#
# Epoch 00025: val_accuracy did not improve from 0.96444
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 9
# Genre split [['Disco', 'Metal'], ['Classical', 'Hip-Hop', 'Pop']]
# Building model...
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.5571 - accuracy: 0.7232 - val_loss: 0.4402 - val_accuracy: 0.8200
#
# Epoch 00001: val_accuracy improved from -inf to 0.82000, saving model to ./models/tree_8/model_root_f2/folder9\model.h5
# Epoch 2/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.4272 - accuracy: 0.8079 - val_loss: 0.4218 - val_accuracy: 0.8267
#
# Epoch 00002: val_accuracy improved from 0.82000 to 0.82667, saving model to ./models/tree_8/model_root_f2/folder9\model.h5
# Epoch 3/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.3838 - accuracy: 0.8286 - val_loss: 0.3778 - val_accuracy: 0.8467
#
# Epoch 00003: val_accuracy improved from 0.82667 to 0.84667, saving model to ./models/tree_8/model_root_f2/folder9\model.h5
# Epoch 4/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.3500 - accuracy: 0.8509 - val_loss: 0.3407 - val_accuracy: 0.8733
#
# Epoch 00004: val_accuracy improved from 0.84667 to 0.87333, saving model to ./models/tree_8/model_root_f2/folder9\model.h5
# Epoch 5/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.3168 - accuracy: 0.8642 - val_loss: 0.3970 - val_accuracy: 0.8311
#
# Epoch 00005: val_accuracy did not improve from 0.87333
# Epoch 6/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.2555 - accuracy: 0.8921 - val_loss: 0.2362 - val_accuracy: 0.9178
#
# Epoch 00006: val_accuracy improved from 0.87333 to 0.91778, saving model to ./models/tree_8/model_root_f2/folder9\model.h5
# Epoch 7/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.2018 - accuracy: 0.9222 - val_loss: 0.2252 - val_accuracy: 0.9244
#
# Epoch 00007: val_accuracy improved from 0.91778 to 0.92444, saving model to ./models/tree_8/model_root_f2/folder9\model.h5
# Epoch 8/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1607 - accuracy: 0.9378 - val_loss: 0.1667 - val_accuracy: 0.9489
#
# Epoch 00008: val_accuracy improved from 0.92444 to 0.94889, saving model to ./models/tree_8/model_root_f2/folder9\model.h5
# Epoch 9/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.1403 - accuracy: 0.9454 - val_loss: 0.1814 - val_accuracy: 0.9467
#
# Epoch 00009: val_accuracy did not improve from 0.94889
# Epoch 10/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1245 - accuracy: 0.9516 - val_loss: 0.1758 - val_accuracy: 0.9444
#
# Epoch 00010: val_accuracy did not improve from 0.94889
# Epoch 11/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1217 - accuracy: 0.9528 - val_loss: 0.1897 - val_accuracy: 0.9400
#
# Epoch 00011: val_accuracy did not improve from 0.94889
# Epoch 12/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0931 - accuracy: 0.9657 - val_loss: 0.1905 - val_accuracy: 0.9356
#
# Epoch 00012: val_accuracy did not improve from 0.94889
# Epoch 13/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.0743 - accuracy: 0.9733 - val_loss: 0.1367 - val_accuracy: 0.9578
#
# Epoch 00013: val_accuracy improved from 0.94889 to 0.95778, saving model to ./models/tree_8/model_root_f2/folder9\model.h5
# Epoch 14/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0468 - accuracy: 0.9820 - val_loss: 0.1776 - val_accuracy: 0.9600
#
# Epoch 00014: val_accuracy improved from 0.95778 to 0.96000, saving model to ./models/tree_8/model_root_f2/folder9\model.h5
# Epoch 15/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0380 - accuracy: 0.9881 - val_loss: 0.1740 - val_accuracy: 0.9556
#
# Epoch 00015: val_accuracy did not improve from 0.96000
# Epoch 16/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0344 - accuracy: 0.9886 - val_loss: 0.1719 - val_accuracy: 0.9600
#
# Epoch 00016: val_accuracy did not improve from 0.96000
# Epoch 17/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0212 - accuracy: 0.9931 - val_loss: 0.1952 - val_accuracy: 0.9578
#
# Epoch 00017: val_accuracy did not improve from 0.96000
# Epoch 18/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.0198 - accuracy: 0.9938 - val_loss: 0.3090 - val_accuracy: 0.9378
#
# Epoch 00018: val_accuracy did not improve from 0.96000
# Epoch 19/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.0426 - accuracy: 0.9840 - val_loss: 0.1901 - val_accuracy: 0.9622
#
# Epoch 00019: val_accuracy improved from 0.96000 to 0.96222, saving model to ./models/tree_8/model_root_f2/folder9\model.h5
# Epoch 20/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0150 - accuracy: 0.9948 - val_loss: 0.2293 - val_accuracy: 0.9489
#
# Epoch 00020: val_accuracy did not improve from 0.96222
# Epoch 21/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.2104 - val_accuracy: 0.9600
#
# Epoch 00021: val_accuracy did not improve from 0.96222
# Epoch 22/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0113 - accuracy: 0.9963 - val_loss: 0.2535 - val_accuracy: 0.9578
#
# Epoch 00022: val_accuracy did not improve from 0.96222
# Epoch 23/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.2318 - val_accuracy: 0.9667
#
# Epoch 00023: val_accuracy improved from 0.96222 to 0.96667, saving model to ./models/tree_8/model_root_f2/folder9\model.h5
# Epoch 24/25
# 127/127 [==============================] - 3s 20ms/step - loss: 5.5347e-04 - accuracy: 1.0000 - val_loss: 0.2371 - val_accuracy: 0.9622
#
# Epoch 00024: val_accuracy did not improve from 0.96667
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 25/25
# 127/127 [==============================] - 3s 20ms/step - loss: 2.8862e-04 - accuracy: 1.0000 - val_loss: 0.2395 - val_accuracy: 0.9622
#
# Epoch 00025: val_accuracy did not improve from 0.96667
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 10
# Genre split [['Classical', 'Metal'], ['Disco', 'Hip-Hop', 'Pop']]
# Building model...
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.5950 - accuracy: 0.7173 - val_loss: 0.4362 - val_accuracy: 0.8178
#
# Epoch 00001: val_accuracy improved from -inf to 0.81778, saving model to ./models/tree_8/model_root_f2/folder10\model.h5
# Epoch 2/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.2498 - accuracy: 0.9010 - val_loss: 0.2285 - val_accuracy: 0.9156
#
# Epoch 00002: val_accuracy improved from 0.81778 to 0.91556, saving model to ./models/tree_8/model_root_f2/folder10\model.h5
# Epoch 3/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1737 - accuracy: 0.9306 - val_loss: 0.2076 - val_accuracy: 0.9267
#
# Epoch 00003: val_accuracy improved from 0.91556 to 0.92667, saving model to ./models/tree_8/model_root_f2/folder10\model.h5
# Epoch 4/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1354 - accuracy: 0.9514 - val_loss: 0.4030 - val_accuracy: 0.8600
#
# Epoch 00004: val_accuracy did not improve from 0.92667
# Epoch 5/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1308 - accuracy: 0.9496 - val_loss: 0.1693 - val_accuracy: 0.9378
#
# Epoch 00005: val_accuracy improved from 0.92667 to 0.93778, saving model to ./models/tree_8/model_root_f2/folder10\model.h5
# Epoch 6/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0913 - accuracy: 0.9679 - val_loss: 0.1302 - val_accuracy: 0.9556
#
# Epoch 00006: val_accuracy improved from 0.93778 to 0.95556, saving model to ./models/tree_8/model_root_f2/folder10\model.h5
# Epoch 7/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0697 - accuracy: 0.9741 - val_loss: 0.1124 - val_accuracy: 0.9600
#
# Epoch 00007: val_accuracy improved from 0.95556 to 0.96000, saving model to ./models/tree_8/model_root_f2/folder10\model.h5
# Epoch 8/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0549 - accuracy: 0.9795 - val_loss: 0.1342 - val_accuracy: 0.9622
#
# Epoch 00008: val_accuracy improved from 0.96000 to 0.96222, saving model to ./models/tree_8/model_root_f2/folder10\model.h5
# Epoch 9/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0407 - accuracy: 0.9872 - val_loss: 0.3000 - val_accuracy: 0.9133
#
# Epoch 00009: val_accuracy did not improve from 0.96222
# Epoch 10/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0317 - accuracy: 0.9891 - val_loss: 0.1182 - val_accuracy: 0.9733
#
# Epoch 00010: val_accuracy improved from 0.96222 to 0.97333, saving model to ./models/tree_8/model_root_f2/folder10\model.h5
# Epoch 11/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0431 - accuracy: 0.9847 - val_loss: 0.1492 - val_accuracy: 0.9533
#
# Epoch 00011: val_accuracy did not improve from 0.97333
# Epoch 12/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0263 - accuracy: 0.9923 - val_loss: 0.1360 - val_accuracy: 0.9644
#
# Epoch 00012: val_accuracy did not improve from 0.97333
# Epoch 13/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0168 - accuracy: 0.9936 - val_loss: 0.1229 - val_accuracy: 0.9711
#
# Epoch 00013: val_accuracy did not improve from 0.97333
# Epoch 14/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0040 - accuracy: 0.9998 - val_loss: 0.1446 - val_accuracy: 0.9622
#
# Epoch 00014: val_accuracy did not improve from 0.97333
# Epoch 15/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0108 - accuracy: 0.9960 - val_loss: 0.1497 - val_accuracy: 0.9622
#
# Epoch 00015: val_accuracy did not improve from 0.97333
# Epoch 16/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0642 - accuracy: 0.9765 - val_loss: 0.1671 - val_accuracy: 0.9533
#
# Epoch 00016: val_accuracy did not improve from 0.97333
# Epoch 17/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0400 - accuracy: 0.9859 - val_loss: 0.1704 - val_accuracy: 0.9578
#
# Epoch 00017: val_accuracy did not improve from 0.97333
# Epoch 18/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0180 - accuracy: 0.9936 - val_loss: 0.1646 - val_accuracy: 0.9689
#
# Epoch 00018: val_accuracy did not improve from 0.97333
# Epoch 19/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0053 - accuracy: 0.9988 - val_loss: 0.1886 - val_accuracy: 0.9644
#
# Epoch 00019: val_accuracy did not improve from 0.97333
# Epoch 20/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.1550 - val_accuracy: 0.9711
#
# Epoch 00020: val_accuracy did not improve from 0.97333
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/25
# 127/127 [==============================] - 3s 20ms/step - loss: 3.2867e-04 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.9733
#
# Epoch 00021: val_accuracy did not improve from 0.97333
# Epoch 22/25
# 127/127 [==============================] - 3s 20ms/step - loss: 2.2631e-04 - accuracy: 1.0000 - val_loss: 0.1610 - val_accuracy: 0.9733
#
# Epoch 00022: val_accuracy did not improve from 0.97333
# Epoch 23/25
# 127/127 [==============================] - 3s 20ms/step - loss: 1.8657e-04 - accuracy: 1.0000 - val_loss: 0.1642 - val_accuracy: 0.9733
#
# Epoch 00023: val_accuracy did not improve from 0.97333
# Epoch 24/25
# 127/127 [==============================] - 3s 20ms/step - loss: 1.5690e-04 - accuracy: 1.0000 - val_loss: 0.1668 - val_accuracy: 0.9711
#
# Epoch 00024: val_accuracy did not improve from 0.97333
# Epoch 25/25
# 127/127 [==============================] - 3s 20ms/step - loss: 1.3890e-04 - accuracy: 1.0000 - val_loss: 0.1695 - val_accuracy: 0.9711
#
# Epoch 00025: val_accuracy did not improve from 0.97333
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
