# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Blues':0, 'Jazz':5, 'Reggae':8}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Blues', 5: 'Jazz', 8: 'Reggae'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((2390, 128, 128), (2390, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((300, 128, 128), (300, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Reggae

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 25

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_8/model_root_f1_2/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_8/model_root_f1_2/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def create_split(elem):
    splits = list(set_partitions(elem, 2))
    
    return splits, len(splits)

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

genre_splits, num_splits = create_split(list(dict_genres.values()))
print("Num splits {}".format(num_splits))

if num_splits > 8:
    n_splits = num_splits
else:
    n_splits = 8

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Num splits 3
# Folder num 1
# Genre split [['Blues'], ['Jazz', 'Reggae']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 74/74 [==============================] - 5s 28ms/step - loss: 0.8367 - accuracy: 0.6464 - val_loss: 0.6370 - val_accuracy: 0.6766
#
# Epoch 00001: val_accuracy improved from -inf to 0.67656, saving model to ./models/tree_8/model_root_f1_2/folder1\model.h5
# Epoch 2/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.6415 - accuracy: 0.6638 - val_loss: 0.6277 - val_accuracy: 0.6766
#
# Epoch 00002: val_accuracy did not improve from 0.67656
# Epoch 3/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.6333 - accuracy: 0.6638 - val_loss: 0.6102 - val_accuracy: 0.6973
#
# Epoch 00003: val_accuracy improved from 0.67656 to 0.69733, saving model to ./models/tree_8/model_root_f1_2/folder1\model.h5
# Epoch 4/25
# 74/74 [==============================] - 2s 22ms/step - loss: 0.5933 - accuracy: 0.6855 - val_loss: 0.6771 - val_accuracy: 0.6202
#
# Epoch 00004: val_accuracy did not improve from 0.69733
# Epoch 5/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.5401 - accuracy: 0.7293 - val_loss: 0.5158 - val_accuracy: 0.7418
#
# Epoch 00005: val_accuracy improved from 0.69733 to 0.74184, saving model to ./models/tree_8/model_root_f1_2/folder1\model.h5
# Epoch 6/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.4642 - accuracy: 0.7731 - val_loss: 0.5498 - val_accuracy: 0.7567
#
# Epoch 00006: val_accuracy improved from 0.74184 to 0.75668, saving model to ./models/tree_8/model_root_f1_2/folder1\model.h5
# Epoch 7/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.4410 - accuracy: 0.7858 - val_loss: 0.4915 - val_accuracy: 0.7537
#
# Epoch 00007: val_accuracy did not improve from 0.75668
# Epoch 8/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.3924 - accuracy: 0.8151 - val_loss: 0.4495 - val_accuracy: 0.7834
#
# Epoch 00008: val_accuracy improved from 0.75668 to 0.78338, saving model to ./models/tree_8/model_root_f1_2/folder1\model.h5
# Epoch 9/25
# 74/74 [==============================] - 1s 19ms/step - loss: 0.3184 - accuracy: 0.8610 - val_loss: 0.4261 - val_accuracy: 0.7923
#
# Epoch 00009: val_accuracy improved from 0.78338 to 0.79228, saving model to ./models/tree_8/model_root_f1_2/folder1\model.h5
# Epoch 10/25
# 74/74 [==============================] - 2s 21ms/step - loss: 0.2983 - accuracy: 0.8704 - val_loss: 0.3759 - val_accuracy: 0.8279
#
# Epoch 00010: val_accuracy improved from 0.79228 to 0.82789, saving model to ./models/tree_8/model_root_f1_2/folder1\model.h5
# Epoch 11/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.2436 - accuracy: 0.9048 - val_loss: 0.3286 - val_accuracy: 0.8487
#
# Epoch 00011: val_accuracy improved from 0.82789 to 0.84866, saving model to ./models/tree_8/model_root_f1_2/folder1\model.h5
# Epoch 12/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.2379 - accuracy: 0.8984 - val_loss: 0.3059 - val_accuracy: 0.8576
#
# Epoch 00012: val_accuracy improved from 0.84866 to 0.85757, saving model to ./models/tree_8/model_root_f1_2/folder1\model.h5
# Epoch 13/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.1783 - accuracy: 0.9273 - val_loss: 0.2782 - val_accuracy: 0.8813
#
# Epoch 00013: val_accuracy improved from 0.85757 to 0.88131, saving model to ./models/tree_8/model_root_f1_2/folder1\model.h5
# Epoch 14/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.1433 - accuracy: 0.9448 - val_loss: 0.3223 - val_accuracy: 0.8576
#
# Epoch 00014: val_accuracy did not improve from 0.88131
# Epoch 15/25
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1063 - accuracy: 0.9613 - val_loss: 0.2662 - val_accuracy: 0.8902
#
# Epoch 00015: val_accuracy improved from 0.88131 to 0.89021, saving model to ./models/tree_8/model_root_f1_2/folder1\model.h5
# Epoch 16/25
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1269 - accuracy: 0.9473 - val_loss: 0.2734 - val_accuracy: 0.8754
#
# Epoch 00016: val_accuracy did not improve from 0.89021
# Epoch 17/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0757 - accuracy: 0.9741 - val_loss: 0.2609 - val_accuracy: 0.8932
#
# Epoch 00017: val_accuracy improved from 0.89021 to 0.89318, saving model to ./models/tree_8/model_root_f1_2/folder1\model.h5
# Epoch 18/25
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0382 - accuracy: 0.9919 - val_loss: 0.3031 - val_accuracy: 0.9021
#
# Epoch 00018: val_accuracy improved from 0.89318 to 0.90208, saving model to ./models/tree_8/model_root_f1_2/folder1\model.h5
# Epoch 19/25
# 74/74 [==============================] - 2s 20ms/step - loss: 0.0276 - accuracy: 0.9915 - val_loss: 0.2861 - val_accuracy: 0.9050
#
# Epoch 00019: val_accuracy improved from 0.90208 to 0.90504, saving model to ./models/tree_8/model_root_f1_2/folder1\model.h5
# Epoch 20/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0126 - accuracy: 0.9983 - val_loss: 0.2871 - val_accuracy: 0.9050
#
# Epoch 00020: val_accuracy did not improve from 0.90504
# Epoch 21/25
# 74/74 [==============================] - 2s 21ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.3039 - val_accuracy: 0.9080
#
# Epoch 00021: val_accuracy improved from 0.90504 to 0.90801, saving model to ./models/tree_8/model_root_f1_2/folder1\model.h5
# Epoch 22/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.3420 - val_accuracy: 0.9110
#
# Epoch 00022: val_accuracy improved from 0.90801 to 0.91098, saving model to ./models/tree_8/model_root_f1_2/folder1\model.h5
# Epoch 23/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.3540 - val_accuracy: 0.9139
#
# Epoch 00023: val_accuracy improved from 0.91098 to 0.91395, saving model to ./models/tree_8/model_root_f1_2/folder1\model.h5
# Epoch 24/25
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3402 - val_accuracy: 0.9080
#
# Epoch 00024: val_accuracy did not improve from 0.91395
# Epoch 25/25
# 74/74 [==============================] - 1s 20ms/step - loss: 9.9755e-04 - accuracy: 1.0000 - val_loss: 0.3399 - val_accuracy: 0.9080
#
# Epoch 00025: val_accuracy did not improve from 0.91395
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Blues', 'Jazz'], ['Reggae']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 74/74 [==============================] - 2s 22ms/step - loss: 0.8708 - accuracy: 0.6409 - val_loss: 0.6434 - val_accuracy: 0.6528
#
# Epoch 00001: val_accuracy improved from -inf to 0.65282, saving model to ./models/tree_8/model_root_f1_2/folder2\model.h5
# Epoch 2/25
# 74/74 [==============================] - 1s 19ms/step - loss: 0.5009 - accuracy: 0.7510 - val_loss: 0.4800 - val_accuracy: 0.7864
#
# Epoch 00002: val_accuracy improved from 0.65282 to 0.78635, saving model to ./models/tree_8/model_root_f1_2/folder2\model.h5
# Epoch 3/25
# 74/74 [==============================] - 1s 19ms/step - loss: 0.4199 - accuracy: 0.8117 - val_loss: 0.4006 - val_accuracy: 0.8368
#
# Epoch 00003: val_accuracy improved from 0.78635 to 0.83680, saving model to ./models/tree_8/model_root_f1_2/folder2\model.h5
# Epoch 4/25
# 74/74 [==============================] - 1s 19ms/step - loss: 0.3371 - accuracy: 0.8491 - val_loss: 0.3506 - val_accuracy: 0.8338
#
# Epoch 00004: val_accuracy did not improve from 0.83680
# Epoch 5/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.2504 - accuracy: 0.9006 - val_loss: 0.2769 - val_accuracy: 0.8754
#
# Epoch 00005: val_accuracy improved from 0.83680 to 0.87537, saving model to ./models/tree_8/model_root_f1_2/folder2\model.h5
# Epoch 6/25
# 74/74 [==============================] - 2s 21ms/step - loss: 0.1849 - accuracy: 0.9282 - val_loss: 0.2136 - val_accuracy: 0.9050
#
# Epoch 00006: val_accuracy improved from 0.87537 to 0.90504, saving model to ./models/tree_8/model_root_f1_2/folder2\model.h5
# Epoch 7/25
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1941 - accuracy: 0.9163 - val_loss: 0.3596 - val_accuracy: 0.8665
#
# Epoch 00007: val_accuracy did not improve from 0.90504
# Epoch 8/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.1292 - accuracy: 0.9494 - val_loss: 0.1727 - val_accuracy: 0.9347
#
# Epoch 00008: val_accuracy improved from 0.90504 to 0.93472, saving model to ./models/tree_8/model_root_f1_2/folder2\model.h5
# Epoch 9/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0750 - accuracy: 0.9737 - val_loss: 0.2062 - val_accuracy: 0.9080
#
# Epoch 00009: val_accuracy did not improve from 0.93472
# Epoch 10/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0495 - accuracy: 0.9796 - val_loss: 0.2151 - val_accuracy: 0.9199
#
# Epoch 00010: val_accuracy did not improve from 0.93472
# Epoch 11/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0486 - accuracy: 0.9834 - val_loss: 0.1639 - val_accuracy: 0.9288
#
# Epoch 00011: val_accuracy did not improve from 0.93472
# Epoch 12/25
# 74/74 [==============================] - 2s 23ms/step - loss: 0.0185 - accuracy: 0.9953 - val_loss: 0.2111 - val_accuracy: 0.9169
#
# Epoch 00012: val_accuracy did not improve from 0.93472
# Epoch 13/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0062 - accuracy: 0.9996 - val_loss: 0.1108 - val_accuracy: 0.9614
#
# Epoch 00013: val_accuracy improved from 0.93472 to 0.96142, saving model to ./models/tree_8/model_root_f1_2/folder2\model.h5
# Epoch 14/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1227 - val_accuracy: 0.9555
#
# Epoch 00014: val_accuracy did not improve from 0.96142
# Epoch 15/25
# 74/74 [==============================] - 1s 20ms/step - loss: 9.8279e-04 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9525
#
# Epoch 00015: val_accuracy did not improve from 0.96142
# Epoch 16/25
# 74/74 [==============================] - 1s 20ms/step - loss: 6.5097e-04 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9585
#
# Epoch 00016: val_accuracy did not improve from 0.96142
# Epoch 17/25
# 74/74 [==============================] - 1s 20ms/step - loss: 4.9136e-04 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9614
#
# Epoch 00017: val_accuracy did not improve from 0.96142
# Epoch 18/25
# 74/74 [==============================] - 1s 19ms/step - loss: 4.1028e-04 - accuracy: 1.0000 - val_loss: 0.1184 - val_accuracy: 0.9555
#
# Epoch 00018: val_accuracy did not improve from 0.96142
# Epoch 19/25
# 74/74 [==============================] - 2s 20ms/step - loss: 3.3541e-04 - accuracy: 1.0000 - val_loss: 0.1191 - val_accuracy: 0.9585
#
# Epoch 00019: val_accuracy did not improve from 0.96142
# Epoch 20/25
# 74/74 [==============================] - 1s 19ms/step - loss: 2.9898e-04 - accuracy: 1.0000 - val_loss: 0.1200 - val_accuracy: 0.9585
#
# Epoch 00020: val_accuracy did not improve from 0.96142
# Epoch 21/25
# 74/74 [==============================] - 1s 20ms/step - loss: 2.3905e-04 - accuracy: 1.0000 - val_loss: 0.1222 - val_accuracy: 0.9555
#
# Epoch 00021: val_accuracy did not improve from 0.96142
# Epoch 22/25
# 74/74 [==============================] - 1s 19ms/step - loss: 2.0959e-04 - accuracy: 1.0000 - val_loss: 0.1220 - val_accuracy: 0.9614
#
# Epoch 00022: val_accuracy did not improve from 0.96142
# Epoch 23/25
# 74/74 [==============================] - 2s 20ms/step - loss: 1.9472e-04 - accuracy: 1.0000 - val_loss: 0.1215 - val_accuracy: 0.9555
#
# Epoch 00023: val_accuracy did not improve from 0.96142
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 24/25
# 74/74 [==============================] - 1s 20ms/step - loss: 1.6630e-04 - accuracy: 1.0000 - val_loss: 0.1226 - val_accuracy: 0.9614
#
# Epoch 00024: val_accuracy did not improve from 0.96142
# Epoch 25/25
# 74/74 [==============================] - 1s 20ms/step - loss: 1.5562e-04 - accuracy: 1.0000 - val_loss: 0.1233 - val_accuracy: 0.9555
#
# Epoch 00025: val_accuracy did not improve from 0.96142
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Jazz'], ['Blues', 'Reggae']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 74/74 [==============================] - 3s 29ms/step - loss: 0.7179 - accuracy: 0.6572 - val_loss: 0.4917 - val_accuracy: 0.7083
#
# Epoch 00001: val_accuracy improved from -inf to 0.70833, saving model to ./models/tree_8/model_root_f1_2/folder3\model.h5
# Epoch 2/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.4468 - accuracy: 0.7808 - val_loss: 0.3611 - val_accuracy: 0.8244
#
# Epoch 00002: val_accuracy improved from 0.70833 to 0.82440, saving model to ./models/tree_8/model_root_f1_2/folder3\model.h5
# Epoch 3/25
# 74/74 [==============================] - 1s 19ms/step - loss: 0.3506 - accuracy: 0.8407 - val_loss: 0.2415 - val_accuracy: 0.9167
#
# Epoch 00003: val_accuracy improved from 0.82440 to 0.91667, saving model to ./models/tree_8/model_root_f1_2/folder3\model.h5
# Epoch 4/25
# 74/74 [==============================] - 1s 19ms/step - loss: 0.2473 - accuracy: 0.8972 - val_loss: 0.2242 - val_accuracy: 0.8929
#
# Epoch 00004: val_accuracy did not improve from 0.91667
# Epoch 5/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.1708 - accuracy: 0.9380 - val_loss: 0.2124 - val_accuracy: 0.9196
#
# Epoch 00005: val_accuracy improved from 0.91667 to 0.91964, saving model to ./models/tree_8/model_root_f1_2/folder3\model.h5
# Epoch 6/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.1346 - accuracy: 0.9499 - val_loss: 0.1627 - val_accuracy: 0.9375
#
# Epoch 00006: val_accuracy improved from 0.91964 to 0.93750, saving model to ./models/tree_8/model_root_f1_2/folder3\model.h5
# Epoch 7/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.1079 - accuracy: 0.9609 - val_loss: 0.1577 - val_accuracy: 0.9524
#
# Epoch 00007: val_accuracy improved from 0.93750 to 0.95238, saving model to ./models/tree_8/model_root_f1_2/folder3\model.h5
# Epoch 8/25
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0755 - accuracy: 0.9771 - val_loss: 0.1024 - val_accuracy: 0.9673
#
# Epoch 00008: val_accuracy improved from 0.95238 to 0.96726, saving model to ./models/tree_8/model_root_f1_2/folder3\model.h5
# Epoch 9/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0362 - accuracy: 0.9898 - val_loss: 0.1352 - val_accuracy: 0.9613
#
# Epoch 00009: val_accuracy did not improve from 0.96726
# Epoch 10/25
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0859 - accuracy: 0.9681 - val_loss: 0.1554 - val_accuracy: 0.9435
#
# Epoch 00010: val_accuracy did not improve from 0.96726
# Epoch 11/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0516 - accuracy: 0.9800 - val_loss: 0.1300 - val_accuracy: 0.9583
#
# Epoch 00011: val_accuracy did not improve from 0.96726
# Epoch 12/25
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0215 - accuracy: 0.9928 - val_loss: 0.1452 - val_accuracy: 0.9494
#
# Epoch 00012: val_accuracy did not improve from 0.96726
# Epoch 13/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0144 - accuracy: 0.9949 - val_loss: 0.1115 - val_accuracy: 0.9732
#
# Epoch 00013: val_accuracy improved from 0.96726 to 0.97321, saving model to ./models/tree_8/model_root_f1_2/folder3\model.h5
# Epoch 14/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.1453 - val_accuracy: 0.9643
#
# Epoch 00014: val_accuracy did not improve from 0.97321
# Epoch 15/25
# 74/74 [==============================] - 2s 22ms/step - loss: 0.0458 - accuracy: 0.9809 - val_loss: 0.1699 - val_accuracy: 0.9554
#
# Epoch 00015: val_accuracy did not improve from 0.97321
# Epoch 16/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0286 - accuracy: 0.9894 - val_loss: 0.1738 - val_accuracy: 0.9613
#
# Epoch 00016: val_accuracy did not improve from 0.97321
# Epoch 17/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0097 - accuracy: 0.9966 - val_loss: 0.1491 - val_accuracy: 0.9643
#
# Epoch 00017: val_accuracy did not improve from 0.97321
# Epoch 18/25
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0026 - accuracy: 0.9996 - val_loss: 0.1393 - val_accuracy: 0.9702
#
# Epoch 00018: val_accuracy did not improve from 0.97321
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 19/25
# 74/74 [==============================] - 1s 19ms/step - loss: 6.0404e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9702
#
# Epoch 00019: val_accuracy did not improve from 0.97321
# Epoch 20/25
# 74/74 [==============================] - 1s 20ms/step - loss: 4.3884e-04 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9673
#
# Epoch 00020: val_accuracy did not improve from 0.97321
# Epoch 21/25
# 74/74 [==============================] - 2s 20ms/step - loss: 3.0882e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9702
#
# Epoch 00021: val_accuracy did not improve from 0.97321
# Epoch 22/25
# 74/74 [==============================] - 2s 21ms/step - loss: 2.7024e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9702
#
# Epoch 00022: val_accuracy did not improve from 0.97321
# Epoch 23/25
# 74/74 [==============================] - 1s 20ms/step - loss: 2.4052e-04 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9673
#
# Epoch 00023: val_accuracy did not improve from 0.97321
# Epoch 24/25
# 74/74 [==============================] - 1s 20ms/step - loss: 2.1880e-04 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9673
#
# Epoch 00024: val_accuracy did not improve from 0.97321
# Epoch 25/25
# 74/74 [==============================] - 1s 20ms/step - loss: 1.9940e-04 - accuracy: 1.0000 - val_loss: 0.1535 - val_accuracy: 0.9702
#
# Epoch 00025: val_accuracy did not improve from 0.97321
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
