# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Disco':3, 'Hip-Hop':4, 'Pop':7}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {3: 'Disco', 4: 'Hip-Hop', 7: 'Pop'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((2400, 128, 128), (2400, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((300, 128, 128), (300, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Disco

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 25

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_8/model_root_f2_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_8/model_root_f2_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def create_split(elem):
    splits = list(set_partitions(elem, 2))

    return splits, len(splits)

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

genre_splits, num_splits = create_split(list(dict_genres.values()))
print("Num splits {}".format(num_splits))

if num_splits > 8:
    n_splits = num_splits
else:
    n_splits = 8

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Num splits 3
# Folder num 1
# Genre split [['Disco'], ['Hip-Hop', 'Pop']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 74/74 [==============================] - 5s 29ms/step - loss: 0.7117 - accuracy: 0.6511 - val_loss: 0.5961 - val_accuracy: 0.6627
#
# Epoch 00001: val_accuracy improved from -inf to 0.66272, saving model to ./models/tree_8/model_root_f2_1/folder1\model.h5
# Epoch 2/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.5574 - accuracy: 0.7096 - val_loss: 0.5019 - val_accuracy: 0.7574
#
# Epoch 00002: val_accuracy improved from 0.66272 to 0.75740, saving model to ./models/tree_8/model_root_f2_1/folder1\model.h5
# Epoch 3/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.5071 - accuracy: 0.7515 - val_loss: 0.4727 - val_accuracy: 0.7899
#
# Epoch 00003: val_accuracy improved from 0.75740 to 0.78994, saving model to ./models/tree_8/model_root_f2_1/folder1\model.h5
# Epoch 4/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.4714 - accuracy: 0.7701 - val_loss: 0.4347 - val_accuracy: 0.7959
#
# Epoch 00004: val_accuracy improved from 0.78994 to 0.79586, saving model to ./models/tree_8/model_root_f2_1/folder1\model.h5
# Epoch 5/25
# 74/74 [==============================] - 2s 21ms/step - loss: 0.4375 - accuracy: 0.7925 - val_loss: 0.4414 - val_accuracy: 0.7781
#
# Epoch 00005: val_accuracy did not improve from 0.79586
# Epoch 6/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.4313 - accuracy: 0.7972 - val_loss: 0.4138 - val_accuracy: 0.8107
#
# Epoch 00006: val_accuracy improved from 0.79586 to 0.81065, saving model to ./models/tree_8/model_root_f2_1/folder1\model.h5
# Epoch 7/25
# 74/74 [==============================] - 2s 21ms/step - loss: 0.3581 - accuracy: 0.8383 - val_loss: 0.3231 - val_accuracy: 0.8580
#
# Epoch 00007: val_accuracy improved from 0.81065 to 0.85799, saving model to ./models/tree_8/model_root_f2_1/folder1\model.h5
# Epoch 8/25
# 74/74 [==============================] - 2s 21ms/step - loss: 0.2852 - accuracy: 0.8793 - val_loss: 0.2867 - val_accuracy: 0.8846
#
# Epoch 00008: val_accuracy improved from 0.85799 to 0.88462, saving model to ./models/tree_8/model_root_f2_1/folder1\model.h5
# Epoch 9/25
# 74/74 [==============================] - 2s 21ms/step - loss: 0.2155 - accuracy: 0.9204 - val_loss: 0.2314 - val_accuracy: 0.8964
#
# Epoch 00009: val_accuracy improved from 0.88462 to 0.89645, saving model to ./models/tree_8/model_root_f2_1/folder1\model.h5
# Epoch 10/25
# 74/74 [==============================] - 2s 22ms/step - loss: 0.1906 - accuracy: 0.9246 - val_loss: 0.2125 - val_accuracy: 0.9172
#
# Epoch 00010: val_accuracy improved from 0.89645 to 0.91716, saving model to ./models/tree_8/model_root_f2_1/folder1\model.h5
# Epoch 11/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.1468 - accuracy: 0.9420 - val_loss: 0.2068 - val_accuracy: 0.9142
#
# Epoch 00011: val_accuracy did not improve from 0.91716
# Epoch 12/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.1125 - accuracy: 0.9539 - val_loss: 0.1862 - val_accuracy: 0.9172
#
# Epoch 00012: val_accuracy did not improve from 0.91716
# Epoch 13/25
# 74/74 [==============================] - 2s 21ms/step - loss: 0.1177 - accuracy: 0.9534 - val_loss: 0.2567 - val_accuracy: 0.9024
#
# Epoch 00013: val_accuracy did not improve from 0.91716
# Epoch 14/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0679 - accuracy: 0.9767 - val_loss: 0.1770 - val_accuracy: 0.9320
#
# Epoch 00014: val_accuracy improved from 0.91716 to 0.93195, saving model to ./models/tree_8/model_root_f2_1/folder1\model.h5
# Epoch 15/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0403 - accuracy: 0.9877 - val_loss: 0.1990 - val_accuracy: 0.9172
#
# Epoch 00015: val_accuracy did not improve from 0.93195
# Epoch 16/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0503 - accuracy: 0.9835 - val_loss: 0.1850 - val_accuracy: 0.9320
#
# Epoch 00016: val_accuracy did not improve from 0.93195
# Epoch 17/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0311 - accuracy: 0.9911 - val_loss: 0.1573 - val_accuracy: 0.9467
#
# Epoch 00017: val_accuracy improved from 0.93195 to 0.94675, saving model to ./models/tree_8/model_root_f2_1/folder1\model.h5
# Epoch 18/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0088 - accuracy: 0.9996 - val_loss: 0.1835 - val_accuracy: 0.9467
#
# Epoch 00018: val_accuracy did not improve from 0.94675
# Epoch 19/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1639 - val_accuracy: 0.9497
#
# Epoch 00019: val_accuracy improved from 0.94675 to 0.94970, saving model to ./models/tree_8/model_root_f2_1/folder1\model.h5
# Epoch 20/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9497
#
# Epoch 00020: val_accuracy did not improve from 0.94970
# Epoch 21/25
# 74/74 [==============================] - 1s 20ms/step - loss: 9.4737e-04 - accuracy: 1.0000 - val_loss: 0.1636 - val_accuracy: 0.9527
#
# Epoch 00021: val_accuracy improved from 0.94970 to 0.95266, saving model to ./models/tree_8/model_root_f2_1/folder1\model.h5
# Epoch 22/25
# 74/74 [==============================] - 1s 20ms/step - loss: 7.4279e-04 - accuracy: 1.0000 - val_loss: 0.1747 - val_accuracy: 0.9497
#
# Epoch 00022: val_accuracy did not improve from 0.95266
# Epoch 23/25
# 74/74 [==============================] - 1s 20ms/step - loss: 6.0261e-04 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9527
#
# Epoch 00023: val_accuracy did not improve from 0.95266
# Epoch 24/25
# 74/74 [==============================] - 1s 20ms/step - loss: 5.1732e-04 - accuracy: 1.0000 - val_loss: 0.1703 - val_accuracy: 0.9497
#
# Epoch 00024: val_accuracy did not improve from 0.95266
# Epoch 25/25
# 74/74 [==============================] - 1s 20ms/step - loss: 4.3622e-04 - accuracy: 1.0000 - val_loss: 0.1748 - val_accuracy: 0.9527
#
# Epoch 00025: val_accuracy did not improve from 0.95266
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Disco', 'Hip-Hop'], ['Pop']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 74/74 [==============================] - 2s 23ms/step - loss: 0.7202 - accuracy: 0.6554 - val_loss: 0.6225 - val_accuracy: 0.6686
#
# Epoch 00001: val_accuracy improved from -inf to 0.66864, saving model to ./models/tree_8/model_root_f2_1/folder2\model.h5
# Epoch 2/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.4300 - accuracy: 0.7722 - val_loss: 0.3637 - val_accuracy: 0.8373
#
# Epoch 00002: val_accuracy improved from 0.66864 to 0.83728, saving model to ./models/tree_8/model_root_f2_1/folder2\model.h5
# Epoch 3/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.3430 - accuracy: 0.8370 - val_loss: 0.3406 - val_accuracy: 0.8609
#
# Epoch 00003: val_accuracy improved from 0.83728 to 0.86095, saving model to ./models/tree_8/model_root_f2_1/folder2\model.h5
# Epoch 4/25
# 74/74 [==============================] - 2s 21ms/step - loss: 0.3159 - accuracy: 0.8577 - val_loss: 0.3237 - val_accuracy: 0.8757
#
# Epoch 00004: val_accuracy improved from 0.86095 to 0.87574, saving model to ./models/tree_8/model_root_f2_1/folder2\model.h5
# Epoch 5/25
# 74/74 [==============================] - 2s 20ms/step - loss: 0.2954 - accuracy: 0.8641 - val_loss: 0.3016 - val_accuracy: 0.8728
#
# Epoch 00005: val_accuracy did not improve from 0.87574
# Epoch 6/25
# 74/74 [==============================] - 2s 21ms/step - loss: 0.2722 - accuracy: 0.8823 - val_loss: 0.2980 - val_accuracy: 0.8728
#
# Epoch 00006: val_accuracy did not improve from 0.87574
# Epoch 7/25
# 74/74 [==============================] - 2s 20ms/step - loss: 0.2525 - accuracy: 0.8959 - val_loss: 0.3018 - val_accuracy: 0.8905
#
# Epoch 00007: val_accuracy improved from 0.87574 to 0.89053, saving model to ./models/tree_8/model_root_f2_1/folder2\model.h5
# Epoch 8/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.2454 - accuracy: 0.9005 - val_loss: 0.3296 - val_accuracy: 0.8521
#
# Epoch 00008: val_accuracy did not improve from 0.89053
# Epoch 9/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.2438 - accuracy: 0.8929 - val_loss: 0.3659 - val_accuracy: 0.8462
#
# Epoch 00009: val_accuracy did not improve from 0.89053
# Epoch 10/25
# 74/74 [==============================] - 2s 20ms/step - loss: 0.2456 - accuracy: 0.8967 - val_loss: 0.2722 - val_accuracy: 0.8994
#
# Epoch 00010: val_accuracy improved from 0.89053 to 0.89941, saving model to ./models/tree_8/model_root_f2_1/folder2\model.h5
# Epoch 11/25
# 74/74 [==============================] - 2s 22ms/step - loss: 0.2201 - accuracy: 0.9098 - val_loss: 0.2853 - val_accuracy: 0.8905
#
# Epoch 00011: val_accuracy did not improve from 0.89941
# Epoch 12/25
# 74/74 [==============================] - 2s 21ms/step - loss: 0.2178 - accuracy: 0.9107 - val_loss: 0.2731 - val_accuracy: 0.8935
#
# Epoch 00012: val_accuracy did not improve from 0.89941
# Epoch 13/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.2022 - accuracy: 0.9187 - val_loss: 0.2879 - val_accuracy: 0.8964
#
# Epoch 00013: val_accuracy did not improve from 0.89941
# Epoch 14/25
# 74/74 [==============================] - 2s 21ms/step - loss: 0.1960 - accuracy: 0.9225 - val_loss: 0.2828 - val_accuracy: 0.8787
#
# Epoch 00014: val_accuracy did not improve from 0.89941
# Epoch 15/25
# 74/74 [==============================] - 2s 20ms/step - loss: 0.1868 - accuracy: 0.9217 - val_loss: 0.2453 - val_accuracy: 0.8964
#
# Epoch 00015: val_accuracy did not improve from 0.89941
# Epoch 16/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.1827 - accuracy: 0.9272 - val_loss: 0.2534 - val_accuracy: 0.9083
#
# Epoch 00016: val_accuracy improved from 0.89941 to 0.90828, saving model to ./models/tree_8/model_root_f2_1/folder2\model.h5
# Epoch 17/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.1569 - accuracy: 0.9373 - val_loss: 0.2519 - val_accuracy: 0.9142
#
# Epoch 00017: val_accuracy improved from 0.90828 to 0.91420, saving model to ./models/tree_8/model_root_f2_1/folder2\model.h5
# Epoch 18/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.1365 - accuracy: 0.9471 - val_loss: 0.2707 - val_accuracy: 0.8876
#
# Epoch 00018: val_accuracy did not improve from 0.91420
# Epoch 19/25
# 74/74 [==============================] - 2s 21ms/step - loss: 0.1441 - accuracy: 0.9479 - val_loss: 0.2503 - val_accuracy: 0.9112
#
# Epoch 00019: val_accuracy did not improve from 0.91420
# Epoch 20/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.1386 - accuracy: 0.9458 - val_loss: 0.2221 - val_accuracy: 0.9172
#
# Epoch 00020: val_accuracy improved from 0.91420 to 0.91716, saving model to ./models/tree_8/model_root_f2_1/folder2\model.h5
# Epoch 21/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.1132 - accuracy: 0.9581 - val_loss: 0.2691 - val_accuracy: 0.8994
#
# Epoch 00021: val_accuracy did not improve from 0.91716
# Epoch 22/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.1163 - accuracy: 0.9543 - val_loss: 0.2291 - val_accuracy: 0.9112
#
# Epoch 00022: val_accuracy did not improve from 0.91716
# Epoch 23/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0849 - accuracy: 0.9704 - val_loss: 0.2374 - val_accuracy: 0.9112
#
# Epoch 00023: val_accuracy did not improve from 0.91716
# Epoch 24/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0730 - accuracy: 0.9742 - val_loss: 0.2328 - val_accuracy: 0.9201
#
# Epoch 00024: val_accuracy improved from 0.91716 to 0.92012, saving model to ./models/tree_8/model_root_f2_1/folder2\model.h5
# Epoch 25/25
# 74/74 [==============================] - 2s 21ms/step - loss: 0.0774 - accuracy: 0.9695 - val_loss: 0.4656 - val_accuracy: 0.8728
#
# Epoch 00025: val_accuracy did not improve from 0.92012
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Hip-Hop'], ['Disco', 'Pop']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 74/74 [==============================] - 2s 26ms/step - loss: 0.8285 - accuracy: 0.6418 - val_loss: 0.5337 - val_accuracy: 0.7249
#
# Epoch 00001: val_accuracy improved from -inf to 0.72485, saving model to ./models/tree_8/model_root_f2_1/folder3\model.h5
# Epoch 2/25
# 74/74 [==============================] - 2s 21ms/step - loss: 0.5897 - accuracy: 0.6880 - val_loss: 0.4829 - val_accuracy: 0.7959
#
# Epoch 00002: val_accuracy improved from 0.72485 to 0.79586, saving model to ./models/tree_8/model_root_f2_1/folder3\model.h5
# Epoch 3/25
# 74/74 [==============================] - 2s 20ms/step - loss: 0.5030 - accuracy: 0.7604 - val_loss: 0.4288 - val_accuracy: 0.8136
#
# Epoch 00003: val_accuracy improved from 0.79586 to 0.81361, saving model to ./models/tree_8/model_root_f2_1/folder3\model.h5
# Epoch 4/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.4342 - accuracy: 0.8031 - val_loss: 0.3638 - val_accuracy: 0.8402
#
# Epoch 00004: val_accuracy improved from 0.81361 to 0.84024, saving model to ./models/tree_8/model_root_f2_1/folder3\model.h5
# Epoch 5/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.3739 - accuracy: 0.8425 - val_loss: 0.3705 - val_accuracy: 0.8550
#
# Epoch 00005: val_accuracy improved from 0.84024 to 0.85503, saving model to ./models/tree_8/model_root_f2_1/folder3\model.h5
# Epoch 6/25
# 74/74 [==============================] - 2s 20ms/step - loss: 0.3382 - accuracy: 0.8544 - val_loss: 0.3906 - val_accuracy: 0.8166
#
# Epoch 00006: val_accuracy did not improve from 0.85503
# Epoch 7/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.2588 - accuracy: 0.8861 - val_loss: 0.2739 - val_accuracy: 0.8787
#
# Epoch 00007: val_accuracy improved from 0.85503 to 0.87870, saving model to ./models/tree_8/model_root_f2_1/folder3\model.h5
# Epoch 8/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.1781 - accuracy: 0.9272 - val_loss: 0.2019 - val_accuracy: 0.9320
#
# Epoch 00008: val_accuracy improved from 0.87870 to 0.93195, saving model to ./models/tree_8/model_root_f2_1/folder3\model.h5
# Epoch 9/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.1345 - accuracy: 0.9416 - val_loss: 0.1988 - val_accuracy: 0.9231
#
# Epoch 00009: val_accuracy did not improve from 0.93195
# Epoch 10/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0962 - accuracy: 0.9615 - val_loss: 0.1854 - val_accuracy: 0.9379
#
# Epoch 00010: val_accuracy improved from 0.93195 to 0.93787, saving model to ./models/tree_8/model_root_f2_1/folder3\model.h5
# Epoch 11/25
# 74/74 [==============================] - 2s 21ms/step - loss: 0.0432 - accuracy: 0.9843 - val_loss: 0.2948 - val_accuracy: 0.8964
#
# Epoch 00011: val_accuracy did not improve from 0.93787
# Epoch 12/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0414 - accuracy: 0.9860 - val_loss: 0.1913 - val_accuracy: 0.9408
#
# Epoch 00012: val_accuracy improved from 0.93787 to 0.94083, saving model to ./models/tree_8/model_root_f2_1/folder3\model.h5
# Epoch 13/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0185 - accuracy: 0.9945 - val_loss: 0.2097 - val_accuracy: 0.9527
#
# Epoch 00013: val_accuracy improved from 0.94083 to 0.95266, saving model to ./models/tree_8/model_root_f2_1/folder3\model.h5
# Epoch 14/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0101 - accuracy: 0.9970 - val_loss: 0.2697 - val_accuracy: 0.9320
#
# Epoch 00014: val_accuracy did not improve from 0.95266
# Epoch 15/25
# 74/74 [==============================] - 2s 20ms/step - loss: 0.0123 - accuracy: 0.9966 - val_loss: 0.2546 - val_accuracy: 0.9408
#
# Epoch 00015: val_accuracy did not improve from 0.95266
# Epoch 16/25
# 74/74 [==============================] - 2s 21ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.2317 - val_accuracy: 0.9438
#
# Epoch 00016: val_accuracy did not improve from 0.95266
# Epoch 17/25
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2149 - val_accuracy: 0.9527
#
# Epoch 00017: val_accuracy did not improve from 0.95266
# Epoch 18/25
# 74/74 [==============================] - 2s 21ms/step - loss: 4.2855e-04 - accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.9467
#
# Epoch 00018: val_accuracy did not improve from 0.95266
# Epoch 19/25
# 74/74 [==============================] - 1s 20ms/step - loss: 2.4102e-04 - accuracy: 1.0000 - val_loss: 0.2271 - val_accuracy: 0.9527
#
# Epoch 00019: val_accuracy did not improve from 0.95266
# Epoch 20/25
# 74/74 [==============================] - 2s 22ms/step - loss: 1.7649e-04 - accuracy: 1.0000 - val_loss: 0.2311 - val_accuracy: 0.9556
#
# Epoch 00020: val_accuracy improved from 0.95266 to 0.95562, saving model to ./models/tree_8/model_root_f2_1/folder3\model.h5
# Epoch 21/25
# 74/74 [==============================] - 2s 21ms/step - loss: 1.4860e-04 - accuracy: 1.0000 - val_loss: 0.2365 - val_accuracy: 0.9556
#
# Epoch 00021: val_accuracy did not improve from 0.95562
# Epoch 22/25
# 74/74 [==============================] - 2s 21ms/step - loss: 1.2587e-04 - accuracy: 1.0000 - val_loss: 0.2388 - val_accuracy: 0.9556
#
# Epoch 00022: val_accuracy did not improve from 0.95562
# Epoch 23/25
# 74/74 [==============================] - 2s 21ms/step - loss: 1.0902e-04 - accuracy: 1.0000 - val_loss: 0.2447 - val_accuracy: 0.9527
#
# Epoch 00023: val_accuracy did not improve from 0.95562
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 24/25
# 74/74 [==============================] - 2s 21ms/step - loss: 9.7733e-05 - accuracy: 1.0000 - val_loss: 0.2457 - val_accuracy: 0.9556
#
# Epoch 00024: val_accuracy did not improve from 0.95562
# Epoch 25/25
# 74/74 [==============================] - 2s 21ms/step - loss: 9.1815e-05 - accuracy: 1.0000 - val_loss: 0.2465 - val_accuracy: 0.9586
#
# Epoch 00025: val_accuracy improved from 0.95562 to 0.95858, saving model to ./models/tree_8/model_root_f2_1/folder3\model.h5
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
