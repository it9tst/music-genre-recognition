# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Blues':0, 'Country':2, 'Jazz':5, 'Reggae':8, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Blues', 2: 'Country', 5: 'Jazz', 8: 'Reggae', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((3990, 128, 128), (3990, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((500, 128, 128), (500, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Reggae

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 25

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_8/model_root_f1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_8/model_root_f1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def create_split(elem):
    splits = list(set_partitions(elem, 2))
    _splits = []
    for i in range(len(splits)):
        try:
            if len(splits[i][0]) != 1 and len(splits[i][1]) != 1:
                _splits.append(splits[i])
        except:
            continue
    
    return _splits, len(_splits)

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

genre_splits, num_splits = create_split(list(dict_genres.values()))
print("Num splits {}".format(num_splits))

if num_splits > 8:
    n_splits = num_splits
else:
    n_splits = 8

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Num splits 10
# Folder num 1
# Genre split [['Blues', 'Country'], ['Jazz', 'Reggae', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 127/127 [==============================] - 10s 44ms/step - loss: 0.8563 - accuracy: 0.5937 - val_loss: 0.7058 - val_accuracy: 0.5724
#
# Epoch 00001: val_accuracy improved from -inf to 0.57238, saving model to ./models/tree_8/model_root_f1/folder1\model.h5
# Epoch 2/25
# 127/127 [==============================] - 4s 28ms/step - loss: 0.6765 - accuracy: 0.5964 - val_loss: 0.6852 - val_accuracy: 0.5724
#
# Epoch 00002: val_accuracy did not improve from 0.57238
# Epoch 3/25
# 127/127 [==============================] - 4s 29ms/step - loss: 0.6732 - accuracy: 0.6021 - val_loss: 0.6834 - val_accuracy: 0.5724
#
# Epoch 00003: val_accuracy did not improve from 0.57238
# Epoch 4/25
# 127/127 [==============================] - 4s 28ms/step - loss: 0.6728 - accuracy: 0.6021 - val_loss: 0.6833 - val_accuracy: 0.5724
#
# Epoch 00004: val_accuracy did not improve from 0.57238
# Epoch 5/25
# 127/127 [==============================] - 3s 26ms/step - loss: 0.6734 - accuracy: 0.6021 - val_loss: 0.6827 - val_accuracy: 0.5724
#
# Epoch 00005: val_accuracy did not improve from 0.57238
# Epoch 6/25
# 127/127 [==============================] - 3s 26ms/step - loss: 0.6731 - accuracy: 0.6021 - val_loss: 0.6831 - val_accuracy: 0.5724
#
# Epoch 00006: val_accuracy did not improve from 0.57238
# Epoch 7/25
# 127/127 [==============================] - 3s 26ms/step - loss: 0.6764 - accuracy: 0.5961 - val_loss: 0.6851 - val_accuracy: 0.5724
#
# Epoch 00007: val_accuracy did not improve from 0.57238
# Epoch 8/25
# 127/127 [==============================] - 4s 28ms/step - loss: 0.6730 - accuracy: 0.6021 - val_loss: 0.6879 - val_accuracy: 0.5724
#
# Epoch 00008: val_accuracy did not improve from 0.57238
# Epoch 9/25
# 127/127 [==============================] - 3s 27ms/step - loss: 0.6774 - accuracy: 0.5984 - val_loss: 0.6838 - val_accuracy: 0.5724
#
# Epoch 00009: val_accuracy did not improve from 0.57238
# Epoch 10/25
# 127/127 [==============================] - 3s 27ms/step - loss: 0.6729 - accuracy: 0.6008 - val_loss: 0.6833 - val_accuracy: 0.5724
#
# Epoch 00010: val_accuracy did not improve from 0.57238
# Epoch 11/25
# 127/127 [==============================] - 4s 28ms/step - loss: 0.6724 - accuracy: 0.6021 - val_loss: 0.6871 - val_accuracy: 0.5724
#
# Epoch 00011: val_accuracy did not improve from 0.57238
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 12/25
# 127/127 [==============================] - 4s 28ms/step - loss: 0.6727 - accuracy: 0.6021 - val_loss: 0.6844 - val_accuracy: 0.5724
#
# Epoch 00012: val_accuracy did not improve from 0.57238
# Epoch 13/25
# 127/127 [==============================] - 3s 27ms/step - loss: 0.6725 - accuracy: 0.6021 - val_loss: 0.6849 - val_accuracy: 0.5724
#
# Epoch 00013: val_accuracy did not improve from 0.57238
# Epoch 14/25
# 127/127 [==============================] - 3s 26ms/step - loss: 0.6725 - accuracy: 0.6021 - val_loss: 0.6859 - val_accuracy: 0.5724
#
# Epoch 00014: val_accuracy did not improve from 0.57238
# Epoch 15/25
# 127/127 [==============================] - 3s 27ms/step - loss: 0.6727 - accuracy: 0.6021 - val_loss: 0.6855 - val_accuracy: 0.5724
#
# Epoch 00015: val_accuracy did not improve from 0.57238
# Epoch 16/25
# 127/127 [==============================] - 3s 26ms/step - loss: 0.6729 - accuracy: 0.6021 - val_loss: 0.6848 - val_accuracy: 0.5724
#
# Epoch 00016: val_accuracy did not improve from 0.57238
# Epoch 17/25
# 127/127 [==============================] - 3s 27ms/step - loss: 0.6723 - accuracy: 0.6021 - val_loss: 0.6834 - val_accuracy: 0.5724
#
# Epoch 00017: val_accuracy did not improve from 0.57238
# Epoch 18/25
# 127/127 [==============================] - 3s 27ms/step - loss: 0.6727 - accuracy: 0.6021 - val_loss: 0.6844 - val_accuracy: 0.5724
#
# Epoch 00018: val_accuracy did not improve from 0.57238
# Epoch 19/25
# 127/127 [==============================] - 4s 28ms/step - loss: 0.6727 - accuracy: 0.6021 - val_loss: 0.6834 - val_accuracy: 0.5724
#
# Epoch 00019: val_accuracy did not improve from 0.57238
# Epoch 20/25
# 127/127 [==============================] - 3s 27ms/step - loss: 0.6723 - accuracy: 0.6021 - val_loss: 0.6866 - val_accuracy: 0.5724
#
# Epoch 00020: val_accuracy did not improve from 0.57238
# Epoch 21/25
# 127/127 [==============================] - 3s 27ms/step - loss: 0.6724 - accuracy: 0.6021 - val_loss: 0.6854 - val_accuracy: 0.5724
#
# Epoch 00021: val_accuracy did not improve from 0.57238
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 22/25
# 127/127 [==============================] - 4s 28ms/step - loss: 0.6722 - accuracy: 0.6021 - val_loss: 0.6839 - val_accuracy: 0.5724
#
# Epoch 00022: val_accuracy did not improve from 0.57238
# Epoch 23/25
# 127/127 [==============================] - 3s 28ms/step - loss: 0.6725 - accuracy: 0.6021 - val_loss: 0.6840 - val_accuracy: 0.5724
#
# Epoch 00023: val_accuracy did not improve from 0.57238
# Epoch 24/25
# 127/127 [==============================] - 4s 29ms/step - loss: 0.6725 - accuracy: 0.6021 - val_loss: 0.6843 - val_accuracy: 0.5724
#
# Epoch 00024: val_accuracy did not improve from 0.57238
# Epoch 25/25
# 127/127 [==============================] - 4s 30ms/step - loss: 0.6723 - accuracy: 0.6021 - val_loss: 0.6845 - val_accuracy: 0.5724
#
# Epoch 00025: val_accuracy did not improve from 0.57238
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Blues', 'Country', 'Jazz'], ['Reggae', 'Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 127/127 [==============================] - 5s 32ms/step - loss: 0.7777 - accuracy: 0.5912 - val_loss: 0.6861 - val_accuracy: 0.4967
#
# Epoch 00001: val_accuracy improved from -inf to 0.49666, saving model to ./models/tree_8/model_root_f1/folder2\model.h5
# Epoch 2/25
# 127/127 [==============================] - 3s 26ms/step - loss: 0.6557 - accuracy: 0.6038 - val_loss: 0.6606 - val_accuracy: 0.7194
#
# Epoch 00002: val_accuracy improved from 0.49666 to 0.71938, saving model to ./models/tree_8/model_root_f1/folder2\model.h5
# Epoch 3/25
# 127/127 [==============================] - 3s 26ms/step - loss: 0.6228 - accuracy: 0.6578 - val_loss: 0.5775 - val_accuracy: 0.6927
#
# Epoch 00003: val_accuracy did not improve from 0.71938
# Epoch 4/25
# 127/127 [==============================] - 4s 28ms/step - loss: 0.5641 - accuracy: 0.7003 - val_loss: 0.4703 - val_accuracy: 0.7639
#
# Epoch 00004: val_accuracy improved from 0.71938 to 0.76392, saving model to ./models/tree_8/model_root_f1/folder2\model.h5
# Epoch 5/25
# 127/127 [==============================] - 3s 27ms/step - loss: 0.5574 - accuracy: 0.7021 - val_loss: 0.5567 - val_accuracy: 0.6748
#
# Epoch 00005: val_accuracy did not improve from 0.76392
# Epoch 6/25
# 127/127 [==============================] - 3s 26ms/step - loss: 0.5122 - accuracy: 0.7399 - val_loss: 0.4564 - val_accuracy: 0.7773
#
# Epoch 00006: val_accuracy improved from 0.76392 to 0.77728, saving model to ./models/tree_8/model_root_f1/folder2\model.h5
# Epoch 7/25
# 127/127 [==============================] - 3s 27ms/step - loss: 0.4442 - accuracy: 0.7949 - val_loss: 0.4185 - val_accuracy: 0.8062
#
# Epoch 00007: val_accuracy improved from 0.77728 to 0.80624, saving model to ./models/tree_8/model_root_f1/folder2\model.h5
# Epoch 8/25
# 127/127 [==============================] - 4s 28ms/step - loss: 0.3866 - accuracy: 0.8213 - val_loss: 0.4348 - val_accuracy: 0.7906
#
# Epoch 00008: val_accuracy did not improve from 0.80624
# Epoch 9/25
# 127/127 [==============================] - 4s 29ms/step - loss: 0.3334 - accuracy: 0.8481 - val_loss: 0.4245 - val_accuracy: 0.7840
#
# Epoch 00009: val_accuracy did not improve from 0.80624
# Epoch 10/25
# 127/127 [==============================] - 4s 28ms/step - loss: 0.2769 - accuracy: 0.8800 - val_loss: 0.3959 - val_accuracy: 0.8196
#
# Epoch 00010: val_accuracy improved from 0.80624 to 0.81960, saving model to ./models/tree_8/model_root_f1/folder2\model.h5
# Epoch 11/25
# 127/127 [==============================] - 3s 28ms/step - loss: 0.2303 - accuracy: 0.9065 - val_loss: 0.4663 - val_accuracy: 0.7951
#
# Epoch 00011: val_accuracy did not improve from 0.81960
# Epoch 12/25
# 127/127 [==============================] - 3s 25ms/step - loss: 0.1530 - accuracy: 0.9423 - val_loss: 0.6048 - val_accuracy: 0.8040
#
# Epoch 00012: val_accuracy did not improve from 0.81960
# Epoch 13/25
# 127/127 [==============================] - 3s 24ms/step - loss: 0.1378 - accuracy: 0.9468 - val_loss: 0.4705 - val_accuracy: 0.8085
#
# Epoch 00013: val_accuracy did not improve from 0.81960
# Epoch 14/25
# 127/127 [==============================] - 3s 25ms/step - loss: 0.0737 - accuracy: 0.9748 - val_loss: 0.3871 - val_accuracy: 0.8575
#
# Epoch 00014: val_accuracy improved from 0.81960 to 0.85746, saving model to ./models/tree_8/model_root_f1/folder2\model.h5
# Epoch 15/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0879 - accuracy: 0.9656 - val_loss: 0.3853 - val_accuracy: 0.8530
#
# Epoch 00015: val_accuracy did not improve from 0.85746
# Epoch 16/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0303 - accuracy: 0.9918 - val_loss: 0.5547 - val_accuracy: 0.8374
#
# Epoch 00016: val_accuracy did not improve from 0.85746
# Epoch 17/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0137 - accuracy: 0.9978 - val_loss: 0.5143 - val_accuracy: 0.8597
#
# Epoch 00017: val_accuracy improved from 0.85746 to 0.85969, saving model to ./models/tree_8/model_root_f1/folder2\model.h5
# Epoch 18/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0035 - accuracy: 0.9998 - val_loss: 0.4507 - val_accuracy: 0.8530
#
# Epoch 00018: val_accuracy did not improve from 0.85969
# Epoch 19/25
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4587 - val_accuracy: 0.8508
#
# Epoch 00019: val_accuracy did not improve from 0.85969
# Epoch 20/25
# 127/127 [==============================] - 3s 20ms/step - loss: 7.8128e-04 - accuracy: 1.0000 - val_loss: 0.4812 - val_accuracy: 0.8552
#
# Epoch 00020: val_accuracy did not improve from 0.85969
# Epoch 21/25
# 127/127 [==============================] - 2s 20ms/step - loss: 5.8507e-04 - accuracy: 1.0000 - val_loss: 0.5050 - val_accuracy: 0.8575
#
# Epoch 00021: val_accuracy did not improve from 0.85969
# Epoch 22/25
# 127/127 [==============================] - 2s 19ms/step - loss: 4.4832e-04 - accuracy: 1.0000 - val_loss: 0.5141 - val_accuracy: 0.8552
#
# Epoch 00022: val_accuracy did not improve from 0.85969
# Epoch 23/25
# 127/127 [==============================] - 3s 22ms/step - loss: 3.7332e-04 - accuracy: 1.0000 - val_loss: 0.5159 - val_accuracy: 0.8552
#
# Epoch 00023: val_accuracy did not improve from 0.85969
# Epoch 24/25
# 127/127 [==============================] - 3s 20ms/step - loss: 3.0881e-04 - accuracy: 1.0000 - val_loss: 0.5295 - val_accuracy: 0.8552
#
# Epoch 00024: val_accuracy did not improve from 0.85969
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 25/25
# 127/127 [==============================] - 3s 20ms/step - loss: 2.6068e-04 - accuracy: 1.0000 - val_loss: 0.5304 - val_accuracy: 0.8575
#
# Epoch 00025: val_accuracy did not improve from 0.85969
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Country', 'Jazz'], ['Blues', 'Reggae', 'Rock']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.7673 - accuracy: 0.5951 - val_loss: 0.6803 - val_accuracy: 0.5991
#
# Epoch 00001: val_accuracy improved from -inf to 0.59911, saving model to ./models/tree_8/model_root_f1/folder3\model.h5
# Epoch 2/25
# 127/127 [==============================] - 2s 19ms/step - loss: 0.6610 - accuracy: 0.5951 - val_loss: 0.6650 - val_accuracy: 0.5991
#
# Epoch 00002: val_accuracy did not improve from 0.59911
# Epoch 3/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.6299 - accuracy: 0.6456 - val_loss: 0.5892 - val_accuracy: 0.7394
#
# Epoch 00003: val_accuracy improved from 0.59911 to 0.73942, saving model to ./models/tree_8/model_root_f1/folder3\model.h5
# Epoch 4/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.5500 - accuracy: 0.7048 - val_loss: 0.4963 - val_accuracy: 0.7283
#
# Epoch 00004: val_accuracy did not improve from 0.73942
# Epoch 5/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.4858 - accuracy: 0.7543 - val_loss: 0.4328 - val_accuracy: 0.7862
#
# Epoch 00005: val_accuracy improved from 0.73942 to 0.78619, saving model to ./models/tree_8/model_root_f1/folder3\model.h5
# Epoch 6/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.4316 - accuracy: 0.7924 - val_loss: 0.3989 - val_accuracy: 0.8085
#
# Epoch 00006: val_accuracy improved from 0.78619 to 0.80846, saving model to ./models/tree_8/model_root_f1/folder3\model.h5
# Epoch 7/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.3758 - accuracy: 0.8275 - val_loss: 0.3626 - val_accuracy: 0.8285
#
# Epoch 00007: val_accuracy improved from 0.80846 to 0.82851, saving model to ./models/tree_8/model_root_f1/folder3\model.h5
# Epoch 8/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.3035 - accuracy: 0.8679 - val_loss: 0.3625 - val_accuracy: 0.8597
#
# Epoch 00008: val_accuracy improved from 0.82851 to 0.85969, saving model to ./models/tree_8/model_root_f1/folder3\model.h5
# Epoch 9/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.2256 - accuracy: 0.9060 - val_loss: 0.4335 - val_accuracy: 0.8196
#
# Epoch 00009: val_accuracy did not improve from 0.85969
# Epoch 10/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.1632 - accuracy: 0.9364 - val_loss: 0.3759 - val_accuracy: 0.8619
#
# Epoch 00010: val_accuracy improved from 0.85969 to 0.86192, saving model to ./models/tree_8/model_root_f1/folder3\model.h5
# Epoch 11/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.1026 - accuracy: 0.9611 - val_loss: 0.4277 - val_accuracy: 0.8552
#
# Epoch 00011: val_accuracy did not improve from 0.86192
# Epoch 12/25
# 127/127 [==============================] - ETA: 0s - loss: 0.0694 - accuracy: 0.97 - 3s 21ms/step - loss: 0.0694 - accuracy: 0.9750 - val_loss: 0.4195 - val_accuracy: 0.8597
#
# Epoch 00012: val_accuracy did not improve from 0.86192
# Epoch 13/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0475 - accuracy: 0.9849 - val_loss: 0.4875 - val_accuracy: 0.8686
#
# Epoch 00013: val_accuracy improved from 0.86192 to 0.86860, saving model to ./models/tree_8/model_root_f1/folder3\model.h5
# Epoch 14/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0250 - accuracy: 0.9923 - val_loss: 0.5799 - val_accuracy: 0.8775
#
# Epoch 00014: val_accuracy improved from 0.86860 to 0.87751, saving model to ./models/tree_8/model_root_f1/folder3\model.h5
# Epoch 15/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0493 - accuracy: 0.9819 - val_loss: 0.5697 - val_accuracy: 0.8396
#
# Epoch 00015: val_accuracy did not improve from 0.87751
# Epoch 16/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0410 - accuracy: 0.9849 - val_loss: 0.5983 - val_accuracy: 0.8797
#
# Epoch 00016: val_accuracy improved from 0.87751 to 0.87973, saving model to ./models/tree_8/model_root_f1/folder3\model.h5
# Epoch 17/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0412 - accuracy: 0.9861 - val_loss: 0.7603 - val_accuracy: 0.8352
#
# Epoch 00017: val_accuracy did not improve from 0.87973
# Epoch 18/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.0123 - accuracy: 0.9958 - val_loss: 0.6301 - val_accuracy: 0.8664
#
# Epoch 00018: val_accuracy did not improve from 0.87973
# Epoch 19/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.6482 - val_accuracy: 0.8664
#
# Epoch 00019: val_accuracy did not improve from 0.87973
# Epoch 20/25
# 127/127 [==============================] - 3s 20ms/step - loss: 6.5487e-04 - accuracy: 1.0000 - val_loss: 0.6961 - val_accuracy: 0.8686
#
# Epoch 00020: val_accuracy did not improve from 0.87973
# Epoch 21/25
# 127/127 [==============================] - 2s 20ms/step - loss: 2.8615e-04 - accuracy: 1.0000 - val_loss: 0.7196 - val_accuracy: 0.8731
#
# Epoch 00021: val_accuracy did not improve from 0.87973
# Epoch 22/25
# 127/127 [==============================] - 3s 21ms/step - loss: 2.1417e-04 - accuracy: 1.0000 - val_loss: 0.7294 - val_accuracy: 0.8731
#
# Epoch 00022: val_accuracy did not improve from 0.87973
# Epoch 23/25
# 127/127 [==============================] - 3s 20ms/step - loss: 1.7102e-04 - accuracy: 1.0000 - val_loss: 0.7324 - val_accuracy: 0.8775
#
# Epoch 00023: val_accuracy did not improve from 0.87973
# Epoch 24/25
# 127/127 [==============================] - 3s 22ms/step - loss: 1.4183e-04 - accuracy: 1.0000 - val_loss: 0.7474 - val_accuracy: 0.8753
#
# Epoch 00024: val_accuracy did not improve from 0.87973
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 25/25
# 127/127 [==============================] - 3s 21ms/step - loss: 1.2212e-04 - accuracy: 1.0000 - val_loss: 0.7518 - val_accuracy: 0.8753
#
# Epoch 00025: val_accuracy did not improve from 0.87973
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Blues', 'Jazz'], ['Country', 'Reggae', 'Rock']]
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.7990 - accuracy: 0.5872 - val_loss: 0.5852 - val_accuracy: 0.7327
#
# Epoch 00001: val_accuracy improved from -inf to 0.73274, saving model to ./models/tree_8/model_root_f1/folder4\model.h5
# Epoch 2/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.5585 - accuracy: 0.7211 - val_loss: 0.5355 - val_accuracy: 0.7149
#
# Epoch 00002: val_accuracy did not improve from 0.73274
# Epoch 3/25
# 127/127 [==============================] - 2s 19ms/step - loss: 0.4792 - accuracy: 0.7723 - val_loss: 0.5184 - val_accuracy: 0.7372
#
# Epoch 00003: val_accuracy improved from 0.73274 to 0.73719, saving model to ./models/tree_8/model_root_f1/folder4\model.h5
# Epoch 4/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.4514 - accuracy: 0.7926 - val_loss: 0.5273 - val_accuracy: 0.7617
#
# Epoch 00004: val_accuracy improved from 0.73719 to 0.76169, saving model to ./models/tree_8/model_root_f1/folder4\model.h5
# Epoch 5/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.4227 - accuracy: 0.8114 - val_loss: 0.4411 - val_accuracy: 0.8040
#
# Epoch 00005: val_accuracy improved from 0.76169 to 0.80401, saving model to ./models/tree_8/model_root_f1/folder4\model.h5
# Epoch 6/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.3962 - accuracy: 0.8288 - val_loss: 0.4577 - val_accuracy: 0.7706
#
# Epoch 00006: val_accuracy did not improve from 0.80401
# Epoch 7/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.3661 - accuracy: 0.8387 - val_loss: 0.3967 - val_accuracy: 0.8285
#
# Epoch 00007: val_accuracy improved from 0.80401 to 0.82851, saving model to ./models/tree_8/model_root_f1/folder4\model.h5
# Epoch 8/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.3356 - accuracy: 0.8533 - val_loss: 0.3712 - val_accuracy: 0.8396
#
# Epoch 00008: val_accuracy improved from 0.82851 to 0.83964, saving model to ./models/tree_8/model_root_f1/folder4\model.h5
# Epoch 9/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.3327 - accuracy: 0.8585 - val_loss: 0.4018 - val_accuracy: 0.8062
#
# Epoch 00009: val_accuracy did not improve from 0.83964
# Epoch 10/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.3111 - accuracy: 0.8664 - val_loss: 0.3922 - val_accuracy: 0.8374
#
# Epoch 00010: val_accuracy did not improve from 0.83964
# Epoch 11/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.2815 - accuracy: 0.8787 - val_loss: 0.3831 - val_accuracy: 0.8174
#
# Epoch 00011: val_accuracy did not improve from 0.83964
# Epoch 12/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.2650 - accuracy: 0.8886 - val_loss: 0.3664 - val_accuracy: 0.8352
#
# Epoch 00012: val_accuracy did not improve from 0.83964
# Epoch 13/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.2695 - accuracy: 0.8815 - val_loss: 0.3776 - val_accuracy: 0.8263
#
# Epoch 00013: val_accuracy did not improve from 0.83964
# Epoch 14/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.2327 - accuracy: 0.9047 - val_loss: 0.4850 - val_accuracy: 0.7951
#
# Epoch 00014: val_accuracy did not improve from 0.83964
# Epoch 15/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.2332 - accuracy: 0.8995 - val_loss: 0.5312 - val_accuracy: 0.8241
#
# Epoch 00015: val_accuracy did not improve from 0.83964
# Epoch 16/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.2174 - accuracy: 0.9119 - val_loss: 0.3809 - val_accuracy: 0.8441
#
# Epoch 00016: val_accuracy improved from 0.83964 to 0.84410, saving model to ./models/tree_8/model_root_f1/folder4\model.h5
# Epoch 17/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1970 - accuracy: 0.9285 - val_loss: 0.3962 - val_accuracy: 0.8374
#
# Epoch 00017: val_accuracy did not improve from 0.84410
# Epoch 18/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.1799 - accuracy: 0.9290 - val_loss: 0.4798 - val_accuracy: 0.8419
#
# Epoch 00018: val_accuracy did not improve from 0.84410
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 19/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.1471 - accuracy: 0.9461 - val_loss: 0.4105 - val_accuracy: 0.8463
#
# Epoch 00019: val_accuracy improved from 0.84410 to 0.84633, saving model to ./models/tree_8/model_root_f1/folder4\model.h5
# Epoch 20/25
# 127/127 [==============================] - 2s 19ms/step - loss: 0.1301 - accuracy: 0.9520 - val_loss: 0.4569 - val_accuracy: 0.8218
#
# Epoch 00020: val_accuracy did not improve from 0.84633
# Epoch 21/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1262 - accuracy: 0.9495 - val_loss: 0.4533 - val_accuracy: 0.8463
#
# Epoch 00021: val_accuracy did not improve from 0.84633
# Epoch 22/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1144 - accuracy: 0.9569 - val_loss: 0.4621 - val_accuracy: 0.8441
#
# Epoch 00022: val_accuracy did not improve from 0.84633
# Epoch 23/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1081 - accuracy: 0.9619 - val_loss: 0.4674 - val_accuracy: 0.8330
#
# Epoch 00023: val_accuracy did not improve from 0.84633
# Epoch 24/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0923 - accuracy: 0.9698 - val_loss: 0.5113 - val_accuracy: 0.8374
#
# Epoch 00024: val_accuracy did not improve from 0.84633
# Epoch 25/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0903 - accuracy: 0.9698 - val_loss: 0.4765 - val_accuracy: 0.8419
#
# Epoch 00025: val_accuracy did not improve from 0.84633
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 5
# Genre split [['Country', 'Jazz', 'Reggae'], ['Blues', 'Rock']]
# Building model...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.7175 - accuracy: 0.5937 - val_loss: 0.6637 - val_accuracy: 0.5835
#
# Epoch 00001: val_accuracy improved from -inf to 0.58352, saving model to ./models/tree_8/model_root_f1/folder5\model.h5
# Epoch 2/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.6005 - accuracy: 0.6924 - val_loss: 0.5851 - val_accuracy: 0.6815
#
# Epoch 00002: val_accuracy improved from 0.58352 to 0.68151, saving model to ./models/tree_8/model_root_f1/folder5\model.h5
# Epoch 3/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.5448 - accuracy: 0.7350 - val_loss: 0.5339 - val_accuracy: 0.7416
#
# Epoch 00003: val_accuracy improved from 0.68151 to 0.74165, saving model to ./models/tree_8/model_root_f1/folder5\model.h5
# Epoch 4/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.5038 - accuracy: 0.7580 - val_loss: 0.5212 - val_accuracy: 0.7394
#
# Epoch 00004: val_accuracy did not improve from 0.74165
# Epoch 5/25
# 127/127 [==============================] - 3s 23ms/step - loss: 0.4558 - accuracy: 0.7859 - val_loss: 0.4775 - val_accuracy: 0.7728
#
# Epoch 00005: val_accuracy improved from 0.74165 to 0.77283, saving model to ./models/tree_8/model_root_f1/folder5\model.h5
# Epoch 6/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.4035 - accuracy: 0.8189 - val_loss: 0.4067 - val_accuracy: 0.8018
#
# Epoch 00006: val_accuracy improved from 0.77283 to 0.80178, saving model to ./models/tree_8/model_root_f1/folder5\model.h5
# Epoch 7/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.3646 - accuracy: 0.8382 - val_loss: 0.3779 - val_accuracy: 0.8085
#
# Epoch 00007: val_accuracy improved from 0.80178 to 0.80846, saving model to ./models/tree_8/model_root_f1/folder5\model.h5
# Epoch 8/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.3260 - accuracy: 0.8547 - val_loss: 0.3776 - val_accuracy: 0.8085
#
# Epoch 00008: val_accuracy did not improve from 0.80846
# Epoch 9/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.2826 - accuracy: 0.8820 - val_loss: 0.3885 - val_accuracy: 0.8107
#
# Epoch 00009: val_accuracy improved from 0.80846 to 0.81069, saving model to ./models/tree_8/model_root_f1/folder5\model.h5
# Epoch 10/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.2545 - accuracy: 0.8911 - val_loss: 0.3237 - val_accuracy: 0.8508
#
# Epoch 00010: val_accuracy improved from 0.81069 to 0.85078, saving model to ./models/tree_8/model_root_f1/folder5\model.h5
# Epoch 11/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.2101 - accuracy: 0.9114 - val_loss: 0.3430 - val_accuracy: 0.8419
#
# Epoch 00011: val_accuracy did not improve from 0.85078
# Epoch 12/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.1815 - accuracy: 0.9235 - val_loss: 0.3708 - val_accuracy: 0.8597
#
# Epoch 00012: val_accuracy improved from 0.85078 to 0.85969, saving model to ./models/tree_8/model_root_f1/folder5\model.h5
# Epoch 13/25
# 127/127 [==============================] - 3s 27ms/step - loss: 0.1259 - accuracy: 0.9520 - val_loss: 0.3525 - val_accuracy: 0.8508
#
# Epoch 00013: val_accuracy did not improve from 0.85969
# Epoch 14/25
# 127/127 [==============================] - 3s 26ms/step - loss: 0.1274 - accuracy: 0.9483 - val_loss: 0.4276 - val_accuracy: 0.8129
#
# Epoch 00014: val_accuracy did not improve from 0.85969
# Epoch 15/25
# 127/127 [==============================] - 3s 25ms/step - loss: 0.0976 - accuracy: 0.9644 - val_loss: 0.4169 - val_accuracy: 0.8597
#
# Epoch 00015: val_accuracy did not improve from 0.85969
# Epoch 16/25
# 127/127 [==============================] - 3s 24ms/step - loss: 0.0529 - accuracy: 0.9807 - val_loss: 0.4551 - val_accuracy: 0.8619
#
# Epoch 00016: val_accuracy improved from 0.85969 to 0.86192, saving model to ./models/tree_8/model_root_f1/folder5\model.h5
# Epoch 17/25
# 127/127 [==============================] - 3s 26ms/step - loss: 0.0412 - accuracy: 0.9869 - val_loss: 0.4111 - val_accuracy: 0.8708
#
# Epoch 00017: val_accuracy improved from 0.86192 to 0.87082, saving model to ./models/tree_8/model_root_f1/folder5\model.h5
# Epoch 18/25
# 127/127 [==============================] - 3s 25ms/step - loss: 0.0521 - accuracy: 0.9822 - val_loss: 0.4077 - val_accuracy: 0.8708
#
# Epoch 00018: val_accuracy did not improve from 0.87082
# Epoch 19/25
# 127/127 [==============================] - 3s 24ms/step - loss: 0.0702 - accuracy: 0.9738 - val_loss: 0.3945 - val_accuracy: 0.8619
#
# Epoch 00019: val_accuracy did not improve from 0.87082
# Epoch 20/25
# 127/127 [==============================] - 3s 26ms/step - loss: 0.0365 - accuracy: 0.9881 - val_loss: 0.3482 - val_accuracy: 0.8775
#
# Epoch 00020: val_accuracy improved from 0.87082 to 0.87751, saving model to ./models/tree_8/model_root_f1/folder5\model.h5
# Epoch 21/25
# 127/127 [==============================] - 3s 25ms/step - loss: 0.0094 - accuracy: 0.9985 - val_loss: 0.5073 - val_accuracy: 0.8530
#
# Epoch 00021: val_accuracy did not improve from 0.87751
# Epoch 22/25
# 127/127 [==============================] - 3s 24ms/step - loss: 0.0045 - accuracy: 0.9993 - val_loss: 0.4251 - val_accuracy: 0.8797
#
# Epoch 00022: val_accuracy improved from 0.87751 to 0.87973, saving model to ./models/tree_8/model_root_f1/folder5\model.h5
# Epoch 23/25
# 127/127 [==============================] - 3s 25ms/step - loss: 9.9998e-04 - accuracy: 1.0000 - val_loss: 0.4490 - val_accuracy: 0.8775
#
# Epoch 00023: val_accuracy did not improve from 0.87973
# Epoch 24/25
# 127/127 [==============================] - 3s 25ms/step - loss: 6.4930e-04 - accuracy: 1.0000 - val_loss: 0.4737 - val_accuracy: 0.8731
#
# Epoch 00024: val_accuracy did not improve from 0.87973
# Epoch 25/25
# 127/127 [==============================] - 3s 24ms/step - loss: 5.1465e-04 - accuracy: 1.0000 - val_loss: 0.4822 - val_accuracy: 0.8775
#
# Epoch 00025: val_accuracy did not improve from 0.87973
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 6
# Genre split [['Blues', 'Jazz', 'Reggae'], ['Country', 'Rock']]
# Building model...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 127/127 [==============================] - 4s 27ms/step - loss: 0.7977 - accuracy: 0.5882 - val_loss: 0.6361 - val_accuracy: 0.7127
#
# Epoch 00001: val_accuracy improved from -inf to 0.71269, saving model to ./models/tree_8/model_root_f1/folder6\model.h5
# Epoch 2/25
# 127/127 [==============================] - 3s 25ms/step - loss: 0.6260 - accuracy: 0.6370 - val_loss: 0.5655 - val_accuracy: 0.6459
#
# Epoch 00002: val_accuracy did not improve from 0.71269
# Epoch 3/25
# 127/127 [==============================] - 3s 25ms/step - loss: 0.4853 - accuracy: 0.7753 - val_loss: 0.4467 - val_accuracy: 0.8062
#
# Epoch 00003: val_accuracy improved from 0.71269 to 0.80624, saving model to ./models/tree_8/model_root_f1/folder6\model.h5
# Epoch 4/25
# 127/127 [==============================] - 3s 25ms/step - loss: 0.4371 - accuracy: 0.8035 - val_loss: 0.5969 - val_accuracy: 0.6837
#
# Epoch 00004: val_accuracy did not improve from 0.80624
# Epoch 5/25
# 127/127 [==============================] - 3s 26ms/step - loss: 0.3959 - accuracy: 0.8198 - val_loss: 0.3542 - val_accuracy: 0.8486
#
# Epoch 00005: val_accuracy improved from 0.80624 to 0.84855, saving model to ./models/tree_8/model_root_f1/folder6\model.h5
# Epoch 6/25
# 127/127 [==============================] - 3s 26ms/step - loss: 0.3572 - accuracy: 0.8434 - val_loss: 0.3272 - val_accuracy: 0.8708
#
# Epoch 00006: val_accuracy improved from 0.84855 to 0.87082, saving model to ./models/tree_8/model_root_f1/folder6\model.h5
# Epoch 7/25
# 127/127 [==============================] - 3s 25ms/step - loss: 0.3174 - accuracy: 0.8604 - val_loss: 0.3479 - val_accuracy: 0.8597
#
# Epoch 00007: val_accuracy did not improve from 0.87082
# Epoch 8/25
# 127/127 [==============================] - 3s 25ms/step - loss: 0.3077 - accuracy: 0.8711 - val_loss: 0.3018 - val_accuracy: 0.8664
#
# Epoch 00008: val_accuracy did not improve from 0.87082
# Epoch 9/25
# 127/127 [==============================] - 3s 26ms/step - loss: 0.2617 - accuracy: 0.8953 - val_loss: 0.2808 - val_accuracy: 0.8797
#
# Epoch 00009: val_accuracy improved from 0.87082 to 0.87973, saving model to ./models/tree_8/model_root_f1/folder6\model.h5
# Epoch 10/25
# 127/127 [==============================] - 3s 25ms/step - loss: 0.2221 - accuracy: 0.9178 - val_loss: 0.3602 - val_accuracy: 0.8352
#
# Epoch 00010: val_accuracy did not improve from 0.87973
# Epoch 11/25
# 127/127 [==============================] - 3s 25ms/step - loss: 0.2013 - accuracy: 0.9186 - val_loss: 0.3132 - val_accuracy: 0.8753
#
# Epoch 00011: val_accuracy did not improve from 0.87973
# Epoch 12/25
# 127/127 [==============================] - 3s 26ms/step - loss: 0.1509 - accuracy: 0.9384 - val_loss: 0.2643 - val_accuracy: 0.8909acy
#
# Epoch 00012: val_accuracy improved from 0.87973 to 0.89087, saving model to ./models/tree_8/model_root_f1/folder6\model.h5
# Epoch 13/25
# 127/127 [==============================] - 3s 24ms/step - loss: 0.1678 - accuracy: 0.9329 - val_loss: 0.3872 - val_accuracy: 0.8352
#
# Epoch 00013: val_accuracy did not improve from 0.89087
# Epoch 14/25
# 127/127 [==============================] - 3s 25ms/step - loss: 0.1205 - accuracy: 0.9572 - val_loss: 0.2696 - val_accuracy: 0.8953
#
# Epoch 00014: val_accuracy improved from 0.89087 to 0.89532, saving model to ./models/tree_8/model_root_f1/folder6\model.h5
# Epoch 15/25
# 127/127 [==============================] - 3s 25ms/step - loss: 0.0801 - accuracy: 0.9723 - val_loss: 0.2470 - val_accuracy: 0.9042
#
# Epoch 00015: val_accuracy improved from 0.89532 to 0.90423, saving model to ./models/tree_8/model_root_f1/folder6\model.h5
# Epoch 16/25
# 127/127 [==============================] - 3s 25ms/step - loss: 0.0835 - accuracy: 0.9693 - val_loss: 0.2348 - val_accuracy: 0.9042
#
# Epoch 00016: val_accuracy did not improve from 0.90423
# Epoch 17/25
# 127/127 [==============================] - 3s 26ms/step - loss: 0.0361 - accuracy: 0.9911 - val_loss: 0.5345 - val_accuracy: 0.8708
#
# Epoch 00017: val_accuracy did not improve from 0.90423
# Epoch 18/25
# 127/127 [==============================] - 3s 23ms/step - loss: 0.0599 - accuracy: 0.9775 - val_loss: 0.3165 - val_accuracy: 0.9109
#
# Epoch 00018: val_accuracy improved from 0.90423 to 0.91091, saving model to ./models/tree_8/model_root_f1/folder6\model.h5
# Epoch 19/25
# 127/127 [==============================] - 3s 23ms/step - loss: 0.0219 - accuracy: 0.9953 - val_loss: 0.3533 - val_accuracy: 0.8976
#
# Epoch 00019: val_accuracy did not improve from 0.91091
# Epoch 20/25
# 127/127 [==============================] - 3s 23ms/step - loss: 0.0193 - accuracy: 0.9951 - val_loss: 0.3215 - val_accuracy: 0.9065
#
# Epoch 00020: val_accuracy did not improve from 0.91091
# Epoch 21/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0112 - accuracy: 0.9975 - val_loss: 0.2886 - val_accuracy: 0.9354
#
# Epoch 00021: val_accuracy improved from 0.91091 to 0.93541, saving model to ./models/tree_8/model_root_f1/folder6\model.h5
# Epoch 22/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.3112 - val_accuracy: 0.9243
#
# Epoch 00022: val_accuracy did not improve from 0.93541
# Epoch 23/25
# 127/127 [==============================] - 2s 20ms/step - loss: 7.1132e-04 - accuracy: 1.0000 - val_loss: 0.3180 - val_accuracy: 0.9287
#
# Epoch 00023: val_accuracy did not improve from 0.93541
# Epoch 24/25
# 127/127 [==============================] - 3s 21ms/step - loss: 4.4664e-04 - accuracy: 1.0000 - val_loss: 0.3276 - val_accuracy: 0.9310
#
# Epoch 00024: val_accuracy did not improve from 0.93541
# Epoch 25/25
# 127/127 [==============================] - 3s 20ms/step - loss: 3.4615e-04 - accuracy: 1.0000 - val_loss: 0.3369 - val_accuracy: 0.9265
#
# Epoch 00025: val_accuracy did not improve from 0.93541
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 7
# Genre split [['Jazz', 'Reggae'], ['Blues', 'Country', 'Rock']]
# Building model...
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 127/127 [==============================] - 3s 23ms/step - loss: 0.7531 - accuracy: 0.5937 - val_loss: 0.6965 - val_accuracy: 0.5100
#
# Epoch 00001: val_accuracy improved from -inf to 0.51002, saving model to ./models/tree_8/model_root_f1/folder7\model.h5
# Epoch 2/25
# ...
#
# Epoch 00022: val_accuracy did not improve from 0.85301
# Epoch 23/25
# 127/127 [==============================] - 3s 21ms/step - loss: 6.1179e-04 - accuracy: 1.0000 - val_loss: 0.6635 - val_accuracy: 0.8396
#
# Epoch 00023: val_accuracy did not improve from 0.85301
# Epoch 24/25
# 127/127 [==============================] - 3s 20ms/step - loss: 5.1339e-04 - accuracy: 1.0000 - val_loss: 0.6818 - val_accuracy: 0.8419
#
# Epoch 00024: val_accuracy did not improve from 0.85301
# Epoch 25/25
# 127/127 [==============================] - 3s 20ms/step - loss: 4.2968e-04 - accuracy: 1.0000 - val_loss: 0.6844 - val_accuracy: 0.8396
#
# Epoch 00025: val_accuracy did not improve from 0.85301
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 9
# Genre split [['Country', 'Reggae'], ['Blues', 'Jazz', 'Rock']]
# Building model...
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 127/127 [==============================] - 3s 23ms/step - loss: 0.7334 - accuracy: 0.6023 - val_loss: 0.6915 - val_accuracy: 0.5657
#
# Epoch 00001: val_accuracy improved from -inf to 0.56570, saving model to ./models/tree_8/model_root_f1/folder9\model.h5
# Epoch 2/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.6744 - accuracy: 0.6028 - val_loss: 0.6846 - val_accuracy: 0.5657
#
# Epoch 00002: val_accuracy did not improve from 0.56570
# Epoch 3/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.6734 - accuracy: 0.6028 - val_loss: 0.6847 - val_accuracy: 0.5657
#
# Epoch 00003: val_accuracy did not improve from 0.56570
# Epoch 4/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.6729 - accuracy: 0.6028 - val_loss: 0.6876 - val_accuracy: 0.5657
#
# Epoch 00004: val_accuracy did not improve from 0.56570
# Epoch 5/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.6727 - accuracy: 0.6028 - val_loss: 0.6871 - val_accuracy: 0.5657
#
# Epoch 00005: val_accuracy did not improve from 0.56570
# Epoch 6/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.6730 - accuracy: 0.6028 - val_loss: 0.6876 - val_accuracy: 0.5657
#
# Epoch 00006: val_accuracy did not improve from 0.56570
# Epoch 7/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.6730 - accuracy: 0.6028 - val_loss: 0.6868 - val_accuracy: 0.5657
#
# Epoch 00007: val_accuracy did not improve from 0.56570
# Epoch 8/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.6758 - accuracy: 0.5996 - val_loss: 0.6877 - val_accuracy: 0.5657
#
# Epoch 00008: val_accuracy did not improve from 0.56570
# Epoch 9/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.6747 - accuracy: 0.6003 - val_loss: 0.6851 - val_accuracy: 0.5657
#
# Epoch 00009: val_accuracy did not improve from 0.56570
# Epoch 10/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.6731 - accuracy: 0.6008 - val_loss: 0.6868 - val_accuracy: 0.5657
#
# Epoch 00010: val_accuracy did not improve from 0.56570
# Epoch 11/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.6721 - accuracy: 0.6028 - val_loss: 0.6850 - val_accuracy: 0.5657
#
# Epoch 00011: val_accuracy did not improve from 0.56570
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 12/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.6728 - accuracy: 0.6028 - val_loss: 0.6870 - val_accuracy: 0.5657
#
# Epoch 00012: val_accuracy did not improve from 0.56570
# Epoch 13/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.6725 - accuracy: 0.6028 - val_loss: 0.6867 - val_accuracy: 0.5657
#
# Epoch 00013: val_accuracy did not improve from 0.56570
# Epoch 14/25
# 127/127 [==============================] - 3s 22ms/step - loss: 0.6721 - accuracy: 0.6028 - val_loss: 0.6884 - val_accuracy: 0.5657
#
# Epoch 00014: val_accuracy did not improve from 0.56570
# Epoch 15/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.6693 - accuracy: 0.6008 - val_loss: 0.6807 - val_accuracy: 0.5657
#
# Epoch 00015: val_accuracy did not improve from 0.56570
# Epoch 16/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.5862 - accuracy: 0.6785 - val_loss: 0.5624 - val_accuracy: 0.6927
#
# Epoch 00016: val_accuracy improved from 0.56570 to 0.69265, saving model to ./models/tree_8/model_root_f1/folder9\model.h5
# Epoch 17/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.5363 - accuracy: 0.7261 - val_loss: 0.5707 - val_accuracy: 0.7105
#
# Epoch 00017: val_accuracy improved from 0.69265 to 0.71047, saving model to ./models/tree_8/model_root_f1/folder9\model.h5
# Epoch 18/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.4968 - accuracy: 0.7533 - val_loss: 0.5218 - val_accuracy: 0.7461
#
# Epoch 00018: val_accuracy improved from 0.71047 to 0.74610, saving model to ./models/tree_8/model_root_f1/folder9\model.h5
# Epoch 19/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.4609 - accuracy: 0.7723 - val_loss: 0.4843 - val_accuracy: 0.7661
#
# Epoch 00019: val_accuracy improved from 0.74610 to 0.76615, saving model to ./models/tree_8/model_root_f1/folder9\model.h5
# Epoch 20/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.4381 - accuracy: 0.7899 - val_loss: 0.4737 - val_accuracy: 0.7661
#
# Epoch 00020: val_accuracy did not improve from 0.76615
# Epoch 21/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.4113 - accuracy: 0.8092 - val_loss: 0.4563 - val_accuracy: 0.7795
#
# Epoch 00021: val_accuracy improved from 0.76615 to 0.77951, saving model to ./models/tree_8/model_root_f1/folder9\model.h5
# Epoch 22/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.3809 - accuracy: 0.8245 - val_loss: 0.4796 - val_accuracy: 0.7595
#
# Epoch 00022: val_accuracy did not improve from 0.77951
# Epoch 23/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.3552 - accuracy: 0.8389 - val_loss: 0.4810 - val_accuracy: 0.7684
#
# Epoch 00023: val_accuracy did not improve from 0.77951
# Epoch 24/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.3294 - accuracy: 0.8547 - val_loss: 0.4328 - val_accuracy: 0.8129
#
# Epoch 00024: val_accuracy improved from 0.77951 to 0.81292, saving model to ./models/tree_8/model_root_f1/folder9\model.h5
# Epoch 25/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.2903 - accuracy: 0.8738 - val_loss: 0.4474 - val_accuracy: 0.7862
#
# Epoch 00025: val_accuracy did not improve from 0.81292
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 10
# Genre split [['Blues', 'Reggae'], ['Country', 'Jazz', 'Rock']]
# Building model...
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.7396 - accuracy: 0.5862 - val_loss: 0.6280 - val_accuracy: 0.7261
#
# Epoch 00001: val_accuracy improved from -inf to 0.72606, saving model to ./models/tree_8/model_root_f1/folder10\model.h5
# Epoch 2/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.5906 - accuracy: 0.6978 - val_loss: 0.5069 - val_accuracy: 0.7840
#
# Epoch 00002: val_accuracy improved from 0.72606 to 0.78396, saving model to ./models/tree_8/model_root_f1/folder10\model.h5
# Epoch 3/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.4911 - accuracy: 0.7694 - val_loss: 0.4517 - val_accuracy: 0.7973
#
# Epoch 00003: val_accuracy improved from 0.78396 to 0.79733, saving model to ./models/tree_8/model_root_f1/folder10\model.h5
# Epoch 4/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.4288 - accuracy: 0.8020 - val_loss: 0.4340 - val_accuracy: 0.7884
#
# Epoch 00004: val_accuracy did not improve from 0.79733
# Epoch 5/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.3622 - accuracy: 0.8396 - val_loss: 0.3623 - val_accuracy: 0.8285
#
# Epoch 00005: val_accuracy improved from 0.79733 to 0.82851, saving model to ./models/tree_8/model_root_f1/folder10\model.h5
# Epoch 6/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.3110 - accuracy: 0.8698 - val_loss: 0.4184 - val_accuracy: 0.8151
#
# Epoch 00006: val_accuracy did not improve from 0.82851
# Epoch 7/25
# 127/127 [==============================] - 3s 21ms/step - loss: 0.2774 - accuracy: 0.8778 - val_loss: 0.4846 - val_accuracy: 0.7951
#
# Epoch 00007: val_accuracy did not improve from 0.82851
# Epoch 8/25
# 127/127 [==============================] - 2s 19ms/step - loss: 0.2283 - accuracy: 0.9055 - val_loss: 0.3851 - val_accuracy: 0.8508
#
# Epoch 00008: val_accuracy improved from 0.82851 to 0.85078, saving model to ./models/tree_8/model_root_f1/folder10\model.h5
# Epoch 9/25
# 127/127 [==============================] - 2s 19ms/step - loss: 0.2179 - accuracy: 0.9129 - val_loss: 0.2909 - val_accuracy: 0.8753
#
# Epoch 00009: val_accuracy improved from 0.85078 to 0.87528, saving model to ./models/tree_8/model_root_f1/folder10\model.h5
# Epoch 10/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.1355 - accuracy: 0.9473 - val_loss: 0.3135 - val_accuracy: 0.8797
#
# Epoch 00010: val_accuracy improved from 0.87528 to 0.87973, saving model to ./models/tree_8/model_root_f1/folder10\model.h5
# Epoch 11/25
# 127/127 [==============================] - 2s 19ms/step - loss: 0.0971 - accuracy: 0.9624 - val_loss: 0.3796 - val_accuracy: 0.8641
#
# Epoch 00011: val_accuracy did not improve from 0.87973
# Epoch 12/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0682 - accuracy: 0.9728 - val_loss: 0.3123 - val_accuracy: 0.8909
#
# Epoch 00012: val_accuracy improved from 0.87973 to 0.89087, saving model to ./models/tree_8/model_root_f1/folder10\model.h5
# Epoch 13/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.0412 - accuracy: 0.9874 - val_loss: 0.5046 - val_accuracy: 0.8597
#
# Epoch 00013: val_accuracy did not improve from 0.89087
# Epoch 14/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0606 - accuracy: 0.9775 - val_loss: 0.3722 - val_accuracy: 0.8864
#
# Epoch 00014: val_accuracy did not improve from 0.89087
# Epoch 15/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0078 - accuracy: 0.9990 - val_loss: 0.3825 - val_accuracy: 0.8909
#
# Epoch 00015: val_accuracy did not improve from 0.89087
# Epoch 16/25
# 127/127 [==============================] - 3s 20ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.4337 - val_accuracy: 0.8820
#
# Epoch 00016: val_accuracy did not improve from 0.89087
# Epoch 17/25
# 127/127 [==============================] - 2s 20ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4424 - val_accuracy: 0.8842
#
# Epoch 00017: val_accuracy did not improve from 0.89087
# Epoch 18/25
# 127/127 [==============================] - 3s 20ms/step - loss: 6.7604e-04 - accuracy: 1.0000 - val_loss: 0.4631 - val_accuracy: 0.8886
#
# Epoch 00018: val_accuracy did not improve from 0.89087
# Epoch 19/25
# 127/127 [==============================] - 3s 20ms/step - loss: 4.9553e-04 - accuracy: 1.0000 - val_loss: 0.4407 - val_accuracy: 0.8820
#
# Epoch 00019: val_accuracy did not improve from 0.89087
# Epoch 20/25
# 127/127 [==============================] - 3s 20ms/step - loss: 4.0634e-04 - accuracy: 1.0000 - val_loss: 0.4841 - val_accuracy: 0.8909
#
# Epoch 00020: val_accuracy did not improve from 0.89087
# Epoch 21/25
# 127/127 [==============================] - 3s 20ms/step - loss: 3.1250e-04 - accuracy: 1.0000 - val_loss: 0.4787 - val_accuracy: 0.8864
#
# Epoch 00021: val_accuracy did not improve from 0.89087
# Epoch 22/25
# 127/127 [==============================] - 3s 20ms/step - loss: 2.6110e-04 - accuracy: 1.0000 - val_loss: 0.4774 - val_accuracy: 0.8864
#
# Epoch 00022: val_accuracy did not improve from 0.89087
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 23/25
# 127/127 [==============================] - 3s 20ms/step - loss: 2.1859e-04 - accuracy: 1.0000 - val_loss: 0.4766 - val_accuracy: 0.8886
#
# Epoch 00023: val_accuracy did not improve from 0.89087
# Epoch 24/25
# 127/127 [==============================] - 3s 20ms/step - loss: 2.0001e-04 - accuracy: 1.0000 - val_loss: 0.4730 - val_accuracy: 0.8886
#
# Epoch 00024: val_accuracy did not improve from 0.89087
# Epoch 25/25
# 127/127 [==============================] - 3s 20ms/step - loss: 1.8500e-04 - accuracy: 1.0000 - val_loss: 0.4870 - val_accuracy: 0.8886
#
# Epoch 00025: val_accuracy did not improve from 0.89087
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
