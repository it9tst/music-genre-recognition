# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Country':2, 'Reggae':8, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {2: 'Country', 8: 'Reggae', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((2400, 128, 128), (2400, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((300, 128, 128), (300, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Country

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation='softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_11/model_root_f1_1_1_1_1_1_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_11/model_root_f1_1_1_1_1_1_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 3
n_splits = 15

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    dict_genres_list = list(dict_genres.values())
    split = [[dict_genres_list.pop(fold_no - 1)], dict_genres_list]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Country'], ['Reggae', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 79/79 [==============================] - 7s 31ms/step - loss: 0.6695 - accuracy: 0.6552 - val_loss: 0.6289 - val_accuracy: 0.6167
#
# Epoch 00001: val_accuracy improved from -inf to 0.61667, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 2/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.5432 - accuracy: 0.7179 - val_loss: 0.4691 - val_accuracy: 0.7722
#
# Epoch 00002: val_accuracy improved from 0.61667 to 0.77222, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 3/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.4604 - accuracy: 0.7563 - val_loss: 0.3735 - val_accuracy: 0.8167
#
# Epoch 00003: val_accuracy improved from 0.77222 to 0.81667, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 4/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.3967 - accuracy: 0.8163 - val_loss: 0.3018 - val_accuracy: 0.8667
#
# Epoch 00004: val_accuracy improved from 0.81667 to 0.86667, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 5/30
# 79/79 [==============================] - 2s 23ms/step - loss: 0.3244 - accuracy: 0.8567 - val_loss: 0.3019 - val_accuracy: 0.8611
#
# Epoch 00005: val_accuracy did not improve from 0.86667
# Epoch 6/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.2812 - accuracy: 0.8790 - val_loss: 0.2116 - val_accuracy: 0.9111
#
# Epoch 00006: val_accuracy improved from 0.86667 to 0.91111, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 7/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.2119 - accuracy: 0.9115 - val_loss: 0.2002 - val_accuracy: 0.9278
#
# Epoch 00007: val_accuracy improved from 0.91111 to 0.92778, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 8/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.1576 - accuracy: 0.9389 - val_loss: 0.1809 - val_accuracy: 0.9278
#
# Epoch 00008: val_accuracy did not improve from 0.92778
# Epoch 9/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.1400 - accuracy: 0.9472 - val_loss: 0.2666 - val_accuracy: 0.8833
#
# Epoch 00009: val_accuracy did not improve from 0.92778
# Epoch 10/30
# 79/79 [==============================] - 2s 23ms/step - loss: 0.0871 - accuracy: 0.9706 - val_loss: 0.1700 - val_accuracy: 0.9444
#
# Epoch 00010: val_accuracy improved from 0.92778 to 0.94444, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 11/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.0619 - accuracy: 0.9786 - val_loss: 0.2536 - val_accuracy: 0.9056
#
# Epoch 00011: val_accuracy did not improve from 0.94444
# Epoch 12/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.0543 - accuracy: 0.9802 - val_loss: 0.2793 - val_accuracy: 0.9167
#
# Epoch 00012: val_accuracy did not improve from 0.94444
# Epoch 13/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.0204 - accuracy: 0.9960 - val_loss: 0.2430 - val_accuracy: 0.9222
#
# Epoch 00013: val_accuracy did not improve from 0.94444
# Epoch 14/30
# 79/79 [==============================] - 2s 23ms/step - loss: 0.0088 - accuracy: 0.9988 - val_loss: 0.1987 - val_accuracy: 0.9500
#
# Epoch 00014: val_accuracy improved from 0.94444 to 0.95000, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 15/30
# 79/79 [==============================] - 2s 22ms/step - loss: 0.0037 - accuracy: 0.9996 - val_loss: 0.2668 - val_accuracy: 0.9278
#
# Epoch 00015: val_accuracy did not improve from 0.95000
# Epoch 16/30
# 79/79 [==============================] - 2s 20ms/step - loss: 8.2530e-04 - accuracy: 1.0000 - val_loss: 0.2269 - val_accuracy: 0.9556
#
# Epoch 00016: val_accuracy improved from 0.95000 to 0.95556, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder1\model.h5
# Epoch 17/30
# 79/79 [==============================] - 2s 21ms/step - loss: 4.4534e-04 - accuracy: 1.0000 - val_loss: 0.2681 - val_accuracy: 0.9389
#
# Epoch 00017: val_accuracy did not improve from 0.95556
# Epoch 18/30
# 79/79 [==============================] - 2s 21ms/step - loss: 3.3457e-04 - accuracy: 1.0000 - val_loss: 0.2702 - val_accuracy: 0.9389
#
# Epoch 00018: val_accuracy did not improve from 0.95556
# Epoch 19/30
# 79/79 [==============================] - 2s 21ms/step - loss: 2.6425e-04 - accuracy: 1.0000 - val_loss: 0.2641 - val_accuracy: 0.9500
#
# Epoch 00019: val_accuracy did not improve from 0.95556
# Epoch 20/30
# 79/79 [==============================] - 2s 21ms/step - loss: 2.2217e-04 - accuracy: 1.0000 - val_loss: 0.2802 - val_accuracy: 0.9389
#
# Epoch 00020: val_accuracy did not improve from 0.95556
# Epoch 21/30
# 79/79 [==============================] - 2s 21ms/step - loss: 1.8790e-04 - accuracy: 1.0000 - val_loss: 0.2648 - val_accuracy: 0.9500
#
# Epoch 00021: val_accuracy did not improve from 0.95556
# Epoch 22/30
# 79/79 [==============================] - 2s 21ms/step - loss: 1.6676e-04 - accuracy: 1.0000 - val_loss: 0.2849 - val_accuracy: 0.9444
#
# Epoch 00022: val_accuracy did not improve from 0.95556
# Epoch 23/30
# 79/79 [==============================] - 2s 23ms/step - loss: 1.4589e-04 - accuracy: 1.0000 - val_loss: 0.2758 - val_accuracy: 0.9500
#
# Epoch 00023: val_accuracy did not improve from 0.95556
# Epoch 24/30
# 79/79 [==============================] - 2s 20ms/step - loss: 1.2950e-04 - accuracy: 1.0000 - val_loss: 0.2938 - val_accuracy: 0.9389
#
# Epoch 00024: val_accuracy did not improve from 0.95556
# Epoch 25/30
# 79/79 [==============================] - 2s 20ms/step - loss: 1.1441e-04 - accuracy: 1.0000 - val_loss: 0.2901 - val_accuracy: 0.9500
#
# Epoch 00025: val_accuracy did not improve from 0.95556
# Epoch 26/30
# 79/79 [==============================] - 2s 21ms/step - loss: 1.0312e-04 - accuracy: 1.0000 - val_loss: 0.2972 - val_accuracy: 0.9389
#
# Epoch 00026: val_accuracy did not improve from 0.95556
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 27/30
# 79/79 [==============================] - 2s 21ms/step - loss: 9.3667e-05 - accuracy: 1.0000 - val_loss: 0.2904 - val_accuracy: 0.9500
#
# Epoch 00027: val_accuracy did not improve from 0.95556
# Epoch 28/30
# 79/79 [==============================] - 2s 23ms/step - loss: 8.9812e-05 - accuracy: 1.0000 - val_loss: 0.2966 - val_accuracy: 0.9444
#
# Epoch 00028: val_accuracy did not improve from 0.95556
# Epoch 29/30
# 79/79 [==============================] - 2s 22ms/step - loss: 8.5871e-05 - accuracy: 1.0000 - val_loss: 0.2977 - val_accuracy: 0.9444
#
# Epoch 00029: val_accuracy did not improve from 0.95556
# Epoch 30/30
# 79/79 [==============================] - 2s 20ms/step - loss: 8.1422e-05 - accuracy: 1.0000 - val_loss: 0.2965 - val_accuracy: 0.9500
#
# Epoch 00030: val_accuracy did not improve from 0.95556
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Reggae'], ['Country', 'Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 79/79 [==============================] - 2s 23ms/step - loss: 0.6550 - accuracy: 0.6587 - val_loss: 0.4629 - val_accuracy: 0.8000
#
# Epoch 00001: val_accuracy improved from -inf to 0.80000, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder2\model.h5
# Epoch 2/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.4251 - accuracy: 0.8091 - val_loss: 0.3463 - val_accuracy: 0.8833
#
# Epoch 00002: val_accuracy improved from 0.80000 to 0.88333, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder2\model.h5
# Epoch 3/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.3194 - accuracy: 0.8623 - val_loss: 0.2981 - val_accuracy: 0.8667
#
# Epoch 00003: val_accuracy did not improve from 0.88333
# Epoch 4/30
# 79/79 [==============================] - 2s 22ms/step - loss: 0.2557 - accuracy: 0.8988 - val_loss: 0.2894 - val_accuracy: 0.8889
#
# Epoch 00004: val_accuracy improved from 0.88333 to 0.88889, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder2\model.h5
# Epoch 5/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.2015 - accuracy: 0.9187 - val_loss: 0.3076 - val_accuracy: 0.8944
#
# Epoch 00005: val_accuracy improved from 0.88889 to 0.89444, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder2\model.h5
# Epoch 6/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.1597 - accuracy: 0.9429 - val_loss: 0.2644 - val_accuracy: 0.8833
#
# Epoch 00006: val_accuracy did not improve from 0.89444
# Epoch 7/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.1336 - accuracy: 0.9476 - val_loss: 0.1960 - val_accuracy: 0.9333
#
# Epoch 00007: val_accuracy improved from 0.89444 to 0.93333, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder2\model.h5
# Epoch 8/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.1099 - accuracy: 0.9607 - val_loss: 0.2692 - val_accuracy: 0.9000
#
# Epoch 00008: val_accuracy did not improve from 0.93333
# Epoch 9/30
# 79/79 [==============================] - 2s 22ms/step - loss: 0.0990 - accuracy: 0.9667 - val_loss: 0.2174 - val_accuracy: 0.9056
#
# Epoch 00009: val_accuracy did not improve from 0.93333
# Epoch 10/30
# 79/79 [==============================] - 2s 22ms/step - loss: 0.0776 - accuracy: 0.9726 - val_loss: 0.1753 - val_accuracy: 0.9333
#
# Epoch 00010: val_accuracy did not improve from 0.93333
# Epoch 11/30
# 79/79 [==============================] - 2s 23ms/step - loss: 0.0269 - accuracy: 0.9929 - val_loss: 0.1915 - val_accuracy: 0.9389
#
# Epoch 00011: val_accuracy improved from 0.93333 to 0.93889, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder2\model.h5
# Epoch 12/30
# 79/79 [==============================] - 2s 22ms/step - loss: 0.0245 - accuracy: 0.9925 - val_loss: 0.1989 - val_accuracy: 0.9278
#
# Epoch 00012: val_accuracy did not improve from 0.93889
# Epoch 13/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.0158 - accuracy: 0.9944 - val_loss: 0.1678 - val_accuracy: 0.9389
#
# Epoch 00013: val_accuracy did not improve from 0.93889
# Epoch 14/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1743 - val_accuracy: 0.9500
#
# Epoch 00014: val_accuracy improved from 0.93889 to 0.95000, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder2\model.h5
# Epoch 15/30
# 79/79 [==============================] - 2s 20ms/step - loss: 9.7506e-04 - accuracy: 1.0000 - val_loss: 0.1775 - val_accuracy: 0.9500
#
# Epoch 00015: val_accuracy did not improve from 0.95000
# Epoch 16/30
# 79/79 [==============================] - 2s 20ms/step - loss: 4.3983e-04 - accuracy: 1.0000 - val_loss: 0.1900 - val_accuracy: 0.9500
#
# Epoch 00016: val_accuracy did not improve from 0.95000
# Epoch 17/30
# 79/79 [==============================] - 2s 20ms/step - loss: 3.2172e-04 - accuracy: 1.0000 - val_loss: 0.1870 - val_accuracy: 0.9556
#
# Epoch 00017: val_accuracy improved from 0.95000 to 0.95556, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder2\model.h5
# Epoch 18/30
# 79/79 [==============================] - 2s 21ms/step - loss: 2.4903e-04 - accuracy: 1.0000 - val_loss: 0.1967 - val_accuracy: 0.9500
#
# Epoch 00018: val_accuracy did not improve from 0.95556
# Epoch 19/30
# 79/79 [==============================] - 2s 20ms/step - loss: 2.0429e-04 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9500
#
# Epoch 00019: val_accuracy did not improve from 0.95556
# Epoch 20/30
# 79/79 [==============================] - 2s 20ms/step - loss: 1.7133e-04 - accuracy: 1.0000 - val_loss: 0.2027 - val_accuracy: 0.9500
#
# Epoch 00020: val_accuracy did not improve from 0.95556
# Epoch 21/30
# 79/79 [==============================] - 2s 20ms/step - loss: 1.4282e-04 - accuracy: 1.0000 - val_loss: 0.2023 - val_accuracy: 0.9556
#
# Epoch 00021: val_accuracy did not improve from 0.95556
# Epoch 22/30
# 79/79 [==============================] - 2s 21ms/step - loss: 1.2160e-04 - accuracy: 1.0000 - val_loss: 0.2134 - val_accuracy: 0.9500
#
# Epoch 00022: val_accuracy did not improve from 0.95556
# Epoch 23/30
# 79/79 [==============================] - 2s 21ms/step - loss: 1.0512e-04 - accuracy: 1.0000 - val_loss: 0.2170 - val_accuracy: 0.9500
#
# Epoch 00023: val_accuracy did not improve from 0.95556
# Epoch 24/30
# 79/79 [==============================] - 2s 20ms/step - loss: 9.0383e-05 - accuracy: 1.0000 - val_loss: 0.2172 - val_accuracy: 0.9500
#
# Epoch 00024: val_accuracy did not improve from 0.95556
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 25/30
# 79/79 [==============================] - 2s 20ms/step - loss: 7.7566e-05 - accuracy: 1.0000 - val_loss: 0.2238 - val_accuracy: 0.9500
#
# Epoch 00025: val_accuracy did not improve from 0.95556
# Epoch 26/30
# 79/79 [==============================] - 2s 22ms/step - loss: 7.2814e-05 - accuracy: 1.0000 - val_loss: 0.2211 - val_accuracy: 0.9500
#
# Epoch 00026: val_accuracy did not improve from 0.95556
# Epoch 27/30
# 79/79 [==============================] - 2s 21ms/step - loss: 6.7645e-05 - accuracy: 1.0000 - val_loss: 0.2223 - val_accuracy: 0.9500
#
# Epoch 00027: val_accuracy did not improve from 0.95556
# Epoch 28/30
# 79/79 [==============================] - 2s 20ms/step - loss: 6.2762e-05 - accuracy: 1.0000 - val_loss: 0.2246 - val_accuracy: 0.9500
#
# Epoch 00028: val_accuracy did not improve from 0.95556
# Epoch 29/30
# 79/79 [==============================] - 2s 21ms/step - loss: 5.9127e-05 - accuracy: 1.0000 - val_loss: 0.2265 - val_accuracy: 0.9500
#
# Epoch 00029: val_accuracy did not improve from 0.95556
# Epoch 30/30
# 79/79 [==============================] - 2s 21ms/step - loss: 5.5013e-05 - accuracy: 1.0000 - val_loss: 0.2357 - val_accuracy: 0.9500
#
# Epoch 00030: val_accuracy did not improve from 0.95556
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Rock'], ['Country', 'Reggae']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 79/79 [==============================] - 2s 24ms/step - loss: 0.7098 - accuracy: 0.6619 - val_loss: 0.5207 - val_accuracy: 0.7167
#
# Epoch 00001: val_accuracy improved from -inf to 0.71667, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 2/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.5664 - accuracy: 0.7290 - val_loss: 0.5200 - val_accuracy: 0.8111
#
# Epoch 00002: val_accuracy improved from 0.71667 to 0.81111, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 3/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.5243 - accuracy: 0.7488 - val_loss: 0.5056 - val_accuracy: 0.7333
#
# Epoch 00003: val_accuracy did not improve from 0.81111
# Epoch 4/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.5091 - accuracy: 0.7560 - val_loss: 0.4688 - val_accuracy: 0.8111
#
# Epoch 00004: val_accuracy did not improve from 0.81111
# Epoch 5/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.4944 - accuracy: 0.7631 - val_loss: 0.4656 - val_accuracy: 0.8222
#
# Epoch 00005: val_accuracy improved from 0.81111 to 0.82222, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 6/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.5011 - accuracy: 0.7643 - val_loss: 0.4571 - val_accuracy: 0.8167
#
# Epoch 00006: val_accuracy did not improve from 0.82222
# Epoch 7/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.4876 - accuracy: 0.7599 - val_loss: 0.4829 - val_accuracy: 0.7833
#
# Epoch 00007: val_accuracy did not improve from 0.82222
# Epoch 8/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.4581 - accuracy: 0.7837 - val_loss: 0.4230 - val_accuracy: 0.8278
#
# Epoch 00008: val_accuracy improved from 0.82222 to 0.82778, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 9/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.4501 - accuracy: 0.7933 - val_loss: 0.4222 - val_accuracy: 0.8333
#
# Epoch 00009: val_accuracy improved from 0.82778 to 0.83333, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 10/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.4164 - accuracy: 0.8115 - val_loss: 0.3747 - val_accuracy: 0.8444
#
# Epoch 00010: val_accuracy improved from 0.83333 to 0.84444, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 11/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.3825 - accuracy: 0.8278 - val_loss: 0.3647 - val_accuracy: 0.8611
#
# Epoch 00011: val_accuracy improved from 0.84444 to 0.86111, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 12/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.3354 - accuracy: 0.8587 - val_loss: 0.3527 - val_accuracy: 0.8556
#
# Epoch 00012: val_accuracy did not improve from 0.86111
# Epoch 13/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.3099 - accuracy: 0.8627 - val_loss: 0.3209 - val_accuracy: 0.8556
#
# Epoch 00013: val_accuracy did not improve from 0.86111
# Epoch 14/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.2770 - accuracy: 0.8806 - val_loss: 0.2827 - val_accuracy: 0.8778
#
# Epoch 00014: val_accuracy improved from 0.86111 to 0.87778, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 15/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.2383 - accuracy: 0.8992 - val_loss: 0.4255 - val_accuracy: 0.7944
#
# Epoch 00015: val_accuracy did not improve from 0.87778
# Epoch 16/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.1985 - accuracy: 0.9210 - val_loss: 0.3341 - val_accuracy: 0.8611
#
# Epoch 00016: val_accuracy did not improve from 0.87778
# Epoch 17/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.1680 - accuracy: 0.9365 - val_loss: 0.2621 - val_accuracy: 0.8833
#
# Epoch 00017: val_accuracy improved from 0.87778 to 0.88333, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 18/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.1182 - accuracy: 0.9571 - val_loss: 0.2995 - val_accuracy: 0.8722
#
# Epoch 00018: val_accuracy did not improve from 0.88333
# Epoch 19/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.0937 - accuracy: 0.9659 - val_loss: 0.3245 - val_accuracy: 0.8556
#
# Epoch 00019: val_accuracy did not improve from 0.88333
# Epoch 20/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.0604 - accuracy: 0.9817 - val_loss: 0.2834 - val_accuracy: 0.8833
#
# Epoch 00020: val_accuracy did not improve from 0.88333
# Epoch 21/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.0398 - accuracy: 0.9869 - val_loss: 0.4482 - val_accuracy: 0.8611
#
# Epoch 00021: val_accuracy did not improve from 0.88333
# Epoch 22/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.0507 - accuracy: 0.9813 - val_loss: 0.3582 - val_accuracy: 0.8889
#
# Epoch 00022: val_accuracy improved from 0.88333 to 0.88889, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1/folder3\model.h5
# Epoch 23/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.0260 - accuracy: 0.9940 - val_loss: 0.4037 - val_accuracy: 0.8833
#
# Epoch 00023: val_accuracy did not improve from 0.88889
# Epoch 24/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.0341 - accuracy: 0.9877 - val_loss: 0.5378 - val_accuracy: 0.8889
#
# Epoch 00024: val_accuracy did not improve from 0.88889
# Epoch 25/30
# 79/79 [==============================] - 2s 21ms/step - loss: 0.0678 - accuracy: 0.9778 - val_loss: 0.4837 - val_accuracy: 0.8667
#
# Epoch 00025: val_accuracy did not improve from 0.88889
# Epoch 26/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.0217 - accuracy: 0.9925 - val_loss: 0.3885 - val_accuracy: 0.8667
#
# Epoch 00026: val_accuracy did not improve from 0.88889
# Epoch 27/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.4534 - val_accuracy: 0.8722
#
# Epoch 00027: val_accuracy did not improve from 0.88889
# Epoch 28/30
# 79/79 [==============================] - 2s 24ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4820 - val_accuracy: 0.8667
#
# Epoch 00028: val_accuracy did not improve from 0.88889
# Epoch 29/30
# 79/79 [==============================] - 2s 20ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4776 - val_accuracy: 0.8556
#
# Epoch 00029: val_accuracy did not improve from 0.88889
# Epoch 30/30
# 79/79 [==============================] - 2s 21ms/step - loss: 7.5209e-04 - accuracy: 1.0000 - val_loss: 0.4972 - val_accuracy: 0.8722
#
# Epoch 00030: val_accuracy did not improve from 0.88889
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
