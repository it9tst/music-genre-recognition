# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Blues':0, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Blues', 2: 'Country', 3: 'Disco', 4: 'Hip-Hop', 5: 'Jazz', 6: 'Metal', 7: 'Pop', 8: 'Reggae', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((7190, 128, 128), (7190, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((900, 128, 128), (900, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Disco

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation='softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_11/model_root_f1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_11/model_root_f1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 9
n_splits = 15

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    dict_genres_list = list(dict_genres.values())
    split = [[dict_genres_list.pop(fold_no - 1)], dict_genres_list]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Blues'], ['Country', 'Disco', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 236/236 [==============================] - 8s 23ms/step - loss: 0.3826 - accuracy: 0.8877 - val_loss: 0.3402 - val_accuracy: 0.8907
#
# Epoch 00001: val_accuracy improved from -inf to 0.89074, saving model to ./models/tree_11/model_root_f1/folder1\model.h5
# Epoch 2/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.3034 - accuracy: 0.8898 - val_loss: 0.2690 - val_accuracy: 0.8907
#
# Epoch 00002: val_accuracy did not improve from 0.89074
# Epoch 3/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.2617 - accuracy: 0.8996 - val_loss: 0.2536 - val_accuracy: 0.9074
#
# Epoch 00003: val_accuracy improved from 0.89074 to 0.90741, saving model to ./models/tree_11/model_root_f1/folder1\model.h5
# Epoch 4/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.2069 - accuracy: 0.9156 - val_loss: 0.1462 - val_accuracy: 0.9444
#
# Epoch 00004: val_accuracy improved from 0.90741 to 0.94444, saving model to ./models/tree_11/model_root_f1/folder1\model.h5
# Epoch 5/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.1626 - accuracy: 0.9344 - val_loss: 0.1317 - val_accuracy: 0.9463
#
# Epoch 00005: val_accuracy improved from 0.94444 to 0.94630, saving model to ./models/tree_11/model_root_f1/folder1\model.h5
# Epoch 6/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.1301 - accuracy: 0.9466 - val_loss: 0.1202 - val_accuracy: 0.9519
#
# Epoch 00006: val_accuracy improved from 0.94630 to 0.95185, saving model to ./models/tree_11/model_root_f1/folder1\model.h5
# Epoch 7/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.1088 - accuracy: 0.9572 - val_loss: 0.0968 - val_accuracy: 0.9648
#
# Epoch 00007: val_accuracy improved from 0.95185 to 0.96481, saving model to ./models/tree_11/model_root_f1/folder1\model.h5
# Epoch 8/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0724 - accuracy: 0.9730 - val_loss: 0.1322 - val_accuracy: 0.9556
#
# Epoch 00008: val_accuracy did not improve from 0.96481
# Epoch 9/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.0569 - accuracy: 0.9785 - val_loss: 0.0878 - val_accuracy: 0.9667
#
# Epoch 00009: val_accuracy improved from 0.96481 to 0.96667, saving model to ./models/tree_11/model_root_f1/folder1\model.h5
# Epoch 10/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0463 - accuracy: 0.9821 - val_loss: 0.0890 - val_accuracy: 0.9648
#
# Epoch 00010: val_accuracy did not improve from 0.96667
# Epoch 11/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.0496 - accuracy: 0.9813 - val_loss: 0.0859 - val_accuracy: 0.9611
#
# Epoch 00011: val_accuracy did not improve from 0.96667
# Epoch 12/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0334 - accuracy: 0.9862 - val_loss: 0.1475 - val_accuracy: 0.9556
#
# Epoch 00012: val_accuracy did not improve from 0.96667
# Epoch 13/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.0147 - accuracy: 0.9950 - val_loss: 0.1830 - val_accuracy: 0.9500
#
# Epoch 00013: val_accuracy did not improve from 0.96667
# Epoch 14/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0226 - accuracy: 0.9918 - val_loss: 0.1268 - val_accuracy: 0.9667
#
# Epoch 00014: val_accuracy did not improve from 0.96667
# Epoch 15/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0285 - accuracy: 0.9905 - val_loss: 0.1861 - val_accuracy: 0.9519
#
# Epoch 00015: val_accuracy did not improve from 0.96667
# Epoch 16/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.0197 - accuracy: 0.9931 - val_loss: 0.1060 - val_accuracy: 0.9648
#
# Epoch 00016: val_accuracy did not improve from 0.96667
# Epoch 17/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.0520 - accuracy: 0.9803 - val_loss: 0.1028 - val_accuracy: 0.9667
#
# Epoch 00017: val_accuracy did not improve from 0.96667
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 18/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0097 - accuracy: 0.9967 - val_loss: 0.1032 - val_accuracy: 0.9630
#
# Epoch 00018: val_accuracy did not improve from 0.96667
# Epoch 19/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0877 - val_accuracy: 0.9722
#
# Epoch 00019: val_accuracy improved from 0.96667 to 0.97222, saving model to ./models/tree_11/model_root_f1/folder1\model.h5
# Epoch 20/30
# 236/236 [==============================] - 5s 19ms/step - loss: 5.6446e-04 - accuracy: 1.0000 - val_loss: 0.0887 - val_accuracy: 0.9667
#
# Epoch 00020: val_accuracy did not improve from 0.97222
# Epoch 21/30
# 236/236 [==============================] - 5s 19ms/step - loss: 3.8083e-04 - accuracy: 1.0000 - val_loss: 0.0897 - val_accuracy: 0.9685
#
# Epoch 00021: val_accuracy did not improve from 0.97222
# Epoch 22/30
# 236/236 [==============================] - 5s 19ms/step - loss: 2.8321e-04 - accuracy: 1.0000 - val_loss: 0.0980 - val_accuracy: 0.9648
#
# Epoch 00022: val_accuracy did not improve from 0.97222
# Epoch 23/30
# 236/236 [==============================] - 5s 20ms/step - loss: 2.2283e-04 - accuracy: 1.0000 - val_loss: 0.0984 - val_accuracy: 0.9648
#
# Epoch 00023: val_accuracy did not improve from 0.97222
# Epoch 24/30
# 236/236 [==============================] - 5s 19ms/step - loss: 1.7767e-04 - accuracy: 1.0000 - val_loss: 0.0969 - val_accuracy: 0.9648
#
# Epoch 00024: val_accuracy did not improve from 0.97222
# Epoch 25/30
# 236/236 [==============================] - 4s 19ms/step - loss: 1.4496e-04 - accuracy: 1.0000 - val_loss: 0.1001 - val_accuracy: 0.9667
#
# Epoch 00025: val_accuracy did not improve from 0.97222
# Epoch 26/30
# 236/236 [==============================] - 5s 19ms/step - loss: 1.1963e-04 - accuracy: 1.0000 - val_loss: 0.1018 - val_accuracy: 0.9648
#
# Epoch 00026: val_accuracy did not improve from 0.97222
# Epoch 27/30
# 236/236 [==============================] - 5s 20ms/step - loss: 9.8601e-05 - accuracy: 1.0000 - val_loss: 0.1025 - val_accuracy: 0.9648
#
# Epoch 00027: val_accuracy did not improve from 0.97222
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 28/30
# 236/236 [==============================] - 5s 20ms/step - loss: 8.3216e-05 - accuracy: 1.0000 - val_loss: 0.1053 - val_accuracy: 0.9648
#
# Epoch 00028: val_accuracy did not improve from 0.97222
# Epoch 29/30
# 236/236 [==============================] - 5s 19ms/step - loss: 7.6106e-05 - accuracy: 1.0000 - val_loss: 0.1058 - val_accuracy: 0.9648
#
# Epoch 00029: val_accuracy did not improve from 0.97222
# Epoch 30/30
# 236/236 [==============================] - 5s 19ms/step - loss: 6.9831e-05 - accuracy: 1.0000 - val_loss: 0.1072 - val_accuracy: 0.9648
#
# Epoch 00030: val_accuracy did not improve from 0.97222
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Country'], ['Blues', 'Disco', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.3530 - accuracy: 0.8832 - val_loss: 0.2982 - val_accuracy: 0.8741
#
# Epoch 00001: val_accuracy improved from -inf to 0.87407, saving model to ./models/tree_11/model_root_f1/folder2\model.h5
# Epoch 2/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.2507 - accuracy: 0.8938 - val_loss: 0.2431 - val_accuracy: 0.8852
#
# Epoch 00002: val_accuracy improved from 0.87407 to 0.88519, saving model to ./models/tree_11/model_root_f1/folder2\model.h5
# Epoch 3/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.2290 - accuracy: 0.9017 - val_loss: 0.2296 - val_accuracy: 0.8926
#
# Epoch 00003: val_accuracy improved from 0.88519 to 0.89259, saving model to ./models/tree_11/model_root_f1/folder2\model.h5
# Epoch 4/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.1961 - accuracy: 0.9205 - val_loss: 0.2292 - val_accuracy: 0.8907
#
# Epoch 00004: val_accuracy did not improve from 0.89259
# Epoch 5/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.1706 - accuracy: 0.9326 - val_loss: 0.2238 - val_accuracy: 0.9093
#
# Epoch 00005: val_accuracy improved from 0.89259 to 0.90926, saving model to ./models/tree_11/model_root_f1/folder2\model.h5
# Epoch 6/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.1454 - accuracy: 0.9421 - val_loss: 0.2176 - val_accuracy: 0.9093
#
# Epoch 00006: val_accuracy did not improve from 0.90926
# Epoch 7/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.1311 - accuracy: 0.9509 - val_loss: 0.1627 - val_accuracy: 0.9333
#
# Epoch 00007: val_accuracy improved from 0.90926 to 0.93333, saving model to ./models/tree_11/model_root_f1/folder2\model.h5
# Epoch 8/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.1135 - accuracy: 0.9556 - val_loss: 0.1507 - val_accuracy: 0.9296
#
# Epoch 00008: val_accuracy did not improve from 0.93333
# Epoch 9/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0842 - accuracy: 0.9681 - val_loss: 0.1703 - val_accuracy: 0.9370
#
# Epoch 00009: val_accuracy improved from 0.93333 to 0.93704, saving model to ./models/tree_11/model_root_f1/folder2\model.h5
# Epoch 10/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0621 - accuracy: 0.9774 - val_loss: 0.1648 - val_accuracy: 0.9500
#
# Epoch 00010: val_accuracy improved from 0.93704 to 0.95000, saving model to ./models/tree_11/model_root_f1/folder2\model.h5
# Epoch 11/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.0463 - accuracy: 0.9846 - val_loss: 0.2000 - val_accuracy: 0.9333
#
# Epoch 00011: val_accuracy did not improve from 0.95000
# Epoch 12/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.0350 - accuracy: 0.9874 - val_loss: 0.3378 - val_accuracy: 0.9296
#
# Epoch 00012: val_accuracy did not improve from 0.95000
# Epoch 13/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.0234 - accuracy: 0.9915 - val_loss: 0.1773 - val_accuracy: 0.9481
#
# Epoch 00013: val_accuracy did not improve from 0.95000
# Epoch 14/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0279 - accuracy: 0.9907 - val_loss: 0.1668 - val_accuracy: 0.9444
#
# Epoch 00014: val_accuracy did not improve from 0.95000
# Epoch 15/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0133 - accuracy: 0.9954 - val_loss: 0.3668 - val_accuracy: 0.9333
#
# Epoch 00015: val_accuracy did not improve from 0.95000
# Epoch 16/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.0483 - accuracy: 0.9824 - val_loss: 0.1868 - val_accuracy: 0.9407
#
# Epoch 00016: val_accuracy did not improve from 0.95000
# Epoch 17/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0245 - accuracy: 0.9914 - val_loss: 0.1784 - val_accuracy: 0.9481
#
# Epoch 00017: val_accuracy did not improve from 0.95000
# Epoch 18/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.0156 - accuracy: 0.9944 - val_loss: 0.2931 - val_accuracy: 0.9370
#
# Epoch 00018: val_accuracy did not improve from 0.95000
# Epoch 19/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.0111 - accuracy: 0.9958 - val_loss: 0.2197 - val_accuracy: 0.9481
#
# Epoch 00019: val_accuracy did not improve from 0.95000
# Epoch 20/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.0079 - accuracy: 0.9971 - val_loss: 0.2060 - val_accuracy: 0.9500
#
# Epoch 00020: val_accuracy did not improve from 0.95000
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/30
# 236/236 [==============================] - 5s 20ms/step - loss: 6.3108e-04 - accuracy: 0.9999 - val_loss: 0.2334 - val_accuracy: 0.9444
#
# Epoch 00021: val_accuracy did not improve from 0.95000
# Epoch 22/30
# 236/236 [==============================] - 5s 20ms/step - loss: 1.8426e-04 - accuracy: 1.0000 - val_loss: 0.2348 - val_accuracy: 0.9481
#
# Epoch 00022: val_accuracy did not improve from 0.95000
# Epoch 23/30
# 236/236 [==============================] - 5s 19ms/step - loss: 1.2971e-04 - accuracy: 1.0000 - val_loss: 0.2398 - val_accuracy: 0.9463
#
# Epoch 00023: val_accuracy did not improve from 0.95000
# Epoch 24/30
# 236/236 [==============================] - 5s 20ms/step - loss: 1.0026e-04 - accuracy: 1.0000 - val_loss: 0.2420 - val_accuracy: 0.9444
#
# Epoch 00024: val_accuracy did not improve from 0.95000
# Epoch 25/30
# 236/236 [==============================] - 5s 19ms/step - loss: 8.2366e-05 - accuracy: 1.0000 - val_loss: 0.2467 - val_accuracy: 0.9463
#
# Epoch 00025: val_accuracy did not improve from 0.95000
# Epoch 26/30
# 236/236 [==============================] - 5s 20ms/step - loss: 6.8730e-05 - accuracy: 1.0000 - val_loss: 0.2505 - val_accuracy: 0.9463
#
# Epoch 00026: val_accuracy did not improve from 0.95000
# Epoch 27/30
# 236/236 [==============================] - 5s 20ms/step - loss: 5.7903e-05 - accuracy: 1.0000 - val_loss: 0.2560 - val_accuracy: 0.9481
#
# Epoch 00027: val_accuracy did not improve from 0.95000
# Epoch 28/30
# 236/236 [==============================] - 5s 19ms/step - loss: 4.9418e-05 - accuracy: 1.0000 - val_loss: 0.2605 - val_accuracy: 0.9481
#
# Epoch 00028: val_accuracy did not improve from 0.95000
# Epoch 29/30
# 236/236 [==============================] - 5s 20ms/step - loss: 4.2430e-05 - accuracy: 1.0000 - val_loss: 0.2610 - val_accuracy: 0.9463
#
# Epoch 00029: val_accuracy did not improve from 0.95000
# Epoch 30/30
# 236/236 [==============================] - 5s 19ms/step - loss: 3.6528e-05 - accuracy: 1.0000 - val_loss: 0.2655 - val_accuracy: 0.9463
#
# Epoch 00030: val_accuracy did not improve from 0.95000
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Disco'], ['Blues', 'Country', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.3649 - accuracy: 0.8894 - val_loss: 0.3613 - val_accuracy: 0.8796
#
# Epoch 00001: val_accuracy improved from -inf to 0.87963, saving model to ./models/tree_11/model_root_f1/folder3\model.h5
# Epoch 2/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.3322 - accuracy: 0.8894 - val_loss: 0.3077 - val_accuracy: 0.8796
#
# Epoch 00002: val_accuracy did not improve from 0.87963
# Epoch 3/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.3079 - accuracy: 0.8879 - val_loss: 0.2574 - val_accuracy: 0.8815
#
# Epoch 00003: val_accuracy improved from 0.87963 to 0.88148, saving model to ./models/tree_11/model_root_f1/folder3\model.h5
# Epoch 4/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.2393 - accuracy: 0.9126 - val_loss: 0.1894 - val_accuracy: 0.9370
#
# Epoch 00004: val_accuracy improved from 0.88148 to 0.93704, saving model to ./models/tree_11/model_root_f1/folder3\model.h5
# Epoch 5/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.1795 - accuracy: 0.9360 - val_loss: 0.1594 - val_accuracy: 0.9463
#
# Epoch 00005: val_accuracy improved from 0.93704 to 0.94630, saving model to ./models/tree_11/model_root_f1/folder3\model.h5
# Epoch 6/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.1622 - accuracy: 0.9438 - val_loss: 0.1861 - val_accuracy: 0.9389
#
# Epoch 00006: val_accuracy did not improve from 0.94630
# Epoch 7/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.1354 - accuracy: 0.9555 - val_loss: 0.1469 - val_accuracy: 0.9556
#
# Epoch 00007: val_accuracy improved from 0.94630 to 0.95556, saving model to ./models/tree_11/model_root_f1/folder3\model.h5
# Epoch 8/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.1162 - accuracy: 0.9623 - val_loss: 0.1520 - val_accuracy: 0.9463
#
# Epoch 00008: val_accuracy did not improve from 0.95556
# Epoch 9/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.1110 - accuracy: 0.9626 - val_loss: 0.1311 - val_accuracy: 0.9611
#
# Epoch 00009: val_accuracy improved from 0.95556 to 0.96111, saving model to ./models/tree_11/model_root_f1/folder3\model.h5
# Epoch 10/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.1009 - accuracy: 0.9657 - val_loss: 0.1304 - val_accuracy: 0.9593
#
# Epoch 00010: val_accuracy did not improve from 0.96111
# Epoch 11/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0900 - accuracy: 0.9705 - val_loss: 0.1699 - val_accuracy: 0.9444
#
# Epoch 00011: val_accuracy did not improve from 0.96111
# Epoch 12/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0730 - accuracy: 0.9755 - val_loss: 0.1785 - val_accuracy: 0.9389
#
# Epoch 00012: val_accuracy did not improve from 0.96111
# Epoch 13/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0700 - accuracy: 0.9763 - val_loss: 0.1216 - val_accuracy: 0.9630
#
# Epoch 00013: val_accuracy improved from 0.96111 to 0.96296, saving model to ./models/tree_11/model_root_f1/folder3\model.h5
# Epoch 14/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0557 - accuracy: 0.9817 - val_loss: 0.1407 - val_accuracy: 0.9593
#
# Epoch 00014: val_accuracy did not improve from 0.96296
# Epoch 15/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0535 - accuracy: 0.9817 - val_loss: 0.1381 - val_accuracy: 0.9685
#
# Epoch 00015: val_accuracy improved from 0.96296 to 0.96852, saving model to ./models/tree_11/model_root_f1/folder3\model.h5
# Epoch 16/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0290 - accuracy: 0.9909 - val_loss: 0.1349 - val_accuracy: 0.9759
#
# Epoch 00016: val_accuracy improved from 0.96852 to 0.97593, saving model to ./models/tree_11/model_root_f1/folder3\model.h5
# Epoch 17/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0248 - accuracy: 0.9914 - val_loss: 0.1583 - val_accuracy: 0.9556
#
# Epoch 00017: val_accuracy did not improve from 0.97593
# Epoch 18/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0275 - accuracy: 0.9910 - val_loss: 0.1408 - val_accuracy: 0.9685
#
# Epoch 00018: val_accuracy did not improve from 0.97593
# Epoch 19/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0166 - accuracy: 0.9943 - val_loss: 0.1522 - val_accuracy: 0.9630
#
# Epoch 00019: val_accuracy did not improve from 0.97593
# Epoch 20/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0181 - accuracy: 0.9936 - val_loss: 0.1880 - val_accuracy: 0.9463
#
# Epoch 00020: val_accuracy did not improve from 0.97593
# Epoch 21/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0147 - accuracy: 0.9948 - val_loss: 0.1752 - val_accuracy: 0.9648
#
# Epoch 00021: val_accuracy did not improve from 0.97593
# Epoch 22/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0109 - accuracy: 0.9970 - val_loss: 0.1797 - val_accuracy: 0.9648
#
# Epoch 00022: val_accuracy did not improve from 0.97593
# Epoch 23/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.2024 - val_accuracy: 0.9630
#
# Epoch 00023: val_accuracy did not improve from 0.97593
# Epoch 24/30
# 236/236 [==============================] - 4s 19ms/step - loss: 7.9179e-04 - accuracy: 1.0000 - val_loss: 0.2429 - val_accuracy: 0.9611
#
# Epoch 00024: val_accuracy did not improve from 0.97593
# Epoch 25/30
# 236/236 [==============================] - 4s 19ms/step - loss: 2.4906e-04 - accuracy: 1.0000 - val_loss: 0.2099 - val_accuracy: 0.9667
#
# Epoch 00025: val_accuracy did not improve from 0.97593
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 26/30
# 236/236 [==============================] - 4s 19ms/step - loss: 1.1802e-04 - accuracy: 1.0000 - val_loss: 0.2166 - val_accuracy: 0.9685
#
# Epoch 00026: val_accuracy did not improve from 0.97593
# Epoch 27/30
# 236/236 [==============================] - 4s 19ms/step - loss: 9.7147e-05 - accuracy: 1.0000 - val_loss: 0.2192 - val_accuracy: 0.9667
#
# Epoch 00027: val_accuracy did not improve from 0.97593
# Epoch 28/30
# 236/236 [==============================] - 4s 19ms/step - loss: 8.3577e-05 - accuracy: 1.0000 - val_loss: 0.2218 - val_accuracy: 0.9667
#
# Epoch 00028: val_accuracy did not improve from 0.97593
# Epoch 29/30
# 236/236 [==============================] - 4s 19ms/step - loss: 7.1878e-05 - accuracy: 1.0000 - val_loss: 0.2247 - val_accuracy: 0.9667
#
# Epoch 00029: val_accuracy did not improve from 0.97593
# Epoch 30/30
# 236/236 [==============================] - 5s 20ms/step - loss: 6.3407e-05 - accuracy: 1.0000 - val_loss: 0.2277 - val_accuracy: 0.9667
#
# Epoch 00030: val_accuracy did not improve from 0.97593
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Hip-Hop'], ['Blues', 'Country', 'Disco', 'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.3875 - accuracy: 0.8785 - val_loss: 0.2239 - val_accuracy: 0.9019
#
# Epoch 00001: val_accuracy improved from -inf to 0.90185, saving model to ./models/tree_11/model_root_f1/folder4\model.h5
# Epoch 2/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.2573 - accuracy: 0.8906 - val_loss: 0.1973 - val_accuracy: 0.9074
#
# Epoch 00002: val_accuracy improved from 0.90185 to 0.90741, saving model to ./models/tree_11/model_root_f1/folder4\model.h5
# Epoch 3/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.2030 - accuracy: 0.9172 - val_loss: 0.1622 - val_accuracy: 0.9352
#
# Epoch 00003: val_accuracy improved from 0.90741 to 0.93519, saving model to ./models/tree_11/model_root_f1/folder4\model.h5
# Epoch 4/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.1667 - accuracy: 0.9340 - val_loss: 0.2247 - val_accuracy: 0.9130
#
# Epoch 00004: val_accuracy did not improve from 0.93519
# Epoch 5/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.1449 - accuracy: 0.9438 - val_loss: 0.1252 - val_accuracy: 0.9574
#
# Epoch 00005: val_accuracy improved from 0.93519 to 0.95741, saving model to ./models/tree_11/model_root_f1/folder4\model.h5
# Epoch 6/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.1073 - accuracy: 0.9562 - val_loss: 0.1425 - val_accuracy: 0.9519
#
# Epoch 00006: val_accuracy did not improve from 0.95741
# Epoch 7/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0760 - accuracy: 0.9706 - val_loss: 0.1128 - val_accuracy: 0.9722
#
# Epoch 00007: val_accuracy improved from 0.95741 to 0.97222, saving model to ./models/tree_11/model_root_f1/folder4\model.h5
# Epoch 8/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0413 - accuracy: 0.9864 - val_loss: 0.2297 - val_accuracy: 0.9444
#
# Epoch 00008: val_accuracy did not improve from 0.97222
# Epoch 9/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0360 - accuracy: 0.9868 - val_loss: 0.1609 - val_accuracy: 0.9593
#
# Epoch 00009: val_accuracy did not improve from 0.97222
# Epoch 10/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0294 - accuracy: 0.9894 - val_loss: 0.2604 - val_accuracy: 0.9500
#
# Epoch 00010: val_accuracy did not improve from 0.97222
# Epoch 11/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0237 - accuracy: 0.9915 - val_loss: 0.1839 - val_accuracy: 0.9611
#
# Epoch 00011: val_accuracy did not improve from 0.97222
# Epoch 12/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0381 - accuracy: 0.9877 - val_loss: 0.1984 - val_accuracy: 0.9667
#
# Epoch 00012: val_accuracy did not improve from 0.97222
# Epoch 13/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0054 - accuracy: 0.9985 - val_loss: 0.2119 - val_accuracy: 0.9667
#
# Epoch 00013: val_accuracy did not improve from 0.97222
# Epoch 14/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.1654 - val_accuracy: 0.9648
#
# Epoch 00014: val_accuracy did not improve from 0.97222
# Epoch 15/30
# 236/236 [==============================] - 5s 19ms/step - loss: 2.4987e-04 - accuracy: 1.0000 - val_loss: 0.1960 - val_accuracy: 0.9778
#
# Epoch 00015: val_accuracy improved from 0.97222 to 0.97778, saving model to ./models/tree_11/model_root_f1/folder4\model.h5
# Epoch 16/30
# 236/236 [==============================] - 4s 19ms/step - loss: 8.7821e-05 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9778
#
# Epoch 00016: val_accuracy did not improve from 0.97778
# Epoch 17/30
# 236/236 [==============================] - 4s 19ms/step - loss: 6.0261e-05 - accuracy: 1.0000 - val_loss: 0.2155 - val_accuracy: 0.9796
#
# Epoch 00017: val_accuracy improved from 0.97778 to 0.97963, saving model to ./models/tree_11/model_root_f1/folder4\model.h5
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 18/30
# 236/236 [==============================] - 4s 19ms/step - loss: 4.7161e-05 - accuracy: 1.0000 - val_loss: 0.2214 - val_accuracy: 0.9778
#
# Epoch 00018: val_accuracy did not improve from 0.97963
# Epoch 19/30
# 236/236 [==============================] - 4s 19ms/step - loss: 4.2118e-05 - accuracy: 1.0000 - val_loss: 0.2215 - val_accuracy: 0.9796
#
# Epoch 00019: val_accuracy did not improve from 0.97963
# Epoch 20/30
# 236/236 [==============================] - 4s 19ms/step - loss: 3.7115e-05 - accuracy: 1.0000 - val_loss: 0.2238 - val_accuracy: 0.9796
#
# Epoch 00020: val_accuracy did not improve from 0.97963
# Epoch 21/30
# 236/236 [==============================] - 4s 19ms/step - loss: 3.3062e-05 - accuracy: 1.0000 - val_loss: 0.2299 - val_accuracy: 0.9778
#
# Epoch 00021: val_accuracy did not improve from 0.97963
# Epoch 22/30
# 236/236 [==============================] - 5s 19ms/step - loss: 2.9412e-05 - accuracy: 1.0000 - val_loss: 0.2305 - val_accuracy: 0.9796
#
# Epoch 00022: val_accuracy did not improve from 0.97963
# Epoch 23/30
# 236/236 [==============================] - 5s 20ms/step - loss: 2.5915e-05 - accuracy: 1.0000 - val_loss: 0.2304 - val_accuracy: 0.9796
#
# Epoch 00023: val_accuracy did not improve from 0.97963
# Epoch 24/30
# 236/236 [==============================] - 5s 19ms/step - loss: 2.2908e-05 - accuracy: 1.0000 - val_loss: 0.2382 - val_accuracy: 0.9796
#
# Epoch 00024: val_accuracy did not improve from 0.97963
# Epoch 25/30
# 236/236 [==============================] - 4s 19ms/step - loss: 1.9248e-05 - accuracy: 1.0000 - val_loss: 0.2394 - val_accuracy: 0.9796
#
# Epoch 00025: val_accuracy did not improve from 0.97963
# Epoch 26/30
# 236/236 [==============================] - 4s 19ms/step - loss: 1.5920e-05 - accuracy: 1.0000 - val_loss: 0.2459 - val_accuracy: 0.9796
#
# Epoch 00026: val_accuracy did not improve from 0.97963
# Epoch 27/30
# 236/236 [==============================] - 5s 19ms/step - loss: 1.3125e-05 - accuracy: 1.0000 - val_loss: 0.2495 - val_accuracy: 0.9796
#
# Epoch 00027: val_accuracy did not improve from 0.97963
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 28/30
# 236/236 [==============================] - 5s 19ms/step - loss: 1.0941e-05 - accuracy: 1.0000 - val_loss: 0.2554 - val_accuracy: 0.9778
#
# Epoch 00028: val_accuracy did not improve from 0.97963
# Epoch 29/30
# 236/236 [==============================] - 4s 19ms/step - loss: 9.8321e-06 - accuracy: 1.0000 - val_loss: 0.2554 - val_accuracy: 0.9778
#
# Epoch 00029: val_accuracy did not improve from 0.97963
# Epoch 30/30
# 236/236 [==============================] - 5s 19ms/step - loss: 8.7424e-06 - accuracy: 1.0000 - val_loss: 0.2588 - val_accuracy: 0.9778
#
# Epoch 00030: val_accuracy did not improve from 0.97963
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 5
# Genre split [['Jazz'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.3236 - accuracy: 0.8922 - val_loss: 0.1718 - val_accuracy: 0.9204
#
# Epoch 00001: val_accuracy improved from -inf to 0.92037, saving model to ./models/tree_11/model_root_f1/folder5\model.h5
# Epoch 2/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.1612 - accuracy: 0.9327 - val_loss: 0.1346 - val_accuracy: 0.9481
#
# Epoch 00002: val_accuracy improved from 0.92037 to 0.94815, saving model to ./models/tree_11/model_root_f1/folder5\model.h5
# Epoch 3/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.1270 - accuracy: 0.9468 - val_loss: 0.0966 - val_accuracy: 0.9667
#
# Epoch 00003: val_accuracy improved from 0.94815 to 0.96667, saving model to ./models/tree_11/model_root_f1/folder5\model.h5
# Epoch 4/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0796 - accuracy: 0.9691 - val_loss: 0.1202 - val_accuracy: 0.9685
#
# Epoch 00004: val_accuracy improved from 0.96667 to 0.96852, saving model to ./models/tree_11/model_root_f1/folder5\model.h5
# Epoch 5/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0645 - accuracy: 0.9742 - val_loss: 0.0774 - val_accuracy: 0.9667
#
# Epoch 00005: val_accuracy did not improve from 0.96852
# Epoch 6/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0480 - accuracy: 0.9817 - val_loss: 0.0893 - val_accuracy: 0.9630
#
# Epoch 00006: val_accuracy did not improve from 0.96852
# Epoch 7/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0370 - accuracy: 0.9840 - val_loss: 0.0808 - val_accuracy: 0.9704
#
# Epoch 00007: val_accuracy improved from 0.96852 to 0.97037, saving model to ./models/tree_11/model_root_f1/folder5\model.h5
# Epoch 8/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0333 - accuracy: 0.9879 - val_loss: 0.0739 - val_accuracy: 0.9778
#
# Epoch 00008: val_accuracy improved from 0.97037 to 0.97778, saving model to ./models/tree_11/model_root_f1/folder5\model.h5
# Epoch 9/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0090 - accuracy: 0.9968 - val_loss: 0.0672 - val_accuracy: 0.9815
#
# Epoch 00009: val_accuracy improved from 0.97778 to 0.98148, saving model to ./models/tree_11/model_root_f1/folder5\model.h5
# Epoch 10/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0230 - accuracy: 0.9913 - val_loss: 0.1356 - val_accuracy: 0.9537
#
# Epoch 00010: val_accuracy did not improve from 0.98148
# Epoch 11/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0184 - accuracy: 0.9918 - val_loss: 0.1093 - val_accuracy: 0.9759
#
# Epoch 00011: val_accuracy did not improve from 0.98148
# Epoch 12/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0230 - accuracy: 0.9917 - val_loss: 0.1476 - val_accuracy: 0.9593
#
# Epoch 00012: val_accuracy did not improve from 0.98148
# Epoch 13/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0254 - accuracy: 0.9910 - val_loss: 0.1276 - val_accuracy: 0.9648
#
# Epoch 00013: val_accuracy did not improve from 0.98148
# Epoch 14/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0169 - accuracy: 0.9940 - val_loss: 0.1527 - val_accuracy: 0.9667
#
# Epoch 00014: val_accuracy did not improve from 0.98148
# Epoch 15/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0133 - accuracy: 0.9944 - val_loss: 0.0677 - val_accuracy: 0.9852
#
# Epoch 00015: val_accuracy improved from 0.98148 to 0.98519, saving model to ./models/tree_11/model_root_f1/folder5\model.h5
# Epoch 16/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0847 - val_accuracy: 0.9833
#
# Epoch 00016: val_accuracy did not improve from 0.98519
# Epoch 17/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0103 - accuracy: 0.9963 - val_loss: 0.0869 - val_accuracy: 0.9722
#
# Epoch 00017: val_accuracy did not improve from 0.98519
# Epoch 18/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0442 - accuracy: 0.9852 - val_loss: 0.1267 - val_accuracy: 0.9630
#
# Epoch 00018: val_accuracy did not improve from 0.98519
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 19/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.0650 - val_accuracy: 0.9833
#
# Epoch 00019: val_accuracy did not improve from 0.98519
# Epoch 20/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0725 - val_accuracy: 0.9833
#
# Epoch 00020: val_accuracy did not improve from 0.98519
# Epoch 21/30
# 236/236 [==============================] - 4s 19ms/step - loss: 2.9596e-04 - accuracy: 1.0000 - val_loss: 0.0740 - val_accuracy: 0.9833
#
# Epoch 00021: val_accuracy did not improve from 0.98519
# Epoch 22/30
# 236/236 [==============================] - 5s 19ms/step - loss: 1.7643e-04 - accuracy: 1.0000 - val_loss: 0.0795 - val_accuracy: 0.9833
#
# Epoch 00022: val_accuracy did not improve from 0.98519
# Epoch 23/30
# 236/236 [==============================] - 5s 19ms/step - loss: 1.2727e-04 - accuracy: 1.0000 - val_loss: 0.0808 - val_accuracy: 0.9833
#
# Epoch 00023: val_accuracy did not improve from 0.98519
# Epoch 24/30
# 236/236 [==============================] - 5s 19ms/step - loss: 9.6617e-05 - accuracy: 1.0000 - val_loss: 0.0834 - val_accuracy: 0.9833
#
# Epoch 00024: val_accuracy did not improve from 0.98519
# Epoch 25/30
# 236/236 [==============================] - 5s 19ms/step - loss: 7.6011e-05 - accuracy: 1.0000 - val_loss: 0.0847 - val_accuracy: 0.9833
#
# Epoch 00025: val_accuracy did not improve from 0.98519
# Epoch 26/30
# 236/236 [==============================] - 5s 19ms/step - loss: 6.0533e-05 - accuracy: 1.0000 - val_loss: 0.0866 - val_accuracy: 0.9833
#
# Epoch 00026: val_accuracy did not improve from 0.98519
# Epoch 27/30
# 236/236 [==============================] - 5s 19ms/step - loss: 4.9518e-05 - accuracy: 1.0000 - val_loss: 0.0889 - val_accuracy: 0.9833
#
# Epoch 00027: val_accuracy did not improve from 0.98519
# Epoch 28/30
# 236/236 [==============================] - 4s 19ms/step - loss: 4.0484e-05 - accuracy: 1.0000 - val_loss: 0.0911 - val_accuracy: 0.9833
#
# Epoch 00028: val_accuracy did not improve from 0.98519
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 29/30
# 236/236 [==============================] - 5s 19ms/step - loss: 3.3596e-05 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 0.9833
#
# Epoch 00029: val_accuracy did not improve from 0.98519
# Epoch 30/30
# 236/236 [==============================] - 5s 19ms/step - loss: 3.0169e-05 - accuracy: 1.0000 - val_loss: 0.0926 - val_accuracy: 0.9833
#
# Epoch 00030: val_accuracy did not improve from 0.98519
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 6
# Genre split [['Metal'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Jazz', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 236/236 [==============================] - 6s 23ms/step - loss: 0.1763 - accuracy: 0.9364 - val_loss: 0.1020 - val_accuracy: 0.9629
#
# Epoch 00001: val_accuracy improved from -inf to 0.96289, saving model to ./models/tree_11/model_root_f1/folder6\model.h5
# Epoch 2/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.1006 - accuracy: 0.9638 - val_loss: 0.1241 - val_accuracy: 0.9666
#
# Epoch 00002: val_accuracy improved from 0.96289 to 0.96660, saving model to ./models/tree_11/model_root_f1/folder6\model.h5
# Epoch 3/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.0981 - accuracy: 0.9650 - val_loss: 0.1124 - val_accuracy: 0.9592
#
# Epoch 00003: val_accuracy did not improve from 0.96660
# Epoch 4/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0917 - accuracy: 0.9665 - val_loss: 0.0673 - val_accuracy: 0.9796
#
# Epoch 00004: val_accuracy improved from 0.96660 to 0.97959, saving model to ./models/tree_11/model_root_f1/folder6\model.h5
# Epoch 5/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0759 - accuracy: 0.9722 - val_loss: 0.0626 - val_accuracy: 0.9777
#
# Epoch 00005: val_accuracy did not improve from 0.97959
# Epoch 6/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.0736 - accuracy: 0.9727 - val_loss: 0.0624 - val_accuracy: 0.9777
#
# Epoch 00006: val_accuracy did not improve from 0.97959
# Epoch 7/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.0709 - accuracy: 0.9744 - val_loss: 0.0770 - val_accuracy: 0.9759
#
# Epoch 00007: val_accuracy did not improve from 0.97959
# Epoch 8/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0649 - accuracy: 0.9760 - val_loss: 0.0609 - val_accuracy: 0.9796
#
# Epoch 00008: val_accuracy did not improve from 0.97959
# Epoch 9/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.0621 - accuracy: 0.9771 - val_loss: 0.0707 - val_accuracy: 0.9777
#
# Epoch 00009: val_accuracy did not improve from 0.97959
# Epoch 10/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.0552 - accuracy: 0.9779 - val_loss: 0.0539 - val_accuracy: 0.9852
#
# Epoch 00010: val_accuracy improved from 0.97959 to 0.98516, saving model to ./models/tree_11/model_root_f1/folder6\model.h5
# Epoch 11/30
# ...
# flatten_7 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.3958 - accuracy: 0.8862 - val_loss: 0.3688 - val_accuracy: 0.8720
#
# Epoch 00001: val_accuracy improved from -inf to 0.87199, saving model to ./models/tree_11/model_root_f1/folder8\model.h5
# Epoch 2/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.3336 - accuracy: 0.8899 - val_loss: 0.3424 - val_accuracy: 0.8720
#
# Epoch 00002: val_accuracy did not improve from 0.87199
# Epoch 3/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.2997 - accuracy: 0.8909 - val_loss: 0.2829 - val_accuracy: 0.8942
#
# Epoch 00003: val_accuracy improved from 0.87199 to 0.89425, saving model to ./models/tree_11/model_root_f1/folder8\model.h5
# Epoch 4/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.2417 - accuracy: 0.9093 - val_loss: 0.2492 - val_accuracy: 0.8942
#
# Epoch 00004: val_accuracy did not improve from 0.89425
# Epoch 5/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.2071 - accuracy: 0.9249 - val_loss: 0.2104 - val_accuracy: 0.9239
#
# Epoch 00005: val_accuracy improved from 0.89425 to 0.92393, saving model to ./models/tree_11/model_root_f1/folder8\model.h5
# Epoch 6/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.1754 - accuracy: 0.9356 - val_loss: 0.1711 - val_accuracy: 0.9388
#
# Epoch 00006: val_accuracy improved from 0.92393 to 0.93878, saving model to ./models/tree_11/model_root_f1/folder8\model.h5
# Epoch 7/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.1392 - accuracy: 0.9490 - val_loss: 0.1606 - val_accuracy: 0.9369
#
# Epoch 00007: val_accuracy did not improve from 0.93878
# Epoch 8/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.1024 - accuracy: 0.9634 - val_loss: 0.1714 - val_accuracy: 0.9406
#
# Epoch 00008: val_accuracy improved from 0.93878 to 0.94063, saving model to ./models/tree_11/model_root_f1/folder8\model.h5
# Epoch 9/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0886 - accuracy: 0.9681 - val_loss: 0.1879 - val_accuracy: 0.9425
#
# Epoch 00009: val_accuracy improved from 0.94063 to 0.94249, saving model to ./models/tree_11/model_root_f1/folder8\model.h5
# Epoch 10/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0543 - accuracy: 0.9803 - val_loss: 0.1278 - val_accuracy: 0.9555
#
# Epoch 00010: val_accuracy improved from 0.94249 to 0.95547, saving model to ./models/tree_11/model_root_f1/folder8\model.h5
# Epoch 11/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0414 - accuracy: 0.9850 - val_loss: 0.1653 - val_accuracy: 0.9592
#
# Epoch 00011: val_accuracy improved from 0.95547 to 0.95918, saving model to ./models/tree_11/model_root_f1/folder8\model.h5
# Epoch 12/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0375 - accuracy: 0.9882 - val_loss: 0.1676 - val_accuracy: 0.9555
#
# Epoch 00012: val_accuracy did not improve from 0.95918
# Epoch 13/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.0326 - accuracy: 0.9869 - val_loss: 0.1684 - val_accuracy: 0.9647
#
# Epoch 00013: val_accuracy improved from 0.95918 to 0.96475, saving model to ./models/tree_11/model_root_f1/folder8\model.h5
# Epoch 14/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0100 - accuracy: 0.9972 - val_loss: 0.2094 - val_accuracy: 0.9536
#
# Epoch 00014: val_accuracy did not improve from 0.96475
# Epoch 15/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0098 - accuracy: 0.9975 - val_loss: 0.3141 - val_accuracy: 0.9388
#
# Epoch 00015: val_accuracy did not improve from 0.96475
# Epoch 16/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0231 - accuracy: 0.9925 - val_loss: 0.2227 - val_accuracy: 0.9536
#
# Epoch 00016: val_accuracy did not improve from 0.96475
# Epoch 17/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 0.2045 - val_accuracy: 0.9536
#
# Epoch 00017: val_accuracy did not improve from 0.96475
# Epoch 18/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0097 - accuracy: 0.9964 - val_loss: 0.2391 - val_accuracy: 0.9573
#
# Epoch 00018: val_accuracy did not improve from 0.96475
# Epoch 19/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0472 - accuracy: 0.9833 - val_loss: 0.1474 - val_accuracy: 0.9536
#
# Epoch 00019: val_accuracy did not improve from 0.96475
# Epoch 20/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0117 - accuracy: 0.9967 - val_loss: 0.4730 - val_accuracy: 0.9518
#
# Epoch 00020: val_accuracy did not improve from 0.96475
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.1919 - val_accuracy: 0.9703
#
# Epoch 00021: val_accuracy improved from 0.96475 to 0.97032, saving model to ./models/tree_11/model_root_f1/folder8\model.h5
# Epoch 22/30
# 236/236 [==============================] - 4s 19ms/step - loss: 3.9128e-04 - accuracy: 1.0000 - val_loss: 0.1973 - val_accuracy: 0.9666
#
# Epoch 00022: val_accuracy did not improve from 0.97032
# Epoch 23/30
# 236/236 [==============================] - 4s 19ms/step - loss: 1.6908e-04 - accuracy: 1.0000 - val_loss: 0.2068 - val_accuracy: 0.9666
#
# Epoch 00023: val_accuracy did not improve from 0.97032
# Epoch 24/30
# 236/236 [==============================] - 4s 19ms/step - loss: 1.2738e-04 - accuracy: 1.0000 - val_loss: 0.2144 - val_accuracy: 0.9685
#
# Epoch 00024: val_accuracy did not improve from 0.97032
# Epoch 25/30
# 236/236 [==============================] - 4s 19ms/step - loss: 9.8686e-05 - accuracy: 1.0000 - val_loss: 0.2208 - val_accuracy: 0.9685
#
# Epoch 00025: val_accuracy did not improve from 0.97032
# Epoch 26/30
# 236/236 [==============================] - 4s 19ms/step - loss: 7.7585e-05 - accuracy: 1.0000 - val_loss: 0.2271 - val_accuracy: 0.9685
#
# Epoch 00026: val_accuracy did not improve from 0.97032
# Epoch 27/30
# 236/236 [==============================] - 4s 19ms/step - loss: 6.1846e-05 - accuracy: 1.0000 - val_loss: 0.2316 - val_accuracy: 0.9685
#
# Epoch 00027: val_accuracy did not improve from 0.97032
# Epoch 28/30
# 236/236 [==============================] - 5s 20ms/step - loss: 4.9408e-05 - accuracy: 1.0000 - val_loss: 0.2431 - val_accuracy: 0.9685
#
# Epoch 00028: val_accuracy did not improve from 0.97032
# Epoch 29/30
# 236/236 [==============================] - 5s 21ms/step - loss: 4.0306e-05 - accuracy: 1.0000 - val_loss: 0.2288 - val_accuracy: 0.9685
#
# Epoch 00029: val_accuracy did not improve from 0.97032
# Epoch 30/30
# 236/236 [==============================] - 5s 20ms/step - loss: 3.3448e-05 - accuracy: 1.0000 - val_loss: 0.2434 - val_accuracy: 0.9685
#
# Epoch 00030: val_accuracy did not improve from 0.97032
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 9
# Genre split [['Rock'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Reggae']]
# Building model...
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 236/236 [==============================] - 5s 21ms/step - loss: 0.3503 - accuracy: 0.8858 - val_loss: 0.3378 - val_accuracy: 0.8776
#
# Epoch 00001: val_accuracy improved from -inf to 0.87755, saving model to ./models/tree_11/model_root_f1/folder9\model.h5
# Epoch 2/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.3297 - accuracy: 0.8896 - val_loss: 0.3334 - val_accuracy: 0.8776
#
# Epoch 00002: val_accuracy did not improve from 0.87755
# Epoch 3/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.3103 - accuracy: 0.8896 - val_loss: 0.2949 - val_accuracy: 0.8757
#
# Epoch 00003: val_accuracy did not improve from 0.87755
# Epoch 4/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.2855 - accuracy: 0.8899 - val_loss: 0.2754 - val_accuracy: 0.8776
#
# Epoch 00004: val_accuracy did not improve from 0.87755
# Epoch 5/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.2674 - accuracy: 0.8921 - val_loss: 0.2731 - val_accuracy: 0.8831
#
# Epoch 00005: val_accuracy improved from 0.87755 to 0.88312, saving model to ./models/tree_11/model_root_f1/folder9\model.h5
# Epoch 6/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.2443 - accuracy: 0.8976 - val_loss: 0.2589 - val_accuracy: 0.8868
#
# Epoch 00006: val_accuracy improved from 0.88312 to 0.88683, saving model to ./models/tree_11/model_root_f1/folder9\model.h5
# Epoch 7/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.2235 - accuracy: 0.9080 - val_loss: 0.2720 - val_accuracy: 0.8868
#
# Epoch 00007: val_accuracy did not improve from 0.88683
# Epoch 8/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.1980 - accuracy: 0.9162 - val_loss: 0.2678 - val_accuracy: 0.8961
#
# Epoch 00008: val_accuracy improved from 0.88683 to 0.89610, saving model to ./models/tree_11/model_root_f1/folder9\model.h5
# Epoch 9/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.1738 - accuracy: 0.9284 - val_loss: 0.2712 - val_accuracy: 0.8924
#
# Epoch 00009: val_accuracy did not improve from 0.89610
# Epoch 10/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.1452 - accuracy: 0.9419 - val_loss: 0.2411 - val_accuracy: 0.9184
#
# Epoch 00010: val_accuracy improved from 0.89610 to 0.91837, saving model to ./models/tree_11/model_root_f1/folder9\model.h5
# Epoch 11/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.1025 - accuracy: 0.9604 - val_loss: 0.2535 - val_accuracy: 0.9109
#
# Epoch 00011: val_accuracy did not improve from 0.91837
# Epoch 12/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0959 - accuracy: 0.9617 - val_loss: 0.3197 - val_accuracy: 0.9035
#
# Epoch 00012: val_accuracy did not improve from 0.91837
# Epoch 13/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0664 - accuracy: 0.9774 - val_loss: 0.2717 - val_accuracy: 0.9184
#
# Epoch 00013: val_accuracy did not improve from 0.91837
# Epoch 14/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0404 - accuracy: 0.9864 - val_loss: 0.3117 - val_accuracy: 0.9184
#
# Epoch 00014: val_accuracy did not improve from 0.91837
# Epoch 15/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0462 - accuracy: 0.9845 - val_loss: 0.3759 - val_accuracy: 0.9165
#
# Epoch 00015: val_accuracy did not improve from 0.91837
# Epoch 16/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0452 - accuracy: 0.9829 - val_loss: 0.2624 - val_accuracy: 0.9202
#
# Epoch 00016: val_accuracy improved from 0.91837 to 0.92022, saving model to ./models/tree_11/model_root_f1/folder9\model.h5
# Epoch 17/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0237 - accuracy: 0.9930 - val_loss: 0.3303 - val_accuracy: 0.9128
#
# Epoch 00017: val_accuracy did not improve from 0.92022
# Epoch 18/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0263 - accuracy: 0.9914 - val_loss: 0.3651 - val_accuracy: 0.9147
#
# Epoch 00018: val_accuracy did not improve from 0.92022
# Epoch 19/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0255 - accuracy: 0.9925 - val_loss: 0.3422 - val_accuracy: 0.9202
#
# Epoch 00019: val_accuracy did not improve from 0.92022
# Epoch 20/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0196 - accuracy: 0.9951 - val_loss: 0.5866 - val_accuracy: 0.8961
#
# Epoch 00020: val_accuracy did not improve from 0.92022
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0079 - accuracy: 0.9980 - val_loss: 0.3635 - val_accuracy: 0.9165
#
# Epoch 00021: val_accuracy did not improve from 0.92022
# Epoch 22/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0067 - accuracy: 0.9987 - val_loss: 0.3800 - val_accuracy: 0.9258
#
# Epoch 00022: val_accuracy improved from 0.92022 to 0.92579, saving model to ./models/tree_11/model_root_f1/folder9\model.h5
# Epoch 23/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0055 - accuracy: 0.9987 - val_loss: 0.3400 - val_accuracy: 0.9202
#
# Epoch 00023: val_accuracy did not improve from 0.92579
# Epoch 24/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0066 - accuracy: 0.9987 - val_loss: 0.3383 - val_accuracy: 0.9202
#
# Epoch 00024: val_accuracy did not improve from 0.92579
# Epoch 25/30
# 236/236 [==============================] - 4s 19ms/step - loss: 0.0064 - accuracy: 0.9984 - val_loss: 0.3527 - val_accuracy: 0.9276
#
# Epoch 00025: val_accuracy improved from 0.92579 to 0.92764, saving model to ./models/tree_11/model_root_f1/folder9\model.h5
# Epoch 26/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0067 - accuracy: 0.9984 - val_loss: 0.3728 - val_accuracy: 0.9221
#
# Epoch 00026: val_accuracy did not improve from 0.92764
# Epoch 27/30
# 236/236 [==============================] - 5s 20ms/step - loss: 0.0067 - accuracy: 0.9987 - val_loss: 0.4216 - val_accuracy: 0.9184
#
# Epoch 00027: val_accuracy did not improve from 0.92764
# Epoch 28/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0053 - accuracy: 0.9988 - val_loss: 0.3420 - val_accuracy: 0.9221
#
# Epoch 00028: val_accuracy did not improve from 0.92764
# Epoch 29/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.4753 - val_accuracy: 0.9202
#
# Epoch 00029: val_accuracy did not improve from 0.92764
# Epoch 30/30
# 236/236 [==============================] - 5s 19ms/step - loss: 0.0093 - accuracy: 0.9980 - val_loss: 0.4687 - val_accuracy: 0.8998
#
# Epoch 00030: val_accuracy did not improve from 0.92764
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
