# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Country':2, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {2: 'Country', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((1600, 128, 128), (1600, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((200, 128, 128), (200, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Country

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation='softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_11/model_root_f1_1_1_1_1_1_1_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_11/model_root_f1_1_1_1_1_1_1_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 1
n_splits = 15

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    dict_genres_list = list(dict_genres.values())
    split = [[dict_genres_list.pop(fold_no - 1)], dict_genres_list]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Country'], ['Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 53/53 [==============================] - 5s 33ms/step - loss: 0.7834 - accuracy: 0.5286 - val_loss: 0.6640 - val_accuracy: 0.5917
#
# Epoch 00001: val_accuracy improved from -inf to 0.59167, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1_1/folder1\model.h5
# Epoch 2/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.6108 - accuracy: 0.6595 - val_loss: 0.6081 - val_accuracy: 0.6833
#
# Epoch 00002: val_accuracy improved from 0.59167 to 0.68333, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1_1/folder1\model.h5
# Epoch 3/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.5688 - accuracy: 0.6881 - val_loss: 0.6038 - val_accuracy: 0.6917
#
# Epoch 00003: val_accuracy improved from 0.68333 to 0.69167, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1_1/folder1\model.h5
# Epoch 4/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.4585 - accuracy: 0.7804 - val_loss: 0.4952 - val_accuracy: 0.7750
#
# Epoch 00004: val_accuracy improved from 0.69167 to 0.77500, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1_1/folder1\model.h5
# Epoch 5/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.3953 - accuracy: 0.8339 - val_loss: 0.5044 - val_accuracy: 0.7917
#
# Epoch 00005: val_accuracy improved from 0.77500 to 0.79167, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1_1/folder1\model.h5
# Epoch 6/30
# 53/53 [==============================] - 1s 20ms/step - loss: 0.3420 - accuracy: 0.8542 - val_loss: 0.4204 - val_accuracy: 0.8000
#
# Epoch 00006: val_accuracy improved from 0.79167 to 0.80000, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1_1/folder1\model.h5
# Epoch 7/30
# 53/53 [==============================] - 1s 20ms/step - loss: 0.3307 - accuracy: 0.8536 - val_loss: 0.4887 - val_accuracy: 0.7750
#
# Epoch 00007: val_accuracy did not improve from 0.80000
# Epoch 8/30
# 53/53 [==============================] - 1s 21ms/step - loss: 0.2836 - accuracy: 0.8804 - val_loss: 0.4830 - val_accuracy: 0.8250
#
# Epoch 00008: val_accuracy improved from 0.80000 to 0.82500, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1_1/folder1\model.h5
# Epoch 9/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.2496 - accuracy: 0.8911 - val_loss: 0.4076 - val_accuracy: 0.8417
#
# Epoch 00009: val_accuracy improved from 0.82500 to 0.84167, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1_1/folder1\model.h5
# Epoch 10/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.2232 - accuracy: 0.9095 - val_loss: 0.3682 - val_accuracy: 0.8583
#
# Epoch 00010: val_accuracy improved from 0.84167 to 0.85833, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1_1/folder1\model.h5
# Epoch 11/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.1639 - accuracy: 0.9387 - val_loss: 0.3436 - val_accuracy: 0.8667
#
# Epoch 00011: val_accuracy improved from 0.85833 to 0.86667, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1_1/folder1\model.h5
# Epoch 12/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.1897 - accuracy: 0.9208 - val_loss: 0.4570 - val_accuracy: 0.8583
#
# Epoch 00012: val_accuracy did not improve from 0.86667
# Epoch 13/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.1586 - accuracy: 0.9423 - val_loss: 0.4250 - val_accuracy: 0.8750
#
# Epoch 00013: val_accuracy improved from 0.86667 to 0.87500, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1_1/folder1\model.h5
# Epoch 14/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.1285 - accuracy: 0.9518 - val_loss: 0.4918 - val_accuracy: 0.8167
#
# Epoch 00014: val_accuracy did not improve from 0.87500
# Epoch 15/30
# 53/53 [==============================] - 1s 20ms/step - loss: 0.1259 - accuracy: 0.9554 - val_loss: 0.5300 - val_accuracy: 0.8167
#
# Epoch 00015: val_accuracy did not improve from 0.87500
# Epoch 16/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.1041 - accuracy: 0.9589 - val_loss: 0.3863 - val_accuracy: 0.8500
#
# Epoch 00016: val_accuracy did not improve from 0.87500
# Epoch 17/30
# 53/53 [==============================] - 1s 20ms/step - loss: 0.1206 - accuracy: 0.9512 - val_loss: 0.4257 - val_accuracy: 0.8583
#
# Epoch 00017: val_accuracy did not improve from 0.87500
# Epoch 18/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0723 - accuracy: 0.9768 - val_loss: 0.3986 - val_accuracy: 0.8500
#
# Epoch 00018: val_accuracy did not improve from 0.87500
# Epoch 19/30
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0435 - accuracy: 0.9863 - val_loss: 0.7096 - val_accuracy: 0.8333
#
# Epoch 00019: val_accuracy did not improve from 0.87500
# Epoch 20/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0590 - accuracy: 0.9810 - val_loss: 0.7624 - val_accuracy: 0.8500
#
# Epoch 00020: val_accuracy did not improve from 0.87500
# Epoch 21/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0284 - accuracy: 0.9929 - val_loss: 0.4982 - val_accuracy: 0.8833
#
# Epoch 00021: val_accuracy improved from 0.87500 to 0.88333, saving model to ./models/tree_11/model_root_f1_1_1_1_1_1_1_1/folder1\model.h5
# Epoch 22/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0132 - accuracy: 0.9988 - val_loss: 0.6650 - val_accuracy: 0.8667
#
# Epoch 00022: val_accuracy did not improve from 0.88333
# Epoch 23/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0065 - accuracy: 0.9988 - val_loss: 0.6756 - val_accuracy: 0.8667
#
# Epoch 00023: val_accuracy did not improve from 0.88333
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 24/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.6333 - val_accuracy: 0.8750
#
# Epoch 00024: val_accuracy did not improve from 0.88333
# Epoch 25/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.6528 - val_accuracy: 0.8750
#
# Epoch 00025: val_accuracy did not improve from 0.88333
# Epoch 26/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.6666 - val_accuracy: 0.8750
#
# Epoch 00026: val_accuracy did not improve from 0.88333
# Epoch 27/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.6411 - val_accuracy: 0.8750
#
# Epoch 00027: val_accuracy did not improve from 0.88333
# Epoch 28/30
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.6468 - val_accuracy: 0.8667
#
# Epoch 00028: val_accuracy did not improve from 0.88333
# Epoch 29/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.7120 - val_accuracy: 0.8667
#
# Epoch 00029: val_accuracy did not improve from 0.88333
# Epoch 30/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.6907 - val_accuracy: 0.8750
#
# Epoch 00030: val_accuracy did not improve from 0.88333
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
