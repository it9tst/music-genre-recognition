# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Country':2, 'Disco':3, 'Hip-Hop':4, 'Reggae':8, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {2: 'Country', 3: 'Disco', 4: 'Hip-Hop', 8: 'Reggae', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((4000, 128, 128), (4000, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((500, 128, 128), (500, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Disco

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation='softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_11/model_root_f1_1_1_1_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_11/model_root_f1_1_1_1_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 5
n_splits = 15

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    dict_genres_list = list(dict_genres.values())
    split = [[dict_genres_list.pop(fold_no - 1)], dict_genres_list]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Country'], ['Disco', 'Hip-Hop', 'Reggae', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 132/132 [==============================] - 7s 25ms/step - loss: 0.5418 - accuracy: 0.7952 - val_loss: 0.4510 - val_accuracy: 0.8067
#
# Epoch 00001: val_accuracy improved from -inf to 0.80667, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 2/30
# 132/132 [==============================] - 3s 22ms/step - loss: 0.3406 - accuracy: 0.8269 - val_loss: 0.3448 - val_accuracy: 0.8500
#
# Epoch 00002: val_accuracy improved from 0.80667 to 0.85000, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 3/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.3188 - accuracy: 0.8431 - val_loss: 0.3262 - val_accuracy: 0.8300
#
# Epoch 00003: val_accuracy did not improve from 0.85000
# Epoch 4/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.2616 - accuracy: 0.8738 - val_loss: 0.2996 - val_accuracy: 0.8300
#
# Epoch 00004: val_accuracy did not improve from 0.85000
# Epoch 5/30
# 132/132 [==============================] - 2s 19ms/step - loss: 0.2247 - accuracy: 0.8964 - val_loss: 0.3185 - val_accuracy: 0.8533
#
# Epoch 00005: val_accuracy improved from 0.85000 to 0.85333, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 6/30
# 132/132 [==============================] - 2s 19ms/step - loss: 0.1996 - accuracy: 0.9083 - val_loss: 0.2637 - val_accuracy: 0.8733
#
# Epoch 00006: val_accuracy improved from 0.85333 to 0.87333, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 7/30
# 132/132 [==============================] - 2s 19ms/step - loss: 0.1555 - accuracy: 0.9357 - val_loss: 0.2549 - val_accuracy: 0.8933
#
# Epoch 00007: val_accuracy improved from 0.87333 to 0.89333, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 8/30
# 132/132 [==============================] - 2s 19ms/step - loss: 0.1509 - accuracy: 0.9383 - val_loss: 0.2867 - val_accuracy: 0.8600
#
# Epoch 00008: val_accuracy did not improve from 0.89333
# Epoch 9/30
# 132/132 [==============================] - 2s 19ms/step - loss: 0.1120 - accuracy: 0.9543 - val_loss: 0.2279 - val_accuracy: 0.8933
#
# Epoch 00009: val_accuracy did not improve from 0.89333
# Epoch 10/30
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0901 - accuracy: 0.9671 - val_loss: 0.2448 - val_accuracy: 0.9100
#
# Epoch 00010: val_accuracy improved from 0.89333 to 0.91000, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 11/30
# 132/132 [==============================] - 2s 19ms/step - loss: 0.0709 - accuracy: 0.9717 - val_loss: 0.2204 - val_accuracy: 0.9233
#
# Epoch 00011: val_accuracy improved from 0.91000 to 0.92333, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 12/30
# 132/132 [==============================] - 2s 19ms/step - loss: 0.0442 - accuracy: 0.9845 - val_loss: 0.2005 - val_accuracy: 0.9400
#
# Epoch 00012: val_accuracy improved from 0.92333 to 0.94000, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder1\model.h5
# Epoch 13/30
# 132/132 [==============================] - 2s 19ms/step - loss: 0.0335 - accuracy: 0.9881 - val_loss: 0.2852 - val_accuracy: 0.9167
#
# Epoch 00013: val_accuracy did not improve from 0.94000
# Epoch 14/30
# 132/132 [==============================] - 2s 19ms/step - loss: 0.0311 - accuracy: 0.9874 - val_loss: 0.3002 - val_accuracy: 0.8933
#
# Epoch 00014: val_accuracy did not improve from 0.94000
# Epoch 15/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0289 - accuracy: 0.9917 - val_loss: 0.3798 - val_accuracy: 0.9033
#
# Epoch 00015: val_accuracy did not improve from 0.94000
# Epoch 16/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.0978 - accuracy: 0.9648 - val_loss: 0.2776 - val_accuracy: 0.9100
#
# Epoch 00016: val_accuracy did not improve from 0.94000
# Epoch 17/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.0222 - accuracy: 0.9926 - val_loss: 0.2892 - val_accuracy: 0.9200
#
# Epoch 00017: val_accuracy did not improve from 0.94000
# Epoch 18/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.0171 - accuracy: 0.9945 - val_loss: 0.3408 - val_accuracy: 0.9033
#
# Epoch 00018: val_accuracy did not improve from 0.94000
# Epoch 19/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.0044 - accuracy: 0.9993 - val_loss: 0.3158 - val_accuracy: 0.9267
#
# Epoch 00019: val_accuracy did not improve from 0.94000
# Epoch 20/30
# 132/132 [==============================] - 3s 19ms/step - loss: 5.3541e-04 - accuracy: 1.0000 - val_loss: 0.3853 - val_accuracy: 0.9267
#
# Epoch 00020: val_accuracy did not improve from 0.94000
# Epoch 21/30
# 132/132 [==============================] - 3s 20ms/step - loss: 3.2035e-04 - accuracy: 1.0000 - val_loss: 0.3756 - val_accuracy: 0.9300
#
# Epoch 00021: val_accuracy did not improve from 0.94000
# Epoch 22/30
# 132/132 [==============================] - 3s 22ms/step - loss: 2.2672e-04 - accuracy: 1.0000 - val_loss: 0.3928 - val_accuracy: 0.9267
#
# Epoch 00022: val_accuracy did not improve from 0.94000
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 23/30
# 132/132 [==============================] - 3s 21ms/step - loss: 1.7611e-04 - accuracy: 1.0000 - val_loss: 0.3953 - val_accuracy: 0.9267
#
# Epoch 00023: val_accuracy did not improve from 0.94000
# Epoch 24/30
# 132/132 [==============================] - 3s 19ms/step - loss: 1.5699e-04 - accuracy: 1.0000 - val_loss: 0.3948 - val_accuracy: 0.9267
#
# Epoch 00024: val_accuracy did not improve from 0.94000
# Epoch 25/30
# 132/132 [==============================] - 3s 20ms/step - loss: 1.3970e-04 - accuracy: 1.0000 - val_loss: 0.3964 - val_accuracy: 0.9267
#
# Epoch 00025: val_accuracy did not improve from 0.94000
# Epoch 26/30
# 132/132 [==============================] - 3s 20ms/step - loss: 1.2517e-04 - accuracy: 1.0000 - val_loss: 0.4041 - val_accuracy: 0.9267
#
# Epoch 00026: val_accuracy did not improve from 0.94000
# Epoch 27/30
# 132/132 [==============================] - 3s 19ms/step - loss: 1.1021e-04 - accuracy: 1.0000 - val_loss: 0.3966 - val_accuracy: 0.9233
#
# Epoch 00027: val_accuracy did not improve from 0.94000
# Epoch 28/30
# 132/132 [==============================] - 3s 19ms/step - loss: 9.3884e-05 - accuracy: 1.0000 - val_loss: 0.4003 - val_accuracy: 0.9267
#
# Epoch 00028: val_accuracy did not improve from 0.94000
# Epoch 29/30
# 132/132 [==============================] - 3s 20ms/step - loss: 8.2352e-05 - accuracy: 1.0000 - val_loss: 0.4228 - val_accuracy: 0.9233
#
# Epoch 00029: val_accuracy did not improve from 0.94000
# Epoch 30/30
# 132/132 [==============================] - 3s 19ms/step - loss: 6.7864e-05 - accuracy: 1.0000 - val_loss: 0.4180 - val_accuracy: 0.9267
#
# Epoch 00030: val_accuracy did not improve from 0.94000
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Disco'], ['Country', 'Hip-Hop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 132/132 [==============================] - 3s 21ms/step - loss: 0.5579 - accuracy: 0.7855 - val_loss: 0.5271 - val_accuracy: 0.7700
#
# Epoch 00001: val_accuracy improved from -inf to 0.77000, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 2/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.4777 - accuracy: 0.8024 - val_loss: 0.4834 - val_accuracy: 0.7700
#
# Epoch 00002: val_accuracy did not improve from 0.77000
# Epoch 3/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.4326 - accuracy: 0.8026 - val_loss: 0.4495 - val_accuracy: 0.7733
#
# Epoch 00003: val_accuracy improved from 0.77000 to 0.77333, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 4/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.4056 - accuracy: 0.8143 - val_loss: 0.3920 - val_accuracy: 0.7967
#
# Epoch 00004: val_accuracy improved from 0.77333 to 0.79667, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 5/30
# 132/132 [==============================] - 3s 21ms/step - loss: 0.3200 - accuracy: 0.8719 - val_loss: 0.3063 - val_accuracy: 0.8767
#
# Epoch 00005: val_accuracy improved from 0.79667 to 0.87667, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 6/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.2658 - accuracy: 0.8988 - val_loss: 0.3018 - val_accuracy: 0.8700
#
# Epoch 00006: val_accuracy did not improve from 0.87667
# Epoch 7/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.2261 - accuracy: 0.9152 - val_loss: 0.2714 - val_accuracy: 0.9133
#
# Epoch 00007: val_accuracy improved from 0.87667 to 0.91333, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 8/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.1802 - accuracy: 0.9312 - val_loss: 0.1967 - val_accuracy: 0.9333
#
# Epoch 00008: val_accuracy improved from 0.91333 to 0.93333, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 9/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.1515 - accuracy: 0.9414 - val_loss: 0.1691 - val_accuracy: 0.9367
#
# Epoch 00009: val_accuracy improved from 0.93333 to 0.93667, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 10/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.1258 - accuracy: 0.9552 - val_loss: 0.1812 - val_accuracy: 0.9400
#
# Epoch 00010: val_accuracy improved from 0.93667 to 0.94000, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 11/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.1069 - accuracy: 0.9595 - val_loss: 0.1597 - val_accuracy: 0.9500
#
# Epoch 00011: val_accuracy improved from 0.94000 to 0.95000, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 12/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.0855 - accuracy: 0.9688 - val_loss: 0.1802 - val_accuracy: 0.9400
#
# Epoch 00012: val_accuracy did not improve from 0.95000
# Epoch 13/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0617 - accuracy: 0.9786 - val_loss: 0.2170 - val_accuracy: 0.9200
#
# Epoch 00013: val_accuracy did not improve from 0.95000
# Epoch 14/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.0462 - accuracy: 0.9855 - val_loss: 0.1138 - val_accuracy: 0.9567
#
# Epoch 00014: val_accuracy improved from 0.95000 to 0.95667, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 15/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.0256 - accuracy: 0.9924 - val_loss: 0.1252 - val_accuracy: 0.9667
#
# Epoch 00015: val_accuracy improved from 0.95667 to 0.96667, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder2\model.h5
# Epoch 16/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0384 - accuracy: 0.9862 - val_loss: 0.1695 - val_accuracy: 0.9467
#
# Epoch 00016: val_accuracy did not improve from 0.96667
# Epoch 17/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0153 - accuracy: 0.9952 - val_loss: 0.2380 - val_accuracy: 0.9400
#
# Epoch 00017: val_accuracy did not improve from 0.96667
# Epoch 18/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0575 - accuracy: 0.9781 - val_loss: 0.2221 - val_accuracy: 0.9367
#
# Epoch 00018: val_accuracy did not improve from 0.96667
# Epoch 19/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0175 - accuracy: 0.9943 - val_loss: 0.1521 - val_accuracy: 0.9600
#
# Epoch 00019: val_accuracy did not improve from 0.96667
# Epoch 20/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.1624 - val_accuracy: 0.9567
#
# Epoch 00020: val_accuracy did not improve from 0.96667
# Epoch 21/30
# 132/132 [==============================] - 3s 19ms/step - loss: 8.6183e-04 - accuracy: 1.0000 - val_loss: 0.1860 - val_accuracy: 0.9467
#
# Epoch 00021: val_accuracy did not improve from 0.96667
# Epoch 22/30
# 132/132 [==============================] - 3s 19ms/step - loss: 4.6416e-04 - accuracy: 1.0000 - val_loss: 0.1699 - val_accuracy: 0.9500
#
# Epoch 00022: val_accuracy did not improve from 0.96667
# Epoch 23/30
# 132/132 [==============================] - 3s 19ms/step - loss: 3.1592e-04 - accuracy: 1.0000 - val_loss: 0.1784 - val_accuracy: 0.9533
#
# Epoch 00023: val_accuracy did not improve from 0.96667
# Epoch 24/30
# 132/132 [==============================] - 3s 19ms/step - loss: 2.5053e-04 - accuracy: 1.0000 - val_loss: 0.1864 - val_accuracy: 0.9533
#
# Epoch 00024: val_accuracy did not improve from 0.96667
# Epoch 25/30
# 132/132 [==============================] - 3s 20ms/step - loss: 2.0416e-04 - accuracy: 1.0000 - val_loss: 0.1722 - val_accuracy: 0.9500
#
# Epoch 00025: val_accuracy did not improve from 0.96667
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 26/30
# 132/132 [==============================] - 3s 20ms/step - loss: 1.7271e-04 - accuracy: 1.0000 - val_loss: 0.1776 - val_accuracy: 0.9533
#
# Epoch 00026: val_accuracy did not improve from 0.96667
# Epoch 27/30
# 132/132 [==============================] - 3s 19ms/step - loss: 1.5898e-04 - accuracy: 1.0000 - val_loss: 0.1800 - val_accuracy: 0.9533
#
# Epoch 00027: val_accuracy did not improve from 0.96667
# Epoch 28/30
# 132/132 [==============================] - 3s 19ms/step - loss: 1.4444e-04 - accuracy: 1.0000 - val_loss: 0.1753 - val_accuracy: 0.9533
#
# Epoch 00028: val_accuracy did not improve from 0.96667
# Epoch 29/30
# 132/132 [==============================] - 3s 19ms/step - loss: 1.3380e-04 - accuracy: 1.0000 - val_loss: 0.1859 - val_accuracy: 0.9533
#
# Epoch 00029: val_accuracy did not improve from 0.96667
# Epoch 30/30
# 132/132 [==============================] - 3s 19ms/step - loss: 1.2349e-04 - accuracy: 1.0000 - val_loss: 0.1856 - val_accuracy: 0.9533
#
# Epoch 00030: val_accuracy did not improve from 0.96667
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Hip-Hop'], ['Country', 'Disco', 'Reggae', 'Rock']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 132/132 [==============================] - 3s 22ms/step - loss: 0.4530 - accuracy: 0.8074 - val_loss: 0.3410 - val_accuracy: 0.8300
#
# Epoch 00001: val_accuracy improved from -inf to 0.83000, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder3\model.h5
# Epoch 2/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.2942 - accuracy: 0.8793 - val_loss: 0.3607 - val_accuracy: 0.7967
#
# Epoch 00002: val_accuracy did not improve from 0.83000
# Epoch 3/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.2544 - accuracy: 0.8990 - val_loss: 0.3481 - val_accuracy: 0.8467
#
# Epoch 00003: val_accuracy improved from 0.83000 to 0.84667, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder3\model.h5
# Epoch 4/30
# 132/132 [==============================] - 3s 21ms/step - loss: 0.2405 - accuracy: 0.9086 - val_loss: 0.2345 - val_accuracy: 0.8900
#
# Epoch 00004: val_accuracy improved from 0.84667 to 0.89000, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder3\model.h5
# Epoch 5/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.1727 - accuracy: 0.9321 - val_loss: 0.1979 - val_accuracy: 0.9167
#
# Epoch 00005: val_accuracy improved from 0.89000 to 0.91667, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder3\model.h5
# Epoch 6/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.1354 - accuracy: 0.9488 - val_loss: 0.1761 - val_accuracy: 0.9400
#
# Epoch 00006: val_accuracy improved from 0.91667 to 0.94000, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder3\model.h5
# Epoch 7/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.0895 - accuracy: 0.9636 - val_loss: 0.3120 - val_accuracy: 0.8867
#
# Epoch 00007: val_accuracy did not improve from 0.94000
# Epoch 8/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.0551 - accuracy: 0.9812 - val_loss: 0.1866 - val_accuracy: 0.9267
#
# Epoch 00008: val_accuracy did not improve from 0.94000
# Epoch 9/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0506 - accuracy: 0.9786 - val_loss: 0.1833 - val_accuracy: 0.9367
#
# Epoch 00009: val_accuracy did not improve from 0.94000
# Epoch 10/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.0329 - accuracy: 0.9888 - val_loss: 0.3262 - val_accuracy: 0.9200
#
# Epoch 00010: val_accuracy did not improve from 0.94000
# Epoch 11/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0286 - accuracy: 0.9886 - val_loss: 0.2640 - val_accuracy: 0.9333
#
# Epoch 00011: val_accuracy did not improve from 0.94000
# Epoch 12/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0283 - accuracy: 0.9886 - val_loss: 0.2158 - val_accuracy: 0.9367
#
# Epoch 00012: val_accuracy did not improve from 0.94000
# Epoch 13/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.0140 - accuracy: 0.9964 - val_loss: 0.2715 - val_accuracy: 0.9267
#
# Epoch 00013: val_accuracy did not improve from 0.94000
# Epoch 14/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0052 - accuracy: 0.9988 - val_loss: 0.3005 - val_accuracy: 0.9467
#
# Epoch 00014: val_accuracy improved from 0.94000 to 0.94667, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder3\model.h5
# Epoch 15/30
# 132/132 [==============================] - 3s 19ms/step - loss: 5.0467e-04 - accuracy: 1.0000 - val_loss: 0.3092 - val_accuracy: 0.9533
#
# Epoch 00015: val_accuracy improved from 0.94667 to 0.95333, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder3\model.h5
# Epoch 16/30
# 132/132 [==============================] - 3s 20ms/step - loss: 2.3076e-04 - accuracy: 1.0000 - val_loss: 0.3100 - val_accuracy: 0.9467
#
# Epoch 00016: val_accuracy did not improve from 0.95333
# Epoch 17/30
# 132/132 [==============================] - 3s 20ms/step - loss: 1.5776e-04 - accuracy: 1.0000 - val_loss: 0.3200 - val_accuracy: 0.9500
#
# Epoch 00017: val_accuracy did not improve from 0.95333
# Epoch 18/30
# 132/132 [==============================] - 3s 20ms/step - loss: 1.2524e-04 - accuracy: 1.0000 - val_loss: 0.3219 - val_accuracy: 0.9467
#
# Epoch 00018: val_accuracy did not improve from 0.95333
# Epoch 19/30
# 132/132 [==============================] - 3s 19ms/step - loss: 1.0170e-04 - accuracy: 1.0000 - val_loss: 0.3259 - val_accuracy: 0.9467
#
# Epoch 00019: val_accuracy did not improve from 0.95333
# Epoch 20/30
# 132/132 [==============================] - 3s 19ms/step - loss: 8.5550e-05 - accuracy: 1.0000 - val_loss: 0.3309 - val_accuracy: 0.9500
#
# Epoch 00020: val_accuracy did not improve from 0.95333
# Epoch 21/30
# 132/132 [==============================] - 3s 20ms/step - loss: 7.1395e-05 - accuracy: 1.0000 - val_loss: 0.3337 - val_accuracy: 0.9467
#
# Epoch 00021: val_accuracy did not improve from 0.95333
# Epoch 22/30
# 132/132 [==============================] - 3s 20ms/step - loss: 6.1305e-05 - accuracy: 1.0000 - val_loss: 0.3383 - val_accuracy: 0.9467
#
# Epoch 00022: val_accuracy did not improve from 0.95333
# Epoch 23/30
# 132/132 [==============================] - 3s 20ms/step - loss: 5.3564e-05 - accuracy: 1.0000 - val_loss: 0.3397 - val_accuracy: 0.9500
#
# Epoch 00023: val_accuracy did not improve from 0.95333
# Epoch 24/30
# 132/132 [==============================] - 3s 20ms/step - loss: 4.6862e-05 - accuracy: 1.0000 - val_loss: 0.3452 - val_accuracy: 0.9533
#
# Epoch 00024: val_accuracy did not improve from 0.95333
# Epoch 25/30
# 132/132 [==============================] - 3s 20ms/step - loss: 4.1020e-05 - accuracy: 1.0000 - val_loss: 0.3463 - val_accuracy: 0.9500
#
# Epoch 00025: val_accuracy did not improve from 0.95333
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 26/30
# 132/132 [==============================] - 3s 20ms/step - loss: 3.6923e-05 - accuracy: 1.0000 - val_loss: 0.3481 - val_accuracy: 0.9500
#
# Epoch 00026: val_accuracy did not improve from 0.95333
# Epoch 27/30
# 132/132 [==============================] - 3s 21ms/step - loss: 3.4545e-05 - accuracy: 1.0000 - val_loss: 0.3491 - val_accuracy: 0.9533
#
# Epoch 00027: val_accuracy did not improve from 0.95333
# Epoch 28/30
# 132/132 [==============================] - 3s 19ms/step - loss: 3.2412e-05 - accuracy: 1.0000 - val_loss: 0.3507 - val_accuracy: 0.9533
#
# Epoch 00028: val_accuracy did not improve from 0.95333
# Epoch 29/30
# 132/132 [==============================] - 3s 19ms/step - loss: 3.0480e-05 - accuracy: 1.0000 - val_loss: 0.3516 - val_accuracy: 0.9533
#
# Epoch 00029: val_accuracy did not improve from 0.95333
# Epoch 30/30
# 132/132 [==============================] - 3s 19ms/step - loss: 2.8507e-05 - accuracy: 1.0000 - val_loss: 0.3509 - val_accuracy: 0.9533
#
# Epoch 00030: val_accuracy did not improve from 0.95333
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Reggae'], ['Country', 'Disco', 'Hip-Hop', 'Rock']]
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 132/132 [==============================] - 3s 22ms/step - loss: 0.5688 - accuracy: 0.7938 - val_loss: 0.5014 - val_accuracy: 0.7933
#
# Epoch 00001: val_accuracy improved from -inf to 0.79333, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder4\model.h5
# Epoch 2/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.4777 - accuracy: 0.7990 - val_loss: 0.4784 - val_accuracy: 0.7933
#
# Epoch 00002: val_accuracy did not improve from 0.79333
# Epoch 3/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.4419 - accuracy: 0.8057 - val_loss: 0.5955 - val_accuracy: 0.8000
#
# Epoch 00003: val_accuracy improved from 0.79333 to 0.80000, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder4\model.h5
# Epoch 4/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.3959 - accuracy: 0.8324 - val_loss: 0.3197 - val_accuracy: 0.8633
#
# Epoch 00004: val_accuracy improved from 0.80000 to 0.86333, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder4\model.h5
# Epoch 5/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.3308 - accuracy: 0.8629 - val_loss: 0.2945 - val_accuracy: 0.8667
#
# Epoch 00005: val_accuracy improved from 0.86333 to 0.86667, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder4\model.h5
# Epoch 6/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.3049 - accuracy: 0.8757 - val_loss: 0.2637 - val_accuracy: 0.8867
#
# Epoch 00006: val_accuracy improved from 0.86667 to 0.88667, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder4\model.h5
# Epoch 7/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.2598 - accuracy: 0.8967 - val_loss: 0.2947 - val_accuracy: 0.8733
#
# Epoch 00007: val_accuracy did not improve from 0.88667
# Epoch 8/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.2168 - accuracy: 0.9155 - val_loss: 0.2058 - val_accuracy: 0.9300
#
# Epoch 00008: val_accuracy improved from 0.88667 to 0.93000, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder4\model.h5
# Epoch 9/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.1822 - accuracy: 0.9264 - val_loss: 0.1837 - val_accuracy: 0.9133
#
# Epoch 00009: val_accuracy did not improve from 0.93000
# Epoch 10/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.1506 - accuracy: 0.9431 - val_loss: 0.1754 - val_accuracy: 0.9333
#
# Epoch 00010: val_accuracy improved from 0.93000 to 0.93333, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder4\model.h5
# Epoch 11/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.1168 - accuracy: 0.9545 - val_loss: 0.1754 - val_accuracy: 0.9433
#
# Epoch 00011: val_accuracy improved from 0.93333 to 0.94333, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder4\model.h5
# Epoch 12/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0934 - accuracy: 0.9631 - val_loss: 0.1636 - val_accuracy: 0.9400
#
# Epoch 00012: val_accuracy did not improve from 0.94333
# Epoch 13/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0592 - accuracy: 0.9783 - val_loss: 0.2035 - val_accuracy: 0.9233
#
# Epoch 00013: val_accuracy did not improve from 0.94333
# Epoch 14/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0301 - accuracy: 0.9907 - val_loss: 0.2857 - val_accuracy: 0.9367
#
# Epoch 00014: val_accuracy did not improve from 0.94333
# Epoch 15/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0140 - accuracy: 0.9969 - val_loss: 0.2142 - val_accuracy: 0.9467
#
# Epoch 00015: val_accuracy improved from 0.94333 to 0.94667, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder4\model.h5
# Epoch 16/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.0143 - accuracy: 0.9962 - val_loss: 0.2412 - val_accuracy: 0.9333
#
# Epoch 00016: val_accuracy did not improve from 0.94667
# Epoch 17/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0433 - accuracy: 0.9850 - val_loss: 0.1579 - val_accuracy: 0.9567
#
# Epoch 00017: val_accuracy improved from 0.94667 to 0.95667, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder4\model.h5
# Epoch 18/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.0085 - accuracy: 0.9979 - val_loss: 0.2415 - val_accuracy: 0.9267
#
# Epoch 00018: val_accuracy did not improve from 0.95667
# Epoch 19/30
# 132/132 [==============================] - 3s 20ms/step - loss: 8.9736e-04 - accuracy: 1.0000 - val_loss: 0.2295 - val_accuracy: 0.9400
#
# Epoch 00019: val_accuracy did not improve from 0.95667
# Epoch 20/30
# 132/132 [==============================] - 3s 20ms/step - loss: 3.6775e-04 - accuracy: 1.0000 - val_loss: 0.2489 - val_accuracy: 0.9400
#
# Epoch 00020: val_accuracy did not improve from 0.95667
# Epoch 21/30
# 132/132 [==============================] - 3s 20ms/step - loss: 2.4105e-04 - accuracy: 1.0000 - val_loss: 0.2582 - val_accuracy: 0.9400
#
# Epoch 00021: val_accuracy did not improve from 0.95667
# Epoch 22/30
# 132/132 [==============================] - 3s 21ms/step - loss: 1.8841e-04 - accuracy: 1.0000 - val_loss: 0.2643 - val_accuracy: 0.9400
#
# Epoch 00022: val_accuracy did not improve from 0.95667
# Epoch 23/30
# 132/132 [==============================] - 3s 20ms/step - loss: 1.5428e-04 - accuracy: 1.0000 - val_loss: 0.2694 - val_accuracy: 0.9400
#
# Epoch 00023: val_accuracy did not improve from 0.95667
# Epoch 24/30
# 132/132 [==============================] - 3s 20ms/step - loss: 1.2727e-04 - accuracy: 1.0000 - val_loss: 0.2714 - val_accuracy: 0.9400
#
# Epoch 00024: val_accuracy did not improve from 0.95667
# Epoch 25/30
# 132/132 [==============================] - 3s 19ms/step - loss: 1.0806e-04 - accuracy: 1.0000 - val_loss: 0.2856 - val_accuracy: 0.9367
#
# Epoch 00025: val_accuracy did not improve from 0.95667
# Epoch 26/30
# 132/132 [==============================] - 3s 20ms/step - loss: 9.1819e-05 - accuracy: 1.0000 - val_loss: 0.2837 - val_accuracy: 0.9367
#
# Epoch 00026: val_accuracy did not improve from 0.95667
# Epoch 27/30
# 132/132 [==============================] - 3s 21ms/step - loss: 7.9959e-05 - accuracy: 1.0000 - val_loss: 0.2891 - val_accuracy: 0.9367
#
# Epoch 00027: val_accuracy did not improve from 0.95667
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 28/30
# 132/132 [==============================] - 3s 20ms/step - loss: 6.9657e-05 - accuracy: 1.0000 - val_loss: 0.2897 - val_accuracy: 0.9367
#
# Epoch 00028: val_accuracy did not improve from 0.95667
# Epoch 29/30
# 132/132 [==============================] - 3s 19ms/step - loss: 6.5160e-05 - accuracy: 1.0000 - val_loss: 0.2896 - val_accuracy: 0.9367
#
# Epoch 00029: val_accuracy did not improve from 0.95667
# Epoch 30/30
# 132/132 [==============================] - 3s 20ms/step - loss: 6.0874e-05 - accuracy: 1.0000 - val_loss: 0.2907 - val_accuracy: 0.9367
#
# Epoch 00030: val_accuracy did not improve from 0.95667
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 5
# Genre split [['Rock'], ['Country', 'Disco', 'Hip-Hop', 'Reggae']]
# Building model...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 132/132 [==============================] - 3s 21ms/step - loss: 0.5434 - accuracy: 0.7919 - val_loss: 0.4541 - val_accuracy: 0.8067
#
# Epoch 00001: val_accuracy improved from -inf to 0.80667, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder5\model.h5
# Epoch 2/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.4713 - accuracy: 0.7995 - val_loss: 0.4514 - val_accuracy: 0.8100
#
# Epoch 00002: val_accuracy improved from 0.80667 to 0.81000, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder5\model.h5
# Epoch 3/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.4378 - accuracy: 0.8029 - val_loss: 0.3681 - val_accuracy: 0.8133
#
# Epoch 00003: val_accuracy improved from 0.81000 to 0.81333, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder5\model.h5
# Epoch 4/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.3709 - accuracy: 0.8348 - val_loss: 0.3508 - val_accuracy: 0.8467
#
# Epoch 00004: val_accuracy improved from 0.81333 to 0.84667, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder5\model.h5
# Epoch 5/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.3462 - accuracy: 0.8398 - val_loss: 0.3039 - val_accuracy: 0.8467
#
# Epoch 00005: val_accuracy did not improve from 0.84667
# Epoch 6/30
# 132/132 [==============================] - 3s 21ms/step - loss: 0.3014 - accuracy: 0.8593 - val_loss: 0.2813 - val_accuracy: 0.8767
#
# Epoch 00006: val_accuracy improved from 0.84667 to 0.87667, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder5\model.h5
# Epoch 7/30
# 132/132 [==============================] - 3s 21ms/step - loss: 0.2715 - accuracy: 0.8743 - val_loss: 0.2725 - val_accuracy: 0.8633
#
# Epoch 00007: val_accuracy did not improve from 0.87667
# Epoch 8/30
# 132/132 [==============================] - 3s 21ms/step - loss: 0.2586 - accuracy: 0.8848 - val_loss: 0.2819 - val_accuracy: 0.8667
#
# Epoch 00008: val_accuracy did not improve from 0.87667
# Epoch 9/30
# 132/132 [==============================] - 3s 21ms/step - loss: 0.2474 - accuracy: 0.8898 - val_loss: 0.3050 - val_accuracy: 0.8667
#
# Epoch 00009: val_accuracy did not improve from 0.87667
# Epoch 10/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.2044 - accuracy: 0.9071 - val_loss: 0.2454 - val_accuracy: 0.8933
#
# Epoch 00010: val_accuracy improved from 0.87667 to 0.89333, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder5\model.h5
# Epoch 11/30
# 132/132 [==============================] - 3s 21ms/step - loss: 0.1862 - accuracy: 0.9233 - val_loss: 0.2723 - val_accuracy: 0.8700
#
# Epoch 00011: val_accuracy did not improve from 0.89333
# Epoch 12/30
# 132/132 [==============================] - 3s 21ms/step - loss: 0.1521 - accuracy: 0.9414 - val_loss: 0.2681 - val_accuracy: 0.8733
#
# Epoch 00012: val_accuracy did not improve from 0.89333
# Epoch 13/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.1218 - accuracy: 0.9481 - val_loss: 0.2383 - val_accuracy: 0.8800
#
# Epoch 00013: val_accuracy did not improve from 0.89333
# Epoch 14/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.0894 - accuracy: 0.9664 - val_loss: 0.2948 - val_accuracy: 0.8867
#
# Epoch 00014: val_accuracy did not improve from 0.89333
# Epoch 15/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.0757 - accuracy: 0.9710 - val_loss: 0.3073 - val_accuracy: 0.8900
#
# Epoch 00015: val_accuracy did not improve from 0.89333
# Epoch 16/30
# 132/132 [==============================] - 3s 21ms/step - loss: 0.0423 - accuracy: 0.9869 - val_loss: 0.3060 - val_accuracy: 0.8900
#
# Epoch 00016: val_accuracy did not improve from 0.89333
# Epoch 17/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.0202 - accuracy: 0.9948 - val_loss: 0.5082 - val_accuracy: 0.8833
#
# Epoch 00017: val_accuracy did not improve from 0.89333
# Epoch 18/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.0346 - accuracy: 0.9890 - val_loss: 0.2991 - val_accuracy: 0.8767
#
# Epoch 00018: val_accuracy did not improve from 0.89333
# Epoch 19/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.0294 - accuracy: 0.9907 - val_loss: 0.3334 - val_accuracy: 0.8933
#
# Epoch 00019: val_accuracy did not improve from 0.89333
# Epoch 20/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0054 - accuracy: 0.9995 - val_loss: 0.4064 - val_accuracy: 0.9033
#
# Epoch 00020: val_accuracy improved from 0.89333 to 0.90333, saving model to ./models/tree_11/model_root_f1_1_1_1_1/folder5\model.h5
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/30
# 132/132 [==============================] - 3s 20ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4118 - val_accuracy: 0.8867
#
# Epoch 00021: val_accuracy did not improve from 0.90333
# Epoch 22/30
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4307 - val_accuracy: 0.9033
#
# Epoch 00022: val_accuracy did not improve from 0.90333
# Epoch 23/30
# 132/132 [==============================] - 3s 19ms/step - loss: 8.7050e-04 - accuracy: 1.0000 - val_loss: 0.4417 - val_accuracy: 0.9000
#
# Epoch 00023: val_accuracy did not improve from 0.90333
# Epoch 24/30
# 132/132 [==============================] - 3s 19ms/step - loss: 7.1108e-04 - accuracy: 1.0000 - val_loss: 0.4448 - val_accuracy: 0.8967
#
# Epoch 00024: val_accuracy did not improve from 0.90333
# Epoch 25/30
# 132/132 [==============================] - 2s 19ms/step - loss: 5.9643e-04 - accuracy: 1.0000 - val_loss: 0.4563 - val_accuracy: 0.8967
#
# Epoch 00025: val_accuracy did not improve from 0.90333
# Epoch 26/30
# 132/132 [==============================] - 2s 19ms/step - loss: 4.9697e-04 - accuracy: 1.0000 - val_loss: 0.4667 - val_accuracy: 0.9000
#
# Epoch 00026: val_accuracy did not improve from 0.90333
# Epoch 27/30
# 132/132 [==============================] - 3s 22ms/step - loss: 4.3233e-04 - accuracy: 1.0000 - val_loss: 0.4675 - val_accuracy: 0.8967
#
# Epoch 00027: val_accuracy did not improve from 0.90333
# Epoch 28/30
# 132/132 [==============================] - 3s 21ms/step - loss: 3.6664e-04 - accuracy: 1.0000 - val_loss: 0.4819 - val_accuracy: 0.8967
#
# Epoch 00028: val_accuracy did not improve from 0.90333
# Epoch 29/30
# 132/132 [==============================] - 3s 19ms/step - loss: 3.3156e-04 - accuracy: 1.0000 - val_loss: 0.4935 - val_accuracy: 0.8967
#
# Epoch 00029: val_accuracy did not improve from 0.90333
# Epoch 30/30
# 132/132 [==============================] - 2s 19ms/step - loss: 2.8295e-04 - accuracy: 1.0000 - val_loss: 0.4889 - val_accuracy: 0.8967
#
# Epoch 00030: val_accuracy did not improve from 0.90333
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
