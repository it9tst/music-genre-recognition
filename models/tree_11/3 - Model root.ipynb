# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Blues', 1: 'Classical', 2: 'Country', 3: 'Disco', 4: 'Hip-Hop', 5: 'Jazz', 6: 'Metal', 7: 'Pop', 8: 'Reggae', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
print(spectogram.shape)
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Disco
# (128, 128)

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
       
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_11/model_root/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_11/model_root/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 10
n_splits = 15

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    dict_genres_list = list(dict_genres.values())
    split = [[dict_genres_list.pop(fold_no - 1)], dict_genres_list]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Blues'], ['Classical', 'Country', 'Disco', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 263/263 [==============================] - 9s 21ms/step - loss: 0.3481 - accuracy: 0.8963 - val_loss: 0.3652 - val_accuracy: 0.8817
#
# Epoch 00001: val_accuracy improved from -inf to 0.88167, saving model to ./models/tree_11/model_root/folder1\model.h5
# Epoch 2/30
# 263/263 [==============================] - 5s 20ms/step - loss: 0.3206 - accuracy: 0.9012 - val_loss: 0.3342 - val_accuracy: 0.8817
#
# Epoch 00002: val_accuracy did not improve from 0.88167
# Epoch 3/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.2767 - accuracy: 0.9026 - val_loss: 0.2820 - val_accuracy: 0.9067
#
# Epoch 00003: val_accuracy improved from 0.88167 to 0.90667, saving model to ./models/tree_11/model_root/folder1\model.h5
# Epoch 4/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.2335 - accuracy: 0.9094 - val_loss: 0.2514 - val_accuracy: 0.9050
#
# Epoch 00004: val_accuracy did not improve from 0.90667
# Epoch 5/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1872 - accuracy: 0.9275 - val_loss: 0.2270 - val_accuracy: 0.9100
#
# Epoch 00005: val_accuracy improved from 0.90667 to 0.91000, saving model to ./models/tree_11/model_root/folder1\model.h5
# Epoch 6/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1589 - accuracy: 0.9364 - val_loss: 0.1978 - val_accuracy: 0.9217
#
# Epoch 00006: val_accuracy improved from 0.91000 to 0.92167, saving model to ./models/tree_11/model_root/folder1\model.h5
# Epoch 7/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1279 - accuracy: 0.9487 - val_loss: 0.2287 - val_accuracy: 0.9217
#
# Epoch 00007: val_accuracy did not improve from 0.92167
# Epoch 8/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0997 - accuracy: 0.9632 - val_loss: 0.1819 - val_accuracy: 0.9317
#
# Epoch 00008: val_accuracy improved from 0.92167 to 0.93167, saving model to ./models/tree_11/model_root/folder1\model.h5
# Epoch 9/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0822 - accuracy: 0.9694 - val_loss: 0.2685 - val_accuracy: 0.9367
#
# Epoch 00009: val_accuracy improved from 0.93167 to 0.93667, saving model to ./models/tree_11/model_root/folder1\model.h5
# Epoch 10/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0709 - accuracy: 0.9708 - val_loss: 0.1694 - val_accuracy: 0.9417
#
# Epoch 00010: val_accuracy improved from 0.93667 to 0.94167, saving model to ./models/tree_11/model_root/folder1\model.h5
# Epoch 11/30
# 263/263 [==============================] - 5s 20ms/step - loss: 0.0474 - accuracy: 0.9827 - val_loss: 0.2349 - val_accuracy: 0.9417
#
# Epoch 00011: val_accuracy did not improve from 0.94167
# Epoch 12/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0361 - accuracy: 0.9859 - val_loss: 0.1649 - val_accuracy: 0.9467
#
# Epoch 00012: val_accuracy improved from 0.94167 to 0.94667, saving model to ./models/tree_11/model_root/folder1\model.h5
# Epoch 13/30
# 263/263 [==============================] - 5s 18ms/step - loss: 0.0125 - accuracy: 0.9967 - val_loss: 0.2662 - val_accuracy: 0.9433
#
# Epoch 00013: val_accuracy did not improve from 0.94667
# Epoch 14/30
# 263/263 [==============================] - 5s 18ms/step - loss: 0.0301 - accuracy: 0.9890 - val_loss: 0.2308 - val_accuracy: 0.9333
#
# Epoch 00014: val_accuracy did not improve from 0.94667
# Epoch 15/30
# 263/263 [==============================] - 5s 18ms/step - loss: 0.0206 - accuracy: 0.9923 - val_loss: 0.2226 - val_accuracy: 0.9550
#
# Epoch 00015: val_accuracy improved from 0.94667 to 0.95500, saving model to ./models/tree_11/model_root/folder1\model.h5
# Epoch 16/30
# 263/263 [==============================] - 5s 18ms/step - loss: 0.0046 - accuracy: 0.9990 - val_loss: 0.2736 - val_accuracy: 0.9517
#
# Epoch 00016: val_accuracy did not improve from 0.95500
# Epoch 17/30
# 263/263 [==============================] - 5s 18ms/step - loss: 5.5520e-04 - accuracy: 1.0000 - val_loss: 0.2797 - val_accuracy: 0.9483
#
# Epoch 00017: val_accuracy did not improve from 0.95500
# Epoch 18/30
# 263/263 [==============================] - 5s 18ms/step - loss: 2.5403e-04 - accuracy: 1.0000 - val_loss: 0.3145 - val_accuracy: 0.9533
#
# Epoch 00018: val_accuracy did not improve from 0.95500
# Epoch 19/30
# 263/263 [==============================] - 5s 19ms/step - loss: 1.5690e-04 - accuracy: 1.0000 - val_loss: 0.3303 - val_accuracy: 0.9550
#
# Epoch 00019: val_accuracy did not improve from 0.95500
# Epoch 20/30
# 263/263 [==============================] - 5s 18ms/step - loss: 1.1554e-04 - accuracy: 1.0000 - val_loss: 0.3295 - val_accuracy: 0.9533
#
# Epoch 00020: val_accuracy did not improve from 0.95500
# Epoch 21/30
# 263/263 [==============================] - 5s 18ms/step - loss: 9.0187e-05 - accuracy: 1.0000 - val_loss: 0.3436 - val_accuracy: 0.9550
#
# Epoch 00021: val_accuracy did not improve from 0.95500
# Epoch 22/30
# 263/263 [==============================] - 5s 20ms/step - loss: 7.2321e-05 - accuracy: 1.0000 - val_loss: 0.3594 - val_accuracy: 0.9533
#
# Epoch 00022: val_accuracy did not improve from 0.95500
# Epoch 23/30
# 263/263 [==============================] - 5s 19ms/step - loss: 5.8549e-05 - accuracy: 1.0000 - val_loss: 0.3482 - val_accuracy: 0.9533
#
# Epoch 00023: val_accuracy did not improve from 0.95500
# Epoch 24/30
# 263/263 [==============================] - 5s 19ms/step - loss: 4.7568e-05 - accuracy: 1.0000 - val_loss: 0.3590 - val_accuracy: 0.9550
#
# Epoch 00024: val_accuracy did not improve from 0.95500
# Epoch 25/30
# 263/263 [==============================] - 5s 19ms/step - loss: 3.9578e-05 - accuracy: 1.0000 - val_loss: 0.3695 - val_accuracy: 0.9533
#
# Epoch 00025: val_accuracy did not improve from 0.95500
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 26/30
# 263/263 [==============================] - 5s 19ms/step - loss: 3.2941e-05 - accuracy: 1.0000 - val_loss: 0.3749 - val_accuracy: 0.9533
#
# Epoch 00026: val_accuracy did not improve from 0.95500
# Epoch 27/30
# 263/263 [==============================] - 5s 19ms/step - loss: 2.9848e-05 - accuracy: 1.0000 - val_loss: 0.3825 - val_accuracy: 0.9550
#
# Epoch 00027: val_accuracy did not improve from 0.95500
# Epoch 28/30
# 263/263 [==============================] - 5s 19ms/step - loss: 2.7490e-05 - accuracy: 1.0000 - val_loss: 0.3796 - val_accuracy: 0.9533
#
# Epoch 00028: val_accuracy did not improve from 0.95500
# Epoch 29/30
# 263/263 [==============================] - 5s 19ms/step - loss: 2.4709e-05 - accuracy: 1.0000 - val_loss: 0.3855 - val_accuracy: 0.9550
#
# Epoch 00029: val_accuracy did not improve from 0.95500
# Epoch 30/30
# 263/263 [==============================] - 5s 19ms/step - loss: 2.2410e-05 - accuracy: 1.0000 - val_loss: 0.3847 - val_accuracy: 0.9550
#
# Epoch 00030: val_accuracy did not improve from 0.95500
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Classical'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 263/263 [==============================] - 6s 20ms/step - loss: 0.2476 - accuracy: 0.9185 - val_loss: 0.1032 - val_accuracy: 0.9667
#
# Epoch 00001: val_accuracy improved from -inf to 0.96667, saving model to ./models/tree_11/model_root/folder2\model.h5
# Epoch 2/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1168 - accuracy: 0.9554 - val_loss: 0.0840 - val_accuracy: 0.9683
#
# Epoch 00002: val_accuracy improved from 0.96667 to 0.96833, saving model to ./models/tree_11/model_root/folder2\model.h5
# Epoch 3/30
# 263/263 [==============================] - 5s 20ms/step - loss: 0.0940 - accuracy: 0.9634 - val_loss: 0.0945 - val_accuracy: 0.9633
#
# Epoch 00003: val_accuracy did not improve from 0.96833
# Epoch 4/30
# 263/263 [==============================] - 5s 20ms/step - loss: 0.0953 - accuracy: 0.9622 - val_loss: 0.1021 - val_accuracy: 0.9667
#
# Epoch 00004: val_accuracy did not improve from 0.96833
# Epoch 5/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0800 - accuracy: 0.9700 - val_loss: 0.0780 - val_accuracy: 0.9667
#
# Epoch 00005: val_accuracy did not improve from 0.96833
# Epoch 6/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0745 - accuracy: 0.9706 - val_loss: 0.0625 - val_accuracy: 0.9667
#
# Epoch 00006: val_accuracy did not improve from 0.96833
# Epoch 7/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0599 - accuracy: 0.9774 - val_loss: 0.0549 - val_accuracy: 0.9767
#
# Epoch 00007: val_accuracy improved from 0.96833 to 0.97667, saving model to ./models/tree_11/model_root/folder2\model.h5
# Epoch 8/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0688 - accuracy: 0.9759 - val_loss: 0.0488 - val_accuracy: 0.9817
#
# Epoch 00008: val_accuracy improved from 0.97667 to 0.98167, saving model to ./models/tree_11/model_root/folder2\model.h5
# Epoch 9/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0430 - accuracy: 0.9831 - val_loss: 0.0518 - val_accuracy: 0.9783
#
# Epoch 00009: val_accuracy did not improve from 0.98167
# Epoch 10/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0334 - accuracy: 0.9868 - val_loss: 0.0506 - val_accuracy: 0.9833
#
# Epoch 00010: val_accuracy improved from 0.98167 to 0.98333, saving model to ./models/tree_11/model_root/folder2\model.h5
# Epoch 11/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0285 - accuracy: 0.9896 - val_loss: 0.0480 - val_accuracy: 0.9833
#
# Epoch 00011: val_accuracy did not improve from 0.98333
# Epoch 12/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0256 - accuracy: 0.9907 - val_loss: 0.0475 - val_accuracy: 0.9817
#
# Epoch 00012: val_accuracy did not improve from 0.98333
# Epoch 13/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0108 - accuracy: 0.9961 - val_loss: 0.0534 - val_accuracy: 0.9833
#
# Epoch 00013: val_accuracy did not improve from 0.98333
# Epoch 14/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0213 - accuracy: 0.9926 - val_loss: 0.0434 - val_accuracy: 0.9833
#
# Epoch 00014: val_accuracy did not improve from 0.98333
# Epoch 15/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.0526 - val_accuracy: 0.9833
#
# Epoch 00015: val_accuracy did not improve from 0.98333
# Epoch 16/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0193 - accuracy: 0.9933 - val_loss: 0.0609 - val_accuracy: 0.9767
#
# Epoch 00016: val_accuracy did not improve from 0.98333
# Epoch 17/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0276 - accuracy: 0.9882 - val_loss: 0.0459 - val_accuracy: 0.9833
#
# Epoch 00017: val_accuracy did not improve from 0.98333
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 18/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.0680 - val_accuracy: 0.9850
#
# Epoch 00018: val_accuracy improved from 0.98333 to 0.98500, saving model to ./models/tree_11/model_root/folder2\model.h5
# Epoch 19/30
# 263/263 [==============================] - 5s 20ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0720 - val_accuracy: 0.9833
#
# Epoch 00019: val_accuracy did not improve from 0.98500
# Epoch 20/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0016 - accuracy: 0.9999 - val_loss: 0.0601 - val_accuracy: 0.9867
#
# Epoch 00020: val_accuracy improved from 0.98500 to 0.98667, saving model to ./models/tree_11/model_root/folder2\model.h5
# Epoch 21/30
# 263/263 [==============================] - 5s 19ms/step - loss: 4.5205e-04 - accuracy: 1.0000 - val_loss: 0.0683 - val_accuracy: 0.9850
#
# Epoch 00021: val_accuracy did not improve from 0.98667
# Epoch 22/30
# 263/263 [==============================] - 5s 19ms/step - loss: 4.1182e-04 - accuracy: 1.0000 - val_loss: 0.0770 - val_accuracy: 0.9850
#
# Epoch 00022: val_accuracy did not improve from 0.98667
# Epoch 23/30
# 263/263 [==============================] - 5s 19ms/step - loss: 1.7782e-04 - accuracy: 1.0000 - val_loss: 0.0773 - val_accuracy: 0.9867
#
# Epoch 00023: val_accuracy did not improve from 0.98667
# Epoch 24/30
# 263/263 [==============================] - 5s 19ms/step - loss: 1.3098e-04 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 0.9867
#
# Epoch 00024: val_accuracy did not improve from 0.98667
# Epoch 25/30
# 263/263 [==============================] - 5s 19ms/step - loss: 1.0169e-04 - accuracy: 1.0000 - val_loss: 0.0856 - val_accuracy: 0.9867
#
# Epoch 00025: val_accuracy did not improve from 0.98667
# Epoch 26/30
# 263/263 [==============================] - 5s 19ms/step - loss: 8.2531e-05 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 0.9867
#
# Epoch 00026: val_accuracy did not improve from 0.98667
# Epoch 27/30
# 263/263 [==============================] - 5s 20ms/step - loss: 6.2140e-05 - accuracy: 1.0000 - val_loss: 0.0903 - val_accuracy: 0.9867
#
# Epoch 00027: val_accuracy did not improve from 0.98667
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 28/30
# 263/263 [==============================] - 5s 19ms/step - loss: 5.0359e-05 - accuracy: 1.0000 - val_loss: 0.0914 - val_accuracy: 0.9867
#
# Epoch 00028: val_accuracy did not improve from 0.98667
# Epoch 29/30
# 263/263 [==============================] - 5s 19ms/step - loss: 4.4878e-05 - accuracy: 1.0000 - val_loss: 0.0945 - val_accuracy: 0.9867
#
# Epoch 00029: val_accuracy did not improve from 0.98667
# Epoch 30/30
# 263/263 [==============================] - 5s 19ms/step - loss: 4.1888e-05 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 0.9867
#
# Epoch 00030: val_accuracy did not improve from 0.98667
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Country'], ['Blues', 'Classical', 'Disco', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 263/263 [==============================] - 6s 20ms/step - loss: 0.3418 - accuracy: 0.8930 - val_loss: 0.2398 - val_accuracy: 0.9233
#
# Epoch 00001: val_accuracy improved from -inf to 0.92333, saving model to ./models/tree_11/model_root/folder3\model.h5
# Epoch 2/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.2762 - accuracy: 0.8969 - val_loss: 0.2023 - val_accuracy: 0.9167
#
# Epoch 00002: val_accuracy did not improve from 0.92333
# Epoch 3/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.2447 - accuracy: 0.9039 - val_loss: 0.2030 - val_accuracy: 0.9250
#
# Epoch 00003: val_accuracy improved from 0.92333 to 0.92500, saving model to ./models/tree_11/model_root/folder3\model.h5
# Epoch 4/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.2227 - accuracy: 0.9091 - val_loss: 0.2006 - val_accuracy: 0.9283
#
# Epoch 00004: val_accuracy improved from 0.92500 to 0.92833, saving model to ./models/tree_11/model_root/folder3\model.h5
# Epoch 5/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.2067 - accuracy: 0.9176 - val_loss: 0.1639 - val_accuracy: 0.9350
#
# Epoch 00005: val_accuracy improved from 0.92833 to 0.93500, saving model to ./models/tree_11/model_root/folder3\model.h5
# Epoch 6/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1878 - accuracy: 0.9248 - val_loss: 0.1473 - val_accuracy: 0.9433
#
# Epoch 00006: val_accuracy improved from 0.93500 to 0.94333, saving model to ./models/tree_11/model_root/folder3\model.h5
# Epoch 7/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1672 - accuracy: 0.9362 - val_loss: 0.1589 - val_accuracy: 0.9417
#
# Epoch 00007: val_accuracy did not improve from 0.94333
# Epoch 8/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1435 - accuracy: 0.9448 - val_loss: 0.1626 - val_accuracy: 0.9383
#
# Epoch 00008: val_accuracy did not improve from 0.94333
# Epoch 9/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1280 - accuracy: 0.9511 - val_loss: 0.1596 - val_accuracy: 0.9333
#
# Epoch 00009: val_accuracy did not improve from 0.94333
# Epoch 10/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1087 - accuracy: 0.9603 - val_loss: 0.1228 - val_accuracy: 0.9483
#
# Epoch 00010: val_accuracy improved from 0.94333 to 0.94833, saving model to ./models/tree_11/model_root/folder3\model.h5
# Epoch 11/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0904 - accuracy: 0.9662 - val_loss: 0.1352 - val_accuracy: 0.9517
#
# Epoch 00011: val_accuracy improved from 0.94833 to 0.95167, saving model to ./models/tree_11/model_root/folder3\model.h5
# Epoch 12/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0751 - accuracy: 0.9734 - val_loss: 0.1686 - val_accuracy: 0.9350
#
# Epoch 00012: val_accuracy did not improve from 0.95167
# Epoch 13/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0585 - accuracy: 0.9782 - val_loss: 0.1515 - val_accuracy: 0.9450
#
# Epoch 00013: val_accuracy did not improve from 0.95167
# Epoch 14/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0459 - accuracy: 0.9809 - val_loss: 0.2042 - val_accuracy: 0.9300
#
# Epoch 00014: val_accuracy did not improve from 0.95167
# Epoch 15/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0321 - accuracy: 0.9896 - val_loss: 0.1810 - val_accuracy: 0.9450
#
# Epoch 00015: val_accuracy did not improve from 0.95167
# Epoch 16/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0238 - accuracy: 0.9907 - val_loss: 0.1752 - val_accuracy: 0.9467
#
# Epoch 00016: val_accuracy did not improve from 0.95167
# Epoch 17/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0157 - accuracy: 0.9951 - val_loss: 0.1953 - val_accuracy: 0.9533
#
# Epoch 00017: val_accuracy improved from 0.95167 to 0.95333, saving model to ./models/tree_11/model_root/folder3\model.h5
# Epoch 18/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.2038 - val_accuracy: 0.9500
#
# Epoch 00018: val_accuracy did not improve from 0.95333
# Epoch 19/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0403 - accuracy: 0.9863 - val_loss: 0.2056 - val_accuracy: 0.9400
#
# Epoch 00019: val_accuracy did not improve from 0.95333
# Epoch 20/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0104 - accuracy: 0.9962 - val_loss: 0.1589 - val_accuracy: 0.9583
#
# Epoch 00020: val_accuracy improved from 0.95333 to 0.95833, saving model to ./models/tree_11/model_root/folder3\model.h5
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/30
# 263/263 [==============================] - 6s 23ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.2098 - val_accuracy: 0.9517
#
# Epoch 00021: val_accuracy did not improve from 0.95833
# Epoch 22/30
# 263/263 [==============================] - 6s 24ms/step - loss: 5.9651e-04 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9483
#
# Epoch 00022: val_accuracy did not improve from 0.95833
# Epoch 23/30
# 263/263 [==============================] - 6s 22ms/step - loss: 3.5141e-04 - accuracy: 1.0000 - val_loss: 0.2170 - val_accuracy: 0.9500
#
# Epoch 00023: val_accuracy did not improve from 0.95833
# Epoch 24/30
# 263/263 [==============================] - 6s 22ms/step - loss: 2.5993e-04 - accuracy: 1.0000 - val_loss: 0.2240 - val_accuracy: 0.9517
#
# Epoch 00024: val_accuracy did not improve from 0.95833
# Epoch 25/30
# 263/263 [==============================] - 6s 23ms/step - loss: 2.0234e-04 - accuracy: 1.0000 - val_loss: 0.2304 - val_accuracy: 0.9517
#
# Epoch 00025: val_accuracy did not improve from 0.95833
# Epoch 26/30
# 263/263 [==============================] - 6s 23ms/step - loss: 1.6272e-04 - accuracy: 1.0000 - val_loss: 0.2338 - val_accuracy: 0.9500
#
# Epoch 00026: val_accuracy did not improve from 0.95833
# Epoch 27/30
# 263/263 [==============================] - 5s 19ms/step - loss: 1.3200e-04 - accuracy: 1.0000 - val_loss: 0.2384 - val_accuracy: 0.9500
#
# Epoch 00027: val_accuracy did not improve from 0.95833
# Epoch 28/30
# 263/263 [==============================] - 5s 19ms/step - loss: 1.0806e-04 - accuracy: 1.0000 - val_loss: 0.2453 - val_accuracy: 0.9483
#
# Epoch 00028: val_accuracy did not improve from 0.95833
# Epoch 29/30
# 263/263 [==============================] - 5s 19ms/step - loss: 9.0173e-05 - accuracy: 1.0000 - val_loss: 0.2507 - val_accuracy: 0.9483
#
# Epoch 00029: val_accuracy did not improve from 0.95833
# Epoch 30/30
# 263/263 [==============================] - 5s 19ms/step - loss: 7.5179e-05 - accuracy: 1.0000 - val_loss: 0.2574 - val_accuracy: 0.9483
#
# Epoch 00030: val_accuracy did not improve from 0.95833
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Disco'], ['Blues', 'Classical', 'Country', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 263/263 [==============================] - 6s 20ms/step - loss: 0.3381 - accuracy: 0.8969 - val_loss: 0.3452 - val_accuracy: 0.8950
#
# Epoch 00001: val_accuracy improved from -inf to 0.89500, saving model to ./models/tree_11/model_root/folder4\model.h5
# Epoch 2/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.3121 - accuracy: 0.9001 - val_loss: 0.3138 - val_accuracy: 0.8950
#
# Epoch 00002: val_accuracy did not improve from 0.89500
# Epoch 3/30
# 263/263 [==============================] - 6s 21ms/step - loss: 0.2577 - accuracy: 0.9094 - val_loss: 0.1996 - val_accuracy: 0.9217
#
# Epoch 00003: val_accuracy improved from 0.89500 to 0.92167, saving model to ./models/tree_11/model_root/folder4\model.h5
# Epoch 4/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1586 - accuracy: 0.9453 - val_loss: 0.1446 - val_accuracy: 0.9517
#
# Epoch 00004: val_accuracy improved from 0.92167 to 0.95167, saving model to ./models/tree_11/model_root/folder4\model.h5
# Epoch 5/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1442 - accuracy: 0.9513 - val_loss: 0.2219 - val_accuracy: 0.9250
#
# Epoch 00005: val_accuracy did not improve from 0.95167
# Epoch 6/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1084 - accuracy: 0.9650 - val_loss: 0.1423 - val_accuracy: 0.9550
#
# Epoch 00006: val_accuracy improved from 0.95167 to 0.95500, saving model to ./models/tree_11/model_root/folder4\model.h5
# Epoch 7/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0947 - accuracy: 0.9682 - val_loss: 0.1117 - val_accuracy: 0.9600
#
# Epoch 00007: val_accuracy improved from 0.95500 to 0.96000, saving model to ./models/tree_11/model_root/folder4\model.h5
# Epoch 8/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0713 - accuracy: 0.9769 - val_loss: 0.1126 - val_accuracy: 0.9567
#
# Epoch 00008: val_accuracy did not improve from 0.96000
# Epoch 9/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0606 - accuracy: 0.9802 - val_loss: 0.1383 - val_accuracy: 0.9550
#
# Epoch 00009: val_accuracy did not improve from 0.96000
# Epoch 10/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0504 - accuracy: 0.9836 - val_loss: 0.1533 - val_accuracy: 0.9400
#
# Epoch 00010: val_accuracy did not improve from 0.96000
# Epoch 11/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0402 - accuracy: 0.9847 - val_loss: 0.1651 - val_accuracy: 0.9483
#
# Epoch 00011: val_accuracy did not improve from 0.96000
# Epoch 12/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0292 - accuracy: 0.9912 - val_loss: 0.2014 - val_accuracy: 0.9600
#
# Epoch 00012: val_accuracy did not improve from 0.96000
# Epoch 13/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0266 - accuracy: 0.9915 - val_loss: 0.2154 - val_accuracy: 0.9600
#
# Epoch 00013: val_accuracy did not improve from 0.96000
# Epoch 14/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0135 - accuracy: 0.9954 - val_loss: 0.1573 - val_accuracy: 0.9583
#
# Epoch 00014: val_accuracy did not improve from 0.96000
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 15/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0032 - accuracy: 0.9993 - val_loss: 0.1920 - val_accuracy: 0.9650
#
# Epoch 00015: val_accuracy improved from 0.96000 to 0.96500, saving model to ./models/tree_11/model_root/folder4\model.h5
# Epoch 16/30
# 263/263 [==============================] - 6s 21ms/step - loss: 6.6152e-04 - accuracy: 1.0000 - val_loss: 0.2042 - val_accuracy: 0.9650
#
# Epoch 00016: val_accuracy did not improve from 0.96500
# Epoch 17/30
# 263/263 [==============================] - 5s 20ms/step - loss: 3.3593e-04 - accuracy: 1.0000 - val_loss: 0.1918 - val_accuracy: 0.9667
#
# Epoch 00017: val_accuracy improved from 0.96500 to 0.96667, saving model to ./models/tree_11/model_root/folder4\model.h5
# Epoch 18/30
# 263/263 [==============================] - 5s 19ms/step - loss: 2.1179e-04 - accuracy: 1.0000 - val_loss: 0.1977 - val_accuracy: 0.9683
#
# Epoch 00018: val_accuracy improved from 0.96667 to 0.96833, saving model to ./models/tree_11/model_root/folder4\model.h5
# Epoch 19/30
# 263/263 [==============================] - 5s 19ms/step - loss: 1.6252e-04 - accuracy: 1.0000 - val_loss: 0.2089 - val_accuracy: 0.9683
#
# Epoch 00019: val_accuracy did not improve from 0.96833
# Epoch 20/30
# 263/263 [==============================] - 5s 19ms/step - loss: 1.2860e-04 - accuracy: 1.0000 - val_loss: 0.2074 - val_accuracy: 0.9683
#
# Epoch 00020: val_accuracy did not improve from 0.96833
# Epoch 21/30
# 263/263 [==============================] - 5s 20ms/step - loss: 1.0293e-04 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 0.9683
#
# Epoch 00021: val_accuracy did not improve from 0.96833
# Epoch 22/30
# 263/263 [==============================] - 5s 19ms/step - loss: 8.3314e-05 - accuracy: 1.0000 - val_loss: 0.2199 - val_accuracy: 0.9683
#
# Epoch 00022: val_accuracy did not improve from 0.96833
# Epoch 23/30
# 263/263 [==============================] - 5s 19ms/step - loss: 6.8507e-05 - accuracy: 1.0000 - val_loss: 0.2318 - val_accuracy: 0.9683
#
# Epoch 00023: val_accuracy did not improve from 0.96833
# Epoch 24/30
# 263/263 [==============================] - 5s 19ms/step - loss: 5.6692e-05 - accuracy: 1.0000 - val_loss: 0.2297 - val_accuracy: 0.9683
#
# Epoch 00024: val_accuracy did not improve from 0.96833
# Epoch 25/30
# 263/263 [==============================] - 5s 19ms/step - loss: 4.7510e-05 - accuracy: 1.0000 - val_loss: 0.2352 - val_accuracy: 0.9683
#
# Epoch 00025: val_accuracy did not improve from 0.96833
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 26/30
# 263/263 [==============================] - 5s 20ms/step - loss: 3.8755e-05 - accuracy: 1.0000 - val_loss: 0.2340 - val_accuracy: 0.9683
#
# Epoch 00026: val_accuracy did not improve from 0.96833
# Epoch 27/30
# 263/263 [==============================] - 5s 20ms/step - loss: 3.5259e-05 - accuracy: 1.0000 - val_loss: 0.2366 - val_accuracy: 0.9683
#
# Epoch 00027: val_accuracy did not improve from 0.96833
# Epoch 28/30
# 263/263 [==============================] - 5s 20ms/step - loss: 3.1940e-05 - accuracy: 1.0000 - val_loss: 0.2413 - val_accuracy: 0.9683
#
# Epoch 00028: val_accuracy did not improve from 0.96833
# Epoch 29/30
# 263/263 [==============================] - 5s 20ms/step - loss: 2.8903e-05 - accuracy: 1.0000 - val_loss: 0.2466 - val_accuracy: 0.9683
#
# Epoch 00029: val_accuracy did not improve from 0.96833
# Epoch 30/30
# 263/263 [==============================] - 5s 19ms/step - loss: 2.5949e-05 - accuracy: 1.0000 - val_loss: 0.2465 - val_accuracy: 0.9683
#
# Epoch 00030: val_accuracy did not improve from 0.96833
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 5
# Genre split [['Hip-Hop'], ['Blues', 'Classical', 'Country', 'Disco', 'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 263/263 [==============================] - 6s 21ms/step - loss: 0.3209 - accuracy: 0.9006 - val_loss: 0.2413 - val_accuracy: 0.8933
#
# Epoch 00001: val_accuracy improved from -inf to 0.89333, saving model to ./models/tree_11/model_root/folder5\model.h5
# Epoch 2/30
# 263/263 [==============================] - 5s 20ms/step - loss: 0.2170 - accuracy: 0.9107 - val_loss: 0.1631 - val_accuracy: 0.9400
#
# Epoch 00002: val_accuracy improved from 0.89333 to 0.94000, saving model to ./models/tree_11/model_root/folder5\model.h5
# Epoch 3/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1738 - accuracy: 0.9298 - val_loss: 0.1630 - val_accuracy: 0.9400
#
# Epoch 00003: val_accuracy did not improve from 0.94000
# Epoch 4/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1553 - accuracy: 0.9383 - val_loss: 0.1482 - val_accuracy: 0.9417
#
# Epoch 00004: val_accuracy improved from 0.94000 to 0.94167, saving model to ./models/tree_11/model_root/folder5\model.h5
# Epoch 5/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1196 - accuracy: 0.9524 - val_loss: 0.1326 - val_accuracy: 0.9433
#
# Epoch 00005: val_accuracy improved from 0.94167 to 0.94333, saving model to ./models/tree_11/model_root/folder5\model.h5
# Epoch 6/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0957 - accuracy: 0.9634 - val_loss: 0.1151 - val_accuracy: 0.9600
#
# Epoch 00006: val_accuracy improved from 0.94333 to 0.96000, saving model to ./models/tree_11/model_root/folder5\model.h5
# Epoch 7/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0632 - accuracy: 0.9762 - val_loss: 0.1301 - val_accuracy: 0.9500
#
# Epoch 00007: val_accuracy did not improve from 0.96000
# Epoch 8/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0590 - accuracy: 0.9777 - val_loss: 0.1048 - val_accuracy: 0.9633
#
# Epoch 00008: val_accuracy improved from 0.96000 to 0.96333, saving model to ./models/tree_11/model_root/folder5\model.h5
# Epoch 9/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0271 - accuracy: 0.9901 - val_loss: 0.1193 - val_accuracy: 0.9600
#
# Epoch 00009: val_accuracy did not improve from 0.96333
# Epoch 10/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0177 - accuracy: 0.9938 - val_loss: 0.1139 - val_accuracy: 0.9517
#
# Epoch 00010: val_accuracy did not improve from 0.96333
# Epoch 11/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0199 - accuracy: 0.9925 - val_loss: 0.1324 - val_accuracy: 0.9467
#
# Epoch 00011: val_accuracy did not improve from 0.96333
# Epoch 12/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0192 - accuracy: 0.9936 - val_loss: 0.0956 - val_accuracy: 0.9717
#
# Epoch 00012: val_accuracy improved from 0.96333 to 0.97167, saving model to ./models/tree_11/model_root/folder5\model.h5
# Epoch 13/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0126 - accuracy: 0.9968 - val_loss: 0.1265 - val_accuracy: 0.9617
#
# Epoch 00013: val_accuracy did not improve from 0.97167
# Epoch 14/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0162 - accuracy: 0.9949 - val_loss: 0.1255 - val_accuracy: 0.9750
#
# Epoch 00014: val_accuracy improved from 0.97167 to 0.97500, saving model to ./models/tree_11/model_root/folder5\model.h5
# Epoch 15/30
# 263/263 [==============================] - 5s 19ms/step - loss: 9.6438e-04 - accuracy: 0.9998 - val_loss: 0.1187 - val_accuracy: 0.9683
#
# Epoch 00015: val_accuracy did not improve from 0.97500
# Epoch 16/30
# 263/263 [==============================] - 5s 19ms/step - loss: 1.2236e-04 - accuracy: 1.0000 - val_loss: 0.1205 - val_accuracy: 0.9700
#
# Epoch 00016: val_accuracy did not improve from 0.97500
# Epoch 17/30
# 263/263 [==============================] - 5s 19ms/step - loss: 7.6724e-05 - accuracy: 1.0000 - val_loss: 0.1294 - val_accuracy: 0.9700
#
# Epoch 00017: val_accuracy did not improve from 0.97500
# Epoch 18/30
# 263/263 [==============================] - 5s 20ms/step - loss: 5.4757e-05 - accuracy: 1.0000 - val_loss: 0.1341 - val_accuracy: 0.9683
#
# Epoch 00018: val_accuracy did not improve from 0.97500
# Epoch 19/30
# 263/263 [==============================] - 5s 19ms/step - loss: 4.2005e-05 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9700
#
# Epoch 00019: val_accuracy did not improve from 0.97500
# Epoch 20/30
# 263/263 [==============================] - 6s 23ms/step - loss: 3.3155e-05 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9700
#
# Epoch 00020: val_accuracy did not improve from 0.97500
# Epoch 21/30
# 263/263 [==============================] - 6s 21ms/step - loss: 2.7002e-05 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9700A: 0s - loss: 2.8
#
# Epoch 00021: val_accuracy did not improve from 0.97500
# Epoch 22/30
# 263/263 [==============================] - 5s 19ms/step - loss: 2.2033e-05 - accuracy: 1.0000 - val_loss: 0.1442 - val_accuracy: 0.9700
#
# Epoch 00022: val_accuracy did not improve from 0.97500
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 23/30
# 263/263 [==============================] - 5s 19ms/step - loss: 1.8399e-05 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9683
#
# Epoch 00023: val_accuracy did not improve from 0.97500
# Epoch 24/30
# 263/263 [==============================] - 5s 19ms/step - loss: 1.6592e-05 - accuracy: 1.0000 - val_loss: 0.1431 - val_accuracy: 0.9683
#
# Epoch 00024: val_accuracy did not improve from 0.97500
# Epoch 25/30
# 263/263 [==============================] - 5s 19ms/step - loss: 1.4805e-05 - accuracy: 1.0000 - val_loss: 0.1457 - val_accuracy: 0.9700
#
# Epoch 00025: val_accuracy did not improve from 0.97500
# Epoch 26/30
# 263/263 [==============================] - 5s 19ms/step - loss: 1.3259e-05 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9700
#
# Epoch 00026: val_accuracy did not improve from 0.97500
# Epoch 27/30
# 263/263 [==============================] - 5s 19ms/step - loss: 1.1768e-05 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 0.9683
#
# Epoch 00027: val_accuracy did not improve from 0.97500
# Epoch 28/30
# 263/263 [==============================] - 5s 20ms/step - loss: 1.0315e-05 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9683
#
# Epoch 00028: val_accuracy did not improve from 0.97500
# Epoch 29/30
# 263/263 [==============================] - 5s 19ms/step - loss: 8.9972e-06 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9700
#
# Epoch 00029: val_accuracy did not improve from 0.97500
# Epoch 30/30
# 263/263 [==============================] - 5s 19ms/step - loss: 7.7723e-06 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9683
#
# Epoch 00030: val_accuracy did not improve from 0.97500
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 6
# Genre split [['Jazz'], ['Blues', 'Classical', 'Country', 'Disco', 'Hip-Hop', 'Metal', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 263/263 [==============================] - 7s 23ms/step - loss: 0.3397 - accuracy: 0.8982 - val_loss: 0.3570 - val_accuracy: 0.9098
#
# Epoch 00001: val_accuracy improved from -inf to 0.90985, saving model to ./models/tree_11/model_root/folder6\model.h5
# Epoch 2/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.2324 - accuracy: 0.9088 - val_loss: 0.1994 - val_accuracy: 0.9249
#
# Epoch 00002: val_accuracy improved from 0.90985 to 0.92487, saving model to ./models/tree_11/model_root/folder6\model.h5
# Epoch 3/30
# 263/263 [==============================] - 6s 21ms/step - loss: 0.1630 - accuracy: 0.9364 - val_loss: 0.1688 - val_accuracy: 0.9399
#
# Epoch 00003: val_accuracy improved from 0.92487 to 0.93990, saving model to ./models/tree_11/model_root/folder6\model.h5
# Epoch 4/30
# 263/263 [==============================] - 5s 21ms/step - loss: 0.1142 - accuracy: 0.9565 - val_loss: 0.1399 - val_accuracy: 0.9499
#
# Epoch 00004: val_accuracy improved from 0.93990 to 0.94992, saving model to ./models/tree_11/model_root/folder6\model.h5
# Epoch 5/30
# 263/263 [==============================] - 6s 24ms/step - loss: 0.0939 - accuracy: 0.9633 - val_loss: 0.1437 - val_accuracy: 0.9482
#
# Epoch 00005: val_accuracy did not improve from 0.94992
# Epoch 6/30
# 263/263 [==============================] - 6s 22ms/step - loss: 0.0725 - accuracy: 0.9735 - val_loss: 0.1743 - val_accuracy: 0.9499
#
# Epoch 00006: val_accuracy did not improve from 0.94992
# Epoch 7/30
# 263/263 [==============================] - 6s 23ms/step - loss: 0.0576 - accuracy: 0.9793 - val_loss: 0.1220 - val_accuracy: 0.9633
#
# Epoch 00007: val_accuracy improved from 0.94992 to 0.96327, saving model to ./models/tree_11/model_root/folder6\model.h5
# Epoch 8/30
# 263/263 [==============================] - 7s 26ms/step - loss: 0.0332 - accuracy: 0.9875 - val_loss: 0.1271 - val_accuracy: 0.9649
#
# Epoch 00008: val_accuracy improved from 0.96327 to 0.96494, saving model to ./models/tree_11/model_root/folder6\model.h5
# Epoch 9/30
# 263/263 [==============================] - 6s 22ms/step - loss: 0.0366 - accuracy: 0.9858 - val_loss: 0.1283 - val_accuracy: 0.9699
#
# Epoch 00009: val_accuracy improved from 0.96494 to 0.96995, saving model to ./models/tree_11/model_root/folder6\model.h5
# Epoch 10/30
# ...
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 263/263 [==============================] - 6s 20ms/step - loss: 0.3606 - accuracy: 0.8968 - val_loss: 0.3215 - val_accuracy: 0.8932
#
# Epoch 00001: val_accuracy improved from -inf to 0.89316, saving model to ./models/tree_11/model_root/folder9\model.h5
# Epoch 2/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.2801 - accuracy: 0.9029 - val_loss: 0.2659 - val_accuracy: 0.8965
#
# Epoch 00002: val_accuracy improved from 0.89316 to 0.89649, saving model to ./models/tree_11/model_root/folder9\model.h5
# Epoch 3/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.2269 - accuracy: 0.9190 - val_loss: 0.2207 - val_accuracy: 0.9182
#
# Epoch 00003: val_accuracy improved from 0.89649 to 0.91820, saving model to ./models/tree_11/model_root/folder9\model.h5
# Epoch 4/30
# 263/263 [==============================] - 5s 20ms/step - loss: 0.1905 - accuracy: 0.9325 - val_loss: 0.1875 - val_accuracy: 0.9382
#
# Epoch 00004: val_accuracy improved from 0.91820 to 0.93823, saving model to ./models/tree_11/model_root/folder9\model.h5
# Epoch 5/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1718 - accuracy: 0.9424 - val_loss: 0.1795 - val_accuracy: 0.9382
#
# Epoch 00005: val_accuracy did not improve from 0.93823
# Epoch 6/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1343 - accuracy: 0.9536 - val_loss: 0.1702 - val_accuracy: 0.9316
#
# Epoch 00006: val_accuracy did not improve from 0.93823
# Epoch 7/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0998 - accuracy: 0.9664 - val_loss: 0.1094 - val_accuracy: 0.9583
#
# Epoch 00007: val_accuracy improved from 0.93823 to 0.95826, saving model to ./models/tree_11/model_root/folder9\model.h5
# Epoch 8/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0741 - accuracy: 0.9745 - val_loss: 0.1176 - val_accuracy: 0.9566
#
# Epoch 00008: val_accuracy did not improve from 0.95826
# Epoch 9/30
# 263/263 [==============================] - 5s 20ms/step - loss: 0.0547 - accuracy: 0.9816 - val_loss: 0.1268 - val_accuracy: 0.9499
#
# Epoch 00009: val_accuracy did not improve from 0.95826
# Epoch 10/30
# 263/263 [==============================] - 5s 20ms/step - loss: 0.0439 - accuracy: 0.9840 - val_loss: 0.1209 - val_accuracy: 0.9599
#
# Epoch 00010: val_accuracy improved from 0.95826 to 0.95993, saving model to ./models/tree_11/model_root/folder9\model.h5
# Epoch 11/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0297 - accuracy: 0.9909 - val_loss: 0.1481 - val_accuracy: 0.9432
#
# Epoch 00011: val_accuracy did not improve from 0.95993
# Epoch 12/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0236 - accuracy: 0.9913 - val_loss: 0.1522 - val_accuracy: 0.9399
#
# Epoch 00012: val_accuracy did not improve from 0.95993
# Epoch 13/30
# 263/263 [==============================] - 5s 21ms/step - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.1247 - val_accuracy: 0.9583
#
# Epoch 00013: val_accuracy did not improve from 0.95993
# Epoch 14/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0098 - accuracy: 0.9968 - val_loss: 0.2212 - val_accuracy: 0.9616
#
# Epoch 00014: val_accuracy improved from 0.95993 to 0.96160, saving model to ./models/tree_11/model_root/folder9\model.h5
# Epoch 15/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0346 - accuracy: 0.9877 - val_loss: 0.1608 - val_accuracy: 0.9616
#
# Epoch 00015: val_accuracy did not improve from 0.96160
# Epoch 16/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0237 - accuracy: 0.9917 - val_loss: 0.1624 - val_accuracy: 0.9499
#
# Epoch 00016: val_accuracy did not improve from 0.96160
# Epoch 17/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0181 - accuracy: 0.9949 - val_loss: 0.1275 - val_accuracy: 0.9666
#
# Epoch 00017: val_accuracy improved from 0.96160 to 0.96661, saving model to ./models/tree_11/model_root/folder9\model.h5
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 18/30
# 263/263 [==============================] - 6s 22ms/step - loss: 0.0016 - accuracy: 0.9999 - val_loss: 0.1448 - val_accuracy: 0.9716
#
# Epoch 00018: val_accuracy improved from 0.96661 to 0.97162, saving model to ./models/tree_11/model_root/folder9\model.h5
# Epoch 19/30
# 263/263 [==============================] - 5s 21ms/step - loss: 2.5802e-04 - accuracy: 1.0000 - val_loss: 0.1782 - val_accuracy: 0.9699
#
# Epoch 00019: val_accuracy did not improve from 0.97162
# Epoch 20/30
# 263/263 [==============================] - 6s 22ms/step - loss: 1.4089e-04 - accuracy: 1.0000 - val_loss: 0.1816 - val_accuracy: 0.9716
#
# Epoch 00020: val_accuracy did not improve from 0.97162
# Epoch 21/30
# 263/263 [==============================] - 5s 19ms/step - loss: 1.0482e-04 - accuracy: 1.0000 - val_loss: 0.1833 - val_accuracy: 0.9716
#
# Epoch 00021: val_accuracy did not improve from 0.97162
# Epoch 22/30
# 263/263 [==============================] - 5s 20ms/step - loss: 8.2626e-05 - accuracy: 1.0000 - val_loss: 0.1844 - val_accuracy: 0.9716
#
# Epoch 00022: val_accuracy did not improve from 0.97162
# Epoch 23/30
# 263/263 [==============================] - 5s 19ms/step - loss: 6.8172e-05 - accuracy: 1.0000 - val_loss: 0.1870 - val_accuracy: 0.9716
#
# Epoch 00023: val_accuracy did not improve from 0.97162
# Epoch 24/30
# 263/263 [==============================] - 5s 19ms/step - loss: 5.6442e-05 - accuracy: 1.0000 - val_loss: 0.1933 - val_accuracy: 0.9716
#
# Epoch 00024: val_accuracy did not improve from 0.97162
# Epoch 25/30
# 263/263 [==============================] - 5s 20ms/step - loss: 4.6614e-05 - accuracy: 1.0000 - val_loss: 0.1939 - val_accuracy: 0.9716
#
# Epoch 00025: val_accuracy did not improve from 0.97162
# Epoch 26/30
# 263/263 [==============================] - 5s 19ms/step - loss: 3.9214e-05 - accuracy: 1.0000 - val_loss: 0.2005 - val_accuracy: 0.9733
#
# Epoch 00026: val_accuracy improved from 0.97162 to 0.97329, saving model to ./models/tree_11/model_root/folder9\model.h5
# Epoch 27/30
# 263/263 [==============================] - 5s 19ms/step - loss: 3.2754e-05 - accuracy: 1.0000 - val_loss: 0.2021 - val_accuracy: 0.9733
#
# Epoch 00027: val_accuracy did not improve from 0.97329
# Epoch 28/30
# 263/263 [==============================] - 5s 19ms/step - loss: 2.7548e-05 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9733
#
# Epoch 00028: val_accuracy did not improve from 0.97329
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 29/30
# 263/263 [==============================] - 5s 19ms/step - loss: 2.3379e-05 - accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9733
#
# Epoch 00029: val_accuracy did not improve from 0.97329
# Epoch 30/30
# 263/263 [==============================] - 5s 20ms/step - loss: 2.1261e-05 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9733
#
# Epoch 00030: val_accuracy did not improve from 0.97329
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 10
# Genre split [['Rock'], ['Blues', 'Classical', 'Country', 'Disco', 'Hip-Hop', 'Jazz', 'Metal', 'Pop', 'Reggae']]
# Building model...
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 263/263 [==============================] - 6s 20ms/step - loss: 0.3413 - accuracy: 0.8949 - val_loss: 0.3452 - val_accuracy: 0.8815
#
# Epoch 00001: val_accuracy improved from -inf to 0.88147, saving model to ./models/tree_11/model_root/folder10\model.h5
# Epoch 2/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.3097 - accuracy: 0.9012 - val_loss: 0.3340 - val_accuracy: 0.8815
#
# Epoch 00002: val_accuracy did not improve from 0.88147
# Epoch 3/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.3003 - accuracy: 0.9013 - val_loss: 0.4648 - val_accuracy: 0.8815
#
# Epoch 00003: val_accuracy did not improve from 0.88147
# Epoch 4/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.2944 - accuracy: 0.9011 - val_loss: 0.3195 - val_accuracy: 0.8815
#
# Epoch 00004: val_accuracy did not improve from 0.88147
# Epoch 5/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.2833 - accuracy: 0.9017 - val_loss: 0.3113 - val_accuracy: 0.8831
#
# Epoch 00005: val_accuracy improved from 0.88147 to 0.88314, saving model to ./models/tree_11/model_root/folder10\model.h5
# Epoch 6/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.2828 - accuracy: 0.9033 - val_loss: 0.3614 - val_accuracy: 0.8831
#
# Epoch 00006: val_accuracy did not improve from 0.88314
# Epoch 7/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.2695 - accuracy: 0.9023 - val_loss: 0.3124 - val_accuracy: 0.8831
#
# Epoch 00007: val_accuracy did not improve from 0.88314
# Epoch 8/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.2624 - accuracy: 0.9032 - val_loss: 0.3111 - val_accuracy: 0.8865
#
# Epoch 00008: val_accuracy improved from 0.88314 to 0.88648, saving model to ./models/tree_11/model_root/folder10\model.h5
# Epoch 9/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.2508 - accuracy: 0.9051 - val_loss: 0.3230 - val_accuracy: 0.8831
#
# Epoch 00009: val_accuracy did not improve from 0.88648
# Epoch 10/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.2381 - accuracy: 0.9088 - val_loss: 0.2776 - val_accuracy: 0.8831
#
# Epoch 00010: val_accuracy did not improve from 0.88648
# Epoch 11/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.2205 - accuracy: 0.9134 - val_loss: 0.2881 - val_accuracy: 0.8848
#
# Epoch 00011: val_accuracy did not improve from 0.88648
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 12/30
# 263/263 [==============================] - 5s 20ms/step - loss: 0.2002 - accuracy: 0.9209 - val_loss: 0.2542 - val_accuracy: 0.8915
#
# Epoch 00012: val_accuracy improved from 0.88648 to 0.89149, saving model to ./models/tree_11/model_root/folder10\model.h5
# Epoch 13/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1825 - accuracy: 0.9268 - val_loss: 0.2559 - val_accuracy: 0.8965
#
# Epoch 00013: val_accuracy improved from 0.89149 to 0.89649, saving model to ./models/tree_11/model_root/folder10\model.h5
# Epoch 14/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1687 - accuracy: 0.9315 - val_loss: 0.2648 - val_accuracy: 0.8948
#
# Epoch 00014: val_accuracy did not improve from 0.89649
# Epoch 15/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1583 - accuracy: 0.9381 - val_loss: 0.2666 - val_accuracy: 0.8998
#
# Epoch 00015: val_accuracy improved from 0.89649 to 0.89983, saving model to ./models/tree_11/model_root/folder10\model.h5
# Epoch 16/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1311 - accuracy: 0.9492 - val_loss: 0.2930 - val_accuracy: 0.9065
#
# Epoch 00016: val_accuracy improved from 0.89983 to 0.90651, saving model to ./models/tree_11/model_root/folder10\model.h5
# Epoch 17/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.1117 - accuracy: 0.9569 - val_loss: 0.2620 - val_accuracy: 0.9065
#
# Epoch 00017: val_accuracy did not improve from 0.90651
# Epoch 18/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0943 - accuracy: 0.9639 - val_loss: 0.2644 - val_accuracy: 0.9098
#
# Epoch 00018: val_accuracy improved from 0.90651 to 0.90985, saving model to ./models/tree_11/model_root/folder10\model.h5
# Epoch 19/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0719 - accuracy: 0.9721 - val_loss: 0.3245 - val_accuracy: 0.9032
#
# Epoch 00019: val_accuracy did not improve from 0.90985
# Epoch 20/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0534 - accuracy: 0.9824 - val_loss: 0.2999 - val_accuracy: 0.9065
#
# Epoch 00020: val_accuracy did not improve from 0.90985
# Epoch 21/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0419 - accuracy: 0.9875 - val_loss: 0.2985 - val_accuracy: 0.9115
#
# Epoch 00021: val_accuracy improved from 0.90985 to 0.91152, saving model to ./models/tree_11/model_root/folder10\model.h5
# Epoch 22/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0312 - accuracy: 0.9899 - val_loss: 0.3780 - val_accuracy: 0.9032
#
# Epoch 00022: val_accuracy did not improve from 0.91152
# Epoch 23/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0270 - accuracy: 0.9920 - val_loss: 0.3709 - val_accuracy: 0.9065
#
# Epoch 00023: val_accuracy did not improve from 0.91152
# Epoch 24/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0211 - accuracy: 0.9944 - val_loss: 0.4511 - val_accuracy: 0.9132
#
# Epoch 00024: val_accuracy improved from 0.91152 to 0.91319, saving model to ./models/tree_11/model_root/folder10\model.h5
# Epoch 25/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0130 - accuracy: 0.9973 - val_loss: 0.4547 - val_accuracy: 0.9065
#
# Epoch 00025: val_accuracy did not improve from 0.91319
# Epoch 26/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0118 - accuracy: 0.9974 - val_loss: 0.5225 - val_accuracy: 0.9065
#
# Epoch 00026: val_accuracy did not improve from 0.91319
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 27/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0084 - accuracy: 0.9985 - val_loss: 0.4562 - val_accuracy: 0.9032
#
# Epoch 00027: val_accuracy did not improve from 0.91319
# Epoch 28/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0080 - accuracy: 0.9983 - val_loss: 0.5284 - val_accuracy: 0.8998
#
# Epoch 00028: val_accuracy did not improve from 0.91319
# Epoch 29/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0055 - accuracy: 0.9987 - val_loss: 0.4237 - val_accuracy: 0.9082
#
# Epoch 00029: val_accuracy did not improve from 0.91319
# Epoch 30/30
# 263/263 [==============================] - 5s 19ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.5019 - val_accuracy: 0.9048
#
# Epoch 00030: val_accuracy did not improve from 0.91319
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
