# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7}
dict_genres = {'Experimental':1, 'International' :5}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {1: 'Experimental', 5: 'International'}

# %%
npzfile = np.load('data/shuffled_train.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394,)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=8).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((1599, 640, 128), (1599, 8))

# %%
npzfile = np.load('data/shuffled_valid.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=8).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((200, 640, 128), (200, 8))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Experimental

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

BATCH_SIZE = 64
EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 640
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = ".\\logs\\model_root_f2_2\\"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/model_root_f2_2/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
def create_split(elem, c):
    splits = []
    for i in range(c):
        equal = False
        np.random.shuffle(elem)
        new_split = list(chunks(elem, int(len(elem)/2)))
        for split in splits:
            if set(new_split[0]) == set(split[0]) and set(new_split[0]) == set(split[1]):
                equal = True
                break
            
        if equal:
            i-=1
            continue
        
        splits.append(new_split)
        
    return splits

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 4

kfold = KFold(n_splits=4, shuffle=True)
genre_splits = create_split(list(dict_genres.values()), num_splits)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)

    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['International'], ['Experimental']]
# Building model...
# Training...
# Epoch 1/30
# 22/22 [==============================] - 16s 196ms/step - loss: 2.5687 - accuracy: 0.5456 - val_loss: 0.8117 - val_accuracy: 0.4711
#
# Epoch 00001: val_accuracy improved from -inf to 0.47111, saving model to ./models/model_root_f2_2/folder1\model.h5
# Epoch 2/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.6903 - accuracy: 0.5760 - val_loss: 0.6297 - val_accuracy: 0.6044
#
# Epoch 00002: val_accuracy improved from 0.47111 to 0.60444, saving model to ./models/model_root_f2_2/folder1\model.h5
# Epoch 3/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.6050 - accuracy: 0.6738 - val_loss: 1.6109 - val_accuracy: 0.4733
#
# Epoch 00003: val_accuracy did not improve from 0.60444
# Epoch 4/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.6919 - accuracy: 0.5990 - val_loss: 0.6001 - val_accuracy: 0.7067
#
# Epoch 00004: val_accuracy improved from 0.60444 to 0.70667, saving model to ./models/model_root_f2_2/folder1\model.h5
# Epoch 5/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.5987 - accuracy: 0.7042 - val_loss: 0.6250 - val_accuracy: 0.6422
#
# Epoch 00005: val_accuracy did not improve from 0.70667
# Epoch 6/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.5090 - accuracy: 0.7798 - val_loss: 1.6145 - val_accuracy: 0.5289
#
# Epoch 00006: val_accuracy did not improve from 0.70667
# Epoch 7/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.7308 - accuracy: 0.6294 - val_loss: 0.6144 - val_accuracy: 0.6311
#
# Epoch 00007: val_accuracy did not improve from 0.70667
# Epoch 8/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.5588 - accuracy: 0.7302 - val_loss: 0.5629 - val_accuracy: 0.7156
#
# Epoch 00008: val_accuracy improved from 0.70667 to 0.71556, saving model to ./models/model_root_f2_2/folder1\model.h5
# Epoch 9/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.5138 - accuracy: 0.7546 - val_loss: 0.5230 - val_accuracy: 0.7622
#
# Epoch 00009: val_accuracy improved from 0.71556 to 0.76222, saving model to ./models/model_root_f2_2/folder1\model.h5
# Epoch 10/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.5119 - accuracy: 0.7554 - val_loss: 0.4953 - val_accuracy: 0.7733
#
# Epoch 00010: val_accuracy improved from 0.76222 to 0.77333, saving model to ./models/model_root_f2_2/folder1\model.h5
# Epoch 11/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.5413 - accuracy: 0.7183 - val_loss: 0.5974 - val_accuracy: 0.6689
#
# Epoch 00011: val_accuracy did not improve from 0.77333
# Epoch 12/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.5006 - accuracy: 0.7732 - val_loss: 0.4991 - val_accuracy: 0.7622
#
# Epoch 00012: val_accuracy did not improve from 0.77333
# Epoch 13/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.4950 - accuracy: 0.7695 - val_loss: 0.6649 - val_accuracy: 0.6867
#
# Epoch 00013: val_accuracy did not improve from 0.77333
# Epoch 14/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.5412 - accuracy: 0.7294 - val_loss: 0.7802 - val_accuracy: 0.6156
#
# Epoch 00014: val_accuracy did not improve from 0.77333
# Epoch 15/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.4937 - accuracy: 0.7709 - val_loss: 0.4990 - val_accuracy: 0.7578
#
# Epoch 00015: val_accuracy did not improve from 0.77333
# Epoch 16/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.4803 - accuracy: 0.7739 - val_loss: 0.5289 - val_accuracy: 0.7378
#
# Epoch 00016: val_accuracy did not improve from 0.77333
# Epoch 17/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.4602 - accuracy: 0.7902 - val_loss: 0.4884 - val_accuracy: 0.7756
#
# Epoch 00017: val_accuracy improved from 0.77333 to 0.77556, saving model to ./models/model_root_f2_2/folder1\model.h5
# Epoch 18/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.4815 - accuracy: 0.7872 - val_loss: 0.6384 - val_accuracy: 0.7089
#
# Epoch 00018: val_accuracy did not improve from 0.77556
# Epoch 19/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.5293 - accuracy: 0.7472 - val_loss: 0.5047 - val_accuracy: 0.7756
#
# Epoch 00019: val_accuracy did not improve from 0.77556
# Epoch 20/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.4433 - accuracy: 0.8028 - val_loss: 0.5381 - val_accuracy: 0.7578
#
# Epoch 00020: val_accuracy did not improve from 0.77556
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/30
# 22/22 [==============================] - 4s 162ms/step - loss: 0.4099 - accuracy: 0.8139 - val_loss: 0.5196 - val_accuracy: 0.7556
#
# Epoch 00021: val_accuracy did not improve from 0.77556
# Epoch 22/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.4204 - accuracy: 0.8132 - val_loss: 0.4585 - val_accuracy: 0.7956
#
# Epoch 00022: val_accuracy improved from 0.77556 to 0.79556, saving model to ./models/model_root_f2_2/folder1\model.h5
# Epoch 23/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.3872 - accuracy: 0.8288 - val_loss: 0.4599 - val_accuracy: 0.8089
#
# Epoch 00023: val_accuracy improved from 0.79556 to 0.80889, saving model to ./models/model_root_f2_2/folder1\model.h5
# Epoch 24/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.3618 - accuracy: 0.8354 - val_loss: 0.4558 - val_accuracy: 0.7911
#
# Epoch 00024: val_accuracy did not improve from 0.80889
# Epoch 25/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.3689 - accuracy: 0.8302 - val_loss: 0.4688 - val_accuracy: 0.7822
#
# Epoch 00025: val_accuracy did not improve from 0.80889
# Epoch 26/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.3496 - accuracy: 0.8466 - val_loss: 0.5090 - val_accuracy: 0.7756
#
# Epoch 00026: val_accuracy did not improve from 0.80889
# Epoch 27/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.3170 - accuracy: 0.8599 - val_loss: 0.5489 - val_accuracy: 0.7467
#
# Epoch 00027: val_accuracy did not improve from 0.80889
# Epoch 28/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.3155 - accuracy: 0.8629 - val_loss: 0.5266 - val_accuracy: 0.7822
#
# Epoch 00028: val_accuracy did not improve from 0.80889
# Epoch 29/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.3063 - accuracy: 0.8636 - val_loss: 0.4736 - val_accuracy: 0.8022
#
# Epoch 00029: val_accuracy did not improve from 0.80889
# Epoch 30/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.2865 - accuracy: 0.8799 - val_loss: 0.5164 - val_accuracy: 0.7689
#
# Epoch 00030: val_accuracy did not improve from 0.80889
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['International'], ['Experimental']]
# Building model...
# Training...
# Epoch 1/30
# 22/22 [==============================] - 4s 161ms/step - loss: 3.4567 - accuracy: 0.5100 - val_loss: 0.6724 - val_accuracy: 0.6822
#
# Epoch 00001: val_accuracy improved from -inf to 0.68222, saving model to ./models/model_root_f2_2/folder2\model.h5
# Epoch 2/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.6849 - accuracy: 0.6027 - val_loss: 0.9705 - val_accuracy: 0.4756
#
# Epoch 00002: val_accuracy did not improve from 0.68222
# Epoch 3/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.6967 - accuracy: 0.5686 - val_loss: 0.6560 - val_accuracy: 0.6533
#
# Epoch 00003: val_accuracy did not improve from 0.68222
# Epoch 4/30
# 22/22 [==============================] - 3s 155ms/step - loss: 0.6069 - accuracy: 0.6953 - val_loss: 0.6247 - val_accuracy: 0.6422
#
# Epoch 00004: val_accuracy did not improve from 0.68222
# Epoch 5/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.6335 - accuracy: 0.6457 - val_loss: 0.6696 - val_accuracy: 0.5267
#
# Epoch 00005: val_accuracy did not improve from 0.68222
# Epoch 6/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.6448 - accuracy: 0.6308 - val_loss: 0.5429 - val_accuracy: 0.7511
#
# Epoch 00006: val_accuracy improved from 0.68222 to 0.75111, saving model to ./models/model_root_f2_2/folder2\model.h5
# Epoch 7/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.5934 - accuracy: 0.6827 - val_loss: 0.6502 - val_accuracy: 0.5600
#
# Epoch 00007: val_accuracy did not improve from 0.75111
# Epoch 8/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.5843 - accuracy: 0.6953 - val_loss: 0.7361 - val_accuracy: 0.6533
#
# Epoch 00008: val_accuracy did not improve from 0.75111
# Epoch 9/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.5555 - accuracy: 0.7235 - val_loss: 0.5690 - val_accuracy: 0.7089
#
# Epoch 00009: val_accuracy did not improve from 0.75111
# Epoch 10/30
# 22/22 [==============================] - 3s 147ms/step - loss: 0.5382 - accuracy: 0.7405 - val_loss: 0.8988 - val_accuracy: 0.5644
#
# Epoch 00010: val_accuracy did not improve from 0.75111
# Epoch 11/30
# 22/22 [==============================] - 3s 147ms/step - loss: 0.5270 - accuracy: 0.7309 - val_loss: 0.5215 - val_accuracy: 0.7378
#
# Epoch 00011: val_accuracy did not improve from 0.75111
# Epoch 12/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.5017 - accuracy: 0.7546 - val_loss: 0.5260 - val_accuracy: 0.7111
#
# Epoch 00012: val_accuracy did not improve from 0.75111
# Epoch 13/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.4619 - accuracy: 0.7961 - val_loss: 0.4996 - val_accuracy: 0.7756
#
# Epoch 00013: val_accuracy improved from 0.75111 to 0.77556, saving model to ./models/model_root_f2_2/folder2\model.h5
# Epoch 14/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.4386 - accuracy: 0.8050 - val_loss: 0.6574 - val_accuracy: 0.6733
#
# Epoch 00014: val_accuracy did not improve from 0.77556
# Epoch 15/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.4456 - accuracy: 0.7887 - val_loss: 0.6342 - val_accuracy: 0.6311
#
# Epoch 00015: val_accuracy did not improve from 0.77556
# Epoch 16/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.4876 - accuracy: 0.7517 - val_loss: 0.6038 - val_accuracy: 0.6867
#
# Epoch 00016: val_accuracy did not improve from 0.77556
# Epoch 17/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.4389 - accuracy: 0.7887 - val_loss: 0.6204 - val_accuracy: 0.6978
#
# Epoch 00017: val_accuracy did not improve from 0.77556
# Epoch 18/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.4032 - accuracy: 0.8184 - val_loss: 0.5232 - val_accuracy: 0.7467
#
# Epoch 00018: val_accuracy did not improve from 0.77556
# Epoch 19/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.3721 - accuracy: 0.8228 - val_loss: 0.4794 - val_accuracy: 0.7733
#
# Epoch 00019: val_accuracy did not improve from 0.77556
# Epoch 20/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.3287 - accuracy: 0.8599 - val_loss: 0.6987 - val_accuracy: 0.7200
#
# Epoch 00020: val_accuracy did not improve from 0.77556
# Epoch 21/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.3118 - accuracy: 0.8577 - val_loss: 0.5908 - val_accuracy: 0.7356
#
# Epoch 00021: val_accuracy did not improve from 0.77556
# Epoch 22/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.3013 - accuracy: 0.8666 - val_loss: 0.9203 - val_accuracy: 0.6756
#
# Epoch 00022: val_accuracy did not improve from 0.77556
# Epoch 23/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.3154 - accuracy: 0.8636 - val_loss: 0.6978 - val_accuracy: 0.7489
#
# Epoch 00023: val_accuracy did not improve from 0.77556
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 24/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.2271 - accuracy: 0.9051 - val_loss: 0.7136 - val_accuracy: 0.7356
#
# Epoch 00024: val_accuracy did not improve from 0.77556
# Epoch 25/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.1989 - accuracy: 0.9281 - val_loss: 0.7213 - val_accuracy: 0.7511
#
# Epoch 00025: val_accuracy did not improve from 0.77556
# Epoch 26/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1496 - accuracy: 0.9414 - val_loss: 0.6912 - val_accuracy: 0.7578
#
# Epoch 00026: val_accuracy did not improve from 0.77556
# Epoch 27/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.1282 - accuracy: 0.9563 - val_loss: 0.7785 - val_accuracy: 0.7644
#
# Epoch 00027: val_accuracy did not improve from 0.77556
# Epoch 28/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.1084 - accuracy: 0.9652 - val_loss: 0.8075 - val_accuracy: 0.7489
#
# Epoch 00028: val_accuracy did not improve from 0.77556
# Epoch 29/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.0971 - accuracy: 0.9689 - val_loss: 0.8886 - val_accuracy: 0.7644
#
# Epoch 00029: val_accuracy did not improve from 0.77556
# Epoch 30/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.0713 - accuracy: 0.9822 - val_loss: 0.8291 - val_accuracy: 0.7600
#
# Epoch 00030: val_accuracy did not improve from 0.77556
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Experimental'], ['International']]
# Building model...
# Training...
# Epoch 1/30
# 22/22 [==============================] - 4s 162ms/step - loss: 2.2621 - accuracy: 0.5656 - val_loss: 0.7607 - val_accuracy: 0.5489
#
# Epoch 00001: val_accuracy improved from -inf to 0.54889, saving model to ./models/model_root_f2_2/folder3\model.h5
# Epoch 2/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.5632 - accuracy: 0.7317 - val_loss: 0.7572 - val_accuracy: 0.6044
#
# Epoch 00002: val_accuracy improved from 0.54889 to 0.60444, saving model to ./models/model_root_f2_2/folder3\model.h5
# Epoch 3/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.5395 - accuracy: 0.7361 - val_loss: 0.5863 - val_accuracy: 0.7044
#
# Epoch 00003: val_accuracy improved from 0.60444 to 0.70444, saving model to ./models/model_root_f2_2/folder3\model.h5
# Epoch 4/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.5291 - accuracy: 0.7435 - val_loss: 0.6178 - val_accuracy: 0.6578
#
# Epoch 00004: val_accuracy did not improve from 0.70444
# Epoch 5/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.5335 - accuracy: 0.7391 - val_loss: 0.5130 - val_accuracy: 0.7400
#
# Epoch 00005: val_accuracy improved from 0.70444 to 0.74000, saving model to ./models/model_root_f2_2/folder3\model.h5
# Epoch 6/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.4864 - accuracy: 0.7717 - val_loss: 0.5694 - val_accuracy: 0.7000
#
# Epoch 00006: val_accuracy did not improve from 0.74000
# Epoch 7/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.4985 - accuracy: 0.7539 - val_loss: 0.5844 - val_accuracy: 0.7244
#
# Epoch 00007: val_accuracy did not improve from 0.74000
# Epoch 8/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.5405 - accuracy: 0.7398 - val_loss: 0.4720 - val_accuracy: 0.8000
#
# Epoch 00008: val_accuracy improved from 0.74000 to 0.80000, saving model to ./models/model_root_f2_2/folder3\model.h5
# Epoch 9/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.4548 - accuracy: 0.8006 - val_loss: 0.4627 - val_accuracy: 0.8022
#
# Epoch 00009: val_accuracy improved from 0.80000 to 0.80222, saving model to ./models/model_root_f2_2/folder3\model.h5
# Epoch 10/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.4644 - accuracy: 0.7769 - val_loss: 0.4565 - val_accuracy: 0.7889
#
# Epoch 00010: val_accuracy did not improve from 0.80222
# Epoch 11/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.4580 - accuracy: 0.7806 - val_loss: 0.6179 - val_accuracy: 0.7111
#
# Epoch 00011: val_accuracy did not improve from 0.80222
# Epoch 12/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.4475 - accuracy: 0.8006 - val_loss: 0.4246 - val_accuracy: 0.8133
#
# Epoch 00012: val_accuracy improved from 0.80222 to 0.81333, saving model to ./models/model_root_f2_2/folder3\model.h5
# Epoch 13/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.3893 - accuracy: 0.8280 - val_loss: 0.4199 - val_accuracy: 0.8156
#
# Epoch 00013: val_accuracy improved from 0.81333 to 0.81556, saving model to ./models/model_root_f2_2/folder3\model.h5
# Epoch 14/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.4179 - accuracy: 0.8065 - val_loss: 0.4099 - val_accuracy: 0.8089
#
# Epoch 00014: val_accuracy did not improve from 0.81556
# Epoch 15/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.3634 - accuracy: 0.8317 - val_loss: 0.4251 - val_accuracy: 0.8133
#
# Epoch 00015: val_accuracy did not improve from 0.81556
# Epoch 16/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.3577 - accuracy: 0.8466 - val_loss: 0.4738 - val_accuracy: 0.7800
#
# Epoch 00016: val_accuracy did not improve from 0.81556
# Epoch 17/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.3324 - accuracy: 0.8614 - val_loss: 0.5611 - val_accuracy: 0.7689
#
# Epoch 00017: val_accuracy did not improve from 0.81556
# Epoch 18/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.3447 - accuracy: 0.8547 - val_loss: 0.5497 - val_accuracy: 0.7644
#
# Epoch 00018: val_accuracy did not improve from 0.81556
# Epoch 19/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.2953 - accuracy: 0.8762 - val_loss: 0.5156 - val_accuracy: 0.8000
#
# Epoch 00019: val_accuracy did not improve from 0.81556
# Epoch 20/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.2697 - accuracy: 0.8777 - val_loss: 0.4752 - val_accuracy: 0.7956
#
# Epoch 00020: val_accuracy did not improve from 0.81556
# Epoch 21/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.2430 - accuracy: 0.9059 - val_loss: 0.5772 - val_accuracy: 0.7867
#
# Epoch 00021: val_accuracy did not improve from 0.81556
# Epoch 22/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.2057 - accuracy: 0.9133 - val_loss: 0.6080 - val_accuracy: 0.7889
#
# Epoch 00022: val_accuracy did not improve from 0.81556
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 23/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1482 - accuracy: 0.9489 - val_loss: 0.5670 - val_accuracy: 0.7956
#
# Epoch 00023: val_accuracy did not improve from 0.81556
# Epoch 24/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1282 - accuracy: 0.9570 - val_loss: 0.5664 - val_accuracy: 0.8156
#
# Epoch 00024: val_accuracy did not improve from 0.81556
# Epoch 25/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.1124 - accuracy: 0.9607 - val_loss: 0.7741 - val_accuracy: 0.7644
#
# Epoch 00025: val_accuracy did not improve from 0.81556
# Epoch 26/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.0975 - accuracy: 0.9666 - val_loss: 0.6529 - val_accuracy: 0.8133
#
# Epoch 00026: val_accuracy did not improve from 0.81556
# Epoch 27/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.0650 - accuracy: 0.9807 - val_loss: 0.7187 - val_accuracy: 0.8133
#
# Epoch 00027: val_accuracy did not improve from 0.81556
# Epoch 28/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.0535 - accuracy: 0.9867 - val_loss: 0.7843 - val_accuracy: 0.7956
#
# Epoch 00028: val_accuracy did not improve from 0.81556
# Epoch 29/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.0494 - accuracy: 0.9881 - val_loss: 0.7856 - val_accuracy: 0.7956
#
# Epoch 00029: val_accuracy did not improve from 0.81556
# Epoch 30/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.0309 - accuracy: 0.9948 - val_loss: 0.8881 - val_accuracy: 0.8000
#
# Epoch 00030: val_accuracy did not improve from 0.81556
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['International'], ['Experimental']]
# Building model...
# Training...
# Epoch 1/30
# 22/22 [==============================] - 4s 186ms/step - loss: 2.8170 - accuracy: 0.4733 - val_loss: 0.6915 - val_accuracy: 0.4855
#
# Epoch 00001: val_accuracy improved from -inf to 0.48552, saving model to ./models/model_root_f2_2/folder4\model.h5
# Epoch 2/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.6846 - accuracy: 0.5622 - val_loss: 0.6275 - val_accuracy: 0.5947
#
# Epoch 00002: val_accuracy improved from 0.48552 to 0.59465, saving model to ./models/model_root_f2_2/folder4\model.h5
# Epoch 3/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.6645 - accuracy: 0.6111 - val_loss: 0.7187 - val_accuracy: 0.4833
#
# Epoch 00003: val_accuracy did not improve from 0.59465
# Epoch 4/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.6688 - accuracy: 0.5889 - val_loss: 0.6226 - val_accuracy: 0.7149
#
# Epoch 00004: val_accuracy improved from 0.59465 to 0.71492, saving model to ./models/model_root_f2_2/folder4\model.h5
# Epoch 5/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.6242 - accuracy: 0.6778 - val_loss: 0.7890 - val_accuracy: 0.5457
#
# Epoch 00005: val_accuracy did not improve from 0.71492
# Epoch 6/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.6921 - accuracy: 0.5481 - val_loss: 0.5228 - val_accuracy: 0.7483
#
# Epoch 00006: val_accuracy improved from 0.71492 to 0.74833, saving model to ./models/model_root_f2_2/folder4\model.h5
# Epoch 7/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.6751 - accuracy: 0.6207 - val_loss: 0.6880 - val_accuracy: 0.5301
#
# Epoch 00007: val_accuracy did not improve from 0.74833
# Epoch 8/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.6856 - accuracy: 0.6311 - val_loss: 0.5346 - val_accuracy: 0.7684
#
# Epoch 00008: val_accuracy improved from 0.74833 to 0.76837, saving model to ./models/model_root_f2_2/folder4\model.h5
# Epoch 9/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.6239 - accuracy: 0.6948 - val_loss: 0.5381 - val_accuracy: 0.7862
#
# Epoch 00009: val_accuracy improved from 0.76837 to 0.78619, saving model to ./models/model_root_f2_2/folder4\model.h5
# Epoch 10/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.5719 - accuracy: 0.6993 - val_loss: 0.5157 - val_accuracy: 0.7394
#
# Epoch 00010: val_accuracy did not improve from 0.78619
# Epoch 11/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.5465 - accuracy: 0.7230 - val_loss: 0.5420 - val_accuracy: 0.7149
#
# Epoch 00011: val_accuracy did not improve from 0.78619
# Epoch 12/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.4987 - accuracy: 0.7637 - val_loss: 0.6823 - val_accuracy: 0.6481
#
# Epoch 00012: val_accuracy did not improve from 0.78619
# Epoch 13/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.5011 - accuracy: 0.7563 - val_loss: 0.5076 - val_accuracy: 0.7595
#
# Epoch 00013: val_accuracy did not improve from 0.78619
# Epoch 14/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.4608 - accuracy: 0.7911 - val_loss: 0.4098 - val_accuracy: 0.8196
#
# Epoch 00014: val_accuracy improved from 0.78619 to 0.81960, saving model to ./models/model_root_f2_2/folder4\model.h5
# Epoch 15/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.4391 - accuracy: 0.8022 - val_loss: 0.4764 - val_accuracy: 0.8018
#
# Epoch 00015: val_accuracy did not improve from 0.81960
# Epoch 16/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.4870 - accuracy: 0.7644 - val_loss: 0.4109 - val_accuracy: 0.8129
#
# Epoch 00016: val_accuracy did not improve from 0.81960
# Epoch 17/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.4401 - accuracy: 0.7911 - val_loss: 0.4016 - val_accuracy: 0.8174
#
# Epoch 00017: val_accuracy did not improve from 0.81960
# Epoch 18/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.4285 - accuracy: 0.8000 - val_loss: 0.4078 - val_accuracy: 0.8307
#
# Epoch 00018: val_accuracy improved from 0.81960 to 0.83073, saving model to ./models/model_root_f2_2/folder4\model.h5
# Epoch 19/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.4354 - accuracy: 0.8015 - val_loss: 0.4183 - val_accuracy: 0.8107
#
# Epoch 00019: val_accuracy did not improve from 0.83073
# Epoch 20/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.3959 - accuracy: 0.8244 - val_loss: 0.4089 - val_accuracy: 0.8263
#
# Epoch 00020: val_accuracy did not improve from 0.83073
# Epoch 21/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.3474 - accuracy: 0.8511 - val_loss: 0.4333 - val_accuracy: 0.8151
#
# Epoch 00021: val_accuracy did not improve from 0.83073
# Epoch 22/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.3564 - accuracy: 0.8444 - val_loss: 0.4370 - val_accuracy: 0.8107
#
# Epoch 00022: val_accuracy did not improve from 0.83073
# Epoch 23/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.3420 - accuracy: 0.8496 - val_loss: 0.4498 - val_accuracy: 0.7929
#
# Epoch 00023: val_accuracy did not improve from 0.83073
# Epoch 24/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.2932 - accuracy: 0.8733 - val_loss: 0.4314 - val_accuracy: 0.8174
#
# Epoch 00024: val_accuracy did not improve from 0.83073
# Epoch 25/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.2849 - accuracy: 0.8822 - val_loss: 0.5413 - val_accuracy: 0.8018
#
# Epoch 00025: val_accuracy did not improve from 0.83073
# Epoch 26/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.2383 - accuracy: 0.8867 - val_loss: 0.4900 - val_accuracy: 0.8129
#
# Epoch 00026: val_accuracy did not improve from 0.83073
# Epoch 27/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.2153 - accuracy: 0.9163 - val_loss: 0.5450 - val_accuracy: 0.8196
#
# Epoch 00027: val_accuracy did not improve from 0.83073
# Epoch 28/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.1831 - accuracy: 0.9274 - val_loss: 0.7084 - val_accuracy: 0.7439
#
# Epoch 00028: val_accuracy did not improve from 0.83073
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 29/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.1473 - accuracy: 0.9393 - val_loss: 0.5605 - val_accuracy: 0.7973
#
# Epoch 00029: val_accuracy did not improve from 0.83073
# Epoch 30/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1352 - accuracy: 0.9489 - val_loss: 0.5521 - val_accuracy: 0.8174
#
# Epoch 00030: val_accuracy did not improve from 0.83073
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
