# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Blues':0, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Pop':7, 'Reggae':8, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Blues', 2: 'Country', 3: 'Disco', 4: 'Hip-Hop', 7: 'Pop', 8: 'Reggae', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((5600, 128, 128), (5600, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((700, 128, 128), (700, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Disco

# %% [markdown]
# ## Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation='softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_11/model_root_f1_1_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_11/model_root_f1_1_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 7
n_splits = 15

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    dict_genres_list = list(dict_genres.values())
    split = [[dict_genres_list.pop(fold_no - 1)], dict_genres_list]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Blues'], ['Country', 'Disco', 'Hip-Hop', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 184/184 [==============================] - 8s 22ms/step - loss: 0.4478 - accuracy: 0.8531 - val_loss: 0.3868 - val_accuracy: 0.8524
#
# Epoch 00001: val_accuracy improved from -inf to 0.85238, saving model to ./models/tree_11/model_root_f1_1_1/folder1\model.h5
# Epoch 2/30
# 184/184 [==============================] - 4s 19ms/step - loss: 0.3302 - accuracy: 0.8690 - val_loss: 0.3487 - val_accuracy: 0.8381
#
# Epoch 00002: val_accuracy did not improve from 0.85238
# Epoch 3/30
# 184/184 [==============================] - 4s 22ms/step - loss: 0.2683 - accuracy: 0.8871 - val_loss: 0.2784 - val_accuracy: 0.8881
#
# Epoch 00003: val_accuracy improved from 0.85238 to 0.88810, saving model to ./models/tree_11/model_root_f1_1_1/folder1\model.h5
# Epoch 4/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.2338 - accuracy: 0.8993 - val_loss: 0.2525 - val_accuracy: 0.8738
#
# Epoch 00004: val_accuracy did not improve from 0.88810
# Epoch 5/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.2099 - accuracy: 0.9105 - val_loss: 0.2336 - val_accuracy: 0.9024
#
# Epoch 00005: val_accuracy improved from 0.88810 to 0.90238, saving model to ./models/tree_11/model_root_f1_1_1/folder1\model.h5
# Epoch 6/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.1700 - accuracy: 0.9264 - val_loss: 0.2098 - val_accuracy: 0.9381
#
# Epoch 00006: val_accuracy improved from 0.90238 to 0.93810, saving model to ./models/tree_11/model_root_f1_1_1/folder1\model.h5
# Epoch 7/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.1516 - accuracy: 0.9357 - val_loss: 0.1880 - val_accuracy: 0.9238
#
# Epoch 00007: val_accuracy did not improve from 0.93810
# Epoch 8/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.1203 - accuracy: 0.9490 - val_loss: 0.1757 - val_accuracy: 0.9452
#
# Epoch 00008: val_accuracy improved from 0.93810 to 0.94524, saving model to ./models/tree_11/model_root_f1_1_1/folder1\model.h5
# Epoch 9/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0975 - accuracy: 0.9605 - val_loss: 0.1615 - val_accuracy: 0.9357
#
# Epoch 00009: val_accuracy did not improve from 0.94524
# Epoch 10/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.0873 - accuracy: 0.9645 - val_loss: 0.1450 - val_accuracy: 0.9548
#
# Epoch 00010: val_accuracy improved from 0.94524 to 0.95476, saving model to ./models/tree_11/model_root_f1_1_1/folder1\model.h5
# Epoch 11/30
# 184/184 [==============================] - 4s 19ms/step - loss: 0.0650 - accuracy: 0.9753 - val_loss: 0.2246 - val_accuracy: 0.9333
#
# Epoch 00011: val_accuracy did not improve from 0.95476
# Epoch 12/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.0481 - accuracy: 0.9844 - val_loss: 0.1483 - val_accuracy: 0.9571
#
# Epoch 00012: val_accuracy improved from 0.95476 to 0.95714, saving model to ./models/tree_11/model_root_f1_1_1/folder1\model.h5
# Epoch 13/30
# 184/184 [==============================] - 4s 19ms/step - loss: 0.0439 - accuracy: 0.9837 - val_loss: 0.2009 - val_accuracy: 0.9357
#
# Epoch 00013: val_accuracy did not improve from 0.95714
# Epoch 14/30
# 184/184 [==============================] - 4s 19ms/step - loss: 0.0294 - accuracy: 0.9888 - val_loss: 0.1470 - val_accuracy: 0.9571
#
# Epoch 00014: val_accuracy did not improve from 0.95714
# Epoch 15/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0345 - accuracy: 0.9871 - val_loss: 0.2095 - val_accuracy: 0.9476
#
# Epoch 00015: val_accuracy did not improve from 0.95714
# Epoch 16/30
# 184/184 [==============================] - 4s 21ms/step - loss: 0.0226 - accuracy: 0.9910 - val_loss: 0.2309 - val_accuracy: 0.9500
#
# Epoch 00016: val_accuracy did not improve from 0.95714
# Epoch 17/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0158 - accuracy: 0.9940 - val_loss: 0.1893 - val_accuracy: 0.9571
#
# Epoch 00017: val_accuracy did not improve from 0.95714
# Epoch 18/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0169 - accuracy: 0.9934 - val_loss: 0.2178 - val_accuracy: 0.9333
#
# Epoch 00018: val_accuracy did not improve from 0.95714
# Epoch 19/30
# 184/184 [==============================] - 4s 21ms/step - loss: 0.0441 - accuracy: 0.9823 - val_loss: 0.1484 - val_accuracy: 0.9571
#
# Epoch 00019: val_accuracy did not improve from 0.95714
# Epoch 20/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0309 - accuracy: 0.9881 - val_loss: 0.2257 - val_accuracy: 0.9548
#
# Epoch 00020: val_accuracy did not improve from 0.95714
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1770 - val_accuracy: 0.9595
#
# Epoch 00021: val_accuracy improved from 0.95714 to 0.95952, saving model to ./models/tree_11/model_root_f1_1_1/folder1\model.h5
# Epoch 22/30
# 184/184 [==============================] - 4s 19ms/step - loss: 6.5512e-04 - accuracy: 1.0000 - val_loss: 0.2186 - val_accuracy: 0.9524
#
# Epoch 00022: val_accuracy did not improve from 0.95952
# Epoch 23/30
# 184/184 [==============================] - 4s 20ms/step - loss: 4.3082e-04 - accuracy: 1.0000 - val_loss: 0.2144 - val_accuracy: 0.9524
#
# Epoch 00023: val_accuracy did not improve from 0.95952
# Epoch 24/30
# 184/184 [==============================] - 3s 19ms/step - loss: 3.1912e-04 - accuracy: 1.0000 - val_loss: 0.2223 - val_accuracy: 0.9524
#
# Epoch 00024: val_accuracy did not improve from 0.95952
# Epoch 25/30
# 184/184 [==============================] - 3s 19ms/step - loss: 2.5510e-04 - accuracy: 1.0000 - val_loss: 0.2292 - val_accuracy: 0.9524
#
# Epoch 00025: val_accuracy did not improve from 0.95952
# Epoch 26/30
# 184/184 [==============================] - 3s 19ms/step - loss: 2.1134e-04 - accuracy: 1.0000 - val_loss: 0.2299 - val_accuracy: 0.9524
#
# Epoch 00026: val_accuracy did not improve from 0.95952
# Epoch 27/30
# 184/184 [==============================] - 3s 19ms/step - loss: 1.7861e-04 - accuracy: 1.0000 - val_loss: 0.2387 - val_accuracy: 0.9524
#
# Epoch 00027: val_accuracy did not improve from 0.95952
# Epoch 28/30
# 184/184 [==============================] - 4s 20ms/step - loss: 1.5344e-04 - accuracy: 1.0000 - val_loss: 0.2883 - val_accuracy: 0.9524
#
# Epoch 00028: val_accuracy did not improve from 0.95952
# Epoch 29/30
# 184/184 [==============================] - 3s 19ms/step - loss: 1.3176e-04 - accuracy: 1.0000 - val_loss: 0.2383 - val_accuracy: 0.9500
#
# Epoch 00029: val_accuracy did not improve from 0.95952
# Epoch 30/30
# 184/184 [==============================] - 4s 20ms/step - loss: 1.1310e-04 - accuracy: 1.0000 - val_loss: 0.2530 - val_accuracy: 0.9524
#
# Epoch 00030: val_accuracy did not improve from 0.95952
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Country'], ['Blues', 'Disco', 'Hip-Hop', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 184/184 [==============================] - 4s 21ms/step - loss: 0.4215 - accuracy: 0.8514 - val_loss: 0.2647 - val_accuracy: 0.8810
#
# Epoch 00001: val_accuracy improved from -inf to 0.88095, saving model to ./models/tree_11/model_root_f1_1_1/folder2\model.h5
# Epoch 2/30
# 184/184 [==============================] - 4s 19ms/step - loss: 0.2889 - accuracy: 0.8673 - val_loss: 0.2853 - val_accuracy: 0.8857
#
# Epoch 00002: val_accuracy improved from 0.88095 to 0.88571, saving model to ./models/tree_11/model_root_f1_1_1/folder2\model.h5
# Epoch 3/30
# 184/184 [==============================] - 4s 19ms/step - loss: 0.2587 - accuracy: 0.8818 - val_loss: 0.2550 - val_accuracy: 0.8833
#
# Epoch 00003: val_accuracy did not improve from 0.88571
# Epoch 4/30
# 184/184 [==============================] - 4s 19ms/step - loss: 0.2425 - accuracy: 0.8891 - val_loss: 0.1917 - val_accuracy: 0.9095
#
# Epoch 00004: val_accuracy improved from 0.88571 to 0.90952, saving model to ./models/tree_11/model_root_f1_1_1/folder2\model.h5
# Epoch 5/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.2298 - accuracy: 0.8949 - val_loss: 0.2016 - val_accuracy: 0.9214
#
# Epoch 00005: val_accuracy improved from 0.90952 to 0.92143, saving model to ./models/tree_11/model_root_f1_1_1/folder2\model.h5
# Epoch 6/30
# 184/184 [==============================] - 4s 21ms/step - loss: 0.2035 - accuracy: 0.9099 - val_loss: 0.1877 - val_accuracy: 0.9214
#
# Epoch 00006: val_accuracy did not improve from 0.92143
# Epoch 7/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.1904 - accuracy: 0.9206 - val_loss: 0.1680 - val_accuracy: 0.9333
#
# Epoch 00007: val_accuracy improved from 0.92143 to 0.93333, saving model to ./models/tree_11/model_root_f1_1_1/folder2\model.h5
# Epoch 8/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.1491 - accuracy: 0.9381 - val_loss: 0.1279 - val_accuracy: 0.9548
#
# Epoch 00008: val_accuracy improved from 0.93333 to 0.95476, saving model to ./models/tree_11/model_root_f1_1_1/folder2\model.h5
# Epoch 9/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.1265 - accuracy: 0.9497 - val_loss: 0.1254 - val_accuracy: 0.9500
#
# Epoch 00009: val_accuracy did not improve from 0.95476
# Epoch 10/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.1028 - accuracy: 0.9570 - val_loss: 0.1441 - val_accuracy: 0.9429
#
# Epoch 00010: val_accuracy did not improve from 0.95476
# Epoch 11/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0795 - accuracy: 0.9656 - val_loss: 0.1329 - val_accuracy: 0.9524
#
# Epoch 00011: val_accuracy did not improve from 0.95476
# Epoch 12/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0690 - accuracy: 0.9747 - val_loss: 0.2733 - val_accuracy: 0.8905
#
# Epoch 00012: val_accuracy did not improve from 0.95476
# Epoch 13/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0319 - accuracy: 0.9896 - val_loss: 0.1990 - val_accuracy: 0.9262
#
# Epoch 00013: val_accuracy did not improve from 0.95476
# Epoch 14/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0257 - accuracy: 0.9906 - val_loss: 0.1857 - val_accuracy: 0.9429
#
# Epoch 00014: val_accuracy did not improve from 0.95476
# Epoch 15/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0239 - accuracy: 0.9925 - val_loss: 0.2874 - val_accuracy: 0.9286
#
# Epoch 00015: val_accuracy did not improve from 0.95476
# Epoch 16/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.0263 - accuracy: 0.9908 - val_loss: 0.2635 - val_accuracy: 0.9310
#
# Epoch 00016: val_accuracy did not improve from 0.95476
# Epoch 17/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0041 - accuracy: 0.9995 - val_loss: 0.2096 - val_accuracy: 0.9452
#
# Epoch 00017: val_accuracy did not improve from 0.95476
# Epoch 18/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2261 - val_accuracy: 0.9429
#
# Epoch 00018: val_accuracy did not improve from 0.95476
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 19/30
# 184/184 [==============================] - 3s 19ms/step - loss: 2.9296e-04 - accuracy: 1.0000 - val_loss: 0.2285 - val_accuracy: 0.9500
#
# Epoch 00019: val_accuracy did not improve from 0.95476
# Epoch 20/30
# 184/184 [==============================] - 3s 19ms/step - loss: 2.2234e-04 - accuracy: 1.0000 - val_loss: 0.2305 - val_accuracy: 0.9500
#
# Epoch 00020: val_accuracy did not improve from 0.95476
# Epoch 21/30
# 184/184 [==============================] - 3s 19ms/step - loss: 1.8067e-04 - accuracy: 1.0000 - val_loss: 0.2367 - val_accuracy: 0.9476
#
# Epoch 00021: val_accuracy did not improve from 0.95476
# Epoch 22/30
# 184/184 [==============================] - 3s 19ms/step - loss: 1.5204e-04 - accuracy: 1.0000 - val_loss: 0.2392 - val_accuracy: 0.9500
#
# Epoch 00022: val_accuracy did not improve from 0.95476
# Epoch 23/30
# 184/184 [==============================] - 3s 19ms/step - loss: 1.2975e-04 - accuracy: 1.0000 - val_loss: 0.2439 - val_accuracy: 0.9476
#
# Epoch 00023: val_accuracy did not improve from 0.95476
# Epoch 24/30
# 184/184 [==============================] - 3s 19ms/step - loss: 1.1258e-04 - accuracy: 1.0000 - val_loss: 0.2478 - val_accuracy: 0.9476
#
# Epoch 00024: val_accuracy did not improve from 0.95476
# Epoch 25/30
# 184/184 [==============================] - 3s 19ms/step - loss: 9.7258e-05 - accuracy: 1.0000 - val_loss: 0.2514 - val_accuracy: 0.9476
#
# Epoch 00025: val_accuracy did not improve from 0.95476
# Epoch 26/30
# 184/184 [==============================] - 3s 18ms/step - loss: 8.5513e-05 - accuracy: 1.0000 - val_loss: 0.2537 - val_accuracy: 0.9476
#
# Epoch 00026: val_accuracy did not improve from 0.95476
# Epoch 27/30
# 184/184 [==============================] - 3s 19ms/step - loss: 7.4986e-05 - accuracy: 1.0000 - val_loss: 0.2568 - val_accuracy: 0.9476
#
# Epoch 00027: val_accuracy did not improve from 0.95476
# Epoch 28/30
# 184/184 [==============================] - 3s 18ms/step - loss: 6.6095e-05 - accuracy: 1.0000 - val_loss: 0.2595 - val_accuracy: 0.9476
#
# Epoch 00028: val_accuracy did not improve from 0.95476
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 29/30
# 184/184 [==============================] - 3s 18ms/step - loss: 5.9366e-05 - accuracy: 1.0000 - val_loss: 0.2618 - val_accuracy: 0.9476
#
# Epoch 00029: val_accuracy did not improve from 0.95476
# Epoch 30/30
# 184/184 [==============================] - 3s 18ms/step - loss: 5.5869e-05 - accuracy: 1.0000 - val_loss: 0.2636 - val_accuracy: 0.9476
#
# Epoch 00030: val_accuracy did not improve from 0.95476
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Disco'], ['Blues', 'Country', 'Hip-Hop', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 184/184 [==============================] - 4s 19ms/step - loss: 0.4300 - accuracy: 0.8510 - val_loss: 0.3499 - val_accuracy: 0.8810
#
# Epoch 00001: val_accuracy improved from -inf to 0.88095, saving model to ./models/tree_11/model_root_f1_1_1/folder3\model.h5
# Epoch 2/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.4089 - accuracy: 0.8554 - val_loss: 0.3482 - val_accuracy: 0.8810
#
# Epoch 00002: val_accuracy did not improve from 0.88095
# Epoch 3/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.4049 - accuracy: 0.8554 - val_loss: 0.3549 - val_accuracy: 0.8810
#
# Epoch 00003: val_accuracy did not improve from 0.88095
# Epoch 4/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.4239 - accuracy: 0.8520 - val_loss: 0.3476 - val_accuracy: 0.8810
#
# Epoch 00004: val_accuracy did not improve from 0.88095
# Epoch 5/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.4045 - accuracy: 0.8554 - val_loss: 0.3489 - val_accuracy: 0.8810
#
# Epoch 00005: val_accuracy did not improve from 0.88095
# Epoch 6/30
# 184/184 [==============================] - 4s 19ms/step - loss: 0.4026 - accuracy: 0.8554 - val_loss: 0.3706 - val_accuracy: 0.8810
#
# Epoch 00006: val_accuracy did not improve from 0.88095
# Epoch 7/30
# 184/184 [==============================] - 4s 21ms/step - loss: 0.3978 - accuracy: 0.8554 - val_loss: 0.3672 - val_accuracy: 0.8810
#
# Epoch 00007: val_accuracy did not improve from 0.88095
# Epoch 8/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.3947 - accuracy: 0.8554 - val_loss: 0.3520 - val_accuracy: 0.8810
#
# Epoch 00008: val_accuracy did not improve from 0.88095
# Epoch 9/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.3951 - accuracy: 0.8554 - val_loss: 0.3458 - val_accuracy: 0.8810
#
# Epoch 00009: val_accuracy did not improve from 0.88095
# Epoch 10/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.3891 - accuracy: 0.8553 - val_loss: 0.3014 - val_accuracy: 0.8833
#
# Epoch 00010: val_accuracy improved from 0.88095 to 0.88333, saving model to ./models/tree_11/model_root_f1_1_1/folder3\model.h5
# Epoch 11/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.3035 - accuracy: 0.8796 - val_loss: 0.3287 - val_accuracy: 0.8690
#
# Epoch 00011: val_accuracy did not improve from 0.88333
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 12/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.2392 - accuracy: 0.9095 - val_loss: 0.1829 - val_accuracy: 0.9262
#
# Epoch 00012: val_accuracy improved from 0.88333 to 0.92619, saving model to ./models/tree_11/model_root_f1_1_1/folder3\model.h5
# Epoch 13/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.2092 - accuracy: 0.9253 - val_loss: 0.1574 - val_accuracy: 0.9381
#
# Epoch 00013: val_accuracy improved from 0.92619 to 0.93810, saving model to ./models/tree_11/model_root_f1_1_1/folder3\model.h5
# Epoch 14/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1922 - accuracy: 0.9335 - val_loss: 0.1636 - val_accuracy: 0.9476
#
# Epoch 00014: val_accuracy improved from 0.93810 to 0.94762, saving model to ./models/tree_11/model_root_f1_1_1/folder3\model.h5
# Epoch 15/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1815 - accuracy: 0.9369 - val_loss: 0.1510 - val_accuracy: 0.9548
#
# Epoch 00015: val_accuracy improved from 0.94762 to 0.95476, saving model to ./models/tree_11/model_root_f1_1_1/folder3\model.h5
# Epoch 16/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1615 - accuracy: 0.9483 - val_loss: 0.1483 - val_accuracy: 0.9524
#
# Epoch 00016: val_accuracy did not improve from 0.95476
# Epoch 17/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1530 - accuracy: 0.9481 - val_loss: 0.1344 - val_accuracy: 0.9500
#
# Epoch 00017: val_accuracy did not improve from 0.95476
# Epoch 18/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1399 - accuracy: 0.9539 - val_loss: 0.1266 - val_accuracy: 0.9500
#
# Epoch 00018: val_accuracy did not improve from 0.95476
# Epoch 19/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1257 - accuracy: 0.9565 - val_loss: 0.1228 - val_accuracy: 0.9500
#
# Epoch 00019: val_accuracy did not improve from 0.95476
# Epoch 20/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1103 - accuracy: 0.9619 - val_loss: 0.1289 - val_accuracy: 0.9476
#
# Epoch 00020: val_accuracy did not improve from 0.95476
# Epoch 21/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0995 - accuracy: 0.9670 - val_loss: 0.1450 - val_accuracy: 0.9524
#
# Epoch 00021: val_accuracy did not improve from 0.95476
# Epoch 22/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0797 - accuracy: 0.9735 - val_loss: 0.1269 - val_accuracy: 0.9476
#
# Epoch 00022: val_accuracy did not improve from 0.95476
# Epoch 23/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0657 - accuracy: 0.9782 - val_loss: 0.1345 - val_accuracy: 0.9500
#
# Epoch 00023: val_accuracy did not improve from 0.95476
# Epoch 24/30
# 184/184 [==============================] - 4s 19ms/step - loss: 0.0463 - accuracy: 0.9869 - val_loss: 0.1841 - val_accuracy: 0.9429
#
# Epoch 00024: val_accuracy did not improve from 0.95476
# Epoch 25/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.0395 - accuracy: 0.9866 - val_loss: 0.2103 - val_accuracy: 0.9452
#
# Epoch 00025: val_accuracy did not improve from 0.95476
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 26/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.0219 - accuracy: 0.9949 - val_loss: 0.1418 - val_accuracy: 0.9452
#
# Epoch 00026: val_accuracy did not improve from 0.95476
# Epoch 27/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0141 - accuracy: 0.9980 - val_loss: 0.1443 - val_accuracy: 0.9548
#
# Epoch 00027: val_accuracy did not improve from 0.95476
# Epoch 28/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0098 - accuracy: 0.9991 - val_loss: 0.1496 - val_accuracy: 0.9452
#
# Epoch 00028: val_accuracy did not improve from 0.95476
# Epoch 29/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0074 - accuracy: 0.9993 - val_loss: 0.1481 - val_accuracy: 0.9571
#
# Epoch 00029: val_accuracy improved from 0.95476 to 0.95714, saving model to ./models/tree_11/model_root_f1_1_1/folder3\model.h5
# Epoch 30/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0051 - accuracy: 0.9997 - val_loss: 0.1469 - val_accuracy: 0.9524
#
# Epoch 00030: val_accuracy did not improve from 0.95714
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Hip-Hop'], ['Blues', 'Country', 'Disco', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 184/184 [==============================] - 4s 19ms/step - loss: 0.3927 - accuracy: 0.8529 - val_loss: 0.3483 - val_accuracy: 0.8429
#
# Epoch 00001: val_accuracy improved from -inf to 0.84286, saving model to ./models/tree_11/model_root_f1_1_1/folder4\model.h5
# Epoch 2/30
# 184/184 [==============================] - ETA: 0s - loss: 0.2961 - accuracy: 0.87 - 3s 18ms/step - loss: 0.2969 - accuracy: 0.8699 - val_loss: 0.3412 - val_accuracy: 0.8429
#
# Epoch 00002: val_accuracy did not improve from 0.84286
# Epoch 3/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.2561 - accuracy: 0.8912 - val_loss: 0.3157 - val_accuracy: 0.8548
#
# Epoch 00003: val_accuracy improved from 0.84286 to 0.85476, saving model to ./models/tree_11/model_root_f1_1_1/folder4\model.h5
# Epoch 4/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.2468 - accuracy: 0.8985 - val_loss: 0.2989 - val_accuracy: 0.8405
#
# Epoch 00004: val_accuracy did not improve from 0.85476
# Epoch 5/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.2245 - accuracy: 0.9053 - val_loss: 0.2383 - val_accuracy: 0.8762
#
# Epoch 00005: val_accuracy improved from 0.85476 to 0.87619, saving model to ./models/tree_11/model_root_f1_1_1/folder4\model.h5
# Epoch 6/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1895 - accuracy: 0.9216 - val_loss: 0.2706 - val_accuracy: 0.8952
#
# Epoch 00006: val_accuracy improved from 0.87619 to 0.89524, saving model to ./models/tree_11/model_root_f1_1_1/folder4\model.h5
# Epoch 7/30
# 184/184 [==============================] - 4s 19ms/step - loss: 0.1626 - accuracy: 0.9323 - val_loss: 0.2538 - val_accuracy: 0.9071
#
# Epoch 00007: val_accuracy improved from 0.89524 to 0.90714, saving model to ./models/tree_11/model_root_f1_1_1/folder4\model.h5
# Epoch 8/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1349 - accuracy: 0.9463 - val_loss: 0.1940 - val_accuracy: 0.9167
#
# Epoch 00008: val_accuracy improved from 0.90714 to 0.91667, saving model to ./models/tree_11/model_root_f1_1_1/folder4\model.h5
# Epoch 9/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.0907 - accuracy: 0.9662 - val_loss: 0.2272 - val_accuracy: 0.8976
#
# Epoch 00009: val_accuracy did not improve from 0.91667
# Epoch 10/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0551 - accuracy: 0.9796 - val_loss: 0.2084 - val_accuracy: 0.9357
#
# Epoch 00010: val_accuracy improved from 0.91667 to 0.93571, saving model to ./models/tree_11/model_root_f1_1_1/folder4\model.h5
# Epoch 11/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.0374 - accuracy: 0.9879 - val_loss: 0.1952 - val_accuracy: 0.9357
#
# Epoch 00011: val_accuracy did not improve from 0.93571
# Epoch 12/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0279 - accuracy: 0.9901 - val_loss: 0.2650 - val_accuracy: 0.9214
#
# Epoch 00012: val_accuracy did not improve from 0.93571
# Epoch 13/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0155 - accuracy: 0.9954 - val_loss: 0.2333 - val_accuracy: 0.9333
#
# Epoch 00013: val_accuracy did not improve from 0.93571
# Epoch 14/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0050 - accuracy: 0.9990 - val_loss: 0.2797 - val_accuracy: 0.9310
#
# Epoch 00014: val_accuracy did not improve from 0.93571
# Epoch 15/30
# 184/184 [==============================] - 3s 18ms/step - loss: 5.6127e-04 - accuracy: 1.0000 - val_loss: 0.2668 - val_accuracy: 0.9429
#
# Epoch 00015: val_accuracy improved from 0.93571 to 0.94286, saving model to ./models/tree_11/model_root_f1_1_1/folder4\model.h5
# Epoch 16/30
# 184/184 [==============================] - 3s 18ms/step - loss: 2.3140e-04 - accuracy: 1.0000 - val_loss: 0.2729 - val_accuracy: 0.9429
#
# Epoch 00016: val_accuracy did not improve from 0.94286
# Epoch 17/30
# 184/184 [==============================] - 3s 18ms/step - loss: 1.5187e-04 - accuracy: 1.0000 - val_loss: 0.2997 - val_accuracy: 0.9429
#
# Epoch 00017: val_accuracy did not improve from 0.94286
# Epoch 18/30
# 184/184 [==============================] - 3s 18ms/step - loss: 1.1318e-04 - accuracy: 1.0000 - val_loss: 0.3066 - val_accuracy: 0.9429
#
# Epoch 00018: val_accuracy did not improve from 0.94286
# Epoch 19/30
# 184/184 [==============================] - 3s 18ms/step - loss: 8.7887e-05 - accuracy: 1.0000 - val_loss: 0.3057 - val_accuracy: 0.9429
#
# Epoch 00019: val_accuracy did not improve from 0.94286
# Epoch 20/30
# 184/184 [==============================] - 3s 18ms/step - loss: 7.2483e-05 - accuracy: 1.0000 - val_loss: 0.3124 - val_accuracy: 0.9429
#
# Epoch 00020: val_accuracy did not improve from 0.94286
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/30
# 184/184 [==============================] - 3s 18ms/step - loss: 6.0661e-05 - accuracy: 1.0000 - val_loss: 0.3141 - val_accuracy: 0.9429
#
# Epoch 00021: val_accuracy did not improve from 0.94286
# Epoch 22/30
# 184/184 [==============================] - 3s 18ms/step - loss: 5.5154e-05 - accuracy: 1.0000 - val_loss: 0.3186 - val_accuracy: 0.9429
#
# Epoch 00022: val_accuracy did not improve from 0.94286
# Epoch 23/30
# 184/184 [==============================] - 3s 18ms/step - loss: 5.0350e-05 - accuracy: 1.0000 - val_loss: 0.3225 - val_accuracy: 0.9429
#
# Epoch 00023: val_accuracy did not improve from 0.94286
# Epoch 24/30
# 184/184 [==============================] - 3s 18ms/step - loss: 4.6298e-05 - accuracy: 1.0000 - val_loss: 0.3223 - val_accuracy: 0.9429
#
# Epoch 00024: val_accuracy did not improve from 0.94286
# Epoch 25/30
# 184/184 [==============================] - 3s 18ms/step - loss: 4.1865e-05 - accuracy: 1.0000 - val_loss: 0.3275 - val_accuracy: 0.9429
#
# Epoch 00025: val_accuracy did not improve from 0.94286
# Epoch 26/30
# 184/184 [==============================] - 3s 18ms/step - loss: 3.7996e-05 - accuracy: 1.0000 - val_loss: 0.3308 - val_accuracy: 0.9429
#
# Epoch 00026: val_accuracy did not improve from 0.94286
# Epoch 27/30
# 184/184 [==============================] - 3s 18ms/step - loss: 3.4504e-05 - accuracy: 1.0000 - val_loss: 0.3311 - val_accuracy: 0.9429
#
# Epoch 00027: val_accuracy did not improve from 0.94286
# Epoch 28/30
# 184/184 [==============================] - 3s 18ms/step - loss: 3.1352e-05 - accuracy: 1.0000 - val_loss: 0.3359 - val_accuracy: 0.9429
#
# Epoch 00028: val_accuracy did not improve from 0.94286
# Epoch 29/30
# 184/184 [==============================] - 3s 18ms/step - loss: 2.8439e-05 - accuracy: 1.0000 - val_loss: 0.3409 - val_accuracy: 0.9405
#
# Epoch 00029: val_accuracy did not improve from 0.94286
# Epoch 30/30
# 184/184 [==============================] - 3s 18ms/step - loss: 2.5620e-05 - accuracy: 1.0000 - val_loss: 0.3386 - val_accuracy: 0.9429
#
# Epoch 00030: val_accuracy did not improve from 0.94286
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 5
# Genre split [['Pop'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 184/184 [==============================] - 4s 19ms/step - loss: 0.4096 - accuracy: 0.8548 - val_loss: 0.2493 - val_accuracy: 0.8833
#
# Epoch 00001: val_accuracy improved from -inf to 0.88333, saving model to ./models/tree_11/model_root_f1_1_1/folder5\model.h5
# Epoch 2/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.2180 - accuracy: 0.9037 - val_loss: 0.2494 - val_accuracy: 0.9071
#
# Epoch 00002: val_accuracy improved from 0.88333 to 0.90714, saving model to ./models/tree_11/model_root_f1_1_1/folder5\model.h5
# Epoch 3/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1966 - accuracy: 0.9207 - val_loss: 0.2129 - val_accuracy: 0.9143
#
# Epoch 00003: val_accuracy improved from 0.90714 to 0.91429, saving model to ./models/tree_11/model_root_f1_1_1/folder5\model.h5
# Epoch 4/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1843 - accuracy: 0.9259 - val_loss: 0.1920 - val_accuracy: 0.9286
#
# Epoch 00004: val_accuracy improved from 0.91429 to 0.92857, saving model to ./models/tree_11/model_root_f1_1_1/folder5\model.h5
# Epoch 5/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1707 - accuracy: 0.9315 - val_loss: 0.1789 - val_accuracy: 0.9214
#
# Epoch 00005: val_accuracy did not improve from 0.92857
# Epoch 6/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.1569 - accuracy: 0.9389 - val_loss: 0.1632 - val_accuracy: 0.9286
#
# Epoch 00006: val_accuracy did not improve from 0.92857
# Epoch 7/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1595 - accuracy: 0.9359 - val_loss: 0.1723 - val_accuracy: 0.9262
#
# Epoch 00007: val_accuracy did not improve from 0.92857
# Epoch 8/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1451 - accuracy: 0.9432 - val_loss: 0.1556 - val_accuracy: 0.9381
#
# Epoch 00008: val_accuracy improved from 0.92857 to 0.93810, saving model to ./models/tree_11/model_root_f1_1_1/folder5\model.h5
# Epoch 9/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1424 - accuracy: 0.9437 - val_loss: 0.1627 - val_accuracy: 0.9286
#
# Epoch 00009: val_accuracy did not improve from 0.93810
# Epoch 10/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1361 - accuracy: 0.9463 - val_loss: 0.1591 - val_accuracy: 0.9238
#
# Epoch 00010: val_accuracy did not improve from 0.93810
# Epoch 11/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1287 - accuracy: 0.9497 - val_loss: 0.1670 - val_accuracy: 0.9429
#
# Epoch 00011: val_accuracy improved from 0.93810 to 0.94286, saving model to ./models/tree_11/model_root_f1_1_1/folder5\model.h5
# Epoch 12/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1230 - accuracy: 0.9527 - val_loss: 0.1407 - val_accuracy: 0.9357
#
# Epoch 00012: val_accuracy did not improve from 0.94286
# Epoch 13/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1139 - accuracy: 0.9577 - val_loss: 0.1726 - val_accuracy: 0.9190
#
# Epoch 00013: val_accuracy did not improve from 0.94286
# Epoch 14/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1100 - accuracy: 0.9597 - val_loss: 0.1676 - val_accuracy: 0.9238
#
# Epoch 00014: val_accuracy did not improve from 0.94286
# Epoch 15/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1050 - accuracy: 0.9609 - val_loss: 0.1548 - val_accuracy: 0.9286
#
# Epoch 00015: val_accuracy did not improve from 0.94286
# Epoch 16/30
# 184/184 [==============================] - 4s 19ms/step - loss: 0.0999 - accuracy: 0.9663 - val_loss: 0.1631 - val_accuracy: 0.9286
#
# Epoch 00016: val_accuracy did not improve from 0.94286
# Epoch 17/30
# 184/184 [==============================] - 4s 21ms/step - loss: 0.0912 - accuracy: 0.9655 - val_loss: 0.1753 - val_accuracy: 0.9238
#
# Epoch 00017: val_accuracy did not improve from 0.94286
# Epoch 18/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0837 - accuracy: 0.9702 - val_loss: 0.1929 - val_accuracy: 0.9310
#
# Epoch 00018: val_accuracy did not improve from 0.94286
# Epoch 19/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.0824 - accuracy: 0.9682 - val_loss: 0.1769 - val_accuracy: 0.9357
#
# Epoch 00019: val_accuracy did not improve from 0.94286
# Epoch 20/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.0689 - accuracy: 0.9733 - val_loss: 0.1806 - val_accuracy: 0.9405
#
# Epoch 00020: val_accuracy did not improve from 0.94286
# Epoch 21/30
# 184/184 [==============================] - 4s 19ms/step - loss: 0.0634 - accuracy: 0.9769 - val_loss: 0.1652 - val_accuracy: 0.9310
#
# Epoch 00021: val_accuracy did not improve from 0.94286
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 22/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.0392 - accuracy: 0.9859 - val_loss: 0.1945 - val_accuracy: 0.9238
#
# Epoch 00022: val_accuracy did not improve from 0.94286
# Epoch 23/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0295 - accuracy: 0.9915 - val_loss: 0.2382 - val_accuracy: 0.9190
#
# Epoch 00023: val_accuracy did not improve from 0.94286
# Epoch 24/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0261 - accuracy: 0.9920 - val_loss: 0.2230 - val_accuracy: 0.9310
#
# Epoch 00024: val_accuracy did not improve from 0.94286
# Epoch 25/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.0207 - accuracy: 0.9934 - val_loss: 0.2211 - val_accuracy: 0.9357
#
# Epoch 00025: val_accuracy did not improve from 0.94286
# Epoch 26/30
# 184/184 [==============================] - 4s 19ms/step - loss: 0.0199 - accuracy: 0.9944 - val_loss: 0.2398 - val_accuracy: 0.9333
#
# Epoch 00026: val_accuracy did not improve from 0.94286
# Epoch 27/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.0113 - accuracy: 0.9985 - val_loss: 0.2921 - val_accuracy: 0.9333
#
# Epoch 00027: val_accuracy did not improve from 0.94286
# Epoch 28/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0117 - accuracy: 0.9976 - val_loss: 0.3016 - val_accuracy: 0.9214
#
# Epoch 00028: val_accuracy did not improve from 0.94286
# Epoch 29/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0065 - accuracy: 0.9993 - val_loss: 0.3150 - val_accuracy: 0.9190
#
# Epoch 00029: val_accuracy did not improve from 0.94286
# Epoch 30/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0065 - accuracy: 0.9990 - val_loss: 0.3308 - val_accuracy: 0.9167
#
# Epoch 00030: val_accuracy did not improve from 0.94286
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 6
# Genre split [['Reggae'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Pop', 'Rock']]
# Building model...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.4699 - accuracy: 0.8526 - val_loss: 0.4313 - val_accuracy: 0.8548
#
# Epoch 00001: val_accuracy improved from -inf to 0.85476, saving model to ./models/tree_11/model_root_f1_1_1/folder6\model.h5
# Epoch 2/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.4119 - accuracy: 0.8575 - val_loss: 0.4112 - val_accuracy: 0.8548
#
# Epoch 00002: val_accuracy did not improve from 0.85476
# Epoch 3/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.3983 - accuracy: 0.8571 - val_loss: 0.4093 - val_accuracy: 0.8524
#
# Epoch 00003: val_accuracy did not improve from 0.85476
# Epoch 4/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.3796 - accuracy: 0.8585 - val_loss: 0.3540 - val_accuracy: 0.8667
#
# Epoch 00004: val_accuracy improved from 0.85476 to 0.86667, saving model to ./models/tree_11/model_root_f1_1_1/folder6\model.h5
# Epoch 5/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.3385 - accuracy: 0.8628 - val_loss: 0.3570 - val_accuracy: 0.8643
#
# Epoch 00005: val_accuracy did not improve from 0.86667
# Epoch 6/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.3076 - accuracy: 0.8762 - val_loss: 0.3278 - val_accuracy: 0.8857
#
# Epoch 00006: val_accuracy improved from 0.86667 to 0.88571, saving model to ./models/tree_11/model_root_f1_1_1/folder6\model.h5
# Epoch 7/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.2758 - accuracy: 0.8869 - val_loss: 0.3287 - val_accuracy: 0.8833
#
# Epoch 00007: val_accuracy did not improve from 0.88571
# Epoch 8/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.2251 - accuracy: 0.9111 - val_loss: 0.3588 - val_accuracy: 0.8810
#
# Epoch 00008: val_accuracy did not improve from 0.88571
# Epoch 9/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1990 - accuracy: 0.9243 - val_loss: 0.2835 - val_accuracy: 0.8929
#
# Epoch 00009: val_accuracy improved from 0.88571 to 0.89286, saving model to ./models/tree_11/model_root_f1_1_1/folder6\model.h5
# Epoch 10/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1613 - accuracy: 0.9403 - val_loss: 0.2426 - val_accuracy: 0.9119
#
# Epoch 00010: val_accuracy improved from 0.89286 to 0.91190, saving model to ./models/tree_11/model_root_f1_1_1/folder6\model.h5
# Epoch 11/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1098 - accuracy: 0.9585 - val_loss: 0.2198 - val_accuracy: 0.9381
#
# Epoch 00011: val_accuracy improved from 0.91190 to 0.93810, saving model to ./models/tree_11/model_root_f1_1_1/folder6\model.h5
# Epoch 12/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.0942 - accuracy: 0.9655 - val_loss: 0.2321 - val_accuracy: 0.9262
#
# Epoch 00012: val_accuracy did not improve from 0.93810
# Epoch 13/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0598 - accuracy: 0.9801 - val_loss: 0.2766 - val_accuracy: 0.9452
#
# Epoch 00013: val_accuracy improved from 0.93810 to 0.94524, saving model to ./models/tree_11/model_root_f1_1_1/folder6\model.h5
# Epoch 14/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0412 - accuracy: 0.9852 - val_loss: 0.2487 - val_accuracy: 0.9452
#
# Epoch 00014: val_accuracy did not improve from 0.94524
# Epoch 15/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0352 - accuracy: 0.9867 - val_loss: 0.2415 - val_accuracy: 0.9500
#
# Epoch 00015: val_accuracy improved from 0.94524 to 0.95000, saving model to ./models/tree_11/model_root_f1_1_1/folder6\model.h5
# Epoch 16/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0280 - accuracy: 0.9886 - val_loss: 0.2850 - val_accuracy: 0.9476
#
# Epoch 00016: val_accuracy did not improve from 0.95000
# Epoch 17/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0141 - accuracy: 0.9963 - val_loss: 0.2186 - val_accuracy: 0.9500
#
# Epoch 00017: val_accuracy did not improve from 0.95000
# Epoch 18/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0070 - accuracy: 0.9983 - val_loss: 0.2862 - val_accuracy: 0.9452
#
# Epoch 00018: val_accuracy did not improve from 0.95000
# Epoch 19/30
# 184/184 [==============================] - 4s 20ms/step - loss: 9.9020e-04 - accuracy: 1.0000 - val_loss: 0.3119 - val_accuracy: 0.9548
#
# Epoch 00019: val_accuracy improved from 0.95000 to 0.95476, saving model to ./models/tree_11/model_root_f1_1_1/folder6\model.h5
# Epoch 20/30
# 184/184 [==============================] - 3s 18ms/step - loss: 3.8540e-04 - accuracy: 1.0000 - val_loss: 0.3267 - val_accuracy: 0.9571
#
# Epoch 00020: val_accuracy improved from 0.95476 to 0.95714, saving model to ./models/tree_11/model_root_f1_1_1/folder6\model.h5
# Epoch 21/30
# 184/184 [==============================] - 3s 19ms/step - loss: 2.4703e-04 - accuracy: 1.0000 - val_loss: 0.3209 - val_accuracy: 0.9595
#
# Epoch 00021: val_accuracy improved from 0.95714 to 0.95952, saving model to ./models/tree_11/model_root_f1_1_1/folder6\model.h5
# Epoch 22/30
# 184/184 [==============================] - 3s 18ms/step - loss: 1.9135e-04 - accuracy: 1.0000 - val_loss: 0.3304 - val_accuracy: 0.9595
#
# Epoch 00022: val_accuracy did not improve from 0.95952
# Epoch 23/30
# 184/184 [==============================] - 3s 18ms/step - loss: 1.5159e-04 - accuracy: 1.0000 - val_loss: 0.3493 - val_accuracy: 0.9548
#
# Epoch 00023: val_accuracy did not improve from 0.95952
# Epoch 24/30
# 184/184 [==============================] - 3s 18ms/step - loss: 1.2650e-04 - accuracy: 1.0000 - val_loss: 0.3478 - val_accuracy: 0.9595
#
# Epoch 00024: val_accuracy did not improve from 0.95952
# Epoch 25/30
# 184/184 [==============================] - 3s 19ms/step - loss: 1.0567e-04 - accuracy: 1.0000 - val_loss: 0.3438 - val_accuracy: 0.9595
#
# Epoch 00025: val_accuracy did not improve from 0.95952
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 26/30
# 184/184 [==============================] - 3s 19ms/step - loss: 8.9140e-05 - accuracy: 1.0000 - val_loss: 0.3495 - val_accuracy: 0.9595
#
# Epoch 00026: val_accuracy did not improve from 0.95952
# Epoch 27/30
# 184/184 [==============================] - 3s 18ms/step - loss: 8.1660e-05 - accuracy: 1.0000 - val_loss: 0.3513 - val_accuracy: 0.9595
#
# Epoch 00027: val_accuracy did not improve from 0.95952
# Epoch 28/30
# 184/184 [==============================] - 3s 18ms/step - loss: 7.5361e-05 - accuracy: 1.0000 - val_loss: 0.3541 - val_accuracy: 0.9595
#
# Epoch 00028: val_accuracy did not improve from 0.95952
# Epoch 29/30
# 184/184 [==============================] - 3s 18ms/step - loss: 6.9694e-05 - accuracy: 1.0000 - val_loss: 0.3591 - val_accuracy: 0.9595
#
# Epoch 00029: val_accuracy did not improve from 0.95952
# Epoch 30/30
# 184/184 [==============================] - 3s 18ms/step - loss: 6.3707e-05 - accuracy: 1.0000 - val_loss: 0.3551 - val_accuracy: 0.9595
#
# Epoch 00030: val_accuracy did not improve from 0.95952
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 7
# Genre split [['Rock'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Pop', 'Reggae']]
# Building model...
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 184/184 [==============================] - 4s 19ms/step - loss: 0.4017 - accuracy: 0.8553 - val_loss: 0.3933 - val_accuracy: 0.8548
#
# Epoch 00001: val_accuracy improved from -inf to 0.85476, saving model to ./models/tree_11/model_root_f1_1_1/folder7\model.h5
# Epoch 2/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.3659 - accuracy: 0.8585 - val_loss: 0.3990 - val_accuracy: 0.8548
#
# Epoch 00002: val_accuracy did not improve from 0.85476
# Epoch 3/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.3353 - accuracy: 0.8634 - val_loss: 0.3566 - val_accuracy: 0.8548
#
# Epoch 00003: val_accuracy did not improve from 0.85476
# Epoch 4/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.3108 - accuracy: 0.8651 - val_loss: 0.3100 - val_accuracy: 0.8810
#
# Epoch 00004: val_accuracy improved from 0.85476 to 0.88095, saving model to ./models/tree_11/model_root_f1_1_1/folder7\model.h5
# Epoch 5/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.2780 - accuracy: 0.8769 - val_loss: 0.3163 - val_accuracy: 0.8762
#
# Epoch 00005: val_accuracy did not improve from 0.88095
# Epoch 6/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.2553 - accuracy: 0.8854 - val_loss: 0.2603 - val_accuracy: 0.8881
#
# Epoch 00006: val_accuracy improved from 0.88095 to 0.88810, saving model to ./models/tree_11/model_root_f1_1_1/folder7\model.h5
# Epoch 7/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.2431 - accuracy: 0.8986 - val_loss: 0.3793 - val_accuracy: 0.8119
#
# Epoch 00007: val_accuracy did not improve from 0.88810
# Epoch 8/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.2162 - accuracy: 0.9080 - val_loss: 0.2516 - val_accuracy: 0.8976
#
# Epoch 00008: val_accuracy improved from 0.88810 to 0.89762, saving model to ./models/tree_11/model_root_f1_1_1/folder7\model.h5
# Epoch 9/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1926 - accuracy: 0.9126 - val_loss: 0.2496 - val_accuracy: 0.9095
#
# Epoch 00009: val_accuracy improved from 0.89762 to 0.90952, saving model to ./models/tree_11/model_root_f1_1_1/folder7\model.h5
# Epoch 10/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1691 - accuracy: 0.9276 - val_loss: 0.2445 - val_accuracy: 0.9000
#
# Epoch 00010: val_accuracy did not improve from 0.90952
# Epoch 11/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1400 - accuracy: 0.9430 - val_loss: 0.2735 - val_accuracy: 0.9000
#
# Epoch 00011: val_accuracy did not improve from 0.90952
# Epoch 12/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.1377 - accuracy: 0.9463 - val_loss: 0.2548 - val_accuracy: 0.8905
#
# Epoch 00012: val_accuracy did not improve from 0.90952
# Epoch 13/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.1017 - accuracy: 0.9600 - val_loss: 0.2520 - val_accuracy: 0.8881
#
# Epoch 00013: val_accuracy did not improve from 0.90952
# Epoch 14/30
# 184/184 [==============================] - 3s 17ms/step - loss: 0.0765 - accuracy: 0.9684 - val_loss: 0.2709 - val_accuracy: 0.8952
#
# Epoch 00014: val_accuracy did not improve from 0.90952
# Epoch 15/30
# 184/184 [==============================] - 4s 19ms/step - loss: 0.0654 - accuracy: 0.9757 - val_loss: 0.2616 - val_accuracy: 0.8833
#
# Epoch 00015: val_accuracy did not improve from 0.90952
# Epoch 16/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0477 - accuracy: 0.9823 - val_loss: 0.3212 - val_accuracy: 0.9048
#
# Epoch 00016: val_accuracy did not improve from 0.90952
# Epoch 17/30
# 184/184 [==============================] - 3s 19ms/step - loss: 0.0162 - accuracy: 0.9957 - val_loss: 0.4327 - val_accuracy: 0.9000
#
# Epoch 00017: val_accuracy did not improve from 0.90952
# Epoch 18/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0053 - accuracy: 0.9990 - val_loss: 0.3554 - val_accuracy: 0.9071
#
# Epoch 00018: val_accuracy did not improve from 0.90952
# Epoch 19/30
# 184/184 [==============================] - 3s 18ms/step - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.3919 - val_accuracy: 0.9000
#
# Epoch 00019: val_accuracy did not improve from 0.90952
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/30
# 184/184 [==============================] - 3s 18ms/step - loss: 8.3760e-04 - accuracy: 1.0000 - val_loss: 0.3976 - val_accuracy: 0.9024
#
# Epoch 00020: val_accuracy did not improve from 0.90952
# Epoch 21/30
# 184/184 [==============================] - 3s 18ms/step - loss: 5.2511e-04 - accuracy: 1.0000 - val_loss: 0.4230 - val_accuracy: 0.9095
#
# Epoch 00021: val_accuracy did not improve from 0.90952
# Epoch 22/30
# 184/184 [==============================] - 3s 18ms/step - loss: 4.1675e-04 - accuracy: 1.0000 - val_loss: 0.4263 - val_accuracy: 0.9048
#
# Epoch 00022: val_accuracy did not improve from 0.90952
# Epoch 23/30
# 184/184 [==============================] - 3s 18ms/step - loss: 3.3732e-04 - accuracy: 1.0000 - val_loss: 0.4389 - val_accuracy: 0.9048
#
# Epoch 00023: val_accuracy did not improve from 0.90952
# Epoch 24/30
# 184/184 [==============================] - 3s 18ms/step - loss: 2.7971e-04 - accuracy: 1.0000 - val_loss: 0.4603 - val_accuracy: 0.9095
#
# Epoch 00024: val_accuracy did not improve from 0.90952
# Epoch 25/30
# 184/184 [==============================] - 3s 18ms/step - loss: 2.3423e-04 - accuracy: 1.0000 - val_loss: 0.4517 - val_accuracy: 0.9071
#
# Epoch 00025: val_accuracy did not improve from 0.90952
# Epoch 26/30
# 184/184 [==============================] - 3s 19ms/step - loss: 1.9908e-04 - accuracy: 1.0000 - val_loss: 0.4529 - val_accuracy: 0.9024
#
# Epoch 00026: val_accuracy did not improve from 0.90952
# Epoch 27/30
# 184/184 [==============================] - 4s 20ms/step - loss: 1.6567e-04 - accuracy: 1.0000 - val_loss: 0.4731 - val_accuracy: 0.9071
#
# Epoch 00027: val_accuracy did not improve from 0.90952
# Epoch 28/30
# 184/184 [==============================] - 4s 20ms/step - loss: 1.3953e-04 - accuracy: 1.0000 - val_loss: 0.4740 - val_accuracy: 0.9024
#
# Epoch 00028: val_accuracy did not improve from 0.90952
# Epoch 29/30
# 184/184 [==============================] - 4s 20ms/step - loss: 1.1785e-04 - accuracy: 1.0000 - val_loss: 0.5151 - val_accuracy: 0.9119
#
# Epoch 00029: val_accuracy improved from 0.90952 to 0.91190, saving model to ./models/tree_11/model_root_f1_1_1/folder7\model.h5
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 30/30
# 184/184 [==============================] - 4s 20ms/step - loss: 1.0122e-04 - accuracy: 1.0000 - val_loss: 0.4943 - val_accuracy: 0.9048
#
# Epoch 00030: val_accuracy did not improve from 0.91190
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
