# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Blues':0, 'Classical':1, 'Jazz':5}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Blues', 1: 'Classical', 5: 'Jazz'}

# %%
npzfile = np.load('data/all_targets_sets_train.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7992, 128, 128) (7992, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((2403, 128, 128), (2403, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (999, 128, 128) (999, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((296, 128, 128), (296, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Jazz

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_7/model_root_f1_2/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_7/model_root_f1_2/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def create_split(elem):
    splits = list(set_partitions(elem, 2))

    return splits, len(splits)

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

genre_splits, num_splits = create_split(list(dict_genres.values()))
print("Num splits {}".format(num_splits))

if num_splits > 8:
    n_splits = num_splits
else:
    n_splits = 8

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)

    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Num splits 3
# Folder num 1
# Genre split [['Blues'], ['Classical', 'Jazz']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 74/74 [==============================] - 6s 28ms/step - loss: 0.7723 - accuracy: 0.6302 - val_loss: 0.5745 - val_accuracy: 0.6893
#
# Epoch 00001: val_accuracy improved from -inf to 0.68935, saving model to ./models/tree_7/model_root_f1_2/folder1\model.h5
# Epoch 2/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.5144 - accuracy: 0.7374 - val_loss: 0.3576 - val_accuracy: 0.8343
#
# Epoch 00002: val_accuracy improved from 0.68935 to 0.83432, saving model to ./models/tree_7/model_root_f1_2/folder1\model.h5
# Epoch 3/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.3801 - accuracy: 0.8352 - val_loss: 0.3606 - val_accuracy: 0.8195
#
# Epoch 00003: val_accuracy did not improve from 0.83432
# Epoch 4/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.3235 - accuracy: 0.8679 - val_loss: 0.3136 - val_accuracy: 0.8698
#
# Epoch 00004: val_accuracy improved from 0.83432 to 0.86982, saving model to ./models/tree_7/model_root_f1_2/folder1\model.h5
# Epoch 5/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.2778 - accuracy: 0.8852 - val_loss: 0.2767 - val_accuracy: 0.8787
#
# Epoch 00005: val_accuracy improved from 0.86982 to 0.87870, saving model to ./models/tree_7/model_root_f1_2/folder1\model.h5
# Epoch 6/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.2526 - accuracy: 0.8916 - val_loss: 0.2747 - val_accuracy: 0.8728
#
# Epoch 00006: val_accuracy did not improve from 0.87870
# Epoch 7/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.2333 - accuracy: 0.9013 - val_loss: 0.2322 - val_accuracy: 0.8905
#
# Epoch 00007: val_accuracy improved from 0.87870 to 0.89053, saving model to ./models/tree_7/model_root_f1_2/folder1\model.h5
# Epoch 8/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1993 - accuracy: 0.9187 - val_loss: 0.2252 - val_accuracy: 0.9083
#
# Epoch 00008: val_accuracy improved from 0.89053 to 0.90828, saving model to ./models/tree_7/model_root_f1_2/folder1\model.h5
# Epoch 9/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1905 - accuracy: 0.9208 - val_loss: 0.2337 - val_accuracy: 0.8994
#
# Epoch 00009: val_accuracy did not improve from 0.90828
# Epoch 10/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1529 - accuracy: 0.9403 - val_loss: 0.2052 - val_accuracy: 0.9083
#
# Epoch 00010: val_accuracy did not improve from 0.90828
# Epoch 11/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1451 - accuracy: 0.9399 - val_loss: 0.1855 - val_accuracy: 0.9053
#
# Epoch 00011: val_accuracy did not improve from 0.90828
# Epoch 12/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1510 - accuracy: 0.9369 - val_loss: 0.2284 - val_accuracy: 0.9142
#
# Epoch 00012: val_accuracy improved from 0.90828 to 0.91420, saving model to ./models/tree_7/model_root_f1_2/folder1\model.h5
# Epoch 13/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1404 - accuracy: 0.9411 - val_loss: 0.1657 - val_accuracy: 0.9260
#
# Epoch 00013: val_accuracy improved from 0.91420 to 0.92604, saving model to ./models/tree_7/model_root_f1_2/folder1\model.h5
# Epoch 14/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0958 - accuracy: 0.9653 - val_loss: 0.1761 - val_accuracy: 0.9201
#
# Epoch 00014: val_accuracy did not improve from 0.92604
# Epoch 15/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0701 - accuracy: 0.9729 - val_loss: 0.1445 - val_accuracy: 0.9290
#
# Epoch 00015: val_accuracy improved from 0.92604 to 0.92899, saving model to ./models/tree_7/model_root_f1_2/folder1\model.h5
# Epoch 16/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0701 - accuracy: 0.9712 - val_loss: 0.1474 - val_accuracy: 0.9408
#
# Epoch 00016: val_accuracy improved from 0.92899 to 0.94083, saving model to ./models/tree_7/model_root_f1_2/folder1\model.h5
# Epoch 17/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1079 - accuracy: 0.9619 - val_loss: 0.1874 - val_accuracy: 0.9083
#
# Epoch 00017: val_accuracy did not improve from 0.94083
# Epoch 18/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0654 - accuracy: 0.9776 - val_loss: 0.1647 - val_accuracy: 0.9349
#
# Epoch 00018: val_accuracy did not improve from 0.94083
# Epoch 19/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0401 - accuracy: 0.9869 - val_loss: 0.1393 - val_accuracy: 0.9467
#
# Epoch 00019: val_accuracy improved from 0.94083 to 0.94675, saving model to ./models/tree_7/model_root_f1_2/folder1\model.h5
# Epoch 20/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0327 - accuracy: 0.9894 - val_loss: 0.1594 - val_accuracy: 0.9379
#
# Epoch 00020: val_accuracy did not improve from 0.94675
# Epoch 21/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0310 - accuracy: 0.9877 - val_loss: 0.1681 - val_accuracy: 0.9260
#
# Epoch 00021: val_accuracy did not improve from 0.94675
# Epoch 22/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0287 - accuracy: 0.9911 - val_loss: 0.1409 - val_accuracy: 0.9408
#
# Epoch 00022: val_accuracy did not improve from 0.94675
# Epoch 23/30
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0125 - accuracy: 0.9970 - val_loss: 0.1281 - val_accuracy: 0.9497
#
# Epoch 00023: val_accuracy improved from 0.94675 to 0.94970, saving model to ./models/tree_7/model_root_f1_2/folder1\model.h5
# Epoch 24/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.1336 - val_accuracy: 0.9527
#
# Epoch 00024: val_accuracy improved from 0.94970 to 0.95266, saving model to ./models/tree_7/model_root_f1_2/folder1\model.h5
# Epoch 25/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0030 - accuracy: 0.9996 - val_loss: 0.1515 - val_accuracy: 0.9438
#
# Epoch 00025: val_accuracy did not improve from 0.95266
# Epoch 26/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1442 - val_accuracy: 0.9527
#
# Epoch 00026: val_accuracy did not improve from 0.95266
# Epoch 27/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9467
#
# Epoch 00027: val_accuracy did not improve from 0.95266
# Epoch 28/30
# 74/74 [==============================] - 1s 19ms/step - loss: 7.7893e-04 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9497
#
# Epoch 00028: val_accuracy did not improve from 0.95266
# Epoch 29/30
# 74/74 [==============================] - 1s 19ms/step - loss: 6.6116e-04 - accuracy: 1.0000 - val_loss: 0.1449 - val_accuracy: 0.9467
#
# Epoch 00029: val_accuracy did not improve from 0.95266
# Epoch 30/30
# 74/74 [==============================] - 1s 19ms/step - loss: 5.9841e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9438
#
# Epoch 00030: val_accuracy did not improve from 0.95266
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Blues', 'Classical'], ['Jazz']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 74/74 [==============================] - 2s 22ms/step - loss: 0.7102 - accuracy: 0.6650 - val_loss: 0.6394 - val_accuracy: 0.6598
#
# Epoch 00001: val_accuracy improved from -inf to 0.65976, saving model to ./models/tree_7/model_root_f1_2/folder2\model.h5
# Epoch 2/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.6317 - accuracy: 0.6692 - val_loss: 0.6508 - val_accuracy: 0.6598
#
# Epoch 00002: val_accuracy did not improve from 0.65976
# Epoch 3/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.6385 - accuracy: 0.6692 - val_loss: 0.6455 - val_accuracy: 0.6598
#
# Epoch 00003: val_accuracy did not improve from 0.65976
# Epoch 4/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.6225 - accuracy: 0.6658 - val_loss: 0.6200 - val_accuracy: 0.6598
#
# Epoch 00004: val_accuracy did not improve from 0.65976
# Epoch 5/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.5884 - accuracy: 0.6946 - val_loss: 0.5526 - val_accuracy: 0.7515
#
# Epoch 00005: val_accuracy improved from 0.65976 to 0.75148, saving model to ./models/tree_7/model_root_f1_2/folder2\model.h5
# Epoch 6/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.6131 - accuracy: 0.6942 - val_loss: 0.5630 - val_accuracy: 0.6775
#
# Epoch 00006: val_accuracy did not improve from 0.75148
# Epoch 7/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.5304 - accuracy: 0.7522 - val_loss: 0.4710 - val_accuracy: 0.8107
#
# Epoch 00007: val_accuracy improved from 0.75148 to 0.81065, saving model to ./models/tree_7/model_root_f1_2/folder2\model.h5
# Epoch 8/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.4445 - accuracy: 0.8115 - val_loss: 0.4344 - val_accuracy: 0.8077
#
# Epoch 00008: val_accuracy did not improve from 0.81065
# Epoch 9/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.3604 - accuracy: 0.8551 - val_loss: 0.3182 - val_accuracy: 0.8609s - loss: 0
#
# Epoch 00009: val_accuracy improved from 0.81065 to 0.86095, saving model to ./models/tree_7/model_root_f1_2/folder2\model.h5
# Epoch 10/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.3040 - accuracy: 0.8746 - val_loss: 0.2832 - val_accuracy: 0.8817
#
# Epoch 00010: val_accuracy improved from 0.86095 to 0.88166, saving model to ./models/tree_7/model_root_f1_2/folder2\model.h5
# Epoch 11/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.2367 - accuracy: 0.9111 - val_loss: 0.2235 - val_accuracy: 0.9024
#
# Epoch 00011: val_accuracy improved from 0.88166 to 0.90237, saving model to ./models/tree_7/model_root_f1_2/folder2\model.h5
# Epoch 12/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1789 - accuracy: 0.9293 - val_loss: 0.2125 - val_accuracy: 0.9053
#
# Epoch 00012: val_accuracy improved from 0.90237 to 0.90533, saving model to ./models/tree_7/model_root_f1_2/folder2\model.h5
# Epoch 13/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1234 - accuracy: 0.9564 - val_loss: 0.2716 - val_accuracy: 0.8935
#
# Epoch 00013: val_accuracy did not improve from 0.90533
# Epoch 14/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1068 - accuracy: 0.9627 - val_loss: 0.2180 - val_accuracy: 0.914253 - accuracy:
#
# Epoch 00014: val_accuracy improved from 0.90533 to 0.91420, saving model to ./models/tree_7/model_root_f1_2/folder2\model.h5
# Epoch 15/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0919 - accuracy: 0.9678 - val_loss: 0.2274 - val_accuracy: 0.9201
#
# Epoch 00015: val_accuracy improved from 0.91420 to 0.92012, saving model to ./models/tree_7/model_root_f1_2/folder2\model.h5
# Epoch 16/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0661 - accuracy: 0.9767 - val_loss: 0.2194 - val_accuracy: 0.9260
#
# Epoch 00016: val_accuracy improved from 0.92012 to 0.92604, saving model to ./models/tree_7/model_root_f1_2/folder2\model.h5
# Epoch 17/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0538 - accuracy: 0.9822 - val_loss: 0.1936 - val_accuracy: 0.9231
#
# Epoch 00017: val_accuracy did not improve from 0.92604
# Epoch 18/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0404 - accuracy: 0.9881 - val_loss: 0.1896 - val_accuracy: 0.9320ss: 0.050
#
# Epoch 00018: val_accuracy improved from 0.92604 to 0.93195, saving model to ./models/tree_7/model_root_f1_2/folder2\model.h5
# Epoch 19/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0153 - accuracy: 0.9962 - val_loss: 0.3193 - val_accuracy: 0.8964
#
# Epoch 00019: val_accuracy did not improve from 0.93195
# Epoch 20/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0183 - accuracy: 0.9941 - val_loss: 0.2590 - val_accuracy: 0.9112
#
# Epoch 00020: val_accuracy did not improve from 0.93195
# Epoch 21/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0226 - accuracy: 0.9928 - val_loss: 0.2504 - val_accuracy: 0.9231
#
# Epoch 00021: val_accuracy did not improve from 0.93195
# Epoch 22/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0185 - accuracy: 0.9945 - val_loss: 0.2105 - val_accuracy: 0.9379
#
# Epoch 00022: val_accuracy improved from 0.93195 to 0.93787, saving model to ./models/tree_7/model_root_f1_2/folder2\model.h5
# Epoch 23/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0313 - accuracy: 0.9898 - val_loss: 0.2931 - val_accuracy: 0.9142
#
# Epoch 00023: val_accuracy did not improve from 0.93787
# Epoch 24/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0466 - accuracy: 0.9856 - val_loss: 0.3259 - val_accuracy: 0.8935
#
# Epoch 00024: val_accuracy did not improve from 0.93787
# Epoch 25/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0250 - accuracy: 0.9915 - val_loss: 0.2346 - val_accuracy: 0.9379
#
# Epoch 00025: val_accuracy did not improve from 0.93787
# Epoch 26/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0078 - accuracy: 0.9992 - val_loss: 0.2283 - val_accuracy: 0.9379
#
# Epoch 00026: val_accuracy did not improve from 0.93787
# Epoch 27/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2439 - val_accuracy: 0.9379
#
# Epoch 00027: val_accuracy did not improve from 0.93787
# Epoch 28/30
# 74/74 [==============================] - 1s 19ms/step - loss: 6.3248e-04 - accuracy: 1.0000 - val_loss: 0.2452 - val_accuracy: 0.9408
#
# Epoch 00028: val_accuracy improved from 0.93787 to 0.94083, saving model to ./models/tree_7/model_root_f1_2/folder2\model.h5
# Epoch 29/30
# 74/74 [==============================] - 1s 19ms/step - loss: 4.4756e-04 - accuracy: 1.0000 - val_loss: 0.2479 - val_accuracy: 0.9408
#
# Epoch 00029: val_accuracy did not improve from 0.94083
# Epoch 30/30
# 74/74 [==============================] - 1s 19ms/step - loss: 3.5766e-04 - accuracy: 1.0000 - val_loss: 0.2522 - val_accuracy: 0.9408
#
# Epoch 00030: val_accuracy did not improve from 0.94083
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Classical'], ['Blues', 'Jazz']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 74/74 [==============================] - 2s 22ms/step - loss: 0.7431 - accuracy: 0.6493 - val_loss: 0.5512 - val_accuracy: 0.6805
#
# Epoch 00001: val_accuracy improved from -inf to 0.68047, saving model to ./models/tree_7/model_root_f1_2/folder3\model.h5
# Epoch 2/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.4013 - accuracy: 0.8187 - val_loss: 0.3807 - val_accuracy: 0.8166
#
# Epoch 00002: val_accuracy improved from 0.68047 to 0.81657, saving model to ./models/tree_7/model_root_f1_2/folder3\model.h5
# Epoch 3/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.2789 - accuracy: 0.8767 - val_loss: 0.1589 - val_accuracy: 0.9527
#
# Epoch 00003: val_accuracy improved from 0.81657 to 0.95266, saving model to ./models/tree_7/model_root_f1_2/folder3\model.h5
# Epoch 4/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1952 - accuracy: 0.9276 - val_loss: 0.1613 - val_accuracy: 0.9438
#
# Epoch 00004: val_accuracy did not improve from 0.95266
# Epoch 5/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1799 - accuracy: 0.9280 - val_loss: 0.1341 - val_accuracy: 0.9556
#
# Epoch 00005: val_accuracy improved from 0.95266 to 0.95562, saving model to ./models/tree_7/model_root_f1_2/folder3\model.h5
# Epoch 6/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1288 - accuracy: 0.9496 - val_loss: 0.1481 - val_accuracy: 0.9497
#
# Epoch 00006: val_accuracy did not improve from 0.95562
# Epoch 7/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1389 - accuracy: 0.9462 - val_loss: 0.1220 - val_accuracy: 0.9675
#
# Epoch 00007: val_accuracy improved from 0.95562 to 0.96746, saving model to ./models/tree_7/model_root_f1_2/folder3\model.h5
# Epoch 8/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1146 - accuracy: 0.9572 - val_loss: 0.1118 - val_accuracy: 0.9675
#
# Epoch 00008: val_accuracy did not improve from 0.96746
# Epoch 9/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0896 - accuracy: 0.9687 - val_loss: 0.1073 - val_accuracy: 0.9615
#
# Epoch 00009: val_accuracy did not improve from 0.96746
# Epoch 10/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0853 - accuracy: 0.9716 - val_loss: 0.1251 - val_accuracy: 0.9586
#
# Epoch 00010: val_accuracy did not improve from 0.96746
# Epoch 11/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0690 - accuracy: 0.9776 - val_loss: 0.0925 - val_accuracy: 0.9734
#
# Epoch 00011: val_accuracy improved from 0.96746 to 0.97337, saving model to ./models/tree_7/model_root_f1_2/folder3\model.h5
# Epoch 12/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0626 - accuracy: 0.9792 - val_loss: 0.0896 - val_accuracy: 0.9822
#
# Epoch 00012: val_accuracy improved from 0.97337 to 0.98225, saving model to ./models/tree_7/model_root_f1_2/folder3\model.h5
# Epoch 13/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0501 - accuracy: 0.9831 - val_loss: 0.1124 - val_accuracy: 0.9645
#
# Epoch 00013: val_accuracy did not improve from 0.98225
# Epoch 14/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0618 - accuracy: 0.9788 - val_loss: 0.1086 - val_accuracy: 0.9704
#
# Epoch 00014: val_accuracy did not improve from 0.98225
# Epoch 15/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0513 - accuracy: 0.9814 - val_loss: 0.1371 - val_accuracy: 0.9645
#
# Epoch 00015: val_accuracy did not improve from 0.98225
# Epoch 16/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0318 - accuracy: 0.9881 - val_loss: 0.0950 - val_accuracy: 0.9793
#
# Epoch 00016: val_accuracy did not improve from 0.98225
# Epoch 17/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0295 - accuracy: 0.9907 - val_loss: 0.2206 - val_accuracy: 0.9201
#
# Epoch 00017: val_accuracy did not improve from 0.98225
# Epoch 18/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0294 - accuracy: 0.9903 - val_loss: 0.1742 - val_accuracy: 0.9467
#
# Epoch 00018: val_accuracy did not improve from 0.98225
# Epoch 19/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0387 - accuracy: 0.9835 - val_loss: 0.1326 - val_accuracy: 0.9704
#
# Epoch 00019: val_accuracy did not improve from 0.98225
# Epoch 20/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0500 - accuracy: 0.9814 - val_loss: 0.1107 - val_accuracy: 0.9704
#
# Epoch 00020: val_accuracy did not improve from 0.98225
# Epoch 21/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0275 - accuracy: 0.9903 - val_loss: 0.1599 - val_accuracy: 0.9556
#
# Epoch 00021: val_accuracy did not improve from 0.98225
# Epoch 22/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0192 - accuracy: 0.9915 - val_loss: 0.1330 - val_accuracy: 0.9763
#
# Epoch 00022: val_accuracy did not improve from 0.98225
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 23/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.1005 - val_accuracy: 0.9852
#
# Epoch 00023: val_accuracy improved from 0.98225 to 0.98521, saving model to ./models/tree_7/model_root_f1_2/folder3\model.h5
# Epoch 24/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0036 - accuracy: 0.9996 - val_loss: 0.1086 - val_accuracy: 0.9882
#
# Epoch 00024: val_accuracy improved from 0.98521 to 0.98817, saving model to ./models/tree_7/model_root_f1_2/folder3\model.h5
# Epoch 25/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0026 - accuracy: 0.9996 - val_loss: 0.1068 - val_accuracy: 0.9852
#
# Epoch 00025: val_accuracy did not improve from 0.98817
# Epoch 26/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9852
#
# Epoch 00026: val_accuracy did not improve from 0.98817
# Epoch 27/30
# 74/74 [==============================] - 1s 19ms/step - loss: 9.5286e-04 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9852
#
# Epoch 00027: val_accuracy did not improve from 0.98817
# Epoch 28/30
# 74/74 [==============================] - 1s 19ms/step - loss: 8.2680e-04 - accuracy: 1.0000 - val_loss: 0.1211 - val_accuracy: 0.9822
#
# Epoch 00028: val_accuracy did not improve from 0.98817
# Epoch 29/30
# 74/74 [==============================] - 1s 19ms/step - loss: 7.7033e-04 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9852
#
# Epoch 00029: val_accuracy did not improve from 0.98817
# Epoch 30/30
# 74/74 [==============================] - 1s 19ms/step - loss: 5.6680e-04 - accuracy: 1.0000 - val_loss: 0.1207 - val_accuracy: 0.9852
#
# Epoch 00030: val_accuracy did not improve from 0.98817
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
