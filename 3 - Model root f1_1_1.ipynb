# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7}
dict_genres = {'Electronic':0, 'Experimental':1, 'Instrumental':4,'International':5, 'Pop' :6}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Electronic', 1: 'Experimental', 4: 'Instrumental', 5: 'International', 6: 'Pop'}

# %%
npzfile = np.load('data/shuffled_train.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394,)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=8).astype(int)

# %%
y_train_max = np.argmax(y_train, axis=1)
y_train_max[y_train_max == 4] = 2
y_train_max[y_train_max == 5] = 3
y_train_max[y_train_max == 6] = 4

# %%
y_train = utils.to_categorical(y_train_max, num_classes=5).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((3998, 640, 128), (3998, 5))

# %%
npzfile = np.load('data/shuffled_valid.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=8).astype(int)

# %%
y_valid_max = np.argmax(y_valid, axis=1)
y_valid_max[y_valid_max == 4] = 2
y_valid_max[y_valid_max == 5] = 3
y_valid_max[y_valid_max == 6] = 4

# %%
y_valid = utils.to_categorical(y_valid_max, num_classes=5).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((500, 640, 128), (500, 5))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Instrumental

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 5
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

BATCH_SIZE = 64
EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = ""):
    n_frames = 640
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_3/model_root_f1_1_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_3/model_root_f1_1_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
model, history = train_model(X_train, y_train, X_valid, y_valid, "folder{}".format(1))
show_summary_stats(history)
# Out:
# Building model...
# Training...
# Epoch 1/30
# 63/63 [==============================] - 22s 192ms/step - loss: 2.1596 - accuracy: 0.2424 - val_loss: 1.4894 - val_accuracy: 0.3540
#
# Epoch 00001: val_accuracy improved from -inf to 0.35400, saving model to ./models/tree_3/model_root_f1_1_1/folder1\model.h5
# Epoch 2/30
# 63/63 [==============================] - 9s 148ms/step - loss: 1.5156 - accuracy: 0.3347 - val_loss: 1.5207 - val_accuracy: 0.3460
#
# Epoch 00002: val_accuracy did not improve from 0.35400
# Epoch 3/30
# 63/63 [==============================] - 9s 148ms/step - loss: 1.4490 - accuracy: 0.3964 - val_loss: 1.4228 - val_accuracy: 0.3560
#
# Epoch 00003: val_accuracy improved from 0.35400 to 0.35600, saving model to ./models/tree_3/model_root_f1_1_1/folder1\model.h5
# Epoch 4/30
# 63/63 [==============================] - 9s 148ms/step - loss: 1.4177 - accuracy: 0.4122 - val_loss: 1.3295 - val_accuracy: 0.5140
#
# Epoch 00004: val_accuracy improved from 0.35600 to 0.51400, saving model to ./models/tree_3/model_root_f1_1_1/folder1\model.h5
# Epoch 5/30
# 63/63 [==============================] - 9s 148ms/step - loss: 1.3086 - accuracy: 0.4822 - val_loss: 1.2793 - val_accuracy: 0.5000
#
# Epoch 00005: val_accuracy did not improve from 0.51400
# Epoch 6/30
# 63/63 [==============================] - 9s 148ms/step - loss: 1.2821 - accuracy: 0.4957 - val_loss: 1.3379 - val_accuracy: 0.4960
#
# Epoch 00006: val_accuracy did not improve from 0.51400
# Epoch 7/30
# 63/63 [==============================] - 9s 148ms/step - loss: 1.2520 - accuracy: 0.5013 - val_loss: 1.2819 - val_accuracy: 0.4860
#
# Epoch 00007: val_accuracy did not improve from 0.51400
# Epoch 8/30
# 63/63 [==============================] - 9s 149ms/step - loss: 1.1690 - accuracy: 0.5563 - val_loss: 1.2526 - val_accuracy: 0.5260
#
# Epoch 00008: val_accuracy improved from 0.51400 to 0.52600, saving model to ./models/tree_3/model_root_f1_1_1/folder1\model.h5
# Epoch 9/30
# 63/63 [==============================] - 9s 149ms/step - loss: 1.0776 - accuracy: 0.5875 - val_loss: 1.3352 - val_accuracy: 0.4500
#
# Epoch 00009: val_accuracy did not improve from 0.52600
# Epoch 10/30
# 63/63 [==============================] - 9s 149ms/step - loss: 1.0068 - accuracy: 0.6188 - val_loss: 1.3341 - val_accuracy: 0.5340
#
# Epoch 00010: val_accuracy improved from 0.52600 to 0.53400, saving model to ./models/tree_3/model_root_f1_1_1/folder1\model.h5
# Epoch 11/30
# 63/63 [==============================] - 9s 149ms/step - loss: 0.9296 - accuracy: 0.6473 - val_loss: 1.4632 - val_accuracy: 0.5120
#
# Epoch 00011: val_accuracy did not improve from 0.53400
# Epoch 12/30
# 63/63 [==============================] - 9s 149ms/step - loss: 0.8344 - accuracy: 0.6898 - val_loss: 1.2926 - val_accuracy: 0.5400
#
# Epoch 00012: val_accuracy improved from 0.53400 to 0.54000, saving model to ./models/tree_3/model_root_f1_1_1/folder1\model.h5
# Epoch 13/30
# 63/63 [==============================] - 9s 149ms/step - loss: 0.7452 - accuracy: 0.7301 - val_loss: 1.4274 - val_accuracy: 0.5200
#
# Epoch 00013: val_accuracy did not improve from 0.54000
# Epoch 14/30
# 63/63 [==============================] - 9s 149ms/step - loss: 0.6098 - accuracy: 0.7771 - val_loss: 1.6823 - val_accuracy: 0.5220
#
# Epoch 00014: val_accuracy did not improve from 0.54000
# Epoch 15/30
# 63/63 [==============================] - 9s 150ms/step - loss: 0.4822 - accuracy: 0.8297 - val_loss: 2.0347 - val_accuracy: 0.5020
#
# Epoch 00015: val_accuracy did not improve from 0.54000
# Epoch 16/30
# 63/63 [==============================] - 9s 150ms/step - loss: 0.3976 - accuracy: 0.8619 - val_loss: 2.6183 - val_accuracy: 0.4440
#
# Epoch 00016: val_accuracy did not improve from 0.54000
# Epoch 17/30
# 63/63 [==============================] - 9s 150ms/step - loss: 0.3156 - accuracy: 0.8879 - val_loss: 2.5397 - val_accuracy: 0.4720
#
# Epoch 00017: val_accuracy did not improve from 0.54000
# Epoch 18/30
# 63/63 [==============================] - 9s 150ms/step - loss: 0.2631 - accuracy: 0.9092 - val_loss: 2.7362 - val_accuracy: 0.4660
#
# Epoch 00018: val_accuracy did not improve from 0.54000
# Epoch 19/30
# 63/63 [==============================] - 9s 149ms/step - loss: 0.1782 - accuracy: 0.9457 - val_loss: 2.9237 - val_accuracy: 0.4760
#
# Epoch 00019: val_accuracy did not improve from 0.54000
# Epoch 20/30
# 63/63 [==============================] - 9s 150ms/step - loss: 0.1124 - accuracy: 0.9687 - val_loss: 3.4027 - val_accuracy: 0.4760
#
# Epoch 00020: val_accuracy did not improve from 0.54000
# Epoch 21/30
# 63/63 [==============================] - 9s 150ms/step - loss: 0.0744 - accuracy: 0.9790 - val_loss: 3.8271 - val_accuracy: 0.4600
#
# Epoch 00021: val_accuracy did not improve from 0.54000
# Epoch 22/30
# 63/63 [==============================] - 9s 150ms/step - loss: 0.0707 - accuracy: 0.9815 - val_loss: 4.0559 - val_accuracy: 0.4720
#
# Epoch 00022: val_accuracy did not improve from 0.54000
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 23/30
# 63/63 [==============================] - 9s 150ms/step - loss: 0.0307 - accuracy: 0.9945 - val_loss: 4.0943 - val_accuracy: 0.4580
#
# Epoch 00023: val_accuracy did not improve from 0.54000
# Epoch 24/30
# 63/63 [==============================] - 9s 150ms/step - loss: 0.0119 - accuracy: 0.9987 - val_loss: 4.4700 - val_accuracy: 0.4580
#
# Epoch 00024: val_accuracy did not improve from 0.54000
# Epoch 25/30
# 63/63 [==============================] - 9s 150ms/step - loss: 0.0111 - accuracy: 0.9990 - val_loss: 4.5427 - val_accuracy: 0.4560
#
# Epoch 00025: val_accuracy did not improve from 0.54000
# Epoch 26/30
# 63/63 [==============================] - 9s 150ms/step - loss: 0.0071 - accuracy: 0.9995 - val_loss: 4.6177 - val_accuracy: 0.4460
#
# Epoch 00026: val_accuracy did not improve from 0.54000
# Epoch 27/30
# 63/63 [==============================] - 9s 150ms/step - loss: 0.0063 - accuracy: 0.9995 - val_loss: 4.9085 - val_accuracy: 0.4560
#
# Epoch 00027: val_accuracy did not improve from 0.54000
# Epoch 28/30
# 63/63 [==============================] - 9s 150ms/step - loss: 0.0079 - accuracy: 0.9992 - val_loss: 4.9311 - val_accuracy: 0.4500
#
# Epoch 00028: val_accuracy did not improve from 0.54000
# Epoch 29/30
# 63/63 [==============================] - 9s 149ms/step - loss: 0.0054 - accuracy: 0.9995 - val_loss: 5.0623 - val_accuracy: 0.4580
#
# Epoch 00029: val_accuracy did not improve from 0.54000
# Epoch 30/30
# 63/63 [==============================] - 9s 150ms/step - loss: 0.0041 - accuracy: 0.9995 - val_loss: 5.1111 - val_accuracy: 0.4520
#
# Epoch 00030: val_accuracy did not improve from 0.54000
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
