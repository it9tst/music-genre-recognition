# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Blues':0, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Pop':7, 'Reggae':8, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Blues', 2: 'Country', 3: 'Disco', 4: 'Hip-Hop', 5: 'Jazz', 7: 'Pop', 8: 'Reggae', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((6390, 128, 128), (6390, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((800, 128, 128), (800, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Disco

# %% [markdown]
# ## Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation='softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_11/model_root_f1_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_11/model_root_f1_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 8
n_splits = 15

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    dict_genres_list = list(dict_genres.values())
    split = [[dict_genres_list.pop(fold_no - 1)], dict_genres_list]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Blues'], ['Country', 'Disco', 'Hip-Hop', 'Jazz', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 210/210 [==============================] - 8s 22ms/step - loss: 0.4396 - accuracy: 0.8700 - val_loss: 0.3798 - val_accuracy: 0.8750
#
# Epoch 00001: val_accuracy improved from -inf to 0.87500, saving model to ./models/tree_11/model_root_f1_1/folder1\model.h5
# Epoch 2/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.3644 - accuracy: 0.8733 - val_loss: 0.3378 - val_accuracy: 0.8750
#
# Epoch 00002: val_accuracy did not improve from 0.87500
# Epoch 3/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.3142 - accuracy: 0.8748 - val_loss: 0.3204 - val_accuracy: 0.8771
#
# Epoch 00003: val_accuracy improved from 0.87500 to 0.87708, saving model to ./models/tree_11/model_root_f1_1/folder1\model.h5
# Epoch 4/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.2894 - accuracy: 0.8806 - val_loss: 0.3025 - val_accuracy: 0.8771
#
# Epoch 00004: val_accuracy did not improve from 0.87708
# Epoch 5/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.2485 - accuracy: 0.8985 - val_loss: 0.2598 - val_accuracy: 0.9021
#
# Epoch 00005: val_accuracy improved from 0.87708 to 0.90208, saving model to ./models/tree_11/model_root_f1_1/folder1\model.h5
# Epoch 6/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.2046 - accuracy: 0.9154 - val_loss: 0.2147 - val_accuracy: 0.9271
#
# Epoch 00006: val_accuracy improved from 0.90208 to 0.92708, saving model to ./models/tree_11/model_root_f1_1/folder1\model.h5
# Epoch 7/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.1761 - accuracy: 0.9276 - val_loss: 0.2000 - val_accuracy: 0.9167
#
# Epoch 00007: val_accuracy did not improve from 0.92708
# Epoch 8/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.1537 - accuracy: 0.9389 - val_loss: 0.2356 - val_accuracy: 0.9104
#
# Epoch 00008: val_accuracy did not improve from 0.92708
# Epoch 9/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.1361 - accuracy: 0.9459 - val_loss: 0.2325 - val_accuracy: 0.9167
#
# Epoch 00009: val_accuracy did not improve from 0.92708
# Epoch 10/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0969 - accuracy: 0.9595 - val_loss: 0.1937 - val_accuracy: 0.9312
#
# Epoch 00010: val_accuracy improved from 0.92708 to 0.93125, saving model to ./models/tree_11/model_root_f1_1/folder1\model.h5
# Epoch 11/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0824 - accuracy: 0.9683 - val_loss: 0.2386 - val_accuracy: 0.9396
#
# Epoch 00011: val_accuracy improved from 0.93125 to 0.93958, saving model to ./models/tree_11/model_root_f1_1/folder1\model.h5
# Epoch 12/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0607 - accuracy: 0.9782 - val_loss: 0.2186 - val_accuracy: 0.9375
#
# Epoch 00012: val_accuracy did not improve from 0.93958
# Epoch 13/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0571 - accuracy: 0.9781 - val_loss: 0.2344 - val_accuracy: 0.9417
#
# Epoch 00013: val_accuracy improved from 0.93958 to 0.94167, saving model to ./models/tree_11/model_root_f1_1/folder1\model.h5
# Epoch 14/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0610 - accuracy: 0.9770 - val_loss: 0.4666 - val_accuracy: 0.9104
#
# Epoch 00014: val_accuracy did not improve from 0.94167
# Epoch 15/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0324 - accuracy: 0.9893 - val_loss: 0.2929 - val_accuracy: 0.9229
#
# Epoch 00015: val_accuracy did not improve from 0.94167
# Epoch 16/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0235 - accuracy: 0.9909 - val_loss: 0.4844 - val_accuracy: 0.9250
#
# Epoch 00016: val_accuracy did not improve from 0.94167
# Epoch 17/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0437 - accuracy: 0.9849 - val_loss: 0.2722 - val_accuracy: 0.9312
#
# Epoch 00017: val_accuracy did not improve from 0.94167
# Epoch 18/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0147 - accuracy: 0.9949 - val_loss: 0.3725 - val_accuracy: 0.8958
#
# Epoch 00018: val_accuracy did not improve from 0.94167
# Epoch 19/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0214 - accuracy: 0.9909 - val_loss: 0.4404 - val_accuracy: 0.9354
#
# Epoch 00019: val_accuracy did not improve from 0.94167
# Epoch 20/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0250 - accuracy: 0.9905 - val_loss: 0.2992 - val_accuracy: 0.9375
#
# Epoch 00020: val_accuracy did not improve from 0.94167
# Epoch 21/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0350 - accuracy: 0.9873 - val_loss: 0.3374 - val_accuracy: 0.8938
#
# Epoch 00021: val_accuracy did not improve from 0.94167
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 22/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0108 - accuracy: 0.9969 - val_loss: 0.3667 - val_accuracy: 0.9333
#
# Epoch 00022: val_accuracy did not improve from 0.94167
# Epoch 23/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3964 - val_accuracy: 0.9396
#
# Epoch 00023: val_accuracy did not improve from 0.94167
# Epoch 24/30
# 210/210 [==============================] - 4s 19ms/step - loss: 8.2992e-04 - accuracy: 1.0000 - val_loss: 0.4349 - val_accuracy: 0.9375
#
# Epoch 00024: val_accuracy did not improve from 0.94167
# Epoch 25/30
# 210/210 [==============================] - 4s 19ms/step - loss: 5.1244e-04 - accuracy: 1.0000 - val_loss: 0.3915 - val_accuracy: 0.9375
#
# Epoch 00025: val_accuracy did not improve from 0.94167
# Epoch 26/30
# 210/210 [==============================] - 4s 19ms/step - loss: 3.8722e-04 - accuracy: 1.0000 - val_loss: 0.4214 - val_accuracy: 0.9354
#
# Epoch 00026: val_accuracy did not improve from 0.94167
# Epoch 27/30
# 210/210 [==============================] - 4s 19ms/step - loss: 3.0476e-04 - accuracy: 1.0000 - val_loss: 0.4172 - val_accuracy: 0.9375
#
# Epoch 00027: val_accuracy did not improve from 0.94167
# Epoch 28/30
# 210/210 [==============================] - 4s 19ms/step - loss: 2.4280e-04 - accuracy: 1.0000 - val_loss: 0.4242 - val_accuracy: 0.9375
#
# Epoch 00028: val_accuracy did not improve from 0.94167
# Epoch 29/30
# 210/210 [==============================] - 4s 19ms/step - loss: 2.0352e-04 - accuracy: 1.0000 - val_loss: 0.4401 - val_accuracy: 0.9396
#
# Epoch 00029: val_accuracy did not improve from 0.94167
# Epoch 30/30
# 210/210 [==============================] - 4s 19ms/step - loss: 1.6871e-04 - accuracy: 1.0000 - val_loss: 0.4498 - val_accuracy: 0.9396
#
# Epoch 00030: val_accuracy did not improve from 0.94167
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Country'], ['Blues', 'Disco', 'Hip-Hop', 'Jazz', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.3985 - accuracy: 0.8678 - val_loss: 0.2866 - val_accuracy: 0.8854
#
# Epoch 00001: val_accuracy improved from -inf to 0.88542, saving model to ./models/tree_11/model_root_f1_1/folder2\model.h5
# Epoch 2/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.2936 - accuracy: 0.8775 - val_loss: 0.2822 - val_accuracy: 0.8750
#
# Epoch 00002: val_accuracy did not improve from 0.88542
# Epoch 3/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.2569 - accuracy: 0.8870 - val_loss: 0.2809 - val_accuracy: 0.8833
#
# Epoch 00003: val_accuracy did not improve from 0.88542
# Epoch 4/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.2443 - accuracy: 0.8939 - val_loss: 0.2833 - val_accuracy: 0.8667
#
# Epoch 00004: val_accuracy did not improve from 0.88542
# Epoch 5/30
# 210/210 [==============================] - 5s 22ms/step - loss: 0.2155 - accuracy: 0.9083 - val_loss: 0.2205 - val_accuracy: 0.9146
#
# Epoch 00005: val_accuracy improved from 0.88542 to 0.91458, saving model to ./models/tree_11/model_root_f1_1/folder2\model.h5
# Epoch 6/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.1879 - accuracy: 0.9215 - val_loss: 0.2266 - val_accuracy: 0.9146
#
# Epoch 00006: val_accuracy did not improve from 0.91458
# Epoch 7/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.1565 - accuracy: 0.9374 - val_loss: 0.1999 - val_accuracy: 0.9250
#
# Epoch 00007: val_accuracy improved from 0.91458 to 0.92500, saving model to ./models/tree_11/model_root_f1_1/folder2\model.h5
# Epoch 8/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.1320 - accuracy: 0.9459 - val_loss: 0.1661 - val_accuracy: 0.9375
#
# Epoch 00008: val_accuracy improved from 0.92500 to 0.93750, saving model to ./models/tree_11/model_root_f1_1/folder2\model.h5
# Epoch 9/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.1104 - accuracy: 0.9581 - val_loss: 0.1956 - val_accuracy: 0.9354
#
# Epoch 00009: val_accuracy did not improve from 0.93750
# Epoch 10/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0877 - accuracy: 0.9653 - val_loss: 0.3055 - val_accuracy: 0.9125
#
# Epoch 00010: val_accuracy did not improve from 0.93750
# Epoch 11/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0663 - accuracy: 0.9776 - val_loss: 0.2448 - val_accuracy: 0.9333
#
# Epoch 00011: val_accuracy did not improve from 0.93750
# Epoch 12/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0431 - accuracy: 0.9851 - val_loss: 0.3036 - val_accuracy: 0.9312
#
# Epoch 00012: val_accuracy did not improve from 0.93750
# Epoch 13/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0324 - accuracy: 0.9900 - val_loss: 0.2557 - val_accuracy: 0.9250
#
# Epoch 00013: val_accuracy did not improve from 0.93750
# Epoch 14/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0253 - accuracy: 0.9899 - val_loss: 0.2942 - val_accuracy: 0.9458
#
# Epoch 00014: val_accuracy improved from 0.93750 to 0.94583, saving model to ./models/tree_11/model_root_f1_1/folder2\model.h5
# Epoch 15/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0152 - accuracy: 0.9954 - val_loss: 0.2984 - val_accuracy: 0.9312
#
# Epoch 00015: val_accuracy did not improve from 0.94583
# Epoch 16/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0142 - accuracy: 0.9948 - val_loss: 0.3241 - val_accuracy: 0.9333
#
# Epoch 00016: val_accuracy did not improve from 0.94583
# Epoch 17/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.0161 - accuracy: 0.9940 - val_loss: 0.3724 - val_accuracy: 0.9187
#
# Epoch 00017: val_accuracy did not improve from 0.94583
# Epoch 18/30
# 210/210 [==============================] - 4s 21ms/step - loss: 0.0150 - accuracy: 0.9942 - val_loss: 0.4861 - val_accuracy: 0.8771
#
# Epoch 00018: val_accuracy did not improve from 0.94583
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 19/30
# 210/210 [==============================] - 5s 22ms/step - loss: 0.0105 - accuracy: 0.9978 - val_loss: 0.3926 - val_accuracy: 0.9354
#
# Epoch 00019: val_accuracy did not improve from 0.94583
# Epoch 20/30
# 210/210 [==============================] - 4s 20ms/step - loss: 6.5221e-04 - accuracy: 1.0000 - val_loss: 0.3788 - val_accuracy: 0.9333
#
# Epoch 00020: val_accuracy did not improve from 0.94583
# Epoch 21/30
# 210/210 [==============================] - 4s 21ms/step - loss: 3.4528e-04 - accuracy: 1.0000 - val_loss: 0.3933 - val_accuracy: 0.9333
#
# Epoch 00021: val_accuracy did not improve from 0.94583
# Epoch 22/30
# 210/210 [==============================] - 4s 19ms/step - loss: 2.4742e-04 - accuracy: 1.0000 - val_loss: 0.3971 - val_accuracy: 0.9333
#
# Epoch 00022: val_accuracy did not improve from 0.94583
# Epoch 23/30
# 210/210 [==============================] - 4s 20ms/step - loss: 1.9225e-04 - accuracy: 1.0000 - val_loss: 0.4048 - val_accuracy: 0.9333
#
# Epoch 00023: val_accuracy did not improve from 0.94583
# Epoch 24/30
# 210/210 [==============================] - 4s 18ms/step - loss: 1.5363e-04 - accuracy: 1.0000 - val_loss: 0.4107 - val_accuracy: 0.9333
#
# Epoch 00024: val_accuracy did not improve from 0.94583
# Epoch 25/30
# 210/210 [==============================] - 4s 18ms/step - loss: 1.2606e-04 - accuracy: 1.0000 - val_loss: 0.4137 - val_accuracy: 0.9333
#
# Epoch 00025: val_accuracy did not improve from 0.94583
# Epoch 26/30
# 210/210 [==============================] - 4s 18ms/step - loss: 1.0489e-04 - accuracy: 1.0000 - val_loss: 0.4211 - val_accuracy: 0.9333
#
# Epoch 00026: val_accuracy did not improve from 0.94583
# Epoch 27/30
# 210/210 [==============================] - 4s 18ms/step - loss: 8.7807e-05 - accuracy: 1.0000 - val_loss: 0.4258 - val_accuracy: 0.9333
#
# Epoch 00027: val_accuracy did not improve from 0.94583
# Epoch 28/30
# 210/210 [==============================] - 4s 18ms/step - loss: 7.4302e-05 - accuracy: 1.0000 - val_loss: 0.4299 - val_accuracy: 0.9333
#
# Epoch 00028: val_accuracy did not improve from 0.94583
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 29/30
# 210/210 [==============================] - 4s 18ms/step - loss: 6.4576e-05 - accuracy: 1.0000 - val_loss: 0.4323 - val_accuracy: 0.9333
#
# Epoch 00029: val_accuracy did not improve from 0.94583
# Epoch 30/30
# 210/210 [==============================] - 4s 18ms/step - loss: 5.9754e-05 - accuracy: 1.0000 - val_loss: 0.4352 - val_accuracy: 0.9333
#
# Epoch 00030: val_accuracy did not improve from 0.94583
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Disco'], ['Blues', 'Country', 'Hip-Hop', 'Jazz', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.3939 - accuracy: 0.8696 - val_loss: 0.4161 - val_accuracy: 0.8438
#
# Epoch 00001: val_accuracy improved from -inf to 0.84375, saving model to ./models/tree_11/model_root_f1_1/folder3\model.h5
# Epoch 2/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.3522 - accuracy: 0.8768 - val_loss: 0.3929 - val_accuracy: 0.8438
#
# Epoch 00002: val_accuracy did not improve from 0.84375
# Epoch 3/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.3285 - accuracy: 0.8772 - val_loss: 0.4768 - val_accuracy: 0.8438
#
# Epoch 00003: val_accuracy did not improve from 0.84375
# Epoch 4/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.3054 - accuracy: 0.8775 - val_loss: 0.2921 - val_accuracy: 0.8646
#
# Epoch 00004: val_accuracy improved from 0.84375 to 0.86458, saving model to ./models/tree_11/model_root_f1_1/folder3\model.h5
# Epoch 5/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.2355 - accuracy: 0.9089 - val_loss: 0.2637 - val_accuracy: 0.9062
#
# Epoch 00005: val_accuracy improved from 0.86458 to 0.90625, saving model to ./models/tree_11/model_root_f1_1/folder3\model.h5
# Epoch 6/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.2014 - accuracy: 0.9243 - val_loss: 0.1990 - val_accuracy: 0.9312
#
# Epoch 00006: val_accuracy improved from 0.90625 to 0.93125, saving model to ./models/tree_11/model_root_f1_1/folder3\model.h5
# Epoch 7/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.1617 - accuracy: 0.9429 - val_loss: 0.2919 - val_accuracy: 0.9167
#
# Epoch 00007: val_accuracy did not improve from 0.93125
# Epoch 8/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.1480 - accuracy: 0.9484 - val_loss: 0.1876 - val_accuracy: 0.9292
#
# Epoch 00008: val_accuracy did not improve from 0.93125
# Epoch 9/30
# 210/210 [==============================] - 4s 21ms/step - loss: 0.1350 - accuracy: 0.9557 - val_loss: 0.2535 - val_accuracy: 0.9125
#
# Epoch 00009: val_accuracy did not improve from 0.93125
# Epoch 10/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.1033 - accuracy: 0.9674 - val_loss: 0.1569 - val_accuracy: 0.9563
#
# Epoch 00010: val_accuracy improved from 0.93125 to 0.95625, saving model to ./models/tree_11/model_root_f1_1/folder3\model.h5
# Epoch 11/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0885 - accuracy: 0.9683 - val_loss: 0.1443 - val_accuracy: 0.9479
#
# Epoch 00011: val_accuracy did not improve from 0.95625
# Epoch 12/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0651 - accuracy: 0.9773 - val_loss: 0.1847 - val_accuracy: 0.9500
#
# Epoch 00012: val_accuracy did not improve from 0.95625
# Epoch 13/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0478 - accuracy: 0.9852 - val_loss: 0.1361 - val_accuracy: 0.9563
#
# Epoch 00013: val_accuracy did not improve from 0.95625
# Epoch 14/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0350 - accuracy: 0.9885 - val_loss: 0.2248 - val_accuracy: 0.9438
#
# Epoch 00014: val_accuracy did not improve from 0.95625
# Epoch 15/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.0458 - accuracy: 0.9838 - val_loss: 0.1713 - val_accuracy: 0.9479
#
# Epoch 00015: val_accuracy did not improve from 0.95625
# Epoch 16/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0223 - accuracy: 0.9921 - val_loss: 0.2310 - val_accuracy: 0.9479
#
# Epoch 00016: val_accuracy did not improve from 0.95625
# Epoch 17/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0346 - accuracy: 0.9870 - val_loss: 0.2252 - val_accuracy: 0.9542
#
# Epoch 00017: val_accuracy did not improve from 0.95625
# Epoch 18/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0090 - accuracy: 0.9975 - val_loss: 0.2218 - val_accuracy: 0.9646
#
# Epoch 00018: val_accuracy improved from 0.95625 to 0.96458, saving model to ./models/tree_11/model_root_f1_1/folder3\model.h5
# Epoch 19/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.0219 - accuracy: 0.9912 - val_loss: 0.3765 - val_accuracy: 0.9354
#
# Epoch 00019: val_accuracy did not improve from 0.96458
# Epoch 20/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.0363 - accuracy: 0.9876 - val_loss: 0.2429 - val_accuracy: 0.9521
#
# Epoch 00020: val_accuracy did not improve from 0.96458
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.0022 - accuracy: 0.9999 - val_loss: 0.2598 - val_accuracy: 0.9500
#
# Epoch 00021: val_accuracy did not improve from 0.96458
# Epoch 22/30
# 210/210 [==============================] - 5s 22ms/step - loss: 6.6465e-04 - accuracy: 1.0000 - val_loss: 0.2682 - val_accuracy: 0.9521
#
# Epoch 00022: val_accuracy did not improve from 0.96458
# Epoch 23/30
# 210/210 [==============================] - 4s 19ms/step - loss: 4.2232e-04 - accuracy: 1.0000 - val_loss: 0.2767 - val_accuracy: 0.9542
#
# Epoch 00023: val_accuracy did not improve from 0.96458
# Epoch 24/30
# 210/210 [==============================] - 4s 18ms/step - loss: 3.1352e-04 - accuracy: 1.0000 - val_loss: 0.2840 - val_accuracy: 0.9542
#
# Epoch 00024: val_accuracy did not improve from 0.96458
# Epoch 25/30
# 210/210 [==============================] - 4s 18ms/step - loss: 2.4242e-04 - accuracy: 1.0000 - val_loss: 0.2889 - val_accuracy: 0.9542
#
# Epoch 00025: val_accuracy did not improve from 0.96458
# Epoch 26/30
# 210/210 [==============================] - 4s 18ms/step - loss: 1.9617e-04 - accuracy: 1.0000 - val_loss: 0.2945 - val_accuracy: 0.9542
#
# Epoch 00026: val_accuracy did not improve from 0.96458
# Epoch 27/30
# 210/210 [==============================] - 4s 21ms/step - loss: 1.5876e-04 - accuracy: 1.0000 - val_loss: 0.3038 - val_accuracy: 0.9542
#
# Epoch 00027: val_accuracy did not improve from 0.96458
# Epoch 28/30
# 210/210 [==============================] - 4s 19ms/step - loss: 1.2949e-04 - accuracy: 1.0000 - val_loss: 0.3081 - val_accuracy: 0.9542
#
# Epoch 00028: val_accuracy did not improve from 0.96458
# Epoch 29/30
# 210/210 [==============================] - 4s 18ms/step - loss: 1.0888e-04 - accuracy: 1.0000 - val_loss: 0.3131 - val_accuracy: 0.9542
#
# Epoch 00029: val_accuracy did not improve from 0.96458
# Epoch 30/30
# 210/210 [==============================] - 4s 17ms/step - loss: 9.2816e-05 - accuracy: 1.0000 - val_loss: 0.3178 - val_accuracy: 0.9542
#
# Epoch 00030: val_accuracy did not improve from 0.96458
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Hip-Hop'], ['Blues', 'Country', 'Disco', 'Jazz', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 210/210 [==============================] - 5s 23ms/step - loss: 0.3332 - accuracy: 0.8686 - val_loss: 0.2461 - val_accuracy: 0.8979
#
# Epoch 00001: val_accuracy improved from -inf to 0.89792, saving model to ./models/tree_11/model_root_f1_1/folder4\model.h5
# Epoch 2/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.2316 - accuracy: 0.8999 - val_loss: 0.1500 - val_accuracy: 0.9396
#
# Epoch 00002: val_accuracy improved from 0.89792 to 0.93958, saving model to ./models/tree_11/model_root_f1_1/folder4\model.h5
# Epoch 3/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.1940 - accuracy: 0.9151 - val_loss: 0.1290 - val_accuracy: 0.9563
#
# Epoch 00003: val_accuracy improved from 0.93958 to 0.95625, saving model to ./models/tree_11/model_root_f1_1/folder4\model.h5
# Epoch 4/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.1609 - accuracy: 0.9323 - val_loss: 0.1190 - val_accuracy: 0.9604
#
# Epoch 00004: val_accuracy improved from 0.95625 to 0.96042, saving model to ./models/tree_11/model_root_f1_1/folder4\model.h5
# Epoch 5/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.1365 - accuracy: 0.9459 - val_loss: 0.1086 - val_accuracy: 0.9500
#
# Epoch 00005: val_accuracy did not improve from 0.96042
# Epoch 6/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0948 - accuracy: 0.9641 - val_loss: 0.0857 - val_accuracy: 0.9708
#
# Epoch 00006: val_accuracy improved from 0.96042 to 0.97083, saving model to ./models/tree_11/model_root_f1_1/folder4\model.h5
# Epoch 7/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0641 - accuracy: 0.9747 - val_loss: 0.1150 - val_accuracy: 0.9646
#
# Epoch 00007: val_accuracy did not improve from 0.97083
# Epoch 8/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0498 - accuracy: 0.9820 - val_loss: 0.1051 - val_accuracy: 0.9604
#
# Epoch 00008: val_accuracy did not improve from 0.97083
# Epoch 9/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0305 - accuracy: 0.9890 - val_loss: 0.0732 - val_accuracy: 0.9708
#
# Epoch 00009: val_accuracy did not improve from 0.97083
# Epoch 10/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0269 - accuracy: 0.9897 - val_loss: 0.0926 - val_accuracy: 0.9625
#
# Epoch 00010: val_accuracy did not improve from 0.97083
# Epoch 11/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0316 - accuracy: 0.9878 - val_loss: 0.1030 - val_accuracy: 0.9771
#
# Epoch 00011: val_accuracy improved from 0.97083 to 0.97708, saving model to ./models/tree_11/model_root_f1_1/folder4\model.h5
# Epoch 12/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0179 - accuracy: 0.9937 - val_loss: 0.1039 - val_accuracy: 0.9729
#
# Epoch 00012: val_accuracy did not improve from 0.97708
# Epoch 13/30
# 210/210 [==============================] - 4s 21ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.1746 - val_accuracy: 0.9458
#
# Epoch 00013: val_accuracy did not improve from 0.97708
# Epoch 14/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.0163 - accuracy: 0.9949 - val_loss: 0.0694 - val_accuracy: 0.9646
#
# Epoch 00014: val_accuracy did not improve from 0.97708
# Epoch 15/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0144 - accuracy: 0.9949 - val_loss: 0.0977 - val_accuracy: 0.9688
#
# Epoch 00015: val_accuracy did not improve from 0.97708
# Epoch 16/30
# 210/210 [==============================] - 4s 17ms/step - loss: 0.0317 - accuracy: 0.9893 - val_loss: 0.0740 - val_accuracy: 0.9792
#
# Epoch 00016: val_accuracy improved from 0.97708 to 0.97917, saving model to ./models/tree_11/model_root_f1_1/folder4\model.h5
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 17/30
# 210/210 [==============================] - 4s 17ms/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 0.0864 - val_accuracy: 0.9792
#
# Epoch 00017: val_accuracy did not improve from 0.97917
# Epoch 18/30
# 210/210 [==============================] - 4s 19ms/step - loss: 5.3222e-04 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 0.9750
#
# Epoch 00018: val_accuracy did not improve from 0.97917
# Epoch 19/30
# 210/210 [==============================] - 4s 20ms/step - loss: 2.7982e-04 - accuracy: 1.0000 - val_loss: 0.1020 - val_accuracy: 0.9750
#
# Epoch 00019: val_accuracy did not improve from 0.97917
# Epoch 20/30
# 210/210 [==============================] - 4s 20ms/step - loss: 1.9942e-04 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9750
#
# Epoch 00020: val_accuracy did not improve from 0.97917
# Epoch 21/30
# 210/210 [==============================] - 4s 20ms/step - loss: 1.5200e-04 - accuracy: 1.0000 - val_loss: 0.1060 - val_accuracy: 0.9750
#
# Epoch 00021: val_accuracy did not improve from 0.97917
# Epoch 22/30
# 210/210 [==============================] - 4s 18ms/step - loss: 1.2098e-04 - accuracy: 1.0000 - val_loss: 0.1064 - val_accuracy: 0.9750
#
# Epoch 00022: val_accuracy did not improve from 0.97917
# Epoch 23/30
# 210/210 [==============================] - 4s 18ms/step - loss: 9.7625e-05 - accuracy: 1.0000 - val_loss: 0.1075 - val_accuracy: 0.9750
#
# Epoch 00023: val_accuracy did not improve from 0.97917
# Epoch 24/30
# 210/210 [==============================] - 4s 20ms/step - loss: 7.9530e-05 - accuracy: 1.0000 - val_loss: 0.1128 - val_accuracy: 0.9750
#
# Epoch 00024: val_accuracy did not improve from 0.97917
# Epoch 25/30
# 210/210 [==============================] - 4s 19ms/step - loss: 6.6817e-05 - accuracy: 1.0000 - val_loss: 0.1102 - val_accuracy: 0.9750
#
# Epoch 00025: val_accuracy did not improve from 0.97917
# Epoch 26/30
# 210/210 [==============================] - 4s 20ms/step - loss: 5.5217e-05 - accuracy: 1.0000 - val_loss: 0.1066 - val_accuracy: 0.9771
#
# Epoch 00026: val_accuracy did not improve from 0.97917
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 27/30
# 210/210 [==============================] - 4s 19ms/step - loss: 4.7329e-05 - accuracy: 1.0000 - val_loss: 0.1094 - val_accuracy: 0.9771
#
# Epoch 00027: val_accuracy did not improve from 0.97917
# Epoch 28/30
# 210/210 [==============================] - 4s 19ms/step - loss: 4.3006e-05 - accuracy: 1.0000 - val_loss: 0.1119 - val_accuracy: 0.9750
#
# Epoch 00028: val_accuracy did not improve from 0.97917
# Epoch 29/30
# 210/210 [==============================] - ETA: 0s - loss: 3.9442e-05 - accuracy: 1.00 - 4s 19ms/step - loss: 3.9469e-05 - accuracy: 1.0000 - val_loss: 0.1124 - val_accuracy: 0.9750
#
# Epoch 00029: val_accuracy did not improve from 0.97917
# Epoch 30/30
# 210/210 [==============================] - 4s 18ms/step - loss: 3.6120e-05 - accuracy: 1.0000 - val_loss: 0.1142 - val_accuracy: 0.9771
#
# Epoch 00030: val_accuracy did not improve from 0.97917
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 5
# Genre split [['Jazz'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.3627 - accuracy: 0.8738 - val_loss: 0.2507 - val_accuracy: 0.8771
#
# Epoch 00001: val_accuracy improved from -inf to 0.87708, saving model to ./models/tree_11/model_root_f1_1/folder5\model.h5
# Epoch 2/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.2025 - accuracy: 0.9151 - val_loss: 0.1665 - val_accuracy: 0.9354
#
# Epoch 00002: val_accuracy improved from 0.87708 to 0.93542, saving model to ./models/tree_11/model_root_f1_1/folder5\model.h5
# Epoch 3/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.1615 - accuracy: 0.9328 - val_loss: 0.0985 - val_accuracy: 0.9625
#
# Epoch 00003: val_accuracy improved from 0.93542 to 0.96250, saving model to ./models/tree_11/model_root_f1_1/folder5\model.h5
# Epoch 4/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.1207 - accuracy: 0.9525 - val_loss: 0.1351 - val_accuracy: 0.9646
#
# Epoch 00004: val_accuracy improved from 0.96250 to 0.96458, saving model to ./models/tree_11/model_root_f1_1/folder5\model.h5
# Epoch 5/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.1000 - accuracy: 0.9615 - val_loss: 0.0700 - val_accuracy: 0.9750
#
# Epoch 00005: val_accuracy improved from 0.96458 to 0.97500, saving model to ./models/tree_11/model_root_f1_1/folder5\model.h5
# Epoch 6/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0689 - accuracy: 0.9748 - val_loss: 0.0967 - val_accuracy: 0.9688
#
# Epoch 00006: val_accuracy did not improve from 0.97500
# Epoch 7/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0471 - accuracy: 0.9820 - val_loss: 0.0580 - val_accuracy: 0.9771
#
# Epoch 00007: val_accuracy improved from 0.97500 to 0.97708, saving model to ./models/tree_11/model_root_f1_1/folder5\model.h5
# Epoch 8/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0353 - accuracy: 0.9869 - val_loss: 0.0606 - val_accuracy: 0.9729
#
# Epoch 00008: val_accuracy did not improve from 0.97708
# Epoch 9/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0313 - accuracy: 0.9882 - val_loss: 0.0620 - val_accuracy: 0.9750
#
# Epoch 00009: val_accuracy did not improve from 0.97708
# Epoch 10/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0302 - accuracy: 0.9885 - val_loss: 0.0566 - val_accuracy: 0.9750
#
# Epoch 00010: val_accuracy did not improve from 0.97708
# Epoch 11/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0167 - accuracy: 0.9927 - val_loss: 0.0964 - val_accuracy: 0.9688
#
# Epoch 00011: val_accuracy did not improve from 0.97708
# Epoch 12/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0023 - accuracy: 0.9999 - val_loss: 0.0900 - val_accuracy: 0.9750
#
# Epoch 00012: val_accuracy did not improve from 0.97708
# Epoch 13/30
# 210/210 [==============================] - 4s 18ms/step - loss: 4.9098e-04 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 0.9792
#
# Epoch 00013: val_accuracy improved from 0.97708 to 0.97917, saving model to ./models/tree_11/model_root_f1_1/folder5\model.h5
# Epoch 14/30
# 210/210 [==============================] - 4s 18ms/step - loss: 1.0730e-04 - accuracy: 1.0000 - val_loss: 0.0639 - val_accuracy: 0.9833
#
# Epoch 00014: val_accuracy improved from 0.97917 to 0.98333, saving model to ./models/tree_11/model_root_f1_1/folder5\model.h5
# Epoch 15/30
# 210/210 [==============================] - 4s 18ms/step - loss: 7.3486e-05 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9833
#
# Epoch 00015: val_accuracy did not improve from 0.98333
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 16/30
# 210/210 [==============================] - 4s 18ms/step - loss: 5.8149e-05 - accuracy: 1.0000 - val_loss: 0.0644 - val_accuracy: 0.9812
#
# Epoch 00016: val_accuracy did not improve from 0.98333
# Epoch 17/30
# 210/210 [==============================] - 4s 18ms/step - loss: 5.1152e-05 - accuracy: 1.0000 - val_loss: 0.0646 - val_accuracy: 0.9833
#
# Epoch 00017: val_accuracy did not improve from 0.98333
# Epoch 18/30
# 210/210 [==============================] - 4s 18ms/step - loss: 4.5768e-05 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9812
#
# Epoch 00018: val_accuracy did not improve from 0.98333
# Epoch 19/30
# 210/210 [==============================] - 4s 18ms/step - loss: 4.0963e-05 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9812
#
# Epoch 00019: val_accuracy did not improve from 0.98333
# Epoch 20/30
# 210/210 [==============================] - 4s 19ms/step - loss: 3.6672e-05 - accuracy: 1.0000 - val_loss: 0.0679 - val_accuracy: 0.9812
#
# Epoch 00020: val_accuracy did not improve from 0.98333
# Epoch 21/30
# 210/210 [==============================] - 5s 23ms/step - loss: 3.2744e-05 - accuracy: 1.0000 - val_loss: 0.0679 - val_accuracy: 0.9812
#
# Epoch 00021: val_accuracy did not improve from 0.98333
# Epoch 22/30
# 210/210 [==============================] - 4s 21ms/step - loss: 2.9107e-05 - accuracy: 1.0000 - val_loss: 0.0688 - val_accuracy: 0.9812
#
# Epoch 00022: val_accuracy did not improve from 0.98333
# Epoch 23/30
# 210/210 [==============================] - 4s 19ms/step - loss: 2.5898e-05 - accuracy: 1.0000 - val_loss: 0.0701 - val_accuracy: 0.9833
#
# Epoch 00023: val_accuracy did not improve from 0.98333
# Epoch 24/30
# 210/210 [==============================] - 4s 18ms/step - loss: 2.3199e-05 - accuracy: 1.0000 - val_loss: 0.0691 - val_accuracy: 0.9812
#
# Epoch 00024: val_accuracy did not improve from 0.98333
# Epoch 25/30
# 210/210 [==============================] - 4s 19ms/step - loss: 2.0789e-05 - accuracy: 1.0000 - val_loss: 0.0708 - val_accuracy: 0.9833
#
# Epoch 00025: val_accuracy did not improve from 0.98333
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 26/30
# 210/210 [==============================] - 4s 18ms/step - loss: 1.8610e-05 - accuracy: 1.0000 - val_loss: 0.0713 - val_accuracy: 0.9833
#
# Epoch 00026: val_accuracy did not improve from 0.98333
# Epoch 27/30
# 210/210 [==============================] - 4s 19ms/step - loss: 1.7540e-05 - accuracy: 1.0000 - val_loss: 0.0705 - val_accuracy: 0.9833
#
# Epoch 00027: val_accuracy did not improve from 0.98333
# Epoch 28/30
# 210/210 [==============================] - 4s 21ms/step - loss: 1.6463e-05 - accuracy: 1.0000 - val_loss: 0.0721 - val_accuracy: 0.9833
#
# Epoch 00028: val_accuracy did not improve from 0.98333
# Epoch 29/30
# 210/210 [==============================] - 4s 20ms/step - loss: 1.5460e-05 - accuracy: 1.0000 - val_loss: 0.0728 - val_accuracy: 0.9833
#
# Epoch 00029: val_accuracy did not improve from 0.98333
# Epoch 30/30
# 210/210 [==============================] - 4s 20ms/step - loss: 1.4452e-05 - accuracy: 1.0000 - val_loss: 0.0723 - val_accuracy: 0.9833
#
# Epoch 00030: val_accuracy did not improve from 0.98333
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 6
# Genre split [['Pop'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Jazz', 'Reggae', 'Rock']]
# Building model...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 210/210 [==============================] - 5s 24ms/step - loss: 0.3872 - accuracy: 0.8702 - val_loss: 0.2500 - val_accuracy: 0.9123
#
# Epoch 00001: val_accuracy improved from -inf to 0.91232, saving model to ./models/tree_11/model_root_f1_1/folder6\model.h5
# Epoch 2/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.2099 - accuracy: 0.9125 - val_loss: 0.1624 - val_accuracy: 0.9311
#
# Epoch 00002: val_accuracy improved from 0.91232 to 0.93111, saving model to ./models/tree_11/model_root_f1_1/folder6\model.h5
# Epoch 3/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.1975 - accuracy: 0.9169 - val_loss: 0.1862 - val_accuracy: 0.9248
#
# Epoch 00003: val_accuracy did not improve from 0.93111
# Epoch 4/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.1810 - accuracy: 0.9277 - val_loss: 0.1704 - val_accuracy: 0.9290
#
# Epoch 00004: val_accuracy did not improve from 0.93111
# Epoch 5/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.1760 - accuracy: 0.9273 - val_loss: 0.1622 - val_accuracy: 0.9353
#
# Epoch 00005: val_accuracy improved from 0.93111 to 0.93528, saving model to ./models/tree_11/model_root_f1_1/folder6\model.h5
# Epoch 6/30
# 210/210 [==============================] - 4s 21ms/step - loss: 0.1630 - accuracy: 0.9352 - val_loss: 0.1565 - val_accuracy: 0.9374
#
# Epoch 00006: val_accuracy improved from 0.93528 to 0.93737, saving model to ./models/tree_11/model_root_f1_1/folder6\model.h5
# Epoch 7/30
# 210/210 [==============================] - 5s 23ms/step - loss: 0.1575 - accuracy: 0.9361 - val_loss: 0.1495 - val_accuracy: 0.9436
#
# Epoch 00007: val_accuracy improved from 0.93737 to 0.94363, saving model to ./models/tree_11/model_root_f1_1/folder6\model.h5
# Epoch 8/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.1596 - accuracy: 0.9402 - val_loss: 0.1524 - val_accuracy: 0.9395
#
# Epoch 00008: val_accuracy did not improve from 0.94363
# Epoch 9/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.1527 - accuracy: 0.9401 - val_loss: 0.1399 - val_accuracy: 0.9582
#
# Epoch 00009: val_accuracy improved from 0.94363 to 0.95825, saving model to ./models/tree_11/model_root_f1_1/folder6\model.h5
# Epoch 10/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.1498 - accuracy: 0.9422 - val_loss: 0.1572 - val_accuracy: 0.9353
#
# Epoch 00010: val_accuracy did not improve from 0.95825
# Epoch 11/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.1515 - accuracy: 0.9402 - val_loss: 0.1459 - val_accuracy: 0.9499
#
# Epoch 00011: val_accuracy did not improve from 0.95825
# Epoch 12/30
# ...
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.4139 - accuracy: 0.8704 - val_loss: 0.3569 - val_accuracy: 0.8873
#
# Epoch 00001: val_accuracy improved from -inf to 0.88727, saving model to ./models/tree_11/model_root_f1_1/folder7\model.h5
# Epoch 2/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.3623 - accuracy: 0.8724 - val_loss: 0.3124 - val_accuracy: 0.8894
#
# Epoch 00002: val_accuracy improved from 0.88727 to 0.88935, saving model to ./models/tree_11/model_root_f1_1/folder7\model.h5
# Epoch 3/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.3188 - accuracy: 0.8797 - val_loss: 0.2477 - val_accuracy: 0.9040
#
# Epoch 00003: val_accuracy improved from 0.88935 to 0.90397, saving model to ./models/tree_11/model_root_f1_1/folder7\model.h5
# Epoch 4/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.2603 - accuracy: 0.9040 - val_loss: 0.2211 - val_accuracy: 0.9228
#
# Epoch 00004: val_accuracy improved from 0.90397 to 0.92276, saving model to ./models/tree_11/model_root_f1_1/folder7\model.h5
# Epoch 5/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.2041 - accuracy: 0.9291 - val_loss: 0.2307 - val_accuracy: 0.9207
#
# Epoch 00005: val_accuracy did not improve from 0.92276
# Epoch 6/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.1545 - accuracy: 0.9467 - val_loss: 0.2001 - val_accuracy: 0.9311
#
# Epoch 00006: val_accuracy improved from 0.92276 to 0.93111, saving model to ./models/tree_11/model_root_f1_1/folder7\model.h5
# Epoch 7/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.1183 - accuracy: 0.9580 - val_loss: 0.1577 - val_accuracy: 0.9395
#
# Epoch 00007: val_accuracy improved from 0.93111 to 0.93946, saving model to ./models/tree_11/model_root_f1_1/folder7\model.h5
# Epoch 8/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.1052 - accuracy: 0.9635 - val_loss: 0.1199 - val_accuracy: 0.9541
#
# Epoch 00008: val_accuracy improved from 0.93946 to 0.95407, saving model to ./models/tree_11/model_root_f1_1/folder7\model.h5
# Epoch 9/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0594 - accuracy: 0.9814 - val_loss: 0.1380 - val_accuracy: 0.9520
#
# Epoch 00009: val_accuracy did not improve from 0.95407
# Epoch 10/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.0438 - accuracy: 0.9869 - val_loss: 0.1419 - val_accuracy: 0.9562
#
# Epoch 00010: val_accuracy improved from 0.95407 to 0.95616, saving model to ./models/tree_11/model_root_f1_1/folder7\model.h5
# Epoch 11/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.0212 - accuracy: 0.9934 - val_loss: 0.1122 - val_accuracy: 0.9624
#
# Epoch 00011: val_accuracy improved from 0.95616 to 0.96242, saving model to ./models/tree_11/model_root_f1_1/folder7\model.h5
# Epoch 12/30
# 210/210 [==============================] - 4s 21ms/step - loss: 0.0443 - accuracy: 0.9832 - val_loss: 0.1554 - val_accuracy: 0.9520
#
# Epoch 00012: val_accuracy did not improve from 0.96242
# Epoch 13/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0287 - accuracy: 0.9897 - val_loss: 0.1823 - val_accuracy: 0.9436
#
# Epoch 00013: val_accuracy did not improve from 0.96242
# Epoch 14/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0161 - accuracy: 0.9937 - val_loss: 0.1702 - val_accuracy: 0.9603
#
# Epoch 00014: val_accuracy did not improve from 0.96242
# Epoch 15/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.2511 - val_accuracy: 0.9478
#
# Epoch 00015: val_accuracy did not improve from 0.96242
# Epoch 16/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.0215 - accuracy: 0.9917 - val_loss: 0.2176 - val_accuracy: 0.9520
#
# Epoch 00016: val_accuracy did not improve from 0.96242
# Epoch 17/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0219 - accuracy: 0.9927 - val_loss: 0.1809 - val_accuracy: 0.9562
#
# Epoch 00017: val_accuracy did not improve from 0.96242
# Epoch 18/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.1851 - val_accuracy: 0.9624
#
# Epoch 00018: val_accuracy did not improve from 0.96242
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 19/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.1758 - val_accuracy: 0.9687
#
# Epoch 00019: val_accuracy improved from 0.96242 to 0.96868, saving model to ./models/tree_11/model_root_f1_1/folder7\model.h5
# Epoch 20/30
# 210/210 [==============================] - 4s 19ms/step - loss: 2.0136e-04 - accuracy: 1.0000 - val_loss: 0.1799 - val_accuracy: 0.9687
#
# Epoch 00020: val_accuracy did not improve from 0.96868
# Epoch 21/30
# 210/210 [==============================] - 4s 19ms/step - loss: 1.3476e-04 - accuracy: 1.0000 - val_loss: 0.1839 - val_accuracy: 0.9687
#
# Epoch 00021: val_accuracy did not improve from 0.96868
# Epoch 22/30
# 210/210 [==============================] - 4s 19ms/step - loss: 1.0497e-04 - accuracy: 1.0000 - val_loss: 0.1868 - val_accuracy: 0.9666
#
# Epoch 00022: val_accuracy did not improve from 0.96868
# Epoch 23/30
# 210/210 [==============================] - 4s 18ms/step - loss: 8.6493e-05 - accuracy: 1.0000 - val_loss: 0.1908 - val_accuracy: 0.9666
#
# Epoch 00023: val_accuracy did not improve from 0.96868
# Epoch 24/30
# 210/210 [==============================] - 4s 19ms/step - loss: 7.2446e-05 - accuracy: 1.0000 - val_loss: 0.1926 - val_accuracy: 0.9666
#
# Epoch 00024: val_accuracy did not improve from 0.96868
# Epoch 25/30
# 210/210 [==============================] - 4s 19ms/step - loss: 6.2179e-05 - accuracy: 1.0000 - val_loss: 0.1945 - val_accuracy: 0.9666
#
# Epoch 00025: val_accuracy did not improve from 0.96868
# Epoch 26/30
# 210/210 [==============================] - 4s 19ms/step - loss: 5.4102e-05 - accuracy: 1.0000 - val_loss: 0.1969 - val_accuracy: 0.9645
#
# Epoch 00026: val_accuracy did not improve from 0.96868
# Epoch 27/30
# 210/210 [==============================] - 4s 20ms/step - loss: 4.7246e-05 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9645
#
# Epoch 00027: val_accuracy did not improve from 0.96868
# Epoch 28/30
# 210/210 [==============================] - 4s 20ms/step - loss: 4.1626e-05 - accuracy: 1.0000 - val_loss: 0.2008 - val_accuracy: 0.9645
#
# Epoch 00028: val_accuracy did not improve from 0.96868
# Epoch 29/30
# 210/210 [==============================] - 4s 18ms/step - loss: 3.6606e-05 - accuracy: 1.0000 - val_loss: 0.2027 - val_accuracy: 0.9645
#
# Epoch 00029: val_accuracy did not improve from 0.96868
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 30/30
# 210/210 [==============================] - 4s 18ms/step - loss: 3.2828e-05 - accuracy: 1.0000 - val_loss: 0.2028 - val_accuracy: 0.9645
#
# Epoch 00030: val_accuracy did not improve from 0.96868
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 8
# Genre split [['Rock'], ['Blues', 'Country', 'Disco', 'Hip-Hop', 'Jazz', 'Pop', 'Reggae']]
# Building model...
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 210/210 [==============================] - 5s 19ms/step - loss: 0.3733 - accuracy: 0.8723 - val_loss: 0.3723 - val_accuracy: 0.8601
#
# Epoch 00001: val_accuracy improved from -inf to 0.86013, saving model to ./models/tree_11/model_root_f1_1/folder8\model.h5
# Epoch 2/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.3324 - accuracy: 0.8772 - val_loss: 0.3294 - val_accuracy: 0.8852
#
# Epoch 00002: val_accuracy improved from 0.86013 to 0.88518, saving model to ./models/tree_11/model_root_f1_1/folder8\model.h5
# Epoch 3/30
# 210/210 [==============================] - 5s 24ms/step - loss: 0.2930 - accuracy: 0.8871 - val_loss: 0.3002 - val_accuracy: 0.8831
#
# Epoch 00003: val_accuracy did not improve from 0.88518
# Epoch 4/30
# 210/210 [==============================] - 5s 22ms/step - loss: 0.2575 - accuracy: 0.8969 - val_loss: 0.2773 - val_accuracy: 0.8747
#
# Epoch 00004: val_accuracy did not improve from 0.88518
# Epoch 5/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.2378 - accuracy: 0.9031 - val_loss: 0.2762 - val_accuracy: 0.8747
#
# Epoch 00005: val_accuracy did not improve from 0.88518
# Epoch 6/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.2118 - accuracy: 0.9131 - val_loss: 0.2562 - val_accuracy: 0.8810
#
# Epoch 00006: val_accuracy did not improve from 0.88518
# Epoch 7/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.1855 - accuracy: 0.9221 - val_loss: 0.2621 - val_accuracy: 0.8831
#
# Epoch 00007: val_accuracy did not improve from 0.88518
# Epoch 8/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.1729 - accuracy: 0.9289 - val_loss: 0.2631 - val_accuracy: 0.8894
#
# Epoch 00008: val_accuracy improved from 0.88518 to 0.88935, saving model to ./models/tree_11/model_root_f1_1/folder8\model.h5
# Epoch 9/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.1527 - accuracy: 0.9344 - val_loss: 0.2602 - val_accuracy: 0.8998
#
# Epoch 00009: val_accuracy improved from 0.88935 to 0.89979, saving model to ./models/tree_11/model_root_f1_1/folder8\model.h5
# Epoch 10/30
# 210/210 [==============================] - 5s 23ms/step - loss: 0.1174 - accuracy: 0.9563 - val_loss: 0.2666 - val_accuracy: 0.9019
#
# Epoch 00010: val_accuracy improved from 0.89979 to 0.90188, saving model to ./models/tree_11/model_root_f1_1/folder8\model.h5
# Epoch 11/30
# 210/210 [==============================] - 4s 21ms/step - loss: 0.0872 - accuracy: 0.9656 - val_loss: 0.3262 - val_accuracy: 0.8914
#
# Epoch 00011: val_accuracy did not improve from 0.90188
# Epoch 12/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0661 - accuracy: 0.9742 - val_loss: 0.3015 - val_accuracy: 0.8727
#
# Epoch 00012: val_accuracy did not improve from 0.90188
# Epoch 13/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0489 - accuracy: 0.9827 - val_loss: 0.3067 - val_accuracy: 0.8894
#
# Epoch 00013: val_accuracy did not improve from 0.90188
# Epoch 14/30
# 210/210 [==============================] - 4s 20ms/step - loss: 0.0289 - accuracy: 0.9906 - val_loss: 0.4910 - val_accuracy: 0.8894
#
# Epoch 00014: val_accuracy did not improve from 0.90188
# Epoch 15/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0387 - accuracy: 0.9850 - val_loss: 0.3825 - val_accuracy: 0.8914
#
# Epoch 00015: val_accuracy did not improve from 0.90188
# Epoch 16/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0196 - accuracy: 0.9937 - val_loss: 0.6360 - val_accuracy: 0.8852
#
# Epoch 00016: val_accuracy did not improve from 0.90188
# Epoch 17/30
# 210/210 [==============================] - 4s 21ms/step - loss: 0.0142 - accuracy: 0.9943 - val_loss: 0.4215 - val_accuracy: 0.8998
#
# Epoch 00017: val_accuracy did not improve from 0.90188
# Epoch 18/30
# 210/210 [==============================] - 4s 18ms/step - loss: 0.0141 - accuracy: 0.9957 - val_loss: 0.5081 - val_accuracy: 0.8873
#
# Epoch 00018: val_accuracy did not improve from 0.90188
# Epoch 19/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0191 - accuracy: 0.9923 - val_loss: 0.5294 - val_accuracy: 0.8873
#
# Epoch 00019: val_accuracy did not improve from 0.90188
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/30
# 210/210 [==============================] - 4s 19ms/step - loss: 0.0074 - accuracy: 0.9978 - val_loss: 0.5215 - val_accuracy: 0.9081
#
# Epoch 00020: val_accuracy improved from 0.90188 to 0.90814, saving model to ./models/tree_11/model_root_f1_1/folder8\model.h5
# Epoch 21/30
# 210/210 [==============================] - 4s 18ms/step - loss: 8.1745e-04 - accuracy: 1.0000 - val_loss: 0.4981 - val_accuracy: 0.9102
#
# Epoch 00021: val_accuracy improved from 0.90814 to 0.91023, saving model to ./models/tree_11/model_root_f1_1/folder8\model.h5
# Epoch 22/30
# 210/210 [==============================] - 4s 19ms/step - loss: 4.1001e-04 - accuracy: 1.0000 - val_loss: 0.5120 - val_accuracy: 0.9061
#
# Epoch 00022: val_accuracy did not improve from 0.91023
# Epoch 23/30
# 210/210 [==============================] - 4s 19ms/step - loss: 2.9690e-04 - accuracy: 1.0000 - val_loss: 0.5284 - val_accuracy: 0.9102
#
# Epoch 00023: val_accuracy did not improve from 0.91023
# Epoch 24/30
# 210/210 [==============================] - 4s 19ms/step - loss: 2.3059e-04 - accuracy: 1.0000 - val_loss: 0.5361 - val_accuracy: 0.9102
#
# Epoch 00024: val_accuracy did not improve from 0.91023
# Epoch 25/30
# 210/210 [==============================] - 4s 18ms/step - loss: 1.8522e-04 - accuracy: 1.0000 - val_loss: 0.5483 - val_accuracy: 0.9102
#
# Epoch 00025: val_accuracy did not improve from 0.91023
# Epoch 26/30
# 210/210 [==============================] - 4s 19ms/step - loss: 1.5226e-04 - accuracy: 1.0000 - val_loss: 0.5558 - val_accuracy: 0.9123
#
# Epoch 00026: val_accuracy improved from 0.91023 to 0.91232, saving model to ./models/tree_11/model_root_f1_1/folder8\model.h5
# Epoch 27/30
# 210/210 [==============================] - 4s 19ms/step - loss: 1.2706e-04 - accuracy: 1.0000 - val_loss: 0.5679 - val_accuracy: 0.9123
#
# Epoch 00027: val_accuracy did not improve from 0.91232
# Epoch 28/30
# 210/210 [==============================] - 4s 19ms/step - loss: 1.0646e-04 - accuracy: 1.0000 - val_loss: 0.5833 - val_accuracy: 0.9081
#
# Epoch 00028: val_accuracy did not improve from 0.91232
# Epoch 29/30
# 210/210 [==============================] - 4s 18ms/step - loss: 9.0644e-05 - accuracy: 1.0000 - val_loss: 0.5868 - val_accuracy: 0.9123
#
# Epoch 00029: val_accuracy did not improve from 0.91232
# Epoch 30/30
# 210/210 [==============================] - 4s 19ms/step - loss: 7.6164e-05 - accuracy: 1.0000 - val_loss: 0.5963 - val_accuracy: 0.9081
#
# Epoch 00030: val_accuracy did not improve from 0.91232
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
