# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Country':2, 'Disco':3, 'Metal':6, 'Pop':7, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {2: 'Country', 3: 'Disco', 6: 'Metal', 7: 'Pop', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7992, 128, 128) (7992, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((4023, 128, 128), (4023, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (999, 128, 128) (999, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((498, 128, 128), (498, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Country

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_7/model_root_f2/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_7/model_root_f2/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def create_split(elem):
    splits = list(set_partitions(elem, 2))
    _splits = []
    for i in range(len(splits)):
        try:
            if len(splits[i][0]) != 1 and len(splits[i][1]) != 1:
                _splits.append(splits[i])
        except:
            continue
    
    return _splits, len(_splits)

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

genre_splits, num_splits = create_split(list(dict_genres.values()))
print("Num splits {}".format(num_splits))

if num_splits > 8:
    n_splits = num_splits
else:
    n_splits = 8

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)

    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Num splits 10
# Folder num 1
# Genre split [['Country', 'Disco'], ['Metal', 'Pop', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 128/128 [==============================] - 6s 22ms/step - loss: 0.7586 - accuracy: 0.5836 - val_loss: 0.6938 - val_accuracy: 0.5916
#
# Epoch 00001: val_accuracy improved from -inf to 0.59161, saving model to ./models/tree_7/model_root_f2/folder1\model.h5
# Epoch 2/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6766 - accuracy: 0.6000 - val_loss: 0.6784 - val_accuracy: 0.5916
#
# Epoch 00002: val_accuracy did not improve from 0.59161
# Epoch 3/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6737 - accuracy: 0.6000 - val_loss: 0.6771 - val_accuracy: 0.5916
#
# Epoch 00003: val_accuracy did not improve from 0.59161
# Epoch 4/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6791 - accuracy: 0.5983 - val_loss: 0.6748 - val_accuracy: 0.5916
#
# Epoch 00004: val_accuracy did not improve from 0.59161
# Epoch 5/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6662 - accuracy: 0.6050 - val_loss: 0.6586 - val_accuracy: 0.5982
#
# Epoch 00005: val_accuracy improved from 0.59161 to 0.59823, saving model to ./models/tree_7/model_root_f2/folder1\model.h5
# Epoch 6/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6476 - accuracy: 0.6300 - val_loss: 0.9534 - val_accuracy: 0.4525
#
# Epoch 00006: val_accuracy did not improve from 0.59823
# Epoch 7/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6193 - accuracy: 0.6409 - val_loss: 0.5954 - val_accuracy: 0.6556: 0.6
#
# Epoch 00007: val_accuracy improved from 0.59823 to 0.65563, saving model to ./models/tree_7/model_root_f2/folder1\model.h5
# Epoch 8/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.5710 - accuracy: 0.6866 - val_loss: 0.5629 - val_accuracy: 0.6843
#
# Epoch 00008: val_accuracy improved from 0.65563 to 0.68433, saving model to ./models/tree_7/model_root_f2/folder1\model.h5
# Epoch 9/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.5263 - accuracy: 0.7151 - val_loss: 0.5563 - val_accuracy: 0.6777
#
# Epoch 00009: val_accuracy did not improve from 0.68433
# Epoch 10/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.4358 - accuracy: 0.7957 - val_loss: 0.4574 - val_accuracy: 0.7616- loss: 0.4326 - accuracy:
#
# Epoch 00010: val_accuracy improved from 0.68433 to 0.76159, saving model to ./models/tree_7/model_root_f2/folder1\model.h5
# Epoch 11/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.3816 - accuracy: 0.8245 - val_loss: 0.4195 - val_accuracy: 0.7815
#
# Epoch 00011: val_accuracy improved from 0.76159 to 0.78146, saving model to ./models/tree_7/model_root_f2/folder1\model.h5
# Epoch 12/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.3196 - accuracy: 0.8552 - val_loss: 0.4277 - val_accuracy: 0.8057
#
# Epoch 00012: val_accuracy improved from 0.78146 to 0.80574, saving model to ./models/tree_7/model_root_f2/folder1\model.h5
# Epoch 13/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.2749 - accuracy: 0.8823 - val_loss: 0.3452 - val_accuracy: 0.8433
#
# Epoch 00013: val_accuracy improved from 0.80574 to 0.84327, saving model to ./models/tree_7/model_root_f2/folder1\model.h5
# Epoch 14/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.2297 - accuracy: 0.9009 - val_loss: 0.4081 - val_accuracy: 0.8322
#
# Epoch 00014: val_accuracy did not improve from 0.84327
# Epoch 15/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1875 - accuracy: 0.9223 - val_loss: 0.3541 - val_accuracy: 0.8587
#
# Epoch 00015: val_accuracy improved from 0.84327 to 0.85872, saving model to ./models/tree_7/model_root_f2/folder1\model.h5
# Epoch 16/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1293 - accuracy: 0.9481 - val_loss: 0.3907 - val_accuracy: 0.8698
#
# Epoch 00016: val_accuracy improved from 0.85872 to 0.86976, saving model to ./models/tree_7/model_root_f2/folder1\model.h5
# Epoch 17/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0871 - accuracy: 0.9683 - val_loss: 0.4468 - val_accuracy: 0.8322loss: 0.0856 - accuracy:
#
# Epoch 00017: val_accuracy did not improve from 0.86976
# Epoch 18/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0546 - accuracy: 0.9821 - val_loss: 0.4706 - val_accuracy: 0.8455
#
# Epoch 00018: val_accuracy did not improve from 0.86976
# Epoch 19/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0392 - accuracy: 0.9870 - val_loss: 0.5162 - val_accuracy: 0.8565
#
# Epoch 00019: val_accuracy did not improve from 0.86976
# Epoch 20/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0298 - accuracy: 0.9909 - val_loss: 0.6103 - val_accuracy: 0.8389
#
# Epoch 00020: val_accuracy did not improve from 0.86976
# Epoch 21/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.5576 - val_accuracy: 0.8675
#
# Epoch 00021: val_accuracy did not improve from 0.86976
# Epoch 22/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5801 - val_accuracy: 0.8653
#
# Epoch 00022: val_accuracy did not improve from 0.86976
# Epoch 23/30
# 128/128 [==============================] - 2s 17ms/step - loss: 8.4432e-04 - accuracy: 1.0000 - val_loss: 0.6078 - val_accuracy: 0.8675
#
# Epoch 00023: val_accuracy did not improve from 0.86976
# Epoch 24/30
# 128/128 [==============================] - 2s 17ms/step - loss: 5.8175e-04 - accuracy: 1.0000 - val_loss: 0.6189 - val_accuracy: 0.8653
#
# Epoch 00024: val_accuracy did not improve from 0.86976
# Epoch 25/30
# 128/128 [==============================] - 2s 17ms/step - loss: 4.4655e-04 - accuracy: 1.0000 - val_loss: 0.6519 - val_accuracy: 0.8653
#
# Epoch 00025: val_accuracy did not improve from 0.86976
# Epoch 26/30
# 128/128 [==============================] - 2s 17ms/step - loss: 3.4501e-04 - accuracy: 1.0000 - val_loss: 0.6622 - val_accuracy: 0.8631
#
# Epoch 00026: val_accuracy did not improve from 0.86976
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 27/30
# 128/128 [==============================] - 2s 17ms/step - loss: 2.8975e-04 - accuracy: 1.0000 - val_loss: 0.6722 - val_accuracy: 0.8675
#
# Epoch 00027: val_accuracy did not improve from 0.86976
# Epoch 28/30
# 128/128 [==============================] - 2s 17ms/step - loss: 2.6146e-04 - accuracy: 1.0000 - val_loss: 0.6783 - val_accuracy: 0.8675
#
# Epoch 00028: val_accuracy did not improve from 0.86976
# Epoch 29/30
# 128/128 [==============================] - 2s 17ms/step - loss: 2.3925e-04 - accuracy: 1.0000 - val_loss: 0.6911 - val_accuracy: 0.8742
#
# Epoch 00029: val_accuracy improved from 0.86976 to 0.87417, saving model to ./models/tree_7/model_root_f2/folder1\model.h5
# Epoch 30/30
# 128/128 [==============================] - 2s 17ms/step - loss: 2.1826e-04 - accuracy: 1.0000 - val_loss: 0.6896 - val_accuracy: 0.8698
#
# Epoch 00030: val_accuracy did not improve from 0.87417
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Country', 'Disco', 'Metal'], ['Pop', 'Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 128/128 [==============================] - 3s 20ms/step - loss: 0.7460 - accuracy: 0.5977 - val_loss: 0.6845 - val_accuracy: 0.5420
#
# Epoch 00001: val_accuracy improved from -inf to 0.54204, saving model to ./models/tree_7/model_root_f2/folder2\model.h5
# Epoch 2/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6746 - accuracy: 0.5942 - val_loss: 0.6758 - val_accuracy: 0.5951
#
# Epoch 00002: val_accuracy improved from 0.54204 to 0.59513, saving model to ./models/tree_7/model_root_f2/folder2\model.h5
# Epoch 3/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6741 - accuracy: 0.5997 - val_loss: 0.6753 - val_accuracy: 0.5951
#
# Epoch 00003: val_accuracy did not improve from 0.59513
# Epoch 4/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6739 - accuracy: 0.5997 - val_loss: 0.6758 - val_accuracy: 0.5951
#
# Epoch 00004: val_accuracy did not improve from 0.59513
# Epoch 5/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6737 - accuracy: 0.5997 - val_loss: 0.6749 - val_accuracy: 0.5951
#
# Epoch 00005: val_accuracy did not improve from 0.59513
# Epoch 6/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6736 - accuracy: 0.5997 - val_loss: 0.6753 - val_accuracy: 0.5951
#
# Epoch 00006: val_accuracy did not improve from 0.59513
# Epoch 7/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6735 - accuracy: 0.5997 - val_loss: 0.6750 - val_accuracy: 0.5951
#
# Epoch 00007: val_accuracy did not improve from 0.59513
# Epoch 8/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6730 - accuracy: 0.5997 - val_loss: 0.6771 - val_accuracy: 0.5951
#
# Epoch 00008: val_accuracy did not improve from 0.59513
# Epoch 9/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6742 - accuracy: 0.5997 - val_loss: 0.6752 - val_accuracy: 0.5951
#
# Epoch 00009: val_accuracy did not improve from 0.59513
# Epoch 10/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6739 - accuracy: 0.5997 - val_loss: 0.6750 - val_accuracy: 0.5951A: 0s - loss: 0.6741 - accuracy: 0.59
#
# Epoch 00010: val_accuracy did not improve from 0.59513
# Epoch 11/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6743 - accuracy: 0.5997 - val_loss: 0.6756 - val_accuracy: 0.5951
#
# Epoch 00011: val_accuracy did not improve from 0.59513
# Epoch 12/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6754 - accuracy: 0.5987 - val_loss: 0.6753 - val_accuracy: 0.5951
#
# Epoch 00012: val_accuracy did not improve from 0.59513
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 13/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6735 - accuracy: 0.5997 - val_loss: 0.6749 - val_accuracy: 0.5951
#
# Epoch 00013: val_accuracy did not improve from 0.59513
# Epoch 14/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6735 - accuracy: 0.5997 - val_loss: 0.6749 - val_accuracy: 0.5951
#
# Epoch 00014: val_accuracy did not improve from 0.59513
# Epoch 15/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6736 - accuracy: 0.5997 - val_loss: 0.6751 - val_accuracy: 0.5951los
#
# Epoch 00015: val_accuracy did not improve from 0.59513
# Epoch 16/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6734 - accuracy: 0.5997 - val_loss: 0.6750 - val_accuracy: 0.5951
#
# Epoch 00016: val_accuracy did not improve from 0.59513
# Epoch 17/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6738 - accuracy: 0.5997 - val_loss: 0.6749 - val_accuracy: 0.5951
#
# Epoch 00017: val_accuracy did not improve from 0.59513
# Epoch 18/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6734 - accuracy: 0.5997 - val_loss: 0.6750 - val_accuracy: 0.5951
#
# Epoch 00018: val_accuracy did not improve from 0.59513
# Epoch 19/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6735 - accuracy: 0.5997 - val_loss: 0.6749 - val_accuracy: 0.5951
#
# Epoch 00019: val_accuracy did not improve from 0.59513
# Epoch 20/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6734 - accuracy: 0.5997 - val_loss: 0.6750 - val_accuracy: 0.5951
#
# Epoch 00020: val_accuracy did not improve from 0.59513
# Epoch 21/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6736 - accuracy: 0.5997 - val_loss: 0.6750 - val_accuracy: 0.5951
#
# Epoch 00021: val_accuracy did not improve from 0.59513
# Epoch 22/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6737 - accuracy: 0.5997 - val_loss: 0.6751 - val_accuracy: 0.5951
#
# Epoch 00022: val_accuracy did not improve from 0.59513
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 23/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6735 - accuracy: 0.5997 - val_loss: 0.6750 - val_accuracy: 0.5951
#
# Epoch 00023: val_accuracy did not improve from 0.59513
# Epoch 24/30
# 128/128 [==============================] - 2s 18ms/step - loss: 0.6734 - accuracy: 0.5997 - val_loss: 0.6750 - val_accuracy: 0.5951
#
# Epoch 00024: val_accuracy did not improve from 0.59513
# Epoch 25/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6733 - accuracy: 0.5997 - val_loss: 0.6749 - val_accuracy: 0.5951
#
# Epoch 00025: val_accuracy did not improve from 0.59513
# Epoch 26/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6733 - accuracy: 0.5997 - val_loss: 0.6749 - val_accuracy: 0.5951
#
# Epoch 00026: val_accuracy did not improve from 0.59513
# Epoch 27/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6733 - accuracy: 0.5997 - val_loss: 0.6751 - val_accuracy: 0.5951
#
# Epoch 00027: val_accuracy did not improve from 0.59513
# Epoch 28/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6735 - accuracy: 0.5997 - val_loss: 0.6752 - val_accuracy: 0.5951
#
# Epoch 00028: val_accuracy did not improve from 0.59513
# Epoch 29/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6734 - accuracy: 0.5997 - val_loss: 0.6750 - val_accuracy: 0.5951
#
# Epoch 00029: val_accuracy did not improve from 0.59513
# Epoch 30/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6734 - accuracy: 0.5997 - val_loss: 0.6749 - val_accuracy: 0.5951
#
# Epoch 00030: val_accuracy did not improve from 0.59513
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Disco', 'Metal'], ['Country', 'Pop', 'Rock']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 128/128 [==============================] - 3s 19ms/step - loss: 0.6260 - accuracy: 0.6921 - val_loss: 0.7757 - val_accuracy: 0.5686
#
# Epoch 00001: val_accuracy improved from -inf to 0.56858, saving model to ./models/tree_7/model_root_f2/folder3\model.h5
# Epoch 2/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.4729 - accuracy: 0.8000 - val_loss: 0.3965 - val_accuracy: 0.8142
#
# Epoch 00002: val_accuracy improved from 0.56858 to 0.81416, saving model to ./models/tree_7/model_root_f2/folder3\model.h5
# Epoch 3/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.4348 - accuracy: 0.8103 - val_loss: 0.3769 - val_accuracy: 0.8385
#
# Epoch 00003: val_accuracy improved from 0.81416 to 0.83850, saving model to ./models/tree_7/model_root_f2/folder3\model.h5
# Epoch 4/30
# 128/128 [==============================] - 2s 18ms/step - loss: 0.4069 - accuracy: 0.8223 - val_loss: 0.3562 - val_accuracy: 0.8230
#
# Epoch 00004: val_accuracy did not improve from 0.83850
# Epoch 5/30
# 128/128 [==============================] - 2s 18ms/step - loss: 0.3785 - accuracy: 0.8437 - val_loss: 0.3343 - val_accuracy: 0.8363
#
# Epoch 00005: val_accuracy did not improve from 0.83850
# Epoch 6/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.3391 - accuracy: 0.8562 - val_loss: 0.3068 - val_accuracy: 0.8518
#
# Epoch 00006: val_accuracy improved from 0.83850 to 0.85177, saving model to ./models/tree_7/model_root_f2/folder3\model.h5
# Epoch 7/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.2828 - accuracy: 0.8847 - val_loss: 0.3048 - val_accuracy: 0.8673
#
# Epoch 00007: val_accuracy improved from 0.85177 to 0.86726, saving model to ./models/tree_7/model_root_f2/folder3\model.h5
# Epoch 8/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.2428 - accuracy: 0.9056 - val_loss: 0.2665 - val_accuracy: 0.8850
#
# Epoch 00008: val_accuracy improved from 0.86726 to 0.88496, saving model to ./models/tree_7/model_root_f2/folder3\model.h5
# Epoch 9/30
# 128/128 [==============================] - 2s 18ms/step - loss: 0.2250 - accuracy: 0.9164 - val_loss: 0.2438 - val_accuracy: 0.8982
#
# Epoch 00009: val_accuracy improved from 0.88496 to 0.89823, saving model to ./models/tree_7/model_root_f2/folder3\model.h5
# Epoch 10/30
# 128/128 [==============================] - 2s 18ms/step - loss: 0.1834 - accuracy: 0.9295 - val_loss: 0.1890 - val_accuracy: 0.9292
#
# Epoch 00010: val_accuracy improved from 0.89823 to 0.92920, saving model to ./models/tree_7/model_root_f2/folder3\model.h5
# Epoch 11/30
# 128/128 [==============================] - 2s 18ms/step - loss: 0.1571 - accuracy: 0.9422 - val_loss: 0.1882 - val_accuracy: 0.9137
#
# Epoch 00011: val_accuracy did not improve from 0.92920
# Epoch 12/30
# 128/128 [==============================] - 2s 18ms/step - loss: 0.1180 - accuracy: 0.9543 - val_loss: 0.1990 - val_accuracy: 0.9204
#
# Epoch 00012: val_accuracy did not improve from 0.92920
# Epoch 13/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1029 - accuracy: 0.9649 - val_loss: 0.1817 - val_accuracy: 0.9248
#
# Epoch 00013: val_accuracy did not improve from 0.92920
# Epoch 14/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0794 - accuracy: 0.9725 - val_loss: 0.2277 - val_accuracy: 0.9093
#
# Epoch 00014: val_accuracy did not improve from 0.92920
# Epoch 15/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0983 - accuracy: 0.9644 - val_loss: 0.2061 - val_accuracy: 0.9314
#
# Epoch 00015: val_accuracy improved from 0.92920 to 0.93142, saving model to ./models/tree_7/model_root_f2/folder3\model.h5
# Epoch 16/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0477 - accuracy: 0.9833 - val_loss: 0.1805 - val_accuracy: 0.9381
#
# Epoch 00016: val_accuracy improved from 0.93142 to 0.93805, saving model to ./models/tree_7/model_root_f2/folder3\model.h5
# Epoch 17/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0301 - accuracy: 0.9912 - val_loss: 0.2782 - val_accuracy: 0.9181
#
# Epoch 00017: val_accuracy did not improve from 0.93805
# Epoch 18/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0252 - accuracy: 0.9919 - val_loss: 0.2331 - val_accuracy: 0.9270ccuracy
#
# Epoch 00018: val_accuracy did not improve from 0.93805
# Epoch 19/30
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0266 - accuracy: 0.9926 - val_loss: 0.2509 - val_accuracy: 0.9270
#
# Epoch 00019: val_accuracy did not improve from 0.93805
# Epoch 20/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0426 - accuracy: 0.9850 - val_loss: 0.2071 - val_accuracy: 0.9403
#
# Epoch 00020: val_accuracy improved from 0.93805 to 0.94027, saving model to ./models/tree_7/model_root_f2/folder3\model.h5
# Epoch 21/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0672 - accuracy: 0.9762 - val_loss: 0.2174 - val_accuracy: 0.9314
#
# Epoch 00021: val_accuracy did not improve from 0.94027
# Epoch 22/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0273 - accuracy: 0.9907 - val_loss: 0.2472 - val_accuracy: 0.9425
#
# Epoch 00022: val_accuracy improved from 0.94027 to 0.94248, saving model to ./models/tree_7/model_root_f2/folder3\model.h5
# Epoch 23/30
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0219 - accuracy: 0.9926 - val_loss: 0.2928 - val_accuracy: 0.9226
#
# Epoch 00023: val_accuracy did not improve from 0.94248
# Epoch 24/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0477 - accuracy: 0.9816 - val_loss: 0.3106 - val_accuracy: 0.9027
#
# Epoch 00024: val_accuracy did not improve from 0.94248
# Epoch 25/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0215 - accuracy: 0.9931 - val_loss: 0.2319 - val_accuracy: 0.9381ss: 0.0
#
# Epoch 00025: val_accuracy did not improve from 0.94248
# Epoch 26/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0242 - accuracy: 0.9919 - val_loss: 0.2107 - val_accuracy: 0.9358 - accura
#
# Epoch 00026: val_accuracy did not improve from 0.94248
# Epoch 27/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0224 - accuracy: 0.9921 - val_loss: 0.2483 - val_accuracy: 0.920448 - accu - ETA: 0s - loss: 0
#
# Epoch 00027: val_accuracy did not improve from 0.94248
# Epoch 28/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0257 - accuracy: 0.9909 - val_loss: 0.3067 - val_accuracy: 0.9270
#
# Epoch 00028: val_accuracy did not improve from 0.94248
# Epoch 29/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0211 - accuracy: 0.9921 - val_loss: 0.2633 - val_accuracy: 0.9292
#
# Epoch 00029: val_accuracy did not improve from 0.94248
# Epoch 30/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0258 - accuracy: 0.9899 - val_loss: 0.2809 - val_accuracy: 0.9292
#
# Epoch 00030: val_accuracy did not improve from 0.94248
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Country', 'Metal'], ['Disco', 'Pop', 'Rock']]
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 128/128 [==============================] - 3s 19ms/step - loss: 0.6863 - accuracy: 0.6223 - val_loss: 0.5307 - val_accuracy: 0.7456
#
# Epoch 00001: val_accuracy improved from -inf to 0.74558, saving model to ./models/tree_7/model_root_f2/folder4\model.h5
# Epoch 2/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.4782 - accuracy: 0.7545 - val_loss: 0.4279 - val_accuracy: 0.7876
#
# Epoch 00002: val_accuracy improved from 0.74558 to 0.78761, saving model to ./models/tree_7/model_root_f2/folder4\model.h5
# Epoch 3/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.4025 - accuracy: 0.7975 - val_loss: 0.4379 - val_accuracy: 0.7832
#
# Epoch 00003: val_accuracy did not improve from 0.78761
# Epoch 4/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.3630 - accuracy: 0.8304 - val_loss: 0.4041 - val_accuracy: 0.7920
#
# Epoch 00004: val_accuracy improved from 0.78761 to 0.79204, saving model to ./models/tree_7/model_root_f2/folder4\model.h5
# Epoch 5/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.3517 - accuracy: 0.8407 - val_loss: 0.3939 - val_accuracy: 0.8031
#
# Epoch 00005: val_accuracy improved from 0.79204 to 0.80310, saving model to ./models/tree_7/model_root_f2/folder4\model.h5
# Epoch 6/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.2899 - accuracy: 0.8725 - val_loss: 0.4587 - val_accuracy: 0.7898
#
# Epoch 00006: val_accuracy did not improve from 0.80310
# Epoch 7/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.2684 - accuracy: 0.8877 - val_loss: 0.3858 - val_accuracy: 0.8274
#
# Epoch 00007: val_accuracy improved from 0.80310 to 0.82743, saving model to ./models/tree_7/model_root_f2/folder4\model.h5
# Epoch 8/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.2475 - accuracy: 0.8897 - val_loss: 0.4288 - val_accuracy: 0.8274
#
# Epoch 00008: val_accuracy did not improve from 0.82743
# Epoch 9/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.2092 - accuracy: 0.9118 - val_loss: 0.4406 - val_accuracy: 0.8319
#
# Epoch 00009: val_accuracy improved from 0.82743 to 0.83186, saving model to ./models/tree_7/model_root_f2/folder4\model.h5
# Epoch 10/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1846 - accuracy: 0.9221 - val_loss: 0.4180 - val_accuracy: 0.8230loss: 0.1882  - ETA: 0s - loss:
#
# Epoch 00010: val_accuracy did not improve from 0.83186
# Epoch 11/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1479 - accuracy: 0.9422 - val_loss: 0.4258 - val_accuracy: 0.8319
#
# Epoch 00011: val_accuracy did not improve from 0.83186
# Epoch 12/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1045 - accuracy: 0.9617 - val_loss: 0.4419 - val_accuracy: 0.8363
#
# Epoch 00012: val_accuracy improved from 0.83186 to 0.83628, saving model to ./models/tree_7/model_root_f2/folder4\model.h5
# Epoch 13/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1048 - accuracy: 0.9580 - val_loss: 0.5277 - val_accuracy: 0.8142
#
# Epoch 00013: val_accuracy did not improve from 0.83628
# Epoch 14/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0971 - accuracy: 0.9604 - val_loss: 0.5551 - val_accuracy: 0.8341
#
# Epoch 00014: val_accuracy did not improve from 0.83628
# Epoch 15/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0489 - accuracy: 0.9838 - val_loss: 0.6422 - val_accuracy: 0.8407
#
# Epoch 00015: val_accuracy improved from 0.83628 to 0.84071, saving model to ./models/tree_7/model_root_f2/folder4\model.h5
# Epoch 16/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0479 - accuracy: 0.9833 - val_loss: 0.6721 - val_accuracy: 0.8363
#
# Epoch 00016: val_accuracy did not improve from 0.84071
# Epoch 17/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0796 - accuracy: 0.9722 - val_loss: 0.5006 - val_accuracy: 0.8695
#
# Epoch 00017: val_accuracy improved from 0.84071 to 0.86947, saving model to ./models/tree_7/model_root_f2/folder4\model.h5
# Epoch 18/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0267 - accuracy: 0.9941 - val_loss: 0.5691 - val_accuracy: 0.8451
#
# Epoch 00018: val_accuracy did not improve from 0.86947
# Epoch 19/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0364 - accuracy: 0.9889 - val_loss: 0.6156 - val_accuracy: 0.8385
#
# Epoch 00019: val_accuracy did not improve from 0.86947
# Epoch 20/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0522 - accuracy: 0.9803 - val_loss: 0.6468 - val_accuracy: 0.8518
#
# Epoch 00020: val_accuracy did not improve from 0.86947
# Epoch 21/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0376 - accuracy: 0.9862 - val_loss: 0.6488 - val_accuracy: 0.8473
#
# Epoch 00021: val_accuracy did not improve from 0.86947
# Epoch 22/30
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0371 - accuracy: 0.9862 - val_loss: 0.6925 - val_accuracy: 0.8142
#
# Epoch 00022: val_accuracy did not improve from 0.86947
# Epoch 23/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0349 - accuracy: 0.9887 - val_loss: 0.8070 - val_accuracy: 0.8407
#
# Epoch 00023: val_accuracy did not improve from 0.86947
# Epoch 24/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0328 - accuracy: 0.9884 - val_loss: 0.6839 - val_accuracy: 0.8540
#
# Epoch 00024: val_accuracy did not improve from 0.86947
# Epoch 25/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0275 - accuracy: 0.9931 - val_loss: 0.7287 - val_accuracy: 0.8628ccu
#
# Epoch 00025: val_accuracy did not improve from 0.86947
# Epoch 26/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0160 - accuracy: 0.9963 - val_loss: 0.9335 - val_accuracy: 0.8142
#
# Epoch 00026: val_accuracy did not improve from 0.86947
# Epoch 27/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0245 - accuracy: 0.9916 - val_loss: 1.0749 - val_accuracy: 0.8451
#
# Epoch 00027: val_accuracy did not improve from 0.86947
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 28/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0211 - accuracy: 0.9929 - val_loss: 0.7303 - val_accuracy: 0.8518
#
# Epoch 00028: val_accuracy did not improve from 0.86947
# Epoch 29/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0114 - accuracy: 0.9971 - val_loss: 0.7979 - val_accuracy: 0.8606
#
# Epoch 00029: val_accuracy did not improve from 0.86947
# Epoch 30/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0079 - accuracy: 0.9978 - val_loss: 0.7710 - val_accuracy: 0.8695
#
# Epoch 00030: val_accuracy did not improve from 0.86947
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 5
# Genre split [['Disco', 'Metal', 'Pop'], ['Country', 'Rock']]
# Building model...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 128/128 [==============================] - 3s 19ms/step - loss: 0.7086 - accuracy: 0.6127 - val_loss: 0.9677 - val_accuracy: 0.4646
#
# Epoch 00001: val_accuracy improved from -inf to 0.46460, saving model to ./models/tree_7/model_root_f2/folder5\model.h5
# Epoch 2/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.5590 - accuracy: 0.7351 - val_loss: 0.4567 - val_accuracy: 0.7677
#
# Epoch 00002: val_accuracy improved from 0.46460 to 0.76770, saving model to ./models/tree_7/model_root_f2/folder5\model.h5
# Epoch 3/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.4201 - accuracy: 0.8172 - val_loss: 0.5013 - val_accuracy: 0.7566
#
# Epoch 00003: val_accuracy did not improve from 0.76770
# Epoch 4/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.3733 - accuracy: 0.8427 - val_loss: 0.3606 - val_accuracy: 0.8584
#
# Epoch 00004: val_accuracy improved from 0.76770 to 0.85841, saving model to ./models/tree_7/model_root_f2/folder5\model.h5
# Epoch 5/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.3291 - accuracy: 0.8611 - val_loss: 0.3826 - val_accuracy: 0.8341
#
# Epoch 00005: val_accuracy did not improve from 0.85841
# Epoch 6/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.2962 - accuracy: 0.8845 - val_loss: 0.3351 - val_accuracy: 0.8739
#
# Epoch 00006: val_accuracy improved from 0.85841 to 0.87389, saving model to ./models/tree_7/model_root_f2/folder5\model.h5
# Epoch 7/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.2662 - accuracy: 0.8973 - val_loss: 0.5358 - val_accuracy: 0.7655
#
# Epoch 00007: val_accuracy did not improve from 0.87389
# Epoch 8/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.2808 - accuracy: 0.8842 - val_loss: 0.2926 - val_accuracy: 0.8872s - loss: 0.2864 - accura
#
# Epoch 00008: val_accuracy improved from 0.87389 to 0.88717, saving model to ./models/tree_7/model_root_f2/folder5\model.h5
# Epoch 9/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.2238 - accuracy: 0.9132 - val_loss: 0.2764 - val_accuracy: 0.8805
#
# Epoch 00009: val_accuracy did not improve from 0.88717
# Epoch 10/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1975 - accuracy: 0.9238 - val_loss: 0.3205 - val_accuracy: 0.8562
#
# Epoch 00010: val_accuracy did not improve from 0.88717
# Epoch 11/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1848 - accuracy: 0.9324 - val_loss: 0.3207 - val_accuracy: 0.8473
#
# Epoch 00011: val_accuracy did not improve from 0.88717
# Epoch 12/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1427 - accuracy: 0.9469 - val_loss: 0.2889 - val_accuracy: 0.9004
#
# Epoch 00012: val_accuracy improved from 0.88717 to 0.90044, saving model to ./models/tree_7/model_root_f2/folder5\model.h5
# Epoch 13/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1343 - accuracy: 0.9523 - val_loss: 0.2885 - val_accuracy: 0.89825
#
# Epoch 00013: val_accuracy did not improve from 0.90044
# Epoch 14/30
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0936 - accuracy: 0.9639 - val_loss: 0.2996 - val_accuracy: 0.9027
#
# Epoch 00014: val_accuracy improved from 0.90044 to 0.90265, saving model to ./models/tree_7/model_root_f2/folder5\model.h5
# Epoch 15/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0856 - accuracy: 0.9676 - val_loss: 0.5560 - val_accuracy: 0.8451
#
# Epoch 00015: val_accuracy did not improve from 0.90265
# Epoch 16/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0608 - accuracy: 0.9789 - val_loss: 0.3052 - val_accuracy: 0.9071
#
# Epoch 00016: val_accuracy improved from 0.90265 to 0.90708, saving model to ./models/tree_7/model_root_f2/folder5\model.h5
# Epoch 17/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0389 - accuracy: 0.9848 - val_loss: 0.4339 - val_accuracy: 0.8496
#
# Epoch 00017: val_accuracy did not improve from 0.90708
# Epoch 18/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0325 - accuracy: 0.9897 - val_loss: 0.3519 - val_accuracy: 0.8938
#
# Epoch 00018: val_accuracy did not improve from 0.90708
# Epoch 19/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0215 - accuracy: 0.9943 - val_loss: 0.3751 - val_accuracy: 0.8938 0s - los
#
# Epoch 00019: val_accuracy did not improve from 0.90708
# Epoch 20/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0376 - accuracy: 0.9857 - val_loss: 0.3649 - val_accuracy: 0.8982
#
# Epoch 00020: val_accuracy did not improve from 0.90708
# Epoch 21/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0389 - accuracy: 0.9862 - val_loss: 0.3346 - val_accuracy: 0.8960
#
# Epoch 00021: val_accuracy did not improve from 0.90708
# Epoch 22/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0377 - accuracy: 0.9887 - val_loss: 0.5241 - val_accuracy: 0.8872
#
# Epoch 00022: val_accuracy did not improve from 0.90708
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 23/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0379 - accuracy: 0.9862 - val_loss: 0.3877 - val_accuracy: 0.9027loss: 0.0400 - accuracy:
#
# Epoch 00023: val_accuracy did not improve from 0.90708
# Epoch 24/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0109 - accuracy: 0.9953 - val_loss: 0.3368 - val_accuracy: 0.9049
#
# Epoch 00024: val_accuracy did not improve from 0.90708
# Epoch 25/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0091 - accuracy: 0.9973 - val_loss: 0.4259 - val_accuracy: 0.8938
#
# Epoch 00025: val_accuracy did not improve from 0.90708
# Epoch 26/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0122 - accuracy: 0.9963 - val_loss: 0.4109 - val_accuracy: 0.9071
#
# Epoch 00026: val_accuracy did not improve from 0.90708
# Epoch 27/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0097 - accuracy: 0.9968 - val_loss: 0.3747 - val_accuracy: 0.8982
#
# Epoch 00027: val_accuracy did not improve from 0.90708
# Epoch 28/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0113 - accuracy: 0.9968 - val_loss: 0.4212 - val_accuracy: 0.8982
#
# Epoch 00028: val_accuracy did not improve from 0.90708
# Epoch 29/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.4001 - val_accuracy: 0.9027- ETA: 0s - loss: 0.0092 - accuracy: 0.99
#
# Epoch 00029: val_accuracy did not improve from 0.90708
# Epoch 30/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0133 - accuracy: 0.9953 - val_loss: 0.6049 - val_accuracy: 0.8827
#
# Epoch 00030: val_accuracy did not improve from 0.90708
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 6
# Genre split [['Country', 'Metal', 'Pop'], ['Disco', 'Rock']]
# Building model...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 128/128 [==============================] - 3s 19ms/step - loss: 0.7282 - accuracy: 0.5871 - val_loss: 0.6893 - val_accuracy: 0.5907
#
# Epoch 00001: val_accuracy improved from -inf to 0.59071, saving model to ./models/tree_7/model_root_f2/folder6\model.h5
# Epoch 2/30
# 128/128 [==============================] - 2s 18ms/step - loss: 0.6766 - accuracy: 0.5967 - val_loss: 0.6815 - val_accuracy: 0.5907
#
# Epoch 00002: val_accuracy did not improve from 0.59071
# Epoch 3/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6752 - accuracy: 0.5984 - val_loss: 0.6772 - val_accuracy: 0.5907loss: 0.6758
#
# Epoch 00003: val_accuracy did not improve from 0.59071
# Epoch 4/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6748 - accuracy: 0.5984 - val_loss: 0.6785 - val_accuracy: 0.5907
#
# Epoch 00004: val_accuracy did not improve from 0.59071
# Epoch 5/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6746 - accuracy: 0.5984 - val_loss: 0.6769 - val_accuracy: 0.5907
#
# Epoch 00005: val_accuracy did not improve from 0.59071
# Epoch 6/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6747 - accuracy: 0.5984 - val_loss: 0.6767 - val_accuracy: 0.5907
#
# Epoch 00006: val_accuracy did not improve from 0.59071
# Epoch 7/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6740 - accuracy: 0.5984 - val_loss: 0.6809 - val_accuracy: 0.5907 accuracy:
#
# Epoch 00007: val_accuracy did not improve from 0.59071
# Epoch 8/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6739 - accuracy: 0.5984 - val_loss: 0.6766 - val_accuracy: 0.5907
#
# Epoch 00008: val_accuracy did not improve from 0.59071
# Epoch 9/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6744 - accuracy: 0.5984 - val_loss: 0.6774 - val_accuracy: 0.5907
#
# Epoch 00009: val_accuracy did not improve from 0.59071
# Epoch 10/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6747 - accuracy: 0.5984 - val_loss: 0.6766 - val_accuracy: 0.5907
#
# Epoch 00010: val_accuracy did not improve from 0.59071
# Epoch 11/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6742 - accuracy: 0.5984 - val_loss: 0.6776 - val_accuracy: 0.5907s - loss: 0.6767 - accuracy - ETA: 0s - loss: 0.6753 - accuracy
#
# Epoch 00011: val_accuracy did not improve from 0.59071
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 12/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.6740 - accuracy: 0.5984 - val_loss: 0.6782 - val_accuracy: 0.5907
#
# ...
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 128/128 [==============================] - 3s 19ms/step - loss: 0.6852 - accuracy: 0.6336 - val_loss: 0.6311 - val_accuracy: 0.6438
#
# Epoch 00001: val_accuracy improved from -inf to 0.64381, saving model to ./models/tree_7/model_root_f2/folder9\model.h5
# Epoch 2/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.4788 - accuracy: 0.7643 - val_loss: 0.6222 - val_accuracy: 0.7190
#
# Epoch 00002: val_accuracy improved from 0.64381 to 0.71903, saving model to ./models/tree_7/model_root_f2/folder9\model.h5
# Epoch 3/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.3273 - accuracy: 0.8575 - val_loss: 0.4367 - val_accuracy: 0.7876
#
# Epoch 00003: val_accuracy improved from 0.71903 to 0.78761, saving model to ./models/tree_7/model_root_f2/folder9\model.h5
# Epoch 4/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.2469 - accuracy: 0.8985 - val_loss: 0.2279 - val_accuracy: 0.8960
#
# Epoch 00004: val_accuracy improved from 0.78761 to 0.89602, saving model to ./models/tree_7/model_root_f2/folder9\model.h5
# Epoch 5/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1981 - accuracy: 0.9204 - val_loss: 0.1772 - val_accuracy: 0.9270
#
# Epoch 00005: val_accuracy improved from 0.89602 to 0.92699, saving model to ./models/tree_7/model_root_f2/folder9\model.h5
# Epoch 6/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1932 - accuracy: 0.9226 - val_loss: 0.2555 - val_accuracy: 0.8850
#
# Epoch 00006: val_accuracy did not improve from 0.92699
# Epoch 7/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1561 - accuracy: 0.9368 - val_loss: 0.1628 - val_accuracy: 0.9381
#
# Epoch 00007: val_accuracy improved from 0.92699 to 0.93805, saving model to ./models/tree_7/model_root_f2/folder9\model.h5
# Epoch 8/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1411 - accuracy: 0.9425 - val_loss: 0.2153 - val_accuracy: 0.9181
#
# Epoch 00008: val_accuracy did not improve from 0.93805
# Epoch 9/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1341 - accuracy: 0.9481 - val_loss: 0.1602 - val_accuracy: 0.9447
#
# Epoch 00009: val_accuracy improved from 0.93805 to 0.94469, saving model to ./models/tree_7/model_root_f2/folder9\model.h5
# Epoch 10/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1037 - accuracy: 0.9592 - val_loss: 0.2416 - val_accuracy: 0.9093
#
# Epoch 00010: val_accuracy did not improve from 0.94469
# Epoch 11/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0832 - accuracy: 0.9685 - val_loss: 0.1712 - val_accuracy: 0.9358
#
# Epoch 00011: val_accuracy did not improve from 0.94469
# Epoch 12/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0673 - accuracy: 0.9710 - val_loss: 0.1347 - val_accuracy: 0.9513
#
# Epoch 00012: val_accuracy improved from 0.94469 to 0.95133, saving model to ./models/tree_7/model_root_f2/folder9\model.h5
# Epoch 13/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0546 - accuracy: 0.9808 - val_loss: 0.1614 - val_accuracy: 0.9491
#
# Epoch 00013: val_accuracy did not improve from 0.95133
# Epoch 14/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0567 - accuracy: 0.9803 - val_loss: 0.2091 - val_accuracy: 0.9381
#
# Epoch 00014: val_accuracy did not improve from 0.95133
# Epoch 15/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0615 - accuracy: 0.9754 - val_loss: 0.2723 - val_accuracy: 0.9204loss: 0 - ETA: 0s -
#
# Epoch 00015: val_accuracy did not improve from 0.95133
# Epoch 16/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0382 - accuracy: 0.9855 - val_loss: 0.2326 - val_accuracy: 0.9381
#
# Epoch 00016: val_accuracy did not improve from 0.95133
# Epoch 17/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0205 - accuracy: 0.9929 - val_loss: 0.1915 - val_accuracy: 0.9558
#
# Epoch 00017: val_accuracy improved from 0.95133 to 0.95575, saving model to ./models/tree_7/model_root_f2/folder9\model.h5
# Epoch 18/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0162 - accuracy: 0.9936 - val_loss: 0.2426 - val_accuracy: 0.9447
#
# Epoch 00018: val_accuracy did not improve from 0.95575
# Epoch 19/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.2070 - val_accuracy: 0.9535
#
# Epoch 00019: val_accuracy did not improve from 0.95575
# Epoch 20/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9602
#
# Epoch 00020: val_accuracy improved from 0.95575 to 0.96018, saving model to ./models/tree_7/model_root_f2/folder9\model.h5
# Epoch 21/30
# 128/128 [==============================] - 2s 17ms/step - loss: 5.7025e-04 - accuracy: 1.0000 - val_loss: 0.2240 - val_accuracy: 0.9558
#
# Epoch 00021: val_accuracy did not improve from 0.96018
# Epoch 22/30
# 128/128 [==============================] - 2s 17ms/step - loss: 3.6471e-04 - accuracy: 1.0000 - val_loss: 0.2426 - val_accuracy: 0.9535
#
# Epoch 00022: val_accuracy did not improve from 0.96018
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 23/30
# 128/128 [==============================] - 2s 17ms/step - loss: 2.7140e-04 - accuracy: 1.0000 - val_loss: 0.2443 - val_accuracy: 0.9535
#
# Epoch 00023: val_accuracy did not improve from 0.96018
# Epoch 24/30
# 128/128 [==============================] - 2s 17ms/step - loss: 2.4423e-04 - accuracy: 1.0000 - val_loss: 0.2470 - val_accuracy: 0.9535
#
# Epoch 00024: val_accuracy did not improve from 0.96018
# Epoch 25/30
# 128/128 [==============================] - 2s 17ms/step - loss: 2.1572e-04 - accuracy: 1.0000 - val_loss: 0.2529 - val_accuracy: 0.9513
#
# Epoch 00025: val_accuracy did not improve from 0.96018
# Epoch 26/30
# 128/128 [==============================] - 2s 17ms/step - loss: 1.9795e-04 - accuracy: 1.0000 - val_loss: 0.2528 - val_accuracy: 0.9513
#
# Epoch 00026: val_accuracy did not improve from 0.96018
# Epoch 27/30
# 128/128 [==============================] - 2s 17ms/step - loss: 1.7739e-04 - accuracy: 1.0000 - val_loss: 0.2552 - val_accuracy: 0.9513ss: 1.8038e-04 - accuracy:
#
# Epoch 00027: val_accuracy did not improve from 0.96018
# Epoch 28/30
# 128/128 [==============================] - 2s 17ms/step - loss: 1.6187e-04 - accuracy: 1.0000 - val_loss: 0.2576 - val_accuracy: 0.9513
#
# Epoch 00028: val_accuracy did not improve from 0.96018
# Epoch 29/30
# 128/128 [==============================] - 2s 17ms/step - loss: 1.4650e-04 - accuracy: 1.0000 - val_loss: 0.2599 - val_accuracy: 0.9535
#
# Epoch 00029: val_accuracy did not improve from 0.96018
# Epoch 30/30
# 128/128 [==============================] - 2s 17ms/step - loss: 1.3463e-04 - accuracy: 1.0000 - val_loss: 0.2637 - val_accuracy: 0.9491
#
# Epoch 00030: val_accuracy did not improve from 0.96018
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 10
# Genre split [['Country', 'Pop'], ['Disco', 'Metal', 'Rock']]
# Building model...
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 128/128 [==============================] - 3s 19ms/step - loss: 0.5770 - accuracy: 0.7144 - val_loss: 0.4740 - val_accuracy: 0.7633
#
# Epoch 00001: val_accuracy improved from -inf to 0.76327, saving model to ./models/tree_7/model_root_f2/folder10\model.h5
# Epoch 2/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.4448 - accuracy: 0.7850 - val_loss: 0.4141 - val_accuracy: 0.8009
#
# Epoch 00002: val_accuracy improved from 0.76327 to 0.80088, saving model to ./models/tree_7/model_root_f2/folder10\model.h5
# Epoch 3/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.4351 - accuracy: 0.8007 - val_loss: 0.4122 - val_accuracy: 0.8053
#
# Epoch 00003: val_accuracy improved from 0.80088 to 0.80531, saving model to ./models/tree_7/model_root_f2/folder10\model.h5
# Epoch 4/30
# 128/128 [==============================] - 2s 18ms/step - loss: 0.3741 - accuracy: 0.8331 - val_loss: 0.3751 - val_accuracy: 0.8385
#
# Epoch 00004: val_accuracy improved from 0.80531 to 0.83850, saving model to ./models/tree_7/model_root_f2/folder10\model.h5
# Epoch 5/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.3429 - accuracy: 0.8506 - val_loss: 0.3425 - val_accuracy: 0.8496
#
# Epoch 00005: val_accuracy improved from 0.83850 to 0.84956, saving model to ./models/tree_7/model_root_f2/folder10\model.h5
# Epoch 6/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.3002 - accuracy: 0.8752 - val_loss: 0.2979 - val_accuracy: 0.8650
#
# Epoch 00006: val_accuracy improved from 0.84956 to 0.86504, saving model to ./models/tree_7/model_root_f2/folder10\model.h5
# Epoch 7/30
# 128/128 [==============================] - 2s 18ms/step - loss: 0.2718 - accuracy: 0.8906 - val_loss: 0.2447 - val_accuracy: 0.9071
#
# Epoch 00007: val_accuracy improved from 0.86504 to 0.90708, saving model to ./models/tree_7/model_root_f2/folder10\model.h5
# Epoch 8/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.2336 - accuracy: 0.9054 - val_loss: 0.2486 - val_accuracy: 0.8982
#
# Epoch 00008: val_accuracy did not improve from 0.90708
# Epoch 9/30
# 128/128 [==============================] - 2s 18ms/step - loss: 0.2147 - accuracy: 0.9145 - val_loss: 0.1795 - val_accuracy: 0.9292
#
# Epoch 00009: val_accuracy improved from 0.90708 to 0.92920, saving model to ./models/tree_7/model_root_f2/folder10\model.h5
# Epoch 10/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1838 - accuracy: 0.9282 - val_loss: 0.2139 - val_accuracy: 0.9004
#
# Epoch 00010: val_accuracy did not improve from 0.92920
# Epoch 11/30
# 128/128 [==============================] - 2s 18ms/step - loss: 0.1489 - accuracy: 0.9425 - val_loss: 0.1778 - val_accuracy: 0.9204
#
# Epoch 00011: val_accuracy did not improve from 0.92920
# Epoch 12/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1374 - accuracy: 0.9499 - val_loss: 0.2136 - val_accuracy: 0.9137
#
# Epoch 00012: val_accuracy did not improve from 0.92920
# Epoch 13/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1090 - accuracy: 0.9587 - val_loss: 0.1590 - val_accuracy: 0.9358
#
# Epoch 00013: val_accuracy improved from 0.92920 to 0.93584, saving model to ./models/tree_7/model_root_f2/folder10\model.h5
# Epoch 14/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0942 - accuracy: 0.9661 - val_loss: 0.2163 - val_accuracy: 0.9181
#
# Epoch 00014: val_accuracy did not improve from 0.93584
# Epoch 15/30
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0832 - accuracy: 0.9671 - val_loss: 0.2271 - val_accuracy: 0.9181
#
# Epoch 00015: val_accuracy did not improve from 0.93584
# Epoch 16/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0604 - accuracy: 0.9771 - val_loss: 0.3668 - val_accuracy: 0.89600595 - accura
#
# Epoch 00016: val_accuracy did not improve from 0.93584
# Epoch 17/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0636 - accuracy: 0.9771 - val_loss: 0.2248 - val_accuracy: 0.93587 - ETA: 0s - loss: 0.0706
#
# Epoch 00017: val_accuracy did not improve from 0.93584
# Epoch 18/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0468 - accuracy: 0.9818 - val_loss: 0.2240 - val_accuracy: 0.9358
#
# Epoch 00018: val_accuracy did not improve from 0.93584
# Epoch 19/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0275 - accuracy: 0.9914 - val_loss: 0.2450 - val_accuracy: 0.9381
#
# Epoch 00019: val_accuracy improved from 0.93584 to 0.93805, saving model to ./models/tree_7/model_root_f2/folder10\model.h5
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0098 - accuracy: 0.9978 - val_loss: 0.2488 - val_accuracy: 0.9270
#
# Epoch 00020: val_accuracy did not improve from 0.93805
# Epoch 21/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0033 - accuracy: 0.9998 - val_loss: 0.2365 - val_accuracy: 0.9336
#
# Epoch 00021: val_accuracy did not improve from 0.93805
# Epoch 22/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2609 - val_accuracy: 0.9314ss: 0.0022 - accuracy
#
# Epoch 00022: val_accuracy did not improve from 0.93805
# Epoch 23/30
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2645 - val_accuracy: 0.9381
#
# Epoch 00023: val_accuracy did not improve from 0.93805
# Epoch 24/30
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2669 - val_accuracy: 0.9381
#
# Epoch 00024: val_accuracy did not improve from 0.93805
# Epoch 25/30
# 128/128 [==============================] - 2s 17ms/step - loss: 8.8013e-04 - accuracy: 1.0000 - val_loss: 0.2763 - val_accuracy: 0.9403
#
# Epoch 00025: val_accuracy improved from 0.93805 to 0.94027, saving model to ./models/tree_7/model_root_f2/folder10\model.h5
# Epoch 26/30
# 128/128 [==============================] - 2s 17ms/step - loss: 7.5185e-04 - accuracy: 1.0000 - val_loss: 0.2826 - val_accuracy: 0.9381
#
# Epoch 00026: val_accuracy did not improve from 0.94027
# Epoch 27/30
# 128/128 [==============================] - 2s 17ms/step - loss: 6.6594e-04 - accuracy: 1.0000 - val_loss: 0.2870 - val_accuracy: 0.9381
#
# Epoch 00027: val_accuracy did not improve from 0.94027
# Epoch 28/30
# 128/128 [==============================] - 2s 18ms/step - loss: 5.7592e-04 - accuracy: 1.0000 - val_loss: 0.2895 - val_accuracy: 0.9381
#
# Epoch 00028: val_accuracy did not improve from 0.94027
# Epoch 29/30
# 128/128 [==============================] - 2s 17ms/step - loss: 5.0649e-04 - accuracy: 1.0000 - val_loss: 0.2976 - val_accuracy: 0.9381
#
# Epoch 00029: val_accuracy did not improve from 0.94027
# Epoch 30/30
# 128/128 [==============================] - 2s 17ms/step - loss: 4.3663e-04 - accuracy: 1.0000 - val_loss: 0.3017 - val_accuracy: 0.9381
#
# Epoch 00030: val_accuracy did not improve from 0.94027
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
