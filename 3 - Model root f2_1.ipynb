# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Country':2, 'Metal':6, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {2: 'Country', 6: 'Metal', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7992, 128, 128) (7992, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((2418, 128, 128), (2418, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (999, 128, 128) (999, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((286, 128, 128), (286, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Country

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_7/model_root_f2_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_7/model_root_f2_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def create_split(elem):
    splits = list(set_partitions(elem, 2))
    
    return splits, len(splits)

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

genre_splits, num_splits = create_split(list(dict_genres.values()))
print("Num splits {}".format(num_splits))

if num_splits > 8:
    n_splits = num_splits
else:
    n_splits = 8

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)

    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Num splits 3
# Folder num 1
# Genre split [['Country'], ['Metal', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 74/74 [==============================] - 6s 29ms/step - loss: 0.7039 - accuracy: 0.6762 - val_loss: 0.4890 - val_accuracy: 0.7544
#
# Epoch 00001: val_accuracy improved from -inf to 0.75444, saving model to ./models/tree_7/model_root_f2_1/folder1\model.h5
# Epoch 2/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.4628 - accuracy: 0.7705 - val_loss: 0.4313 - val_accuracy: 0.8018
#
# Epoch 00002: val_accuracy improved from 0.75444 to 0.80178, saving model to ./models/tree_7/model_root_f2_1/folder1\model.h5
# Epoch 3/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.4173 - accuracy: 0.7929 - val_loss: 0.4186 - val_accuracy: 0.7840
#
# Epoch 00003: val_accuracy did not improve from 0.80178
# Epoch 4/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.3940 - accuracy: 0.8153 - val_loss: 0.3989 - val_accuracy: 0.7840
#
# Epoch 00004: val_accuracy did not improve from 0.80178
# Epoch 5/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.3751 - accuracy: 0.8280 - val_loss: 0.3548 - val_accuracy: 0.8195
#
# Epoch 00005: val_accuracy improved from 0.80178 to 0.81953, saving model to ./models/tree_7/model_root_f2_1/folder1\model.h5
# Epoch 6/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.3547 - accuracy: 0.8398 - val_loss: 0.3927 - val_accuracy: 0.7929
#
# Epoch 00006: val_accuracy did not improve from 0.81953
# Epoch 7/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.3700 - accuracy: 0.8297 - val_loss: 0.3476 - val_accuracy: 0.8521
#
# Epoch 00007: val_accuracy improved from 0.81953 to 0.85207, saving model to ./models/tree_7/model_root_f2_1/folder1\model.h5
# Epoch 8/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.3336 - accuracy: 0.8449 - val_loss: 0.3016 - val_accuracy: 0.8639
#
# Epoch 00008: val_accuracy improved from 0.85207 to 0.86391, saving model to ./models/tree_7/model_root_f2_1/folder1\model.h5
# Epoch 9/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.3259 - accuracy: 0.8495 - val_loss: 0.3246 - val_accuracy: 0.8580
#
# Epoch 00009: val_accuracy did not improve from 0.86391
# Epoch 10/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.2852 - accuracy: 0.8795 - val_loss: 0.2634 - val_accuracy: 0.8728
#
# Epoch 00010: val_accuracy improved from 0.86391 to 0.87278, saving model to ./models/tree_7/model_root_f2_1/folder1\model.h5
# Epoch 11/30
# 74/74 [==============================] - 1s 20ms/step - loss: 0.2465 - accuracy: 0.8939 - val_loss: 0.2301 - val_accuracy: 0.9024
#
# Epoch 00011: val_accuracy improved from 0.87278 to 0.90237, saving model to ./models/tree_7/model_root_f2_1/folder1\model.h5
# Epoch 12/30
# 74/74 [==============================] - 1s 20ms/step - loss: 0.2090 - accuracy: 0.9163 - val_loss: 0.2152 - val_accuracy: 0.9053
#
# Epoch 00012: val_accuracy improved from 0.90237 to 0.90533, saving model to ./models/tree_7/model_root_f2_1/folder1\model.h5
# Epoch 13/30
# 74/74 [==============================] - 1s 20ms/step - loss: 0.1999 - accuracy: 0.9176 - val_loss: 0.1929 - val_accuracy: 0.9112
#
# Epoch 00013: val_accuracy improved from 0.90533 to 0.91124, saving model to ./models/tree_7/model_root_f2_1/folder1\model.h5
# Epoch 14/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1687 - accuracy: 0.9324 - val_loss: 0.2270 - val_accuracy: 0.9024
#
# Epoch 00014: val_accuracy did not improve from 0.91124
# Epoch 15/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1502 - accuracy: 0.9408 - val_loss: 0.1817 - val_accuracy: 0.9142
#
# Epoch 00015: val_accuracy improved from 0.91124 to 0.91420, saving model to ./models/tree_7/model_root_f2_1/folder1\model.h5
# Epoch 16/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1152 - accuracy: 0.9531 - val_loss: 0.3108 - val_accuracy: 0.8639
#
# Epoch 00016: val_accuracy did not improve from 0.91420
# Epoch 17/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1186 - accuracy: 0.9556 - val_loss: 0.1997 - val_accuracy: 0.9231
#
# Epoch 00017: val_accuracy improved from 0.91420 to 0.92308, saving model to ./models/tree_7/model_root_f2_1/folder1\model.h5
# Epoch 18/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0821 - accuracy: 0.9670 - val_loss: 0.2210 - val_accuracy: 0.9201
#
# Epoch 00018: val_accuracy did not improve from 0.92308
# Epoch 19/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0742 - accuracy: 0.9755 - val_loss: 0.2249 - val_accuracy: 0.9172
#
# Epoch 00019: val_accuracy did not improve from 0.92308
# Epoch 20/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0477 - accuracy: 0.9856 - val_loss: 0.2287 - val_accuracy: 0.9408
#
# Epoch 00020: val_accuracy improved from 0.92308 to 0.94083, saving model to ./models/tree_7/model_root_f2_1/folder1\model.h5
# Epoch 21/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0548 - accuracy: 0.9755 - val_loss: 0.2448 - val_accuracy: 0.9260
#
# Epoch 00021: val_accuracy did not improve from 0.94083
# Epoch 22/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1056 - accuracy: 0.9641 - val_loss: 0.2753 - val_accuracy: 0.8964
#
# Epoch 00022: val_accuracy did not improve from 0.94083
# Epoch 23/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0897 - accuracy: 0.9653 - val_loss: 0.2359 - val_accuracy: 0.9320
#
# Epoch 00023: val_accuracy did not improve from 0.94083
# Epoch 24/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0254 - accuracy: 0.9915 - val_loss: 0.2358 - val_accuracy: 0.9290
#
# Epoch 00024: val_accuracy did not improve from 0.94083
# Epoch 25/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0131 - accuracy: 0.9975 - val_loss: 0.2293 - val_accuracy: 0.9290
#
# Epoch 00025: val_accuracy did not improve from 0.94083
# Epoch 26/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0054 - accuracy: 0.9996 - val_loss: 0.2570 - val_accuracy: 0.9290
#
# Epoch 00026: val_accuracy did not improve from 0.94083
# Epoch 27/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.3058 - val_accuracy: 0.9231
#
# Epoch 00027: val_accuracy did not improve from 0.94083
# Epoch 28/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3003 - val_accuracy: 0.9290
#
# Epoch 00028: val_accuracy did not improve from 0.94083
# Epoch 29/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3049 - val_accuracy: 0.9260
#
# Epoch 00029: val_accuracy did not improve from 0.94083
# Epoch 30/30
# 74/74 [==============================] - 1s 19ms/step - loss: 8.5831e-04 - accuracy: 1.0000 - val_loss: 0.3149 - val_accuracy: 0.9260
#
# Epoch 00030: val_accuracy did not improve from 0.94083
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Country', 'Metal'], ['Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 74/74 [==============================] - 2s 22ms/step - loss: 0.7146 - accuracy: 0.6505 - val_loss: 0.6536 - val_accuracy: 0.6391
#
# Epoch 00001: val_accuracy improved from -inf to 0.63905, saving model to ./models/tree_7/model_root_f2_1/folder2\model.h5
# Epoch 2/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.6425 - accuracy: 0.6682 - val_loss: 0.6520 - val_accuracy: 0.6391
#
# Epoch 00002: val_accuracy did not improve from 0.63905
# Epoch 3/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.6451 - accuracy: 0.6615 - val_loss: 0.6542 - val_accuracy: 0.6391
#
# Epoch 00003: val_accuracy did not improve from 0.63905
# Epoch 4/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.6384 - accuracy: 0.6682 - val_loss: 0.6526 - val_accuracy: 0.6391
#
# Epoch 00004: val_accuracy did not improve from 0.63905
# Epoch 5/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.6372 - accuracy: 0.6682 - val_loss: 0.6578 - val_accuracy: 0.6391
#
# Epoch 00005: val_accuracy did not improve from 0.63905
# Epoch 6/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.6348 - accuracy: 0.6627 - val_loss: 0.6379 - val_accuracy: 0.6391
#
# Epoch 00006: val_accuracy did not improve from 0.63905
# Epoch 7/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.6460 - accuracy: 0.6615 - val_loss: 0.6532 - val_accuracy: 0.6391
#
# Epoch 00007: val_accuracy did not improve from 0.63905
# Epoch 8/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.6402 - accuracy: 0.6682 - val_loss: 0.6533 - val_accuracy: 0.6391
#
# Epoch 00008: val_accuracy did not improve from 0.63905
# Epoch 9/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.6356 - accuracy: 0.6682 - val_loss: 0.6485 - val_accuracy: 0.6391
#
# Epoch 00009: val_accuracy did not improve from 0.63905
# Epoch 10/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.6206 - accuracy: 0.6598 - val_loss: 0.6310 - val_accuracy: 0.6391
#
# Epoch 00010: val_accuracy did not improve from 0.63905
# Epoch 11/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.5994 - accuracy: 0.6657 - val_loss: 0.5681 - val_accuracy: 0.6657
#
# Epoch 00011: val_accuracy improved from 0.63905 to 0.66568, saving model to ./models/tree_7/model_root_f2_1/folder2\model.h5
# Epoch 12/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.5769 - accuracy: 0.6830 - val_loss: 0.6175 - val_accuracy: 0.6479
#
# Epoch 00012: val_accuracy did not improve from 0.66568
# Epoch 13/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.5738 - accuracy: 0.6864 - val_loss: 0.5533 - val_accuracy: 0.6864
#
# Epoch 00013: val_accuracy improved from 0.66568 to 0.68639, saving model to ./models/tree_7/model_root_f2_1/folder2\model.h5
# Epoch 14/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.5619 - accuracy: 0.7033 - val_loss: 0.5378 - val_accuracy: 0.6953
#
# Epoch 00014: val_accuracy improved from 0.68639 to 0.69527, saving model to ./models/tree_7/model_root_f2_1/folder2\model.h5
# Epoch 15/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.5454 - accuracy: 0.7210 - val_loss: 0.5246 - val_accuracy: 0.7337
#
# Epoch 00015: val_accuracy improved from 0.69527 to 0.73373, saving model to ./models/tree_7/model_root_f2_1/folder2\model.h5
# Epoch 16/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.5337 - accuracy: 0.7223 - val_loss: 0.5631 - val_accuracy: 0.6716
#
# Epoch 00016: val_accuracy did not improve from 0.73373
# Epoch 17/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.5339 - accuracy: 0.7295 - val_loss: 0.4956 - val_accuracy: 0.7544
#
# Epoch 00017: val_accuracy improved from 0.73373 to 0.75444, saving model to ./models/tree_7/model_root_f2_1/folder2\model.h5
# Epoch 18/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.4946 - accuracy: 0.7608 - val_loss: 0.4858 - val_accuracy: 0.7692
#
# Epoch 00018: val_accuracy improved from 0.75444 to 0.76923, saving model to ./models/tree_7/model_root_f2_1/folder2\model.h5
# Epoch 19/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.4590 - accuracy: 0.7823 - val_loss: 0.4281 - val_accuracy: 0.8107
#
# Epoch 00019: val_accuracy improved from 0.76923 to 0.81065, saving model to ./models/tree_7/model_root_f2_1/folder2\model.h5
# Epoch 20/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.4029 - accuracy: 0.8145 - val_loss: 0.3878 - val_accuracy: 0.8166
#
# Epoch 00020: val_accuracy improved from 0.81065 to 0.81657, saving model to ./models/tree_7/model_root_f2_1/folder2\model.h5
# Epoch 21/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.3803 - accuracy: 0.8259 - val_loss: 0.3667 - val_accuracy: 0.8284
#
# Epoch 00021: val_accuracy improved from 0.81657 to 0.82840, saving model to ./models/tree_7/model_root_f2_1/folder2\model.h5
# Epoch 22/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.3417 - accuracy: 0.8474 - val_loss: 0.3654 - val_accuracy: 0.8432
#
# Epoch 00022: val_accuracy improved from 0.82840 to 0.84320, saving model to ./models/tree_7/model_root_f2_1/folder2\model.h5
# Epoch 23/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.3012 - accuracy: 0.8652 - val_loss: 0.5949 - val_accuracy: 0.7722
#
# Epoch 00023: val_accuracy did not improve from 0.84320
# Epoch 24/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.2807 - accuracy: 0.8855 - val_loss: 0.3653 - val_accuracy: 0.8491
#
# Epoch 00024: val_accuracy improved from 0.84320 to 0.84911, saving model to ./models/tree_7/model_root_f2_1/folder2\model.h5
# Epoch 25/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.2589 - accuracy: 0.8791 - val_loss: 0.3407 - val_accuracy: 0.8402
#
# Epoch 00025: val_accuracy did not improve from 0.84911
# Epoch 26/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1994 - accuracy: 0.9269 - val_loss: 0.3538 - val_accuracy: 0.8550
#
# Epoch 00026: val_accuracy improved from 0.84911 to 0.85503, saving model to ./models/tree_7/model_root_f2_1/folder2\model.h5
# Epoch 27/30
# 74/74 [==============================] - 3s 41ms/step - loss: 0.1894 - accuracy: 0.9201 - val_loss: 0.3506 - val_accuracy: 0.8609
#
# Epoch 00027: val_accuracy improved from 0.85503 to 0.86095, saving model to ./models/tree_7/model_root_f2_1/folder2\model.h5
# Epoch 28/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1336 - accuracy: 0.9510 - val_loss: 0.4429 - val_accuracy: 0.8432
#
# Epoch 00028: val_accuracy did not improve from 0.86095
# Epoch 29/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1721 - accuracy: 0.9315 - val_loss: 0.3903 - val_accuracy: 0.8580
#
# Epoch 00029: val_accuracy did not improve from 0.86095
# Epoch 30/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1003 - accuracy: 0.9603 - val_loss: 0.4284 - val_accuracy: 0.8639
#
# Epoch 00030: val_accuracy improved from 0.86095 to 0.86391, saving model to ./models/tree_7/model_root_f2_1/folder2\model.h5
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Metal'], ['Country', 'Rock']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 74/74 [==============================] - 2s 22ms/step - loss: 0.5452 - accuracy: 0.7451 - val_loss: 0.2368 - val_accuracy: 0.9053
#
# Epoch 00001: val_accuracy improved from -inf to 0.90533, saving model to ./models/tree_7/model_root_f2_1/folder3\model.h5
# Epoch 2/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1929 - accuracy: 0.9256 - val_loss: 0.2207 - val_accuracy: 0.9083
#
# Epoch 00002: val_accuracy improved from 0.90533 to 0.90828, saving model to ./models/tree_7/model_root_f2_1/folder3\model.h5
# Epoch 3/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1727 - accuracy: 0.9374 - val_loss: 0.1822 - val_accuracy: 0.9379
#
# Epoch 00003: val_accuracy improved from 0.90828 to 0.93787, saving model to ./models/tree_7/model_root_f2_1/folder3\model.h5
# Epoch 4/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1569 - accuracy: 0.9404 - val_loss: 0.3029 - val_accuracy: 0.8757
#
# Epoch 00004: val_accuracy did not improve from 0.93787
# Epoch 5/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1505 - accuracy: 0.9501 - val_loss: 0.1545 - val_accuracy: 0.9467
#
# Epoch 00005: val_accuracy improved from 0.93787 to 0.94675, saving model to ./models/tree_7/model_root_f2_1/folder3\model.h5
# Epoch 6/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1352 - accuracy: 0.9476 - val_loss: 0.1621 - val_accuracy: 0.9497
#
# Epoch 00006: val_accuracy improved from 0.94675 to 0.94970, saving model to ./models/tree_7/model_root_f2_1/folder3\model.h5
# Epoch 7/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1207 - accuracy: 0.9548 - val_loss: 0.1632 - val_accuracy: 0.9349
#
# Epoch 00007: val_accuracy did not improve from 0.94970
# Epoch 8/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1080 - accuracy: 0.9607 - val_loss: 0.1668 - val_accuracy: 0.9320
#
# Epoch 00008: val_accuracy did not improve from 0.94970
# Epoch 9/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.1088 - accuracy: 0.9586 - val_loss: 0.1671 - val_accuracy: 0.9497
#
# Epoch 00009: val_accuracy did not improve from 0.94970
# Epoch 10/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0992 - accuracy: 0.9641 - val_loss: 0.1741 - val_accuracy: 0.9379
#
# Epoch 00010: val_accuracy did not improve from 0.94970
# Epoch 11/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0920 - accuracy: 0.9683 - val_loss: 0.1835 - val_accuracy: 0.9290
#
# Epoch 00011: val_accuracy did not improve from 0.94970
# Epoch 12/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0829 - accuracy: 0.9700 - val_loss: 0.1608 - val_accuracy: 0.9379
#
# Epoch 00012: val_accuracy did not improve from 0.94970
# Epoch 13/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0835 - accuracy: 0.9713 - val_loss: 0.1410 - val_accuracy: 0.9527
#
# Epoch 00013: val_accuracy improved from 0.94970 to 0.95266, saving model to ./models/tree_7/model_root_f2_1/folder3\model.h5
# Epoch 14/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0765 - accuracy: 0.9717 - val_loss: 0.1975 - val_accuracy: 0.9172
#
# Epoch 00014: val_accuracy did not improve from 0.95266
# Epoch 15/30
# 74/74 [==============================] - 1s 20ms/step - loss: 0.0624 - accuracy: 0.9763 - val_loss: 0.1315 - val_accuracy: 0.9586
#
# Epoch 00015: val_accuracy improved from 0.95266 to 0.95858, saving model to ./models/tree_7/model_root_f2_1/folder3\model.h5
# Epoch 16/30
# 74/74 [==============================] - 2s 21ms/step - loss: 0.0721 - accuracy: 0.9759 - val_loss: 0.1568 - val_accuracy: 0.9527
#
# Epoch 00016: val_accuracy did not improve from 0.95858
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 17/30
# 74/74 [==============================] - 2s 21ms/step - loss: 0.0442 - accuracy: 0.9839 - val_loss: 0.1421 - val_accuracy: 0.9615
#
# Epoch 00017: val_accuracy improved from 0.95858 to 0.96154, saving model to ./models/tree_7/model_root_f2_1/folder3\model.h5
# Epoch 18/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0434 - accuracy: 0.9822 - val_loss: 0.1350 - val_accuracy: 0.9615
#
# Epoch 00018: val_accuracy did not improve from 0.96154
# Epoch 19/30
# 74/74 [==============================] - 2s 25ms/step - loss: 0.0345 - accuracy: 0.9861 - val_loss: 0.1403 - val_accuracy: 0.9615
#
# Epoch 00019: val_accuracy did not improve from 0.96154
# Epoch 20/30
# 74/74 [==============================] - 2s 22ms/step - loss: 0.0257 - accuracy: 0.9911 - val_loss: 0.1583 - val_accuracy: 0.9645
#
# Epoch 00020: val_accuracy improved from 0.96154 to 0.96450, saving model to ./models/tree_7/model_root_f2_1/folder3\model.h5
# Epoch 21/30
# 74/74 [==============================] - 2s 26ms/step - loss: 0.0263 - accuracy: 0.9924 - val_loss: 0.1529 - val_accuracy: 0.9586
#
# Epoch 00021: val_accuracy did not improve from 0.96450
# Epoch 22/30
# 74/74 [==============================] - 2s 21ms/step - loss: 0.0199 - accuracy: 0.9945 - val_loss: 0.1659 - val_accuracy: 0.9675
#
# Epoch 00022: val_accuracy improved from 0.96450 to 0.96746, saving model to ./models/tree_7/model_root_f2_1/folder3\model.h5
# Epoch 23/30
# 74/74 [==============================] - 2s 21ms/step - loss: 0.0178 - accuracy: 0.9937 - val_loss: 0.1628 - val_accuracy: 0.9527
#
# Epoch 00023: val_accuracy did not improve from 0.96746
# Epoch 24/30
# 74/74 [==============================] - 2s 22ms/step - loss: 0.0155 - accuracy: 0.9949 - val_loss: 0.1715 - val_accuracy: 0.9675
#
# Epoch 00024: val_accuracy did not improve from 0.96746
# Epoch 25/30
# 74/74 [==============================] - 2s 26ms/step - loss: 0.0168 - accuracy: 0.9962 - val_loss: 0.1698 - val_accuracy: 0.9586
#
# Epoch 00025: val_accuracy did not improve from 0.96746
# Epoch 26/30
# 74/74 [==============================] - 2s 23ms/step - loss: 0.0158 - accuracy: 0.9949 - val_loss: 0.1722 - val_accuracy: 0.9615
#
# Epoch 00026: val_accuracy did not improve from 0.96746
# Epoch 27/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0174 - accuracy: 0.9941 - val_loss: 0.1874 - val_accuracy: 0.9556
#
# Epoch 00027: val_accuracy did not improve from 0.96746
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 28/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0113 - accuracy: 0.9962 - val_loss: 0.1756 - val_accuracy: 0.9675
#
# Epoch 00028: val_accuracy did not improve from 0.96746
# Epoch 29/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0102 - accuracy: 0.9958 - val_loss: 0.1836 - val_accuracy: 0.9645
#
# Epoch 00029: val_accuracy did not improve from 0.96746
# Epoch 30/30
# 74/74 [==============================] - 1s 19ms/step - loss: 0.0107 - accuracy: 0.9966 - val_loss: 0.1817 - val_accuracy: 0.9675
#
# Epoch 00030: val_accuracy did not improve from 0.96746
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
