# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7}
dict_genres = {'Pop':6, 'Rock' :7}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {6: 'Pop', 7: 'Rock'}

# %%
npzfile = np.load('data/shuffled_train.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394,)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=8).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((1599, 640, 128), (1599, 8))

# %%
npzfile = np.load('data/shuffled_valid.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=8).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((200, 640, 128), (200, 8))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Pop

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

BATCH_SIZE = 64
EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding= 'valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation = 'softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 640
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = ".\\logs\\model_root_f1_1\\"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/model_root_f1_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def chunks(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
def create_split(elem, c):
    splits = []
    for i in range(c):
        equal = False
        np.random.shuffle(elem)
        new_split = list(chunks(elem, int(len(elem)/2)))
        for split in splits:
            if set(new_split[0]) == set(split[0]) and set(new_split[0]) == set(split[1]):
                equal = True
                break
            
        if equal:
            i-=1
            continue
        
        splits.append(new_split)
        
    return splits

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 4

kfold = KFold(n_splits=4, shuffle=True)
genre_splits = create_split(list(dict_genres.values()), num_splits)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    split = genre_splits[fold_no - 1]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)

    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Rock'], ['Pop']]
# Building model...
# Training...
# Epoch 1/30
# 22/22 [==============================] - 15s 197ms/step - loss: 2.0732 - accuracy: 0.4907 - val_loss: 0.6862 - val_accuracy: 0.4956
#
# Epoch 00001: val_accuracy improved from -inf to 0.49556, saving model to ./models/model_root_f1_1/folder1\model.h5
# Epoch 2/30
# 22/22 [==============================] - 4s 162ms/step - loss: 0.6811 - accuracy: 0.5567 - val_loss: 0.6670 - val_accuracy: 0.6067
#
# Epoch 00002: val_accuracy improved from 0.49556 to 0.60667, saving model to ./models/model_root_f1_1/folder1\model.h5
# Epoch 3/30
# 22/22 [==============================] - 4s 160ms/step - loss: 0.6674 - accuracy: 0.5997 - val_loss: 0.6273 - val_accuracy: 0.7156
#
# Epoch 00003: val_accuracy improved from 0.60667 to 0.71556, saving model to ./models/model_root_f1_1/folder1\model.h5
# Epoch 4/30
# 22/22 [==============================] - 4s 161ms/step - loss: 0.6274 - accuracy: 0.6657 - val_loss: 0.6060 - val_accuracy: 0.6667
#
# Epoch 00004: val_accuracy did not improve from 0.71556
# Epoch 5/30
# 22/22 [==============================] - 4s 160ms/step - loss: 0.6154 - accuracy: 0.6672 - val_loss: 0.5714 - val_accuracy: 0.7133
#
# Epoch 00005: val_accuracy did not improve from 0.71556
# Epoch 6/30
# 22/22 [==============================] - 3s 160ms/step - loss: 0.5921 - accuracy: 0.6887 - val_loss: 0.7272 - val_accuracy: 0.5311
#
# Epoch 00006: val_accuracy did not improve from 0.71556
# Epoch 7/30
# 22/22 [==============================] - 4s 162ms/step - loss: 0.6168 - accuracy: 0.6694 - val_loss: 0.5810 - val_accuracy: 0.6822
#
# Epoch 00007: val_accuracy did not improve from 0.71556
# Epoch 8/30
# 22/22 [==============================] - 4s 165ms/step - loss: 0.6152 - accuracy: 0.6679 - val_loss: 0.9298 - val_accuracy: 0.5378
#
# Epoch 00008: val_accuracy did not improve from 0.71556
# Epoch 9/30
# 22/22 [==============================] - 4s 170ms/step - loss: 0.6110 - accuracy: 0.6812 - val_loss: 0.5622 - val_accuracy: 0.7133
#
# Epoch 00009: val_accuracy did not improve from 0.71556
# Epoch 10/30
# 22/22 [==============================] - 4s 167ms/step - loss: 0.5545 - accuracy: 0.7109 - val_loss: 0.5368 - val_accuracy: 0.7467
#
# Epoch 00010: val_accuracy improved from 0.71556 to 0.74667, saving model to ./models/model_root_f1_1/folder1\model.h5
# Epoch 11/30
# 22/22 [==============================] - 3s 159ms/step - loss: 0.5435 - accuracy: 0.7183 - val_loss: 0.5523 - val_accuracy: 0.7400
#
# Epoch 00011: val_accuracy did not improve from 0.74667
# Epoch 12/30
# 22/22 [==============================] - 3s 158ms/step - loss: 0.5113 - accuracy: 0.7502 - val_loss: 0.5366 - val_accuracy: 0.7422
#
# Epoch 00012: val_accuracy did not improve from 0.74667
# Epoch 13/30
# 22/22 [==============================] - 3s 159ms/step - loss: 0.4975 - accuracy: 0.7687 - val_loss: 0.5579 - val_accuracy: 0.7200
#
# Epoch 00013: val_accuracy did not improve from 0.74667
# Epoch 14/30
# 22/22 [==============================] - 3s 159ms/step - loss: 0.4677 - accuracy: 0.7850 - val_loss: 0.5443 - val_accuracy: 0.7356
#
# Epoch 00014: val_accuracy did not improve from 0.74667
# Epoch 15/30
# 22/22 [==============================] - 4s 161ms/step - loss: 0.4864 - accuracy: 0.7680 - val_loss: 0.6439 - val_accuracy: 0.7156
#
# Epoch 00015: val_accuracy did not improve from 0.74667
# Epoch 16/30
# 22/22 [==============================] - 4s 160ms/step - loss: 0.4117 - accuracy: 0.8102 - val_loss: 0.7519 - val_accuracy: 0.7067
#
# Epoch 00016: val_accuracy did not improve from 0.74667
# Epoch 17/30
# 22/22 [==============================] - 3s 160ms/step - loss: 0.4044 - accuracy: 0.8221 - val_loss: 0.6213 - val_accuracy: 0.7289
#
# Epoch 00017: val_accuracy did not improve from 0.74667
# Epoch 18/30
# 22/22 [==============================] - 4s 161ms/step - loss: 0.3462 - accuracy: 0.8443 - val_loss: 0.8253 - val_accuracy: 0.7044
#
# Epoch 00018: val_accuracy did not improve from 0.74667
# Epoch 19/30
# 22/22 [==============================] - 4s 161ms/step - loss: 0.3045 - accuracy: 0.8703 - val_loss: 0.9825 - val_accuracy: 0.6933
#
# Epoch 00019: val_accuracy did not improve from 0.74667
# Epoch 20/30
# 22/22 [==============================] - 4s 162ms/step - loss: 0.2596 - accuracy: 0.8962 - val_loss: 0.7758 - val_accuracy: 0.7111
#
# Epoch 00020: val_accuracy did not improve from 0.74667
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/30
# 22/22 [==============================] - 4s 161ms/step - loss: 0.2068 - accuracy: 0.9259 - val_loss: 0.8198 - val_accuracy: 0.7356
#
# Epoch 00021: val_accuracy did not improve from 0.74667
# Epoch 22/30
# 22/22 [==============================] - 3s 160ms/step - loss: 0.1858 - accuracy: 0.9318 - val_loss: 1.0706 - val_accuracy: 0.6800
#
# Epoch 00022: val_accuracy did not improve from 0.74667
# Epoch 23/30
# 22/22 [==============================] - 4s 161ms/step - loss: 0.1538 - accuracy: 0.9474 - val_loss: 0.9356 - val_accuracy: 0.7200
#
# Epoch 00023: val_accuracy did not improve from 0.74667
# Epoch 24/30
# 22/22 [==============================] - 4s 165ms/step - loss: 0.1215 - accuracy: 0.9629 - val_loss: 1.0069 - val_accuracy: 0.6911
#
# Epoch 00024: val_accuracy did not improve from 0.74667
# Epoch 25/30
# 22/22 [==============================] - 8s 392ms/step - loss: 0.0995 - accuracy: 0.9733 - val_loss: 1.1280 - val_accuracy: 0.6756
#
# Epoch 00025: val_accuracy did not improve from 0.74667
# Epoch 26/30
# 22/22 [==============================] - 10s 457ms/step - loss: 0.0984 - accuracy: 0.9696 - val_loss: 1.2830 - val_accuracy: 0.6822
#
# Epoch 00026: val_accuracy did not improve from 0.74667
# Epoch 27/30
# 22/22 [==============================] - 17s 807ms/step - loss: 0.0650 - accuracy: 0.9881 - val_loss: 1.3416 - val_accuracy: 0.6844
#
# Epoch 00027: val_accuracy did not improve from 0.74667
# Epoch 28/30
# 22/22 [==============================] - 10s 476ms/step - loss: 0.0521 - accuracy: 0.9889 - val_loss: 1.3189 - val_accuracy: 0.6844
#
# Epoch 00028: val_accuracy did not improve from 0.74667
# Epoch 29/30
# 22/22 [==============================] - 13s 482ms/step - loss: 0.0382 - accuracy: 0.9926 - val_loss: 1.3442 - val_accuracy: 0.6956
#
# Epoch 00029: val_accuracy did not improve from 0.74667
# Epoch 30/30
# 22/22 [==============================] - 12s 581ms/step - loss: 0.0238 - accuracy: 0.9993 - val_loss: 1.7239 - val_accuracy: 0.6622
#
# Epoch 00030: val_accuracy did not improve from 0.74667
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Pop'], ['Rock']]
# Building model...
# Training...
# Epoch 1/30
# 22/22 [==============================] - 25s 1000ms/step - loss: 2.7054 - accuracy: 0.5093 - val_loss: 0.6954 - val_accuracy: 0.4733
#
# Epoch 00001: val_accuracy improved from -inf to 0.47333, saving model to ./models/model_root_f1_1/folder2\model.h5
# Epoch 2/30
# 22/22 [==============================] - 15s 685ms/step - loss: 0.6938 - accuracy: 0.4952 - val_loss: 0.6962 - val_accuracy: 0.4733
#
# Epoch 00002: val_accuracy did not improve from 0.47333
# Epoch 3/30
# 22/22 [==============================] - 12s 561ms/step - loss: 0.6945 - accuracy: 0.4744 - val_loss: 0.6957 - val_accuracy: 0.4733
#
# Epoch 00003: val_accuracy did not improve from 0.47333
# Epoch 4/30
# 22/22 [==============================] - 15s 700ms/step - loss: 0.6942 - accuracy: 0.5085 - val_loss: 0.6936 - val_accuracy: 0.4733
#
# Epoch 00004: val_accuracy did not improve from 0.47333
# Epoch 5/30
# 22/22 [==============================] - 12s 570ms/step - loss: 0.6936 - accuracy: 0.5063 - val_loss: 0.6931 - val_accuracy: 0.5267
#
# Epoch 00005: val_accuracy improved from 0.47333 to 0.52667, saving model to ./models/model_root_f1_1/folder2\model.h5
# Epoch 6/30
# 22/22 [==============================] - 12s 557ms/step - loss: 0.6941 - accuracy: 0.5026 - val_loss: 0.6985 - val_accuracy: 0.4733
#
# Epoch 00006: val_accuracy did not improve from 0.52667
# Epoch 7/30
# 22/22 [==============================] - 13s 622ms/step - loss: 0.6945 - accuracy: 0.5085 - val_loss: 0.6957 - val_accuracy: 0.4733
#
# Epoch 00007: val_accuracy did not improve from 0.52667
# Epoch 8/30
# 22/22 [==============================] - 10s 481ms/step - loss: 0.6933 - accuracy: 0.5085 - val_loss: 0.6940 - val_accuracy: 0.4733
#
# Epoch 00008: val_accuracy did not improve from 0.52667
# Epoch 9/30
# 22/22 [==============================] - 11s 498ms/step - loss: 0.6936 - accuracy: 0.4841 - val_loss: 0.6928 - val_accuracy: 0.5267
#
# Epoch 00009: val_accuracy did not improve from 0.52667
# Epoch 10/30
# 22/22 [==============================] - 13s 623ms/step - loss: 0.6933 - accuracy: 0.4915 - val_loss: 0.6930 - val_accuracy: 0.5267
#
# Epoch 00010: val_accuracy did not improve from 0.52667
# Epoch 11/30
# 22/22 [==============================] - 11s 512ms/step - loss: 0.6933 - accuracy: 0.4744 - val_loss: 0.6932 - val_accuracy: 0.4733
#
# Epoch 00011: val_accuracy did not improve from 0.52667
# Epoch 12/30
# 22/22 [==============================] - 11s 506ms/step - loss: 0.6931 - accuracy: 0.5085 - val_loss: 0.6935 - val_accuracy: 0.4733
#
# Epoch 00012: val_accuracy did not improve from 0.52667
# Epoch 13/30
# 22/22 [==============================] - 11s 501ms/step - loss: 0.6931 - accuracy: 0.5085 - val_loss: 0.6938 - val_accuracy: 0.4733
#
# Epoch 00013: val_accuracy did not improve from 0.52667
# Epoch 14/30
# 22/22 [==============================] - 10s 471ms/step - loss: 0.6931 - accuracy: 0.5085 - val_loss: 0.6939 - val_accuracy: 0.4733
#
# Epoch 00014: val_accuracy did not improve from 0.52667
# Epoch 15/30
# 22/22 [==============================] - 12s 574ms/step - loss: 0.6931 - accuracy: 0.5085 - val_loss: 0.6937 - val_accuracy: 0.4733
#
# Epoch 00015: val_accuracy did not improve from 0.52667
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 16/30
# 22/22 [==============================] - 10s 469ms/step - loss: 0.6930 - accuracy: 0.5085 - val_loss: 0.6938 - val_accuracy: 0.4733
#
# Epoch 00016: val_accuracy did not improve from 0.52667
# Epoch 17/30
# 22/22 [==============================] - 13s 613ms/step - loss: 0.6930 - accuracy: 0.5085 - val_loss: 0.6937 - val_accuracy: 0.4733
#
# Epoch 00017: val_accuracy did not improve from 0.52667
# Epoch 18/30
# 22/22 [==============================] - 11s 494ms/step - loss: 0.6930 - accuracy: 0.5085 - val_loss: 0.6938 - val_accuracy: 0.4733
#
# Epoch 00018: val_accuracy did not improve from 0.52667
# Epoch 19/30
# 22/22 [==============================] - 14s 667ms/step - loss: 0.6930 - accuracy: 0.5085 - val_loss: 0.6940 - val_accuracy: 0.4733
#
# Epoch 00019: val_accuracy did not improve from 0.52667
# Epoch 20/30
# 22/22 [==============================] - 10s 473ms/step - loss: 0.6930 - accuracy: 0.5085 - val_loss: 0.6941 - val_accuracy: 0.4733
#
# Epoch 00020: val_accuracy did not improve from 0.52667
# Epoch 21/30
# 22/22 [==============================] - 12s 473ms/step - loss: 0.6930 - accuracy: 0.5085 - val_loss: 0.6940 - val_accuracy: 0.4733
#
# Epoch 00021: val_accuracy did not improve from 0.52667
# Epoch 22/30
# 22/22 [==============================] - 10s 470ms/step - loss: 0.6930 - accuracy: 0.5085 - val_loss: 0.6940 - val_accuracy: 0.4733
#
# Epoch 00022: val_accuracy did not improve from 0.52667
# Epoch 23/30
# 22/22 [==============================] - 10s 369ms/step - loss: 0.6930 - accuracy: 0.5085 - val_loss: 0.6940 - val_accuracy: 0.4733
#
# Epoch 00023: val_accuracy did not improve from 0.52667
# Epoch 24/30
# 22/22 [==============================] - 3s 158ms/step - loss: 0.6930 - accuracy: 0.5085 - val_loss: 0.6941 - val_accuracy: 0.4733
#
# Epoch 00024: val_accuracy did not improve from 0.52667
# Epoch 25/30
# 22/22 [==============================] - 12s 551ms/step - loss: 0.6930 - accuracy: 0.5085 - val_loss: 0.6940 - val_accuracy: 0.4733
#
# Epoch 00025: val_accuracy did not improve from 0.52667
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 26/30
# 22/22 [==============================] - 19s 922ms/step - loss: 0.6930 - accuracy: 0.5085 - val_loss: 0.6940 - val_accuracy: 0.4733
#
# Epoch 00026: val_accuracy did not improve from 0.52667
# Epoch 27/30
# 22/22 [==============================] - 11s 540ms/step - loss: 0.6930 - accuracy: 0.5085 - val_loss: 0.6940 - val_accuracy: 0.4733
#
# Epoch 00027: val_accuracy did not improve from 0.52667
# Epoch 28/30
# 22/22 [==============================] - 15s 701ms/step - loss: 0.6930 - accuracy: 0.5085 - val_loss: 0.6939 - val_accuracy: 0.4733
#
# Epoch 00028: val_accuracy did not improve from 0.52667
# Epoch 29/30
# 22/22 [==============================] - 12s 571ms/step - loss: 0.6930 - accuracy: 0.5085 - val_loss: 0.6939 - val_accuracy: 0.4733
#
# Epoch 00029: val_accuracy did not improve from 0.52667
# Epoch 30/30
# 22/22 [==============================] - 13s 635ms/step - loss: 0.6930 - accuracy: 0.5085 - val_loss: 0.6939 - val_accuracy: 0.4733
#
# Epoch 00030: val_accuracy did not improve from 0.52667
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Rock'], ['Pop']]
# Building model...
# Training...
# Epoch 1/30
# 22/22 [==============================] - 17s 601ms/step - loss: 1.8163 - accuracy: 0.5107 - val_loss: 0.6779 - val_accuracy: 0.6356
#
# Epoch 00001: val_accuracy improved from -inf to 0.63556, saving model to ./models/model_root_f1_1/folder3\model.h5
# Epoch 2/30
# 22/22 [==============================] - 12s 475ms/step - loss: 0.6779 - accuracy: 0.5352 - val_loss: 0.6847 - val_accuracy: 0.5022
#
# Epoch 00002: val_accuracy did not improve from 0.63556
# Epoch 3/30
# 22/22 [==============================] - 10s 469ms/step - loss: 0.6638 - accuracy: 0.6027 - val_loss: 0.6464 - val_accuracy: 0.5689
#
# Epoch 00003: val_accuracy did not improve from 0.63556
# Epoch 4/30
# 22/22 [==============================] - 12s 483ms/step - loss: 0.6320 - accuracy: 0.6390 - val_loss: 0.5971 - val_accuracy: 0.7289
#
# Epoch 00004: val_accuracy improved from 0.63556 to 0.72889, saving model to ./models/model_root_f1_1/folder3\model.h5
# Epoch 5/30
# 22/22 [==============================] - 10s 473ms/step - loss: 0.6497 - accuracy: 0.6219 - val_loss: 0.6561 - val_accuracy: 0.5867
#
# Epoch 00005: val_accuracy did not improve from 0.72889
# Epoch 6/30
# 22/22 [==============================] - 10s 471ms/step - loss: 0.6078 - accuracy: 0.6805 - val_loss: 0.5912 - val_accuracy: 0.7044
#
# Epoch 00006: val_accuracy did not improve from 0.72889
# Epoch 7/30
# 22/22 [==============================] - 12s 578ms/step - loss: 0.6148 - accuracy: 0.6664 - val_loss: 0.5990 - val_accuracy: 0.6844
#
# Epoch 00007: val_accuracy did not improve from 0.72889
# Epoch 8/30
# 22/22 [==============================] - 10s 472ms/step - loss: 0.5984 - accuracy: 0.6790 - val_loss: 0.6317 - val_accuracy: 0.6133
#
# Epoch 00008: val_accuracy did not improve from 0.72889
# Epoch 9/30
# 22/22 [==============================] - 12s 579ms/step - loss: 0.5961 - accuracy: 0.6686 - val_loss: 1.3578 - val_accuracy: 0.4867
#
# Epoch 00009: val_accuracy did not improve from 0.72889
# Epoch 10/30
# 22/22 [==============================] - 10s 476ms/step - loss: 0.6969 - accuracy: 0.6086 - val_loss: 0.5907 - val_accuracy: 0.7178
#
# Epoch 00010: val_accuracy did not improve from 0.72889
# Epoch 11/30
# 22/22 [==============================] - 11s 498ms/step - loss: 0.6010 - accuracy: 0.6864 - val_loss: 0.7052 - val_accuracy: 0.6000
#
# Epoch 00011: val_accuracy did not improve from 0.72889
# Epoch 12/30
# 22/22 [==============================] - 10s 475ms/step - loss: 0.6066 - accuracy: 0.6627 - val_loss: 0.6662 - val_accuracy: 0.6489
#
# Epoch 00012: val_accuracy did not improve from 0.72889
# Epoch 13/30
# 22/22 [==============================] - 12s 578ms/step - loss: 0.5730 - accuracy: 0.6887 - val_loss: 0.6301 - val_accuracy: 0.7089
#
# Epoch 00013: val_accuracy did not improve from 0.72889
# Epoch 14/30
# 22/22 [==============================] - 10s 473ms/step - loss: 0.5501 - accuracy: 0.7272 - val_loss: 0.6198 - val_accuracy: 0.6956
#
# Epoch 00014: val_accuracy did not improve from 0.72889
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 15/30
# 22/22 [==============================] - 12s 580ms/step - loss: 0.5027 - accuracy: 0.7450 - val_loss: 0.6389 - val_accuracy: 0.7356
#
# Epoch 00015: val_accuracy improved from 0.72889 to 0.73556, saving model to ./models/model_root_f1_1/folder3\model.h5
# Epoch 16/30
# 22/22 [==============================] - 10s 474ms/step - loss: 0.4852 - accuracy: 0.7643 - val_loss: 0.6685 - val_accuracy: 0.7333
#
# Epoch 00016: val_accuracy did not improve from 0.73556
# Epoch 17/30
# 22/22 [==============================] - 12s 472ms/step - loss: 0.4767 - accuracy: 0.7591 - val_loss: 0.6162 - val_accuracy: 0.7244
#
# Epoch 00017: val_accuracy did not improve from 0.73556
# Epoch 18/30
# 22/22 [==============================] - 12s 577ms/step - loss: 0.4511 - accuracy: 0.7835 - val_loss: 0.6701 - val_accuracy: 0.6444
#
# Epoch 00018: val_accuracy did not improve from 0.73556
# Epoch 19/30
# 22/22 [==============================] - 10s 473ms/step - loss: 0.4596 - accuracy: 0.7798 - val_loss: 0.5973 - val_accuracy: 0.7422
#
# Epoch 00019: val_accuracy improved from 0.73556 to 0.74222, saving model to ./models/model_root_f1_1/folder3\model.h5
# Epoch 20/30
# 22/22 [==============================] - 10s 472ms/step - loss: 0.4028 - accuracy: 0.8110 - val_loss: 0.6085 - val_accuracy: 0.7222
#
# Epoch 00020: val_accuracy did not improve from 0.74222
# Epoch 21/30
# 22/22 [==============================] - 4s 161ms/step - loss: 0.3655 - accuracy: 0.8265 - val_loss: 0.6026 - val_accuracy: 0.7267
#
# Epoch 00021: val_accuracy did not improve from 0.74222
# Epoch 22/30
# 22/22 [==============================] - 11s 536ms/step - loss: 0.3531 - accuracy: 0.8354 - val_loss: 0.7803 - val_accuracy: 0.7400
#
# Epoch 00022: val_accuracy did not improve from 0.74222
# Epoch 23/30
# 22/22 [==============================] - 13s 490ms/step - loss: 0.3319 - accuracy: 0.8547 - val_loss: 0.6664 - val_accuracy: 0.7467
#
# Epoch 00023: val_accuracy improved from 0.74222 to 0.74667, saving model to ./models/model_root_f1_1/folder3\model.h5
# Epoch 24/30
# 22/22 [==============================] - 13s 593ms/step - loss: 0.2832 - accuracy: 0.8755 - val_loss: 0.6923 - val_accuracy: 0.7489
#
# Epoch 00024: val_accuracy improved from 0.74667 to 0.74889, saving model to ./models/model_root_f1_1/folder3\model.h5
# Epoch 25/30
# 22/22 [==============================] - 10s 476ms/step - loss: 0.2757 - accuracy: 0.8836 - val_loss: 0.6394 - val_accuracy: 0.7022
#
# Epoch 00025: val_accuracy did not improve from 0.74889
# Epoch 26/30
# 22/22 [==============================] - 13s 595ms/step - loss: 0.2402 - accuracy: 0.9029 - val_loss: 0.6572 - val_accuracy: 0.7333
#
# Epoch 00026: val_accuracy did not improve from 0.74889
# Epoch 27/30
# 22/22 [==============================] - 10s 488ms/step - loss: 0.2261 - accuracy: 0.9103 - val_loss: 0.7232 - val_accuracy: 0.7067
#
# Epoch 00027: val_accuracy did not improve from 0.74889
# Epoch 28/30
# 22/22 [==============================] - 13s 483ms/step - loss: 0.1659 - accuracy: 0.9370 - val_loss: 0.7302 - val_accuracy: 0.7333
#
# Epoch 00028: val_accuracy did not improve from 0.74889
# Epoch 29/30
# 22/22 [==============================] - 12s 585ms/step - loss: 0.1563 - accuracy: 0.9489 - val_loss: 1.0858 - val_accuracy: 0.7600
#
# Epoch 00029: val_accuracy improved from 0.74889 to 0.76000, saving model to ./models/model_root_f1_1/folder3\model.h5
# Epoch 30/30
# 22/22 [==============================] - 10s 471ms/step - loss: 0.1423 - accuracy: 0.9518 - val_loss: 1.0083 - val_accuracy: 0.7311
#
# Epoch 00030: val_accuracy did not improve from 0.76000
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Rock'], ['Pop']]
# Building model...
# Training...
# Epoch 1/30
# 22/22 [==============================] - 21s 751ms/step - loss: 1.5919 - accuracy: 0.5156 - val_loss: 0.6781 - val_accuracy: 0.6927
#
# Epoch 00001: val_accuracy improved from -inf to 0.69265, saving model to ./models/model_root_f1_1/folder4\model.h5
# Epoch 2/30
# 22/22 [==============================] - 12s 577ms/step - loss: 0.6555 - accuracy: 0.6119 - val_loss: 0.7198 - val_accuracy: 0.5189
#
# Epoch 00002: val_accuracy did not improve from 0.69265
# Epoch 3/30
# 22/22 [==============================] - 13s 613ms/step - loss: 0.6179 - accuracy: 0.6659 - val_loss: 0.7160 - val_accuracy: 0.5212
#
# Epoch 00003: val_accuracy did not improve from 0.69265
# Epoch 4/30
# 22/22 [==============================] - 12s 584ms/step - loss: 0.6290 - accuracy: 0.6570 - val_loss: 0.6133 - val_accuracy: 0.7216
#
# Epoch 00004: val_accuracy improved from 0.69265 to 0.72160, saving model to ./models/model_root_f1_1/folder4\model.h5
# Epoch 5/30
# 22/22 [==============================] - 10s 473ms/step - loss: 0.5979 - accuracy: 0.6793 - val_loss: 1.0976 - val_accuracy: 0.4922
#
# Epoch 00005: val_accuracy did not improve from 0.72160
# Epoch 6/30
# 22/22 [==============================] - 12s 474ms/step - loss: 0.6516 - accuracy: 0.6356 - val_loss: 0.6359 - val_accuracy: 0.6392
#
# Epoch 00006: val_accuracy did not improve from 0.72160
# Epoch 7/30
# 22/22 [==============================] - 12s 578ms/step - loss: 0.5628 - accuracy: 0.7237 - val_loss: 0.8474 - val_accuracy: 0.5167
#
# Epoch 00007: val_accuracy did not improve from 0.72160
# Epoch 8/30
# 22/22 [==============================] - 10s 475ms/step - loss: 0.6138 - accuracy: 0.6793 - val_loss: 0.5920 - val_accuracy: 0.6726
#
# Epoch 00008: val_accuracy did not improve from 0.72160
# Epoch 9/30
# 22/22 [==============================] - 13s 531ms/step - loss: 0.5616 - accuracy: 0.7081 - val_loss: 0.6409 - val_accuracy: 0.6726
#
# Epoch 00009: val_accuracy did not improve from 0.72160
# Epoch 10/30
# 22/22 [==============================] - 10s 476ms/step - loss: 0.5508 - accuracy: 0.7215 - val_loss: 0.6007 - val_accuracy: 0.6927
#
# Epoch 00010: val_accuracy did not improve from 0.72160
# Epoch 11/30
# 22/22 [==============================] - 10s 480ms/step - loss: 0.5230 - accuracy: 0.7533 - val_loss: 0.6708 - val_accuracy: 0.6837
#
# Epoch 00011: val_accuracy did not improve from 0.72160
# Epoch 12/30
# 22/22 [==============================] - 12s 580ms/step - loss: 0.5383 - accuracy: 0.7326 - val_loss: 0.5606 - val_accuracy: 0.7327
#
# Epoch 00012: val_accuracy improved from 0.72160 to 0.73274, saving model to ./models/model_root_f1_1/folder4\model.h5
# Epoch 13/30
# 22/22 [==============================] - 10s 469ms/step - loss: 0.5443 - accuracy: 0.7348 - val_loss: 0.5448 - val_accuracy: 0.7216
#
# Epoch 00013: val_accuracy did not improve from 0.73274
# Epoch 14/30
# 22/22 [==============================] - 12s 574ms/step - loss: 0.4959 - accuracy: 0.7778 - val_loss: 0.6549 - val_accuracy: 0.6437
#
# Epoch 00014: val_accuracy did not improve from 0.73274
# Epoch 15/30
# 22/22 [==============================] - 10s 469ms/step - loss: 0.4943 - accuracy: 0.7615 - val_loss: 0.5711 - val_accuracy: 0.7082
#
# Epoch 00015: val_accuracy did not improve from 0.73274
# Epoch 16/30
# 22/22 [==============================] - 12s 575ms/step - loss: 0.4932 - accuracy: 0.7711 - val_loss: 0.7848 - val_accuracy: 0.6325
#
# Epoch 00016: val_accuracy did not improve from 0.73274
# Epoch 17/30
# 22/22 [==============================] - 10s 474ms/step - loss: 0.5362 - accuracy: 0.7163 - val_loss: 0.5323 - val_accuracy: 0.7372
#
# Epoch 00017: val_accuracy improved from 0.73274 to 0.73719, saving model to ./models/model_root_f1_1/folder4\model.h5
# Epoch 18/30
# 22/22 [==============================] - 4s 162ms/step - loss: 0.4648 - accuracy: 0.7844 - val_loss: 0.5261 - val_accuracy: 0.7483
#
# Epoch 00018: val_accuracy improved from 0.73719 to 0.74833, saving model to ./models/model_root_f1_1/folder4\model.h5
# Epoch 19/30
# 22/22 [==============================] - 8s 386ms/step - loss: 0.4225 - accuracy: 0.8163 - val_loss: 0.6030 - val_accuracy: 0.7038
#
# Epoch 00019: val_accuracy did not improve from 0.74833
# Epoch 20/30
# 22/22 [==============================] - 16s 752ms/step - loss: 0.4267 - accuracy: 0.8044 - val_loss: 0.9088 - val_accuracy: 0.6481
#
# Epoch 00020: val_accuracy did not improve from 0.74833
# Epoch 21/30
# 22/22 [==============================] - 12s 574ms/step - loss: 0.4107 - accuracy: 0.8178 - val_loss: 0.5911 - val_accuracy: 0.7171
#
# Epoch 00021: val_accuracy did not improve from 0.74833
# Epoch 22/30
# 22/22 [==============================] - 15s 563ms/step - loss: 0.3615 - accuracy: 0.8444 - val_loss: 0.5674 - val_accuracy: 0.7416
#
# Epoch 00022: val_accuracy did not improve from 0.74833
# Epoch 23/30
# 22/22 [==============================] - 20s 946ms/step - loss: 0.3138 - accuracy: 0.8704 - val_loss: 0.6429 - val_accuracy: 0.7283
#
# Epoch 00023: val_accuracy did not improve from 0.74833
# Epoch 24/30
# 22/22 [==============================] - 19s 879ms/step - loss: 0.3364 - accuracy: 0.8585 - val_loss: 0.6220 - val_accuracy: 0.7394
#
# Epoch 00024: val_accuracy did not improve from 0.74833
# Epoch 25/30
# 22/22 [==============================] - 15s 702ms/step - loss: 0.2817 - accuracy: 0.8852 - val_loss: 1.0086 - val_accuracy: 0.6993
#
# Epoch 00025: val_accuracy did not improve from 0.74833
# Epoch 26/30
# 22/22 [==============================] - 12s 542ms/step - loss: 0.2883 - accuracy: 0.8719 - val_loss: 1.0848 - val_accuracy: 0.6704
#
# Epoch 00026: val_accuracy did not improve from 0.74833
# Epoch 27/30
# 22/22 [==============================] - 17s 792ms/step - loss: 0.2132 - accuracy: 0.9178 - val_loss: 0.9384 - val_accuracy: 0.6993
#
# Epoch 00027: val_accuracy did not improve from 0.74833
# Epoch 28/30
# 22/22 [==============================] - 15s 695ms/step - loss: 0.1700 - accuracy: 0.9378 - val_loss: 0.9583 - val_accuracy: 0.7394
#
# Epoch 00028: val_accuracy did not improve from 0.74833
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 29/30
# 22/22 [==============================] - 18s 838ms/step - loss: 0.1070 - accuracy: 0.9637 - val_loss: 1.0335 - val_accuracy: 0.7149
#
# Epoch 00029: val_accuracy did not improve from 0.74833
# Epoch 30/30
# 22/22 [==============================] - 16s 776ms/step - loss: 0.0771 - accuracy: 0.9756 - val_loss: 1.1305 - val_accuracy: 0.7171
#
# Epoch 00030: val_accuracy did not improve from 0.74833
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
