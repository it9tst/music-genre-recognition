# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
from os.path import isfile
from datetime import datetime
from more_itertools import set_partitions
# %matplotlib inline

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import Session

config = ConfigProto()
config.gpu_options.allow_growth = True
sess = Session(config=config)

if tf.test.gpu_device_name():
    print("GPU found")
else:
    print("No GPU found")
# Out:
# GPU found

# %% [markdown]
# ## Load training and Validation arrays

# %%
#dict_genres = {'Blues':0, 'Classical':1, 'Country':2, 'Disco':3, 'Hip-Hop':4, 'Jazz':5, 'Metal':6, 'Pop':7, 'Reggae':8, 'Rock':9}
dict_genres = {'Country':2, 'Disco':3,'Hip-Hop':4, 'Pop':7, 'Reggae':8, 'Rock':9}

reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {2: 'Country', 3: 'Disco', 4: 'Hip-Hop', 7: 'Pop', 8: 'Reggae', 9: 'Rock'}

# %%
npzfile = np.load('data/all_targets_sets_train_new.npz')
print(npzfile.files)

X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (7990, 128, 128) (7990, 10)

# %%
y_train = np.argmax(y_train, axis = -1)

# %%
y_train_mask = np.in1d(y_train, list(dict_genres.values()))

# %%
y_train = y_train[y_train_mask]

# %%
y_train = utils.to_categorical(y_train, num_classes=10).astype(int)

# %%
X_train = X_train[y_train_mask]

# %%
X_train.shape, y_train.shape
# Out:
# ((4800, 128, 128), (4800, 10))

# %%
npzfile = np.load('data/all_targets_sets_valid_new.npz')
print(npzfile.files)

X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (1000, 128, 128) (1000, 10)

# %%
y_valid = np.argmax(y_valid, axis = -1)

# %%
y_valid_mask = np.in1d(y_valid, list(dict_genres.values()))

# %%
y_valid = y_valid[y_valid_mask]

# %%
y_valid = utils.to_categorical(y_valid, num_classes=10).astype(int)

# %%
X_valid = X_valid[y_valid_mask]

# %%
X_valid.shape, y_valid.shape
# Out:
# ((600, 128, 128), (600, 10))

# %% [markdown]
# ## Check by plotting a Spectogram

# %%
num = 0
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Disco

# %% [markdown]
# ## Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 2
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=32
nb_filters2=64
nb_filters3=128
nb_filters4=512
ksize = (3,3)
pool_size_1= (2,2)

EPOCH_COUNT = 30

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1, padding='valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_1)(conv_4)
    
    flatten1 = Flatten()(pool_4)
    
    output = Dense(num_classes, activation='softmax', name='preds')(flatten1)
    
    model_output = output
    model = Model(model_input, model_output)
    
    opt = Adam(learning_rate=0.001)
    
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val, info = "", genres_name = ""):
    n_frames = 128
    n_frequency = 128
    
    #reshape and expand dims for conv2d
    x_train = np.expand_dims(x_train, axis = -1)
    x_val = np.expand_dims(x_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
    log_dir = "./logs/tree_11/model_root_f1_1_1_1/"+datetime.now().strftime("%Y%m%d-%H%M%S_")+info
    tb_callback = TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=False, update_freq='batch', profile_batch=2, embeddings_freq=0, embeddings_metadata=None)

    model_folder = "./models/tree_11/model_root_f1_1_1_1/{}".format(info)
    os.makedirs(model_folder, exist_ok=True)
    
    f = open("{}/info.txt".format(model_folder), "w")
    f.write("genre name split: {}".format(genres_name))
    checkpoint_callback = ModelCheckpoint('{}/model.h5'.format(model_folder), monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_delta=0.01, verbose=1)
    callbacks_list = [tb_callback, checkpoint_callback, reducelr_callback]
    
    f.close()
    
    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=batch_size, epochs=EPOCH_COUNT, validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)
    
    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
X_train_cross = np.concatenate((X_train, X_valid), axis=0)
y_train_cross = np.concatenate((y_train, y_valid), axis=0)

num_splits = 6
n_splits = 15

kfold = KFold(n_splits, shuffle=True)

fold_no = 1
for train, test in kfold.split(X_train_cross, y_train_cross):
    dict_genres_list = list(dict_genres.values())
    split = [[dict_genres_list.pop(fold_no - 1)], dict_genres_list]
    
    y_train_cross_binary = np.argmax(y_train_cross, axis=1)
    y_train_cross_binary = np.in1d(y_train_cross_binary, split[0])
    y_train_cross_binary = utils.to_categorical(y_train_cross_binary*1, num_classes=2)
    
    print("Folder num {}".format(fold_no))
    genres_name = [[reverse_map[g] for g in split_l] for split_l in split]
    print("Genre split {}".format(genres_name))
    
    model, history  = train_model(X_train_cross[train], y_train_cross_binary[train], X_train_cross[test], y_train_cross_binary[test], "folder{}".format(fold_no), genres_name)
    show_summary_stats(history)
    
    fold_no += 1
    if fold_no > num_splits:
        break
# Out:
# Folder num 1
# Genre split [['Country'], ['Disco', 'Hip-Hop', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 158/158 [==============================] - 7s 22ms/step - loss: 0.4784 - accuracy: 0.8310 - val_loss: 0.3152 - val_accuracy: 0.8583
#
# Epoch 00001: val_accuracy improved from -inf to 0.85833, saving model to ./models/tree_11/model_root_f1_1_1_1/folder1\model.h5
# Epoch 2/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.3053 - accuracy: 0.8558 - val_loss: 0.2832 - val_accuracy: 0.8556
#
# Epoch 00002: val_accuracy did not improve from 0.85833
# Epoch 3/30
# 158/158 [==============================] - 3s 20ms/step - loss: 0.2703 - accuracy: 0.8661 - val_loss: 0.2633 - val_accuracy: 0.8778
#
# Epoch 00003: val_accuracy improved from 0.85833 to 0.87778, saving model to ./models/tree_11/model_root_f1_1_1_1/folder1\model.h5
# Epoch 4/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.2425 - accuracy: 0.8821 - val_loss: 0.2306 - val_accuracy: 0.8944
#
# Epoch 00004: val_accuracy improved from 0.87778 to 0.89444, saving model to ./models/tree_11/model_root_f1_1_1_1/folder1\model.h5
# Epoch 5/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.2058 - accuracy: 0.9004 - val_loss: 0.2381 - val_accuracy: 0.9111
#
# Epoch 00005: val_accuracy improved from 0.89444 to 0.91111, saving model to ./models/tree_11/model_root_f1_1_1_1/folder1\model.h5
# Epoch 6/30
# 158/158 [==============================] - 3s 20ms/step - loss: 0.1821 - accuracy: 0.9185 - val_loss: 0.1780 - val_accuracy: 0.9361
#
# Epoch 00006: val_accuracy improved from 0.91111 to 0.93611, saving model to ./models/tree_11/model_root_f1_1_1_1/folder1\model.h5
# Epoch 7/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.1631 - accuracy: 0.9306 - val_loss: 0.2211 - val_accuracy: 0.8944
#
# Epoch 00007: val_accuracy did not improve from 0.93611
# Epoch 8/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.1265 - accuracy: 0.9486 - val_loss: 0.1746 - val_accuracy: 0.9250
#
# Epoch 00008: val_accuracy did not improve from 0.93611
# Epoch 9/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.1008 - accuracy: 0.9585 - val_loss: 0.1361 - val_accuracy: 0.9500
#
# Epoch 00009: val_accuracy improved from 0.93611 to 0.95000, saving model to ./models/tree_11/model_root_f1_1_1_1/folder1\model.h5
# Epoch 10/30
# 158/158 [==============================] - 3s 22ms/step - loss: 0.0616 - accuracy: 0.9788 - val_loss: 0.1532 - val_accuracy: 0.9500
#
# Epoch 00010: val_accuracy did not improve from 0.95000
# Epoch 11/30
# 158/158 [==============================] - 4s 23ms/step - loss: 0.0575 - accuracy: 0.9790 - val_loss: 0.1683 - val_accuracy: 0.9472
#
# Epoch 00011: val_accuracy did not improve from 0.95000
# Epoch 12/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0294 - accuracy: 0.9909 - val_loss: 0.1562 - val_accuracy: 0.9472
#
# Epoch 00012: val_accuracy did not improve from 0.95000
# Epoch 13/30
# 158/158 [==============================] - 3s 20ms/step - loss: 0.0186 - accuracy: 0.9935 - val_loss: 0.2339 - val_accuracy: 0.9417
#
# Epoch 00013: val_accuracy did not improve from 0.95000
# Epoch 14/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0077 - accuracy: 0.9978 - val_loss: 0.2296 - val_accuracy: 0.9500
#
# Epoch 00014: val_accuracy did not improve from 0.95000
# Epoch 15/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0025 - accuracy: 0.9996 - val_loss: 0.2814 - val_accuracy: 0.9389
#
# Epoch 00015: val_accuracy did not improve from 0.95000
# Epoch 16/30
# 158/158 [==============================] - 3s 18ms/step - loss: 4.6422e-04 - accuracy: 1.0000 - val_loss: 0.2880 - val_accuracy: 0.9472
#
# Epoch 00016: val_accuracy did not improve from 0.95000
# Epoch 17/30
# 158/158 [==============================] - 3s 18ms/step - loss: 1.9625e-04 - accuracy: 1.0000 - val_loss: 0.2883 - val_accuracy: 0.9500
#
# Epoch 00017: val_accuracy did not improve from 0.95000
# Epoch 18/30
# 158/158 [==============================] - 3s 19ms/step - loss: 1.3504e-04 - accuracy: 1.0000 - val_loss: 0.2923 - val_accuracy: 0.9500
#
# Epoch 00018: val_accuracy did not improve from 0.95000
# Epoch 19/30
# 158/158 [==============================] - 3s 19ms/step - loss: 1.0517e-04 - accuracy: 1.0000 - val_loss: 0.2976 - val_accuracy: 0.9528
#
# Epoch 00019: val_accuracy improved from 0.95000 to 0.95278, saving model to ./models/tree_11/model_root_f1_1_1_1/folder1\model.h5
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/30
# 158/158 [==============================] - 3s 19ms/step - loss: 8.6399e-05 - accuracy: 1.0000 - val_loss: 0.2989 - val_accuracy: 0.9528
#
# Epoch 00020: val_accuracy did not improve from 0.95278
# Epoch 21/30
# 158/158 [==============================] - 3s 18ms/step - loss: 7.7844e-05 - accuracy: 1.0000 - val_loss: 0.3004 - val_accuracy: 0.9500
#
# Epoch 00021: val_accuracy did not improve from 0.95278
# Epoch 22/30
# 158/158 [==============================] - 3s 18ms/step - loss: 7.0908e-05 - accuracy: 1.0000 - val_loss: 0.3027 - val_accuracy: 0.9500
#
# Epoch 00022: val_accuracy did not improve from 0.95278
# Epoch 23/30
# 158/158 [==============================] - 3s 18ms/step - loss: 6.4815e-05 - accuracy: 1.0000 - val_loss: 0.3050 - val_accuracy: 0.9500
#
# Epoch 00023: val_accuracy did not improve from 0.95278
# Epoch 24/30
# 158/158 [==============================] - 3s 18ms/step - loss: 5.8615e-05 - accuracy: 1.0000 - val_loss: 0.3052 - val_accuracy: 0.9472
#
# Epoch 00024: val_accuracy did not improve from 0.95278
# Epoch 25/30
# 158/158 [==============================] - 3s 18ms/step - loss: 5.3189e-05 - accuracy: 1.0000 - val_loss: 0.3082 - val_accuracy: 0.9528
#
# Epoch 00025: val_accuracy did not improve from 0.95278
# Epoch 26/30
# 158/158 [==============================] - 3s 18ms/step - loss: 4.8295e-05 - accuracy: 1.0000 - val_loss: 0.3099 - val_accuracy: 0.9528
#
# Epoch 00026: val_accuracy did not improve from 0.95278
# Epoch 27/30
# 158/158 [==============================] - 3s 18ms/step - loss: 4.3996e-05 - accuracy: 1.0000 - val_loss: 0.3110 - val_accuracy: 0.9472
#
# Epoch 00027: val_accuracy did not improve from 0.95278
# Epoch 28/30
# 158/158 [==============================] - 3s 18ms/step - loss: 4.0097e-05 - accuracy: 1.0000 - val_loss: 0.3131 - val_accuracy: 0.9528
#
# Epoch 00028: val_accuracy did not improve from 0.95278
# Epoch 29/30
# 158/158 [==============================] - 3s 18ms/step - loss: 3.6690e-05 - accuracy: 1.0000 - val_loss: 0.3132 - val_accuracy: 0.9472
#
# Epoch 00029: val_accuracy did not improve from 0.95278
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 30/30
# 158/158 [==============================] - 3s 18ms/step - loss: 3.3717e-05 - accuracy: 1.0000 - val_loss: 0.3158 - val_accuracy: 0.9528
#
# Epoch 00030: val_accuracy did not improve from 0.95278
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 2
# Genre split [['Disco'], ['Country', 'Hip-Hop', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.4778 - accuracy: 0.8317 - val_loss: 0.4625 - val_accuracy: 0.8278
#
# Epoch 00001: val_accuracy improved from -inf to 0.82778, saving model to ./models/tree_11/model_root_f1_1_1_1/folder2\model.h5
# Epoch 2/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.4422 - accuracy: 0.8337 - val_loss: 0.4473 - val_accuracy: 0.8278
#
# Epoch 00002: val_accuracy did not improve from 0.82778
# Epoch 3/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.4422 - accuracy: 0.8310 - val_loss: 0.4594 - val_accuracy: 0.8278
#
# Epoch 00003: val_accuracy did not improve from 0.82778
# Epoch 4/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.4423 - accuracy: 0.8337 - val_loss: 0.4411 - val_accuracy: 0.8278
#
# Epoch 00004: val_accuracy did not improve from 0.82778
# Epoch 5/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.4365 - accuracy: 0.8337 - val_loss: 0.4424 - val_accuracy: 0.8278
#
# Epoch 00005: val_accuracy did not improve from 0.82778
# Epoch 6/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.4188 - accuracy: 0.8337 - val_loss: 0.3753 - val_accuracy: 0.8417
#
# Epoch 00006: val_accuracy improved from 0.82778 to 0.84167, saving model to ./models/tree_11/model_root_f1_1_1_1/folder2\model.h5
# Epoch 7/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.3129 - accuracy: 0.8750 - val_loss: 0.2968 - val_accuracy: 0.8861
#
# Epoch 00007: val_accuracy improved from 0.84167 to 0.88611, saving model to ./models/tree_11/model_root_f1_1_1_1/folder2\model.h5
# Epoch 8/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.2434 - accuracy: 0.9083 - val_loss: 0.2390 - val_accuracy: 0.9194
#
# Epoch 00008: val_accuracy improved from 0.88611 to 0.91944, saving model to ./models/tree_11/model_root_f1_1_1_1/folder2\model.h5
# Epoch 9/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.2022 - accuracy: 0.9290 - val_loss: 0.2843 - val_accuracy: 0.9111
#
# Epoch 00009: val_accuracy did not improve from 0.91944
# Epoch 10/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.1782 - accuracy: 0.9373 - val_loss: 0.2191 - val_accuracy: 0.9167
#
# Epoch 00010: val_accuracy did not improve from 0.91944
# Epoch 11/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.1586 - accuracy: 0.9448 - val_loss: 0.2656 - val_accuracy: 0.9306
#
# Epoch 00011: val_accuracy improved from 0.91944 to 0.93056, saving model to ./models/tree_11/model_root_f1_1_1_1/folder2\model.h5
# Epoch 12/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.1415 - accuracy: 0.9504 - val_loss: 0.2074 - val_accuracy: 0.9278
#
# Epoch 00012: val_accuracy did not improve from 0.93056
# Epoch 13/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.1048 - accuracy: 0.9647 - val_loss: 0.2369 - val_accuracy: 0.9361
#
# Epoch 00013: val_accuracy improved from 0.93056 to 0.93611, saving model to ./models/tree_11/model_root_f1_1_1_1/folder2\model.h5
# Epoch 14/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0961 - accuracy: 0.9645 - val_loss: 0.2755 - val_accuracy: 0.9361
#
# Epoch 00014: val_accuracy did not improve from 0.93611
# Epoch 15/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0851 - accuracy: 0.9712 - val_loss: 0.2699 - val_accuracy: 0.9278
#
# Epoch 00015: val_accuracy did not improve from 0.93611
# Epoch 16/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0513 - accuracy: 0.9841 - val_loss: 0.3160 - val_accuracy: 0.9333
#
# Epoch 00016: val_accuracy did not improve from 0.93611
# Epoch 17/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0461 - accuracy: 0.9849 - val_loss: 0.2676 - val_accuracy: 0.9278
#
# Epoch 00017: val_accuracy did not improve from 0.93611
# Epoch 18/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0504 - accuracy: 0.9831 - val_loss: 0.3246 - val_accuracy: 0.9333
#
# Epoch 00018: val_accuracy did not improve from 0.93611
# Epoch 19/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0485 - accuracy: 0.9833 - val_loss: 0.3081 - val_accuracy: 0.9333
#
# Epoch 00019: val_accuracy did not improve from 0.93611
# Epoch 20/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0178 - accuracy: 0.9944 - val_loss: 0.4003 - val_accuracy: 0.9500
#
# Epoch 00020: val_accuracy improved from 0.93611 to 0.95000, saving model to ./models/tree_11/model_root_f1_1_1_1/folder2\model.h5
# Epoch 21/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0228 - accuracy: 0.9909 - val_loss: 0.4297 - val_accuracy: 0.9139
#
# Epoch 00021: val_accuracy did not improve from 0.95000
# Epoch 22/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0287 - accuracy: 0.9895 - val_loss: 0.4817 - val_accuracy: 0.9250
#
# Epoch 00022: val_accuracy did not improve from 0.95000
# Epoch 23/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0268 - accuracy: 0.9925 - val_loss: 0.4682 - val_accuracy: 0.9250
#
# Epoch 00023: val_accuracy did not improve from 0.95000
# Epoch 24/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.5326 - val_accuracy: 0.9306
#
# Epoch 00024: val_accuracy did not improve from 0.95000
# Epoch 25/30
# 158/158 [==============================] - 3s 20ms/step - loss: 8.5758e-04 - accuracy: 1.0000 - val_loss: 0.5374 - val_accuracy: 0.9333
#
# Epoch 00025: val_accuracy did not improve from 0.95000
# Epoch 26/30
# 158/158 [==============================] - 3s 18ms/step - loss: 4.6018e-04 - accuracy: 1.0000 - val_loss: 0.5508 - val_accuracy: 0.9250
#
# Epoch 00026: val_accuracy did not improve from 0.95000
# Epoch 27/30
# 158/158 [==============================] - 3s 20ms/step - loss: 2.9749e-04 - accuracy: 1.0000 - val_loss: 0.5657 - val_accuracy: 0.9278
#
# Epoch 00027: val_accuracy did not improve from 0.95000
# Epoch 28/30
# 158/158 [==============================] - 3s 20ms/step - loss: 2.2677e-04 - accuracy: 1.0000 - val_loss: 0.5786 - val_accuracy: 0.9278
#
# Epoch 00028: val_accuracy did not improve from 0.95000
# Epoch 29/30
# 158/158 [==============================] - 3s 19ms/step - loss: 1.8474e-04 - accuracy: 1.0000 - val_loss: 0.5923 - val_accuracy: 0.9278
#
# Epoch 00029: val_accuracy did not improve from 0.95000
# Epoch 30/30
# 158/158 [==============================] - 3s 18ms/step - loss: 1.5520e-04 - accuracy: 1.0000 - val_loss: 0.5972 - val_accuracy: 0.9278
#
# Epoch 00030: val_accuracy did not improve from 0.95000
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 3
# Genre split [['Hip-Hop'], ['Country', 'Disco', 'Pop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 158/158 [==============================] - 4s 20ms/step - loss: 0.4677 - accuracy: 0.8198 - val_loss: 0.3512 - val_accuracy: 0.8222
#
# Epoch 00001: val_accuracy improved from -inf to 0.82222, saving model to ./models/tree_11/model_root_f1_1_1_1/folder3\model.h5
# Epoch 2/30
# 158/158 [==============================] - 3s 20ms/step - loss: 0.3331 - accuracy: 0.8478 - val_loss: 0.2888 - val_accuracy: 0.8667
#
# Epoch 00002: val_accuracy improved from 0.82222 to 0.86667, saving model to ./models/tree_11/model_root_f1_1_1_1/folder3\model.h5
# Epoch 3/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.2782 - accuracy: 0.8875 - val_loss: 0.2533 - val_accuracy: 0.9000
#
# Epoch 00003: val_accuracy improved from 0.86667 to 0.90000, saving model to ./models/tree_11/model_root_f1_1_1_1/folder3\model.h5
# Epoch 4/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.2229 - accuracy: 0.9071 - val_loss: 0.2118 - val_accuracy: 0.9167
#
# Epoch 00004: val_accuracy improved from 0.90000 to 0.91667, saving model to ./models/tree_11/model_root_f1_1_1_1/folder3\model.h5
# Epoch 5/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.1877 - accuracy: 0.9214 - val_loss: 0.2105 - val_accuracy: 0.9306
#
# Epoch 00005: val_accuracy improved from 0.91667 to 0.93056, saving model to ./models/tree_11/model_root_f1_1_1_1/folder3\model.h5
# Epoch 6/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.1444 - accuracy: 0.9405 - val_loss: 0.1945 - val_accuracy: 0.9278
#
# Epoch 00006: val_accuracy did not improve from 0.93056
# Epoch 7/30
# 158/158 [==============================] - 4s 25ms/step - loss: 0.1253 - accuracy: 0.9502 - val_loss: 0.1788 - val_accuracy: 0.9417
#
# Epoch 00007: val_accuracy improved from 0.93056 to 0.94167, saving model to ./models/tree_11/model_root_f1_1_1_1/folder3\model.h5
# Epoch 8/30
# 158/158 [==============================] - 3s 22ms/step - loss: 0.0773 - accuracy: 0.9698 - val_loss: 0.2210 - val_accuracy: 0.9500
#
# Epoch 00008: val_accuracy improved from 0.94167 to 0.95000, saving model to ./models/tree_11/model_root_f1_1_1_1/folder3\model.h5
# Epoch 9/30
# 158/158 [==============================] - 3s 20ms/step - loss: 0.0330 - accuracy: 0.9907 - val_loss: 0.2073 - val_accuracy: 0.9500
#
# Epoch 00009: val_accuracy did not improve from 0.95000
# Epoch 10/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0252 - accuracy: 0.9917 - val_loss: 0.2670 - val_accuracy: 0.9444
#
# Epoch 00010: val_accuracy did not improve from 0.95000
# Epoch 11/30
# 158/158 [==============================] - 3s 20ms/step - loss: 0.0290 - accuracy: 0.9903 - val_loss: 0.2493 - val_accuracy: 0.9500
#
# Epoch 00011: val_accuracy did not improve from 0.95000
# Epoch 12/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.2469 - val_accuracy: 0.9417
#
# Epoch 00012: val_accuracy did not improve from 0.95000
# Epoch 13/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0219 - accuracy: 0.9923 - val_loss: 0.2589 - val_accuracy: 0.9556
#
# Epoch 00013: val_accuracy improved from 0.95000 to 0.95556, saving model to ./models/tree_11/model_root_f1_1_1_1/folder3\model.h5
# Epoch 14/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2701 - val_accuracy: 0.9667
#
# Epoch 00014: val_accuracy improved from 0.95556 to 0.96667, saving model to ./models/tree_11/model_root_f1_1_1_1/folder3\model.h5
# Epoch 15/30
# 158/158 [==============================] - 3s 19ms/step - loss: 3.6456e-04 - accuracy: 1.0000 - val_loss: 0.3080 - val_accuracy: 0.9611
#
# Epoch 00015: val_accuracy did not improve from 0.96667
# Epoch 16/30
# 158/158 [==============================] - 3s 19ms/step - loss: 1.6547e-04 - accuracy: 1.0000 - val_loss: 0.3130 - val_accuracy: 0.9611
#
# Epoch 00016: val_accuracy did not improve from 0.96667
# Epoch 17/30
# 158/158 [==============================] - 3s 19ms/step - loss: 1.1963e-04 - accuracy: 1.0000 - val_loss: 0.3257 - val_accuracy: 0.9611
#
# Epoch 00017: val_accuracy did not improve from 0.96667
# Epoch 18/30
# 158/158 [==============================] - 3s 19ms/step - loss: 9.3763e-05 - accuracy: 1.0000 - val_loss: 0.3371 - val_accuracy: 0.9611
#
# Epoch 00018: val_accuracy did not improve from 0.96667
# Epoch 19/30
# 158/158 [==============================] - 3s 19ms/step - loss: 7.5203e-05 - accuracy: 1.0000 - val_loss: 0.3386 - val_accuracy: 0.9611
#
# Epoch 00019: val_accuracy did not improve from 0.96667
# Epoch 20/30
# 158/158 [==============================] - 3s 18ms/step - loss: 6.2974e-05 - accuracy: 1.0000 - val_loss: 0.3448 - val_accuracy: 0.9611
#
# Epoch 00020: val_accuracy did not improve from 0.96667
# Epoch 21/30
# 158/158 [==============================] - 3s 19ms/step - loss: 5.2306e-05 - accuracy: 1.0000 - val_loss: 0.3489 - val_accuracy: 0.9611
#
# Epoch 00021: val_accuracy did not improve from 0.96667
# Epoch 22/30
# 158/158 [==============================] - 3s 18ms/step - loss: 4.4252e-05 - accuracy: 1.0000 - val_loss: 0.3564 - val_accuracy: 0.9611
#
# Epoch 00022: val_accuracy did not improve from 0.96667
# Epoch 23/30
# 158/158 [==============================] - 3s 19ms/step - loss: 3.7778e-05 - accuracy: 1.0000 - val_loss: 0.3568 - val_accuracy: 0.9611
#
# Epoch 00023: val_accuracy did not improve from 0.96667
# Epoch 24/30
# 158/158 [==============================] - 3s 19ms/step - loss: 3.1889e-05 - accuracy: 1.0000 - val_loss: 0.3620 - val_accuracy: 0.9611
#
# Epoch 00024: val_accuracy did not improve from 0.96667
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 25/30
# 158/158 [==============================] - 3s 19ms/step - loss: 2.6555e-05 - accuracy: 1.0000 - val_loss: 0.3703 - val_accuracy: 0.9611
#
# Epoch 00025: val_accuracy did not improve from 0.96667
# Epoch 26/30
# 158/158 [==============================] - 3s 19ms/step - loss: 2.3451e-05 - accuracy: 1.0000 - val_loss: 0.3826 - val_accuracy: 0.9583
#
# Epoch 00026: val_accuracy did not improve from 0.96667
# Epoch 27/30
# 158/158 [==============================] - 3s 19ms/step - loss: 2.0667e-05 - accuracy: 1.0000 - val_loss: 0.3799 - val_accuracy: 0.9583
#
# Epoch 00027: val_accuracy did not improve from 0.96667
# Epoch 28/30
# 158/158 [==============================] - 3s 19ms/step - loss: 1.7902e-05 - accuracy: 1.0000 - val_loss: 0.4009 - val_accuracy: 0.9556
#
# Epoch 00028: val_accuracy did not improve from 0.96667
# Epoch 29/30
# 158/158 [==============================] - 3s 20ms/step - loss: 1.5608e-05 - accuracy: 1.0000 - val_loss: 0.4037 - val_accuracy: 0.9583
#
# Epoch 00029: val_accuracy did not improve from 0.96667
# Epoch 30/30
# 158/158 [==============================] - 3s 19ms/step - loss: 1.3943e-05 - accuracy: 1.0000 - val_loss: 0.4034 - val_accuracy: 0.9556
#
# Epoch 00030: val_accuracy did not improve from 0.96667
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 4
# Genre split [['Pop'], ['Country', 'Disco', 'Hip-Hop', 'Reggae', 'Rock']]
# Building model...
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 158/158 [==============================] - 4s 20ms/step - loss: 0.3963 - accuracy: 0.8403 - val_loss: 0.2154 - val_accuracy: 0.9194
#
# Epoch 00001: val_accuracy improved from -inf to 0.91944, saving model to ./models/tree_11/model_root_f1_1_1_1/folder4\model.h5
# Epoch 2/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.2564 - accuracy: 0.8875 - val_loss: 0.2038 - val_accuracy: 0.9083
#
# Epoch 00002: val_accuracy did not improve from 0.91944
# Epoch 3/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.2243 - accuracy: 0.9087 - val_loss: 0.1650 - val_accuracy: 0.9472
#
# Epoch 00003: val_accuracy improved from 0.91944 to 0.94722, saving model to ./models/tree_11/model_root_f1_1_1_1/folder4\model.h5
# Epoch 4/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.2030 - accuracy: 0.9165 - val_loss: 0.1723 - val_accuracy: 0.9361
#
# Epoch 00004: val_accuracy did not improve from 0.94722
# Epoch 5/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.1982 - accuracy: 0.9194 - val_loss: 0.1865 - val_accuracy: 0.9306
#
# Epoch 00005: val_accuracy did not improve from 0.94722
# Epoch 6/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.2009 - accuracy: 0.9187 - val_loss: 0.1775 - val_accuracy: 0.9250
#
# Epoch 00006: val_accuracy did not improve from 0.94722
# Epoch 7/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.1846 - accuracy: 0.9250 - val_loss: 0.1392 - val_accuracy: 0.9528
#
# Epoch 00007: val_accuracy improved from 0.94722 to 0.95278, saving model to ./models/tree_11/model_root_f1_1_1_1/folder4\model.h5
# Epoch 8/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.1769 - accuracy: 0.9313 - val_loss: 0.1735 - val_accuracy: 0.9333
#
# Epoch 00008: val_accuracy did not improve from 0.95278
# Epoch 9/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.1687 - accuracy: 0.9365 - val_loss: 0.1410 - val_accuracy: 0.9556
#
# Epoch 00009: val_accuracy improved from 0.95278 to 0.95556, saving model to ./models/tree_11/model_root_f1_1_1_1/folder4\model.h5
# Epoch 10/30
# 158/158 [==============================] - 3s 20ms/step - loss: 0.1660 - accuracy: 0.9367 - val_loss: 0.1319 - val_accuracy: 0.9500
#
# Epoch 00010: val_accuracy did not improve from 0.95556
# Epoch 11/30
# 158/158 [==============================] - 3s 20ms/step - loss: 0.1579 - accuracy: 0.9413 - val_loss: 0.1562 - val_accuracy: 0.9333
#
# Epoch 00011: val_accuracy did not improve from 0.95556
# Epoch 12/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.1524 - accuracy: 0.9403 - val_loss: 0.1391 - val_accuracy: 0.9583
#
# Epoch 00012: val_accuracy improved from 0.95556 to 0.95833, saving model to ./models/tree_11/model_root_f1_1_1_1/folder4\model.h5
# Epoch 13/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.1567 - accuracy: 0.9407 - val_loss: 0.1367 - val_accuracy: 0.9528
#
# Epoch 00013: val_accuracy did not improve from 0.95833
# Epoch 14/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.1405 - accuracy: 0.9448 - val_loss: 0.1318 - val_accuracy: 0.9417
#
# Epoch 00014: val_accuracy did not improve from 0.95833
# Epoch 15/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.1370 - accuracy: 0.9464 - val_loss: 0.1337 - val_accuracy: 0.9611
#
# Epoch 00015: val_accuracy improved from 0.95833 to 0.96111, saving model to ./models/tree_11/model_root_f1_1_1_1/folder4\model.h5
# Epoch 16/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.1306 - accuracy: 0.9524 - val_loss: 0.1157 - val_accuracy: 0.9639
#
# Epoch 00016: val_accuracy improved from 0.96111 to 0.96389, saving model to ./models/tree_11/model_root_f1_1_1_1/folder4\model.h5
# Epoch 17/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.1206 - accuracy: 0.9546 - val_loss: 0.1348 - val_accuracy: 0.9556
#
# Epoch 00017: val_accuracy did not improve from 0.96389
# Epoch 18/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.1130 - accuracy: 0.9567 - val_loss: 0.1314 - val_accuracy: 0.9472
#
# Epoch 00018: val_accuracy did not improve from 0.96389
# Epoch 19/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.1005 - accuracy: 0.9623 - val_loss: 0.1393 - val_accuracy: 0.9583
#
# Epoch 00019: val_accuracy did not improve from 0.96389
# Epoch 20/30
# 158/158 [==============================] - 3s 20ms/step - loss: 0.0943 - accuracy: 0.9597 - val_loss: 0.1130 - val_accuracy: 0.9583
#
# Epoch 00020: val_accuracy did not improve from 0.96389
# Epoch 21/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0839 - accuracy: 0.9683 - val_loss: 0.1308 - val_accuracy: 0.9611
#
# Epoch 00021: val_accuracy did not improve from 0.96389
# Epoch 22/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0695 - accuracy: 0.9720 - val_loss: 0.1134 - val_accuracy: 0.9639
#
# Epoch 00022: val_accuracy did not improve from 0.96389
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 23/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0429 - accuracy: 0.9859 - val_loss: 0.1395 - val_accuracy: 0.9472
#
# Epoch 00023: val_accuracy did not improve from 0.96389
# Epoch 24/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0369 - accuracy: 0.9877 - val_loss: 0.1375 - val_accuracy: 0.9722
#
# Epoch 00024: val_accuracy improved from 0.96389 to 0.97222, saving model to ./models/tree_11/model_root_f1_1_1_1/folder4\model.h5
# Epoch 25/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0283 - accuracy: 0.9917 - val_loss: 0.1318 - val_accuracy: 0.9611
#
# Epoch 00025: val_accuracy did not improve from 0.97222
# Epoch 26/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0203 - accuracy: 0.9950 - val_loss: 0.1511 - val_accuracy: 0.9667
#
# Epoch 00026: val_accuracy did not improve from 0.97222
# Epoch 27/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0171 - accuracy: 0.9958 - val_loss: 0.1534 - val_accuracy: 0.9667
#
# Epoch 00027: val_accuracy did not improve from 0.97222
# Epoch 28/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0137 - accuracy: 0.9972 - val_loss: 0.1661 - val_accuracy: 0.9667
#
# Epoch 00028: val_accuracy did not improve from 0.97222
# Epoch 29/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0097 - accuracy: 0.9984 - val_loss: 0.1678 - val_accuracy: 0.9611
#
# Epoch 00029: val_accuracy did not improve from 0.97222
# Epoch 30/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0087 - accuracy: 0.9990 - val_loss: 0.1933 - val_accuracy: 0.9611
#
# Epoch 00030: val_accuracy did not improve from 0.97222
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 5
# Genre split [['Reggae'], ['Country', 'Disco', 'Hip-Hop', 'Pop', 'Rock']]
# Building model...
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 158/158 [==============================] - 4s 21ms/step - loss: 0.5047 - accuracy: 0.8286 - val_loss: 0.4812 - val_accuracy: 0.8139
#
# Epoch 00001: val_accuracy improved from -inf to 0.81389, saving model to ./models/tree_11/model_root_f1_1_1_1/folder5\model.h5
# Epoch 2/30
# 158/158 [==============================] - 3s 22ms/step - loss: 0.4163 - accuracy: 0.8429 - val_loss: 0.4316 - val_accuracy: 0.8472
#
# Epoch 00002: val_accuracy improved from 0.81389 to 0.84722, saving model to ./models/tree_11/model_root_f1_1_1_1/folder5\model.h5
# Epoch 3/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.3334 - accuracy: 0.8671 - val_loss: 0.4305 - val_accuracy: 0.8306
#
# Epoch 00003: val_accuracy did not improve from 0.84722
# Epoch 4/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.2872 - accuracy: 0.8863 - val_loss: 0.3197 - val_accuracy: 0.8611
#
# Epoch 00004: val_accuracy improved from 0.84722 to 0.86111, saving model to ./models/tree_11/model_root_f1_1_1_1/folder5\model.h5
# Epoch 5/30
# 158/158 [==============================] - 3s 20ms/step - loss: 0.2441 - accuracy: 0.9091 - val_loss: 0.2897 - val_accuracy: 0.9028
#
# Epoch 00005: val_accuracy improved from 0.86111 to 0.90278, saving model to ./models/tree_11/model_root_f1_1_1_1/folder5\model.h5
# Epoch 6/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.2163 - accuracy: 0.9117 - val_loss: 0.2537 - val_accuracy: 0.9083
#
# Epoch 00006: val_accuracy improved from 0.90278 to 0.90833, saving model to ./models/tree_11/model_root_f1_1_1_1/folder5\model.h5
# Epoch 7/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.1816 - accuracy: 0.9321 - val_loss: 0.2168 - val_accuracy: 0.9000
#
# Epoch 00007: val_accuracy did not improve from 0.90833
# Epoch 8/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.1342 - accuracy: 0.9504 - val_loss: 0.3290 - val_accuracy: 0.8944
#
# Epoch 00008: val_accuracy did not improve from 0.90833
# Epoch 9/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.1211 - accuracy: 0.9538 - val_loss: 0.2945 - val_accuracy: 0.9028
#
# Epoch 00009: val_accuracy did not improve from 0.90833
# Epoch 10/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0846 - accuracy: 0.9696 - val_loss: 0.1714 - val_accuracy: 0.9278
#
# Epoch 00010: val_accuracy improved from 0.90833 to 0.92778, saving model to ./models/tree_11/model_root_f1_1_1_1/folder5\model.h5
# Epoch 11/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0667 - accuracy: 0.9778 - val_loss: 0.2110 - val_accuracy: 0.9083
#
# Epoch 00011: val_accuracy did not improve from 0.92778
# Epoch 12/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0352 - accuracy: 0.9891 - val_loss: 0.2405 - val_accuracy: 0.9222
#
# Epoch 00012: val_accuracy did not improve from 0.92778
# Epoch 13/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0346 - accuracy: 0.9873 - val_loss: 0.1942 - val_accuracy: 0.9306
#
# Epoch 00013: val_accuracy improved from 0.92778 to 0.93056, saving model to ./models/tree_11/model_root_f1_1_1_1/folder5\model.h5
# Epoch 14/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0286 - accuracy: 0.9905 - val_loss: 0.2347 - val_accuracy: 0.9333
#
# Epoch 00014: val_accuracy improved from 0.93056 to 0.93333, saving model to ./models/tree_11/model_root_f1_1_1_1/folder5\model.h5
# Epoch 15/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0364 - accuracy: 0.9859 - val_loss: 0.2595 - val_accuracy: 0.9417
#
# Epoch 00015: val_accuracy improved from 0.93333 to 0.94167, saving model to ./models/tree_11/model_root_f1_1_1_1/folder5\model.h5
# Epoch 16/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0073 - accuracy: 0.9982 - val_loss: 0.3107 - val_accuracy: 0.9361
#
# Epoch 00016: val_accuracy did not improve from 0.94167
# Epoch 17/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0453 - accuracy: 0.9841 - val_loss: 0.3187 - val_accuracy: 0.9139
#
# Epoch 00017: val_accuracy did not improve from 0.94167
# Epoch 18/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0082 - accuracy: 0.9980 - val_loss: 0.2757 - val_accuracy: 0.9278
#
# Epoch 00018: val_accuracy did not improve from 0.94167
# Epoch 19/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.3828 - val_accuracy: 0.9333
#
# Epoch 00019: val_accuracy did not improve from 0.94167
# Epoch 20/30
# 158/158 [==============================] - 3s 20ms/step - loss: 3.2609e-04 - accuracy: 1.0000 - val_loss: 0.3109 - val_accuracy: 0.9333
#
# Epoch 00020: val_accuracy did not improve from 0.94167
# Epoch 21/30
# 158/158 [==============================] - 3s 19ms/step - loss: 1.6377e-04 - accuracy: 1.0000 - val_loss: 0.3202 - val_accuracy: 0.9306
#
# Epoch 00021: val_accuracy did not improve from 0.94167
# Epoch 22/30
# 158/158 [==============================] - 3s 19ms/step - loss: 1.1996e-04 - accuracy: 1.0000 - val_loss: 0.3362 - val_accuracy: 0.9278
#
# Epoch 00022: val_accuracy did not improve from 0.94167
# Epoch 23/30
# 158/158 [==============================] - 3s 19ms/step - loss: 9.8354e-05 - accuracy: 1.0000 - val_loss: 0.3374 - val_accuracy: 0.9278
#
# Epoch 00023: val_accuracy did not improve from 0.94167
# Epoch 24/30
# 158/158 [==============================] - 3s 18ms/step - loss: 7.9327e-05 - accuracy: 1.0000 - val_loss: 0.3314 - val_accuracy: 0.9306
#
# Epoch 00024: val_accuracy did not improve from 0.94167
# Epoch 25/30
# 158/158 [==============================] - 3s 19ms/step - loss: 6.6391e-05 - accuracy: 1.0000 - val_loss: 0.3357 - val_accuracy: 0.9306
#
# Epoch 00025: val_accuracy did not improve from 0.94167
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 26/30
# 158/158 [==============================] - 3s 19ms/step - loss: 5.7170e-05 - accuracy: 1.0000 - val_loss: 0.3399 - val_accuracy: 0.9306
#
# Epoch 00026: val_accuracy did not improve from 0.94167
# Epoch 27/30
# 158/158 [==============================] - 3s 19ms/step - loss: 5.3093e-05 - accuracy: 1.0000 - val_loss: 0.3364 - val_accuracy: 0.9361
#
# Epoch 00027: val_accuracy did not improve from 0.94167
# Epoch 28/30
# 158/158 [==============================] - 3s 19ms/step - loss: 4.9319e-05 - accuracy: 1.0000 - val_loss: 0.3367 - val_accuracy: 0.9389
#
# Epoch 00028: val_accuracy did not improve from 0.94167
# Epoch 29/30
# 158/158 [==============================] - 3s 19ms/step - loss: 4.5731e-05 - accuracy: 1.0000 - val_loss: 0.3429 - val_accuracy: 0.9306
#
# Epoch 00029: val_accuracy did not improve from 0.94167
# Epoch 30/30
# 158/158 [==============================] - 3s 19ms/step - loss: 4.2417e-05 - accuracy: 1.0000 - val_loss: 0.3431 - val_accuracy: 0.9361
#
# Epoch 00030: val_accuracy did not improve from 0.94167
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
# Folder num 6
# Genre split [['Rock'], ['Country', 'Disco', 'Hip-Hop', 'Pop', 'Reggae']]
# Building model...
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv_1 (Conv2D)              (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 12, 12, 512)       590336
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# preds (Dense)                (None, 2)                 36866
# =================================================================
# Total params: 719,874
# Trainable params: 719,874
# Non-trainable params: 0
# _________________________________________________________________
# None
# Training...
# Epoch 1/30
# 158/158 [==============================] - 4s 20ms/step - loss: 0.4532 - accuracy: 0.8331 - val_loss: 0.4057 - val_accuracy: 0.8417
#
# Epoch 00001: val_accuracy improved from -inf to 0.84167, saving model to ./models/tree_11/model_root_f1_1_1_1/folder6\model.h5
# Epoch 2/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.3882 - accuracy: 0.8466 - val_loss: 0.4066 - val_accuracy: 0.8444
#
# Epoch 00002: val_accuracy improved from 0.84167 to 0.84444, saving model to ./models/tree_11/model_root_f1_1_1_1/folder6\model.h5
# Epoch 3/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.3354 - accuracy: 0.8611 - val_loss: 0.2429 - val_accuracy: 0.8889
#
# Epoch 00003: val_accuracy improved from 0.84444 to 0.88889, saving model to ./models/tree_11/model_root_f1_1_1_1/folder6\model.h5
# Epoch 4/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.2893 - accuracy: 0.8734 - val_loss: 0.2265 - val_accuracy: 0.9000
#
# Epoch 00004: val_accuracy improved from 0.88889 to 0.90000, saving model to ./models/tree_11/model_root_f1_1_1_1/folder6\model.h5
# Epoch 5/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.2493 - accuracy: 0.8915 - val_loss: 0.2513 - val_accuracy: 0.8694
#
# Epoch 00005: val_accuracy did not improve from 0.90000
# Epoch 6/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.2306 - accuracy: 0.8996 - val_loss: 0.2243 - val_accuracy: 0.9028
#
# Epoch 00006: val_accuracy improved from 0.90000 to 0.90278, saving model to ./models/tree_11/model_root_f1_1_1_1/folder6\model.h5
# Epoch 7/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.1852 - accuracy: 0.9212 - val_loss: 0.2709 - val_accuracy: 0.8528
#
# Epoch 00007: val_accuracy did not improve from 0.90278
# Epoch 8/30
# 158/158 [==============================] - 3s 20ms/step - loss: 0.1852 - accuracy: 0.9208 - val_loss: 0.2253 - val_accuracy: 0.9250
#
# Epoch 00008: val_accuracy improved from 0.90278 to 0.92500, saving model to ./models/tree_11/model_root_f1_1_1_1/folder6\model.h5
# Epoch 9/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.1511 - accuracy: 0.9391 - val_loss: 0.1697 - val_accuracy: 0.9417
#
# Epoch 00009: val_accuracy improved from 0.92500 to 0.94167, saving model to ./models/tree_11/model_root_f1_1_1_1/folder6\model.h5
# Epoch 10/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.1192 - accuracy: 0.9548 - val_loss: 0.2003 - val_accuracy: 0.9250
#
# Epoch 00010: val_accuracy did not improve from 0.94167
# Epoch 11/30
# 158/158 [==============================] - 3s 20ms/step - loss: 0.0922 - accuracy: 0.9649 - val_loss: 0.2993 - val_accuracy: 0.8917
#
# Epoch 00011: val_accuracy did not improve from 0.94167
# Epoch 12/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0712 - accuracy: 0.9722 - val_loss: 0.1878 - val_accuracy: 0.9306
#
# Epoch 00012: val_accuracy did not improve from 0.94167
# Epoch 13/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0415 - accuracy: 0.9865 - val_loss: 0.2550 - val_accuracy: 0.9306
#
# Epoch 00013: val_accuracy did not improve from 0.94167
# Epoch 14/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0525 - accuracy: 0.9827 - val_loss: 0.2481 - val_accuracy: 0.9333
#
# Epoch 00014: val_accuracy did not improve from 0.94167
# Epoch 15/30
# 158/158 [==============================] - 3s 18ms/step - loss: 0.0253 - accuracy: 0.9923 - val_loss: 0.2894 - val_accuracy: 0.9417
#
# Epoch 00015: val_accuracy did not improve from 0.94167
# Epoch 16/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0084 - accuracy: 0.9984 - val_loss: 0.3299 - val_accuracy: 0.9278
#
# Epoch 00016: val_accuracy did not improve from 0.94167
# Epoch 17/30
# 158/158 [==============================] - 3s 19ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.3456 - val_accuracy: 0.9389
#
# Epoch 00017: val_accuracy did not improve from 0.94167
# Epoch 18/30
# 158/158 [==============================] - 3s 19ms/step - loss: 6.1044e-04 - accuracy: 1.0000 - val_loss: 0.3625 - val_accuracy: 0.9361
#
# Epoch 00018: val_accuracy did not improve from 0.94167
# Epoch 19/30
# 158/158 [==============================] - 3s 18ms/step - loss: 3.4997e-04 - accuracy: 1.0000 - val_loss: 0.3736 - val_accuracy: 0.9361
#
# Epoch 00019: val_accuracy did not improve from 0.94167
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 20/30
# 158/158 [==============================] - 3s 18ms/step - loss: 2.5773e-04 - accuracy: 1.0000 - val_loss: 0.3796 - val_accuracy: 0.9389
#
# Epoch 00020: val_accuracy did not improve from 0.94167
# Epoch 21/30
# 158/158 [==============================] - 3s 18ms/step - loss: 2.2457e-04 - accuracy: 1.0000 - val_loss: 0.3854 - val_accuracy: 0.9389
#
# Epoch 00021: val_accuracy did not improve from 0.94167
# Epoch 22/30
# 158/158 [==============================] - 3s 20ms/step - loss: 1.9718e-04 - accuracy: 1.0000 - val_loss: 0.3899 - val_accuracy: 0.9389
#
# Epoch 00022: val_accuracy did not improve from 0.94167
# Epoch 23/30
# 158/158 [==============================] - 3s 19ms/step - loss: 1.7486e-04 - accuracy: 1.0000 - val_loss: 0.3958 - val_accuracy: 0.9417
#
# Epoch 00023: val_accuracy did not improve from 0.94167
# Epoch 24/30
# 158/158 [==============================] - 3s 21ms/step - loss: 1.5531e-04 - accuracy: 1.0000 - val_loss: 0.3997 - val_accuracy: 0.9389
#
# Epoch 00024: val_accuracy did not improve from 0.94167
# Epoch 25/30
# 158/158 [==============================] - 3s 19ms/step - loss: 1.3864e-04 - accuracy: 1.0000 - val_loss: 0.4057 - val_accuracy: 0.9417
#
# Epoch 00025: val_accuracy did not improve from 0.94167
# Epoch 26/30
# 158/158 [==============================] - 3s 19ms/step - loss: 1.2360e-04 - accuracy: 1.0000 - val_loss: 0.4103 - val_accuracy: 0.9417
#
# Epoch 00026: val_accuracy did not improve from 0.94167
# Epoch 27/30
# 158/158 [==============================] - 3s 18ms/step - loss: 1.1071e-04 - accuracy: 1.0000 - val_loss: 0.4153 - val_accuracy: 0.9417
#
# Epoch 00027: val_accuracy did not improve from 0.94167
# Epoch 28/30
# 158/158 [==============================] - 3s 18ms/step - loss: 9.8150e-05 - accuracy: 1.0000 - val_loss: 0.4198 - val_accuracy: 0.9417
#
# Epoch 00028: val_accuracy did not improve from 0.94167
# Epoch 29/30
# 158/158 [==============================] - 3s 18ms/step - loss: 8.8465e-05 - accuracy: 1.0000 - val_loss: 0.4242 - val_accuracy: 0.9417
#
# Epoch 00029: val_accuracy did not improve from 0.94167
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 30/30
# 158/158 [==============================] - 3s 18ms/step - loss: 7.9529e-05 - accuracy: 1.0000 - val_loss: 0.4266 - val_accuracy: 0.9417
#
# Epoch 00030: val_accuracy did not improve from 0.94167
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])
